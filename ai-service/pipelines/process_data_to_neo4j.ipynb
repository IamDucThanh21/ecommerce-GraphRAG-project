# %%
iphone_data=[
    {'sku': 'iphone-17-pro-max', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'iOS 26', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '48MP', 'Aperture camera chính': 'ƒ/1.6', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '8x', 'Quay video camera sau': '4K@120fps', 'Chất lượng kính lens camera': 'Kính sapphire', 'Độ phân giải camera trước': '18MP', 'Aperture camera trước': 'ƒ/1.9', 'Quay video camera trước': '4K@60fps', 'Tính năng AI camera': 'Ảnh chân dung mới với Lấy nét và Điều khiển độ sâu, Chiếu sáng chân dung 6 chế độ, Chế độ Ban Đêm', 'Kích thước màn hình': '6.9 inches', 'Công nghệ màn hình': 'Super Retina XDR', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3000 nit', 'Chất lượng màu': 'P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2868 x 1320', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'A19 Pro', 'AnTuTu score': 2606807, 'Xếp loại chip': 'A+', 'RAM': 'N/A', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'GPU 6 lõi với Neural Accelerator', 'Hệ điều hành': 'iOS 26', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': 'N/A', 'Sạc có dây': '25W', 'Sạc không dây': '25W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7 (802.11be) với 2x2 MIMO11', 'Bluetooth': 'Bluetooth 6', 'GPS': 'GPS, GLONASS, Galileo, QZSS, BeiDou, NavIC', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM + eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.75 mm', 'Trọng lượng': '231 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': '3D Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '5', 'Thể thao / Outdoor (Đối tượng)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '5', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm (Apple iPhone)', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '5', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device (Apple A-series)', 'Danh sách tính năng AI thực tế': 'Ảnh chân dung mới với Lấy nét và Điều khiển độ sâu, Chiếu sáng chân dung 6 chế độ, Chế độ Ban Đêm, Visual Intelligence, Live Translation, Clean Up, Genmoji, Writing Tool, Siri', 'AI Score tổng hợp': '5'},
    {'sku': 'iphone-17-pro', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'iOS 26', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '48MP', 'Aperture camera chính': 'ƒ/1.6', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '8x', 'Quay video camera sau': '4K@120fps', 'Chất lượng kính lens camera': 'Kính sapphire', 'Độ phân giải camera trước': '18MP', 'Aperture camera trước': 'ƒ/1.9', 'Quay video camera trước': '4K@60fps', 'Tính năng AI camera': 'Ảnh chân dung mới với Lấy nét và Điều khiển độ sâu, Chiếu sáng chân dung 6 chế độ, Chế độ Ban Đêm', 'Kích thước màn hình': '6.3 inches', 'Công nghệ màn hình': 'Super Retina XDR', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3000 nit', 'Chất lượng màu': 'P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2622 x 1206 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'A19 Pro', 'AnTuTu score': 2606807, 'Xếp loại chip': 'A+', 'RAM': 'N/A', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'GPU 6 lõi với Neural Accelerator', 'Hệ điều hành': 'iOS 26', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': 'N/A', 'Sạc có dây': '25W', 'Sạc không dây': '25W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7', 'Bluetooth': 'Bluetooth 6', 'GPS': 'GPS, GLONASS, Galileo, QZSS, BeiDou, NavIC', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM + eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.75 mm', 'Trọng lượng': '204g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': '3D Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '5', 'Thể thao / Outdoor (Đối tượng)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '5', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '5', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device', 'Danh sách tính năng AI thực tế': ['Ảnh chân dung mới với Lấy nét và Điều khiển độ sâu', 'Chiếu sáng chân dung 6 chế độ', 'Chế độ Ban Đêm'], 'AI Score tổng hợp': '3'},
    {'sku': 'iphone-17-256gb', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 5, 'Phiên bản OS ra mắt': 'iOS 26', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '48MP', 'Aperture camera chính': 'f/1.6', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '2x', 'Quay video camera sau': '4K@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '18MP', 'Aperture camera trước': 'f/1.9', 'Quay video camera trước': '4K@60fps', 'Tính năng AI camera': 'Apple Intelligence, Siri mới, Nút tác vụ, SOS khẩn cấp, Phát hiện va chạm', 'Kích thước màn hình': '6.3 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3000 nit (ngoài trời)', 'Chất lượng màu': 'P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2622 x 1206', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A19', 'AnTuTu score': 2606807, 'Xếp loại chip': 'A+', 'RAM': 'N/A', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'GPU 5 lõi với Neural Accelerator', 'Hệ điều hành': 'iOS 26', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': 'N/A', 'Sạc có dây': '25W', 'Sạc không dây': '25W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7', 'Bluetooth': 'Bluetooth 6', 'GPS': 'GPS, GLONASS, Galileo, QZSS, BeiDou, NavIC', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM + eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.95 mm', 'Trọng lượng': '177 g', 'Số màu sắc': 5, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Không', 'Nhận diện khuôn mặt': '3D Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Âm thanh không gian, Thu âm stereo', 'Hỗ trợ AI': 'Apple Intelligence, Siri mới, Nút tác vụ, SOS khẩn cấp, Phát hiện va chạm', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'có', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'có', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '5', 'Thể thao / Outdoor (Use Case)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '4', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '4', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device', 'Danh sách tính năng AI thực tế': 'Apple Intelligence, Siri mới, Nút tác vụ, SOS khẩn cấp, Phát hiện va chạm, Night Mode, Portrait, Clean Up', 'AI Score tổng hợp': '5'},
    {'sku': 'iphone-16-pro-max', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'iOS 18', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '48MP', 'Aperture camera chính': 'f/1.78', 'OIS / Chống rung': 'Không có', 'Zoom quang học': '2x', 'Quay video camera sau': '4K@60 fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'ƒ/1.9', 'Quay video camera trước': '4K@60 fps', 'Tính năng AI camera': 'Flash True Tone, Photonic Engine, Deep Fusion, HDR thông minh thế hệ 5, Hiệu ứng Chiếu Sáng Chân Dung với sáu chế độ, Chế độ Ban Đêm, Chụp ảnh toàn cảnh Panorama (lên đến 63MP), Phong Cách Nhiếp Ảnh thế hệ mới nhất, Ảnh không gian', 'Kích thước màn hình': '6.9 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2868 x 1320', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A18 Pro', 'AnTuTu score': 2305678, 'Xếp loại chip': 'A+', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'GPU 6 lõi mới', 'Hệ điều hành': 'iOS 18', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': 'N/A', 'Sạc có dây': '25W', 'Sạc không dây': '25W', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7 (802.11be)', 'Bluetooth': '5.3', 'GPS': 'GPS, GLONASS, Galileo, QZSS, BeiDou, NavIC', 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Sim kép (nano-Sim và e-Sim) - Hỗ trợ 2 e-Sim', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Titanium', 'Độ mỏng': '8.25 mm', 'Trọng lượng': '227 gram', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'AAC, APAC, MP3, Apple Lossless, FLAC, Dolby Digital, Dolby Digital Plus, Dolby Atmos', 'Hỗ trợ AI': 'Face ID, FaceTime', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '5', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '5', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm (Apple iPhone)', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device', 'Danh sách tính năng AI thực tế': ['Flash True Tone', 'Photonic Engine', 'Deep Fusion', 'HDR thông minh thế hệ 5', 'Hiệu ứng Chiếu Sáng Chân Dung với sáu chế độ', 'Chế độ Ban Đêm', 'Chụp ảnh toàn cảnh Panorama (lên đến 63MP)', 'Phong Cách Nhiếp Ảnh thế hệ mới nhất', 'Ảnh không gian', 'Face ID', 'FaceTime'], 'AI Score tổng hợp': '5'},
    {'sku': 'iphone-air-256gb', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'iOS 26', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '48MP', 'Aperture camera chính': 'f/1.6', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '2x', 'Quay video camera sau': '4K@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '18MP', 'Aperture camera trước': 'f/1.6', 'Quay video camera trước': '4K@60fps', 'Tính năng AI camera': 'Apple Intelligence, Siri mới, Nút tác vụ, SOS khẩn cấp, Phát hiện va chạm, Face ID', 'Kích thước màn hình': '6.5 inches', 'Công nghệ màn hình': 'Super Retina XDR', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3000 nit', 'Chất lượng màu': 'P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2736 x 1260', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'A19 Pro', 'AnTuTu score': 2606807, 'Xếp loại chip': 'A+', 'RAM': 'N/A', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'GPU 5 lõi với Neural Accelerator', 'Hệ điều hành': 'iOS 26', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': 'N/A', 'Sạc có dây': '20W', 'Sạc không dây': '20W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7', 'Bluetooth': 'Bluetooth 6', 'GPS': 'GPS, GLONASS, Galileo, QZSS, BeiDou, NavIC', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Titanium', 'Độ mỏng': '5.6 mm', 'Trọng lượng': '165 g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Không', 'Nhận diện khuôn mặt': 'Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Âm thanh không gian', 'Hỗ trợ AI': 'Apple Intelligence, Siri mới, Nút tác vụ, SOS khẩn cấp, Phát hiện va chạm', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '5', 'Thể thao / Outdoor (Use Case)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '5', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm (Apple iPhone)', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '5', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device (Apple A-series)', 'Danh sách tính năng AI thực tế': ['Apple Intelligence', 'Siri mới', 'Nút tác vụ', 'SOS khẩn cấp', 'Phát hiện va chạm', 'Face ID'], 'AI Score tổng hợp': '5'},
    {'sku': 'iphone-17e', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'iOS 26', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '48MP', 'Aperture camera chính': 'ƒ/1.6', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '2x', 'Quay video camera sau': '4K@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'ƒ/1.9', 'Quay video camera trước': '4K@60fps', 'Tính năng AI camera': 'Apple Intelligence, Siri mới, SOS khẩn cấp, Phát hiện va chạm, Face ID', 'Kích thước màn hình': '6.1 inches', 'Công nghệ màn hình': 'Super Retina XDR', 'Tần số quét': '60Hz', 'Độ sáng tối đa': '1200 nit (HDR)', 'Chất lượng màu': 'P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Tai thỏ', 'Độ phân giải màn hình': '2532 x 1170', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A19', 'AnTuTu score': 2456789, 'Xếp loại chip': 'A+', 'RAM': 'N/A', 'Bộ nhớ trong': '256 GB', 'GPU tier': '4 lõi với Neural Accelerators', 'Hệ điều hành': 'iOS 26', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': 'N/A', 'Sạc có dây': '25W', 'Sạc không dây': '25W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6 (802.11ax) với 2x2 MIMO', 'Bluetooth': '5.3', 'GPS': 'GPS, GLONASS, Galileo, QZSS, BeiDou, NavIC', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.8 mm', 'Trọng lượng': '170 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': '3D Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Âm thanh không gian, Thu âm stereo', 'Hỗ trợ AI': 'Apple Intelligence, Siri mới, SOS khẩn cấp, Phát hiện va chạm', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'có', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '5', 'Thể thao / Outdoor (Đối tượng)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '2', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device', 'Danh sách tính năng AI thực tế': ['Apple Intelligence', 'Siri mới', 'SOS khẩn cấp', 'Phát hiện va chạm', 'Chế độ chân dung thế hệ mới - tự nhận diện người, chó và mèo', 'Quay video 4K Dolby Vision 60fps - chuẩn điện ảnh', 'Trải nghiệm Âm thanh không gian & giảm tiếng gió bằng AI', 'Dịch Trực Tiếp (Live Translation)', 'Siri thế hệ mới', 'Công cụ viết (Writing Tools)'], 'AI Score tổng hợp': '5'},
    {'sku': 'iphone-15', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 5, 'Phiên bản OS ra mắt': 'iOS 17', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '48 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@60fps', 'Chất lượng kính lens camera': 'Ceramic Shield', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'ƒ/1.9', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Chế độ hành động, Dolby Vision, HDR, Trôi nhanh thời gian, Zoom kỹ thuật số, Cinematic, Quay chậm, Xóa phông, Deep Fusion, Toàn cảnh, Chống rung quang học (OIS), Ban đêm, HDR, Zoom quang học, Siêu độ phân giải, Quay Siêu c', 'Kích thước màn hình': '6.1 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED', 'Tần số quét': '60Hz', 'Độ sáng tối đa': '2000 nits', 'Chất lượng màu': 'Wide color (P3)', 'Kính bảo vệ màn hình': 'Kính cường lực Ceramic Shield', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2556 x 1179', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A16 Bionic 6 nhân', 'AnTuTu score': 1633145, 'Xếp loại chip': 'A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': '5‑core GPU', 'Hệ điều hành': 'iOS 17', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '3349 mAh', 'Sạc có dây': '20 W', 'Sạc không dây': 'Sạc không dây MagSafe', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': 'v5.3', 'GPS': 'GPS, GLONASS, Galileo, QZSS, and BeiDou', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.80 mm', 'Trọng lượng': '171g', 'Số màu sắc': 5, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'Mở khoá khuôn mặt Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'AAC, MP3, Apple Lossless, FLAC, Dolby Digital, Dolby Digital Plus, và Dolby Atmos', 'Hỗ trợ AI': 'Apple Intelligence, Circle to Search, Live Translate, Gemini', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'Phát Hiện Va Chạm', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '5', 'Thể thao / Outdoor (Đối tượng)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm (Apple iPhone)', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '5', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device (Apple A-series)', 'Danh sách tính năng AI thực tế': ['Chế độ hành động', 'Dolby Vision', 'HDR', 'Trôi nhanh thời gian', 'Zoom kỹ thuật số', 'Cinematic', 'Quay chậm', 'Xóa phông', 'Deep Fusion', 'Toàn cảnh', 'Chống rung quang học (OIS)', 'Ban đêm', 'HDR', 'Zoom quang học', 'Siêu độ phân giải', 'Quay Siêu c', 'Apple Intelligence', 'Circle to Search', 'Live Translate', 'Gemini'], 'AI Score tổng hợp': '5'},
    {'sku': 'iphone-14', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 6, 'Phiên bản OS ra mắt': 'iOS 16', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '12MP', 'Aperture camera chính': 'ƒ/1.5', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@24fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'ƒ/1.9', 'Quay video camera trước': '4230p@60fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.1 inches', 'Công nghệ màn hình': 'OLED', 'Tần số quét': '60Hz (cố định)', 'Độ sáng tối đa': '1200 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Ceramic Shield', 'Kiểu màn hình / Notch': 'Tai thỏ', 'Độ phân giải màn hình': '2532 x 1170 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A15 Bionic 6 nhân', 'AnTuTu score': 1413275, 'Xếp loại chip': 'A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Apple GPU 5 nhân', 'Hệ điều hành': 'iOS 16', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': '3279mAh', 'Sạc có dây': '20W', 'Sạc không dây': 'Sạc không dây MagSafe', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 802.11 ax', 'Bluetooth': 'v5.3', 'GPS': 'BEIDOU, GALILEO, GPS, QZSS, iBeacon, GLONASS', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.8 mm', 'Trọng lượng': '172 g', 'Số màu sắc': 6, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'Mở khoá khuôn mặt Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'Điện thoại AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Đối tượng)': '4', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '2', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm (Ước lượng dựa trên Apple iPhone)', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'On-device (Do chip Apple A15 Bionic)', 'Danh sách tính năng AI thực tế': 'Mở khoá khuôn mặt Face ID', 'AI Score tổng hợp': '2'},
    {'sku': 'iphone-16e', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'iOS 18', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '48MP', 'Aperture camera chính': 'ƒ/1.6', 'OIS / Chống rung': 'Không có', 'Zoom quang học': '2x', 'Quay video camera sau': '4K@60fps', 'Chất lượng kính lens camera': 'Sapphire', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'ƒ/1.9', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Điều Khiển Chiều Sâu, Deep Fusion', 'Kích thước màn hình': '6.1 inches', 'Công nghệ màn hình': 'Super Retina XDR', 'Tần số quét': 'N/A', 'Độ sáng tối đa': '1200 nit', 'Chất lượng màu': 'P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Tai thỏ', 'Độ phân giải màn hình': '2532 x 1170', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'A18', 'AnTuTu score': 2005678, 'Xếp loại chip': 'A+', 'RAM': 'N/A', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'GPU 4 lõi mới', 'Hệ điều hành': 'iOS 18', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': 'N/A', 'Sạc có dây': '20W', 'Sạc không dây': '7.5W', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': '5.3', 'GPS': 'GPS, GLONASS, Galileo, QZSS, BeiDou, NavIC, La bàn kỹ thuật số, Định vị vi mô iBeacon, Mạng di động', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM + eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.80 mm', 'Trọng lượng': '167 gram', 'Số màu sắc': 2, 'Điện thoại gập': 'không', 'Cảm biến vân tay': 'Không', 'Nhận diện khuôn mặt': '3D Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa stereo tích hợp sẵn, Dolby Atmos', 'Hỗ trợ AI': 'Apple Intelligence, Circle to Search, Live Translate, Gemini', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'Phát Hiện Va Chạm', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Use Case)': '4', 'Kinh doanh (Use Case)': '4', 'Thể thao / Outdoor (Use Case)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': '26 giờ xem video', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'On-device', 'Danh sách tính năng AI thực tế': ['Điều Khiển Chiều Sâu', 'Deep Fusion', 'Apple Intelligence', 'Circle to Search', 'Live Translate', 'Gemini'], 'AI Score tổng hợp': '5'},
    {'sku': 'iphone-16-pro', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'iOS 18', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '48MP', 'Aperture camera chính': 'f/1.78', 'OIS / Chống rung': 'chống rung quang học dịch chuyển cảm biến thế hệ thứ hai', 'Zoom quang học': '2x', 'Quay video camera sau': '4K@24 fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'ƒ/1.9', 'Quay video camera trước': '4K@60 fps', 'Tính năng AI camera': 'Flash True Tone, Photonic Engine, Deep Fusion, HDR thông minh thế hệ 5, Hiệu ứng Chiếu Sáng Chân Dung với sáu chế độ, Chế độ Ban Đêm, Chụp ảnh toàn cảnh Panorama (lên đến 63MP), Phong Cách Nhiếp Ảnh thế hệ mới nhất, Ảnh không gian', 'Kích thước màn hình': '6.3 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1000 nit', 'Chất lượng màu': 'Dải màu rộng (P3)', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2622 x 1206', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A18 Pro', 'AnTuTu score': 2305678, 'Xếp loại chip': 'A+', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'GPU 6 lõi mới', 'Hệ điều hành': 'iOS 18', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': 'N/A', 'Sạc có dây': 'N/A', 'Sạc không dây': 'Sạc không dây MagSafe lên đến 25W với bộ tiếp hợp 30W trở lên, Sạc không dây Qi2 lên đến 15W, Sạc không dây Qi lên đến 7,5W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7 (802.11be) với 2x2 MIMO7', 'Bluetooth': 'Bluetooth 5.3', 'GPS': 'GPS, GLONASS, Galileo, QZSS và BeiDou', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Sim kép (nano-Sim và e-Sim) - Hỗ trợ 2 e-Sim', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Titanium', 'Độ mỏng': '8.25 mm', 'Trọng lượng': '199 gram', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'AAC, APAC, MP3, Apple Lossless, FLAC, Dolby Digital, Dolby Digital Plus, và Dolby Atmos', 'Hỗ trợ AI': 'Face ID, FaceTime', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '4', 'Kinh doanh (Use Case)': '5', 'Thể thao / Outdoor (Use Case)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '5', 'Dân văn phòng (Đối tượng)': '5', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '5', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm (Apple iPhone)', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '5', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device (Apple A-series)', 'Danh sách tính năng AI thực tế': ['Flash True Tone', 'Photonic Engine', 'Deep Fusion', 'HDR thông minh thế hệ 5', 'Hiệu ứng Chiếu Sáng Chân Dung với sáu chế độ', 'Chế độ Ban Đêm', 'Chụp ảnh toàn cảnh Panorama (lên đến 63MP)', 'Phong Cách Nhiếp Ảnh thế hệ mới nhất', 'Ảnh không gian', 'Sáng tạo những thước phim chuyển động chậm đầy tính nghệ thuật', 'Dịch trực tiếp', 'Công cụ viết', 'Tạo Genmoji', 'Trợ lý Siri'], 'AI Score tổng hợp': '5'},
    {'sku': 'iphone-16', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 5, 'Phiên bản OS ra mắt': 'iOS 18', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '48MP', 'Aperture camera chính': 'f/1.6', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@60 fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'f/1.9', 'Quay video camera trước': '4K@60 fps', 'Tính năng AI camera': 'Flash True Tone, Photonic Engine, Deep Fusion, HDR thông minh thế hệ 5, Hiệu ứng Chiếu Sáng Chân Dung với sáu chế độ, Chế độ Ban Đêm, Chụp ảnh toàn cảnh Panorama (lên đến 63MP), Phong Cách Nhiếp Ảnh thế hệ mới nhất, Ảnh không gian', 'Kích thước màn hình': '6.1 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED', 'Tần số quét': '60Hz', 'Độ sáng tối đa': '1000 nit', 'Chất lượng màu': 'P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2556 x 1179 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A18', 'AnTuTu score': 2305678, 'Xếp loại chip': 'A+', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'GPU 5 lõi mới', 'Hệ điều hành': 'iOS 18', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': 'N/A', 'Sạc có dây': 'N/A', 'Sạc không dây': '25W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7 (802.11be)', 'Bluetooth': '5.3', 'GPS': 'GPS, GLONASS, Galileo, QZSS và BeiDou', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Sim kép (nano-Sim và e-Sim) - Hỗ trợ 2 e-Sim', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.80 mm', 'Trọng lượng': '170 gram', 'Số màu sắc': 5, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'AAC, APAC, MP3, Apple Lossless, FLAC, Dolby Digital, Dolby Digital Plus, và Dolby Atmos', 'Hỗ trợ AI': 'Apple Intelligence, Circle to Search, Live Translate, Gemini', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'Phát Hiện Va Chạm', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '5', 'Thể thao / Outdoor (Đối tượng)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '5', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm (Apple iPhone)', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '5', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device (Apple A-series)', 'Danh sách tính năng AI thực tế': ['Flash True Tone', 'Photonic Engine', 'Deep Fusion', 'HDR thông minh thế hệ 5', 'Hiệu ứng Chiếu Sáng Chân Dung với sáu chế độ', 'Chế độ Ban Đêm', 'Chụp ảnh toàn cảnh Panorama (lên đến 63MP)', 'Phong Cách Nhiếp Ảnh thế hệ mới nhất', 'Ảnh không gian', 'Apple Intelligence', 'Circle to Search', 'Live Translate', 'Gemini'], 'AI Score tổng hợp': '5'},
    {'sku': 'iphone-14-pro-max', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'iOS 16', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '48 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '3x', 'Quay video camera sau': '4K@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12 MP', 'Aperture camera trước': 'f/1.9', 'Quay video camera trước': '4K@60fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2000 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2796 x 1290-pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A16 Bionic 6-core', 'AnTuTu score': 1633145, 'Xếp loại chip': 'A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Apple GPU (5-core graphics)', 'Hệ điều hành': 'iOS 16', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': '4.323 mAh', 'Sạc có dây': '30W', 'Sạc không dây': '15W', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 802.11 ax', 'Bluetooth': 'v5.3', 'GPS': 'BEIDOU, GALILEO, GPS, QZSS, iBeacon, GLONASS', 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': '7.9 mm', 'Trọng lượng': '240 gr', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': '3D Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'không', 'Nút SOS / khẩn cấp': 'Phát Hiện Va Chạm', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '4', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device', 'Danh sách tính năng AI thực tế': ['3D Face ID'], 'AI Score tổng hợp': '2'},
    {'sku': 'iphone-13', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 6, 'Phiên bản OS ra mắt': 'iOS 15', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '12MP', 'Aperture camera chính': 'f/1.6', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': '4K@30fps', 'Tính năng AI camera': 'Nhận diện khuôn mặt', 'Kích thước màn hình': '6.1 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED', 'Tần số quét': '60Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Tai thỏ', 'Độ phân giải màn hình': '2532 x 1170', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A15', 'AnTuTu score': 1413275, 'Xếp loại chip': 'A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Apple GPU 4 nhân', 'Hệ điều hành': 'iOS 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '3240mAh', 'Sạc có dây': '20W', 'Sạc không dây': 'Sạc không dây 15W', 'Sạc ngược': 'Sạc ngược không dây 15W', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6 (802.11ax)', 'Bluetooth': 'v5.0', 'GPS': 'GPS, GLONASS, Galileo, QZSS, and BeiDou', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.65 mm', 'Trọng lượng': '173g', 'Số màu sắc': 6, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '4', 'Kinh doanh (Use Case)': '4', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'On-device', 'Danh sách tính năng AI thực tế': ['Nhận diện khuôn mặt', 'Night Mode', 'Portrait', 'Clean Up'], 'AI Score tổng hợp': '3'},
    {'sku': 'iphone-15-plus', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 5, 'Phiên bản OS ra mắt': 'iOS 17', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '48 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@60 fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'ƒ/1.9', 'Quay video camera trước': '4K@60 fps', 'Tính năng AI camera': 'Camera TrueDepth hỗ trợ nhận diện khuôn mặt', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED', 'Tần số quét': '60Hz', 'Độ sáng tối đa': '2000 nits', 'Chất lượng màu': 'Wide color (P3)', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2796 x 1290-pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A16 Bionic', 'AnTuTu score': 1633145, 'Xếp loại chip': 'A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'GPU 5 lõi', 'Hệ điều hành': 'iOS 17', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4383 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': '15W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6 (802.11ax)', 'Bluetooth': 'v5.3', 'GPS': 'GPS, GLONASS, Galileo, QZSS, and BeiDou', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.80 mm', 'Trọng lượng': '201 g', 'Số màu sắc': 5, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': '3D Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'AAC, MP3, Apple Lossless, FLAC, Dolby Digital, Dolby Digital Plus, và Dolby Atmos', 'Hỗ trợ AI': 'Apple Intelligence, Circle to Search, Live Translate, Gemini', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'Phát Hiện Va Chạm', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '4', 'Kinh doanh (Use Case)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm (Apple iPhone)', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device (Apple A-series)', 'Danh sách tính năng AI thực tế': ['Camera TrueDepth hỗ trợ nhận diện khuôn mặt', 'Apple Intelligence', 'Circle to Search', 'Live Translate', 'Gemini'], 'AI Score tổng hợp': '5'},
    {'sku': 'iphone-16-plus', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 5, 'Phiên bản OS ra mắt': 'iOS 18', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '48MP', 'Aperture camera chính': 'f/1.6', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@60 fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'f/1.9', 'Quay video camera trước': '4K@60 fps', 'Tính năng AI camera': 'Flash True Tone, Photonic Engine, Deep Fusion, HDR thông minh thế hệ 5, Hiệu ứng Chiếu Sáng Chân Dung với sáu chế độ, Chế độ Ban Đêm, Chụp ảnh toàn cảnh Panorama (lên đến 63MP), Phong Cách Nhiếp Ảnh thế hệ mới nhất, Ảnh không gian', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED', 'Tần số quét': '60Hz', 'Độ sáng tối đa': '1000 nit', 'Chất lượng màu': 'P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2796 x 1290', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A18', 'AnTuTu score': 2005678, 'Xếp loại chip': 'A+', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'GPU 5 lõi mới', 'Hệ điều hành': 'iOS 18', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': 'N/A', 'Sạc có dây': 'N/A', 'Sạc không dây': '25W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7', 'Bluetooth': '5.3', 'GPS': 'GPS, GLONASS, Galileo, QZSS, BeiDou', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Sim kép (nano-Sim và e-Sim) - Hỗ trợ 2 e-Sim', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.80 mm', 'Trọng lượng': '199 gram', 'Số màu sắc': 5, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': '3D Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'AAC, APAC, MP3, Apple Lossless, FLAC, Dolby Digital, Dolby Digital Plus, Dolby Atmos', 'Hỗ trợ AI': 'Apple Intelligence, Circle to Search, Live Translate, Gemini', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'Phát Hiện Va Chạm', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '4', 'Kinh doanh (Use Case)': '5', 'Thể thao / Outdoor (Use Case)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '5', 'Dân văn phòng (Đối tượng)': '5', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '5', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm (Ước lượng dựa trên Apple iPhone)', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '5', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device (Apple A-series)', 'Danh sách tính năng AI thực tế': ['Flash True Tone', 'Photonic Engine', 'Deep Fusion', 'HDR thông minh thế hệ 5', 'Hiệu ứng Chiếu Sáng Chân Dung với sáu chế độ', 'Chế độ Ban Đêm', 'Chụp ảnh toàn cảnh Panorama (lên đến 63MP)', 'Phong Cách Nhiếp Ảnh thế hệ mới nhất', 'Ảnh không gian', 'Apple Intelligence', 'Circle to Search', 'Live Translate', 'Gemini'], 'AI Score tổng hợp': '5'},
    {'sku': 'iphone-15-pro-max-512gb', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'iOS 17', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '48MP', 'Aperture camera chính': 'ƒ/1.78', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '5x', 'Quay video camera sau': '4K@60 fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'ƒ/1.9', 'Quay video camera trước': '4K@60 fps', 'Tính năng AI camera': 'Flash True Tone Thích Ứng, Photonic Engine, Deep Fusion, HDR thông minh thế hệ 5, Ảnh chân dung thế hệ mới với Focus và Depth Control, Hiệu ứng Chiếu Sáng Chân Dung với sáu chế độ, Chế độ Ban Đêm', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2000 nits', 'Chất lượng màu': 'P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2796 x 1290', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A17 Pro 6 nhân', 'AnTuTu score': 1503813, 'Xếp loại chip': 'A', 'RAM': '8 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'GPU 6 nhân mới', 'Hệ điều hành': 'iOS 17', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4422 mAh', 'Sạc có dây': '20 W', 'Sạc không dây': '15W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6E (802.11ax)', 'Bluetooth': 'v5.3', 'GPS': 'GPS, GLONASS, Galileo, QZSS, BeiDou, NavIC', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Titanium', 'Độ mỏng': '8.25 mm', 'Trọng lượng': '221 g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Không', 'Nhận diện khuôn mặt': '3D Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'AAC, MP3, Apple Lossless, FLAC, Dolby Digital, Dolby Digital Plus, Dolby Atmos', 'Hỗ trợ AI': 'Apple Intelligence, Circle to Search, Live Translate, Gemini', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'Phát Hiện Va Chạm', 'Gaming (Use Case)': '4', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '5', 'Thể thao / Outdoor (Use Case)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '5', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm (Apple iPhone)', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device (Apple A-series)', 'Danh sách tính năng AI thực tế': ['Flash True Tone Thích Ứng', 'Photonic Engine', 'Deep Fusion', 'HDR thông minh thế hệ 5', 'Ảnh chân dung thế hệ mới với Focus và Depth Control', 'Hiệu ứng Chiếu Sáng Chân Dung với sáu chế độ', 'Chế độ Ban Đêm', 'Apple Intelligence', 'Circle to Search', 'Live Translate', 'Gemini'], 'AI Score tổng hợp': '5'},
    {'sku': 'iphone-14-pro', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'iOS 16', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '48 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '3x', 'Quay video camera sau': '4K @24 fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12 MP', 'Aperture camera trước': 'f/1.9', 'Quay video camera trước': '4K HDR @30 fps', 'Tính năng AI camera': 'Night Mode, AI Portrait, Chụp chân dung đêm', 'Kích thước màn hình': '6.1 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2.000 nits (ngoài trời)', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2556 x 1179', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A16 Bionic 6 nhân', 'AnTuTu score': 1633145, 'Xếp loại chip': 'A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'GPU 5 nhân', 'Hệ điều hành': 'iOS 16', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': '3200 mAh', 'Sạc có dây': '20W', 'Sạc không dây': '15W', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6 (802.11ax)', 'Bluetooth': 'Bluetooth 5.3', 'GPS': 'BEIDOU, GALILEO, GPS, QZSS, iBeacon, GLONASS', 'NFC': 'có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': '7.85mm', 'Trọng lượng': '206g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Không', 'Nhận diện khuôn mặt': 'Mở khoá khuôn mặt Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'Nhận diện khuôn mặt', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Đối tượng)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '4', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '5', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device', 'Danh sách tính năng AI thực tế': ['Night Mode', 'AI Portrait', 'Chụp chân dung đêm', 'Nhận diện khuôn mặt'], 'AI Score tổng hợp': '2'},
    {'sku': 'iphone-15-pro', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'iOS 17', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '48MP', 'Aperture camera chính': 'ƒ/1.78', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '3x', 'Quay video camera sau': '4K@60 fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'ƒ/1.9', 'Quay video camera trước': '4K@60 fps', 'Tính năng AI camera': 'Flash True Tone Thích Ứng, Photonic Engine, Deep Fusion, HDR thông minh thế hệ 5, Ảnh chân dung thế hệ mới với Focus và Depth Control, Hiệu ứng Chiếu Sáng Chân Dung với sáu chế độ, Chế độ Ban Đêm', 'Kích thước màn hình': '6.1 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2.000 nit', 'Chất lượng màu': 'P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2556 x 1179', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A17 Pro 6 nhân', 'AnTuTu score': 1503813, 'Xếp loại chip': 'A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'GPU 6 nhân mới', 'Hệ điều hành': 'iOS 17', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '3274 mAh', 'Sạc có dây': '20 W', 'Sạc không dây': '15W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6E (802.11ax)', 'Bluetooth': 'v5.3', 'GPS': 'GPS, GLONASS, Galileo, QZSS, BeiDou, NavIC', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Titanium', 'Độ mỏng': '8.25 mm', 'Trọng lượng': '187 g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Không', 'Nhận diện khuôn mặt': '3D Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'AAC, MP3, Apple Lossless, FLAC, Dolby Digital, Dolby Digital Plus, Dolby Atmos', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'Phát Hiện Va Chạm', 'Gaming (Use Case)': '4', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '4', 'Kinh doanh (Use Case)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '5', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm (Apple iPhone)', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'On-device (Apple A-series)', 'Danh sách tính năng AI thực tế': ['Flash True Tone Thích Ứng', 'Photonic Engine', 'Deep Fusion', 'HDR thông minh thế hệ 5', 'Ảnh chân dung thế hệ mới với Focus và Depth Control', 'Hiệu ứng Chiếu Sáng Chân Dung với sáu chế độ', 'Chế độ Ban Đêm'], 'AI Score tổng hợp': '5'},
    {'name': 'iPhone 12 Pro Max 128GB I Chính hãng VN/A', 'sku': 'iphone-12-pro-max', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'iOS 14.1 hoặc cao hơn (Tùy vào phiên bản phát hành)', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '12 MP', 'Aperture camera chính': 'f/1.6', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '2x', 'Quay video camera sau': '4K@24/30/60fps, 1080p@30/60/120fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12 MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': '4K@24/30/60fps, 1080p@30/60/120fps', 'Tính năng AI camera': 'Ban đêm (Night Mode), Trôi nhanh thời gian (Time Lapse), Quay chậm (Slow Motion), Xóa phông Zoom quang học, Toàn cảnh (Panorama), Chống rung quang học (OIS), Tự động lấy nét (AF), Nhận diện khuôn mặt, HDR, Ảnh Raw', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED, HDR10, Dolby Vision, Wide color gamut, True-tone, OLED', 'Tần số quét': '60Hz', 'Độ sáng tối đa': '800 nits', 'Chất lượng màu': 'Dolby Vision', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Tai thỏ', 'Độ phân giải màn hình': '1284 x 2778 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A14 Bionic (5 nm)', 'AnTuTu score': 1337390, 'Xếp loại chip': 'B', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Apple GPU (4-core graphics)', 'Hệ điều hành': 'iOS 14.1 hoặc cao hơn (Tùy vào phiên bản phát hành)', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': 'N/A', 'Sạc có dây': '20W', 'Sạc không dây': '15W', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 802.11 a/b/g/n/ac/6, dual-band, hotspot', 'Bluetooth': '5.0, A2DP, LE', 'GPS': 'A-GPS, GLONASS, GALILEO, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': '7.4 mm', 'Trọng lượng': '228', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Không', 'Nhận diện khuôn mặt': '3D Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Stereo', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm (Apple iPhone)', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '5', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device', 'Danh sách tính năng AI thực tế': ['Ban đêm (Night Mode)', 'Trôi nhanh thời gian (Time Lapse)', 'Quay chậm (Slow Motion)', 'Xóa phông', 'Zoom quang học', 'Toàn cảnh (Panorama)', 'Chống rung quang học (OIS)', 'Tự động lấy nét (AF)', 'Nhận diện khuôn mặt', 'HDR', 'Ảnh Raw'], 'AI Score tổng hợp': '5'},
    {'name': 'iPhone 13 Pro Max 128GB | Chính hãng VN/A', 'sku': 'iphone-13-pro-max', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 5, 'Phiên bản OS ra mắt': 'iOS15', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '12MP', 'Aperture camera chính': 'ƒ/1.5', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'ƒ/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Nhận diện khuôn mặt', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1200 nits', 'Chất lượng màu': 'P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Tai thỏ', 'Độ phân giải màn hình': '2778 x 1284 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A15 Bionic 6 nhân', 'AnTuTu score': 1413275, 'Xếp loại chip': 'A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'GPU 5 nhân', 'Hệ điều hành': 'iOS15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': '4352mAh', 'Sạc có dây': '20W', 'Sạc không dây': 'Sạc không dây MagSafe', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 802.11 ax', 'Bluetooth': 'v5.0', 'GPS': 'GPS, GLONASS, Galileo, QZSS, and BeiDou', 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': '7.65 mm', 'Trọng lượng': '240g', 'Số màu sắc': 5, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'Mở khoá khuôn mặt Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Ghi âm có microphone chuyên dụng chống ồn', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '5', 'Thể thao / Outdoor (Đối tượng)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '4', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '5', 'AI on-device vs Cloud': 'On-device', 'Danh sách tính năng AI thực tế': ['Nhận diện khuôn mặt'], 'AI Score tổng hợp': '3'},
    {'name': 'iPhone 11 64GB | Chính hãng VN/A', 'sku': 'iphone-11', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'iOS 13 hoặc cao hơn (Tùy vào phiên bản phát hành)', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '12MP', 'Aperture camera chính': 'ƒ/1.8 aperture', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@24/30/60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12 MP', 'Aperture camera trước': 'ƒ/2.2 aperture', 'Quay video camera trước': '4K@24/30/60fps, 1080p@30/60/120fps, gyro-EIS', 'Tính năng AI camera': 'Retina Flash, Nhãn dán (AR Stickers), Ban đêm (Night Mode), Chạm lấy nét, Góc rộng (Wide), Góc siêu rộng (Ultrawide), HDR, Nhận diện khuôn mặt, Quay chậm (Slow Motion), Toàn cảnh (Panorama), Trôi nhanh thời gian (Time L', 'Kích thước màn hình': '6.1 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '60Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Tai thỏ', 'Độ phân giải màn hình': '1792 x 828 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'A13 Bionic', 'AnTuTu score': 1091336, 'Xếp loại chip': 'B', 'RAM': '4 GB', 'Bộ nhớ trong': '64 GB', 'GPU tier': 'Apple GPU', 'Hệ điều hành': 'iOS 13 hoặc cao hơn (Tùy vào phiên bản phát hành)', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '3110 mAh', 'Sạc có dây': '18W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G', 'Wi-Fi': '802.11ax Wi‑Fi 6 with 2x2 MIMO', 'Bluetooth': '5.0', 'GPS': 'GPS/GNSS', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': 'Nano-SIM + eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': '8.3 mm', 'Trọng lượng': '194 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Không', 'Nhận diện khuôn mặt': '3D Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Apple Intelligence, Circle to Search, Live Translate, Gemini', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '2', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'On-device', 'Danh sách tính năng AI thực tế': ['Retina Flash', 'Nhãn dán (AR Stickers)', 'Ban đêm (Night Mode)', 'Chạm lấy nét', 'Góc rộng (Wide)', 'Góc siêu rộng (Ultrawide)', 'HDR', 'Nhận diện khuôn mặt', 'Quay chậm (Slow Motion)', 'Toàn cảnh (Panorama)', 'Trôi nhanh thời gian (Time L)', 'Apple Intelligence', 'Circle to Search', 'Live Translate', 'Gemini'], 'AI Score tổng hợp': '5'},
    {'name': 'iPhone 12 64GB | Chính hãng VN/A', 'sku': 'iphone-12', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 6, 'Phiên bản OS ra mắt': 'iOS 14.1 hoặc cao hơn (Tùy vào phiên bản phát hành)', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '12 MP', 'Aperture camera chính': 'f/1.6', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@24/30/60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12 MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': '4K@24/30/60fps', 'Tính năng AI camera': 'Night Mode, Trôi nhanh thời gian (Time Lapse), Quay chậm (Slow Motion), Xóa phông, Toàn cảnh (Panorama), Tự động lấy nét (AF), Nhận diện khuôn mặt, HDR, Zoom kỹ thuật số, Góc rộng (Wide), Góc siêu rộng (Ul)', 'Kích thước màn hình': '6.1 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED, HDR10, Dolby Vision, Wide color gamut, True-tone, OLED', 'Tần số quét': '60Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'Dolby Vision', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Tai thỏ', 'Độ phân giải màn hình': '1170 x 2532 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A14 Bionic (5 nm)', 'AnTuTu score': 1337390, 'Xếp loại chip': 'B', 'RAM': '4 GB', 'Bộ nhớ trong': '64 GB', 'GPU tier': 'Apple GPU (4-core graphics)', 'Hệ điều hành': 'iOS 14.1 hoặc cao hơn (Tùy vào phiên bản phát hành)', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': 'N/A', 'Sạc có dây': '20W', 'Sạc không dây': '15W', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': '5.0', 'GPS': 'A-GPS, GLONASS, GALILEO, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': '7.4 mm', 'Trọng lượng': '164', 'Số màu sắc': 6, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Không', 'Nhận diện khuôn mặt': '3D Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Apple Intelligence, Circle to Search, Live Translate, Gemini', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm (Apple iPhone)', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '5', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'On-device', 'Danh sách tính năng AI thực tế': 'Night Mode, Trôi nhanh thời gian (Time Lapse), Quay chậm (Slow Motion), Xóa phông, Toàn cảnh (Panorama), Tự động lấy nét (AF), Nhận diện khuôn mặt, HDR, Zoom kỹ thuật số, Góc rộng (Wide), Góc siêu rộng (Ul), Apple Intelligence, Circle to Search, Live Translate, Gemini', 'AI Score tổng hợp': '5'},
    {'name': 'iPhone 14 Plus 128GB | Chính hãng VN/A', 'sku': 'iphone-14-plus', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'iOS', 'Thương hiệu': 'Apple', 'Xuất xứ': 'Mỹ', 'Giao diện OS': 'iOS', 'Màu sắc hỗ trợ': 6, 'Phiên bản OS ra mắt': 'iOS 16', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '12MP', 'Aperture camera chính': 'ƒ/1.5', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K / Full HD 60FPS', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'f/1.9', 'Quay video camera trước': '4K / Full HD 60FPS', 'Tính năng AI camera': 'Deep Fusion, Smart HDR 4,Panorama, Chụp đêm, Chân dung, QuickTake video, Time‑lapse, Slo-mo video', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super Retina XDR OLED', 'Tần số quét': '60Hz', 'Độ sáng tối đa': '1200 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Ceramic Shield', 'Kiểu màn hình / Notch': 'Tai thỏ', 'Độ phân giải màn hình': '2778 x 1284 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Apple A15 Bionic', 'AnTuTu score': 1413275, 'Xếp loại chip': 'A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': '5 nhân GPU', 'Hệ điều hành': 'iOS 16', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4325 mAh', 'Sạc có dây': '20W', 'Sạc không dây': '15W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6 (802.11ax)', 'Bluetooth': '5.3', 'GPS': 'GPS, GLONASS, Galileo, QZSS, BeiDou', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.8mm', 'Trọng lượng': '203gr', 'Số màu sắc': 6, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Không', 'Nhận diện khuôn mặt': 'Mở khoá khuôn mặt Face ID', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'Nhận diện khuôn mặt', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Đối tượng)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Cao (~70-85%)', 'Số năm OS update': 'Tối thiểu 6 năm', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'On-device', 'Danh sách tính năng AI thực tế': 'Deep Fusion, Smart HDR 4, Panorama, Chụp đêm, Chân dung, QuickTake video, Time‑lapse, Slo-mo video, Night Mode, Portrait, Clean Up', 'AI Score tổng hợp': '5'},
]

meizu_data = [
    {'name': 'Điện thoại Meizu Mblu Note 21 Pro NFC 8GB 256GB', 'sku': 'dien-thoai-meizu-mblu-note-21-pro', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Meizu', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 14, Flyme AIOS', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '64 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '13 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.78 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '550 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '1080 x 2400 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Mediatek Helio G99 (6 nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'GPU Mali-G57 MC2', 'Hệ điều hành': 'Android 14, Flyme AIOS', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '30W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G', 'Wi-Fi': 'Wi-Fi 5', 'Bluetooth': '5.3', 'GPS': 'N/A', 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSD', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.3 mm', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Mediatek Helio G99)', 'Danh sách tính năng AI thực tế': ['Hệ thống xử lý hình ảnh thông minh điều chỉnh ánh sáng, độ tương phản và màu da'], 'AI Score tổng hợp': '3'},
    {'name': 'Điện thoại Meizu Mblu 22 Pro NFC 6GB 256GB', 'sku': 'dien-thoai-meizu-mblu-22-pro-6gb-256gb', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Meizu', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '5 MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Night Shot, Portrait, Time-lapse, Panorama, Pro/Manual, HDR, Filters, Timer, Flash, AI', 'Kích thước màn hình': '6.79 inches', 'Công nghệ màn hình': 'TFT LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '720 x 1640', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G81', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Mali-G52 MP2', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '18W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 5', 'Bluetooth': '5.0', 'GPS': 'GPS, GLONASS, GALILEO, BDS', 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP52', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.5 mm', 'Trọng lượng': '212 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay cạnh bên', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Dual Speaker, Boost 300%', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%) Lý do: Thương hiệu Meizu (thường nằm trong phân khúc tầm trung/giá trung bình)', 'Số năm OS update': '3 năm Lý do: Ước lượng dựa trên dòng sản phẩm (Meizu/Android)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud Lý do: Chip MediaTek Helio G81 (chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Night Shot, Portrait, Time-lapse, Panorama, Pro/Manual, HDR, Filters, Timer, Flash, AI', 'AI Score tổng hợp': '3'},
    {'name': 'Meizu Lucky 08 5G 12GB 256GB', 'sku': 'dien-thoai-meizu-lucky-08', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Meizu', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '108MP', 'Aperture camera chính': 'ƒ/1.67', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8MP', 'Aperture camera trước': 'ƒ/2.0', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': ['AI Beauty Algorithm', 'Backlit HDR Selfie', 'Front Night Mode'], 'Kích thước màn hình': '6.78 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '5000nits', 'Chất lượng màu': '100% DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2780 x 1264', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 7s Gen 2', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno™ 710', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6000mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 5 (802.11a/b/g/n/ac)', 'Bluetooth': '5.1', 'GPS': 'Dual GPS(L1/L5) /BeiDou /GLONASS /Galileo /QZSS', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP52', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.60 mm', 'Trọng lượng': '202g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Stereo, loa kép', 'Hỗ trợ AI': ['Nút AI đa chức năng', 'Xử lý cuộc gọi AI', 'So sánh giá AI', 'Tìm kiếm AI', 'Đầu vào hỗ trợ AI', 'Phiên âm AI', 'Phân tích tài liệu AI', 'Vòng tròn để tìm kiếm', 'AI Eraser', 'Trò chuyện bằng giọng nói AI', 'Trợ lý kịch bản AI'], 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) Lý do: Thương hiệu Meizu (tương đương Xiaomi/OPPO/Vivo) trong phân khúc Mid-range.', 'Số năm OS update': '3 năm Ước lượng: Xiaomi mid-range (3 năm)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (Giao diện OS: Flyme AIOS tùy biến)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Cloud Lý do: Thương hiệu Meizu và chip Snapdragon tầm trung thường sử dụng mô hình Cloud cho các tính năng AI phức tạp.', 'Danh sách tính năng AI thực tế': ['AI Beauty Algorithm', 'Backlit HDR Selfie', 'Front Night Mode', 'trợ lý ảo', 'tự động trả lời cuộc gọi', 'tóm tắt nội dung cuộc gọi', 'phân tích tài liệu AI'], 'AI Score tổng hợp': '3'},
    {'name': 'Điện thoại Meizu Mblu 22 3GB 64GB', 'sku': 'dien-thoai-meizu-mblu-22', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Meizu', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '13 MP', 'Aperture camera chính': 'ƒ/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '5 MP', 'Aperture camera trước': 'ƒ/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.79 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '400 nit', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '1640 x 720', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc SC9863A(28 nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '3 GB', 'Bộ nhớ trong': '64 GB', 'GPU tier': 'IMG8322', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '10W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': 'N/A', 'Wi-Fi': 'Wi-Fi 4 (802.11b/g/n)', 'Bluetooth': '4.2', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': 'N/A', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.9 mm', 'Trọng lượng': '200 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': '2 Loa âm thanh nổi', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '4', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu Meizu)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi/mid-range)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên Chip Unisoc SC9863A)', 'Danh sách tính năng AI thực tế': ['识别面部', '自拍和视频通话'], 'AI Score tổng hợp': '3'},
    {'name': 'Điện thoại Meizu Mblu 21 6GB 128GB', 'sku': 'dien-thoai-meizu-mblu-21-128gb', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Meizu', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '13MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.79', 'Công nghệ màn hình': 'N/A', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Spreadtrum T606', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4900mAh', 'Sạc có dây': '18.96Wh', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'WiFi 2.4G/5G', 'Bluetooth': 'v5.0', 'GPS': 'GPS, GLONASS, Galileo,Beidou', 'NFC': 'Không', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Stereo speakers', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '3 Tốt ban ngày, tối chấp nhận', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Điện thoại Meizu Mblu 22 Pro NFC 4GB 128GB', 'sku': 'dien-thoai-meizu-mblu-22-pro', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Meizu', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Night Shot, Portrait, Time-lapse, Panorama, Pro/Manual, HDR, Filters, Timer, Flash, AI', 'Kích thước màn hình': '6.79 inches', 'Công nghệ màn hình': 'TFT LCD', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '720 x 1640 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G81', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G52 MP2', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '18W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 5', 'Bluetooth': '5.0', 'GPS': 'GPS, GLONASS, GALILEO, BDS', 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'không có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.5 mm', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Lý do: Thương hiệu Meizu/Phân khúc Tầm trung)', 'Số năm OS update': '3 năm (Ước lượng: Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Lý do: Chip MediaTek Helio G81 tầm trung)', 'Danh sách tính năng AI thực tế': 'Night Mode, Portrait, Clean Up, AI', 'AI Score tổng hợp': '3'},
    {'name': 'Điện thoại Meizu Mblu 21 4GB 64GB', 'sku': 'dien-thoai-meizu-mblu-21', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Meizu', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '13MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.79 inches', 'Công nghệ màn hình': 'N/A', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Spreadtrum T606', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '64 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4900mAh', 'Sạc có dây': '18.96Wh', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'WiFi 2.4G/5G', 'Bluetooth': 'v5.0', 'GPS': 'GPS, GLONASS, Galileo,Beidou', 'NFC': 'Không', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Stereo speakers', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '2', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Lý do: Thương hiệu Meizu/Chip Unisoc Mid-range)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '4 4K@60fps ổn định tốt', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Chụp chân dung, chụp cận cảnh, AI Portrait', 'AI Score tổng hợp': '3'},
 
]

masstel_data = [
    {'name': 'Điện thoại trẻ em Masstel Alfa 5', 'sku': 'dien-thoai-masstel-alfa-5', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Masstel', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': 'N/A', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'Hỗ trợ', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'Hỗ trợ gọi video', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '3.5', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '240 x 320 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'ASR', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '128 MB', 'Bộ nhớ trong': '128 MB', 'GPU tier': 'N/A', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '1750 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'GPS', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '1 SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa Box 1.5W, thoại HD', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'Có', 'Gaming (Use Case)': '2', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên Thương hiệu Masstel và phân khúc giá Rẻ)', 'Số năm OS update': 'N/A', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (Dựa trên Giao diện OS: N/A, suy luận từ thương hiệu Trung Quốc)', 'Chất lượng ảnh ban ngày': '3', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip tier ASR và thương hiệu Trung Quốc)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Masstel Izi 15 4G', 'sku': 'masstel-izi-15', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Masstel', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 0, 'Độ phân giải camera chính': 'N/A', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '1.77', 'Công nghệ màn hình': 'N/A', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc UMS9117', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '48 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'RAM 48 MB, ROM 128 MB', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '1000 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'v5.1', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '14 mm', 'Trọng lượng': '76 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Do thương hiệu Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '3 Tốt ban ngày, tối chấp nhận', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Masstel Fami 8 4G', 'sku': 'dien-thoai-masstel-fami-8', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'nan', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 0, 'Độ phân giải camera chính': 'N/A', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '1.77', 'Công nghệ màn hình': 'QQVGA', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '128 x 160', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'UNISOC T107', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '128', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '1400 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'V5.1', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '14.9 mm', 'Trọng lượng': '92g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '2', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '2', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '2', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '2', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Do thương hiệu nan và phân khúc giá Trung bình)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (Dựa trên ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '3', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Dựa trên Chip tier UNISOC T107)', 'Danh sách tính năng AI thực tế': ['N/A'], 'AI Score tổng hợp': '1'},
    {'name': 'Masstel izi T5 plus 4G', 'sku': 'dien-thoai-masstel-izi-t5-plus', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Masstel', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 0, 'Độ phân giải camera chính': 'N/A', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '2.4 inches', 'Công nghệ màn hình': 'N/A', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '240 x 320 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'UNISOC T107', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': 'N/A', 'Bộ nhớ trong': 'N/A', 'GPU tier': 'N/A', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '2300 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '2', 'Camera / Creator (Use Case)': '1', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '1', 'Nhiếp ảnh gia (Đối tượng)': '2', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu Masstel và phân khúc giá Rẻ)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '3', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Masstel izi 22', 'sku': 'dien-thoai-masstel-izi-22', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Masstel', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 0, 'Độ phân giải camera chính': 'N/A', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '1.77', 'Công nghệ màn hình': 'N/A', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '128 x 160', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'ASR Platform', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': 'N/A', 'Bộ nhớ trong': 'N/A', 'GPU tier': 'N/A', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '1000', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'Không', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '1 SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa 2030 Box', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '2', 'Camera / Creator (Use Case)': '2', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu Masstel và phân khúc giá 4G phổ thông)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên dòng sản phẩm Masstel)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (Dựa trên Giao diện OS N/A)', 'Chất lượng ảnh ban ngày': '3', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip tier ASR Platform và thương hiệu)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Masstel Izi S8', 'sku': 'dien-thoai-masstel-izi-s8', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Masstel', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 0, 'Độ phân giải camera chính': 'N/A', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '1.77', 'Công nghệ màn hình': 'TFT LCD', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'T107 (UMS9117)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': 'N/A', 'Bộ nhớ trong': 'N/A', 'GPU tier': 'N/A', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '1400mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '14.5 mm', 'Trọng lượng': '104.2 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa ngoài âm thanh to, rõ', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip tầm trung)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Masstel Fami 25', 'sku': 'dien-thoai-masstel-fami-25', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'nan', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 0, 'Độ phân giải camera chính': 'N/A', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '1.77', 'Công nghệ màn hình': 'TFT LCD', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'T107 (UMS9117)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '48GB', 'Bộ nhớ trong': '128GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '1400 mAh', 'Sạc có dây': '5V', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': '5.1', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '13.2 mm', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa ngoài công suất lớn, âm thanh to rõ', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '2', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '2', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Lý do: Thương hiệu nan/Masstel, phân khúc giá Trung bình)', 'Số năm OS update': '3 năm (Ước lượng: Xiaomi mid, do thương hiệu nan/Masstel không rõ ràng, giả định là tầm trung)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (Dựa trên Giao diện OS: N/A, giả định là ColorOS/HyperOS nếu là Android tầm trung)', 'Chất lượng ảnh ban ngày': '3', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Lý do: Chip tier T107 (UMS9117) tầm trung)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Masstel izi 16 4G', 'sku': 'dien-thoai-masstel-izi-16-4g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Masstel', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 0, 'Độ phân giải camera chính': 'N/A', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '1.77', 'Công nghệ màn hình': 'N/A', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc UMS9117', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '128 MB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '1000 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'v5.1', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '14 mm', 'Trọng lượng': '68.8 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '2', 'Nhiếp ảnh gia (Đối tượng)': '2', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '2', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) Lý do: Thương hiệu Masstel và phân khúc giá Phổ thông dưới 500 nghìn đồng.', 'Số năm OS update': '3 năm Ước lượng dựa trên thương hiệu: Xiaomi mid.', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '3', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud Lý do: Chip tier Unisoc UMS9117 là chip tầm trung.', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Masstel izi 30', 'sku': 'masstel-izi-30', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Masstel', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 0, 'Độ phân giải camera chính': 'N/A', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '2.4 inches', 'Công nghệ màn hình': 'N/A', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '240 x 320 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc UMS9117', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '48MB', 'Bộ nhớ trong': '128MB', 'GPU tier': 'RAM 48MB, ROM 128MB', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '1800 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'v4.2', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa (khung viền kim loại)', 'Chất lượng khung viền': 'Nhựa (khung viền kim loại)', 'Độ mỏng': '15 mm', 'Trọng lượng': '102.9 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '2', 'Camera / Creator (Use Case)': '2', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu Masstel và phân khúc giá Priceline < 500k)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (Dựa trên Giao diện OS: N/A, có thể là ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '3', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Unisoc UMS9117 và thương hiệu)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Masstel Fami 60S 4G', 'sku': 'dien-thoai-masstel-fami-60s', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'nan', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 0, 'Độ phân giải camera chính': 'N/A', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '2.0 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '240 x 320 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'N/A', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '128 MB', 'Bộ nhớ trong': '128 MB', 'GPU tier': 'N/A', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '2300 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '15.2 mm', 'Trọng lượng': '141 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '2', 'Camera / Creator (Use Case)': '1', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '2', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (MIUI/ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '3', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Masstel Lux 20', 'sku': 'masstel-lux-20', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Masstel', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 0, 'Độ phân giải camera chính': 'N/A', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '2.4', 'Công nghệ màn hình': 'TFT LCD', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '240 x 320', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc T107', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '128 MB', 'Bộ nhớ trong': '128 MB', 'GPU tier': 'N/A', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '1800 mAh', 'Sạc có dây': '2.5 W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'v5.0', 'GPS': 'N/A', 'NFC': 'Không', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'không có', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'không có', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '13.4 mm', 'Trọng lượng': '137.6 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '2', 'Freelancer (Đối tượng)': '2', 'Gamer (Đối tượng)': '2', 'Nhiếp ảnh gia (Đối tượng)': '2', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Lý do: Thương hiệu Masstel, phân khúc giá Phe duong pho tong)', 'Số năm OS update': 'N/A', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '3', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Masstel S7 4GB 128GB', 'sku': 'dien-thoai-masstel-s7', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Masstel', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 14 Go', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '13.0 MP', 'Aperture camera chính': 'ƒ/2.0', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '5.0 MP', 'Aperture camera trước': 'ƒ/2.0', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'Flash LED, HDR, Toàn cảnh (Panorama), Quay chậm (Slow Motion), Chụp hình & quay phim với Portrait AI, Pro Time-lapse', 'Kích thước màn hình': '6.745 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '60Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '720 x 1600 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc SC9863A', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'GE8322', 'Hệ điều hành': 'Android 14 Go', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '10 W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '802.11 b/g/n', 'Bluetooth': 'v4.2', 'GPS': 'BDS, GLONASS, GALILEO, GPS, A-GPS', 'NFC': 'N/A', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.8 mm', 'Trọng lượng': '195 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '2', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) Lý do: Thương hiệu Masstel, phân khúc Mid-range 10-15tr', 'Số năm OS update': '3 năm Ước lượng: Xiaomi mid (3 năm)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '3 Tốt ban ngày, tối chấp nhận', 'AI on-device vs Cloud': 'Cloud Lý do: Chip tier Unisoc SC9863A (chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Night Mode, Portrait, Clean Up', 'AI Score tổng hợp': '2'},
    {'name': 'Masstel izi T8', 'sku': 'dien-thoai-masstel-izi-t8', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Masstel', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 0, 'Độ phân giải camera chính': 'N/A', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '2.4 inches', 'Công nghệ màn hình': 'N/A', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'ASR3603S', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': 'N/A', 'Bộ nhớ trong': 'N/A', 'GPU tier': 'N/A', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '2300mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '14mm', 'Trọng lượng': '131.4', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa 2030 box', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '2', 'Camera / Creator (Use Case)': '1', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '2', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Dựa trên thương hiệu Masstel và phân khúc giá Prestige)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên nguồn Masstel/Android)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (Giao diện Android 14 / One UI 7)', 'Chất lượng ảnh ban ngày': '3', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip tier ASR3603S và thương hiệu)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Masstel izi S3 4G', 'sku': 'dien-thoai-masstel-izi-s3', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Masstel', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 0, 'Độ phân giải camera chính': 'N/A', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '1.77 inches', 'Công nghệ màn hình': 'N/A', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '128 x 160 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'N/A', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '16 GB', 'Bộ nhớ trong': '16 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '1000 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '1 SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '15 mm', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu Masstel và thông tin chip Entry)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '3', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Masstel Izi 10 4G', 'sku': 'masstel-izi-10-4g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'nan', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 0, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 0, 'Độ phân giải camera chính': 'N/A', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '1.77', 'Công nghệ màn hình': 'TFT LCD', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '128 x 160', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc UMS9117', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '128 MB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '1000 mAh', 'Sạc có dây': '2.5 W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'v4.2', 'GPS': 'N/A', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'Không', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '12.8 mm', 'Trọng lượng': '75g', 'Số màu sắc': 0, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu nan/Masstel trong phân khúc giá Trung bình/Mid-range)', 'Số năm OS update': '3 năm (Ước lượng dựa trên phân khúc/thương hiệu)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (Dựa trên Giao diện OS N/A)', 'Chất lượng ảnh ban ngày': '3', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Do chip Unisoc UMS9117)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
]

honor_data = [
    {'name': 'HONOR 400 Pro 5G 12GB 512GB', 'sku': 'dien-thoai-honor-400-pro-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Honor', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'MagicOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'MagicOS 9.0 (Android 15)', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '200MP', 'Aperture camera chính': 'f/1.9', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K (3840 × 2160)', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '50MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': '4K (3840 × 2160)', 'Tính năng AI camera': 'Chân dung AI nâng cao, Siêu zoom AI, Chế độ sân khấu, Nghệ thuật, Mô phỏng phim, Ảnh chuyển động, Tua nhanh thời gian, Góc siêu rộng, Chụp đêm, Nhiều video, Toàn cảnh, HDR, Quay chậm, Siêu cận cảnh, Quét tài liệu', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2800 x 1280', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 Gen 3', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Adreno 750', 'Hệ điều hành': 'MagicOS 9.0 (Android 15)', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': '6000 mAh', 'Sạc có dây': '100W', 'Sạc không dây': '50W', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7 (802.11 a/b/g/n/ac/ax/be), 2x2 MIMO', 'Bluetooth': 'v5.4', 'GPS': 'GPS, AGPS, GLONASS, BeiDou, Galileo', 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano SIM hoặc 1 Nano + 1 eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68, IP69', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.1 mm', 'Trọng lượng': '205 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Công nghệ âm thanh HONOR, Loa stereo', 'Hỗ trợ AI': 'Điện thoại AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Dựa trên thương hiệu Honor/Phân khúc Mid-range)', 'Số năm OS update': '4 năm (Dựa trên description)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Snapdragon và thương hiệu)', 'Danh sách tính năng AI thực tế': 'Chân dung AI nâng cao, Siêu zoom AI, Chế độ sân khấu, Nghệ thuật, Mô phỏng phim, Ảnh chuyển động, Tua nhanh thời gian, Góc siêu rộng, Chụp đêm, Nhiều video, Toàn cảnh, HDR, Quay chậm, Siêu cận cảnh, Quét tài liệu, HDR tự động, Chỉnh sửa ảnh AI', 'AI Score tổng hợp': '4'},
    {'name': 'HONOR X8d 8GB 128GB', 'sku': 'dien-thoai-honor-x8d', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'HONOR', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'MagicOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'MagicOS 10 (Dựa trên Android 16)', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '108MP', 'Aperture camera chính': 'f/1.75', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080P (1920×1080)', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16MP', 'Aperture camera trước': 'f/2.45', 'Quay video camera trước': '1080P (1920×1080)', 'Tính năng AI camera': 'Ảnh, Video, Chân dung, Đêm, PRO, Chế độ xem kép, Chuyển động chậm, Toàn cảnh, Tua nhanh thời gian, Độ phân giải cao, Câu chuyện, Quét tài liệu, Chụp nụ cười, v.v.', 'Kích thước màn hình': '6.77 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3000 nit', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2392', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 6s 4G thế hệ 2', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Adreno 610', 'Hệ điều hành': 'MagicOS 10 (Dựa trên Android 16)', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '7000 mAh (giá trị điển hình)', 'Sạc có dây': '45W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '802.11 a/b/g/n/ac, 2.4GHz và 5GHz', 'Bluetooth': 'BT 5.1', 'GPS': 'GPS, AGPS, Glonass, BeiDou, Galileo', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP65', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.5mm', 'Trọng lượng': '188', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Âm thanh HONOR, 300% Âm lượng âm thanh nổi', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Dựa trên thương hiệu HONOR và phân khúc Tầm trung)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': ['Ảnh', 'Video', 'Chân dung', 'Đêm', 'PRO', 'Chế độ xem kép', 'Chuyển động chậm', 'Toàn cảnh', 'Tua nhanh thời gian', 'Độ phân giải cao', 'Câu chuyện', 'Quét tài liệu', 'Chụp nụ cười'], 'AI Score tổng hợp': '3'},
    {'name': 'HONOR X7d 8GB 256GB', 'sku': 'dien-thoai-honor-x7d', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Honor', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'MagicOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15, MagicOS 9.0', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '108 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.77 inches', 'Công nghệ màn hình': 'TFT LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '720 x 1610 px', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm Snapdragon 685', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno 610', 'Hệ điều hành': 'Android 15, MagicOS 9.0', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6500 mAh', 'Sạc có dây': '35W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '1 SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP65', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu Honor/Mid-range)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Snapdragon 685)', 'Danh sách tính năng AI thực tế': ['xóa vật thể', 'mở rộng khung hình', 'sửa mắt nhắm AI', 'Magic Portal', 'Vùng Ma Thuật'], 'AI Score tổng hợp': '3'},
    {'name': 'HONOR X9d 5G 12GB 512GB', 'sku': 'dien-thoai-honor-x9d', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Honor', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'MagicOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'MagicOS 9.0 (Dựa trên Android 15)', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '108MP', 'Aperture camera chính': 'F1.75', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K (3840×2160)', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16MP', 'Aperture camera trước': 'F2.45', 'Quay video camera trước': '1080P (lên đến 2520×1080)', 'Tính năng AI camera': 'Điểm nổi bật, Ảnh động, Nhiếp ảnh AI, Chế độ ban đêm, Chân dung (có làm đẹp), Chuyên nghiệp, Toàn cảnh, Bộ lọc, Tua nhanh thời gian, Độ phân giải cao, Chụp nụ cười, Chuyển động chậm, Góc rộng, Đa video, Đóng dấu, Quét tài liệu, Hẹn giờ', 'Kích thước màn hình': '6.79 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '6000 nits', 'Chất lượng màu': '100% DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1200 x 2640 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 6 Gen 4', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Adreno A810', 'Hệ điều hành': 'MagicOS 9.0 (Dựa trên Android 15)', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '8300 mAh', 'Sạc có dây': '66W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6 (802.11 ax)', 'Bluetooth': 'v5.2', 'GPS': 'GPS, AGPS, Glonass, BeiDou, Galileo', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP66, IP68, IP69, IP69K', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.76 mm', 'Trọng lượng': '193 gram', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'HONOR Sound 7.3, loa stereo', 'Hỗ trợ AI': 'Điện thoại AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%) (Dựa trên thương hiệu Honor/Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng dựa trên dòng sản phẩm Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Snapdragon tầm trung)', 'Danh sách tính năng AI thực tế': ['Ảnh động', 'Nhiếp ảnh AI', 'Chế độ ban đêm', 'Chân dung (có làm đẹp)', 'Chuyên nghiệp', 'Toàn cảnh', 'Bộ lọc', 'Tua nhanh thời gian', 'Độ phân giải cao', 'Chụp nụ cười', 'Chuyển động chậm', 'Góc rộng', 'Đa video', 'Đóng dấu', 'Quét tài liệu', 'Hẹn giờ', 'AI Eraser', 'AI Cutout', 'AI Upscale'], 'AI Score tổng hợp': '4'},
    {'name': 'HONOR 400 5G 12GB 256GB', 'sku': 'dien-thoai-honor-400-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Honor', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'MagicOS', 'Màu sắc hỗ trợ': 1, 'Phiên bản OS ra mắt': 'MagicOS 9.0 (dựa trên Android 15)', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '200MP', 'Aperture camera chính': 'f/1.9', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '3840 × 2160 (4K)', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '50MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': '3840 × 2160 (4K)', 'Tính năng AI camera': 'Siêu zoom AI, Nghệ thuật, Mô phỏng phim, Ảnh chuyển động, Tua nhanh thời gian, Nhiếp ảnh AI, Góc siêu rộng, Khẩu độ, Chụp đêm, Chân dung, Chuyên nghiệp, HDR, Toàn cảnh, Siêu cận cảnh, Quét tài liệu', 'Kích thước màn hình': '6.55 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2736 x 1264', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 7 Gen 3', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno 720', 'Hệ điều hành': 'MagicOS 9.0 (dựa trên Android 15)', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6000 mAh', 'Sạc có dây': '80W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'ax', 'Bluetooth': 'v5.4', 'GPS': 'GPS, AGPS, GLONASS, BeiDou, Galileo', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano SIM hoặc 1 Nano + 1 eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP66', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.3 mm', 'Trọng lượng': '184 g', 'Số màu sắc': 1, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Điện thoại AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Dựa trên thương hiệu Honor/Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Chip Snapdragon tầm trung)', 'Danh sách tính năng AI thực tế': ['Trợ lý ảo Gemini', 'Dịch thuật giọng nói và văn bản theo thời gian thực', 'Khả năng chụp đêm ấn tượng', 'Chụp ảnh động HD', 'Chia sẻ dữ liệu nhanh giữa các nền tảng'], 'AI Score tổng hợp': '3'},
    {'name': 'HONOR X6c 6GB 128GB', 'sku': 'dien-thoai-honor-x6c', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Honor', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'MagicOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'MagicOS 9.0 (Trên nền tảng Android 15)', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'F1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '10X', 'Quay video camera sau': '1080P', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '5MP', 'Aperture camera trước': 'F2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Chân dung (bao gồm chế độ làm đẹp và xóa phông)', 'Kích thước màn hình': '6.6 inches', 'Công nghệ màn hình': 'TFT LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '720 x 1604', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G81 Ultra', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'ARM Mail G52 MC2', 'Hệ điều hành': 'MagicOS 9.0 (Trên nền tảng Android 15)', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5300mAh', 'Sạc có dây': '35W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '802.11 a/b/g/n/ac 2.4 GHz và 5 GHz', 'Bluetooth': 'BT5.1', 'GPS': 'GPS, AGPS, GLONASS, BeiDou, Galileo', 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP64', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.39 mm', 'Trọng lượng': '199 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Dựa trên thương hiệu Honor và phân khúc giá Trung bình)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên Chip MediaTek Helio G81 Ultra và thương hiệu Honor)', 'Danh sách tính năng AI thực tế': 'Chân dung (bao gồm chế độ làm đẹp và xóa phông), Night Mode, Portrait, Clean Up', 'AI Score tổng hợp': '3'},
    {'name': 'HONOR Play 10 4GB 128GB', 'sku': 'dien-thoai-honor-play-10-4gb-128gb', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Honor', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '13 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'FullHD 1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '5 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.74 inches', 'Công nghệ màn hình': 'TFT LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '480 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '720 x 1600 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G81', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'MediaTek Helio G81', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '10W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G', 'Wi-Fi': 'Wi-Fi 5', 'Bluetooth': '5.1', 'GPS': 'GPS, GLONASS, GALILEO, BEIDOU, AGPS', 'NFC': 'N/A', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP52', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.55 mm', 'Trọng lượng': '189g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Lý do: Thương hiệu HONOR, phân khúc Bình dân)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Đáp ứng được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '3 Tốt ban ngày, tối chấp nhận', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Honor X5c Plus 4GB 64GB', 'sku': 'dien-thoai-honor-x5c-plus', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Honor', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'MagicOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 15, MagicOS 9', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1920x1080', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '5 MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': '1080P (1920x1080)', 'Tính năng AI camera': 'Nhận diện khuôn mặt, Chế độ làm đẹp', 'Kích thước màn hình': '6.74 inches', 'Công nghệ màn hình': 'TFT LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '720 x 1600 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G81', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '64 GB', 'GPU tier': 'ARM Mail G52 MC2', 'Hệ điều hành': 'Android 15, MagicOS 9', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5130mAh', 'Sạc có dây': '15W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '2.4GHz và 5GHz', 'Bluetooth': 'BT5.1', 'GPS': 'GPS, AGPS, GLONASS, BeiDou, Galileo', 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': 'Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.9 mm', 'Trọng lượng': '186 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Lý do: Thương hiệu Honor, phân khúc giá Peachmarket 2-3tr)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip MediaTek Helio G81)', 'Danh sách tính năng AI thực tế': 'Nhận diện khuôn mặt, Chế độ làm đẹp, Night Mode, Portrait, Clean Up', 'AI Score tổng hợp': '3'},
    {'name': 'HONOR 400 Lite 5G 12GB 256GB', 'sku': 'dien-thoai-honor-400-lite-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'HONOR', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'MagicOS', 'Màu sắc hỗ trợ': 1, 'Phiên bản OS ra mắt': 'MagicOS 9.0 (Dựa trên Android 15)', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '108MP', 'Aperture camera chính': 'f/1.75', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080P', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16MP', 'Aperture camera trước': 'f/2.45', 'Quay video camera trước': '1080P', 'Tính năng AI camera': 'Chân dung, Chụp đêm, Chuyên nghiệp, Tùy chỉnh khẩu độ, Nhiều video, Chuyển động chậm, Toàn cảnh, Tua nhanh thời gian, Hình chìm mờ, Nhãn dán, Độ phân giải cao, HDR, Ảnh chuyển động, Quét tài liệu, Bắt nét nụ cười', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': '100% DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2412 x 1080', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Dimensity 7025-Ultra', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'IMG BXM-8-256', 'Hệ điều hành': 'MagicOS 9.0 (Dựa trên Android 15)', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5230 mAh', 'Sạc có dây': '35W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': '802.11 a/b/g/n/ac, 2.4GHz & 5GHz', 'Bluetooth': 'v5.3', 'GPS': 'GPS, AGPS, GLONASS, BeiDou, Galileo', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano SIM hoặc 1 Nano + 1 eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP65', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.29 mm', 'Trọng lượng': '171 g', 'Số màu sắc': 1, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Dịch Trực Tiếp AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': ['Chân dung', 'Chụp đêm', 'Chuyên nghiệp', 'Tùy chỉnh khẩu độ', 'Nhiều video', 'Chuyển động chậm', 'Toàn cảnh', 'Tua nhanh thời gian', 'Hình chìm mờ', 'Nhãn dán', 'Độ phân giải cao', 'HDR', 'Ảnh chuyển động', 'Quét tài liệu', 'Bắt nét nụ cười', 'xóa vật thể', 'mở rộng hình ảnh', 'chụp ảnh chuyển động', 'chế độ chân dung đường phố', 'zoom kỹ thuật số đến 10x', 'phím tắt điều khiển Camera AI'], 'AI Score tổng hợp': '4'},
    {'name': 'HONOR Magic V5 16GB 512GB', 'sku': 'dien-thoai-honor-magic-v5', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'HONOR', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'MagicOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'MagicOS 9.0.1 (Dựa trên Android 15)', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/2.0', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '3x', 'Quay video camera sau': '4K (3840 × 2160 điểm ảnh)', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '20MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': ['Chụp cảm biến chuyển động AI', 'Chụp ảnh AI'], 'Kích thước màn hình': '6.4 inches', 'Công nghệ màn hình': 'OLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Màn hình gập', 'Độ phân giải màn hình': '2352 x 2172', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm Snapdragon 8 Elite', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'A+', 'RAM': '16 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Adreno 830', 'Hệ điều hành': 'MagicOS 9.0.1 (Dựa trên Android 15)', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5820 mAh', 'Sạc có dây': '66W', 'Sạc không dây': '50W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7', 'Bluetooth': '6.0SBC', 'GPS': ['GPS(L1+L5)', 'AGPS', 'GLONASS', 'BeiDou(B1I+B1C+B2a+B2b)', 'Galileo(E1+E5a+E5b)', 'QZSS (L1 + L5)'], 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'SIM 1 + SIM 2 / SIM 1 + eSIM / 2 eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP58, IP59', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '9 mm', 'Trọng lượng': '217 g', 'Số màu sắc': 2, 'Điện thoại gập': 'Flip', 'Cảm biến vân tay': 'Bảo mật vân tay', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'HONOR Sound', 'Hỗ trợ AI': ['Điện thoại AI'], 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) (Dựa trên thương hiệu HONOR và phân khúc Cao cấp/Mid-range)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Qualcomm Snapdragon và thương hiệu Honor)', 'Danh sách tính năng AI thực tế': 'Chụp cảm biến chuyển động AI, Chụp ảnh AI, Google Gemini, One Tap Perfection with AI, AI Call Translation', 'AI Score tổng hợp': '3'},
    {'name': 'HONOR X9c 5G 12GB 256GB', 'sku': 'dien-thoai-honor-x9c-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Honor', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'MagicOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'MagicOS 8.0, dựa trên Android 14', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '108MP', 'Aperture camera chính': 'F1.75', 'OIS / Chống rung': 'OIS', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080P', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16MP', 'Aperture camera trước': 'F2.45', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Điểm nổi bật, Ảnh động, Nhiếp ảnh AI, Khẩu độ, Chế độ ban đêm, Chân dung (bao gồm chế độ làm đẹp), Chuyên nghiệp, Toàn cảnh, HDR, Bộ lọc, Chụp ảnh tua nhanh thời gian, Độ phân giải cao, Chụp nụ cười, Chuyển động chậm, Góc rộng, Đa video, Đóng dấu, Quét tà', 'Kích thước màn hình': '6.78 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '4000nit', 'Chất lượng màu': '100% DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2700 x 1224', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm Snapdragon 6 Gen 1', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'MagicOS 8.0, dựa trên Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6600mAh', 'Sạc có dây': '66W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': '802.11 a/b/g/n/ac (2.4 GHz và 5 GHz)', 'Bluetooth': 'BT5.1', 'GPS': 'GPS,AGPS,GLONASS,BeiDou,Galileo', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP65', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.98 mm', 'Trọng lượng': '189', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'HONOR Histen', 'Hỗ trợ AI': 'Điện thoại AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '4', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Lý do: Thương hiệu Honor, phân khúc Mid-range 10-15tr)', 'Số năm OS update': '3 năm (Ước lượng: Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Lý do: Chip tầm trung Snapdragon 6 Gen 1)', 'Danh sách tính năng AI thực tế': ['Điểm nổi bật', 'Ảnh động', 'Nhiếp ảnh AI', 'Khẩu độ', 'Chế độ ban đêm', 'Chân dung (bao gồm chế độ làm đẹp)', 'Chuyên nghiệp', 'Toàn cảnh', 'HDR', 'Bộ lọc', 'Chụp ảnh tua nhanh thời gian', 'Độ phân giải cao', 'Chụp nụ cười', 'Chuyển động chậm', 'Góc rộng', 'Đa video', 'Đóng dấu', 'Quét tà'], 'AI Score tổng hợp': '3'},
]
huawei_data = [
    {'name': 'Huawei nova 3e Chính hãng', 'sku': 'huawei-nova-3e-chinh-hang', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Huawei', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'EMUI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': '8.0 (Oreo)', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '16 MP', 'Aperture camera chính': 'f/2.2', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16 MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': '1080p', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '5.84 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '1080 x 2280 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'HiSilicon Kirin 659', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'C', 'RAM': '64 GB', 'Bộ nhớ trong': '64 GB', 'GPU tier': 'Mali-T830 MP2', 'Hệ điều hành': '8.0 (Oreo)', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '3000 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '802.11 b/g/n', 'Bluetooth': '4.2', 'GPS': ['A-GPS', 'GLONASS'], 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.4 mm', 'Trọng lượng': '145 gram', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Lý do: Thương hiệu Huawei, phân khúc Mid-range 10-15tr)', 'Số năm OS update': '3 năm (Ước lượng từ: Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (MIUI)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Lý do: Chip Kirin 659 - các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Chụp ảnh xóa phông ảo diệu', 'AI Score tổng hợp': '3'},
]

infinix_data = [
    {'name': 'Infinix Note 50 Pro 12GB 256GB', 'sku': 'dien-thoai-infinix-note-50-pro', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Infinix', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.78 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': 'Từ 144Hz trở lên', 'Độ sáng tối đa': '1300 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G100 Ultimate', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': 'N/A', 'Sạc có dây': '90W', 'Sạc không dây': '30W', 'Sạc ngược': 'N/A', 'Mạng di động': 'N/A', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'N/A', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Một chạm Infinix AI, Trợ lý sức khỏe nâng cao', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%) (Dựa trên thương hiệu Infinix/phân khúc Tầm trung)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip MediaTek Helio G100 Ultimate)', 'Danh sách tính năng AI thực tế': 'Night Mode, Portrait, Clean Up, AI camera, Trợ lý sức khỏe nâng cao', 'AI Score tổng hợp': '3'},
    {'name': 'Infinix Note 50 8GB 256GB', 'sku': 'dien-thoai-infinix-note-50', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Infinix', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '13MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.78 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': 'Từ 144Hz trở lên', 'Độ sáng tối đa': '1300 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G100 Ultimate', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5200mAh', 'Sạc có dây': '45W', 'Sạc không dây': '30W', 'Sạc ngược': 'N/A', 'Mạng di động': 'N/A', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'N/A', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép, Tinh chỉnh bởi JBL', 'Hỗ trợ AI': 'Một chạm Infinix AI', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%) Lý do: Thương hiệu Xiaomi/OPPO/Vivo (dựa trên phân khúc giá thấp)', 'Số năm OS update': '3 năm Lý do: Xiaomi mid', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud Lý do: Các hãng khác hoặc chip tầm trung', 'Danh sách tính năng AI thực tế': ['AI, chân dung, macro, Super Night'], 'AI Score tổng hợp': '4'},
    {'name': 'Infinix Note 30 4G 8GB 256GB', 'sku': 'infinix-note-30', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Infinix', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '64MP', 'Aperture camera chính': 'F/1.69', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080P/60FPS', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16MP', 'Aperture camera trước': 'F2.0', 'Quay video camera trước': '1080P/60FPS', 'Tính năng AI camera': 'Video ngắn, làm đẹp, siêu chụp đêm, chân dung, chuyển động chậm, Time-lapse, AR Shot', 'Kích thước màn hình': '6.78 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '580 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '1080x2460 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G99', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Mali-G57 MC2', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5.000 mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '802.11 ac/a/b/g/n(2.4G/5G)', 'Bluetooth': 'v5.0', 'GPS': 'GPS', 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP53', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.58mm', 'Trọng lượng': '219g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh viền', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép bởi JBL', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Do là Infinix tầm trung)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Do sử dụng chip MediaTek Helio G99)', 'Danh sách tính năng AI thực tế': 'Video ngắn, làm đẹp, siêu chụp đêm, chân dung, chuyển động chậm, Time-lapse, AR Shot, Night Mode', 'AI Score tổng hợp': '3'},
    {'name': 'Infinix Hot 40i 4GB 128GB', 'sku': 'dien-thoai-infinix-hot-40i', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Infinix', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android 13', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.6 + AI CAM, f/2.0', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32 MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'AI cam, Làm đẹp, Siêu chụp đêm, Chân dung, Chuyển động chậm, Time-lapse', 'Kích thước màn hình': '6.56 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '480 nits', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '720 x 1612', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc T606 (12 nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G57 MC2, 650MHz', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '18W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 802.11 (a/b/g/n/ac)', 'Bluetooth': 'Có', 'GPS': 'GPS, A-GPS', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.30 mm', 'Trọng lượng': '190 g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa âm thanh nổi', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Lý do: Thương hiệu Infinix, phân khúc giá Giá rẻ)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (MIUI/ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Do sử dụng chip tầm trung Unisoc)', 'Danh sách tính năng AI thực tế': 'Night Mode, Portrait, Clean Up', 'AI Score tổng hợp': '4'},
    {'name': 'Infinix Hot 50 Pro Plus 8GB 256GB', 'sku': 'dien-thoai-infinix-hot-50-pro-plus', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Infinix', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '13MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.78', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '1080 x 2436', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G100', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5,000 mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'G-Sensor / E-Compass / Gyro / Light Sensor / Proximity', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu Infinix)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (MIUI)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Dựa trên thương hiệu và chip tầm trung)', 'Danh sách tính năng AI thực tế': ['Night Mode', 'Portrait', 'Clean Up'], 'AI Score tổng hợp': '2'},
    {'name': 'Infinix Hot 30i 4GB 128GB', 'sku': 'infinix-hot-30i', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Infinix', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 12', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '13 MP', 'Aperture camera chính': 'f/1.85', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.56 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '500 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '720 x 1612', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc T606', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'ARM Mali-G57 MP1', 'Hệ điều hành': 'Android 12', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '18 W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'IEEE 802.11 ac/a/b/g/n(2.4G/5G)', 'Bluetooth': 'Có', 'GPS': 'N/A', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.4 mm', 'Trọng lượng': '191 gram', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) Lý do: Thương hiệu Infinix, phân khúc giá Rẻ, chất lượng tốt', 'Số năm OS update': '3 năm Ước lượng: Xiaomi mid', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud Lý do: Chip tier Unisoc T606 (chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Night Mode, Portrait, Clean Up', 'AI Score tổng hợp': '3'},
    {'name': 'Infinix Hot 50 8GB 256GB', 'sku': 'dien-thoai-infinix-hot-50', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Infinix', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.78 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '800nit', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080x2460', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G100', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5,000 mAh', 'Sạc có dây': '18W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'G-Sensor, E-Compass, Gyro, Light Sensor, Proximity', 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '187 mm', 'Trọng lượng': '187 gr', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Night Mode, Portrait, Clean Up', 'AI Score tổng hợp': '4'},
]

itel_data = [
    {'name': 'Điện thoại Itel P55 Plus NFC 8GB 256GB', 'sku': 'dien-thoai-itel-p55-plus-8gb-256gb', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'itel', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android 13', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Chế độ toàn cảnh, Chế độ siêu đêm, Chân dung AI rõ nét, Chế độ chuyên nghiệp, Chế độ tua nhanh thời gian', 'Kích thước màn hình': '6.6 inches', 'Công nghệ màn hình': 'N/A', 'Tần số quét': '90Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc T606', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'N/A', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Do là thương hiệu Trung Quốc)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Unisoc T606)', 'Danh sách tính năng AI thực tế': 'Chế độ toàn cảnh, Chế độ siêu đêm, Chân dung AI rõ nét, Chế độ chuyên nghiệp, Chế độ tua nhanh thời gian', 'AI Score tổng hợp': '3'},
    {'name': 'Itel RS4 12GB 256GB NFC', 'sku': 'dien-thoai-itel-rs4-12gb-256gb', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'itel', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'f/1.6', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.56 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '720 x 1612', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Mediatek Helio G99 Ultimate', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Mali-G57 MC2', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5,000 mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Có', 'Bluetooth': 'N/A', 'GPS': 'GPS', 'NFC': 'có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.2 mm', 'Trọng lượng': '198 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa âm thanh nổi', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Dựa trên thương hiệu itel)', 'Số năm OS update': '3 năm (Ước lượng dựa trên dòng sản phẩm Xiaomi/mid-range)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '3', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Chip tier Mediatek Helio G99 Ultimate)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Itel RS4 8GB 256GB NFC', 'sku': 'dien-thoai-itel-rs4', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'itel', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'f/1.6', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.56 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '720 x 1612', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Mediatek Helio G99 Ultimate', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Mali-G57 MC2', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5,000 mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Có', 'Bluetooth': 'N/A', 'GPS': 'GPS', 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.2 mm', 'Trọng lượng': '198 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa âm thanh nổi', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '2', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '4', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Dựa trên phân khúc Mid-range)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Mediatek Helio G99)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
]

nokia_data = [
    {'name': 'Nokia 220 4G', 'sku': 'nokia-220-4g', 'Phân khúc giá': 'Giá rẻ', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Nokia', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'S30+', 'Số lượng camera sau (thật)': 0, 'Độ phân giải camera chính': 'N/A', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '2.8 inches', 'Công nghệ màn hình': 'QQVGA', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc T107', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '128 MB', 'Bộ nhớ trong': '128 MB', 'GPU tier': 'N/A', 'Hệ điều hành': 'S30+', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '1450 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'v5.0', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '11.63 mm', 'Trọng lượng': 'N/A', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Đài FM (Yêu cầu tai nghe)', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '2', 'Nhiếp ảnh gia (Đối tượng)': '2', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': "Thấp-Trung bình (~30-45%) (Lý do: Thương hiệu Nokia, phân khúc giá 'Giá rẻ' và chip tầm trung Unisoc T107)", 'Số năm OS update': '3 năm (Ước lượng dựa trên dòng sản phẩm)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '3', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Lý do: Chip tầm trung Unisoc T107)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Nokia 3210 4G', 'sku': 'nokia-3210-4g', 'Phân khúc giá': 'Giá rẻ', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Nokia', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '2MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '2.4 inches', 'Công nghệ màn hình': 'N/A', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc T107', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '128 MB', 'Bộ nhớ trong': '128 MB', 'GPU tier': 'N/A', 'Hệ điều hành': 'N/A', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '1450 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'v5.0', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'không có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '13,14 mm', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '2', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '2', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': "Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu Nokia và phân khúc giá 'Giá rẻ')", 'Số năm OS update': '3 năm (Ước lượng dựa trên thương hiệu Nokia/dòng sản phẩm)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (Dựa trên Giao diện OS N/A)', 'Chất lượng ảnh ban ngày': '3', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Nokia C32 4GB 128GB', 'sku': 'nokia-c32', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Nokia', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android 13', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.5 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '720 x 1600 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc SC9863A (28nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'IMG8322', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5050 mAh', 'Sạc có dây': '10W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G', 'Wi-Fi': '802.11 b/g/n', 'Bluetooth': 'v5.2', 'GPS': 'GPS/AGPS/Galileo', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP52', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.55 mm', 'Trọng lượng': '199.4g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Lý do: Thương hiệu Nokia, phân khúc giá Trung bình)', 'Số năm OS update': '3 năm (Ước lượng: Nokia/Android tầm trung)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '3 Tốt ban ngày, tối chấp nhận', 'AI on-device vs Cloud': 'Cloud (Dựa trên Chip tier Unisoc SC9863A tầm trung)', 'Danh sách tính năng AI thực tế': 'Chụp chân dung, Chụp ban đêm, HDR tự động', 'AI Score tổng hợp': '2'},
]

oppo_data = [
    {'name': 'OPPO Reno15 F 5G 8GB 256GB', 'sku': 'dien-thoai-oppo-reno15-f', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'ColorOS 16.0', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '50MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': '4K@30fps', 'Tính năng AI camera': 'Chân dung, Ban đêm, Toàn cảnh, Macro, PRO, HI-RES, Google Lens, Chụp dưới nước, Scan tài liệu, Retouch', 'Kích thước màn hình': '6.5 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1400 nits', 'Chất lượng màu': 'DCI-P3 100%', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2372 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm Snapdragon 6 Gen 1 5G', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno 710', 'Hệ điều hành': 'ColorOS 16.0', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '7000mAh', 'Sạc có dây': '80W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 5 (802.11ac)', 'Bluetooth': 'v5.1', 'GPS': 'GPS, GLONASS, Beidou, Galileo, QZSS, A-GPS', 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano SIM (Sim 2 chung khe với thẻ nhớ)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP66, IP68, IP69', 'Chất lượng mặt lưng': 'Thuỷ tinh hữu cơ', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.14 mm', 'Trọng lượng': '195g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu OPPO)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Qualcomm Snapdragon)', 'Danh sách tính năng AI thực tế': 'Chân dung, Ban đêm, Toàn cảnh, Macro, PRO, HI-RES, Google Lens, Chụp dưới nước, Scan tài liệu, Retouch, Night Mode, Portrait, Clean Up, Lưu trữ nội dung quan trọng, Tổ chức thông tin theo Smart Collections, Phân loại nội dung dựa trên chủ đề', 'AI Score tổng hợp': '5'},
    {'name': 'OPPO Find N6 16GB 512GB', 'sku': 'dien-thoai-oppo-find-n6', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'ColorOS 16.0', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '200MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '50x', 'Quay video camera sau': '4K@120fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '20MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': '4K@30fps', 'Tính năng AI camera': 'Chân dung, Ban đêm, Toàn cảnh, Cinematic, Slow motion, Timelapse, Xpan, HI-RES', 'Kích thước màn hình': '8.1 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1800 nits', 'Chất lượng màu': '10-bit (1.07 tỷ màu), 100% DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Màn hình gập', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon® 8 Elite Gen 5', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'A+', 'RAM': '16 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Adreno 840', 'Hệ điều hành': 'ColorOS 16.0', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6000 mAh', 'Sạc có dây': '80W', 'Sạc không dây': '50W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7', 'Bluetooth': 'v6.0', 'GPS': 'GPS, GLONASS, Galileo, BDS, QZSS, NavIC', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Dual nano-SIM hoặc 1 nano-SIM + 1 eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP56 | IP58 | IP595', 'Chất lượng mặt lưng': 'Sợi thuỷ tinh', 'Chất lượng khung viền': 'Hợp kim nhôm', 'Độ mỏng': '8.93 mm', 'Trọng lượng': '225g', 'Số màu sắc': 2, 'Điện thoại gập': 'Flip', 'Cảm biến vân tay': 'Cảm biến vân tay cạnh bên', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Lý do: Thương hiệu OPPO/Xiaomi/Vivo)', 'Số năm OS update': '3-4 năm (Nguồn ước lượng: OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Lý do: Chip Snapdragon® 8 Elite Gen 5, hãng OPPO)', 'Danh sách tính năng AI thực tế': ['Thuật toán AI tự động cân chỉnh ánh sáng chân dung hài hòa'], 'AI Score tổng hợp': '3'},
    {'name': 'OPPO Reno15 5G 12GB 256GB', 'sku': 'dien-thoai-oppo-reno15', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'ColorOS 16.0', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'OIS quang học/EIS điện tử', 'Zoom quang học': '50MP', 'Quay video camera sau': '4K@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '50MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': '4K@60fps', 'Tính năng AI camera': 'Ban đêm, Chân dung, PRO, Toàn cảnh, Time-lapse, Hi-Res, Google Lens, Dưới nước, Quét văn bản, Điện ảnh', 'Kích thước màn hình': '6.59 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1200 nits', 'Chất lượng màu': '10-bit (1.07 tỷ màu), 100% DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1256 x 2760', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm Snapdragon 7 Gen4 5G', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno 722', 'Hệ điều hành': 'ColorOS 16.0', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6500 mAh', 'Sạc có dây': '80W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': 'v5.4', 'GPS': 'GPS, GLONASS, Beidou, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Dual nano-SIM hoặc 1 nano-SIM + 1 eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP66, IP68, IP69', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.89 mm', 'Trọng lượng': '197 gram', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép, 3 micro', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (OPPO/Xiaomi/Vivo)', 'Số năm OS update': '3-4 năm (Ước lượng: OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chipset Snapdragon)', 'Danh sách tính năng AI thực tế': ['O+ Connect', 'AI Eraser', 'AI Mind Space', 'AI Translate', 'AI Call Translator', 'Skin Tone Improvement', 'AI Motion Photo Slow-Mo'], 'AI Score tổng hợp': '4'},
    {'name': 'OPPO Find X8 16GB 512GB', 'sku': 'dien-thoai-oppo-find-x8', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'F/2.4', 'Quay video camera trước': '4K@60fps', 'Tính năng AI camera': 'Chụp đêm, Cinematic, Slo-mo, Time-lapse, Sticker, Scan tài liệu, XPAN, HI-RES, Master', 'Kích thước màn hình': '6.59 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1600 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'GG 7i', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1256 x 2760 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Dimensity 9400', 'AnTuTu score': 3205688, 'Xếp loại chip': 'A+', 'RAM': '16 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Immortalis G925 MC12', 'Hệ điều hành': 'ColorOS 15, nền tảng Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5630 mAh', 'Sạc có dây': '80W', 'Sạc không dây': '50W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'N/A', 'Bluetooth': '5.4 BLE', 'GPS': 'GPS, GLONASS, BDS, Galileo, QZSS, NavlC', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Dual nano-SIM hoặc 1 nano-SIM + 1 eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68/69', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.85 mm', 'Trọng lượng': '193 gr', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'Điện thoại AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '4', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu OPPO)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip MediaTek Dimensity 9400)', 'Danh sách tính năng AI thực tế': 'Chụp đêm, Cinematic, Slo-mo, Time-lapse, Sticker, Scan tài liệu, XPAN, HI-RES, Master', 'AI Score tổng hợp': '3'},
    {'name': 'OPPO Reno10 Pro+ 5G 12GB 256GB', 'sku': 'oppo-reno10-pro-plus', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'OIS', 'Zoom quang học': '5x', 'Quay video camera sau': '4K@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32 MP', 'Aperture camera trước': 'f/2.4', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.74 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1100 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1240 x 2772 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 plus Gen 1 8 nhân', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'B', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno 730', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': '4700 mAh', 'Sạc có dây': '100W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': 'v5.3', 'GPS': 'GPS, GLONASS, GALILEO, BEIDOU', 'NFC': 'có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IPX4', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Kính', 'Độ mỏng': '8.3 mm', 'Trọng lượng': '194 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép, Dolby Atmos', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A'},
    {'name': 'OPPO A6 Pro 8GB 256GB', 'sku': 'dien-thoai-oppo-a6-pro', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16MP', 'Aperture camera trước': 'f/2.4', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Chế độ chân dung, HDR, AI', 'Kích thước màn hình': '6.57 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1400 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2372', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G100', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'ARM G57 MC2@1G', 'Hệ điều hành': 'ColorOS 15 (Android 15)', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '7000mAh', 'Sạc có dây': '80W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G', 'Wi-Fi': '2.4G/5G', 'Bluetooth': '5.4 BLE', 'GPS': 'GPS, GLONASS, BDS, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano SIM (Sim 2 chung khe với thẻ nhớ)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP66, IP68, IP69', 'Chất lượng mặt lưng': 'Thuỷ tinh hữu cơ', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8 mm', 'Trọng lượng': '188', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép, micro kép', 'Hỗ trợ AI': 'Điện thoại AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu OPPO)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Chế độ chân dung, HDR, AI, Night Mode, Portrait, Clean Up, AI GameBoost 2.0', 'AI Score tổng hợp': '3'},
    {'name': 'OPPO Find X9 Pro 16GB 512GB', 'sku': 'dien-thoai-oppo-find-x9-pro', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'ColorOS 16, nền tảng Android 16', 'Số lượng camera sau (thật)': 4, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/2.0', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '2x', 'Quay video camera sau': '4K@120fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '50MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': '4K@60fps', 'Tính năng AI camera': 'Chân dung, ban đêm, PRO, PANO, toàn cảnh, chuyển động chậm, HDR, chế độ xem kép, Hasselblad Hi-Res, chụp dưới nước, Google Lens, Doc Scanner', 'Kích thước màn hình': '6.78', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '800 nits', 'Chất lượng màu': '100% DCI-P3', 'Kính bảo vệ màn hình': 'Gorilla Glass Victus 2', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1272 x 2772', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Dimensity 9500 5G', 'AnTuTu score': 3508681, 'Xếp loại chip': 'A+', 'RAM': '16 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Arm Mali Drage MC12', 'Hệ điều hành': 'ColorOS 16, nền tảng Android 16', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '7500mAh', 'Sạc có dây': '80W', 'Sạc không dây': '50W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': 'v6.0', 'GPS': 'GPS, GLONASS, BDS, Galileo, QZSS, NavlC', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Dual nano-SIM hoặc 1 nano-SIM + 1 eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP66, IP68, IP69', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '8.25 mm', 'Trọng lượng': '224g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Đối tượng)': '4', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '4', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Do là OPPO/Xiaomi)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Do chip Dimensity 9500 5G)', 'Danh sách tính năng AI thực tế': ['Chân dung', 'ban đêm', 'PRO', 'PANO', 'toàn cảnh', 'chuyển động chậm', 'HDR', 'chế độ xem kép', 'Hasselblad Hi-Res', 'chụp dưới nước', 'Google Lens', 'Doc Scanner', 'ColorOS 16', 'Gemini Live'], 'AI Score tổng hợp': '5'},
    {'name': 'OPPO Find X9 16GB 512GB', 'sku': 'dien-thoai-oppo-find-x9-16gb-512gb', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'ColorOS 16, nền tảng Android 16', 'Số lượng camera sau (thật)': 4, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@120fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'f/2.4', 'Quay video camera trước': '4K@60fps', 'Tính năng AI camera': 'Chụp đêm, chân dung, PRO, toàn cảnh, XPAN, Hasselblad HI-RES, Google Lens, chụp dưới nước, quét tài liệu', 'Kích thước màn hình': '6.59 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1800nits', 'Chất lượng màu': '100% DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1256 x 2760', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Dimensity 9500 5G', 'AnTuTu score': 3508681, 'Xếp loại chip': 'A+', 'RAM': '16 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Arm Mali Drage MC12', 'Hệ điều hành': 'ColorOS 16, nền tảng Android 16', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': '7025mAh', 'Sạc có dây': '80W', 'Sạc không dây': '50W', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6, Wi-Fi 2.4G/5G, 802.11 a/b/g/n/ac/ax', 'Bluetooth': 'v6.0', 'GPS': 'GPS, GLONASS, BDS, Galileo, QZSS, NavlC', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Dual nano-SIM hoặc 1 nano-SIM + 1 eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP66, IP68, IP69', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.99 mm', 'Trọng lượng': '203g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '4', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Do là OPPO/Xiaomi)', 'Số năm OS update': '3-4 năm (Ước lượng từ OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Do sử dụng Dimensity 9500 5G)', 'Danh sách tính năng AI thực tế': ['Chụp đêm', 'chân dung', 'PRO', 'toàn cảnh', 'XPAN', 'Hasselblad HI-RES', 'Google Lens', 'chụp dưới nước', 'quét tài liệu'], 'AI Score tổng hợp': '3'},
    {'name': 'OPPO Reno12 5G 12GB 256GB', 'sku': 'dien-thoai-oppo-reno12-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Dimensity 7300', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '80W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'N/A', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Thấp (~30-45%) (OPPO/Xiaomi/OPPO)', 'Số năm OS update': '3-4 năm (Ước lượng từ OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip MediaTek Dimensity 7300)', 'Danh sách tính năng AI thực tế': 'Khả năng tách nền, ghép sticker, xóa vật thể AI', 'AI Score tổng hợp': '3'},
    {'name': 'OPPO Reno14 5G 12GB 256GB', 'sku': 'dien-thoai-oppo-reno14', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'F/1.8', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '50MP', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '50MP', 'Aperture camera trước': 'F/2.0', 'Quay video camera trước': 'Có', 'Tính năng AI camera': 'Nhận diện khuôn mặt', 'Kích thước màn hình': '6.59 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1200 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '1256 x 2760', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Dimensity 8350 5G', 'AnTuTu score': 1718082, 'Xếp loại chip': 'B', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'ARM G615-MC6', 'Hệ điều hành': 'ColorOS 15, Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6000mAh', 'Sạc có dây': '80W', 'Sạc không dây': 'Không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6 (802.11 a/b/g/n/ac/ax), 2.4G/5G', 'Bluetooth': '5.4 BLE', 'GPS': 'GPS, GLONASS, BDS, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'Không', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP66, IP68, IP69', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Hợp kim', 'Độ mỏng': '7.42 mm', 'Trọng lượng': '187g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'Điện thoại AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Do là OPPO/Mid-range)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Do chip MediaTek Dimensity)', 'Danh sách tính năng AI thực tế': ['Nhận diện khuôn mặt'], 'AI Score tổng hợp': '2'},
    {'name': 'OPPO Reno12 F 5G 8GB 256GB', 'sku': 'dien-thoai-oppo-reno12-f', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Dimensity 6300', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'N/A', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'Điện thoại AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Lý do: Thương hiệu OPPO/Xiaomi/Vivo)', 'Số năm OS update': '3-4 năm (Nguồn ước lượng: OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Lý do: Chip tầm trung MediaTek D6300)', 'Danh sách tính năng AI thực tế': 'Nhận diện khuôn mặt', 'AI Score tổng hợp': '2'},
    {'name': 'OPPO Find N3 16GB 512GB', 'sku': 'oppo-find-n3', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '48MP', 'Aperture camera chính': 'f/1.7', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '64MP', 'Quay video camera sau': '4K@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '20MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'Ban đêm, Chuyên nghiệp, HDR, Phơi sáng, Zoom quang học, Làm đẹp, Nhãn dán (AR Stickers)', 'Kích thước màn hình': '7.82 inches', 'Công nghệ màn hình': 'OLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2800 nit', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Màn hình gập', 'Độ phân giải màn hình': '2268 x 2440', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 Gen 2 8 nhân', 'AnTuTu score': 1752044, 'Xếp loại chip': 'B', 'RAM': '16 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Adreno 740', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'Không', 'Dung lượng pin': '4805 mAh', 'Sạc có dây': '67W', 'Sạc không dây': 'Sạc ngược không dây', 'Sạc ngược': 'Có', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7', 'Bluetooth': 'v5.3', 'GPS': 'GPS, GLONASS, GALILEO, BEIDOU, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '1 SIM + eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IPX4', 'Chất lượng mặt lưng': 'Đen', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '5.9', 'Trọng lượng': '245 g', 'Số màu sắc': 2, 'Điện thoại gập': 'Flip', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '4', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu OPPO)', 'Số năm OS update': '3-4 năm (Ước lượng: OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Snapdragon)', 'Danh sách tính năng AI thực tế': ['Công cụ xóa chủ thể AI'], 'AI Score tổng hợp': '3'},
    {'name': 'OPPO Find X5 Pro 5G 12GB 256GB', 'sku': 'oppo-find-x5-pro', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'ColorOS 12.1 dựa trên Android 12', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.7', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'f/2.4', 'Quay video camera trước': '1080P/720P (30fps)', 'Tính năng AI camera': 'Night Mode, Pro, Panorama, chân dung, Time-lapse, quay chậm, quét văn bản, Hi-Res, chế độ phim, phơi sáng lâu, video kép, ống kính Google, Sticker', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1300 nits', 'Chất lượng màu': '100% DCI-P3', 'Kính bảo vệ màn hình': 'Corning Gorilla Glass Victus', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1440 x 3216 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm Snapdragon 8 Gen 1', 'AnTuTu score': 1294632, 'Xếp loại chip': 'B', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno 730 @818MHz', 'Hệ điều hành': 'ColorOS 12.1 dựa trên Android 12', 'Công nghệ tản nhiệt': 'Hệ thống tản nhiệt thế hệ mới với khoang chứa hơi siêu lớn với diện tích lớn hơn gần 75% cùng các màng graphene 3D tiên tiến', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '80W', 'Sạc không dây': 'Có', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6 (802.11ax)', 'Bluetooth': '5.2', 'GPS': 'GPS: L1, Galileo: E1, BeiDou: B1I + B1C, QZSS: L1', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Gốm', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': '8.5 mm', 'Trọng lượng': '218 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Dolby Atmos', 'Hỗ trợ AI': 'Tích hợp NPU MariSilicon X', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '4', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (OPPO/Xiaomi/Vivo)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Snapdragon và thương hiệu)', 'Danh sách tính năng AI thực tế': 'Night Mode, Pro, Panorama, chân dung, Time-lapse, quay chậm, quét văn bản, Hi-Res, chế độ phim, phơi sáng lâu, video kép, ống kính Google, Sticker, Tích hợp NPU MariSilicon X', 'AI Score tổng hợp': '4'},
    {'name': 'OPPO A5i Pro 8GB 128GB', 'sku': 'dien-thoai-oppo-a5i-pro', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'ColorOS 15 (nền tảng Android 15)', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'F/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '5 MP', 'Aperture camera trước': 'F/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Chế độ chụp chân dung, xóa phông, HDR, AI', 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '1000 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '720 x 1604', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 6s 4G Gen1', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Adreno 610', 'Hệ điều hành': 'ColorOS 15 (nền tảng Android 15)', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6000mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '2.4G/5G', 'Bluetooth': '5.0', 'GPS': 'Beidou, GPS, GLONASS, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP65', 'Chất lượng mặt lưng': 'Thuỷ tinh hữu cơ', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '7.99 mm', 'Trọng lượng': '193', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Thấp (~35-45%) (Lý do: OPPO/Xiaomi/OPPO mid-range)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Do sử dụng Snapdragon 6s 4G Gen1)', 'Danh sách tính năng AI thực tế': 'Chế độ chụp chân dung, xóa phông, HDR, AI, Selfie, Video Call, Online Learning', 'AI Score tổng hợp': '3'},
    {'name': 'OPPO A6t 4GB 64GB', 'sku': 'dien-thoai-oppo-a6t', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '13MP', 'Aperture camera chính': 'f/2.2 + f/3.0', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '5MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.75 inches', 'Công nghệ màn hình': 'LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1125 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Kính cường lực Panda', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm Snapdragon 685', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '64 GB', 'GPU tier': 'Adreno 610', 'Hệ điều hành': 'ColorOS 15, nền tảng Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6100mAh', 'Sạc có dây': '15W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G', 'Wi-Fi': 'Wi-Fi 2.4G/5G, 802.11 a/b/g/n/ac', 'Bluetooth': 'v5.0', 'GPS': 'GPS, GLONASS, BDS, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP64', 'Chất lượng mặt lưng': 'Thuỷ tinh hữu cơ', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.61mm', 'Trọng lượng': '205g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (OPPO/Xiaomi/OPPO)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên Chip Snapdragon tầm trung)', 'Danh sách tính năng AI thực tế': 'Nhận diện khuôn mặt', 'AI Score tổng hợp': '2'},
    {'name': 'OPPO Reno10 5G 8GB 256GB', 'sku': 'oppo-reno10', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '64MP', 'Aperture camera chính': 'f/1.7', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '2X', 'Quay video camera sau': '4K@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32 MP', 'Aperture camera trước': 'f/2.4', 'Quay video camera trước': '1080P@30fps', 'Tính năng AI camera': 'Trôi nhanh thời gian (Time Lapse), Góc siêu rộng, Zoom kỹ thuật số, Quét tài liệu, Quay chậm, Xóa phông, Toàn cảnh (Panorama), Chống rung quang học (OIS), Ban đêm, Chuyên nghiệp (Pro), HDR, Zoom quang học', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '950 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2412', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Dimensity 7050 5G 8 nhân', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'ARM Mail-G68 MC4', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '67W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': '5.3', 'GPS': 'GPS, GLONASS, GALILEO, BDS, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Hợp kim', 'Độ mỏng': '7.99 mm', 'Trọng lượng': '185 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'Trợ lý ảo Google Assistant', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Lý do: Thương hiệu OPPO/Xiaomi tầm trung)', 'Số năm OS update': '3-4 năm (Nguồn ước lượng: OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Lý do: Chip MediaTek Dimensity, không phải dòng chip cao cấp tập trung AI on-device như Apple/Google flagship)', 'Danh sách tính năng AI thực tế': ['Trôi nhanh thời gian (Time Lapse)', 'Góc siêu rộng', 'Zoom kỹ thuật số', 'Quét tài liệu', 'Quay chậm', 'Xóa phông', 'Toàn cảnh (Panorama)', 'Chống rung quang học (OIS)', 'Ban đêm', 'Chuyên nghiệp (Pro)', 'HDR', 'Zoom quang học', 'Google Lens', 'Chế Độ Dễ Thương'], 'AI Score tổng hợp': '4'},
    {'name': 'OPPO Find N3 Flip 12GB 256GB', 'sku': 'oppo-find-n3-flip', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '3x', 'Quay video camera sau': '4K@2160p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32 MP', 'Aperture camera trước': 'f/2.4', 'Quay video camera trước': '4K@30fps', 'Tính năng AI camera': 'Trôi nhanh thời gian, Zoom kỹ thuật số, Quét tài liệu, Quay chậm, Xóa phông, Toàn cảnh, Chống rung quang học (OIS), Tự động lấy nét (AF), Ảnh Raw, Ban đêm, Chuyên nghiệp (Pro), HDR, Phơi sáng, Zoom quang học, Siêu độ phân gi', 'Kích thước màn hình': '6.8 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1600 nits', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Màn hình gập', 'Độ phân giải màn hình': '1080 x 2520 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Dimensity 9200', 'AnTuTu score': 1755232, 'Xếp loại chip': 'B', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Immortalis-G715 MC11', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': '4300 mAh', 'Sạc có dây': '44 W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7', 'Bluetooth': 'v5.3', 'GPS': ['BEIDOU', 'QZSS', 'GPS', 'GLONASS', 'GALILEO'], 'NFC': 'có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IPX4', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.79 mm', 'Trọng lượng': '198 g', 'Số màu sắc': 2, 'Điện thoại gập': 'Flip', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Dolby Atmos', 'Hỗ trợ AI': 'Trợ lý ảo Google Assistant', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Do là OPPO/Xiaomi/Vivo)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Do sử dụng chip MediaTek Dimensity)', 'Danh sách tính năng AI thực tế': 'Trôi nhanh thời gian, Zoom kỹ thuật số, Quét tài liệu, Quay chậm, Xóa phông, Toàn cảnh, Chống rung quang học (OIS), Tự động lấy nét (AF), Ảnh Raw, Ban đêm, Chuyên nghiệp (Pro), HDR, Phơi sáng, Zoom quang học, Siêu độ phân gi, Trợ lý ảo Google Assistant', 'AI Score tổng hợp': '3'},
    {'name': 'OPPO Find X9 12GB 256GB', 'sku': 'dien-thoai-oppo-find-x9', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'ColorOS 16.0', 'Số lượng camera sau (thật)': 4, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@120fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'f/2.4', 'Quay video camera trước': '4K@60fps', 'Tính năng AI camera': 'Chụp đêm, chân dung, PRO, toàn cảnh, XPAN, Hasselblad HI-RES, Google Lens, chụp dưới nước, quét tài liệu', 'Kích thước màn hình': '6.59 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1800nits', 'Chất lượng màu': '10-bit, 100% DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1256 x 2760', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Dimensity 9500 5G', 'AnTuTu score': 3508681, 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Arm Mali Drage MC12', 'Hệ điều hành': 'ColorOS 16.0', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': '7025mAh', 'Sạc có dây': '80W', 'Sạc không dây': '50W', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': 'v6.0', 'GPS': 'GPS, GLONASS, BDS, Galileo, QZSS, NavlC', 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Dual nano-SIM hoặc 1 nano-SIM + 1 eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP66, IP68, IP69', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.99 mm', 'Trọng lượng': '203g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '4', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~30-45%) (Lý do: Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3-4 năm (Nguồn ước lượng: OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Lý do: Chip tầm trung)', 'Danh sách tính năng AI thực tế': ['Chụp đêm', 'chân dung', 'PRO', 'toàn cảnh', 'XPAN', 'Hasselblad HI-RES', 'Google Lens', 'chụp dưới nước', 'quét tài liệu'], 'AI Score tổng hợp': '3'},
    {'name': 'OPPO Find N5 16GB 512GB', 'sku': 'dien-thoai-oppo-find-n5', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'ƒ/1.8', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8MP', 'Aperture camera trước': 'ƒ/2.4', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '8.12 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1400nit', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2480 x 2248', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm Snapdragon® 8 Elite', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'A+', 'RAM': '16 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Adreno 830', 'Hệ điều hành': 'ColorOS 15, nền tảng Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5600mAh', 'Sạc có dây': '80W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': '5.4 BLE', 'GPS': 'GPS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Dual nano-SIM hoặc 1 nano-SIM + 1 eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IPX6, IPX8, IPX9', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'Hợp kim', 'Độ mỏng': '4.21 mm', 'Trọng lượng': '229g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': '2 loa, 4 mic', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Do là OPPO/Xiaomi)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Snapdragon và thương hiệu)', 'Danh sách tính năng AI thực tế': 'Khoanh Để Tìm Kiếm, Trợ lý tài liệu, Tóm tắt văn bản, Rút gọn nội dung, Mở rộng ý tưởng, Thay đổi văn phong, Tóm tắt cuộc gọi, On-device processing', 'AI Score tổng hợp': '5'},
    {'name': 'OPPO A3X 6GB 128GB', 'sku': 'dien-thoai-oppo-a3x-6gb-128gb', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'ColorOS 14.0', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '8MP', 'Aperture camera chính': 'f/2', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080P@30 fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '5MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': '1080P/720P@30fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '720 x 1604', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm® Snapdragon® 6s 4G Gen1', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Adreno 610@1050MHz', 'Hệ điều hành': 'ColorOS 14.0', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5100mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G', 'Wi-Fi': 'Wi-Fi 5', 'Bluetooth': 'v5.0', 'GPS': 'GPS', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.68 mm', 'Trọng lượng': '186g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu OPPO)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Qualcomm Snapdragon)', 'Danh sách tính năng AI thực tế': 'time-lapse, phóng to tiện lợi', 'AI Score tổng hợp': '2'},
    {'name': 'OPPO A58 8GB 128GB', 'sku': 'oppo-a58-8gb-128gb', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'FullHD 1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Xóa phông, Tự động lấy nét (AF), Trôi nhanh thời gian (Time Lapse), Toàn cảnh (Panorama), Nhãn dán (AR Stickers), Làm đẹp, Hiệu ứng Bokeh, Chuyên nghiệp (Pro), Ban đêm (Night Mode)', 'Kích thước màn hình': '6.72 inches', 'Công nghệ màn hình': 'N/A', 'Tần số quét': '60Hz', 'Độ sáng tối đa': '680 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Kính cường lực Panda', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2412 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G85 8 nhân', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G52 MP2', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': '5,000mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': '802.11 a/b/g/n/ac', 'Bluetooth': 'v5.3', 'GPS': ['GPS', 'GLONASS', 'GALILEO', 'BEIDOU'], 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'Thuỷ tinh hữu cơ', 'Chất lượng khung viền': 'Hợp kim', 'Độ mỏng': '7.99 mm', 'Trọng lượng': '192 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa stereo kép', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Lý do: OPPO/Xiaomi tầm trung)', 'Số năm OS update': '3-4 năm (Nguồn ước lượng: OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Lý do: Sử dụng chip MediaTek Helio G85 tầm trung)', 'Danh sách tính năng AI thực tế': 'Xóa phông, Tự động lấy nét (AF), Trôi nhanh thời gian (Time Lapse), Toàn cảnh (Panorama), Nhãn dán (AR Stickers), Làm đẹp, Hiệu ứng Bokeh, Chuyên nghiệp (Pro), Ban đêm (Night Mode)', 'AI Score tổng hợp': '3'},
    {'name': 'OPPO A78 4G 8GB 256GB', 'sku': 'oppo-a78', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'Google Lens, Trôi nhanh thời gian (Time Lapse), Toàn cảnh (Panorama), Tự động lấy nét (AF), Ban đêm (Night Mode), Quay chậm (Slow Motion), Xóa phông', 'Kích thước màn hình': '6.43 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '430 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Kính cường lực Corning Gorilla Glass 5', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2400', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm Snapdragon 680', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno 610', 'Hệ điều hành': 'ColorOS 13.1.1, nền tảng Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '67W', 'Sạc không dây': 'Không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '802.11 ac', 'Bluetooth': 'v5.0', 'GPS': 'GLONASS, GPS, GALILEO, QZSS', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': '7.93 mm', 'Trọng lượng': '180g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (OPPO/Xiaomi/Vivo)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Chip tầm trung Qualcomm Snapdragon 680)', 'Danh sách tính năng AI thực tế': ['Google Lens', 'Trôi nhanh thời gian (Time Lapse)', 'Toàn cảnh (Panorama)', 'Tự động lấy nét (AF)', 'Ban đêm (Night Mode)', 'Quay chậm (Slow Motion)', 'Xóa phông'], 'AI Score tổng hợp': '4'},
    {'name': 'OPPO A18 4GB 128GB', 'sku': 'oppo-a18', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '8 MP', 'Aperture camera chính': 'f/2.0', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'FullHD 1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '5 MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': '1080P/720P@30fps', 'Tính năng AI camera': 'Trôi nhanh thời gian (Time Lapse), Xóa phông, Ban đêm (Night Mode), Chuyên nghiệp (Pro), Làm đẹp, Nhãn dán (AR Stickers), Google Lens, Bộ lọc màu', 'Kích thước màn hình': '6.5 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '720 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Kính cường lực Panda', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '720 x 1612', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G85 8 nhân', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali G52 MP2', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '10W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G', 'Wi-Fi': '2.4G/5G', 'Bluetooth': 'v5.3', 'GPS': 'B11; GPS: L1; GLONASS: G1; Galileo: E1; QZSS: L1', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.16 mm', 'Trọng lượng': '188g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu OPPO)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip MediaTek Helio G85)', 'Danh sách tính năng AI thực tế': ['Trôi nhanh thời gian (Time Lapse)', 'Xóa phông', 'Ban đêm (Night Mode)', 'Chuyên nghiệp (Pro)', 'Làm đẹp', 'Nhãn dán (AR Stickers)', 'Google Lens', 'Bộ lọc màu'], 'AI Score tổng hợp': '3'},
    {'name': 'OPPO Reno11 F 5G 8GB 256GB', 'sku': 'dien-thoai-oppo-reno-11-f', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '64 MP', 'Aperture camera chính': 'f/1.7', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32 MP', 'Aperture camera trước': 'f/2.4', 'Quay video camera trước': '4K@30fps, 1080p@30fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2412 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Mediatek Dimensity 7050 (6 nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'ColorOS 14 Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '67W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': 'v5.2', 'GPS': 'GPS, GLONASS, BDS, GALILEO', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP65', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '7.5 mm', 'Trọng lượng': '178g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa đơn', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Thấp (~30-45%) (Lý do: Thương hiệu OPPO/Xiaomi/Vivo)', 'Số năm OS update': '3-4 năm (Nguồn ước lượng: OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Lý do: Chip MediaTek Dimensity 7050 tầm trung)', 'Danh sách tính năng AI thực tế': 'Chụp chân dung, Thuật toán Chuyên gia chân dung, Lọc tiếng ồn', 'AI Score tổng hợp': '3'},
    {'name': 'OPPO A77s 8GB 128GB', 'sku': 'oppo-a77s', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 12', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'Ban đêm, Chuyên gia, Panorama, Chân dung, Time-lapse, Sticker, Quay chậm, Quét văn bản, ống kính Google, Siêu HD', 'Kích thước màn hình': '6.56 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '600 nits (typ)', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '720 x 1612', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 680 4G', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Adreno 610', 'Hệ điều hành': 'Android 12', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5,000mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct, hotspot', 'Bluetooth': '5.0', 'GPS': 'GPS, BDS, GLONASS, GALILEO và hệ thống định vị QZSS có hỗ trợ', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'Kim loại', 'Chất lượng khung viền': 'Kính', 'Độ mỏng': '8 mm', 'Trọng lượng': '187 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (OPPO/Xiaomi/Vivo)', 'Số năm OS update': '3-4 năm (Ước lượng từ OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Do sử dụng Snapdragon 680)', 'Danh sách tính năng AI thực tế': 'Ban đêm, Chuyên gia, Panorama, Chân dung, Time-lapse, Sticker, Quay chậm, Quét văn bản, ống kính Google, Siêu HD', 'AI Score tổng hợp': '3'},
    {'name': 'Điện thoại OPPO A55 (4GB - 64GB)', 'sku': 'oppo-a55', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 11, ColorOS 11.1', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'f/2.2', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16 MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'AI Camera, Chuyên nghiệp (Pro), Tự động lấy nét (AF), Chạm lấy nét, Nhận diện khuôn mặt, HDR, Toàn cảnh (Panorama), Ban đêm (Night Mode), Làm đẹp, Xóa phông, Zoom kỹ thuật số', 'Kích thước màn hình': '6.5 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '60Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Kính cường lực Dinorex™ Glass', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '720 x 1600 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G35', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '64 GB', 'GPU tier': 'IMG PowerVR GE8320', 'Hệ điều hành': 'Android 11, ColorOS 11.1', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '18W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 5 (802.11ac), 802.11a/b/g/n/Wi-Fi 2.4G/5.1G/5.8G', 'Bluetooth': 'v5.0', 'GPS': 'GPS, GLONASS, GALILEO, BDS, QZSS', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IPX4', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.4 mm', 'Trọng lượng': '193 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '2', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%) (Dựa trên thương hiệu OPPO/Xiaomi)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Chip tầm trung MediaTek Helio G35)', 'Danh sách tính năng AI thực tế': 'AI Camera, Chuyên nghiệp (Pro), Tự động lấy nét (AF), Chạm lấy nét, Nhận diện khuôn mặt, HDR, Toàn cảnh (Panorama), Ban đêm (Night Mode), Làm đẹp, Xóa phông, Zoom kỹ thuật số', 'AI Score tổng hợp': '3'},
    {'name': 'OPPO A57 4GB 128GB', 'sku': 'oppo-a57-128gb', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'ColorOS 12.1, nền tảng Android 12', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '13 MP', 'Aperture camera chính': 'f/2.2', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p @30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': '1080p @ 30fps', 'Tính năng AI camera': 'Night Mode, HDR, Toàn cảnh (Panorama), Ban đêm (Night Mode), Nhãn dán (AR Stickers), Làm đẹp, Google Lens, Hiệu ứng Bokeh Bộ lọc màu, Trôi nhanh thời gian (Time Lapse), Xóa phông', 'Kích thước màn hình': '6.56 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '60Hz', 'Độ sáng tối đa': '600 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Kính cường lực Panda', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '720 x 1612', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G35', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'IMG GE8320 @ 680 MHz', 'Hệ điều hành': 'ColorOS 12.1, nền tảng Android 12', 'Công nghệ tản nhiệt': 'LiquidCool', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '802.11 ac/a/b/g/n/', 'Bluetooth': 'v5.2, A2DP, LE, aptX HD', 'GPS': 'GPS, GLONASS, GALILEO, BDS, QZSS', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IPX4', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '7.99 mm', 'Trọng lượng': '187 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'Google Assistant', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (OPPO là thương hiệu tầm trung)', 'Số năm OS update': '3-4 năm (Ước lượng từ OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Chip MediaTek Helio G35 tầm trung)', 'Danh sách tính năng AI thực tế': ['Night Mode', 'HDR', 'Toàn cảnh (Panorama)', 'Ban đêm (Night Mode)', 'Nhãn dán (AR Stickers)', 'Làm đẹp', 'Google Lens', 'Hiệu ứng Bokeh Bộ lọc màu', 'Trôi nhanh thời gian (Time Lapse)', 'Xóa phông'], 'AI Score tổng hợp': '3'},
    {'name': 'Oppo A52', 'sku': 'oppo-a52', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Qualcomm', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': '0', 'Phiên bản OS ra mắt': 'Android 10, ColorOS 7.1', 'Số lượng camera sau (thật)': '4', 'Độ phân giải camera chính': '12 MP', 'Aperture camera chính': 'f/1.7', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16 MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.5 inches', 'Công nghệ màn hình': 'LTPS IPS LCD, 16 triệu màu', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '1176 x 2400 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm SM6125 Snapdragon 665 (11 nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Adreno 610', 'Hệ điều hành': 'Android 10, ColorOS 7.1', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '18W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct, hotspot', 'Bluetooth': '5.0, A2DP, LE', 'GPS': 'A-GPS, GLONASS, GALILEO, BDS', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.9 mm', 'Trọng lượng': '192 g', 'Số màu sắc': '0', 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay, cạnh viền', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu OPPO/Xiaomi/OPPO)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Chip Snapdragon tầm trung)', 'Danh sách tính năng AI thực tế': ['AI giúp hiệu chỉnh ánh sáng, màu da'], 'AI Score tổng hợp': '3'},
    {'name': 'Oppo A92', 'sku': 'oppo-a92', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Qualcomm', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': '0', 'Phiên bản OS ra mắt': 'Android 10, ColorOS 7.1', 'Số lượng camera sau (thật)': '3', 'Độ phân giải camera chính': '48 MP', 'Aperture camera chính': 'f/1.7', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '2160p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16 MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.5 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2400 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 665 (11 nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Adreno 610', 'Hệ điều hành': 'Android 10, ColorOS 7.1', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '18W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct, hotspot', 'Bluetooth': '5.0', 'GPS': 'A-GPS, GLONASS, GALILEO, BDS', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.9 mm', 'Trọng lượng': '192 g', 'Số màu sắc': '0', 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '2', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Lý do: Thương hiệu OPPO/Xiaomi/OPPO, phân khúc Mid-range)', 'Số năm OS update': '3-4 năm (Nguồn ước lượng: OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Do sử dụng Snapdragon 665 - Chip tầm trung)', 'Danh sách tính năng AI thực tế': ['Night Mode', 'Portrait', 'Clean Up'], 'AI Score tổng hợp': '2'},
    {'name': 'OPPO Reno14 F 5G 8GB 256GB', 'sku': 'dien-thoai-oppo-reno14-f', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'F/1.8', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@2160p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'F/2.0', 'Quay video camera trước': 'Có', 'Tính năng AI camera': ['Xóa phông', 'làm đẹp AI', 'HDR', 'bộ lọc màu', 'chụp đêm', 'siêu độ phân giải'], 'Kích thước màn hình': '6.57 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1400 nits', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '1080 x 2372', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm Snapdragon 6 Gen 1 5G', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno 710', 'Hệ điều hành': 'ColorOS 15, Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6000mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 2.4G/5G', 'Bluetooth': '5.1 BLE', 'GPS': ['GPS', 'GLONASS', 'BDS', 'Galileo', 'QZSS'], 'NFC': 'có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP66, IP68, IP69', 'Chất lượng mặt lưng': 'Thuỷ tinh hữu cơ', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '7.78 mm', 'Trọng lượng': '180g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': ['Trợ lý ảo Google Gemini', 'Phiên dịch AI', 'Mở mắt AI'], 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Lý do: Thương hiệu OPPO/Xiaomi/Vivo)', 'Số năm OS update': '3-4 năm (Nguồn ước lượng: OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Lý do: Chip tầm trung Qualcomm Snapdragon 6 Gen 1 5G)', 'Danh sách tính năng AI thực tế': ['Xóa phông', 'làm đẹp AI', 'HDR', 'bộ lọc màu', 'chụp đêm', 'siêu độ phân giải', 'Trợ lý ảo Google Gemini', 'Phiên dịch AI', 'Mở mắt AI'], 'AI Score tổng hợp': '3'},
    {'name': 'OPPO A6t 6GB 256GB', 'sku': 'dien-thoai-oppo-a6t-6gb-256gb', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '13MP', 'Aperture camera chính': 'f/2.2 + f/3.0', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '5MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.75 inches', 'Công nghệ màn hình': 'LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1125 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Kính cường lực Panda', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm Snapdragon 685', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno 610', 'Hệ điều hành': 'ColorOS 15, nền tảng Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6100mAh', 'Sạc có dây': '15W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 2.4G/5G, 802.11 a/b/g/n/ac', 'Bluetooth': 'v5.0', 'GPS': 'GPS, GLONASS, BDS, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP64', 'Chất lượng mặt lưng': 'Thuỷ tinh hữu cơ', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.61mm', 'Trọng lượng': '205g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu OPPO/Xiaomi)', 'Số năm OS update': '3-4 năm (Ước lượng từ OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Qualcomm Snapdragon 685)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'OPPO A79 5G 8GB 256GB', 'sku': 'oppo-a79', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'Xóa phông, Tự động lấy nét (AF), Trôi nhanh thời gian (Time Lapse), Toàn cảnh (Panorama), Siêu độ phân giải, Quét tài liệu, Quét mã QR', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'N/A', 'Tần số quét': '90Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2400', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Dimensity 6020 5G 8 nhân', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Mali-G57 MC2', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Dual-band (2.4 GHz/5 GHz)', 'Bluetooth': 'v5.3', 'GPS': ['GPS', 'GLONASS', 'GALILEO', 'BEIDOU'], 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IPX4', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.99 mm', 'Trọng lượng': '193', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa âm thanh nổi kép', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu OPPO)', 'Số năm OS update': '3-4 năm (Ước lượng từ OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip MediaTek Dimensity 6020 5G)', 'Danh sách tính năng AI thực tế': 'Xóa phông, Tự động lấy nét (AF), Trôi nhanh thời gian (Time Lapse), Toàn cảnh (Panorama), Siêu độ phân giải, Quét tài liệu, Quét mã QR, Night Mode, Portrait, Clean Up', 'AI Score tổng hợp': '3'},
    {'name': 'OPPO A58 4G 6GB 128GB', 'sku': 'oppo-a58', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'ColorOS 13.1, nền tảng Android 13', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'F/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'F/2.0', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '60Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Kính cường lực Panda', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2400 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Helio G85, tối đa 2.0GHz', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali G52 MP2', 'Hệ điều hành': 'ColorOS 13.1, nền tảng Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G', 'Wi-Fi': '2.4G/5G, 802.11 a/b/g/n/ac', 'Bluetooth': '5.3', 'GPS': 'GPS', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.99 mm', 'Trọng lượng': '192g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu OPPO)', 'Số năm OS update': '3-4 năm (Ước lượng dựa trên OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Do sử dụng chip Helio G85/Mali G52 MP2)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'OPPO A3 6GB 128GB', 'sku': 'dien-thoai-oppo-a3', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'OPPO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'ColorOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'F/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '5 MP', 'Aperture camera trước': 'F/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '1000 nit', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Kính cường lực Panda', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '720 x 1604', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 6s 4G Gen1', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Adreno 610', 'Hệ điều hành': 'ColorOS 14, nền tảng Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5100mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '2.4G/5G', 'Bluetooth': '5.0', 'GPS': 'Beidou, GPS, GLONASS, Galileo, QZSS', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.68 mm', 'Trọng lượng': '186 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Chế độ siêu âm lượng 300%', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu OPPO/mid-range)', 'Số năm OS update': '3-4 năm (Ước lượng từ OPPO/Vivo)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Chip tầm trung Snapdragon)', 'Danh sách tính năng AI thực tế': ['2D nhận diện khuôn mặt'], 'AI Score tổng hợp': '2'},
]

realme_data = [
    {'name': 'realme Note 60 4GB 64GB', 'sku': 'dien-thoai-realme-note-60', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Realme', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '32MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '5MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.74 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '560nit', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '1600 x 720 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'UNISOC T612', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '64 GB', 'GPU tier': 'Mali-G57', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '10W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '2.4GHz, 5GHz', 'Bluetooth': 'v5.0', 'GPS': 'AGPS/GPS, GLONASS, BDS, Galileo', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'không có', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP64', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '7.84 mm', 'Trọng lượng': '188g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu Realme/Phân khúc Mid-range)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip UNISOC T612)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'realme 11 8GB 128GB', 'sku': 'realme-11', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Realme', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'realme UI 4.0', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '108MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'Chế độ 108MP, Chụp đêm, Toàn cảnh, Chuyên gia, HDR, Nhận dạng cảnh AI, Làm đẹp AI, Bộ lọc màu, Tùy chỉnh hiệu ứng Bokeh, Chụp đường phố, Quét lấy dữ liệu, Mô hình, Chế độ ảnh', 'Kích thước màn hình': '6.4 inches', 'Công nghệ màn hình': 'Super AMOLED', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '1000nit', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning Gorilla Glass 5', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2400', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Helio G99', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'ARM G57 MC2', 'Hệ điều hành': 'realme UI 4.0 Trên nền tảng Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5.000 mAh', 'Sạc có dây': '67W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 5', 'Bluetooth': '5.3', 'GPS': 'GPS, GALILEO, GLONASS, BDS, QZSS', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '7.95 mm', 'Trọng lượng': '178g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Nhận dạng cảnh AI, Làm đẹp AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Lý do: Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Nguồn ước lượng: Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Lý do: Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Chế độ 108MP, Chụp đêm, Toàn cảnh, Chuyên gia, HDR, Nhận dạng cảnh AI, Làm đẹp AI, Bộ lọc màu, Tùy chỉnh hiệu ứng Bokeh, Chụp đường phố, Quét lấy dữ liệu, Mô hình, Chế độ ảnh, Nhận dạng cảnh AI, Làm đẹp AI', 'AI Score tổng hợp': '4'},
    {'name': 'realme C51 4GB 128GB', 'sku': 'realme-c51', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'realme', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'realme UI T Edition - Android 13', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080P/30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '5M', 'Aperture camera trước': 'f/2.22', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Night Mode, Quay chậm (Slow Motion), Xóa phông, Toàn cảnh (Panorama), Ban đêm (Night Mode), Trôi nhanh thời gian (Time Lapse), Chuyên nghiệp (Pro), HDR, Siêu độ phân giải Bộ lọc màu', 'Kích thước màn hình': '6.74 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '560nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '720 x 1600 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc UNISOC T612', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G57', 'Hệ điều hành': 'realme UI T Edition - Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '2.4/5GHz Wi-Fi', 'Bluetooth': '5.0', 'GPS': 'GPS, GLONASS, Galileo', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'không có', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '7.99mm', 'Trọng lượng': '186g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': ['Night Mode', 'Quay chậm (Slow Motion)', 'Xóa phông', 'Toàn cảnh (Panorama)', 'Ban đêm (Night Mode)', 'Trôi nhanh thời gian (Time Lapse)', 'Chuyên nghiệp (Pro)', 'HDR', 'Siêu độ phân giải Bộ lọc màu'], 'AI Score tổng hợp': '2'},
    {'name': 'realme 11 Pro (8GB - 256GB)', 'sku': 'realme-11-pro', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Realme', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '100 MP', 'Aperture camera chính': 'f/1.75', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16 MP', 'Aperture camera trước': 'f/2.45', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': '100% DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2412 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Mediatek Dimensity 7050 5G', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Mali-G68', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5.000 mAh', 'Sạc có dây': '67W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': 'v5.2', 'GPS': 'GPS, GALILEO, GLONASS, BDS, QZSS', 'NFC': 'có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.7 mm', 'Trọng lượng': '191g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu Realme)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Chống rung quang học, Chụp đêm, Chụp trôi nhanh thời gian', 'AI Score tổng hợp': '3'},
]

sony_data = [
    {'name': 'Sony Xperia 1 VII 12GB 256GB', 'sku': 'dien-thoai-sony-xperia-1-vii', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Sony', 'Xuất xứ': 'Nhật Bản', 'Giao diện OS': 'Stock Android', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '52MP', 'Aperture camera chính': 'f/1.9', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@120fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': '4K@60fps', 'Tính năng AI camera': 'Night Mode, Alpha™', 'Kích thước màn hình': '6.5 inches', 'Công nghệ màn hình': 'OLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Tràn viền (Không khiếm khuyết)', 'Độ phân giải màn hình': '1080 x 2340 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon® 8 Elite', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'Có', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6/6E/7', 'Bluetooth': '6.0', 'GPS': 'A-GPS, A-GLONASS, BeiDou, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IPX5/IPX8, IP6X', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.2 mm', 'Trọng lượng': '197g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Hi-Res Audio (có dây & không dây LDAC), Dolby Atmos, 360 Reality Audio, DSEE Ultimate, loa stereo, Walkman®', 'Hỗ trợ AI': 'Điện thoại AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '4', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) Lý do: Thương hiệu Sony trong phân khúc Cao cấp (Specification) nhưng description đặt trong Mid-range 10-15tr.', 'Số năm OS update': 'Không đề cập', 'Chất lượng phần mềm / ít bloatware': 'Rất tốt - không bloatware (Stock Android)', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud Lý do: Chip Snapdragon® 8 Elite (thường là Hybrid/Cloud đối với các dòng flagship không phải Google Pixel)', 'Danh sách tính năng AI thực tế': 'Night Mode, Alpha™', 'AI Score tổng hợp': '2'},
    {'name': 'Sony Xperia 10 VII 8GB 128GB', 'sku': 'dien-thoai-sony-xperia-10-vii', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Sony', 'Xuất xứ': 'Nhật Bản', 'Giao diện OS': 'N/A', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'F1.9', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '6x', 'Quay video camera sau': 'Chống rung quang học (OIS/EIS), SteadyShot, quay chậm', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8MP', 'Aperture camera trước': 'F2.0', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Chụp đêm, toàn cảnh, chụp tay, hiệu ứng bokeh, đèn LED và flash trợ sáng.', 'Kích thước màn hình': '6.1 inches', 'Công nghệ màn hình': 'FHD+ OLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '1080 x 2340 pixels (FullHD+)', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon® 6 Thế hệ 3', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Snapdragon® 6 Thế hệ 3', 'Hệ điều hành': 'Android™ 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5.000 mAh', 'Sạc có dây': 'USB Power Delivery', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6E', 'Bluetooth': 'v.5.', 'GPS': ['A-GPS', 'A-GLONASS', 'BeiDou', 'Galileo', 'QZSS'], 'NFC': 'có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP65/IP68', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.3 mm', 'Trọng lượng': '168 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Dựa trên phân khúc giá Trung bình và thương hiệu Sony)', 'Số năm OS update': '3 năm (Ước lượng dựa trên dòng sản phẩm Sony/Android)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (Hệ điều hành Android 15)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Chipset Snapdragon® 6 Thế hệ 3 không thuộc nhóm Apple A-series hoặc Pixel Tensor G4 trở lên)', 'Danh sách tính năng AI thực tế': 'Chụp đêm, toàn cảnh, chụp tay, hiệu ứng bokeh, đèn LED và flash trợ sáng., Night Mode, Zoom bằng AI, Gemini Live, Tính năng nhận dạng cảnh, Tính năng Magic Editor, AI tự động nhận diện cảnh', 'AI Score tổng hợp': '4'},
    {'name': 'Sony Xperia 1V 12GB 256GB', 'sku': 'sony-xperia-1-v', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Sony', 'Xuất xứ': 'Nhật Bản', 'Giao diện OS': 'Stock Android', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '52 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.5 inches', 'Công nghệ màn hình': 'OLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Gor Corning® Gorilla® Glass Victus', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '3840 x 1644 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 Gen 2', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Snapdragon 8 Gen 2', 'Hệ điều hành': 'Android™ 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'IEEE802.11a/b/g/n/ac/ax, 2,4/5/6 GHz', 'Bluetooth': 'A-GPS, A-GLONASS, Beidou, Galileo, QZSS', 'GPS': 'GPS, GLONASS, Galileo, BeiDou, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IPX5/IPX8/IP6X', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8,3 mm', 'Trọng lượng': '187g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Bảo mật vân tay', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Hi-Resolution Audio, High-Resolution Audio Wireless, Dolby Atmos', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '4', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) Lý do: Thương hiệu Sony (Flagship/Cao cấp)', 'Số năm OS update': 'N/A', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (Stock Android)', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud Lý do: Thương hiệu Sony/Snapdragon (Không phải Apple A-series hoặc Pixel Tensor)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Điện thoại Sony Xperia 10 V', 'sku': 'sony-xperia-10-v', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Sony', 'Xuất xứ': 'Nhật Bản', 'Giao diện OS': 'Stock Android', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '12MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.1 inches', 'Công nghệ màn hình': 'OLED', 'Tần số quét': '60 Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'Corning® Gorilla® Glass Victus®', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '1080 x 2520 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 695 5G', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'B', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Snapdragon 695', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'IEEE802.11a/b/g/n/ac, 2,4/5 GHz', 'Bluetooth': 'v5.1', 'GPS': 'A-GPS, A-Glonass, Beidou, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IPX5/IPX8/IP6X', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.3 mm', 'Trọng lượng': '159g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Hi-Resolution Audio, High-Resolution Audio Wireless (LDAC), Loa âm thanh nổi', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': "Trung bình (~40-55%) (Lý do: Thương hiệu Sony, phân khúc giá 'Trung bình' trong spec và 'Cận cao cấp' trong desc, chip Snapdragon 695)", 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid-range)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (Stock Android)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Bắt nét, Night Mode, Clean Up', 'AI Score tổng hợp': '4'},
]

tecno_data = [
    {'name': 'Tecno Pova 7 8GB 128GB', 'sku': 'dien-thoai-tecno-pova-7', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Tecno', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '108M', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.78 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '900nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080x2460 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G100 Utimate', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G57@950Mhz', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '7000mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G', 'Wi-Fi': 'WiFi 2.4G\nWiFi 5G', 'Bluetooth': 'v5.4', 'GPS': 'N/A', 'NFC': 'có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP64', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '9.31mm', 'Trọng lượng': '226g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép Stereo, Dolby Audio', 'Hỗ trợ AI': 'Tecno AI', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '2', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Night Mode, Portrait, Clean Up, Viết AI, Studio AI', 'AI Score tổng hợp': '3'},
    {'name': 'TECNO Spark 40 Pro+ 8GB 256GB', 'sku': 'dien-thoai-tecno-spark-40-pro-plus', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Tecno', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'EIS điện tử', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'Full HD 1080p - 30 fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '13 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Super Night Mode', 'Kích thước màn hình': '6.78 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': 'Từ 144Hz trở lên', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '1224 x 2720', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G200', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'MediaTek Helio G200', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5200mAh', 'Sạc có dây': '45W', 'Sạc không dây': '30W', 'Sạc ngược': '5W', 'Mạng di động': '4G', 'Wi-Fi': 'ac (2.4GHz & 5GHz)', 'Bluetooth': 'Có', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP64', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '6.49 mm', 'Trọng lượng': '160g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Dolby Atmos, Dual Speakers', 'Hỗ trợ AI': 'AI Eraser 2.0, Ask Ella, AI Writing, khử ồn AI', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%) (Lý do: Thương hiệu Tecno/Phân khúc Under 5tr)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Lý do: Chip MediaTek Helio G200, các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': ['Super Night Mode', 'AI Eraser 2.0', 'Ask Ella', 'AI Writing', 'khử ồn AI'], 'AI Score tổng hợp': '3'},
    {'name': 'TECNO CAMON 40 8GB 128GB', 'sku': 'dien-thoai-tecno-camon-40', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Tecno', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'ƒ/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Chụp góc rộng, Chế độ chụp FlashSnap, Chụp tự động, Chụp toàn cảnh, Chụp đêm, Chụp cận, Thu Phóng 2X, Lấy nét theo mắt AF, OIS, Cảm biến AI Snapshot', 'Kích thước màn hình': '6.78 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1300 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Mediatek Helio G100 Ultimate', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'Tản nhiệt thông minh E-Sports Pro', 'Bypass charging': 'N/A', 'Dung lượng pin': '5200 mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': 'N/A', 'Wi-Fi': 'Wifi 2.4', 'Bluetooth': 'BT 5.2', 'GPS': 'N/A', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP66', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.34mm', 'Trọng lượng': '177g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Studio AI, Sáng tạo hình nền AI, Khoanh vùng tìm kiếm AI, Trợ lý viết AI, Ghi chú AI, Dịch thuật, Cảm ứng thông minh Ella', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Do là Tecno, phân khúc Tầm trung)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Mediatek Helio G100 Ultimate và thương hiệu Tecno)', 'Danh sách tính năng AI thực tế': ['Chụp góc rộng', 'Chế độ chụp FlashSnap', 'Chụp tự động', 'Chụp toàn cảnh', 'Chụp đêm', 'Chụp cận', 'Thu Phóng 2X', 'Lấy nét theo mắt AF', 'OIS', 'Cảm biến AI Snapshot', 'Studio AI', 'Sáng tạo hình nền AI', 'Khoanh vùng tìm kiếm AI', 'Trợ lý viết AI', 'Ghi chú AI', 'Dịch thuật', 'Cảm ứng thông minh Ella'], 'AI Score tổng hợp': '3'},
    {'name': 'TECNO CAMON 40 Pro 8GB 256GB', 'sku': 'dien-thoai-tecno-camon-40-pro', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Tecno', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'ƒ/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '50MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Chụp đêm, Chụp cận, Thu Phóng 2X, Lấy nét theo mắt AF, OIS, Cảm biến AI Snapshot', 'Kích thước màn hình': '6.78 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1300 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Màn hình cong đôi', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Mediatek Helio G100 Ultimate', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'Tản nhiệt thông minh E-Sports Pro', 'Bypass charging': 'N/A', 'Dung lượng pin': '5200mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wifi 2.4', 'Bluetooth': 'BT 5.4', 'GPS': ['GPS', 'GLONASS', 'Galileo', 'BeiDou', 'QZSS', 'NavIC'], 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68/IP69', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.31mm', 'Trọng lượng': '178g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Studio AI, Sáng tạo hình nền AI, Khoanh vùng tìm kiếm AI, Trợ lý viết AI, Ghi chú AI, Dịch thuật, Cảm ứng thông minh Ella', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Dựa trên thương hiệu Tecno và phân khúc giá Trung bình)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Chụp đêm, Chụp cận, Thu Phóng 2X, Lấy nét theo mắt AF, OIS, Cảm biến AI Snapshot, Studio AI, Sáng tạo hình nền AI, Khoanh vùng tìm kiếm AI, Trợ lý viết AI, Ghi chú AI, Dịch thuật, Cảm ứng thông minh Ella', 'AI Score tổng hợp': '3'},
    {'name': 'TECNO Spark Go 2 4GB 64GB', 'sku': 'dien-thoai-tecno-spark-go-2', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Tecno', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 15 Go edition', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '13 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'FullHD 1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'FullHD', 'Tính năng AI camera': 'Làm đẹp, xóa phông, quay video kép', 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '720 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '720 x 1600 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc T7250', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '64 GB', 'GPU tier': 'Mali-G57 MP1 @ 850MHz', 'Hệ điều hành': 'Android 15 Go edition', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '15W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '802.11 a/b/g/n/ac, Dual-band (2.4GHz/5GHz)', 'Bluetooth': 'v5.2', 'GPS': ['GPS'], 'NFC': 'Không', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP64', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.25 mm', 'Trọng lượng': '188g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay cạnh bên', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép DTS Studio Sound', 'Hỗ trợ AI': ['AI Writing', 'AI dịch thuật'], 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) Lý do: Thương hiệu Tecno (thường nằm ở phân khúc tầm trung)', 'Số năm OS update': '3 năm Lý do: Xiaomi mid (Ước lượng từ thương hiệu Tecno/chip Unisoc)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '3 Tốt ban ngày, tối chấp nhận', 'AI on-device vs Cloud': 'Cloud Lý do: Sử dụng chip Unisoc T7250 (chip tầm trung)', 'Danh sách tính năng AI thực tế': ['Làm đẹp', 'xóa phông', 'quay video kép', 'Night Mode', 'Portrait', 'Clean Up', 'AI Writing', 'AI dịch thuật'], 'AI Score tổng hợp': '3'},
    {'name': 'TECNO CAMON 30S 8GB 256GB', 'sku': 'dien-thoai-tecno-camon-30s', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Tecno', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '100MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'Gorilla Glass 5', 'Độ phân giải camera trước': '13MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.78 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Gorilla Glass 5', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2436 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Mediatek G100', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '802.11ac', 'Bluetooth': 'v5.3', 'GPS': 'N/A', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP53', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.62 mm', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Do thương hiệu Tecno và phân khúc giá Trung bình)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Cloud (Do sử dụng chip tầm trung Mediatek G100)', 'Danh sách tính năng AI thực tế': 'Chân dung, Bokeh tự nhiên, AI Portrait', 'AI Score tổng hợp': '3'},
    {'name': 'TECNO CAMON 30 8GB 256GB', 'sku': 'tecno-camon-30', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Tecno', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 14 (Upside Down Cake)', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'ƒ/1.9', 'OIS / Chống rung': 'OIS quang học + chống rung điện tử (EIS)', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1440p @ 30 fps, 1080p @ 30/60 fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '50 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': '1440p @ 30 fps, 1080p @ 30/60 fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.78 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2436', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Helio G99 Ultimate(6nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'ARM Mali-G57 MC2', 'Hệ điều hành': 'Android 14 (Upside Down Cake)', 'Công nghệ tản nhiệt': '20 lớp', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '70 W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '802.11/b/a/g/n/ac', 'Bluetooth': 'v5.3', 'GPS': 'GPS', 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Kính + da cà phê', 'Chất lượng khung viền': 'Mạ kim loại', 'Độ mỏng': '7.7 mm', 'Trọng lượng': 'N/A', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trên màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép Dolby Atmos', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu Tecno và phân khúc Mid-range)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid-range)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Helio G99 Ultimate)', 'Danh sách tính năng AI thực tế': 'Night Mode, Portrait, Clean Up', 'AI Score tổng hợp': '4'},
    {'name': 'TECNO POVA 6 8GB 256GB', 'sku': 'tecno-pova-6', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Tecno', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '108M', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '2k@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': '2k@30fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.78 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2436 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek G99 Ultimate', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Mali-G57 3D Graphics', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6.000 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '802.11ac', 'Bluetooth': 'v5.3', 'GPS': 'GPS', 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.88 mm', 'Trọng lượng': '192.5 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Bảo mật vân tay', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Dựa trên thương hiệu Tecno và phân khúc Mid-range 10-15tr)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid-range)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip MediaTek G99 Ultimate và thương hiệu Tecno)', 'Danh sách tính năng AI thực tế': 'Nhận diện khuôn mặt', 'AI Score tổng hợp': '2'},
    {'name': 'TECNO Spark 40 6GB 128GB', 'sku': 'dien-thoai-tecno-spark-40', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'TECNO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': ['AI Camera', 'TECNO AI'], 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '700 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '720 x 1600 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G91', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G52', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5200mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'Có', 'Mạng di động': '4G LTE', 'Wi-Fi': '2.4GHz + 5GHz, 802.11 b/g/n/ac', 'Bluetooth': 'v5.4', 'GPS': ['GPS'], 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP64', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.67 mm', 'Trọng lượng': '188g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép DTS', 'Hỗ trợ AI': ['Ask Ella'], 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': ['AI Camera', 'TECNO AI', 'Ask Ella'], 'AI Score tổng hợp': '3'},
    {'name': 'TECNO SPARK 30 5G 6GB 128GB', 'sku': 'dien-thoai-tecno-spark-30-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Tecno', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '108MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': 'N/A', 'Công nghệ màn hình': 'N/A', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek D6300', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'HyperOS', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '18W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'N/A', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Lý do: Thương hiệu Tecno, phân khúc Mid-range 10-15tr)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (ColorOS / HyperOS -> Trung bình)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Lý do: Chip MediaTek D6300, các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': ['N/A'], 'AI Score tổng hợp': '1'},
    {'name': 'TECNO SPARK 30 Pro 8GB 256GB Transformer', 'sku': 'dien-thoai-tecno-spark-30-pro-8gb-256gb', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Tecno', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '108MP', 'Aperture camera chính': 'f/1.75', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '13MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Làm đẹp chi tiết khuôn mặt (chế độ chân dung), Bộ lọc màu', 'Kích thước màn hình': '6.78 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1700 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G100', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G', 'Wi-Fi': 'WiFi 2.4+5G', 'Bluetooth': 'BT5.4', 'GPS': 'GPS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.4 mm', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép Dolby Atmos', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Dựa trên thương hiệu Tecno/Phân khúc Tầm trung)', 'Số năm OS update': '3 năm (Ước lượng: Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Do sử dụng chip MediaTek Helio G100)', 'Danh sách tính năng AI thực tế': 'Làm đẹp chi tiết khuôn mặt (chế độ chân dung), Bộ lọc màu', 'AI Score tổng hợp': '2'},
    {'name': 'TECNO Spark Go 3 4GB 64GB', 'sku': 'dien-thoai-tecno-spark-go-3', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Tecno', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '13 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.75 inches', 'Công nghệ màn hình': 'N/A', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '720 x 1600 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc T7250', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '64 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '15 W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': 'N/A', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'N/A', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.1 mm', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A'},
    {'name': 'TECNO SPARK 20 8GB 128GB', 'sku': 'tecno-spark-20', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '14 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Tecno', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android 13', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.6', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '2K', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.5 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '720 x 1612', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G85', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G52 MC2', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '18W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 2.4+5GHz', 'Bluetooth': 'v5.2', 'GPS': ['GPS'], 'NFC': 'Không', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP53', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.45 mm', 'Trọng lượng': 'N/A', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': '2 loa', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Lý do: Thương hiệu Tecno, phân khúc giá Rẻ)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (MIUI/ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Lý do: Chip tầm trung MediaTek Helio G85)', 'Danh sách tính năng AI thực tế': 'HDR, Face Recognition, Visual Intelligence, HDR, Face Recognition', 'AI Score tổng hợp': '2'},
    {'name': 'TECNO SPARK 20C 4GB 128GB', 'sku': 'tecno-spark-20c', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Tecno', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'Android T', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android T', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.6 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '720 x 1612', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MTK G36', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android T', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '18W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'Không', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'không', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.55 mm', 'Trọng lượng': 'N/A', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép dts 400% âm lượng', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu Tecno)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip MTK G36 và thương hiệu)', 'Danh sách tính năng AI thực tế': ['Night Mode', 'Portrait', 'Clean Up', 'cảm biến chính 50MP với ống kính AI'], 'AI Score tổng hợp': '3'},
    ]

samsung_data = [
    {'name': 'Samsung Galaxy S26 Ultra 12GB 256GB', 'sku': 'dien-thoai-samsung-galaxy-s26-ultra', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '200MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '5x', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Chỉnh sửa ảnh thế hệ mới, Không gian sáng tạo, Gợi ý thông minh, Khoanh tròn để tìm kiếm, Lọc cuộc gọi tự động, Proscaler & 10-bit mDNIe', 'Kích thước màn hình': '6.9 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2600 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '3120 x 1440', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 Elite Gen 5 dành cho Galaxy (3nm)', 'AnTuTu score': 3932243, 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '60W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'GPS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM + eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.9 mm', 'Trọng lượng': '214g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Privacy Display (Chống nhìn trộm chủ động), Chỉnh sửa ảnh thế hệ mới, Không gian sáng tạo, Gợi ý thông minh, Khoanh tròn để tìm kiếm, Lọc cuộc gọi tự động, Proscaler & 10-bit mDNIe', 'Gaming (Use Case)': '4', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '4', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) Lý do: Samsung flagship', 'Số năm OS update': '7 năm Lý do: Samsung Galaxy S series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['Chỉnh sửa ảnh thế hệ mới', 'Không gian sáng tạo', 'Gợi ý thông minh', 'Khoanh tròn để tìm kiếm', 'Lọc cuộc gọi tự động', 'Proscaler & 10-bit mDNIe'], 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy S26 12GB 256GB', 'sku': 'dien-thoai-samsung-galaxy-s26', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Không có', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'Không có', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Chỉnh sửa ảnh thế hệ mới (Photo Assist)', 'Kích thước màn hình': '6.3 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2600 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2340 x 1080', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Exynos 2600 (2nm)', 'AnTuTu score': 3145925, 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'Không có', 'Dung lượng pin': '4300 mAh', 'Sạc có dây': '25W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'Không có', 'Mạng di động': '5G', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'GPS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM + eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.2 mm', 'Trọng lượng': '167g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Circle to Search', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Samsung mid)', 'Số năm OS update': '4 năm (Ước lượng dựa trên Samsung A series)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid (Dựa trên chip Exynos 2600)', 'Danh sách tính năng AI thực tế': 'Chỉnh sửa ảnh thế hệ mới (Photo Assist), Circle to Search', 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy Z Flip7 12GB 256GB', 'sku': 'dien-thoai-samsung-galaxy-z-flip-7', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'F1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '2x', 'Quay video camera sau': 'UHD 4K@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '10MP', 'Aperture camera trước': 'F2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Auto Zoom, Chân dung tự nhiên (Natural Portrait), Tạo bộ lọc cá nhân từ ảnh, FlexCam quay/chụp không cần tay, Thu phóng quang học 2x, Tự động lấy nét', 'Kích thước màn hình': '6.9 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Màn hình gập', 'Độ phân giải màn hình': '2520 x 1080', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'N/A', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4300mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6E', 'Bluetooth': 'v5.4', 'GPS': 'GPS, Glonass, Beidou, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '6.5 mm', 'Trọng lượng': '188g', 'Số màu sắc': 3, 'Điện thoại gập': 'Flip', 'Cảm biến vân tay': 'Cảm biến vân tay', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Gemini Live, Phiên dịch viên 2 màn hình, FlexCam - Zoom Rocker', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) Lý do: Samsung (cao cấp/flagship dòng Flip)', 'Số năm OS update': '7 năm Lý do: Samsung Galaxy S series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '5 Sắc nét tuyệt vời, màu chuẩn, dynamic range rộng', 'Chất lượng ảnh ban đêm': '4 Rất tốt, ít noise', 'Chất lượng video thực tế': '4 4K@60fps ổn định tốt', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': 'Auto Zoom, Chân dung tự nhiên (Natural Portrait), Tạo bộ lọc cá nhân từ ảnh, FlexCam quay/chụp không cần tay, Thu phóng quang học 2x, Tự động lấy nét, Natural Portraits, Filters, Google Gemini AI, Live Translation, FlexCam - Zoom Rocker', 'AI Score tổng hợp': '5'},
    {'name': 'Samsung Galaxy S25 Ultra 12GB 256GB', 'sku': 'dien-thoai-samsung-galaxy-s25-ultra', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '200 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '5x', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Chụp hình Super HDR, Chân dung, Tự động lấy nét, Quay Video đêm', 'Kích thước màn hình': '6.9 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2600 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning® Gorilla® Armor 2', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '3120 x 1440', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 Elite dành cho Galaxy (3nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '45W', 'Sạc không dây': '2.0', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'GPS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM + eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Titanium', 'Chất lượng khung viền': 'Titanium', 'Độ mỏng': '8.2 mm', 'Trọng lượng': '218g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Lọc âm thanh (Audio Eraser)', 'Hỗ trợ AI': 'Thực hiện tác vụ liên ứng dụng bằng lời nói (Seamless Actions across Apps), Biên tập Video thông minh (Auto trim), Khoanh tròn để tìm kiếm (Circle to Search), Trợ lý cuộc gọi (Call Assist), Trợ lý chỉnh ảnh (Photo Assist)', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '5', 'Thể thao / Outdoor (Use Case)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) Lý do: Samsung flagship', 'Số năm OS update': '7 năm Lý do: Samsung Galaxy S series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['Chụp hình Super HDR', 'Chân dung', 'Tự động lấy nét', 'Quay Video đêm', 'Thực hiện tác vụ liên ứng dụng bằng lời nói (Seamless Actions across Apps)', 'Biên tập Video thông minh (Auto trim)', 'Khoanh tròn để tìm kiếm (Circle to Search)', 'Trợ lý cuộc gọi (Call Assist)', 'Trợ lý chỉnh ảnh (Photo Assist)'], 'AI Score tổng hợp': '4'},
    {'name': 'Samsung Galaxy A57 5G 8GB 128GB', 'sku': 'dien-thoai-samsung-galaxy-a57', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 16', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Zoom kỹ thuật số, Xóa phông, Tự động lấy nét, Trôi nhanh thời gian, Toàn cảnh, Quay siêu chậm, HDR, Chống rung quang học, Chân dung AI, Chuyên nghiệp, Ban đêm, AI Camera, Chụp ảnh khử nhiễu', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super AMOLED Plus', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1900 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2340 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Exynos 1680', 'AnTuTu score': 1390055, 'Xếp loại chip': 'B', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Xclipse 550', 'Hệ điều hành': 'Android 16', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6E', 'Bluetooth': 'v6.0', 'GPS': 'GPS, GLONASS, GALILEO, BEIDOU', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '1 SIM + eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': '76.8 mm', 'Trọng lượng': '182 g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) Lý do: Samsung mid', 'Số năm OS update': '4 năm Lý do: Samsung A series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['Zoom kỹ thuật số', 'Xóa phông', 'Tự động lấy nét', 'Trôi nhanh thời gian', 'Toàn cảnh', 'Quay siêu chậm', 'HDR', 'Chống rung quang học', 'Chân dung AI', 'Chuyên nghiệp', 'Ban đêm', 'AI Camera', 'Chụp ảnh khử nhiễu', 'Chế độ chụp đêm', 'giảm nhiễu Low Noise', 'Super HDR', 'chân dung AI', 'AR sticker', 'Làm đẹp', 'Hệ thống còn nhận diện và xóa các chi tiết không cần thiết trong ảnh', 'AI tích hợp nâng cao trải nghiệm', 'Hỗ trợ tạo và tùy chỉnh bộ lọc màu theo phong cách riêng'], 'AI Score tổng hợp': '4'},
    {'name': 'Samsung Galaxy A17 5G 8GB 128GB', 'sku': 'dien-thoai-samsung-galaxy-a17-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '10x', 'Quay video camera sau': 'FullHD 1080p@30fps', 'Chất lượng kính lens camera': 'Gorilla Glass 7', 'Độ phân giải camera trước': '13 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Làm đẹp, Night Mode', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super AMOLED', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '800 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning Gorilla Glass 7', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '1080 x 2340 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Exynos 1330', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G68', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '25W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': '802.11 a/b/g/n/ac 2.4GHz+5GHz', 'Bluetooth': 'v5.3', 'GPS': 'QZSS, GPS, GLONASS, GALILEO, BEIDOU', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 Nano SIM (Sim 2 chung khe với thẻ nhớ)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '7.5 mm', 'Trọng lượng': '192g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Mở khóa khuôn mặt, Smart Switch', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) Lý do: Samsung flagship', 'Số năm OS update': '7 năm Lý do: Samsung Galaxy S series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['Làm đẹp', 'Night Mode', 'Portrait', 'Clean Up'], 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy Z Fold7 12GB 256GB', 'sku': 'dien-thoai-samsung-galaxy-z-fold-7', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '200 MP', 'Aperture camera chính': 'f/1.7', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'UHD 8K@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '10MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': ['Visual Engine AI'], 'Kích thước màn hình': '8.0 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Màn hình gập', 'Độ phân giải màn hình': '2184 x 1968', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon® 8 Elite 3nm for Galaxy', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4400mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6E', 'Bluetooth': 'v5.4', 'GPS': ['GPS', 'Glonass', 'Beidou', 'Galileo', 'QZSS'], 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '4.2 mm', 'Trọng lượng': '215 gram', 'Số màu sắc': 3, 'Điện thoại gập': 'Fold', 'Cảm biến vân tay': 'Cảm biến vân tay', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': ['Now Brief', 'Generative Edit (Chỉnh sửa tạo sinh)', 'Intelligent Multimodal Search', 'Interpreter 2 màn hình', 'AI thực hiện tác vụ bằng lời nói'], 'Tên thuộc tính': 'Giá trị', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) Lý do: Samsung flagship', 'Số năm OS update': '7 năm Lý do: Samsung Galaxy S series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['Visual Engine AI', 'Now Brief', 'Generative Edit (Chỉnh sửa tạo sinh)', 'Intelligent Multimodal Search', 'Interpreter 2 màn hình', 'AI thực hiện tác vụ bằng lời nói'], 'AI Score tổng hợp': '5'},
    {'name': 'Samsung Galaxy A07 4GB 128GB', 'sku': 'dien-thoai-samsung-galaxy-a07', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '10x', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '480 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Kính cường lực Panda', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '720 x 1600 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G99', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G57', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '25W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 5', 'Bluetooth': 'v5.3', 'GPS': 'GPS, GLONASS, GALILEO, BEIDOU, QZSS', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'không có', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '7.6 mm', 'Trọng lượng': '184 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) Lý do: Samsung mid-range', 'Số năm OS update': '4 năm Lý do: Samsung A series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Cloud Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['Thủ thuật xử lý hình ảnh thông minh, khả năng cân bằng sáng được tối ưu'], 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy A56 5G 8GB 128GB', 'sku': 'dien-thoai-samsung-galaxy-a56', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50.0 MP', 'Aperture camera chính': 'F/1.8', 'OIS / Chống rung': 'OIS', 'Zoom quang học': '10x', 'Quay video camera sau': 'UHD 4K@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12.0 MP', 'Aperture camera trước': 'F/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1200 nit', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning Gorilla Glass Victus+', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2340 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Exynos 1580', 'AnTuTu score': 1243000, 'Xếp loại chip': 'B', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'ax', 'Bluetooth': 'v5.3', 'GPS': 'GPS, Glonass, Beidou, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': 'SIM 1 + SIM 2 / SIM 1 + eSIM / 2 eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP67', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': '7.4 mm', 'Trọng lượng': '198g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Hỗ Trợ Âm Thanh Nổi', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%)', 'Số năm OS update': '4 năm (Ước lượng từ Samsung A series)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid (Samsung Galaxy S)', 'Danh sách tính năng AI thực tế': 'Super HDR, Low Noise', 'AI Score tổng hợp': '2'},
    {'name': 'Samsung Galaxy S25 FE 8GB 128GB', 'sku': 'dien-thoai-samsung-galaxy-s25-fe', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 16, One UI 8', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'UHD 8K (7680×4320) @30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'UHD 8K (7680×4320) @60fps', 'Tính năng AI camera': 'Nightography, Super HDR Selfie Video, Panorama, Góc rộng, Audio Eraser, Xóa & tạo ảnh AI, Best Face, Tùy chỉnh bộ lọc (Cường độ, Tương phản, Bão hòa, Nhiệt độ màu, Hạt phim)', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1900 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Gorilla® Victus+', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2340', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Exynos 2400', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 16, One UI 8', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4900 mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'Sạc nhanh không dây 2.0', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'ax (2.4GHz+5GHz+6GHz)', 'Bluetooth': 'v5.4', 'GPS': 'GPS, Glonass, Beidou, Galileo, NavIC, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 Nano-SIM + eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.4 mm', 'Trọng lượng': '190g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Gemini, Gemini Live, Now Brief, Now Bar, Khoanh tròn tìm kiếm, hỗ trợ viết, hỗ trợ cuộc gọi, liên tác vụ bằng giọng nói', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Đối tượng)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) Lý do: Samsung mid-range', 'Số năm OS update': '4 năm Lý do: Samsung A series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '4 4K@60fps ổn định tốt', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': 'Nightography, Super HDR Selfie Video, Panorama, Góc rộng, Audio Eraser, Xóa & tạo ảnh AI, Best Face, Tùy chỉnh bộ lọc (Cường độ, Tương phản, Bão hòa, Nhiệt độ màu, Hạt phim, Seamless actions across apps, Circle to Search, Audio Eraser, Auto Trim, Photo Assist, Writing Assist', 'AI Score tổng hợp': '4'},
    {'name': 'Samsung Galaxy S24 Plus 12GB 256GB', 'sku': 'samsung-galaxy-s24-plus', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 14, One UI 6.1', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '3x', 'Quay video camera sau': '8K@24/30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12 MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': ['Trợ lí Chỉnh ảnh (Gợi ý chỉnh sửa, Hậu kì sáng tạo)', 'Chụp đêm Nightography', 'Chế độ Super HDR', 'Chụp hình & quay phim với Portrait AI'], 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2600 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning® Gorilla® Glass Victus® 2', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '3120 x 1440', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Exynos 2400', 'AnTuTu score': 1987654, 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno 750', 'Hệ điều hành': 'Android 14, One UI 6.1', 'Công nghệ tản nhiệt': 'Hệ thống tản nhiệt Vapor Chamber', 'Bypass charging': 'N/A', 'Dung lượng pin': '4900mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'Có', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'ax', 'Bluetooth': '5.3', 'GPS': 'GPS, GLONASS, BDS, GALILEO', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'SIM 1 + SIM 2 / SIM 1 + eSIM / 2 eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.75 mm', 'Trọng lượng': '196 gram', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Âm thanh AKG, Âm thanh Dolby Atmos', 'Hỗ trợ AI': ['Khoanh tròn để tìm kiếm', 'Trợ lí chình ảnh chuyên nghiệp', 'Phiên dịch cuộc gọi trực tiếp', 'Trợ lý chat thông minh'], 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'Samsung DeX (Kết nối màn hình sử dụng giao diện tương tự PC)', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Đối tượng)': '4', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '4', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) Lý do: Samsung mid-range', 'Số năm OS update': '4 năm Lý do: Samsung A series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '4 Rất tốt, ít noise', 'Chất lượng video thực tế': '4 4K@60fps ổn định tốt', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': 'Trợ lí Chỉnh ảnh (Gợi ý chỉnh sửa, Hậu kì sáng tạo), Chụp đêm Nightography, Chế độ Super HDR, Chụp hình & quay phim với Portrait AI, Khoanh tròn để tìm kiếm, Trợ lí chình ảnh chuyên nghiệp, Phiên dịch cuộc gọi trực tiếp, Trợ lý chat thông minh', 'AI Score tổng hợp': '4'},
    {'name': 'Samsung Galaxy A36 5G 8GB 128GB', 'sku': 'dien-thoai-samsung-galaxy-a36', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50.0 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'OIS', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'UHD 4K (3840 x 2160)@30fps, 240fps @HD', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12.0 MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1.200 nit', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning Gorilla Glass Victus+', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2340', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 6 Gen 3', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '45 W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'ax', 'Bluetooth': 'v5.4', 'GPS': 'GPS, Glonass, Beidou, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': 'SIM 1 + SIM 2 / SIM 1 + eSIM / 2 eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP67', 'Chất lượng mặt lưng': 'Kim loại', 'Chất lượng khung viền': 'Kính', 'Độ mỏng': '7.4 mm', 'Trọng lượng': '195 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Hỗ Trợ Âm Thanh Nổi', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) Lý do: Samsung mid', 'Số năm OS update': '4 năm Lý do: Samsung A series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '4 Rất tốt, ít noise', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['Nhận diện khuôn mặt'], 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy A06 5G 4GB 128GB', 'sku': 'dien-thoai-samsung-galaxy-a06-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50.0 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'FHD (1920 x 1080)@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8.0 MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Night Mode', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'PLS LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '576 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '720 x 1600 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Mali-G57', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G52', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '25W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 802.11 a/b/g/n/ac', 'Bluetooth': 'v5.3', 'GPS': 'GPS, Glonass, Beidou, Galileo', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano SIM (Sim 2 chung khe với thẻ nhớ)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.0 mm', 'Trọng lượng': '191 gr', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) Lý do: Samsung mid-range', 'Số năm OS update': '4 năm Lý do: Samsung A series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc Lý do: Độ phân giải 50.0 MP, f/1.8, AI Night Mode', 'Chất lượng ảnh ban đêm': '4 Rất tốt, ít noise Lý do: Aperture f/1.8, có Night Mode và Chip Mali-G57', 'Chất lượng video thực tế': '4 4K@60fps ổn định tốt Lý do: Quay video sau FHD (1920 x 1080)@60fps (specification), 4K@60fps (description)', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối Lý do: Độ phân giải 8.0 MP, f/2.0', 'AI on-device vs Cloud': 'Cloud Lý do: Sử dụng chip Mali-G57 (tầm trung)', 'Danh sách tính năng AI thực tế': 'Night Mode', 'AI Score tổng hợp': '2'},
    {'name': 'Samsung Galaxy A37 5G 8GB 128GB', 'sku': 'dien-thoai-samsung-galaxy-a37', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 16', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': ['Chân dung AI', 'AI Camera'], 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1900 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2340', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Exynos 1480', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Xclipse 530', 'Hệ điều hành': 'Android 16', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': 'v5.3', 'GPS': ['GPS', 'GLONASS', 'GALILEO', 'BEIDOU'], 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'N/A', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': '7.4 mm', 'Trọng lượng': '196g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': ['Circle to Search', 'Live Translate', 'Gemini'], 'product_color_1': 'Xanh', 'product_color_2': 'Đen', 'product_color_3': 'Trắng', 'product_color_4': 'Tím', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '4', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) Lý do: Samsung mid', 'Số năm OS update': '4 năm Lý do: Samsung A series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['Chân dung AI', 'AI Camera', 'Circle to Search', 'Live Translate', 'Gemini'], 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy S25 256GB', 'sku': 'dien-thoai-samsung-galaxy-s25', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Quay Log Video, Chụp hình Super HDR, Chế độ quay phim 10-bit HDR, Chân dung, Tự động lấy nét, Quay Video đêm', 'Kích thước màn hình': '6.2 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2600 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning® Gorilla® Armor 2', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '2340 x 1080', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 Elite', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4000 mAh', 'Sạc có dây': '25W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6E', 'Bluetooth': 'v5.4', 'GPS': 'GPS, Glonass, Beidou, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano SIM hoặc 2 eSIM hoặc 1 Nano SIM + 1 eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.2 mm', 'Trọng lượng': '162g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Lọc âm thanh (Audio Eraser)', 'Hỗ trợ AI': 'Thực hiện tác vụ liên ứng dụng bằng lời nói (Seamless Actions across Apps)', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) (Samsung mid)', 'Số năm OS update': '7 năm (Ước lượng dựa trên Samsung Galaxy S series)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid (Samsung Galaxy S 2024 trở lên)', 'Danh sách tính năng AI thực tế': ['Quay Log Video', 'Chụp hình Super HDR', 'Chế độ quay phim 10-bit HDR', 'Chân dung', 'Tự động lấy nét', 'Quay Video đêm', 'Thực hiện tác vụ liên ứng dụng bằng lời nói (Seamless Actions across Apps)'], 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy A17 8GB 128GB', 'sku': 'dien-thoai-samsung-galaxy-a17', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'Chống rung quang học', 'Zoom quang học': '10x', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '13 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Night Mode, AI Portrait, Clean Up, ProRAW, Apple Log, Generative Edit', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super AMOLED', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '800 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Gorilla Glass 7', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '1080 x 2340 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G99', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G57', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '25W', 'Sạc không dây': 'Không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '802.11 a/b/g/n/ac 2.4GHz+5GHz', 'Bluetooth': 'v5.3', 'GPS': 'GPS, GLONASS, GALILEO, BEIDOU', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 Nano SIM (Sim 2 chung khe với thẻ nhớ)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '7.5 mm', 'Trọng lượng': '190g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Samsung mid)', 'Số năm OS update': '4 năm (Ước lượng: Samsung A series)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid (Samsung Galaxy S 2024 trở lên)', 'Danh sách tính năng AI thực tế': 'Night Mode, AI Portrait, Clean Up, ProRAW, Apple Log, Generative Edit, Quick Share, Smart Switch', 'AI Score tổng hợp': '4'},
    {'name': 'Samsung Galaxy S25 Plus 256GB', 'sku': 'dien-thoai-samsung-galaxy-s25-plus', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Quay Log Video, Chụp hình Super HDR, Chế độ quay phim 10-bit HDR, Chân dung, Tự động lấy nét, Quay Video đêm', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2600 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning® Gorilla® Armor 2', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '3120 x 1440', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 Elite', 'AnTuTu score': 3336910, 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Snapdragon 8 Elite dành cho Galaxy (3nm)', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4900 mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'Fast Wireless Charging 2.0', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6E', 'Bluetooth': 'v5.4', 'GPS': 'GPS, Glonass, Beidou, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM + eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.3 mm', 'Trọng lượng': '190g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Lọc âm thanh (Audio Eraser)', 'Hỗ trợ AI': 'Thực hiện tác vụ liên ứng dụng bằng lời nói (Seamless Actions across Apps)', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '4', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '4', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) Lý do: Samsung flagship', 'Số năm OS update': '7 năm Lý do: Samsung Galaxy S series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['Quay Log Video', 'Chụp hình Super HDR', 'Chế độ quay phim 10-bit HDR', 'Chân dung', 'Tự động lấy nét', 'Quay Video đêm', 'Circle to Search with Google'], 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy Z Fold 6 12GB 256GB', 'sku': 'samsung-galaxy-z-fold-6', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 5, 'Phiên bản OS ra mắt': 'Android', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50.0 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '3x', 'Quay video camera sau': 'UHD 8K (7680 x 4320)@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '10 MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '7.6 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2600nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning® Gorilla® Glass Victus® 2', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2160 x 1856', 'Hỗ trợ bút stylus': 'Hỗ trợ S Pen', 'Chip tier': 'Snapdragon 8 Gen 3 for Galaxy Tăng lên 42% AI', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Snapdragon 8 Gen 3', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4400 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': '802.11ax', 'Bluetooth': 'v5.3', 'GPS': 'GPS, Glonass, Beidou, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'SIM 1 + SIM 2 / SIM 1 + eSIM / 2 eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP48', 'Chất lượng mặt lưng': 'Nhôm', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '5.6 mm', 'Trọng lượng': '239 g', 'Số màu sắc': 5, 'Điện thoại gập': 'Không gập', 'Cảm biến vân tay': 'Bảo mật vân tay', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Hỗ Trợ Âm Thanh Nổi', 'Hỗ trợ AI': 'Tích hợp ứng dụng Google Gemini', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '4', 'Kinh doanh (Use Case)': '4', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '5', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) Lý do: Samsung flagship', 'Số năm OS update': '7 năm Lý do: Samsung Galaxy S series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': 'Chân dung AI Studio, Tích hợp ứng dụng Google Gemini', 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy S26 12GB 512GB', 'sku': 'dien-thoai-samsung-galaxy-s26-12gb-512gb', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Chỉnh sửa ảnh thế hệ mới (Photo Assist)', 'Kích thước màn hình': '6.3 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2600 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2340 x 1080', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Exynos 2600 (2nm)', 'AnTuTu score': 3145925, 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4300 mAh', 'Sạc có dây': '25W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'GPS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM + eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.2 mm', 'Trọng lượng': '167g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Circle to Search, Live Translate, Gemini', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Samsung mid)', 'Số năm OS update': '4 năm (Ước lượng từ Samsung A series)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid (Samsung Galaxy S 2024 trở lên)', 'Danh sách tính năng AI thực tế': 'Chỉnh sửa ảnh thế hệ mới (Photo Assist), Circle to Search, Live Translate, Gemini', 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy S24 Ultra 12GB 512GB', 'sku': 'samsung-galaxy-s24-ultra-512gb', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 14, One UI 6.1', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '200MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '5x', 'Quay video camera sau': '8K@24/30fps, 4K@30/60/120fps, 1080p@30/60/240fps, 1080p@960fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12 MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Hỗ trợ AI', 'Kích thước màn hình': '6.8 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2,600 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1440 x 3120 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 Gen 3', 'AnTuTu score': 2203456, 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Adreno 750 (1 GHz)', 'Hệ điều hành': 'Android 14, One UI 6.1', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6E', 'Bluetooth': '5.3', 'GPS': 'GPS, Glonass, Beidou, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'SIM 1 + SIM 2 / SIM 1 + eSIM / 2 eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Titanium', 'Độ mỏng': '8.6mm', 'Trọng lượng': '232g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Điện thoại AI, Samsung DeX, Samsung Wireless DeX (hỗ trợ trải nghiệm máy tính để bàn), Hỗ trợ băng thông siêu rộng (UWB)', 'Gaming (Use Case)': '4', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) (Samsung flagship)', 'Số năm OS update': '7 năm (Ước lượng dựa trên Samsung Galaxy S series)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid (Samsung Galaxy S 2024 trở lên)', 'Danh sách tính năng AI thực tế': 'Hỗ trợ AI, Samsung DeX, Samsung Wireless DeX (hỗ trợ trải nghiệm máy tính để bàn), Hỗ trợ băng thông siêu rộng (UWB)', 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy A06 4GB 128GB', 'sku': 'dien-thoai-samsung-galaxy-a06', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50.0 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'FHD (1920 x 1080)@60fps, 120fps @HD', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8.0 MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'PLS LCD', 'Tần số quét': '60Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '720 x 1600 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G85', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'MediaTek Helio G85', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '25W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G', 'Wi-Fi': 'Wi-Fi 5', 'Bluetooth': 'v5.3', 'GPS': 'GPS, Glonass, Beidou, Galileo', 'NFC': 'N/A', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.0 mm', 'Trọng lượng': '189 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) Lý do: Samsung mid-range', 'Số năm OS update': '4 năm Lý do: Samsung A series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc Lý do: Độ phân giải 50.0 MP, f/1.8, Chip MediaTek Helio G85, Tính năng AI camera', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được Lý do: Aperture f/1.8, N/A OIS, N/A Night Mode', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận Lý do: Quay video FHD (1920 x 1080)@60fps, 120fps @HD, N/A OIS', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối Lý do: Độ phân giải 8.0 MP, f/2.0, Quay video camera trước N/A', 'AI on-device vs Cloud': 'Cloud Lý do: Chip MediaTek Helio G85 (chip tầm trung)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Samsung Galaxy S24 FE 5G 8GB 128GB', 'sku': 'dien-thoai-samsung-galaxy-s24-fe', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '10MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Dynamic AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2400', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Exynos 2400e (4nm)', 'AnTuTu score': 1987654, 'Xếp loại chip': 'A+', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4700 mAh', 'Sạc có dây': '25W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'GPS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '1 SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Nhận diện khuôn mặt', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) Lý do: Samsung mid-range', 'Số năm OS update': '4 năm Lý do: Samsung A series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['tách nền', 'xóa chi tiết thừa'], 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy Z Flip6 12GB 256GB', 'sku': 'samsung-galaxy-z-flip-6', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 5, 'Phiên bản OS ra mắt': 'Android', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50.0 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'OIS', 'Zoom quang học': '2x', 'Quay video camera sau': 'UHD 4K (3840 x 2160)@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '10.0 MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1600nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Gorilla Glass Victus® 2', 'Kiểu màn hình / Notch': 'Màn hình gập', 'Độ phân giải màn hình': '1080 x 2640 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 Gen 3 for Galaxy Tăng lên 42% AI', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Snapdragon 8 Gen 3', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'Vapor Chamber', 'Bypass charging': 'N/A', 'Dung lượng pin': '4000 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 802.11a/b/g/n/ac/ax', 'Bluetooth': 'v5.3', 'GPS': 'GPS, Glonass, Beidou, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '1 Nano SIM + 1 eSIM hoặc 2 eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP48', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '6.9 mm', 'Trọng lượng': '187 g', 'Số màu sắc': 5, 'Điện thoại gập': 'Flip', 'Cảm biến vân tay': 'Bảo mật vân tay', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Hỗ Trợ Âm Thanh Nổi', 'Hỗ trợ AI': 'Tích hợp ứng dụng Google Gemini', 'Gaming (Use Case)': '4', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) Samsung flagship', 'Số năm OS update': '7 năm Samsung Galaxy S series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['Gợi ý trả lời tin nhắn'], 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy Note 10', 'sku': 'samsung-galaxy-note-10-chinh-hang', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 0, 'Phiên bản OS ra mắt': '9.0 (Pie)', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '12MP', 'Aperture camera chính': 'F2.1', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@2160p@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '10 MP', 'Aperture camera trước': 'F2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.3 inches', 'Công nghệ màn hình': 'Dynamic AMOLED FHD+', 'Tần số quét': 'N/A', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '1080 x 2280', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Samsung Exynos 9825', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'B', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Mali-G76', 'Hệ điều hành': '9.0 (Pie)', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '3500 mAh', 'Sạc có dây': '25W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': 'N/A', 'Wi-Fi': 'Wi-Fi 802.11 a/b/g/n/ac', 'Bluetooth': 'v5.0', 'GPS': 'BDS, A-GPS, GLONASS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.9 mm', 'Trọng lượng': '168 g', 'Số màu sắc': 0, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) Lý do: Samsung mid', 'Số năm OS update': '4 năm Lý do: Samsung A series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '4 4K@60fps ổn định tốt', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Cloud Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Samsung Galaxy Z Fold6 12GB 512GB', 'sku': 'samsung-galaxy-z-fold-6-512gb', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50.0 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '3x', 'Quay video camera sau': 'UHD 8K (7680 x 4320)@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '10 MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '7.6 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2600nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Gorilla Glass Victus® 2', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2160 x 1856', 'Hỗ trợ bút stylus': 'Hỗ trợ S Pen', 'Chip tier': 'Snapdragon 8 Gen 3 for Galaxy Tăng lên 42% AI', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Snapdragon 8 Gen 3', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4400 mAh', 'Sạc có dây': 'N/A', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': '802.11ax', 'Bluetooth': 'v5.3', 'GPS': 'GPS, Glonass, Beidou, Galileo, QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'SIM 1 + SIM 2 / SIM 1 + eSIM / 2 eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP48', 'Chất lượng mặt lưng': 'Nhôm', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '5.6 mm', 'Trọng lượng': '239 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Bảo mật vân tay', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Hỗ Trợ Âm Thanh Nổi', 'Hỗ trợ AI': 'Tích hợp ứng dụng Google Gemini', 'Gaming (Use Case)': '4', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) (Samsung flagship)', 'Số năm OS update': '7 năm (Ước lượng dựa trên Samsung Galaxy S series)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid (Samsung Galaxy S 2024 trở lên)', 'Danh sách tính năng AI thực tế': 'Tích hợp ứng dụng Google Gemini', 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy Z Fold5 12GB 512GB', 'sku': 'samsung-galaxy-z-fold-5', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '3X', 'Quay video camera sau': '8K@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '10 MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Khoanh vùng search đa năng, là trợ lý chỉnh ảnh,trợ lý note thông minh, phiên dịch trực tiếp', 'Kích thước màn hình': '7.6 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1750 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Màn hình gập', 'Độ phân giải màn hình': '2176 x 1812', 'Hỗ trợ bút stylus': 'tích hợp sẵn', 'Chip tier': 'Snapdragon 8 Gen 2 for Galaxy (4nm) 8 nhân', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Adreno 740', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4400 mAh', 'Sạc có dây': '25W', 'Sạc không dây': 'Sạc không dây', 'Sạc ngược': 'Sạc ngược không dây', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 802.11 ax', 'Bluetooth': 'v5.3', 'GPS': ['GLONASS', 'GPS', 'GALILEO', 'QZSS', 'BEIDOU'], 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'không', 'Kháng nước / bụi': 'IPX8', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '6.1 mm', 'Trọng lượng': '253 g', 'Số màu sắc': 3, 'Điện thoại gập': 'Flip', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Âm thanh AKG', 'Hỗ trợ AI': ['Galaxy AI tiện ích - Khoanh vùng search đa năng', 'là trợ lý chỉnh ảnh', 'trợ lý note thông minh', 'phiên dịch trực tiếp'], 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) (Samsung flagship)', 'Số năm OS update': '7 năm (Ước lượng dựa trên Samsung Galaxy S series)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid (Samsung Galaxy S (2024 trở lên))', 'Danh sách tính năng AI thực tế': 'Khoanh vùng search đa năng, là trợ lý chỉnh ảnh,trợ lý note thông minh, phiên dịch trực tiếp', 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy Z Flip4 128GB', 'sku': 'samsung-galaxy-z-flip-4', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 12', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '12 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@30/60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '10 MP', 'Aperture camera trước': 'f/2.4', 'Quay video camera trước': '4K@30fps', 'Tính năng AI camera': 'AI Camera', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1200 nits (peak)', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning Gorilla Glass Victus+', 'Kiểu màn hình / Notch': 'Màn hình gập', 'Độ phân giải màn hình': '1080 x 2640 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8+ Gen 1 8 nhân', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'A+', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Adreno 670', 'Hệ điều hành': 'Android 12', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'Không', 'Dung lượng pin': '3700 mAh', 'Sạc có dây': '25W', 'Sạc không dây': '10W', 'Sạc ngược': 'Không', 'Mạng di động': '5G', 'Wi-Fi': 'ax', 'Bluetooth': 'v5.2', 'GPS': 'GLONASS, GPS, GALILEO, QZSS, BEIDOU', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IPX8', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '6.9 mm', 'Trọng lượng': '187 g', 'Số màu sắc': 4, 'Điện thoại gập': 'Flip', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Dolby Atmos', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'Samsung DeX (Kết nối màn hình sử dụng giao diện tương tự PC)', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) Lý do: Samsung mid-range', 'Số năm OS update': '7 năm Lý do: Samsung Galaxy S series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['AI Camera'], 'AI Score tổng hợp': '2'},
    {'name': 'Samsung Galaxy Z Fold4 256GB', 'sku': 'samsung-galaxy-z-fold-4', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 12', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '3x', 'Quay video camera sau': 'UHD 8K (7680 x 4320)@24fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '10MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': '960fps @HD, 240fps @FHD', 'Tính năng AI camera': 'AI Camera', 'Kích thước màn hình': '7.6 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Màn hình gập', 'Độ phân giải màn hình': '2176 x 1812', 'Hỗ trợ bút stylus': 'hỗ trợ mua thêm', 'Chip tier': 'Snapdragon 8 Plus Gen 1', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno 670', 'Hệ điều hành': 'Android 12', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': '4,400 mAh', 'Sạc có dây': '25 W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'ax', 'Bluetooth': 'v5.2', 'GPS': 'A-GPS, GLONASS, GALILEO, BDS', 'NFC': 'có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (nano‑SIM và eSIM)', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IPX8', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '6.3 mm', 'Trọng lượng': '263', 'Số màu sắc': 3, 'Điện thoại gập': 'Fold', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Hỗ Trợ Âm Thanh Nổi, Dolby Atmos', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'Samsung DeX (Kết nối màn hình sử dụng giao diện tương tự PC)', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Đối tượng)': '2', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) Lý do: Samsung flagship', 'Số năm OS update': '7 năm Lý do: Samsung Galaxy S series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '5 Sắc nét tuyệt vời, màu chuẩn, dynamic range rộng', 'Chất lượng ảnh ban đêm': '4 Rất tốt, ít noise', 'Chất lượng video thực tế': '4 4K@60fps ổn định tốt', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['AI Camera', 'Zoom quang học 3X', 'Nhận diện khuôn mặt', 'Chụp liên tục', 'Tự động cân bằng sáng', 'ISO', 'tính năng chụp HDR rực rỡ', 'AI Camera'], 'AI Score tổng hợp': '3'},
    {'name': 'Samsung Galaxy S22 Plus (8GB + 128GB)', 'sku': 'samsung-galaxy-s22-plus', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 12', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '8K@24fps, 4K@30/60fps, 1080p@30/60/240fps, 720p@960fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '10 MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Đèn LED kép, Chuyên nghiệp (Pro), Tự động lấy nét (AF), HDR, Toàn cảnh (Panorama), Quay Siêu chậm (Super Slow Motion), Làm đẹp', 'Kích thước màn hình': '6.6 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1750 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Kính cường lực Corning Gorilla Glass Victus+', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2340 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 Gen 1', 'AnTuTu score': 1556789, 'Xếp loại chip': 'A+', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Adreno 730', 'Hệ điều hành': 'Android 12', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4500 mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'Có', 'Sạc ngược': 'Có', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6/6E/7 (Dual-band (2.4 GHz/5 GHz), Wi-Fi 802.11 a/b/g/n/ac/ax, Wi-Fi Direct, Wi-Fi hotspot)', 'Bluetooth': 'v5.2', 'GPS': 'GPS, GLONASS, GALILEO, BDS', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 Nano SIM hoặc 1 Nano + 1 eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': '7.6 mm', 'Trọng lượng': '195 g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Âm thanh Dolby Atmos, Âm thanh AKG', 'Hỗ trợ AI': 'Trợ lý ảo Samsung Bixby', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) (Samsung flagship)', 'Số năm OS update': '7 năm (Ước lượng dựa trên Samsung Galaxy S series)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid (Suy luận dựa trên Samsung Galaxy S)', 'Danh sách tính năng AI thực tế': 'Đèn LED kép, Chuyên nghiệp (Pro), Tự động lấy nét (AF), HDR, Toàn cảnh (Panorama), Quay Siêu chậm (Super Slow Motion), Làm đẹp, Khả năng ghi lại hình ảnh rõ nét và giàu chi tiết ngay cả khi ánh sáng yếu', 'AI Score tổng hợp': '4'},
    {'name': 'Samsung Galaxy S22 (8GB - 256GB)', 'sku': 'samsung-galaxy-s22-256gb', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 12', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '8K@24fps, 4K@30/60fps, 1080p@30/60/240fps, 720p@960fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '10MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': '4K@30/60fps, 1080p@30fps', 'Tính năng AI camera': 'AI Camera Chuyên nghiệp (Pro)', 'Kích thước màn hình': '6.1 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1300 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning Gorilla Glass Victus+', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2340', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 Gen 1', 'AnTuTu score': 1556789, 'Xếp loại chip': 'A+', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno 730', 'Hệ điều hành': 'Android 12', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': '3700 mAh', 'Sạc có dây': '25W', 'Sạc không dây': '15W', 'Sạc ngược': '4,5W', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': 'v5.2', 'GPS': 'A-GPS, GLONASS, BDS, GALILEO', 'NFC': 'có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 Nano SIM hoặc 1 Nano + 1 eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': '7.6 mm', 'Trọng lượng': '167', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Dolby Atmos', 'Hỗ trợ AI': 'Samsung Bixby', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '5', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) (Samsung flagship)', 'Số năm OS update': '7 năm (Ước lượng dựa trên Samsung Galaxy S series)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid (Samsung Galaxy S 2024 trở lên)', 'Danh sách tính năng AI thực tế': 'AI Camera Chuyên nghiệp (Pro), Samsung Bixby', 'AI Score tổng hợp': '2'},
    {'name': 'Samsung Galaxy A26 5G 8GB 128GB', 'sku': 'dien-thoai-samsung-galaxy-a26', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '10x', 'Quay video camera sau': 'UHD 4K 3840 x 2160@30fps, 480fps@240fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '13MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Chụp làm đẹp', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '800 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Gorilla Glass Victus', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '1080 x 2340', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Exynos 1380 (Quartz)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G68', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '25W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': 'v5.3', 'GPS': 'GPS,GLONASS,Beidou,Galileo,QZSS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP67', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '7.7 mm', 'Trọng lượng': '200g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%)', 'Số năm OS update': '4 năm (Ước lượng dựa trên Samsung A series)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid (Do sử dụng Exynos chip)', 'Danh sách tính năng AI thực tế': ['Chụp làm đẹp'], 'AI Score tổng hợp': '2'},
    {'name': 'Samsung Galaxy S24 Ultra 12GB 256GB', 'sku': 'samsung-galaxy-s24-ultra', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 14, One UI 6.1', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '200MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '3x', 'Quay video camera sau': '8K@24/30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12 MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': ['Trợ lí Chỉnh ảnh (Gợi ý chỉnh sửa, Hậu kì sáng tạo)', 'Chụp đêm Nightography', 'Chế độ Super HDR', 'Chụp hình & quay phim với Portrait AI'], 'Kích thước màn hình': '6.8 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2,600 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning® Gorilla® Armor®', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1440 x 3120 pixels', 'Hỗ trợ bút stylus': 'tích hợp sẵn', 'Chip tier': 'Snapdragon 8 Gen 3 For Galaxy', 'AnTuTu score': 2203456, 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno 750 (1 GHz)', 'Hệ điều hành': 'Android 14, One UI 6.1', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5,000mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'Chia sẻ pin không dây', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'ax', 'Bluetooth': 'v5.3', 'GPS': ['GPS', 'Glonass', 'Beidou', 'Galileo', 'QZSS'], 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'SIM 1 + SIM 2 / SIM 1 + eSIM / 2 eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'Không hỗ trợ', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Titanium', 'Độ mỏng': '8.6mm', 'Trọng lượng': '232g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Âm thanh AKG, Âm thanh Dolby Atmos', 'Hỗ trợ AI': ['Khoanh tròn để tìm kiếm', 'trợ lí note', 'Trợ lí chình ảnh chuyên nghiệp', 'Phiên dịch cuộc gọi trực tiếp', 'Trợ lý chat thông minh'], 'Gaming (Use Case)': '4', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '5', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '4', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) Lý do: Samsung flagship', 'Số năm OS update': '7 năm Lý do: Samsung Galaxy S series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['Trợ lí Chỉnh ảnh (Gợi ý chỉnh sửa, Hậu kì sáng tạo)', 'Chụp đêm Nightography', 'Chế độ Super HDR', 'Chụp hình & quay phim với Portrait AI', 'Khoanh tròn để tìm kiếm', 'trợ lí note', 'Trợ lí chình ảnh chuyên nghiệp', 'Phiên dịch cuộc gọi trực tiếp', 'Trợ lý chat thông minh'], 'AI Score tổng hợp': '5'},
    {'name': 'Samsung Galaxy S26 Ultra 16GB 1TB', 'sku': 'dien-thoai-samsung-galaxy-s26-ultra-16gb-1tb', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Không có', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '200MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '100x', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Quay Log Video, Chế độ quay phim 10-bit HDR, Chế độ Chân dung, Tự động lấy nét, Quay Video đêm', 'Kích thước màn hình': '6.9 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2600 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '3120 x 1440', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 Elite Gen 5 dành cho Galaxy (3nm)', 'AnTuTu score': 3932243, 'Xếp loại chip': 'A+', 'RAM': '16 GB', 'Bộ nhớ trong': '1 TB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '60W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'GPS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM + eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.9 mm', 'Trọng lượng': '214 g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Gợi ý thông minh, Khoanh tròn để tìm kiếm, Lọc cuộc gọi tự động, Proscaler & 10-bit mDNIe', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình-Cao (~55-65%) Lý do: Samsung flagship', 'Số năm OS update': '7 năm Lý do: Samsung Galaxy S series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['Quay Log Video', 'Chế độ quay phim 10-bit HDR', 'Chế độ Chân dung', 'Tự động lấy nét', 'Quay Video đêm', 'Gợi ý thông minh', 'Khoanh tròn để tìm kiếm', 'Lọc cuộc gọi tự động', 'Proscaler & 10-bit mDNIe'], 'AI Score tổng hợp': '4'},
    {'name': 'Samsung Galaxy S26 Plus 12GB 256GB', 'sku': 'dien-thoai-samsung-galaxy-s26-plus', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Không có', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'Không có', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': ['Chỉnh sửa ảnh thế hệ mới (Photo Assist)', 'Không gian sáng tạo (Creative Studio)', 'Gợi ý thông minh (Now Nudge)', 'Khoanh tròn để tìm kiếm (Circle to Search)', 'Lọc cuộc gọi tự động (Call Screening)', 'Proscaler & 10-bit mDNIe'], 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2600 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '3120 x 1440', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Exynos 2600 (2nm)', 'AnTuTu score': 3145925, 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '4900 mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': ['GPS'], 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM + eSIM', 'eSIM': 'Có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.3 mm', 'Trọng lượng': '190 g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': ['Chỉnh sửa ảnh thế hệ mới (Photo Assist)', 'Không gian sáng tạo (Creative Studio)', 'Gợi ý thông minh (Now Nudge)', 'Khoanh tròn để tìm kiếm (Circle to Search)', 'Lọc cuộc gọi tự động (Call Screening)', 'Proscaler & 10-bit mDNIe'], 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) Lý do: Samsung mid-range', 'Số năm OS update': '4 năm Lý do: Samsung A series', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid Lý do: Samsung Galaxy S (2024 trở lên)', 'Danh sách tính năng AI thực tế': ['Chỉnh sửa ảnh thế hệ mới (Photo Assist)', 'Không gian sáng tạo (Creative Studio)', 'Gợi ý thông minh (Now Nudge)', 'Khoanh tròn để tìm kiếm (Circle to Search)', 'Lọc cuộc gọi tự động (Call Screening)', 'Proscaler & 10-bit mDNIe'], 'AI Score tổng hợp': '5'},
    {'name': 'Samsung Galaxy A16 LTE 4GB 128GB', 'sku': 'dien-thoai-samsung-galaxy-a16-lte', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'F1.8, F2.2, F2.4', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'FHD (1920 x 1080)@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '13MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super AMOLED', 'Tần số quét': '90Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '1080 x 2340 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G99', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G57', 'Hệ điều hành': 'Android 15', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5,000mAh', 'Sạc có dây': '25W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '802.11a/b/g/n/ac 2.4GHz+5GHz, VHT80 Wi-Fi Direct', 'Bluetooth': '5.3', 'GPS': 'GPS, Glonass , Beidou , Galileo', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '7.9 mm', 'Trọng lượng': '192 gr', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Dựa trên Samsung mid-range)', 'Số năm OS update': '4 năm (Ước lượng dựa trên Samsung A series)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip MediaTek Helio G99)', 'Danh sách tính năng AI thực tế': 'Night Mode, Portrait, Clean Up', 'AI Score tổng hợp': '4'},
    {'name': 'Samsung Galaxy M55 12GB 256GB', 'sku': 'dien-thoai-samsung-galaxy-m55', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '50 MP', 'Aperture camera trước': 'f/2.4', 'Quay video camera trước': '4K@30fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'Super AMOLED Plus', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1000 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2400 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm Snapdragon 7 Gen 1 (4 nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno 644', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': 'v5.2', 'GPS': 'GPS, GALILEO, GLONASS, BDS, QZSS', 'NFC': 'có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.8 mm', 'Trọng lượng': '180 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Samsung mid)', 'Số năm OS update': '4 năm (Ước lượng dựa trên Samsung A series)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '4 Rất tốt, ít noise', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Hybrid (Samsung Galaxy S 2024 trở lên)', 'Danh sách tính năng AI thực tế': 'Night Mode', 'AI Score tổng hợp': '2'},
    {'name': 'Samsung Galaxy S23 8GB 128GB ĐKH Online', 'sku': 'samsung-galaxy-s23-128gb', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Samsung', 'Xuất xứ': 'Hàn Quốc', 'Giao diện OS': 'One UI', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '12MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'Quay video 4K', 'Tính năng AI camera': ['Trôi nhanh thời gian (Time Lapse)', 'Góc siêu rộng (Ultrawide)', 'Zoom kỹ thuật số', 'Quay chậm (Slow Motion)', 'Xóa phông', 'Toàn cảnh (Panorama)', 'Chống rung quang học (OIS)', 'Tự động lấy nét (AF)', 'Ảnh Raw', 'Ban đêm (Night Mode)', 'Chuyên nghiệp'], 'Kích thước màn hình': '6.1 inches', 'Công nghệ màn hình': 'Dynamic AMOLED 2X', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1750 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning Gorilla Glass Victus 2', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2340', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 Gen 2 for Galaxy', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Adreno 740', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '3900 mAh', 'Sạc có dây': '25 W', 'Sạc không dây': 'Sạc không dây', 'Sạc ngược': 'Không', 'Mạng di động': '5G', 'Wi-Fi': 'ax', 'Bluetooth': 'v5.3', 'GPS': ['BEIDOU', 'GPS', 'GLONASS', 'GALILEO'], 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 Nano SIM hoặc 1 Nano + 1 eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '7.6 mm', 'Trọng lượng': '168 g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Âm thanh Dolby Atmos, Âm thanh AKG', 'Hỗ trợ AI': ['Galaxy AI tiện ích - Khoanh vùng search đa năng', 'trợ lý chỉnh ảnh', 'trợ lý chat thông minh', 'phiên dịch trực tiếp'], 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'Samsung DeX (Kết nối màn hình sử dụng giao diện tương tự PC)', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~40-55%) (Dựa trên Samsung mid-range)', 'Số năm OS update': '7 năm (Ước lượng dựa trên Samsung Galaxy S series)', 'Chất lượng phần mềm / ít bloatware': 'Tốt - ít bloatware (One UI)', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid (Dựa trên thương hiệu Samsung và chip Snapdragon 8 Gen 2 for Galaxy)', 'Danh sách tính năng AI thực tế': 'Trôi nhanh thời gian (Time Lapse), Góc siêu rộng (Ultrawide), Zoom kỹ thuật số, Quay chậm (Slow Motion), Xóa phông, Toàn cảnh (Panorama), Chống rung quang học (OIS), Tự động lấy nét (AF), Ảnh Raw, Ban đêm (Night Mode), Chuyên nghiệp, Galaxy AI tiện ích - Khoanh vùng search đa năng, trợ lý chỉnh ảnh, trợ lý chat thông minh, phiên dịch trực tiếp', 'AI Score tổng hợp': '5'},
]

xiaomi_data = [
    {'name': 'Xiaomi Redmi Note 14 Pro Plus 5G 8GB 256GB', 'sku': 'dien-thoai-xiaomi-redmi-note-14-pro-plus', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 4, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '200MP', 'Aperture camera chính': 'f/1.65', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@2160p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '20 MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': '20 MP', 'Tính năng AI camera': 'Khoanh vùng tìm kiếm, Google Gemini, Phiên dịch AI, Ghi chú AI, Ghi âm AI, Phụ đề AI, Làm phim AI, Làm', 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3000 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2712 x 1220', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon® 7s Gen 3', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Qualcomm® Adreno™ GPU', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5110 mAh', 'Sạc có dây': '120W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6E', 'Bluetooth': '5.4', 'GPS': 'GPS, GLONASS, GALILEO, BEIDOU', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.75 mm', 'Trọng lượng': '210.14g', 'Số màu sắc': 4, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép, Dolby Atmos', 'Hỗ trợ AI': 'Khoanh vùng tìm kiếm, Google Gemini, Phiên dịch AI, Ghi chú AI, Ghi âm AI, Phụ đề AI, Làm phim AI, Làm', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%)', 'Số năm OS update': '4 năm (Ước lượng từ Xiaomi flagship)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Do sử dụng Snapdragon® 7s Gen 3)', 'Danh sách tính năng AI thực tế': ['Khoanh vùng tìm kiếm', 'Google Gemini', 'Phiên dịch AI', 'Ghi chú AI', 'Ghi âm AI', 'Phụ đề AI', 'Làm phim AI', 'Làm'], 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi 15 Ultra 5G 16GB 512GB', 'sku': 'dien-thoai-xiaomi-15-ultra', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'HarmonyOS', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Xiaomi HyperOS 2', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'ƒ/1.63', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '200MP', 'Quay video camera sau': '8K@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'ƒ/2.0', 'Quay video camera trước': '4K@60 fps', 'Tính năng AI camera': ['Xiaomi HyperAI', 'Viết AI', 'Phiên dịch AI', 'Nhận diện giọng nói AI', 'Trợ lý sáng tạo AI', 'Khoanh tròn để tìm kiếm bằng Google'], 'Kích thước màn hình': '6.7 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3200 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '3200 x 1440', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 Elite (Tiến trình sản xuất 3nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '16 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Adreno GPU', 'Hệ điều hành': 'Xiaomi HyperOS 2', 'Công nghệ tản nhiệt': 'Hệ thống làm mát kép IceLoop 3D', 'Bypass charging': 'N/A', 'Dung lượng pin': '5410mAh', 'Sạc có dây': '90W', 'Sạc không dây': '80W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7', 'Bluetooth': '6.0', 'GPS': ['GPS: L1+L5', 'Galileo: E1+E5a', 'GLONASS: G1', 'Beidou', 'QZSS: L1 + L5', 'NavIC: L5'], 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Sim kép (nano-Sim và e-Sim) - Hỗ trợ 2 e-Sim', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '9.35 mm', 'Trọng lượng': '226g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay siêu âm', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Dolby Atmos', 'Hỗ trợ AI': ['Xiaomi HyperAI', 'Viết AI', 'Phiên dịch AI', 'Nhận diện giọng nói AI', 'Trợ lý sáng tạo AI', 'Khoanh tròn để tìm kiếm bằng Google'], 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '4', 'Kinh doanh (Use Case)': '4', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) Lý do: Xiaomi/OPPO/Vivo', 'Số năm OS update': '4 năm Lý do: Xiaomi flagship', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Hybrid Lý do: Các hãng khác hoặc chip tầm trung', 'Danh sách tính năng AI thực tế': ['Xiaomi HyperAI', 'Viết AI', 'Phiên dịch AI', 'Nhận diện giọng nói AI', 'Trợ lý sáng tạo AI', 'Khoanh tròn để tìm kiếm bằng Google'], 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi Redmi Note 15 6GB 128GB', 'sku': 'dien-thoai-xiaomi-redmi-note-15', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'HarmonyOS', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'HyperOS 2', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '108MP', 'Aperture camera chính': 'ƒ/1.7', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '3x', 'Quay video camera sau': '1080P 30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '20MP', 'Aperture camera trước': 'ƒ/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'AI chỉnh sửa hình ảnh', 'Kích thước màn hình': '6.77 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3200 nits', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '1080 x 2392 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G100-Ultra', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Xiaomi HyperOS 2', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6000 mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G', 'Wi-Fi': '2.4GHz | 5GHz', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'N/A', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP64', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.94 mm', 'Trọng lượng': '183.7 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Dolby Atmos®, Hi-Res', 'Hỗ trợ AI': 'Google Gemini, Khoanh tròn tìm kiếm Google, AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'AI chỉnh sửa hình ảnh, Google Gemini, Khoanh tròn tìm kiếm Google, AI', 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi 15T 5G 12GB 512GB', 'sku': 'dien-thoai-xiaomi-15t-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Xiaomi HyperOS 2', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.7', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'AI hỗ trợ chụp/quay', 'Kích thước màn hình': '6.8 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3200 nits (25% vùng hiển thị)', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Dimensity 8400-Ultra', 'AnTuTu score': 1934134, 'Xếp loại chip': 'A', 'RAM': '12 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Xiaomi HyperOS 2, tích hợp Xiaomi HyperAI & Google Gemini', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5500mAh', 'Sạc có dây': '67W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6E', 'Bluetooth': 'N/A', 'GPS': 'GPS, GLONASS, Galileo, Beidou', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.50 mm', 'Trọng lượng': '194g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Nhận diện khuôn mặt', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép, Dolby Atmos®, Hi-Res Audio & Hi-Res Audio Wireless', 'Hỗ trợ AI': 'Google Gemini, Xiaomi HyperAI, khoanh tròn tìm kiếm, dịch, ghi âm AI, viết AI', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': ['AI hỗ trợ chụp/quay', 'Google Gemini', 'Xiaomi HyperAI', 'khoanh tròn tìm kiếm', 'dịch', 'ghi âm AI', 'viết AI'], 'AI Score tổng hợp': '4'},
    {'name': 'Xiaomi POCO X7 Pro 5G 12GB 256GB', 'sku': 'dien-thoai-poco-x7-pro-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Poco', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30/60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': 'N/A', 'Aperture camera trước': 'N/A', 'Quay video camera trước': '1080p@30/60fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3200 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '1220 x 2712 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Dimensity 8400-Ultra', 'AnTuTu score': 1934134, 'Xếp loại chip': 'A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Mali G615', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6000 mAh', 'Sạc có dây': '90W', 'Sạc không dây': 'Không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'GPS, GALILEO, GLONASS, QZSS, BDS (B1I+B1c)', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS / HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip tầm trung Dimensity)', 'Danh sách tính năng AI thực tế': 'Chế độ tiên tiến, Quay video thông minh', 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi Redmi Note 14 5G 8GB 256GB', 'sku': 'dien-thoai-xiaomi-redmi-note-14-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Xiaomi HyperOS', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '108MP', 'Aperture camera chính': 'ƒ/1.7', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '3x', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '20MP', 'Aperture camera trước': 'ƒ/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': ['Google Gemini', 'Xoá AI', 'AI Sky', 'làm đẹp AI'], 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '2100 nits', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'Corning Gorilla Glass 5', 'Kiểu màn hình / Notch': 'Dynamic Island', 'Độ phân giải màn hình': '1080 x 2400 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Dimensity 7025 - Ultra', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'IMG BXM-8-256', 'Hệ điều hành': 'Xiaomi HyperOS', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5110mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'N/A', 'Bluetooth': '5.3', 'GPS': ['GPS', 'GLONASS', 'Galileo', 'BeiDou', 'QZSS', 'NavIC'], 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP64', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.99 mm', 'Trọng lượng': '190g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'Mở khóa khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': ['Google Gemini', 'Xoá AI', 'AI Sky', 'làm đẹp AI'], 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip MediaTek Dimensity 7025 - Ultra)', 'Danh sách tính năng AI thực tế': 'Google Gemini, Xoá AI, AI Sky, làm đẹp AI, Night Mode, Portrait, Clean Up', 'AI Score tổng hợp': '4'},
    {'name': 'Xiaomi Redmi Note 15 Pro 12GB 256GB', 'sku': 'dien-thoai-xiaomi-redmi-note-15-pro', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '14 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Xiaomi HyperOS 2', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '200MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '2x/4x', 'Quay video camera sau': '1080p 30fps & 60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.77 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3200 nits', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '1080 x 2392 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G200-Ultra', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Xiaomi HyperOS 2', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6500mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '2.4GHz | 5GHz', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '1 SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP65', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.96 mm', 'Trọng lượng': '195g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Google Gemini, Khoanh tròn tìm kiếm Google, Trợ lý sáng tạo AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Khoanh tròn tìm kiếm Google, Trợ lý sáng tạo AI, Gemini trợ hỏi đáp', 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi POCO F8 Pro 5G 12GB 256GB', 'sku': 'dien-thoai-poco-f8-pro-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'POCO', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Xiaomi HyperOS 3', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.88', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '8K 30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '20MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': '1080p 30/60fps', 'Tính năng AI camera': 'Chụp động, Ghi hình chuyển động, Tài liệu, Lấy nét theo chuyển động, Chân dung, Pro, 50MP, Siêu macro, Chụp liên tục 2.0, Tele tầm xa thích ứng, Chụp bằng giọng nói, Siêu trăng, HDR, Toàn cảnh, Phơi sáng lâu, ShootSteady, Theo dõi nguồn, Máy nhắc chữ vide', 'Kích thước màn hình': '6.59 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3500 nits', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2510 x 1156 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon® 8 Elite', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'A+', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno™', 'Hệ điều hành': 'Xiaomi HyperOS 3', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6210mAh', 'Sạc có dây': '100W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'có', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7', 'Bluetooth': 'v5.4', 'GPS': 'Beidou, GPS, Galileo, GLONASS, QZSS, NavIC, AGNSS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano SIM hoặc 2 eSIM hoặc 1 Nano SIM + 1 eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': '8 mm', 'Trọng lượng': '199g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Hi-Res, Hi-Res Audio Wireless, Dolby Atmos®, Âm thanh bởi Bose', 'Hỗ trợ AI': 'Điện thoại AI'},
    {'name': 'Xiaomi Redmi Note 15 Pro 5G 12GB 256GB', 'sku': 'dien-thoai-xiaomi-redmi-note-15-pro-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Xiaomi HyperOS 2', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '200MP', 'Aperture camera chính': 'f/1.7', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K ở 30 fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '20MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': '1080p ở 30/60 fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.8', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3200 nits', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2772 x 1280', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Dimensity 7400-Ultra', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Mali-G615', 'Hệ điều hành': 'Xiaomi HyperOS 2', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6580mAh(typ)', 'Sạc có dây': '45W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6/6E/7 (ax)', 'Bluetooth': '5.4', 'GPS': 'GPS, GLONASS, BDS, Galileo, QZSS', 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano SIM hoặc 1 Nano + 1 eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP66, IP68, IP69, IP69K', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.96 mm', 'Trọng lượng': '210 gram', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Dolby Atmos', 'Hỗ trợ AI': 'Điện thoại AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Chip tầm trung)', 'Danh sách tính năng AI thực tế': ['Night Mode', 'Portrait', 'Clean Up', 'AI Portrait', 'Film Filter', 'Watermark', 'Super Night', 'Document Mode', 'EIS', 'Gemini Live', 'Tạo hình ảnh AI', 'AI hỗ trợ xóa phản chiếu', 'Nâng cấp ảnh chụp AI'], 'AI Score tổng hợp': '4'},
    {'name': 'Xiaomi Redmi 15 5G 8GB 256GB', 'sku': 'dien-thoai-xiaomi-redmi-15-5g-8gb-256gb', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Xiaomi HyperOS 2', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8MP', 'Aperture camera trước': 'f/2.05', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'HDR, Chụp đêm, Chụp chân dung, Time-lapse, Chế độ phim, Vòng sáng mềm', 'Kích thước màn hình': '6.9 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': 'Từ 144Hz trở lên', 'Độ sáng tối đa': '850 nits (HBM)', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2340 x 1080', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon® 6s Gen 3', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno', 'Hệ điều hành': 'Xiaomi HyperOS 2', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '7000mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': '5GHz', 'Bluetooth': 'v5.4 (hỗ trợ AAC, SBC, LDAC)', 'GPS': 'GPS, Glonass, Galileo, Beidou', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP64', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.4 mm', 'Trọng lượng': '217g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Hi-Res Audio, Dolby Atmos®', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'HDR, Chụp đêm, Chụp chân dung, Time-lapse, Chế độ phim, Vòng sáng mềm, Nhận diện khung cảnh, tối ưu màu sắc và cân bằng trắng, Circle to Search', 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi Redmi Note 15 5G 6GB 128GB', 'sku': 'dien-thoai-xiaomi-redmi-note-15-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Xiaomi HyperOS 2', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '108MP', 'Aperture camera chính': 'ƒ/1.7', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '3x', 'Quay video camera sau': '4K@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '20MP', 'Aperture camera trước': 'ƒ/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'AI Google Gemini, Khoanh tròn tìm kiếm Google, Công cụ chỉnh sửa ảnh AI', 'Kích thước màn hình': '6.77 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3200 nits', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ', 'Độ phân giải màn hình': '1080 x 2392', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon® 6 Gen 3', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Snapdragon® 6 Gen 3', 'Hệ điều hành': 'Xiaomi HyperOS 2', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5520mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': '2.4GHz / 5GHz', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'N/A', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP66', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.35 mm', 'Trọng lượng': '178g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Dolby Atmos, Hi-Res', 'Hỗ trợ AI': 'AI Google Gemini, Khoanh tròn tìm kiếm Google, Công cụ chỉnh sửa ảnh AI', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Xiaomi mid) (Ước lượng)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Chip tầm trung)', 'Danh sách tính năng AI thực tế': ['AI Google Gemini', 'Khoanh tròn tìm kiếm Google', 'Công cụ chỉnh sửa ảnh AI', 'Chống rung quang học OIS'], 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi Redmi 15C 4GB 128GB NFC', 'sku': 'dien-thoai-xiaomi-redmi-15c', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'HarmonyOS', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Xiaomi HyperOS 2', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'HDR, Chụp đêm, Chụp chân dung, Time-lapse, Chế độ phim', 'Kích thước màn hình': '6.9 inches', 'Công nghệ màn hình': 'LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '810 nits (HBM)', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '1600 x 720 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G81-Ultra', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G52 MC2', 'Hệ điều hành': 'Xiaomi HyperOS 2', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6000mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'có', 'Mạng di động': '4G LTE', 'Wi-Fi': '2.4GHz / 5GHz', 'Bluetooth': 'v5.4 (hỗ trợ AAC, SBC, LDAC)', 'GPS': 'GPS, Glonass, Galileo, Beidou', 'NFC': 'có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP64', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.99 mm', 'Trọng lượng': '205g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Do là Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (HyperOS)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Đáp ứng được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Cloud (Dựa trên thương hiệu và chip MediaTek Helio G81-Ultra)', 'Danh sách tính năng AI thực tế': 'HDR, Chụp đêm, Chụp chân dung, Time-lapse, Chế độ phim, Chế độ Ultra HD, Chế độ chân dung, Chế độ làm đẹp selfie', 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi Redmi A7 Pro 4GB 128GB', 'sku': 'dien-thoai-xiaomi-redmi-a7-pro', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 16', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '13MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.9 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc T7250', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Android 16', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '6000 mAh', 'Sạc có dây': '15W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': 'N/A', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'N/A', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': 'N/A', 'Trọng lượng': 'N/A', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%) (Xiaomi/Mid-range)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (HyperOS)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '4 4K@60fps ổn định tốt', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Unisoc T7250 và thương hiệu Xiaomi)', 'Danh sách tính năng AI thực tế': ['Night Mode'], 'AI Score tổng hợp': '2'},
    {'name': 'Xiaomi POCO X7 5G 12GB 512GB', 'sku': 'dien-thoai-xiaomi-poco-x7-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'HarmonyOS', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Xiaomi HyperOS', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.5', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@24/30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '20MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': '1080p@30/60fps', 'Tính năng AI camera': 'Chế độ ban đêm, AI làm đẹp, Chế độ chân dung, Tập trung theo dõi chuyển động', 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '500 nits', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'Kính Corning® Gorilla® Victus® 2', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2712 x 1220', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Powerful Dimensity 7300-Ultra', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Mali-G615 MC2', 'Hệ điều hành': 'Xiaomi HyperOS', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5110mAh', 'Sạc có dây': '45W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': 'v5.4', 'GPS': 'Beidou, GPS, Galileo, GLONASS, QZSS, A-GPS', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.4 mm', 'Trọng lượng': '185.5g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép, Dolby Atmos', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '4', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '4', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Night Mode, Portrait, Clean Up, Chế độ ban đêm, AI làm đẹp, Chế độ chân dung, Tập trung theo dõi chuyển động', 'AI Score tổng hợp': '4'},
    {'name': 'Xiaomi Redmi Note 13 Pro Plus 5G 8GB 256GB', 'sku': 'xiaomi-redmi-note-13-pro-plus', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '200 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@2160p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': '1080p@30/60fps', 'Tính năng AI camera': ['Làm đẹp A.I'], 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1220 x 2712', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Mediatek Dimensity 7200 Ultra (4 nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Mali-G610 MC4', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '120W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 802.11 a/b/g/n/ac', 'Bluetooth': '5.2', 'GPS': ['BEIDOU', 'QZSS', 'GPS', 'GLONASS', 'GALILEO'], 'NFC': 'có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'Không', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '8.9 mm', 'Trọng lượng': '204.5 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa âm thanh nổi', 'Hỗ trợ AI': ['Bảo mật vân tay', 'Nhận diện khuôn mặt'], 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) Lý do: Xiaomi/OPPO/Vivo', 'Số năm OS update': '3 năm Lý do: Xiaomi mid', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud Lý do: Các hãng khác hoặc chip tầm trung', 'Danh sách tính năng AI thực tế': 'Làm đẹp A.I, Bảo mật vân tay, Nhận diện khuôn mặt', 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi 14T Pro 12GB 512GB', 'sku': 'xiaomi-14t-pro', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'ƒ/1 6', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'ƒ/2,0', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Night Mode, AI Portrait, Clean Up, ProRAW', 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': 'Từ 144Hz trở lên', 'Độ sáng tối đa': '4000 nits', 'Chất lượng màu': 'HDR10+, Dolby Vision®', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1220 x 2712', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Dimensity 9300+', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Immortalis-G720 MC12', 'Hệ điều hành': 'HyperOS', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '120W', 'Sạc không dây': '50W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7', 'Bluetooth': 'v5.4', 'GPS': 'N/A', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Sim kép (nano-Sim và e-Sim) - Hỗ trợ 2 e-Sim', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP686', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'Hợp kim', 'Độ mỏng': '8,39 mm', 'Trọng lượng': '209g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Dolby Atmos', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '4 năm (Xiaomi flagship)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': ['ghi chú thông minh', 'chỉnh sửa ảnh', 'chú thích và dịch thuật tức thì', 'Google Gemini', 'Circle to Search', 'Night Mode', 'AI Portrait', 'Clean Up', 'ProRAW'], 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi 15 5G 12GB 256GB', 'sku': 'dien-thoai-xiaomi-15', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Xiaomi HyperOS 2', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'ƒ/1.62', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@24/30/60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'ƒ/2.0', 'Quay video camera trước': '4K@30/60fps', 'Tính năng AI camera': 'HDR, Chụp ảnh động, Chế độ ban đêm, Chế độ chân dung, Super macro, Toàn cảnh, Chuyển động chậm, Chuyển động nhanh, Quay đêm Ultra Night Video, Chụp ảnh bằng giọng nói', 'Kích thước màn hình': '6.36 inches', 'Công nghệ màn hình': 'CrystalRes AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3200 nits', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2670 x 1200', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 8 Elite (Tiến trình sản xuất 3nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Adreno GPU', 'Hệ điều hành': 'Xiaomi HyperOS 2', 'Công nghệ tản nhiệt': 'Hệ thống cánh tản nhiệt Xiaomi IceLoop', 'Bypass charging': 'N/A', 'Dung lượng pin': '5240mAh', 'Sạc có dây': '90W', 'Sạc không dây': '50W', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7', 'Bluetooth': 'Bluetooth 6.0, Dual-Bluetooth', 'GPS': 'GPS: L1+L5, Galileo: E1+E5a, GLONASS: G1, Beidou, QZSS: L1 + L5, NavIC: L5', 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Sim kép (nano-Sim và e-Sim) - Hỗ trợ 2 e-Sim', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'Nhôm', 'Chất lượng khung viền': 'Nhôm', 'Độ mỏng': '8.08 mm', 'Trọng lượng': '191g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay siêu âm', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Dolby Atmos', 'Hỗ trợ AI': 'Xiaomi HyperAI, Viết AI, Nhận diện giọng nói AI, Phiên dịch AI, Khoanh vùng tìm kiếm AI, Trợ lý sáng tạo AI', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) Lý do: Xiaomi/OPPO/Vivo', 'Số năm OS update': '4 năm Lý do: Xiaomi flagship', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud Lý do: Các hãng khác hoặc chip tầm trung', 'Danh sách tính năng AI thực tế': 'HDR, Chụp ảnh động, Chế độ ban đêm, Chế độ chân dung, Super macro, Toàn cảnh, Chuyển động chậm, Chuyển động nhanh, Quay đêm Ultra Night Video, Chụp ảnh bằng giọng nói, Tối ưu độ sâu màu, tăng cường độ chi tiết, tạo hiệu ứng bokeh tự nhiên, Truy cập nhanh chóng, tiện lợi, Sáng tạo hình ảnh, AI Gallery Editor, Live Translation, Khoanh vùng tìm kiếm AI, Trợ lý sáng tạo AI', 'AI Score tổng hợp': '5'},
    {'name': 'Xiaomi Redmi 14C 4GB 128GB', 'sku': 'dien-thoai-xiaomi-redmi-14c', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080P (1920x1080) ở tốc độ 30 khung hình / giây', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '13MP', 'Aperture camera trước': 'f/2.0', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.88 inches', 'Công nghệ màn hình': 'N/A', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '600 nits (HBM)', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '720 x 1640 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G81-Ultra', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'HyperOS', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5160mAh', 'Sạc có dây': '18W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'N/A', 'Bluetooth': 'N/A', 'GPS': 'N/A', 'NFC': 'N/A', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.22 mm', 'Trọng lượng': '211g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': 'có', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng: Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Nhận diện khuôn mặt', 'AI Score tổng hợp': '2'},
    {'name': 'Xiaomi Redmi 13C 6GB 128GB', 'sku': 'xiaomi-redmi-13c', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Trôi nhanh thời gian, Zoom kỹ thuật số, Xóa phông, Tự động lấy nét (AF), Ban đêm, HDR, Siêu độ phân giải, Làm đẹp, Siêu cận, Google Lens, Bộ lọc màu, Chụp hẹn giờ', 'Kích thước màn hình': '6.74 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '600 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Kính cường lực Corning Gorilla Glass', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '720 x 1600 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G85 8 nhân', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G52 MC2', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '18 W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 802.11 a/b/g/n/ac', 'Bluetooth': 'v5.3', 'GPS': ['BEIDOU', 'GPS', 'GLONASS'], 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '78 mm', 'Trọng lượng': '192 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Trợ lý ảo Google Assistant', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%) (Lý do: Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (MIUI)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Cloud (Lý do: Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': ['Trôi nhanh thời gian', 'Zoom kỹ thuật số', 'Xóa phông', 'Tự động lấy nét (AF)', 'Ban đêm', 'HDR', 'Siêu độ phân giải', 'Làm đẹp', 'Siêu cận', 'Google Lens', 'Bộ lọc màu', 'Chụp hẹn giờ'], 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi Redmi Note 12 4GB 128GB', 'sku': 'xiaomi-redmi-note-12', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '13MP', 'Aperture camera trước': 'f/2.45', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'Chân dung, Toàn cảnh, Chế độ chuyên nghiệp, Chế độ ban đêm, Hình mờ tùy chỉnh, Chế độ tài liệu, HDR, Phát hiện cảnh AI, Bùng nổ thời gian, Google Ống kính, Hình mờ AI, Chế độ Video ngắn, Thời Gian Trôi Đi, khung phim, Video vĩ', 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1200nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning® Gorilla® Glass 3', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2400', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm Snapdragon 685', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Adreno™ 610', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'Graphit', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '802.11ac', 'Bluetooth': 'v5', 'GPS': 'GPS,GLONASS', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP53', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.85 mm', 'Trọng lượng': '183.5 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh viền', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Phát hiện cảnh AI, Hình mờ AI, Google Ống kính, Hình mờ AI', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%) (Xiaomi/Mid-range)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip Qualcomm Snapdragon 685)', 'Danh sách tính năng AI thực tế': 'Chân dung, Toàn cảnh, Chế độ chuyên nghiệp, Chế độ ban đêm, Hình mờ tùy chỉnh, Chế độ tài liệu, HDR, Phát hiện cảnh AI, Bùng nổ thời gian, Google Ống kính, Hình mờ AI, Phát hiện cảnh AI, Hình mờ AI', 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi POCO C71 4GB 128GB', 'sku': 'dien-thoai-xiaomi-poco-c71', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 15', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '32 MP', 'Aperture camera chính': 'f/1.8 (góc rộng)', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '8 MP', 'Aperture camera trước': 'f/2.0 (góc rộng)', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.88 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '450 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '720 x 1640 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Unisoc T7250 (12 nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G57 MP1', 'Hệ điều hành': 'Android 15, HyperOS', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5200 mAh', 'Sạc có dây': '15W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 802.11 a/b/g/n/ac, băng tần kép', 'Bluetooth': 'v5.2', 'GPS': 'GPS', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'không có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.3 mm', 'Trọng lượng': '193 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Đáp ứng được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Night Mode, Portrait, Clean Up', 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi POCO M6 6GB 128GB', 'sku': 'dien-thoai-xiaomi-poco-m6', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '108MP', 'Aperture camera chính': 'f/1,75', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '13MP', 'Aperture camera trước': 'f/2,45', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'Chế độ 108MP, Chế độ HDR, Chế độ ban đêm, Chế độ chân dung, Tua nhanh thời gian Xóa phông Vẫy tay chụp ảnh Trôi nhanh thời gian (Time Lapse), Quay video HD, Quay video Full HD, Làm đẹp', 'Kích thước màn hình': '6.79 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '450 nit', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '2460 x 1080', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Helio G91-Ultra', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G52 MC2', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5030 mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'Không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 2.4GHz | 5GHz', 'Bluetooth': 'v5.4', 'GPS': ['GPS', 'Glonass', 'Galileo', 'Beidou'], 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8,3 mm', 'Trọng lượng': '205 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'Trợ lý ảo Google Assistant', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Chế độ 108MP, Chế độ HDR, Chế độ ban đêm, Chế độ chân dung, Tua nhanh thời gian Xóa phông Vẫy tay chụp ảnh Trôi nhanh thời gian (Time Lapse), Quay video HD, Quay video Full HD, Làm đẹp, Trợ lý ảo Google Assistant', 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi Redmi Note 11 128GB', 'sku': 'xiaomi-redmi-note-11-128gb', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'MIUI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 11, MIUI 12.5', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'f/1.8', 'OIS / Chống rung': 'N/A', 'Zoom quang học': '10x', 'Quay video camera sau': '1080p 30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '13 MP', 'Aperture camera trước': 'f/2.5', 'Quay video camera trước': '1080p 30fps', 'Tính năng AI camera': ['Nhận dạng khuôn mặt', 'HDR', 'Máy ảnh AI 5.0', 'Làm đẹp AI'], 'Kích thước màn hình': '6.43 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '90Hz', 'Độ sáng tối đa': '1000 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning Gorilla Glass 3', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2400', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 680 8 nhân', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '4 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Adreno 610', 'Hệ điều hành': 'Android 11, MIUI 12.5', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct, hotspot', 'Bluetooth': '5.0', 'GPS': ['A-GPS', 'GLONASS', 'GALILEO', 'BDS'], 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP53', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.09 mm', 'Trọng lượng': '179 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'loa kép', 'Hỗ trợ AI': ['Máy ảnh AI 5.0', 'Làm đẹp AI'], 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '4', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Nhận dạng khuôn mặt, HDR, Máy ảnh AI 5.0, Làm đẹp AI, Máy ảnh AI 5.0, Làm đẹp AI', 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi Redmi Note 11S', 'sku': 'xiaomi-redmi-note-11s', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'MIUI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 11', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '108MP', 'Aperture camera chính': 'f/1.9', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p 1920x1080 | 30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16MP', 'Aperture camera trước': 'f/2.4', 'Quay video camera trước': '1080p 1920x1080 | 30fps', 'Tính năng AI camera': ['Ban đêm (Night Mode)', 'AI Camera', 'Google Lens', 'Siêu cận (Macro)', 'Xóa phông'], 'Kích thước màn hình': '6.43 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '90Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2400', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G96CPU', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'ARM Mali-G57 MC2', 'Hệ điều hành': 'MIUI 13, Android 11', 'Công nghệ tản nhiệt': 'LiquidCool', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': '802.11ac', 'Bluetooth': '5.0', 'GPS': ['GPS L1', 'Glonass G1', 'BDS B1', 'Galileo E1'], 'NFC': 'có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'không có', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.09mm', 'Trọng lượng': '179g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép', 'Hỗ trợ AI': ['Night Mode', 'AI Camera', 'Google Lens', 'Siêu cận (Macro)', 'Xóa phông'], 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '2', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng từ Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Chấp nhận được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Ban đêm (Night Mode), AI Camera, Google Lens, Siêu cận (Macro), Xóa phông', 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi Redmi 9A', 'sku': 'xiaomi-redmi-9a', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'MIUI', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 10, MIUI 12', 'Số lượng camera sau (thật)': 1, 'Độ phân giải camera chính': '13MP', 'Aperture camera chính': 'ƒ/2.2', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '5MP', 'Aperture camera trước': 'ƒ/2.2', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.53 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': '60Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Giọt nước', 'Độ phân giải màn hình': '720 x 1600 pixel', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G25 (12 nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '2 GB', 'Bộ nhớ trong': '32 GB', 'GPU tier': 'PowerVR GE8320 (650 MHz)', 'Hệ điều hành': 'Android 10, MIUI 12', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '10W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G', 'Wi-Fi': 'Wi-Fi 802.11 b/g/n, hotspot', 'Bluetooth': '5.0, A2DP, LE', 'GPS': 'Yes, with A-GPS', 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'không có', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '9.0mm', 'Trọng lượng': '194g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Không', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Đối tượng)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên Xiaomi/Mid-range)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (MIUI)', 'Chất lượng ảnh ban ngày': '4 Rất tốt cho phân khúc', 'Chất lượng ảnh ban đêm': '3 Đáp ứng được, noise nhưng nhìn được', 'Chất lượng video thực tế': '3 4K@30fps đủ dùng, EIS chấp nhận', 'Chất lượng selfie thực tế': '4 Rất tốt ngày, ổn tối', 'AI on-device vs Cloud': 'Cloud (Dựa trên chip MediaTek Helio G25)', 'Danh sách tính năng AI thực tế': 'Night Mode, Portrait, Clean Up', 'AI Score tổng hợp': '4'},
    {'name': 'Xiaomi Redmi Note 9 Pro', 'sku': 'xiaomi-redmi-note-9-pro', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Qualcomm', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'MIUI', 'Màu sắc hỗ trợ': '0', 'Phiên bản OS ra mắt': 'Android 10.0; MIUI 11', 'Số lượng camera sau (thật)': '3', 'Độ phân giải camera chính': '64 MP', 'Aperture camera chính': 'f/1.9', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '2160p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16 MP', 'Aperture camera trước': 'f/2.5', 'Quay video camera trước': '1080p@30/120fps', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.66 inches', 'Công nghệ màn hình': 'IPS LCD', 'Tần số quét': 'N/A', 'Độ sáng tối đa': '450 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'Corning Gorilla Glass 5', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2400 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 720G (8 nm)', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6 GB', 'Bộ nhớ trong': '64 GB', 'GPU tier': 'Adreno 618', 'Hệ điều hành': 'Android 10.0; MIUI 11', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5020 mAh', 'Sạc có dây': '30W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 802.11 a/b/g/n/ac, dual-band, Wi-Fi Direct, hotspot', 'Bluetooth': '5.0', 'GPS': 'A-GPS, GLONASS, GALILEO, BDS, NavIC', 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'Kính', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.8 mm', 'Trọng lượng': '209 g', 'Số màu sắc': '0', 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'cạnh bên', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '3', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '2', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '4', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Lý do: Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Nguồn ước lượng: Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '3', 'AI on-device vs Cloud': 'Cloud (Lý do: Chip tầm trung)', 'Danh sách tính năng AI thực tế': 'N/A', 'AI Score tổng hợp': '1'},
    {'name': 'Xiaomi 17 Ultra 5G 16GB 512GB', 'sku': 'dien-thoai-xiaomi-17-ultra', 'Phân khúc giá': 'Cao cấp', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Android 16', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '200 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '8K', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '50 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.9 inches', 'Công nghệ màn hình': 'LTPO AMOLED', 'Tần số quét': '120Hz (LTPO)', 'Độ sáng tối đa': '3500 nits', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '2608 x 1200', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Qualcomm Snapdragon 8 Elite Gen 5', 'AnTuTu score': 3932243, 'Xếp loại chip': 'A+', 'RAM': '16 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Adreno 840', 'Hệ điều hành': 'Android 16 với HyperOS', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': '6000 mAh', 'Sạc có dây': '90W', 'Sạc không dây': '50W', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7', 'Bluetooth': 'v5.4', 'GPS': 'N/A', 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '8.5 mm', 'Trọng lượng': '230 g', 'Số màu sắc': 2, 'Điện thoại gập': 'không', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa stereo, Dolby Atmos', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '4', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '4', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '4', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '4 năm (Xiaomi flagship)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình (HyperOS)', 'Chất lượng ảnh ban ngày': '5', 'Chất lượng ảnh ban đêm': '4', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên thương hiệu và chip)', 'Danh sách tính năng AI thực tế': 'Night Mode, Portrait, Clean Up, Super XiaoAi', 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi 15T Pro 5G 12GB 512GB', 'sku': 'dien-thoai-xiaomi-15t-pro-5g', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'Xiaomi HyperOS 2', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'f/1.62', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': '5x', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.83 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '3200 nits', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': 'N/A', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Dimensity 9400+', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'N/A', 'Hệ điều hành': 'Xiaomi HyperOS 2', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'không', 'Dung lượng pin': '5500mAh', 'Sạc có dây': '90W', 'Sạc không dây': '50W', 'Sạc ngược': 'không', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 7', 'Bluetooth': 'N/A', 'GPS': 'GPS', 'NFC': 'N/A', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '1 SIM + eSIM', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.96 mm', 'Trọng lượng': '210g', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Bảo mật vân tay', 'Nhận diện khuôn mặt': 'Nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép, 3-Mic, Hi-Res & Hi-Res Audio Wireless, Dolby Atmos®', 'Hỗ trợ AI': 'Xiaomi HyperAI, Google Gemini, Xiaomi Call ngoại tuyến', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '4 năm (Ước lượng từ Xiaomi flagship)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': ['AI Search', 'AI Dynamic Wallpaper'], 'AI Score tổng hợp': '2'},
    {'name': 'Xiaomi Redmi Note 14 6GB 128GB', 'sku': 'dien-thoai-xiaomi-redmi-note-14', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 14', 'Số lượng camera sau (thật)': 2, 'Độ phân giải camera chính': '108MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'FullHD 1080p@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '20MP', 'Aperture camera trước': 'f/2.2', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': ['Google Gemini', 'Xóa vật thể AI', 'AI Sky', 'AI Beautify'], 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1800 nits đỉnh', 'Chất lượng màu': 'N/A', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2400', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G99-Ultra', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G57 MC2', 'Hệ điều hành': 'Android 14', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5500mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 802.11 a/b/g/n/ac', 'Bluetooth': '5.3', 'GPS': ['QZSS', 'GPS', 'GLONASS', 'GALILEO', 'BEIDOU'], 'NFC': 'có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': '2 Nano-SIM', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '8.16 mm', 'Trọng lượng': '196.5g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay dưới màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa kép\nDolby Atmos®', 'Hỗ trợ AI': ['Google Gemini', 'Xóa vật thể AI', 'AI Sky', 'AI Beautify'], 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '3', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Dựa trên Chip MediaTek Helio G99-Ultra và thương hiệu Xiaomi)', 'Danh sách tính năng AI thực tế': ['Google Gemini', 'Xóa vật thể AI', 'AI Sky', 'AI Beautify'], 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi 14T 12GB 512GB', 'sku': 'xiaomi-14t', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 2, 'Phiên bản OS ra mắt': 'N/A', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50MP', 'Aperture camera chính': 'ƒ/1', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'N/A', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '32MP', 'Aperture camera trước': 'ƒ/2.0', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'Google Gemini, Phiên dịch AI, Ghi chú AI', 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': 'Từ 144Hz trở lên', 'Độ sáng tối đa': '4000 nits', 'Chất lượng màu': 'HDR10+, Dolby Vision', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1220 x 2712 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Dimensity 8300-Ultra', 'AnTuTu score': 1609292, 'Xếp loại chip': 'B', 'RAM': '12 GB', 'Bộ nhớ trong': '512 GB', 'GPU tier': 'Arm Mali-G615 MC6', 'Hệ điều hành': 'HyperOS', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '67W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6E', 'Bluetooth': 'v5.4', 'GPS': 'N/A', 'NFC': 'Có', 'Jack 3.5mm': 'N/A', 'Hỗ trợ SIM': 'Sim kép (nano-Sim và e-Sim) - Hỗ trợ 2 e-Sim', 'eSIM': 'có', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'N/A', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.80 mm', 'Trọng lượng': '195 gram', 'Số màu sắc': 2, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'N/A', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Dolby Atmos, Loa âm thanh nổi', 'Hỗ trợ AI': 'Google Gemini, Phiên dịch AI, Ghi chú AI', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '1', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Dựa trên thương hiệu Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (ColorOS/HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Do sử dụng chip MediaTek Dimensity và các tính năng AI được liệt kê không ám chỉ xử lý trên chip cấp cao)', 'Danh sách tính năng AI thực tế': ['Circle to Search', 'Trình thông dịch AI', 'Phim AI', 'Chỉnh sửa ảnh AI', 'Bộ công cụ nâng cao năng suất', 'Google Gemini', 'Phiên dịch AI', 'Ghi chú AI'], 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi Redmi Note 13 Pro 4G 8GB 128GB', 'sku': 'xiaomi-redmi-note-13-pro', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '200 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'OIS quang học', 'Zoom quang học': 'N/A', 'Quay video camera sau': 'FullHD 1080p@60/30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16 MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': '1080p@30/60fps', 'Tính năng AI camera': ['Làm đẹp A.I'], 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': '1300 nits', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'Corning Gorilla Glass 5', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2400 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Helio G99-Ultra 8 nhân', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '8 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Mali-G57 MC2', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '67 W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 802.11 a/b/g/n/ac', 'Bluetooth': 'v5.2', 'GPS': ['GPS (L1)', 'GLONASS (G1)', 'BDS (B1I+B1c)', 'GALILEO (E1)', 'QZSS (L1)'], 'NFC': 'Có', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'microSDXC', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'Nhựa', 'Chất lượng khung viền': 'Nhựa', 'Độ mỏng': '7.98 mm', 'Trọng lượng': '188 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Loa âm thanh nổi, Dolby Atmos, Loa kép', 'Hỗ trợ AI': [], 'Tên thuộc tính': 'Giá trị', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '3', 'Văn phòng (Use Case)': '4', 'Mạng xã hội (Use Case)': '4', 'Học tập (Đối tượng)': '3', 'Kinh doanh (Đối tượng)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '3', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) (Xiaomi/OPPO/Vivo)', 'Số năm OS update': '3 năm (Ước lượng dựa trên Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': ['Làm đẹp A.I', 'Night Mode', 'Clean Up'], 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi Redmi Note 13 6GB 128GB', 'sku': 'xiaomi-redmi-note-13', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '108 MP', 'Aperture camera chính': 'N/A', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '1080p@30fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '16MP', 'Aperture camera trước': 'N/A', 'Quay video camera trước': 'N/A', 'Tính năng AI camera': 'N/A', 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': '120Hz', 'Độ sáng tối đa': 'N/A', 'Chất lượng màu': 'DCI-P3', 'Kính bảo vệ màn hình': 'N/A', 'Kiểu màn hình / Notch': 'Đục lỗ (Nốt ruồi)', 'Độ phân giải màn hình': '1080 x 2400 pixels', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'Snapdragon 685', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '6 GB', 'Bộ nhớ trong': '128 GB', 'GPU tier': 'Adreno 610', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'N/A', 'Bypass charging': 'N/A', 'Dung lượng pin': '5000 mAh', 'Sạc có dây': '33W', 'Sạc không dây': 'không hỗ trợ', 'Sạc ngược': 'N/A', 'Mạng di động': '4G LTE', 'Wi-Fi': 'Wi-Fi 802.11 a/b/g/n/ac', 'Bluetooth': '5.1', 'GPS': ['BEIDOU', 'GPS', 'GLONASS', 'GALILEO'], 'NFC': 'Không', 'Jack 3.5mm': 'Có', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP54', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'N/A', 'Độ mỏng': '7.97 mm', 'Trọng lượng': '188.5 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': '2D nhận diện khuôn mặt', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'N/A', 'Hỗ trợ AI': 'N/A', 'Phụ kiện trong hộp': 'N/A', 'Action Button': 'N/A', 'Camera Button': 'N/A', 'Desktop Mode / DeX': 'N/A', 'Nút SOS / khẩn cấp': 'N/A', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '3', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '3', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '3', 'Freelancer (Đối tượng)': '3', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '3', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Trung bình (~30-45%) (Xiaomi/mid)', 'Số năm OS update': '3 năm (Ước lượng: Xiaomi mid)', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo (HyperOS)', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '3', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud (Các hãng khác hoặc chip tầm trung)', 'Danh sách tính năng AI thực tế': 'Zoom kỹ, Night Mode, Clean Up', 'AI Score tổng hợp': '3'},
    {'name': 'Xiaomi 13T 12GB 256GB', 'sku': 'xiaomi-13t', 'Phân khúc giá': 'Trung bình', 'Tuổi đời': '8 tháng', 'Hệ sinh thái': 'Android', 'Thương hiệu': 'Xiaomi', 'Xuất xứ': 'Trung Quốc', 'Giao diện OS': 'HyperOS', 'Màu sắc hỗ trợ': 3, 'Phiên bản OS ra mắt': 'Android 13', 'Số lượng camera sau (thật)': 3, 'Độ phân giải camera chính': '50 MP', 'Aperture camera chính': 'f/1,9', 'OIS / Chống rung': 'N/A', 'Zoom quang học': 'N/A', 'Quay video camera sau': '4K@60fps', 'Chất lượng kính lens camera': 'N/A', 'Độ phân giải camera trước': '20 MP', 'Aperture camera trước': 'f/2,2', 'Quay video camera trước': '1080p@30fps', 'Tính năng AI camera': 'Trôi nhanh thời gian (Time Lapse), Góc siêu rộng (Ultrawide), Zoom kỹ thuật số, Xiaomi ProCut, Quét tài liệu, Quay chậm (Slow Motion), Xóa phông, Toàn cảnh (Panorama)', 'Kích thước màn hình': '6.67 inches', 'Công nghệ màn hình': 'AMOLED', 'Tần số quét': 'Từ 144Hz trở lên', 'Độ sáng tối đa': '2600 nits', 'Chất lượng màu': 'Dolby Vision', 'Kính bảo vệ màn hình': 'Kính cường lực Corning Gorilla Glass 5', 'Kiểu màn hình / Notch': 'N/A', 'Độ phân giải màn hình': '1220 x 2712', 'Hỗ trợ bút stylus': 'N/A', 'Chip tier': 'MediaTek Dimensity 8200-Ultra', 'AnTuTu score': 'N/A', 'Xếp loại chip': 'N/A', 'RAM': '12 GB', 'Bộ nhớ trong': '256 GB', 'GPU tier': 'Mali-G610', 'Hệ điều hành': 'Android 13', 'Công nghệ tản nhiệt': 'LiquidCool', 'Bypass charging': 'N/A', 'Dung lượng pin': '5.000 mAh', 'Sạc có dây': '67 W', 'Sạc không dây': 'N/A', 'Sạc ngược': 'N/A', 'Mạng di động': '5G', 'Wi-Fi': 'Wi-Fi 6', 'Bluetooth': 'v5.4', 'GPS': 'GPS (L1+L5), GLONASS (G1), BDS (B1I+B1c+B2a), GALILEO (E1+E5a), QZSS (L1+L5), NavIC (L5)', 'NFC': 'Có', 'Jack 3.5mm': 'Không', 'Hỗ trợ SIM': '2 SIM (Nano-SIM)', 'eSIM': 'N/A', 'Hỗ trợ thẻ nhớ': 'N/A', 'Kháng nước / bụi': 'IP68', 'Chất lượng mặt lưng': 'N/A', 'Chất lượng khung viền': 'Kim loại', 'Độ mỏng': '8.49 mm', 'Trọng lượng': '197 g', 'Số màu sắc': 3, 'Điện thoại gập': 'không gập', 'Cảm biến vân tay': 'Cảm biến vân tay trong màn hình', 'Nhận diện khuôn mặt': 'N/A', 'Mật khẩu / PIN': 'Có', 'Công nghệ âm thanh': 'Âm thanh Dolby Atmos, Âm thanh Hi-Res Audio, Loa kép', 'Hỗ trợ AI': 'Trợ lý ảo Google Assistant', 'Gaming (Use Case)': '3', 'Camera / Creator (Use Case)': '4', 'Văn phòng (Use Case)': '5', 'Mạng xã hội (Use Case)': '4', 'Học tập (Use Case)': '4', 'Kinh doanh (Use Case)': '3', 'Thể thao / Outdoor (Use Case)': '3', 'Học sinh cấp 3 (Đối tượng)': '4', 'Sinh viên (Đối tượng)': '4', 'Dân văn phòng (Đối tượng)': '4', 'Freelancer (Đối tượng)': '4', 'Gamer (Đối tượng)': '3', 'Nhiếp ảnh gia (Đối tượng)': '4', 'Người lớn tuổi (Đối tượng)': '3', 'Doanh nhân (Đối tượng)': '3', 'Thời gian sạc thực tế (phút)': 'Không đề cập', 'Pin thực tế (giờ)': 'Không đề cập', 'Điểm giữ giá': 'Thấp-Trung bình (~30-45%) Lý do: Xiaomi/OPPO/Vivo', 'Số năm OS update': '4 năm Lý do: Xiaomi flagship', 'Chất lượng phần mềm / ít bloatware': 'Trung bình - có quảng cáo', 'Chất lượng ảnh ban ngày': '4', 'Chất lượng ảnh ban đêm': '3', 'Chất lượng video thực tế': '4', 'Chất lượng selfie thực tế': '4', 'AI on-device vs Cloud': 'Cloud Lý do: Các hãng khác hoặc chip tầm trung', 'Danh sách tính năng AI thực tế': ['Trôi nhanh thời gian (Time Lapse)', 'Góc siêu rộng (Ultrawide)', 'Zoom kỹ thuật số', 'Xiaomi ProCut', 'Quét tài liệu', 'Quay chậm (Slow Motion)', 'Xóa phông', 'Toàn cảnh (Panorama)', 'Trợ lý ảo Google Assistant'], 'AI Score tổng hợp': '3'},
]

# %% [markdown]
# ### Laptop data

# %%
raw_data = [
    {'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7535HS (6 lõi / 12 luồng, Base Clock: 3.3 GHz, Max. Boost Clock: Up to 4.55 GHz, 3MB L2 Cache; 16MB L3 Cache)'}, {'name': 'Mô tả CPU', 'value': '6 lõi / 12 luồng, Base Clock: 3.3 GHz, Max. Boost Clock: Up to 4.55 GHz, 3MB L2 Cache; 16MB L3 Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050'}, {'name': 'Mô tả card đồ họa', 'value': '6 GB VRAM GDDR6 chuyên dụng, hỗ trợ 2560 lõi NVIDIA CUDA'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Up to 4800 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Up to 4TB PCIe Gen4 NVMe SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '180 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'LCD TFT đèn nền LED Acer ComfyView, Góc nhìn rộng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 3x USB-A, 1x Cổng HDMI 2.1 hỗ trợ HDCP, 1x Giắc cắm tai nghe/loa 3.5 mm, 1x Ethernet (RJ-45), 1x Giắc cắm DC-in cho bộ đổi nguồn AC'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'Có'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '362.3 x 239.89 x 23.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-ion 4 cell 57Whr'}, {'name': 'Sạc nhanh', 'value': 'Bộ đổi nguồn AC 135W'}, {'name': 'Loại sạc', 'value': 'Bộ đổi nguồn AC 135W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS X:Ultra Audio, DAC SNR, Công nghệ Acer Purified.Voice, Tương thích với Cortana bằng giọng nói, Công nghệ Acer TrueHarmony'}, {'name': 'Webcam', 'value': 'Video HD 720p ở tốc độ 30 khung hình/giây với tính năng Giảm nhiễu theo thời gian'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Có (Đơn sắc - Trắng)'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Giải pháp Mô-đun nền tảng đáng tin cậy (TPM) phần sụn Người dùng BIOS, mật khẩu giám sát, khe khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 6600H (6 lõi / 12 luồng, 3.30 GHz - 4.50 GHz, 3 MB L2 cache, up to 16 MB L3 cache)'}, {'name': 'Mô tả CPU', 'value': '6 lõi / 12 luồng, xung nhịp từ 3.30 GHz đến 4.50 GHz, 3 MB L2 cache, up to 16 MB L3 cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050'}, {'name': 'Mô tả card đồ họa', 'value': '6GB GDDR6 VRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 4800MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 96GB (cắm sẵn 16GB))'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB (có 1 khe trống hoặc khả năng thay thế)'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Up to 4TB PCIe Gen4 NVMe SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45%'}, {'name': 'Công nghệ màn hình', 'value': 'Acer ComfyView'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB Type-C (USB4 40Gbps, DisplayPort, sạc 5V–3A, DC-in 20V–65W), 3 x USB Type-A 3.2 Gen 1 (1 cổng hỗ trợ sạc khi tắt máy), 1 x HDMI 2.1 (HDCP), 1 x Jack tai nghe/loa 3.5 mm tích hợp micrô, 1 x Ethernet RJ-45, 1 x Cổng nguồn DC-in'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '362.3 x 239.89 x 23.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '57Whr 4-cell, Adapter: 135W AC adapter'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'Adapter 135W AC adapter'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS X:Ultra, Hỗ trợ âm thanh không gian Windows cho game PC, DAC SNR cao với đầu ra 2.1 Vrms, điều khiển tai nghe lên đến 600 ohm, Acer Purified.Voice giảm tiếng ồn AI, Tương thích Cortana, Công nghệ Acer TrueHarmony'}, {'name': 'Webcam', 'value': '720p HD'}, {'name': 'Micro', 'value': 'Jack tai nghe/loa 3.5 mm tích hợp micrô'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Giải pháp TPM dạng firmware, Mật khẩu BIOS người dùng và quản trị viên, Khe khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i3-1305U (5 lõi / 6 luồng, 3.3 GHz, 4.5 GHz, 10 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i3-1305U, 5 lõi / 6 luồng, xung nhịp 3.3 GHz, tối đa 4.5 GHz, 10 MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Up to 4800 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 8GB), Nâng cấp tối đa 64GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '256GB PCIe NVMe SSD (nâng cấp tối đa 2TB SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 3x USB-A, Đầu đọc thẻ MicroSD, HDMI 1.4 hỗ trợ HDCP, Giắc cắm tai nghe/loa 3.5 mm'}, {'name': 'Wi-Fi', 'value': 'Intel Wireless Wi-Fi 6 AX201'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa và kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa và kim loại'}, {'name': 'Kích thước', 'value': '313.3 x 218 x 16.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.5 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-ion 3 cell 58Wh'}, {'name': 'Sạc nhanh', 'value': '65W PD Type C'}, {'name': 'Loại sạc', 'value': 'Bộ chuyển đổi 65W PD Type C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hai loa stereo tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD'}, {'name': 'Micro', 'value': 'Hai micrô kỹ thuật số tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Copilot Key'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'BIOS user, supervisor, SSD passwords, Kensington lock slot'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-12650H (10 lõi / 16 luồng, Turbo tối đa E-core: 3.5 GHz, P-core: 4.7 GHz)'}, {'name': 'Mô tả CPU', 'value': '10 lõi / 16 luồng'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6 GB'}, {'name': 'Mô tả card đồ họa', 'value': 'Supporting 2560 NVIDIA CUDA Cores'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Nâng cấp tối đa 4TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Acer ComfyView, Độ sáng 250nits, Độ phủ màu 45% NTSC, Góc nhìn rộng lên đến 170 độ, Thiết kế siêu mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB Type-C: 2 cổng, USB Standard-A: 2 cổng, HDMI: 1 cổng (2.1 hỗ trợ HDCP), Ethernet (RJ-45): 1 cổng, USB-A: 2 cổng, 3.5mm: Có, Mini DisplayPort: 1 cổng, Khe đọc thẻ nhớ: Có'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'N/A'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.5 x 238 x 22.7 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.99 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-ion 3 cell 54,8Wh'}, {'name': 'Sạc nhanh', 'value': 'Bộ đổi nguồn AC 150W'}, {'name': 'Loại sạc', 'value': 'Bộ đổi nguồn AC 150W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hai loa stereo tích hợp'}, {'name': 'Webcam', 'value': '720p HD'}, {'name': 'Micro', 'value': 'Hai micrô kỹ thuật số tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Một vùng, 15 màu'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Người dùng BIOS, giám sát viên'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Viền màn hình siêu mỏng'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 6600H (6 lõi / 12 luồng, 3.3 GHz - 4.5 GHz / 3 MB L2 cache, up to 16 MB L3 cache)'}, {'name': 'Mô tả CPU', 'value': '6 lõi / 12 luồng, xung nhịp từ 3.3 GHz đến 4.5 GHz, 3 MB L2 cache, up to 16 MB L3 cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050 6 GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'Hỗ trợ 2560 NVIDIA CUDA Cores, VRAM 6 GB GDDR6'}, {'name': 'Bộ xử lý AI / NPU', 'value': '194 TOPs'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 4800MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (nâng cấp tối đa 4 TB SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45%'}, {'name': 'Công nghệ màn hình', 'value': 'LCD TFT đèn nền LED Acer ComfyView, Độ sáng 300nits'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C (40Gbps / DisplayPort / sạc), 3x USB-A, 1x Cổng HDMI 2.1 hỗ trợ HDCP, 1x Giắc cắm tai nghe/loa 3.5 mm, 1x Cổng Ethernet (RJ-45), 1x Giắc cắm DC-in cho bộ đổi nguồn AC'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '362.3 x 239.89 x 23.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '57Whr 4-cell, 135W 5.5PHY Adapter'}, {'name': 'Sạc nhanh', 'value': '135W'}, {'name': 'Loại sạc', 'value': '5.5PHY Adapter'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS X:Ultra Audio, Hỗ trợ Windows Spatial Sound cho PC Gaming, Công nghệ Acer Purified.Voice, Công nghệ Acer TrueHarmony'}, {'name': 'Webcam', 'value': '720p HD'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Có'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware Trusted Platform Module (TPM) solution, BIOS user, supervisor passwords, Kensington lock slot'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H (8 lõi / 12 luồng, Turbo max 3.4 GHz E-core / 4.6 GHz P-core, 12 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': '8 lõi / 12 luồng'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050'}, {'name': 'Mô tả card đồ họa', 'value': '6 GB VRAM GDDR6 chuyên dụng, hỗ trợ 2560 lõi NVIDIA CUDA'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Up to 4800 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 8GB Onboard + 1 x 8GB rời, nâng cấp lên tối đa 56GB (8GB Onboard + 48GB 1 thanh RAM rời))'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 56GB'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Nâng cấp tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45%'}, {'name': 'Công nghệ màn hình', 'value': 'Acer ComfyView LED-backlit TFT LCD, Góc nhìn rộng lên đến 170 độ'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 2x USB-A, Giắc cắm tai nghe/loa 3.5 mm, Cổng HDMI 2.1, Cổng Ethernet (RJ-45)'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '362.2 x 248.47 x 22.9/22.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.95 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-ion 3 cell 53Wh'}, {'name': 'Sạc nhanh', 'value': 'Bộ chuyển đổi TypeC 100W'}, {'name': 'Loại sạc', 'value': 'Type-C 100W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hai loa stereo tích hợp'}, {'name': 'Webcam', 'value': 'FHD Camera MISC 2M FHD Camera_CTE'}, {'name': 'Micro', 'value': 'Hai micrô kỹ thuật số tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đơn sắc - Trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Người dùng BIOS, mật khẩu giám sát, Khe khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7 Raptor Lake - 1355U (10 lõi / 12 luồng, 1.7GHz, Turbo Boost 5.0 GHz)'}, {'name': 'Mô tả CPU', 'value': '10 lõi / 12 luồng, 1.7GHz, Turbo Boost 5.0 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 4800 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 khe 16 GB + 1 khe rời, nâng cấp tối đa 64 GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64 GB'}, {'name': 'Ổ cứng', 'value': '512 GB SSD NVMe PCIe (Có thể tháo ra, lắp thanh khác tối đa 2 TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'LED Backlit, Acer ComfyView, Chống chói, Viền N/A, Cảm ứng N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Jack tai nghe 3.5 mm, 3 x USB 3.2, 1x HDMI, 1 x USB Type-C (hỗ trợ USB, Power Delivery và DisplayPort), Khe đọc thẻ nhớ'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '357.6 x 247 x 18.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.7 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell Li-ion, 58 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Stereo speakers'}, {'name': 'Webcam', 'value': 'Full HD Webcam'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7735HS (8 lõi / 16 luồng / Base Clock : 3.2 GHz / Max. Boost Clock : Up to 4.75 GHz / 4MB L2 Cache ; 16MB L3 Cache)'}, {'name': 'Mô tả CPU', 'value': '8 lõi / 16 luồng / Base Clock : 3.2 GHz / Max. Boost Clock : Up to 4.75 GHz / 4MB L2 Cache ; 16MB L3 Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'Hỗ trợ 2560 NVIDIA CUDA Cores, VRAM: 6GB GDDR6'}, {'name': 'Bộ xử lý AI / NPU', 'value': '194 TOPs'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Up to 4800 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Tối đa 4TB PCIe Gen4 NVMe SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '180 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'sRGB 100%'}, {'name': 'Công nghệ màn hình', 'value': 'LCD TFT đèn nền LED Acer ComfyView, Góc nhìn rộng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 3x USB Chuẩn A, 1x Cổng HDMI 2.1 hỗ trợ HDCP, 1x Giắc cắm tai nghe/loa 3.5 mm, 1x Cổng Ethernet (RJ-45), 1x Giắc cắm DC-in cho bộ đổi nguồn AC'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'Có'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '362.3 x 239.89 x 23.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '57Whr 4-cell Li-ion Battery, 135W AC Adapter'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': '135W AC Adapter'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS X:Ultra Audio, Hỗ trợ Windows Spatial Sound cho PC Gaming, DAC SNR, Công nghệ Acer Purified.Voice, Tương thích với Cortana bằng giọng nói, Công nghệ Acer TrueHarmony'}, {'name': 'Webcam', 'value': 'Video HD 720p ở tốc độ 30 khung hình/giây với tính năng Giảm nhiễu theo thời gian'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đơn sắc - Trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Giải pháp Mô-đun Nền tảng Tin cậy (TPM), Phần mềm Người dùng BIOS, mật khẩu giám sát, Khe khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7430U (6 lõi / 12 luồng, 4.3 GHz - 2.3 GHz, 16 MB L3 Cache)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 7430U (6 lõi / 12 luồng, 4.3 GHz - 2.3 GHz, 16 MB L3 Cache)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR4X Up to 4800MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '1TB PCIe NVMe SSD, Up to 2TB PCIe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Acer ComfyView LED-backlit TFT LCD'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB Type-C, 2x USB-A, Cổng HDMI 2.1 hỗ trợ HDCP, Giắc cắm tai nghe/loa 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E 802.11 a/b/g/n/ac/ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '321.71 x 211.72 x 15.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.25 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50Wh Li-ion, 65W Type-C adapter'}, {'name': 'Sạc nhanh', 'value': '65W Type-C adapter'}, {'name': 'Loại sạc', 'value': 'Type-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh DTS X:Ultra, Giọng nói tinh khiết của Acer, Cortana, Công nghệ Acer TrueHarmony, Hai loa âm thanh nổi tích hợp'}, {'name': 'Webcam', 'value': '1080p HD video at 60 fps'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đơn sắc - Trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'BIOS user, HDD password, Supervisor, Kensington lock'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7735HS (8 lõi / 16 luồng, Base Clock: 3.2 GHz, Max. Boost Clock: Up to 4.75 GHz, 4MB L2 Cache; 16MB L3 Cache)'}, {'name': 'Mô tả CPU', 'value': '8 lõi / 16 luồng, Base Clock: 3.2 GHz, Max. Boost Clock: Up to 4.75 GHz, 4MB L2 Cache; 16MB L3 Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050'}, {'name': 'Mô tả card đồ họa', 'value': '6 GB VRAM GDDR6 chuyên dụng, hỗ trợ 2560 lõi NVIDIA CUDA'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Up to 4800 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Up to 4TB PCIe Gen4 NVMe SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '180 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'LCD TFT đèn nền LED Acer ComfyView, Góc nhìn rộng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 3x USB-A, 1x Cổng HDMI 2.1 hỗ trợ HDCP, 1x Giắc cắm tai nghe/loa 3.5 mm, 1x Ethernet (RJ-45), 1x Giắc cắm DC-in cho bộ đổi nguồn AC'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'Có'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '362.3 x 239.89 x 23.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-ion 4 cell 57Whr'}, {'name': 'Sạc nhanh', 'value': 'Bộ đổi nguồn AC 135W'}, {'name': 'Loại sạc', 'value': 'Bộ đổi nguồn AC 135W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS X:Ultra Audio, DAC SNR, Công nghệ Acer Purified.Voice, Tương thích với Cortana bằng giọng nói, Công nghệ Acer TrueHarmony'}, {'name': 'Webcam', 'value': 'Video HD 720p ở tốc độ 30 khung hình/giây với tính năng Giảm nhiễu theo thời gian'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Có (Đơn sắc - Trắng)'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Giải pháp Mô-đun nền tảng đáng tin cậy (TPM) phần sụn Người dùng BIOS, mật khẩu giám sát, khe khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-1335U (10 lõi / 12 luồng, Tần số Turbo tối đa của E-core : 3.4 GHz, Tần số Turbo tối đa của P-core : 4.6 GHz, 12 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-1335U với 10 lõi / 12 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 4800MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (nâng cấp tối đa 2TB SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2240 x 1400 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'sRGB 100%'}, {'name': 'Công nghệ màn hình', 'value': 'LCD TFT đèn nền LED Acer ComfyView'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB-C (USB 3.2 Gen 1, 5Gbps, DisplayPort, sạc 5–20V / 3.25A), 3 x USB-A (USB 3.2 Gen 1), 1 x HDMI 1.4 (HDCP), 1 x Jack tai nghe/loa 3,5mm (hỗ trợ headset có micro), 1 x Khe thẻ microSD'}, {'name': 'Wi-Fi', 'value': 'Intel Wireless Wi-Fi 6 AX201'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Kim loại'}, {'name': 'Kích thước', 'value': '313.3 x 218 x 16.9/16.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.5 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '58Wh 3-cell Li-ion battery'}, {'name': 'Sạc nhanh', 'value': 'Adapter 65W Type-C'}, {'name': 'Loại sạc', 'value': 'Type-C 65W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': '2 x Loa stereo tích hợp, 2 x Micro kỹ thuật số tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD 2MP (phục vụ hội nghị video)'}, {'name': 'Micro', 'value': '2 x Micro kỹ thuật số tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu BIOS (User, Supervisor, SSD), Khe khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 lõi / 16 luồng, Tần số Turbo tối đa của E-core: 3.6 GHz, Tần số Turbo tối đa của P-core: 4.9 GHz, 24 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H (10 lõi / 16 luồng, Tần số Turbo tối đa của E-core: 3.6 GHz, Tần số Turbo tối đa của P-core: 4.9 GHz, 24 MB Intel Smart Cache)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5050'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 Up to 3200 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Nâng cấp tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '180Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'sRGB 100%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu sRGB 100%, Màn hình LCD TFT đèn nền LED Acer ComfyView, Góc nhìn rộng, Thiết kế siêu mỏng, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 3x USB-A, 1x Cổng HDMI 2.1 hỗ trợ HDCP, 1x Giắc cắm tai nghe/loa 3.5 mm, 1x Ethernet (RJ-45), 1x Giắc cắm DC-in cho bộ đổi nguồn AC'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '362.3 x 239.89 x 15.7/23.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-ion 4 cell 76Wh'}, {'name': 'Sạc nhanh', 'value': 'Bộ chuyển đổi 135W 5.5PHY'}, {'name': 'Loại sạc', 'value': 'Bộ chuyển đổi 135W 5.5PHY'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS X:Ultra Audio, DAC SNR cao, Công nghệ Acer Purified.Voice, Tương thích với Cortana bằng giọng nói, Công nghệ Acer TrueHarmony'}, {'name': 'Webcam', 'value': 'Video HD 720p ở tốc độ 30 khung hình/giây với tính năng Giảm nhiễu theo thời gian'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Amber-backlit keyboard'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Giải pháp Mô-đun nền tảng đáng tin cậy (TPM) phần sụn Người dùng BIOS, mật khẩu giám sát, khe khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 120U (10 lõi / 12 luồng, 3.8 GHz - 5 GHz, 12 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 5 120U, 10 lõi / 12 luồng, xung nhịp 3.8 GHz - 5 GHz, 12 MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 up to 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Nâng cấp tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '350nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45%'}, {'name': 'Công nghệ màn hình', 'value': 'LCD TFT đèn nền LED Acer ComfyView, Độ sáng 350nits, Độ phủ màu NTSC 45%'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB Type-C, 2x USB-A, 1x Cổng HDMI 2.1 hỗ trợ HDCP, 1x Giắc cắm tai nghe/loa 3.5 mm'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'N/A'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '357.7 x 234.4 x 12.2/17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.53 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '55Wh 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': '65W Type-C Adapter'}, {'name': 'Loại sạc', 'value': 'Type-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Acer Purified, Tương thích với Cortana bằng giọng nói, Hai loa âm thanh nổi tích hợp với công nghệ Acer TrueHarmony cho độ méo tiếng thấp hơn, dải tần rộng hơn'}, {'name': 'Webcam', 'value': '1080p HD video at 60 fps'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Kensington lock'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 9 365 (10 lõi / 20 luồng, xung nhịp cơ bản 2.0 GHz, Max Boost 5.0 GHz, 24 MB L3 Cache)'}, {'name': 'Mô tả CPU', 'value': '10 lõi / 20 luồng, xung nhịp cơ bản 2.0 GHz, Max Boost 5.0 GHz, 24 MB L3 Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5070'}, {'name': 'Mô tả card đồ họa', 'value': '8 GB GDDR7 VRAM, hỗ trợ 4608 NVIDIA CUDA Cores'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Up to 50 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Up to 5600 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD, 2 khe cắm SSD (Nâng cấp tối đa 4TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 pixel (2K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '180 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'sRGB 100%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400nits, Độ phủ màu sRGB 100%, màn hình LCD TFT đèn nền LED Acer ComfyView độ sáng cao, Viền màn hình siêu mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-C (2 cổng - DisplayPort / Sạc), USB-A (3 cổng), HDMI (1 cổng 2.1), microSD card reader (1 cổng), 3.5mm headphone/speaker jack (1 cổng), Ethernet (RJ-45) (1 cổng), DC-in jack cho AC adapter (1 cổng)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E Wireless LAN'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '356.78 x 275.5 x 12.14/19.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.18 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '76Wh 4-cell Li-ion battery, 230W 5.5PHY Adapter'}, {'name': 'Sạc nhanh', 'value': '230W 5.5PHY Adapter'}, {'name': 'Loại sạc', 'value': 'Adapter 230W 5.5PHY'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS X:Ultra Audio, Hỗ trợ Windows Spatial Sound cho PC Gaming, DAC SNR cao, Công nghệ Acer Purified.Voice, Tương thích với Cortana bằng giọng nói, Công nghệ Acer TrueHarmony'}, {'name': 'Webcam', 'value': '1080p HD'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': '4-zone RGB Keyboard'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'BIOS quyền: User, Supervisor, HDD Passwords, Bộ xử lý bảo mật Microsoft Pluton Security Processor như giải pháp Firmware TPM (vì Pluton hỗ trợ chuẩn TPM 2.0)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H (8 lõi / 12 luồng, Tần số Turbo tối đa của E-core: 3.4 GHz, Tần số Turbo tối đa của P-core: 4.6 GHz, 12 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H (8 lõi / 12 luồng, Tần số Turbo tối đa của E-core: 3.4 GHz, Tần số Turbo tối đa của P-core: 4.6 GHz, 12 MB Intel Smart Cache)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5050'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 Up to 3200 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Nâng cấp tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '180Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'sRGB 100%'}, {'name': 'Công nghệ màn hình', 'value': 'LCD TFT đèn nền LED Acer ComfyView, Góc nhìn rộng, Thiết kế siêu mỏng, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 3x USB-A, 1x Cổng HDMI 2.1 hỗ trợ HDCP, 1x Giắc cắm tai nghe/loa 3.5 mm, 1x Ethernet (RJ-45), 1x Giắc cắm DC-in cho bộ đổi nguồn AC'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '362.3 x 239.89 x 15.7/23.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-ion 4 cell 76Wh'}, {'name': 'Sạc nhanh', 'value': 'Bộ chuyển đổi 135W 5.5PHY'}, {'name': 'Loại sạc', 'value': 'Bộ chuyển đổi 135W 5.5PHY'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS X:Ultra Audio, DAC SNR cao, Công nghệ Acer Purified.Voice, Tương thích với Cortana bằng giọng nói, Công nghệ Acer TrueHarmony'}, {'name': 'Webcam', 'value': 'Video HD 720p ở tốc độ 30 khung hình/giây với tính năng Giảm nhiễu theo thời gian'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Amber-backlit keyboard'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Giải pháp Mô-đun nền tảng đáng tin cậy (TPM) phần sụn Người dùng BIOS, mật khẩu giám sát, khe khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 lõi / 16 luồng, Tần số Turbo tối đa của E-core: 3.6 GHz, Tần số Turbo tối đa của P-core: 4.9 GHz, 24 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 10 lõi / 16 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Up to 4800 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Nâng cấp tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250 nits, Độ phủ màu NTSC 45%, Màn hình LCD TFT đèn nền LED Acer ComfyView, Góc nhìn rộng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB Type-C, 3 x USB Standard-A, 1 x Cổng HDMI 1.4 hỗ trợ HDCP, 1 x Giắc cắm DC-in, 1 x Thẻ nhớ microSD lên đến 512 GB (tương thích SDXC, tương thích exFAT), 1 x Giắc cắm tai nghe/loa 3.5 mm, hỗ trợ tai nghe có micrô tích hợp'}, {'name': 'Wi-Fi', 'value': 'Intel Wireless Wi-Fi 6 AX201'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '357.5 x 229.1 x 19.9/19.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.79 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '58Wh 3-cell Li-ion battery'}, {'name': 'Sạc nhanh', 'value': '90W AC adapter'}, {'name': 'Loại sạc', 'value': '90W AC adapter'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hai loa âm thanh nổi tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD Camera MISC 2M FHD Camera_CTE'}, {'name': 'Micro', 'value': 'Hai micro kỹ thuật số tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Người dùng BIOS, giám sát, mật khẩu ổ cứng Khóa Kensington, Màn trập camera'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 260 (8 lõi / 16 luồng, Base Clock: 3.8 GHz, 8MB L2 Cache; 16MB L3 Cache)'}, {'name': 'Mô tả CPU', 'value': '8 lõi / 16 luồng, Base Clock: 3.8 GHz, 8MB L2 Cache; 16MB L3 Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8 GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': '8 GB GDDR7 VRAM, hỗ trợ 2560 NVIDIA CUDA Cores'}, {'name': 'Bộ xử lý AI / NPU', 'value': '440 TOPs'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Up to 5600 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1024GB PCIe NVMe SSD, 2 khe cắm SSD (Up to 4TB PCIe Gen4 NVMe SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '180 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'sRGB 100%'}, {'name': 'Công nghệ màn hình', 'value': 'LCD TFT Acer ComfyView LED-backlit độ sáng cao, Viền màn hình siêu mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C (40Gbps / DisplayPort / sạc), 3x USB-A, 1x Cổng HDMI 2.1 hỗ trợ HDCP, 1x Đầu đọc thẻ nhớ microSD, 1x Giắc cắm tai nghe/loa 3.5 mm, 1x Cổng Ethernet (RJ-45)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E Wireless LAN'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '357.7 x 264 x 13.9/19.95 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '76Wh 4-cell Li-ion battery, 135W 5.5PHY Adapter'}, {'name': 'Sạc nhanh', 'value': '135W 5.5PHY Adapter'}, {'name': 'Loại sạc', 'value': 'Adapter 135W 5.5PHY'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS X:Ultra Audio, Hỗ trợ Windows Spatial Sound cho PC Gaming, DAC SNR cao, Công nghệ Acer Purified.Voice, Tương thích với Cortana bằng giọng nói, Công nghệ Acer TrueHarmony'}, {'name': 'Webcam', 'value': '720p HD'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': '4-zone RGB Keyboard'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'MSFT Pluton Security Processor như giải pháp Firmware-TPM, cho phép thiết lập quyền BIOS User và Supervisor'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 226V (8 lõi / 8 luồng, 3.5 GHz - 4.5 GHz, 8 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': '8 lõi / 8 luồng, xung nhịp từ 3.5 GHz đến 4.5 GHz, 8 MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics 130V'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Arc Graphics 130V'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel Core Ultra (Ngụ ý có NPU do là dòng Core Ultra)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X 8533 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp (Onboard)'}, {'name': 'Ổ cứng', 'value': '1TB PCIe NVMe SSD (nâng cấp tối đa 2 TB SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '90 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'DCI-P3 100%/Adobe100%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu DCI-P3 100%/Adobe100% Chứng nhận TÜV Rheinland Eyesafe 2.0 DisplayHDR True Black 500, Góc nhìn rộng lên đến 170 độ, Không chứa thủy ngân, thân thiện với môi trường'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB Type-C (USB4 40Gbps / DisplayPort qua USB-C / Thunderbolt 4 / Sạc), 2x USB-A (Một cổng cho USB 3.2 Gen 1 / Một cổng cho USB 3.2 Gen 1 có chức năng sạc USB khi tắt nguồn), Cổng HDMI 2.1 hỗ trợ HDCP, Giắc cắm tai nghe/loa'}, {'name': 'Wi-Fi', 'value': 'Killer Wi-Fi 7 Wireless LAN 802.11 a/b/g/n/ac/ax/be'}, {'name': 'Bluetooth', 'value': 'N/A'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Qua USB-C/Thunderbolt 4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa và kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa và kim loại'}, {'name': 'Kích thước', 'value': '312.4 x 221.2 x 9.7 - 15.95 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.26 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-ion 3 cell 65 Wh'}, {'name': 'Sạc nhanh', 'value': '3 pin USB Type-C 65 W PD PCR 50%, Bộ đổi nguồn AC TCO 9.0'}, {'name': 'Loại sạc', 'value': 'USB Type-C Power Delivery (PD)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS X:Ultra Audio, DAC SNR, Công nghệ Acer Purified, Công nghệ Acer TrueHarmony, Tương thích với Cortana bằng giọng nói'}, {'name': 'Webcam', 'value': 'Độ phân giải 2560 x 1440, Video QHD 1440p ở tốc độ 30 khung hình/giây với Giảm nhiễu theo thời gian'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bộ xử lý bảo mật MSFT Pluton làm giải pháp TPM Firmware, Đầu đọc dấu vân tay trên nắp phím nguồn với thiết kế khớp trên chip, Màn trập camera'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 7 240H (10 lõi / 16 luồng, 1.8 GHz Base, 5.2 GHz Max Turbo)'}, {'name': 'Mô tả CPU', 'value': '10 lõi / 16 luồng, Efficient-core Base Frequency: 1.8 GHz, Max Turbo Frequency: 5.2 GHz, 24 MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050'}, {'name': 'Mô tả card đồ họa', 'value': '6 GB GDDR6 VRAM, hỗ trợ 2560 NVIDIA CUDA Cores'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5600 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Nâng cấp tối đa 4TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '180 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'sRGB 100%'}, {'name': 'Công nghệ màn hình', 'value': 'Acer ComfyView LED-backlit TFT LCD, 3 ms Overdrive, Góc nhìn rộng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB-C (hỗ trợ USB 3.2 Gen 2 10Gbps, DP over USB-C, Thunderbolt 4), 3x USB-A (2x USB 3.2 Gen 1 hỗ trợ sạc khi tắt máy + 1x USB 3.2 Gen 1), 1x HDMI 2.1, 1x jack tai nghe 3.5 mm, 1x Ethernet RJ-45, 1x DC-in'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '362.3 x 239.89 x 15.7/23.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '57 Wh 4-cell Li-ion batter, 135W 5.5PHY Adapter'}, {'name': 'Sạc nhanh', 'value': '135W'}, {'name': 'Loại sạc', 'value': '5.5PHY Adapter'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS X:Ultra Audio với Bass, Loudness, bảo vệ loa, 6 chế độ tùy chỉnh, Hỗ trợ Windows Spatial Sound, DAC SNR cao, 2.1 Vrms, hỗ trợ tai nghe 600Ω, Acer Purified.Voice AI khử ồn, Hỗ trợ Cortana, Acer TrueHarmony'}, {'name': 'Webcam', 'value': '720p HD'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím có đèn nền màu hổ phách'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM, Mật khẩu BIOS (user, supervisor), Kensington lock slot'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 5 340 (6 lõi / 8 luồng, Up to 4.8 GHz, 6MB L2 Cache ; 16MB L3 Cache)'}, {'name': 'Mô tả CPU', 'value': '6 lõi / 8 luồng, Tốc độ lên đến 4.8 GHz, Bộ nhớ đệm L2 6MB, Bộ nhớ đệm L3 16MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời, 8GB VRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Up to 50 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Up to 5600 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Up to 4TB PCIe Gen4 NVMe SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '180Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'sRGB 100%'}, {'name': 'Công nghệ màn hình', 'value': 'LCD TFT Acer ComfyView LED-backlit độ sáng cao, Chuyển từ xám sang xám 3 ms của Overdrive, Hỗ trợ Nvidia Advanced Optimus, Góc nhìn rộng, Thiết kế siêu mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 3 cổng, USB-C: 1 cổng (40Gbps / DP / Sạc), Thunderbolt: N/A, HDMI: 1 cổng (2.1 hỗ trợ HDCP), LAN: 1 cổng (RJ-45), SD: 1 cổng (Đầu đọc thẻ nhớ microSD), 3.5mm: 1 cổng (Giắc cắm tai nghe/loa có mic tích hợp), Khác: 1x Giắc cắm DC-in cho bộ đổi nguồn AC'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '357.7 x 264 x 13.9/19.95 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-ion 4 cell 76Wh'}, {'name': 'Sạc nhanh', 'value': 'Bộ đổi nguồn AC 135W'}, {'name': 'Loại sạc', 'value': 'Bộ đổi nguồn AC 135W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS X:Ultra Audio, Hỗ trợ Windows Spatial Sound cho PC Gaming, Công nghệ Acer Purified.Voice, Tương thích với Cortana bằng Giọng nói, Công nghệ Acer TrueHarmony'}, {'name': 'Webcam', 'value': 'Video HD 1080p ở tốc độ 60 khung hình/giây với tính năng Giảm nhiễu theo thời gian'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': '4-zone RGB Keyboard'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bộ xử lý bảo mật MSFT Pluton làm phần sụn giải pháp TPM Người dùng BIOS, giám sát viên'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Viền màn hình siêu mỏng, Wi-Fi 6'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 nhân, 16 luồng, Turbo tối đa Efficient-core: 3.6 GHz, Performance-core: 4.9 GHz, 24 MB Smart Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H (10 nhân, 16 luồng, Turbo tối đa Efficient-core: 3.6 GHz, Performance-core: 4.9 GHz, 24 MB Smart Cache)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050 6 GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': '6 GB GDDR6 VRAM, hỗ trợ 2560 NVIDIA CUDA Cores'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Up to 5200 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 8GB Onboard + 1 x 8GB rời, nâng cấp lên tối đa 56GB (8GB Onboard + 48GB 1 thanh RAM rời))'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 56GB (sử dụng 2 khe)'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Nâng cấp tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': '16:10'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '180 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45%'}, {'name': 'Công nghệ màn hình', 'value': 'Acer ComfyView LED-backlit TFT LCD độ sáng cao, 3ms (Overdrive), tương thích Nvidia Advanced Optimus, Góc nhìn rộng, Thiết kế siêu mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB-C (USB 3.2 Gen 2, Thunderbolt 4, sạc 5V 3A, DC-in 20V 65W), 2x USB-A (1 cổng USB 3.2 Gen 1, 1 cổng USB 3.2 Gen 1 hỗ trợ sạc khi tắt máy), 1x HDMI 2.1 (HDCP), 1x jack tai nghe/mic 3.5mm, 1x cổng LAN RJ-45'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '362.2 x 248.47 x 22.9/22.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.95 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '53Wh 3-cell Li-ion battery, 100W TypeC adapter'}, {'name': 'Sạc nhanh', 'value': '100W TypeC adapter'}, {'name': 'Loại sạc', 'value': 'TypeC'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hai loa stereo tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD'}, {'name': 'Micro', 'value': 'Hai micro kỹ thuật số tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đơn sắc - Trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'BIOS user & supervisor passwords, Kensington lock slot'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-12500H (12 lõi, 16 luồng, Up to 4.50GHz, 18MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-12500H'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 4800MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2x 8GB (1 RAM Onboard + 1 khe RAM rời, Nâng cấp tối đa 40GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 40GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe NVMe (Nâng cấp tối đa 2TB SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Acer ComfyView'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 3x USB-A, 1x HDMI 1.4 hỗ trợ HDCP, 1x Đầu đọc thẻ MicroSD, 1x giắc cắm tai nghe/loa 3.5 mm'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'Có'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa và kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa và kim loại'}, {'name': 'Kích thước', 'value': '314.4 x 221.9 x 19.5/19.5 mm'}, {'name': 'Trọng lượng', 'value': '1.55 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 cell 58WHrs'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hỗ trợ tai nghe có micrô tích hợp qua cổng 3.5mm'}, {'name': 'Webcam', 'value': 'Camera FHD Camera MISC 2M FHD Camera_CTE'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không đèn bàn phím, không bàn phím số, hotkey Copilot Key'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'BIOS user, supervisor, HDD passwords'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 125U (12 lõi / 14 luồng, 3.6 GHz, 4.3 GHz, 12 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core Ultra 5 125U (12 lõi / 14 luồng, 3.6 GHz, 4.3 GHz, 12 MB Intel Smart Cache)'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel Core Ultra (Ngụ ý có NPU do là Core Ultra)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 4800 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe nâng cấp tối đa 32GB (2x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Nâng cấp tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Acer ComfyView LED-backlit TFT LCD'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 3x USB-A, 1x Khe cắm microSD (tương thích SDXC, tương thích exFAT), 1x HDMI 1.4 port, 1x Headphone/speaker jack'}, {'name': 'Wi-Fi', 'value': 'Intel Wireless Wi-Fi 6 AX201'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '314.4 x 221.9 x 17.5 mm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '1.27 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '58Whr 3-cell'}, {'name': 'Sạc nhanh', 'value': '65W PD Type-C Adapter'}, {'name': 'Loại sạc', 'value': 'Type-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hai loa stereo tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD'}, {'name': 'Micro', 'value': 'Hai micro kỹ thuật số tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'BIOS user, supervisor, HDD passwords, Kensington lock'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 125H (14 lõi / 18 luồng, Turbo Max E-core: 3.6 GHz, Turbo Max P-core: 4.5 GHz, 18 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': '14 lõi / 18 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Tích hợp, 11 TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': '11 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Up to 5600 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Nâng cấp tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'sRGB 100%'}, {'name': 'Công nghệ màn hình', 'value': 'LCD TFT đèn nền LED Acer ComfyView, Góc nhìn rộng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB Type-C, 2x USB 3.2 Gen 1 Type A, 1x HDMI 2.1 (hỗ trợ HDCP), 1x Ethernet (RJ-45), 1x Thẻ nhớ microSD (tương thích SDXC, exFAT), 1x Giắc cắm tai nghe/loa 3.5 mm'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '313.6 x 227.3 x 17.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.5 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-ion 3 cell 55 Wh'}, {'name': 'Sạc nhanh', 'value': 'Bộ chuyển đổi AC USB Type-C 65 W PD'}, {'name': 'Loại sạc', 'value': 'USB Type-C PD 65W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hai loa âm thanh nổi tích hợp'}, {'name': 'Webcam', 'value': 'Ghi âm thanh/video HD 720p'}, {'name': 'Micro', 'value': 'Hai micro kỹ thuật số tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Kensington lock'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H (8 nhân/12 luồng, Turbo Boost 4.6 GHz, 12 MB)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 nhân/12 luồng, Turbo Boost 4.6 GHz, 12 MB cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX 4050, 6GB GDDR6 VRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200Mhz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Máy nguyên bản 2x 8GB, nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SED SSD (nâng cấp tối đa 2 TB Gen4, 16 Gb/s, NVMe)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Acer ComfyView, chống chói, viền N/A, cảm ứng N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 3x USB 3.2 Gen 1, 1x HDMI 2.1, 1x Ethernet (RJ-45), 1x 3.5 mm headphone/speaker jack, 1x DC-in jack'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 802.11 a/b/g/n/ac'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '362.3 x 239.89 x 22.9 mm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell, 57 Whr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in jack'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Spatial Audio, Acer Purified Voice, Acer TrueHarmony, DTS:X ULTRA'}, {'name': 'Webcam', 'value': 'HD webcam'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đơn sắc'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 64 Bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Laptop Gaming'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 lõi / 16 luồng, upto 4.90 GHz, 24 MB)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 10 lõi / 16 luồng, xung nhịp upto 4.90 GHz, Cache 24 MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 2050'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX 2050 4GB GDDR6 VRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8 GB + 8 GB), Hỗ trợ nâng cấp tối đa 32GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe cắm'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (nâng cấp tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Acer ComfyView LED-backlit TFT LCD'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB Type-C™, 3 x USB-A, 1 x HDMI® 2.1 port with HDCP support, 1 x 3.5 mm headphone/speaker jack, 1 x Ethernet (RJ-45) port, 1 x DC-in jack for AC adapter'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6 AX201(2*2 ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '362.3 x 239.89 x 22.9/26.9 mm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 cell, 57Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in jack for AC adapter'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'N/A'}, {'name': 'Webcam', 'value': '720P HD'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Giải pháp vân tay Acer Bio-Protection, Giải pháp Mô-đun Nền Tảng Tin Cậy (TPM) Firmware, Mật khẩu người dùng, Quản trị viên BIOS, Khe khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H (8 lõi / 12 luồng, up to 4.60 GHz, 12 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi / 12 luồng, xung nhịp lên đến 4.60 GHz, 12 MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 2050'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX 2050, 4 GB GDDR6 VRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, máy nguyên bản 8GB, được tặng 8GB, nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp tối đa lên 32GB'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (2 khe cắm, nâng cấp tối đa 2TB SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Acer ComfyView LED-backlit TFT LCD'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 3x USB-A, 1x Ethernet (RJ-45), 1x DC-in jack for AC adapter, 1x HDMI 2.1 (hỗ trợ HDCP), 1x 3.5 mm headphone/speaker jack'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '362.3 x 239.89 x 22.9 - 26.9 mm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 cell - 57 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in jack for AC adapter'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS® X:Ultra'}, {'name': 'Webcam', 'value': '720p HD'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Led trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Laptop Gaming'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 lõi / 12 luồng, 3.6 GHz, 4.9 GHz, 24 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 10 lõi / 12 luồng, xung nhịp tối đa 4.9 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời NVIDIA GeForce RTX 3050 với 6GB GDDR6 VRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe rời (1x 16GB, Nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe cắm'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (nâng cấp tối đa 4 TB SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '180 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'LCD TFT đèn nền LED ComfyView của Acer, Góc nhìn rộng lên đến 170 độ, Thiết kế siêu mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C (DisplayPort / Thunderbolt 4 / Sạc / DC-in), 3x USB-A, 1x HDMI 2.1 hỗ trợ HDCP, 1x 3.5 mm headphone/speaker jack (supporting headsets with built-in microphone), 1x Ethernet (RJ-45), 1x DC-in jack for AC adapter'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'N/A'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '362.3 x 239.89 x 22.9 - 26.9 mm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '57Whr 4-cell, 135W 5.5 PHY Adapter'}, {'name': 'Sạc nhanh', 'value': '135W'}, {'name': 'Loại sạc', 'value': 'Adapter 5.5 PHY'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS X:Ultra Audio, High SNR DAC, Acer Purified, Tương thích với Cortana bằng giọng nói, Acer TrueHarmony'}, {'name': 'Webcam', 'value': '720p HD'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Giải pháp vân tay Acer Bio-Protection, có tính năng bảo vệ máy tính và Chứng nhận bảo mật Windows Hello, Giải pháp Firmware Trusted Platform Module (TPM), Người dùng BIOS, mật khẩu giám sát, khe khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 255HX (20 lõi / 20 luồng, Efficient-core Max Turbo Frequency : 4.5 GHz, Performance-core Max Turbo Frequency : 5.2 GHz, 30MB Cache)'}, {'name': 'Mô tả CPU', 'value': '20 lõi / 20 luồng, Efficient-core Max Turbo Frequency : 4.5 GHz, Performance-core Max Turbo Frequency : 5.2 GHz, 30MB Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060'}, {'name': 'Mô tả card đồ họa', 'value': '8 GB VRAM GDDR7 chuyên dụng, hỗ trợ 3328 lõi NVIDIA CUDA'}, {'name': 'Bộ xử lý AI / NPU', 'value': '572 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Up to 6400 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 32GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '1TB PCIe NVMe SED SSD (Up to 4TB PCIe Gen4 NVMe SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 pixels (2K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '240 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'DCI-P3 100%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 500 nits\nĐộ phủ màu DCI-P3 100%\nMàn hình LCD TFT đèn nền LED Acer ComfyView\nTương thích Nvidia Advanced Optimus\nGóc nhìn rộng\nThiết kế siêu mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB Type-C (DP / Thunderbolt 4 / Sạc / DC-in), 1x USB Type-C (10Gbps / DP / Sạc / DC-in), 3x USB-A, 1x HDMI 2.1 hỗ trợ HDCP, 1x Ethernet (RJ-45), 1x Thẻ nhớ microSD (tương thích SDXC), 1x DC-in, 1x Giắc cắm tai nghe/loa 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Killer Wireless Wi-Fi 6E 1675i'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '356.78 x 275.5 x 13.47/23.90 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.7 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-ion 4 cell 90Wh\nBộ đổi nguồn AC 230W'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'Bộ đổi nguồn AC 230W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS X:Ultra Audio\nDAC SNR cao\nCông nghệ Acer Purified.Voice\nTương thích với Cortana bằng giọng nói\nCông nghệ Acer TrueHarmony\nChứng nhận Âm thanh Độ phân giải Cao của JAS'}, {'name': 'Webcam', 'value': 'Video HD 1080p ở tốc độ 60 khung hình/giây với tính năng Giảm nhiễu theo thời gian'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': '4-zone RGB Lighting'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Người dùng BIOS, giám sát Giải pháp Mô-đun nền tảng đáng tin cậy (TPM) phần sụn 1 Khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 5700U (8 lõi / 16 luồng, 1.8 GHz - 4.3 GHz, Total Cache L2 : 4MB - Total Cache L3 : 8MB)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 5700U, 8 lõi / 16 luồng, xung nhịp từ 1.8 GHz đến 4.3 GHz, Cache L2: 4MB, Cache L3: 8MB'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Nâng cấp tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250 nits, Độ phủ màu NTSC 45%, màn hình chống chói, Acer ComfyView'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 3x cổng USB-A, 1x HDMI 1.4, Khe đọc thẻ nhớ, Giắc cắm tai nghe/loa 3.5 mm'}, {'name': 'Wi-Fi', 'value': '802.11a/b/g/n/ac+ax wireless LAN'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '358.6 x 232.7 x 18.95 mm'}, {'name': 'Trọng lượng', 'value': '1.7 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-ion 3 cell 58Wh'}, {'name': 'Sạc nhanh', 'value': '65W PD Type C'}, {'name': 'Loại sạc', 'value': 'Bộ chuyển đổi 65W PD Type C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hai loa stereo tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD Camera MISC 2M FHD Camera_CTE'}, {'name': 'Micro', 'value': 'Hai micrô kỹ thuật số tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'BIOS user, supervisor'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-12450H (8 lõi / 12 luồng, up to 4.40 GHz, 12 MB)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-12450H, 8 lõi / 12 luồng, xung nhịp lên đến 4.40 GHz, Cache 12 MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR45 4800MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe rời (Máy nguyên bản 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Acer ComfyView, Độ sáng 250nits'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 3x USB-A, 1x HDMI 1.4 hỗ trợ HDCP, 1x giắc cắm tai nghe/loa 3.5 mm, Khe đọc thẻ nhớ, Thẻ nhớ MicroSD lên đến 512 GB (tương thích SDXC, tương thích exFAT)'}, {'name': 'Wi-Fi', 'value': 'Intel Wireless Wi-Fi 6 AX201'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '357.5 x 229.1 x 19.9 mm'}, {'name': 'Trọng lượng', 'value': '1.79 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '58Wh 3-cell Li-ion battery'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hỗ trợ tai nghe có micrô tích hợp qua cổng 3.5mm'}, {'name': 'Webcam', 'value': 'Camera FHD'}, {'name': 'Micro', 'value': 'Micro tích hợp với jack 3.5mm'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'BIOS user, supervisor, HDD passwords'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H (8 lõi / 12 luồng, upto 4.60 GHz, 12 MB)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi / 12 luồng, xung nhịp upto 4.60 GHz, Cache 12 MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX 4050, 6GB GDDR6 VRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB + 8GB), Nâng cấp tối đa 64GB (cắm sẵn 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (nâng cấp tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Acer ComfyView, LED-backlit TFT LCD'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB Type-C™, 3 x USB-A, 1 x HDMI® 2.1 port with HDCP support, 1 x 3.5 mm headphone/speaker jack, 1 x Ethernet (RJ-45) port, 1 x DC-in jack for AC adapter'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6 AX201(2*2 ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '362.3 x 239.89 x 22.9/26.9 mm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 cell, 57Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in jack for AC adapter'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS® X:Ultra'}, {'name': 'Webcam', 'value': '720P HD'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Led trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Giải pháp vân tay Acer Bio-Protection, Giải pháp Mô-đun Nền Tảng Tin Cậy (TPM) Firmware, Mật khẩu người dùng, Quản trị viên BIOS, Khe khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 258V (8 lõi / 8 luồng, 3.7 GHz - 4.8 GHz, 12 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': '8 lõi / 8 luồng, xung nhịp từ 3.7 GHz đến 4.8 GHz, 12 MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics 140V'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Arc Graphics 140V'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel Core Ultra (Ngụ ý có NPU do là dòng Core Ultra)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X 8533 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1x 32GB Onboard'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A (Onboard)'}, {'name': 'Ổ cứng', 'value': '1TB PCIe NVMe SSD (nâng cấp tối đa 2 TB SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '90 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'DCI-P3 100%/Adobe100%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu DCI-P3 100%/Adobe100% Chứng nhận TÜV Rheinland Eyesafe 2.0 DisplayHDR True Black 500, Góc nhìn rộng lên đến 170 độ, Không chứa thủy ngân, thân thiện với môi trường'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB Type-C (USB4 40Gbps / DisplayPort qua USB-C / Thunderbolt 4 / Sạc), 2x USB-A (Một cổng cho USB 3.2 Gen 1 / Một cổng cho USB 3.2 Gen 1 có chức năng sạc USB khi tắt nguồn), Cổng HDMI 2.1 hỗ trợ HDCP, Giắc cắm tai nghe/loa'}, {'name': 'Wi-Fi', 'value': 'Killer Wi-Fi 7 Wireless LAN 802.11 a/b/g/n/ac/ax/be'}, {'name': 'Bluetooth', 'value': 'N/A'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa và kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '312.4 x 221.2 x 9.7 - 15.95 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.26 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-ion 3 cell 65 Wh'}, {'name': 'Sạc nhanh', 'value': '3 pin USB Type-C 65 W PD PCR 50%, Bộ đổi nguồn AC TCO 9.0'}, {'name': 'Loại sạc', 'value': 'USB Type-C PD 65W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS X:Ultra Audio, DAC SNR, Công nghệ Acer Purified, Công nghệ Acer TrueHarmony, Tương thích với Cortana bằng giọng nói'}, {'name': 'Webcam', 'value': 'Độ phân giải 2560 x 1440, Video QHD 1440p ở tốc độ 30 khung hình/giây với Giảm nhiễu theo thời gian'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bộ xử lý bảo mật MSFT Pluton làm giải pháp TPM Firmware, Đầu đọc dấu vân tay trên nắp phím nguồn với thiết kế khớp trên chip, Màn trập camera'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 155U (12 lõi / 14 luồng, 3.8 GHz, 4.8 GHz, 12 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core Ultra 7 155U, 12 lõi / 14 luồng, xung nhịp 3.8 GHz, 4.8 GHz, 12 MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel Core Ultra series (ngụ ý có NPU)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5600 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Nâng cấp tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Acer ComfyView LED-backlit TFT LCD, Độ sáng 300 nits, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 3x USB-A, 1x Khe cắm microSD (SDXC, exFAT), 1x HDMI 1.4, 1x Headphone/speaker jack'}, {'name': 'Wi-Fi', 'value': 'Intel Wireless Wi-Fi 6 AX201'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa và kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314.4 x 221.9 x 17.5 mm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '1.27 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '58Whr 3-cell'}, {'name': 'Sạc nhanh', 'value': '65W PD Type-C Adapter'}, {'name': 'Loại sạc', 'value': 'Type-C (65W PD)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hai loa stereo tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD'}, {'name': 'Micro', 'value': 'Hai micro kỹ thuật số tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'BIOS user, supervisor, HDD passwords, Kensington lock'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-1355U (3.7 Ghz, up to 5.0 GHz, 24MB cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-1355U, 3.7 Ghz, up to 5.0 GHz, 24MB cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5 5200Mhz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 khe Onboard, Không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình LCD TFT có đèn nền LED Acer ComfyView hỗ trợ giải pháp cảm ứng đa điểm và bút AES'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 2x USB-A, 1x HDMI 2.1, 1x 3.5 mm headphone/speaker jack, 1x DC-in jack for AC adapter'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E, 802.11a/b/g/n/ac/ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '318.2 x 225.5 x 17.99 mm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '1.6 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50Wh Li-ion battery'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in jack for AC adapter'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Acer Purified, Giảm tiếng ồn AI, Hai loa âm thanh nổi tích hợp'}, {'name': 'Webcam', 'value': '1080p HD'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'BIOS user, supervisor passwords, Kensington lock slot'}, {'name': 'Hệ điều hành', 'value': 'Win 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, Màn hình cảm ứng, Xoay gập 360 độ (2 in 1)'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 5800H 3.2GHz up to 4.4GHz 16MB'}, {'name': 'Mô tả CPU', 'value': 'Ryzen 7 5800H, 16MB Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3070'}, {'name': 'Mô tả card đồ họa', 'value': '8GB GDDR6'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe cắm tối đa 32GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 PCIE'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Tần số quét 144Hz, màn hình chống loá'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 3.2 Gen 2 Type-C Ports (up to 10 Gbps), 1x USB 3.2 Gen 2 Type-A Ports, 2x USB 3.2 Gen 1 Type-A Ports, RJ45, 1x HDMI'}, {'name': 'Wi-Fi', 'value': '802.11AX (2x2)'}, {'name': 'Bluetooth', 'value': 'v5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '363.4 x 255 x 23.9 mm'}, {'name': 'Trọng lượng', 'value': '2.2 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell 57WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Waves MaxxAudio®, Acer TrueHarmony™'}, {'name': 'Webcam', 'value': 'HD 720p'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 10 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Laptop gaming'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-1255U (10 lõi / 12 luồng, 3.5 GHz, turbo boost 4.7 GHz, 12 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-1255U, 10 lõi / 12 luồng, 3.5 GHz, turbo boost 4.7 GHz, 12 MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 4800 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB PCIe NVMe SSD (Hỗ trợ khe cắm SSD M.2, nâng cấp tối đa 2TB SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits, Độ phủ màu 45% NTSC, màn hình LCD TFT đèn nền LED ComfyView của Acer, Góc nhìn rộng lên đến 170 độ'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C (DisplayPort / Sạc), 3x USB-A Gen 1, 1x HDMI 1.4 port với HDCP, 1x Giắc cắm tai nghe/loa 3,5 mm, Thẻ nhớ microSD lên tới 512 GB (tương thích SDXC, tương thích exFAT)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 AX201'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '357.6 x 247 x 18.9 mm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '1.8 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Li-ion Battery 58Whr 3-cell'}, {'name': 'Sạc nhanh', 'value': '65W PD Type-C Adapter'}, {'name': 'Loại sạc', 'value': 'Type-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hai loa stereo tích hợp'}, {'name': 'Webcam', 'value': 'FHD Camera'}, {'name': 'Micro', 'value': 'Hai micrô kỹ thuật số tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'BIOS user, supervisor, HDD passwords'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H 2.1 GHz (8 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 2.1 GHz, 12MB Cache, up to 4.6 GHz, 8 lõi, 12 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '8GB DDR4 on board + 8GB DDR4 SO-DIMM (Có thể nâng cấp; Cần tháo vỏ dưới/trên)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (thông qua việc thay thế hoặc bổ sung module RAM)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, TÜV Rheinland-certified, With stylus support, Màn hình cảm ứng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1x (480Mbps), USB 3.2 Gen 2 Type-A: 1x (10Gbps), USB 3.2 Gen 2 Type-C (hỗ trợ hiển thị/cung cấp điện): 1x (10Gbps), HDMI: 1x (2.1 TMDS), Giắc cắm âm thanh kết hợp 3.5mm: 1x, DC-in: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '31.32 x 22.76 x 1.89 ~ 1.89 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.50 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp, Micrô mảng tích hợp harman/kardon (Chính thống)'}, {'name': 'Webcam', 'value': '1080p FHD với màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp harman/kardon (Chính thống)'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 210H 2.2 GHz (8 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 5 210H, 2.2 GHz (12MB Cache, up to 4.8 GHz, 8 lõi, 12 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời, 6GB GDDR6'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIe 4.0 NVMe M.2 SSD (Hỗ trợ tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45%'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói, N/A (Không đề cập công nghệ độc quyền cụ thể ngoài các tính năng cơ bản)'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x LAN RJ45, 1x USB 3.2 Gen 2 Type-C (hỗ trợ DisplayPort / cấp nguồn, 10Gbps), 2x USB 3.2 Gen 1 Type-A (5Gbps), 1x HDMI 2.1, 1x 3.5mm Combo Audio Jack'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.4 x 25.1 x 2.21 ~ 2.67 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.20 Kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '56WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống 2 loa, Công nghệ chống ồn AI, Dolby Atmos, Chứng nhận Hi-Res (cho tai nghe)'}, {'name': 'Webcam', 'value': '720P HD camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên BIOS và bảo vệ mật khẩu người dùng, Khe Kensington Security, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'TUF Gaming (Chuyên dòng Gaming)'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 210H 2.2 GHz (8 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 5 210H, 2.2 GHz (12MB Cache, up to 4.8 GHz, 8 lõi, 12 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX 4050 6GB GDDR6 (194 AI TOPs)'}, {'name': 'Bộ xử lý AI / NPU', 'value': '194 AI TOPs'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Có thể nâng cấp; Cần tháo vỏ dưới/trên'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (cần tháo vỏ)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 1x (hỗ trợ hiển thị/sạc 5Gbps), Thunderbolt: N/A, HDMI: 1x (2.1 FRL), LAN: N/A, SD: N/A, 3.5mm: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.70 x 25.07 x 1.80 ~ 2.20 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.95 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '63WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô tích hợp'}, {'name': 'Webcam', 'value': '1080p FHD với màn trập camera'}, {'name': 'Micro', 'value': 'Micrô tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu người dùng thiết lập BIOS, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7 14650HX 2.2 GHz (16 lõi, 24 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7 14650HX, 2.2 GHz (30MB Cache, up to 5.2 GHz, 16 lõi, 24 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7, Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600 SO-DIMM, tốc độ bộ nhớ của hệ thống thay đổi tùy theo CPU'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2x SO-DIMM (Tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe SO-DIMM'}, {'name': 'Ổ cứng', 'value': '1TB PCIe 4.0 NVMe M.2 SSD (2 Khe cắm M.2 hỗ trợ SATA hoặc NVMe, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '240 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'DCI-P3 100%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 500nits, Độ phủ màu DCI-P3 100%, màn hình chống chói, G-Sync, ROG Nebula Display, Dolby Vision HDR, ROG intelligent cooling'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x LAN RJ45, 1x Thunderbolt 4 (hỗ trợ DisplayPort / Sạc / G-SYNC - 40Gbps), 1x USB 3.2 Gen 2 Type-C (hỗ trợ DisplayPort / Sạc - 10Gbps), 3x USB 3.2 Gen 2 Type-A (10Gbps), 1x HDMI 2.1 FRL, 1x Giắc cắm âm thanh kết hợp 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Triple band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Qua cổng Thunderbolt 4 và HDMI)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.4 x 26.8 x 2.28 ~ 3.08 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.65 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '90WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ chống ồn AI, Dolby Atmos, Chứng nhận Hi-Res (cho tai nghe), Công nghệ Smart Amp'}, {'name': 'Webcam', 'value': '1080P FHD IR Camera for Windows Hello'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 4 vùng Với phím Copilot Aura Sync'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên BIOS và bảo vệ mật khẩu người dùng, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'ROG intelligent cooling'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 210H 2.2 GHz (12MB Cache, up to 4.8 GHz, 8 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': '8 lõi, 12 luồng, xung nhịp tối đa 4.8 GHz, 12MB Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB DDR5 Onboard + 8GB DDR5 SO-DIMM)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp qua khe SO-DIMM còn trống'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB 3.2 Gen 1 Type-A, 2x USB 3.2 Gen 1 Type-C (hỗ trợ hiển thị/cấp nguồn), 1x HDMI 1.4, 1x Giắc cắm âm thanh kết hợp 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập riêng tư'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại hỗ trợ Windows Hello, McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mật khẩu người dùng thiết lập BIOS, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H 2.1 GHz (8 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi, 12 luồng, 12MB Cache, xung nhịp lên đến 4.6 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA Geforce RTX 3050 4GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời, 4GB GDDR6'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB DDR4 on board + 8GB DDR4 SO-DIMM)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp thêm 8GB RAM (tùy thuộc vào khe trống)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói, TÜV Rheinland-certified'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 3.2 Gen 1 Type-C (hỗ trợ cấp nguồn 5Gbps), 2x USB 3.2 Gen 1 Type-A (5Gbps), 1x HDMI 2.1 TMDS, 1x Giắc cắm âm thanh kết hợp 3,5mm, 1x DC-in, Đầu đọc thẻ SD 4.0'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax) (Dual band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.86 x 24.91 x 1.89 ~ 1.89 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.80 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'HD 720p có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee, BIOS Booting User Password Protection, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 210H 2.2 GHz (8 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 5 210H, 2.2 GHz, 12MB Cache, lên đến 4.8 GHz, 8 lõi, 12 luồng'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX 4050 6GB GDDR6 (194 AI TOPs) 2420MHz* at 140W (2370MHz Boost Clock+50MHz OC, 115W+25W Dynamic Boost), Intel Iris Xe Graphics (tích hợp)'}, {'name': 'Bộ xử lý AI / NPU', 'value': '194 AI TOPs'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2x SO-DIMM (Tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe SO-DIMM'}, {'name': 'Ổ cứng', 'value': '512GB PCIe 4.0 NVMe M.2 SSD (2 Khe cắm M.2 hỗ trợ SATA hoặc NVMe, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45%, màn hình chống chói, G-Sync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x LAN RJ45, 1x Thunderbolt 4 hỗ trợ DisplayPort (40Gbps), 1x USB 3.2 Gen 2 Type-C hỗ trợ DisplayPort / Sạc / G-SYNC (10Gbps), 2x USB 3.2 Gen 1 Type-A (5Gbps), 1x HDMI 2.1 FRL, 1x Giắc cắm âm thanh kết hợp 3.5mm, Micrô mảng tích hợp'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua Thunderbolt 4 hỗ trợ DisplayPort)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.4 x 25.1 x 2.21 ~ 2.67 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.20 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '56WHrs, 4S1P, 4-cell Li-ion, Sạc lại từ 0-50% trong 30 phút'}, {'name': 'Sạc nhanh', 'value': 'Sạc lại từ 0-50% trong 30 phút'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ chống ồn AI, Dolby Atmos, Chứng nhận Hi-Res (cho tai nghe)'}, {'name': 'Webcam', 'value': '720P HD camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên BIOS và bảo vệ mật khẩu người dùng, Khe Kensington Security, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'TUF Gaming series'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 150 3.3GHz (6 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 150 3.3GHz (18MB Cache, up to 4.55 GHz, 6 lõi, 12 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': '8GB DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB DDR5 on board + 8GB DDR5 SO-DIMM, Có thể nâng cấp; Cần tháo vỏ dưới/trên)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (qua khe SO-DIMM)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits, Độ phủ màu 45% NTSC, màn hình chống chói, Chứng nhận TÜV Rheinland'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB 2.0 Type-A (480Mbps), 1 x USB 3.2 Gen 1 Type-C (5Gbps), 1 x USB 3.2 Gen 1 Type-C hỗ trợ Power Delivery (5Gbps), 2 x USB 3.2 Gen 1 Type-A (5Gbps), 1 x HDMI 1.4, 1 x Jack âm thanh 3.5mm combo'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '31.71 x 22.20 x 1.99 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.60 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Mic đa hướng tích hợp'}, {'name': 'Webcam', 'value': 'Camera HD 720p; Có màn trập camera'}, {'name': 'Micro', 'value': 'Mic đa hướng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet'}, {'name': 'Touchpad', 'value': 'Có cảm biến vân tay tích hợp'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay tích hợp trong touchpad, McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mật khẩu người dùng trong thiết lập BIOS, Mô-đun TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7445HS (6 lõi, 12 luồng, up to 4.7GHz, 22MB Cache)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 7445HS 3.2GHz (22MB Cache, up to 4.7GHz, 6 lõi, 12 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 4GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 4GB GDDR6 Up to 1675MHz at 60W (75W with Dynamic Boost), AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe cắm.'}, {'name': 'Ổ cứng', 'value': '512GB PCIe 4.0 NVMe M.2 SSD. 2 Khe cắm M.2 hỗ trợ cả SATA hoặc NVMe, tối đa 1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45% / SRGB 62.5% / Adobe 47.34%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250nits, Màn hình chống chói, Adaptive-Sync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x cổng LAN RJ45, 1x cổng USB 3.2 Gen 2 Type-C hỗ trợ DisplayPort (lên đến 10Gbps), 3x cổng USB 3.2 Gen 1 Type-A (lên đến 5Gbps), 1x cổng HDMI 2.1 TMDS, 1x 3.5mm Combo Audio Jack'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.9 x 25.6 x 2.28 ~ 2.45 cm (Dải x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.30 Kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '48WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ chống ồn AI, Xử lý âm thanh DTS, Chứng nhận Hi-Res (cho tai nghe)'}, {'name': 'Webcam', 'value': '720P HD camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu Quản trị viên BIOS và Bảo vệ Mật khẩu Người dùng, Khe Bảo mật Kensington, Mô-đun Nền tảng Đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'TUF Gaming series'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Snapdragon X X1 26 100 (8 lõi, 8 luồng)'}, {'name': 'Mô tả CPU', 'value': '30MB Cache, up to 2.97GHz'}, {'name': 'Tên card đồ họa', 'value': 'Qualcomm Adreno GPU'}, {'name': 'Mô tả card đồ họa', 'value': 'Tiến trình chip mới nên có thể không kết nối được với các thiết bị có driver cũ'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Qualcomm Hexagon NPU up to 45TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp (Onboard)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits (Độ sáng tối đa 600nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, HDR True Black 600, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi 0.2ms, Giảm 70% ánh sáng xanh có hại, TÜV Rheinland-certified, Màn hình chăm sóc mắt SGS'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 3.2 Gen 2 Type-A (10Gbps), 2x USB 4.0 Gen 3 Type-C (hỗ trợ hiển thị/sạc 40Gbps), 1x HDMI 2.1 TMDS, 1x Giắc cắm âm thanh kết hợp 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Mg-Al'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Mg-Al'}, {'name': 'Kích thước', 'value': '31.07 x 21.39 x 1.34 ~ 1.59 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '0.98 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, McAfee, BIOS Booting User Password Protection, BIOS setup user password, Microsoft Pluton security processor, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7520U 2.8GHz (4 lõi, 8 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 7520U, 2.8GHz, 6MB Cache, up to 4.3GHz, 4 lõi, 8 luồng'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không thể nâng cấp thêm)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 3.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250nits, Độ phủ màu 45% NTSC, màn hình chống chói, TÜV Rheinland-certified'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1x (tốc độ dữ liệu lên đến 480Mbps), USB 3.2 Gen 1 Type-A: 1x (5Gbps), USB 3.2 Gen 1 Type-C: 1x (5Gbps), HDMI: 1x (1.4), LAN: N/A, SD: N/A, 3.5mm: 1x Jack âm thanh kết hợp'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 1*1'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '36.03 x 23.25 x 1.79 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.63 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera HD 720p; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mô-đun Nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7 14650HX 2.2 GHz (16 lõi, 24 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7 14650HX, 2.2 GHz, 30MB Cache, up to 5.2 GHz, 16 lõi, 24 luồng'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7 115W (100W+15W)'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5060, 8GB GDDR7 VRAM, 115W TDP'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1x 16GB, nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB PCIe 4.0 NVMe M.2 SSD (2 Khe cắm M.2 tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 72.00%, SRGB 100.00%, Adobe 75.35%'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói, G-Sync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x LAN RJ45, 1x Thunderbolt 4 (DisplayPort / G-SYNC 40Gbps), 1x USB 3.2 Gen 2 Type-C (DisplayPort / cung cấp điện 10Gbps), 3x USB 3.2 Gen 2 Type-A (10Gbps), 1x HDMI 2.1, 1x Giắc cắm âm thanh kết hợp 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax) (Triple band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua Thunderbolt 4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.4 x 26.9 x 1.79 ~ 2.73 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.20 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '90WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ chống ồn AI, Dolby Atmos, Chứng nhận Hi-Res (cho tai nghe)'}, {'name': 'Webcam', 'value': 'Camera IR FHD 1080P cho Windows Hello'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên BIOS và bảo vệ mật khẩu người dùng, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'TUF Gaming series'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i3-1315U 1.2 GHz (6 lõi, 8 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i3-1315U, 1.2 GHz, 10MB Cache, up to 4.5 GHz, 6 lõi, 8 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '8GB On board (Có thể nâng cấp, cần tháo vỏ dưới/trên)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (cần tháo vỏ)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250nits, Độ phủ màu 45% NTSC, màn hình chống chói, TÜV Rheinland-certified'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 2.0 Type-A, 2x USB 3.2 Gen 1 Type-A, 1x USB 3.2 Gen 1 Type-C, 1x HDMI 1.4, 1x 3.5mm Combo Audio Jack, 1x DC-in'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 1*1'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '32.49 x 21.39 x 1.79 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': '720p HD camera với màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet'}, {'name': 'Touchpad', 'value': 'Có cảm biến vân tay tích hợp với Touchpad'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay tích hợp với Touchpad, McAfee, BIOS Booting User Password Protection, BIOS setup user password, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 225H 1.7 GHz (18MB Cache, up to 4.9 GHz, 14 lõi, 14 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500 nits (Độ sáng tối đa 1000 nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Display HDR True Black 1000, Giảm 70% ánh sáng xanh có hại, Được chứng nhận bởi TÜV Rheinland, SGS Eye Care Display'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 2 (Thunderbolt 4), Thunderbolt: 2, HDMI: 1, LAN: N/A, SD: N/A, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Tri-band)2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2 x Thunderbolt 4 (hỗ trợ xuất hình / cấp nguồn)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.24 x 22.01 x 1.49 ~ 1.49 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.20 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 2S2P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello, có màn trập camera'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại (IR) hỗ trợ Windows Hello, McAfee, Mô-đun nền tảng tin cậy TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7520U 2.8GHz (4 lõi, 8 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 7520U, 2.8GHz, 6MB Cache, up to 4.3GHz, 4 lõi, 8 luồng'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không thể nâng cấp)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 3.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250 nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 2.0 Type-A (480Mbps), 1x USB 3.2 Gen 1 Type-A (5Gbps), 1x USB 3.2 Gen 1 Type-C (5Gbps), 1x HDMI 1.4, 1x Jack âm thanh kết hợp 3.5mm, 1x DC-in'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 1x1'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '32.55 x 21.39 x 1.79 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.38 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet'}, {'name': 'Touchpad', 'value': 'Có, tích hợp với cảm biến vân tay'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay tích hợp với Touchpad, McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 150 3.3GHz (6 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 150 3.3GHz (18MB Cache, up to 4.55 GHz, 6 lõi, 12 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB DDR5 on board + 8GB DDR5 SO-DIMM, Có thể nâng cấp; Cần tháo vỏ dưới/trên)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (2 khe)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 x 5 Gbps, USB-C: 2 x 5 Gbps (có hỗ trợ Power Delivery), Thunderbolt: N/A, HDMI: 1 x 1.4, LAN: N/A, SD: N/A, 3.5mm: 1 x Jack tai nghe/micro'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.97 x 23.25 x 1.99 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.70 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Microphone mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera HD 720p, có màn trập camera'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có phím số'}, {'name': 'Touchpad', 'value': 'Touchpad tích hợp với cảm biến vân tay'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay tích hợp trên Touchpad, Phần mềm bảo mật McAfee, Mật khẩu khởi động BIOS, Mật khẩu truy cập thiết lập BIOS, Mô-đun nền tảng tin cậy TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'McAfee'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H 2.4 GHz (24MB Cache, up to 4.9 GHz, 10 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': '10 lõi, 16 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 SO-DIMM Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm thêm)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, màn hình chống chói, TÜV Rheinland-certified'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 2x (hỗ trợ hiển thị/cung cấp điện), Thunderbolt: N/A, HDMI: 1x, LAN: N/A, SD: N/A, 3.5mm: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Nhôm, Nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello, có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, McAfee, BIOS Booting User Password Protection, BIOS setup user password, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7 14650HX 2.2 GHz (16 lõi, 24 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7 14650HX, 2.2 GHz, 30MB Cache, up to 5.2 GHz, 16 lõi, 24 luồng'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7 115W (100W+15W)'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5050, 8GB GDDR7, 115W (100W+15W)'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe cắm'}, {'name': 'Ổ cứng', 'value': '1TB PCIe 4.0 NVMe M.2 SSD (2 Khe cắm M.2 hỗ trợ SATA hoặc NVMe, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 72.00%, SRGB 100.00%, Adobe 75.35%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits, Màn hình chống chói, G-Sync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x LAN RJ45, 1x Thunderbolt 4 (hỗ trợ DisplayPort / G-SYNC - 40Gbps), 1x USB 3.2 Gen 2 Type-C (hỗ trợ DisplayPort / cung cấp điện - 10Gbps), 3x USB 3.2 Gen 2 Type-A (10Gbps), 1x HDMI 2.1 FRL, 1x Giắc cắm âm thanh kết hợp 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Qua Thunderbolt 4 và HDMI)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.4 x 26.9 x 1.79 ~ 2.73 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.20 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '90WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ chống ồn AI, Dolby Atmos, Chứng nhận Hi-Res (cho tai nghe)'}, {'name': 'Webcam', 'value': 'Camera IR FHD 1080P cho Windows Hello'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng Với phím Copilot Aura Sync'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên BIOS và bảo vệ mật khẩu người dùng, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'TUF Gaming series'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H 2.4 GHz (10 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 2.4 GHz, 24MB Cache, up to 4.9 GHz, 10 lõi, 16 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB DDR5 Onboard + 8GB DDR5 SO-DIMM, Có thể nâng cấp; Cần tháo vỏ dưới/trên)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (qua khe SO-DIMM)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 2x (hỗ trợ hiển thị/cấp nguồn), Thunderbolt: N/A, HDMI: 1x, LAN: N/A, SD: N/A, 3.5mm: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '35.70 x 25.06 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.70 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập riêng tư'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại hỗ trợ Windows Hello, McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI MAX+ 395 3.0GHz (16 lõi, 32 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD XDNA lên tới 50TOPS'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA lên tới 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '128GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X 8000 On board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'On board (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB PCIe 4.0 NVMe M.2 SSD (2230)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.4 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '180 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'DCI-P3 100%'}, {'name': 'Công nghệ màn hình', 'value': 'ROG Nebula Display, Support Dolby Vision HDR'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 3.2 Gen 2 Type-A (10Gbps), 2x Type-C USB 4 (hỗ trợ DisplayPort / cung cấp điện 40Gbps), 1x đầu đọc thẻ (microSD) (UHS-II), 1x HDMI 2.1, 1x 3.5mm Combo Audio Jack (có mảng 3 micro)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11ab) (Triple band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '30.0 x 20.4 x 1.30 ~ 1.49 cm (Dài x Rộng x Dày), Kích thước bàn phím: 30.0 x 20.6 x 0.55 cm'}, {'name': 'Trọng lượng', 'value': '1.20 kg (Laptop), 0.39 Kg (Bàn phím)'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion, Sạc lại từ 0-50% trong 30 phút'}, {'name': 'Sạc nhanh', 'value': 'Sạc lại từ 0-50% trong 30 phút'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': '2x 2W lực kép với Công nghệ Smart Amp, Dolby Atmos, Chứng nhận Hi-Res (cho tai nghe), Công nghệ Smart Amp'}, {'name': 'Webcam', 'value': 'Camera 13MP và camera IR 5MP'}, {'name': 'Micro', 'value': 'Built-in 3-microphone array'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng, Aura Sync'}, {'name': 'Touchpad', 'value': 'Màn hình cảm ứng'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên BIOS và bảo vệ mật khẩu người dùng, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 9 8940HX 2.4GHz (16 lõi, 32 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 9 8940HX, 2.4GHz (80MB Cache, up to 5.3GHz, 16 lõi, 32 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7, AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5200 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIe 4.0 NVMe M.2 SSD (2 Khe cắm M.2 hỗ trợ cả SATA hoặc NVMe, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '240 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'DCI-P3 100%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 500 nits, Tỷ lệ tương phản 1200:1, Màn hình chống chói, Công nghệ Adaptive-Sync G-Sync, Chứng nhận Pantone Validated, ROG Nebula Display, Dolby Vision HDR, Tản nhiệt ROG Intelligent Cooling'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x RJ45 LAN, 1 x USB 4 Type-C (hỗ trợ DisplayPort / G-Sync, 40Gbps), 1 x USB 4 Type-C (hỗ trợ DisplayPort / Power Delivery / G-Sync, 40Gbps), 2 x USB 3.2 Gen 2 Type-A (10Gbps), 1 x HDMI 2.1 FRL, 1 x Jack âm thanh 3.5mm combo'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.4 x 26.4 x 2.26 ~ 3.04 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.50 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '90WHrs, 4S1P, 4-cell Li-ion, Sạc từ 0-50% trong 30 phút'}, {'name': 'Sạc nhanh', 'value': 'Sạc từ 0-50% trong 30 phút'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống 2 loa với công nghệ khuếch đại thông minh, Công nghệ khử ồn AI, Dolby Atmos, Chứng nhận Hi-Res (cho tai nghe), Công nghệ Smart Amp'}, {'name': 'Webcam', 'value': '1080P FHD camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 4 vùng Có phím Copilot, Aura Sync'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu Quản trị viên BIOS và bảo vệ mật khẩu người dùng, Mô-đun TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'Tản nhiệt ROG Intelligent Cooling'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i3-1315U 1.2 GHz (10MB Cache, up to 4.5 GHz, 6 lõi, 8 luồng)'}, {'name': 'Mô tả CPU', 'value': '6 lõi, 8 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4 on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Có thể nâng cấp; Cần tháo vỏ dưới/trên'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (cần tháo lắp)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x (5Gbps), USB-C: 1x (5Gbps), HDMI: 1x (1.4), 3.5mm Combo Audio Jack: 1x, DC-in: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 1*1'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '32.49 x 21.39 x 1.79 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera HD 720p; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'Có cảm biến vân tay tích hợp với Touchpad'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay tích hợp với Touchpad, McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mật khẩu người dùng thiết lập BIOS, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Snapdragon X X1 26 100 (8 lõi, 8 luồng, up to 2.97GHz, 30MB Cache)'}, {'name': 'Mô tả CPU', 'value': 'Chip Qualcomm với NPU up to 45TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Qualcomm Adreno GPU'}, {'name': 'Mô tả card đồ họa', 'value': 'Tiến trình chip mới nên có thể không kết nối được với các thiết bị có driver cũ'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Qualcomm Hexagon NPU up to 45TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 2x (hỗ trợ hiển thị/cung cấp điện), Thunderbolt: N/A, HDMI: 1x, LAN: N/A, SD: N/A, 3.5mm: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.70 x 25.06 x 1.79 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.88 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Công nghệ Smart Amp, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello, có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím số Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, McAfee, BIOS Booting User Password Protection, BIOS setup user password, Microsoft Pluton security processor, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 40 (Total 6MB, up to 4.30GHz)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 40 (Total 6MB, up to 4.30GHz)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không thể nâng cấp)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 3.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250nits\nĐộ phủ màu 45% NTSC\nMàn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1 x (tốc độ dữ liệu lên đến 480 Mbps)\nUSB-C: 1 x (tốc độ dữ liệu lên đến 5 Gbps)\nThunderbolt: N/A\nHDMI: 1 x 1.4\nLAN: N/A\nSD: N/A\n3.5mm: 1 x Jack tai nghe / micro'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 1*1'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '32.55 x 21.39 x 1.79 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.38 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster\nLoa tích hợp\nMicrophone mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera HD 720p, có màn trập camera'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay tích hợp trên bàn di chuột\nPhần mềm bảo mật McAfee\nBảo vệ mật khẩu người dùng khi khởi động BIOS\nMô-đun nền tảng tin cậy TPM (dạng firmware)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'McAfee, Windows 11 Home'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 350 2.0GHz (8 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': '2.0GHz, 24MB Cache, up to 5.0GHz, 8 lõi, 16 luồng'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7, AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX 5060 8GB GDDR7; AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 x 16GB LPDDR5X 7500 on board'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A (RAM hàn chết trên bo mạch)'}, {'name': 'Ổ cứng', 'value': '1TB PCIe 4.0 NVMe M.2 SSD (2 Khe cắm M.2 hỗ trợ SATA hoặc NVMe, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'SRGB 100,00%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400nits, Tỷ lệ tương phản 1000:1, Độ phủ màu SRGB 100,00%, màn hình chống chói, G-Sync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Type-C USB 4 hỗ trợ DisplayPort / Sạc (40Gbps), 1x USB 3.2 Gen 2 Type-C hỗ trợ DisplayPort (10Gbps), 2x USB 3.2 Gen 2 Type-A (10Gbps), 1x đầu đọc thẻ (microSD) (UHS-II), 1x HDMI 2.1 FRL, 1x Giắc cắm âm thanh kết hợp 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '31.1 x 22.7 x 1.69 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.46 Kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '73WHrs, 4S1P, 4-cell Li-ion, Sạc lại từ 0-50% trong 30 phút'}, {'name': 'Sạc nhanh', 'value': 'Sạc lại từ 0-50% trong 30 phút'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ chống ồn AI, Dolby Atmos, Chứng nhận Hi-Res (cho tai nghe)'}, {'name': 'Webcam', 'value': 'Camera IR FHD 1080P cho Windows Hello'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Đèn đơn Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên BIOS và bảo vệ mật khẩu người dùng, Bộ xử lý bảo mật Pluton, Máy tính lõi bảo mật (Cấp độ 3)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'TUF Gaming series'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 210H, 8 lõi, 12 luồng, up to 4.8 GHz, 12MB Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 5 210H'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX 4050 6GB GDDR6 (194 AI TOPs), tích hợp Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': '194 AI TOPs'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Có thể nâng cấp; Cần tháo vỏ dưới/trên'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (cần tháo lắp)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Nhựa'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x (5Gbps), USB-C (Type-C): 1x (5Gbps, hỗ trợ hiển thị/cung cấp điện), Thunderbolt: N/A, HDMI: 1x (2.1 FRL), LAN: N/A, SD: N/A, 3.5mm: 1x (Giắc cắm âm thanh kết hợp)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.70 x 25.07 x 1.80 ~ 2.20 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.95 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '63WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô tích hợp'}, {'name': 'Webcam', 'value': '1080p FHD với màn trập camera'}, {'name': 'Micro', 'value': 'Micrô tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu người dùng thiết lập BIOS, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 210H 2.2 GHz (12MB Cache, up to 4.8 GHz, 8 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': '8 lõi, 12 luồng, xung nhịp tối đa 4.8 GHz, 12MB Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Có thể nâng cấp; Cần tháo vỏ dưới/trên'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (cần tháo lắp)'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2280 NVMe PCIe 4.0, có khe mở rộng lưu trữ SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45%'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 x, USB-C: 2 x (hỗ trợ xuất hình & cấp nguồn), Thunderbolt: N/A, HDMI: 1 x, LAN: 1 x, SD: N/A, 3.5mm: 1 x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '32.45 x 21.44 x 1.97 ~ 1.97 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.47 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '63WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh do Dirac cung cấp, Loa tích hợp'}, {'name': 'Webcam', 'value': 'Camera HD 720p, có màn trập camera'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Khe khóa bảo mật Kensington Nano (6 x 2.5 mm), Bảo vệ bằng mật khẩu người dùng khi khởi động BIOS, Mật khẩu người dùng trong thiết lập BIOS, Bảo vệ và bảo mật ổ cứng bằng mật khẩu, Hỗ trợ Absolute Persistence 2.0 (Computrace), TPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Snapdragon X X1 26 100 (8 lõi, 8 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Snapdragon X X1 26 100 (30MB Cache, up to 2.97GHz)'}, {'name': 'Tên card đồ họa', 'value': 'Qualcomm Adreno GPU'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Qualcomm Adreno GPU'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Qualcomm Hexagon NPU up to 45TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '95% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits, Độ phủ màu 95% DCI-P3, Tỷ lệ tương phản 1.000.000:1, 1.07 tỷ màu, Chống chói giảm 70% ánh sáng xanh có hại, Được chứng nhận bởi TÜV Rheinland'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB 3.2 Gen 1 Type-A, 2x USB 4.0 Gen 3 Type-C (hỗ trợ hiển thị/cấp nguồn), 1x HDMI 2.1 TMDS, 1x Giắc cắm âm thanh kết hợp 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.35 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Công nghệ Smart Amp, Loa tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại hỗ trợ Windows Hello, McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mật khẩu người dùng thiết lập BIOS, Bộ xử lý bảo mật Microsoft Pluton, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 225H 1.7 GHz (18MB Cache, up to 4.9 GHz, 14 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'On board (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits (Độ sáng tối đa 500nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, Gamut mapping, HDR True Black 500, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi 0.2ms, Giảm 70% ánh sáng xanh có hại, TÜV Rheinland-certified, Màn hình chăm sóc mắt SGS'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 2 (Thunderbolt 4), Thunderbolt: 2, HDMI: 1, LAN: N/A, SD: N/A, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Tri-band)2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2x Thunderbolt 4 hỗ trợ hiển thị/cung cấp điện'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.24 x 22.01 x 1.49 ~ 1.49 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.28 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 2S2P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello, Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền'}, {'name': 'Touchpad', 'value': 'Màn hình cảm ứng'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, McAfee, Trusted Platform Module (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 170 3.2GHz (8 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 170 3.2GHz (20MB Cache, up to 4.75 GHz, 8 lõi, 16 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB DDR5 on board + 8GB DDR5 SO-DIMM, Có thể nâng cấp; Cần tháo vỏ dưới/trên)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (2 khe)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 x 5 Gbps, USB-C: 2 x 5 Gbps (có hỗ trợ Power Delivery), Thunderbolt: N/A, HDMI: 1 x 1.4, LAN: N/A, SD: N/A, 3.5mm: 1 x Jack tai nghe/micro'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.97 x 23.25 x 1.99 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.70 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Microphone mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera HD 720p, có màn trập camera'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có phím số'}, {'name': 'Touchpad', 'value': 'Touchpad tích hợp với cảm biến vân tay'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay tích hợp trên Touchpad, Phần mềm bảo mật McAfee, Mật khẩu khởi động BIOS, Mật khẩu truy cập thiết lập BIOS, Mô-đun nền tảng tin cậy TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'McAfee'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 7 240H 2.5 GHz (10 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 7 240H, 2.5 GHz, 24MB Cache, up to 5.2 GHz, 10 lõi, 16 luồng'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5060, 8GB GDDR7, Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1x 16GB, nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Nhựa'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 3.2 Gen 1 Type-C (5Gbps), 2x USB 3.2 Gen 1 Type-A (5Gbps), 1x HDMI 2.1 FRL, 1x Giắc cắm âm thanh kết hợp 3.5mm, 1x DC-in'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.70 x 25.07 x 1.80 ~ 2.20 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.95 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '63WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô tích hợp'}, {'name': 'Webcam', 'value': '1080p FHD với màn trập camera'}, {'name': 'Micro', 'value': 'Micrô tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu người dùng thiết lập BIOS, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 170 3.2GHz (8 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 170 3.2GHz (20MB Cache, up to 4.75 GHz, 8 lõi, 16 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB DDR5 on board + 8GB DDR5 SO-DIMM, Có thể nâng cấp; Cần tháo vỏ dưới/trên)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (2 khe)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits, Độ phủ màu 45% NTSC, Bề mặt màn hình chống loá, Chứng nhận TÜV Rheinland'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB 2.0 Type-A (480Mbps), 1 x USB 3.2 Gen 1 Type-C (5Gbps), 1 x USB 3.2 Gen 1 Type-C (5Gbps hỗ trợ PD), 2 x USB 3.2 Gen 1 Type-A (5Gbps), 1 x HDMI 1.4, 1 x Jack âm thanh 3.5mm combo'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '31.71 x 22.20 x 1.99 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.60 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Mic đa hướng tích hợp'}, {'name': 'Webcam', 'value': 'Camera HD 720p; Có màn trập camera'}, {'name': 'Micro', 'value': 'Mic đa hướng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền LED'}, {'name': 'Touchpad', 'value': 'Có cảm biến vân tay tích hợp'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay tích hợp trong touchpad, McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mật khẩu người dùng trong thiết lập BIOS, Mô-đun TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13450HX, 10 lõi (6 P-cores and 4 E-cores), 2.4 GHz base clock, 20M Cache'}, {'name': 'Mô tả CPU', 'value': '13th Gen Intel Core i5-13450HX'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời, 8GB GDDR7 VRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB PCIe 4.0 NVMe M.2 SSD (2 Khe cắm M.2 hỗ trợ SATA hoặc NVMe, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 72,00% / SRGB 100,00% / Adobe 75,35%'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói, G-Sync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x LAN RJ45, 1x Thunderbolt 4 (hỗ trợ DisplayPort / G-SYNC - 40Gbps), 1x USB 3.2 Gen 2 Type-C (hỗ trợ DisplayPort / Sạc - 10Gbps), 3x USB 3.2 Gen 2 Type-A (10Gbps), 1x HDMI 2.1, 1x Giắc cắm âm thanh kết hợp 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax) (Triple band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Qua Thunderbolt 4 và HDMI)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.4 x 26.9 x 1.79 ~ 2.73 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.20 Kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '90WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ chống ồn AI, Dolby Atmos, Chứng nhận Hi-Res (cho tai nghe)'}, {'name': 'Webcam', 'value': 'Camera IR FHD 1080P cho Windows Hello'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên BIOS và bảo vệ mật khẩu người dùng, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 225H 1.7 GHz (18MB Cache, up to 4.9 GHz, 14 lõi, 14 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2, USB-C: 2, Thunderbolt: N/A, HDMI: 1, LAN: N/A, SD: N/A, 3.5mm: 1 (combo)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 1*1'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.79 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.46 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Microphone mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello; Có màn che bảo mật'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee (phần mềm bảo mật), Bảo vệ bằng mật khẩu người dùng khi khởi động BIOS, Mô-đun nền tảng tin cậy TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 350 2.0GHz (8 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': '24MB Cache, up to 5.0GHz'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không thể nâng cấp)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits (Độ sáng tối đa 500nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi 0.2ms, HDR True Black 500, Giảm 70% ánh sáng xanh có hại, TÜV Rheinland-certified, SGS Eye Care Display'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 3.2 Gen 2 Type-A (10Gbps), 2x USB 4.0 Gen 3 Type-C (hỗ trợ hiển thị/cung cấp điện 40Gbps), 1x HDMI 2.1 TMDS, 1x Giắc cắm âm thanh kết hợp 3.5mm, Đầu đọc thẻ SD 4.0'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Tri-band)2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '35.36 x 24.30 x 1.19 ~ 1.29 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.50 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '78WHrs, 2S2P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, Bộ xử lý bảo mật Microsoft Pluton, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Nhận diện khuôn mặt, Màn hình Oled, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 220 3.2GHz (6 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 220 3.2GHz (22MB Cache, up to 4.9GHz, 6 lõi, 12 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '95% DCI-P3, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 95% DCI-P3, 1.07 tỷ màu'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2, USB-C: 2, Thunderbolt: N/A, HDMI: 1, LAN: N/A, SD: N/A, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp, Microphone mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello, có màn trập camera'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee, Mật khẩu người dùng khi khởi động BIOS, Mật khẩu thiết lập BIOS, Mô-đun nền tảng tin cậy TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Snapdragon X X1 26 100 (8 lõi, 8 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Chip AI Qualcomm Hexagon NPU up to 45TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Qualcomm Adreno GPU'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Qualcomm Hexagon NPU up to 45TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '95% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói giảm 70% ánh sáng xanh có hại, Được chứng nhận bởi TÜV Rheinland'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 2x (hỗ trợ hiển thị/cấp nguồn), Thunderbolt: N/A, HDMI: 1x, LAN: N/A, SD: N/A, 3.5mm: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '35.70 x 25.07 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.74 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD 1080p; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím số Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại hỗ trợ Windows Hello, McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mật khẩu người dùng thiết lập BIOS, Bộ xử lý bảo mật Microsoft Pluton, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 226V 16GB 2.1 GHz (8MB Cache, up to 4.5 GHz, 8 lõi, 8 luồng)'}, {'name': 'Mô tả CPU', 'value': '8 lõi, 8 luồng, xung nhịp lên đến 4.5 GHz, 8MB Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 40TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X 16GB'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400 nits (Độ sáng tối đa 600 nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, Ánh xạ gam màu, HDR True Black 600, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'HDR được chứng nhận VESA, Giảm 70% ánh sáng xanh có hại'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB 3.2 Gen 1 Type-A (5Gbps), 2x Thunderbolt 4 hỗ trợ hiển thị/cấp nguồn (40Gbps), 1x HDMI 2.1 TMDS, 1x Jack âm thanh kết hợp 3.5mm, Khe đọc thẻ nhớ Micro SD'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Tri-band)2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2x Thunderbolt 4 hỗ trợ hiển thị/cấp nguồn'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.05 x 22.19 x 1.39 ~ 1.59 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.30 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp, Micrô tích hợp, Micrô mảng tích hợp, Harman/Kardon (Mainstream)'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello, có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng, không có phím số Có phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại hỗ trợ Windows Hello, McAfee, Bộ xử lý bảo mật Microsoft Pluton, Mô-đun Nền tảng Đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Nhận diện khuôn mặt, Màn hình Oled, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 225H 1.7 GHz (18MB Cache, up to 4.9 GHz, 14 lõi, 14 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Có thể nâng cấp; Cần tháo vỏ dưới/trên'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (Cần tháo vỏ)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits (Độ sáng tối đa 500 nits)'}, {'name': 'Độ phủ màu màn hình', 'value': '95% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói, Ánh sáng xanh thấp, giảm 70% ánh sáng xanh có hại'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 2x (hỗ trợ hiển thị/cấp nguồn), Thunderbolt: N/A, HDMI: 1x, LAN: N/A, SD: N/A, 3.5mm: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '35.70 x 25.06 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.70 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập riêng tư'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại hỗ trợ Windows Hello, McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 9 285H 2.9 GHz (24MB Cache, up to 5.4 GHz, 16 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500 nits (Độ sáng tối đa 1000 nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 500 nits\nĐộ sáng tối đa 1000 nits HDR\nĐộ phủ màu 100% DCI-P3\nTỷ lệ tương phản 1.000.000:1\nDisplay HDR True Black 1000\n1.07 tỷ màu\nGiảm 70% ánh sáng xanh có hại\nĐược chứng nhận bởi TÜV Rheinland\nSGS Eye Care Display'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 2, Thunderbolt: 2, HDMI: 1, LAN: N/A, SD: N/A, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Tri-band)2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2 x Thunderbolt 4 (hỗ trợ xuất hình / cấp nguồn)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.24 x 22.01 x 1.49 ~ 1.49 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.20 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 2S2P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp\nLoa tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello, có màn trập camera'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại (IR) hỗ trợ Windows Hello\nMcAfee\nMô-đun nền tảng tin cậy TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 9 HX 370 2.0GHz (12 lõi, 24 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 9 HX 370 2.0GHz (36MB Cache, up to 5.1GHz, 12 lõi, 24 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7, AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7; AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X 7500 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB PCIe 4.0 NVMe M.2 SSD (1 Khe cắm M.2 hỗ trợ SATA hoặc NVMe, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'DCI-P3 100%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 500nits, Tỷ lệ tương phản 1000000:1, G-Sync / Adaptive-Sync, Màn hình Nebula ROG Nebula Display, Dolby Vision HDR, Tản nhiệt thông minh ROG'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C 4 (hỗ trợ DisplayPort / Sạc 40Gbps), 1x USB 3.2 Gen 2 Type-C (hỗ trợ DisplayPort / Sạc / G-SYNC 10Gbps), 2x USB 3.2 Gen 2 Type-A (10Gbps), 1x đầu đọc thẻ (microSD) (UHS-II), 1x HDMI 2.1 FRL, 1x Giắc cắm âm thanh kết hợp 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Triple band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '31.1 x 22.0 x 1.59 ~ 1.63 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.50 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '73WHrs, 4S1P, 4-cell Li-ion, Sạc lại từ 0-50% trong 30 phút'}, {'name': 'Sạc nhanh', 'value': 'Sạc lại từ 0-50% trong 30 phút'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống 4 loa (loa trầm lực kép) với Công nghệ Smart Amply, 2 loa Tweeter, Công nghệ chống ồn AI, Dolby Atmos, Chứng nhận Hi-Res (cho tai nghe), Công nghệ Smart Amply'}, {'name': 'Webcam', 'value': 'Camera IR FHD 1080P cho Windows Hello'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng Với phím Copilot, Aura Sync'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên BIOS và bảo vệ mật khẩu người dùng, Bộ xử lý bảo mật Pluton, Máy tính lõi bảo mật (Cấp độ 3)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'Tản nhiệt thông minh ROG'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 255H 2.0 GHz (24MB Cache, up to 5.1 GHz, 16 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500 nits (Độ sáng tối đa 1000 nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Display HDR True Black 1000, Giảm 70% ánh sáng xanh có hại, Được chứng nhận bởi TÜV Rheinland, SGS Eye Care Display'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 2 (Thunderbolt 4), Thunderbolt: 2, HDMI: 1, LAN: N/A, SD: N/A, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Tri-band)2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2 x Thunderbolt 4 (hỗ trợ xuất hình / cấp nguồn)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.24 x 22.01 x 1.49 ~ 1.49 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.20 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 2S2P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello, có màn trập camera'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại (IR) hỗ trợ Windows Hello, McAfee, Mô-đun nền tảng tin cậy TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 210H (8 lõi, 12 luồng, up to 4.8 GHz, 12MB Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 5 210H, 8 lõi, 12 luồng, xung nhịp lên đến 4.8 GHz, 12MB Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX 3050 với 6GB GDDR6 VRAM, tích hợp Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Có thể nâng cấp; Cần tháo vỏ dưới/trên.'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (cần tháo lắp)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói, N/A (không đề cập công nghệ độc quyền cụ thể ngoài các thông số trên)'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 x, USB-C: 1 x (Type-C hỗ trợ xuất hình & sạc, 5Gbps), Thunderbolt: N/A, HDMI: 1 x (2.1), LAN: N/A, SD: N/A, 3.5mm: 1 x (Headphone/Microphone), DC-in: 1 x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.70 x 25.07 x 1.80 ~ 2.20 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.95 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '63WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micro tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD 1080p; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micro tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền và phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'BIOS setup user password, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 7 240H 2.5 GHz (24MB Cache, up to 5.2 GHz, 10 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': '10 lõi, 16 luồng, xung nhịp tối đa 5.2 GHz, 24MB Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': '6GB GDDR6, 194 AI TOPs, tích hợp Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': '194 AI TOPs'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Có thể nâng cấp; Cần tháo vỏ dưới/trên'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (cần tháo lắp)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Nhựa'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 3.2 Gen 1 Type-C (hỗ trợ hiển thị/cung cấp điện, tốc độ 5Gbps), 2x USB 3.2 Gen 1 Type-A (tốc độ 5Gbps), 1x HDMI 2.1 FRL, 1x Giắc cắm âm thanh kết hợp 3.5mm, 1x DC-in'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.70 x 25.07 x 1.80 ~ 2.20 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.95 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '63WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD 1080p; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu người dùng thiết lập BIOS, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 225H 1.7 GHz (18MB Cache, up to 4.9 GHz, 14 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB 3.2 Gen 1 Type-A, 2x USB 3.2 Gen 1 Type-C (hỗ trợ hiển thị/Sạc), 1x HDMI 1.4, 1x Giắc cắm âm thanh kết hợp 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, McAfee, BIOS Booting User Password Protection, BIOS setup user password, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 445'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 7 445'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'On board (Không thể nâng cấp)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits (tối đa 600nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi 0.2ms, True Black 600, Giảm 70% ánh sáng xanh có hại, SGS Eye Care'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 2 (Gen 2, Gen 3), Thunderbolt: 1 (qua USB-C), HDMI: 1, LAN: N/A, SD: N/A, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.24 x 22.01 x 1.49 ~ 1.49 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.20 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp, Micro đa hướng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello, với màn trập camera'}, {'name': 'Micro', 'value': 'Micro đa hướng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại (IR) hỗ trợ Windows Hello, McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mật khẩu người dùng trong thiết lập BIOS, Bộ xử lý bảo mật Microsoft Pluton, Mô-đun nền tảng tin cậy TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 7 150U 1.8 GHz (12MB Cache, up to 5.4 GHz, 10 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': '10 lõi, 12 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB DDR5 on board + 8GB DDR5 SO-DIMM, Có thể nâng cấp; Cần tháo vỏ dưới/trên)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250 nits\nĐộ phủ màu 45% NTSC\nBề mặt màn hình chống loá\nChứng nhận TÜV Rheinland'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB 2.0 Type-A (tốc độ đến 480Mbps), 1 x USB 3.2 Gen 1 Type-C (tốc độ đến 5Gbps), 2 x USB 3.2 Gen 1 Type-A (tốc độ đến 5Gbps), 1 x HDMI 1.4, 1 x Jack âm thanh 3.5mm combo, 1 x Cổng sạc DC-in'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 1*1'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '32.49 x 21.39 x 1.79 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster\nLoa tích hợp\nMic đa hướng tích hợp'}, {'name': 'Webcam', 'value': 'Camera HD 720p; Có màn trập camera'}, {'name': 'Micro', 'value': 'Mic đa hướng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet'}, {'name': 'Touchpad', 'value': 'Cảm biến vân tay tích hợp trong touchpad'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay tích hợp trong touchpad\nMcAfee\nBảo vệ mật khẩu người dùng khi khởi động BIOS\nMô-đun TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 445 ( 2.0 GHz - 4.6 GHz / 8MB / 6 nhân, 12 luồng ), GORGON POINT 6C (GPT3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 7 445, 6 nhân, 12 luồng'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2, USB-C: 2, Thunderbolt: N/A, HDMI: 1, LAN: N/A, SD: N/A, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.79 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.46 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Microphone mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello; Có màn che bảo mật'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại (IR) hỗ trợ Windows Hello; Phần mềm bảo mật McAfee; Bảo vệ khởi động bằng mật khẩu người dùng BIOS; Bộ xử lý bảo mật Microsoft Pluton; Mô-đun nền tảng tin cậy TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 7 240H 2.5 GHz (24MB Cache, up to 5.2 GHz, 10 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': '10 lõi, 16 luồng, xung nhịp tối đa 5.2 GHz, 24MB Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời, 8GB GDDR7'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Có thể nâng cấp; Cần tháo vỏ dưới/trên'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (cần tháo lắp)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Nhựa'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 3.2 Gen 1 Type-C (hỗ trợ hiển thị/cung cấp điện, tốc độ 5Gbps), 2x USB 3.2 Gen 1 Type-A (tốc độ 5Gbps), 1x HDMI 2.1 FRL, 1x Giắc cắm âm thanh kết hợp 3.5mm, 1x DC-in'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.70 x 25.07 x 1.80 ~ 2.20 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.95 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '63WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD 1080p; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu người dùng thiết lập BIOS, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 260 3.8GHz (8 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 260 3.8GHz (24MB Cache, up to 5.1 GHz, 8 lõi, 16 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7, AMD Radeon 780M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7; AMD Radeon 780M Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 16TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB PCIe 4.0 NVMe M.2 SSD (2 khe cắm M.2 hỗ trợ cả SATA hoặc NVMe, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '72% NTSC / 100% sRGB / 75.35% AdobeRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi 3 ms, Góc nhìn: 85°/85°/85°/85°, màn hình chống chói, NVIDIA G-Sync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x RJ45 LAN, 1 x USB 2.0 Type-A (480Mbps), 1 x USB 3.2 Gen 2 Type-C (DisplayPort, Power Delivery, G-SYNC, 10Gbps), 2 x USB 3.2 Gen 2 Type-A (10Gbps), 1 x USB-C USB 4 (DisplayPort, 40Gbps), 1 x HDMI 2.1 FRL, 1x 3.5mm Combo Audio Jack'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.4 x 26.9 x 1.79 ~ 2.57 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.20 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '90WHrs, 4S1P, 4-cell Li-ion, sạc từ 0-50% trong 30 phút'}, {'name': 'Sạc nhanh', 'value': 'Sạc từ 0-50% trong 30 phút'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ khử ồn AI, Dolby Atmos, Chứng nhận Hi-Res Audio (cho tai nghe)'}, {'name': 'Webcam', 'value': 'Camera hồng ngoại FHD 1080P dành cho Windows Hello'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng Với phím Copilot, Aura Sync, MUX Switch + NVIDIA Advanced Optimus'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu BIOS (quản trị viên & người dùng), Bộ xử lý bảo mật Pluton, Secured-core PC (Cấp độ 3)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'TUF Gaming series'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 255H 2.0 GHz (24MB Cache, up to 5.1 GHz, 16 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Có thể nâng cấp; Cần tháo vỏ dưới/trên'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (Cần tháo vỏ)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits (Độ sáng tối đa 500 nits)'}, {'name': 'Độ phủ màu màn hình', 'value': '95% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói, Ánh sáng xanh thấp, giảm 70% ánh sáng xanh có hại'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 2x (hỗ trợ hiển thị/cấp nguồn), Thunderbolt: N/A, HDMI: 1x, LAN: N/A, SD: N/A, 3.5mm: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '35.70 x 25.06 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.70 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập riêng tư'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại hỗ trợ Windows Hello, McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 225H 1.7 GHz (18MB Cache, up to 4.9 GHz, 14 lõi, 14 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 x, USB-C: 2 x, Thunderbolt: N/A, HDMI: 1 x, LAN: N/A, SD: N/A, 3.5mm: 1 x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 1*1'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.70 x 25.06 x 1.79 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.88 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Microphone mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello, có màn trập camera'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền và phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại (IR) hỗ trợ đăng nhập Windows Hello, Phần mềm bảo mật McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mô-đun nền tảng tin cậy TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'McAfee, Phần mềm bảo mật'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7 14650HX 2.2 GHz (16 lõi, 24 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7 14650HX, 2.2 GHz (30MB Cache, up to 5.2 GHz, 16 lõi, 24 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7, Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIe 4.0 NVMe M.2 SSD (2 Khe cắm M.2 hỗ trợ cả SATA hoặc NVMe, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '72% NTSC / 100% sRGB / 75.35% AdobeRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400 nits, Độ tương phản 1000:1, Chống chói, NVIDIA G-Sync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x RJ45 LAN, 1 x USB 3.2 Gen 2 Type-C (DisplayPort, Power Delivery, 10Gbps), 3 x USB 3.2 Gen 2 Type-A (10Gbps), 1 x HDMI 2.1 FRL, 1 x Jack tai nghe/mic 3.5 mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.4 x 26.9 x 1.79 ~ 2.73 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.20 Kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ khử ồn AI, Dolby Atmos, Chứng nhận Hi-Res Audio (cho tai nghe)'}, {'name': 'Webcam', 'value': '1080P FHD Camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng Với phím Copilot, Aura Sync, MUX Switch + NVIDIA Advanced Optimus'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bảo vệ bằng mật khẩu quản trị BIOS và mật khẩu người dùng, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 40 (2.8 GHz - 4.3 GHz/ 4MB/ 4 lõi, 8 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 40 (2.8 GHz - 4.3 GHz/ 4MB/ 4 lõi, 8 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5 on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 3.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250 nits\nĐộ phủ màu 45% NTSC\nMàn hình chống chói\nTÜV Rheinland'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB-A 2.0 (480Mbps), 1x USB-A 3.2 Gen 1 (5Gbps), 1x USB-C 3.2 Gen 1 (5Gbps), 1x HDMI 1.4, 1x jack tai nghe/mic 3.5mm, 1x cổng nguồn DC-in'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 1*1'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '36.03 x 23.25 x 1.79 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.63 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster\nLoa tích hợp\nMicrophone mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee\nBảo vệ mật khẩu người dùng khi khởi động BIOS\nMô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, Bảo mật vân tay'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 255H 2.0 GHz (24MB Cache, up to 5.1 GHz, 16 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB 3.2 Gen 1 Type-A, 2x USB 3.2 Gen 1 Type-C (hỗ trợ hiển thị/Sạc), 1x HDMI 1.4, 1x Giắc cắm âm thanh kết hợp 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, McAfee, BIOS Booting User Password Protection, BIOS setup user password, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 5 330'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 5 330'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '95% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits, Độ phủ màu 95% DCI-P3, Tỷ lệ tương phản 1.000.000:1, 1.07 tỷ màu, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 2x (hỗ trợ hiển thị/cấp nguồn), Thunderbolt: N/A, HDMI: 1x, LAN: N/A, SD: N/A, 3.5mm: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.59 ~ 1.86 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại hỗ trợ Windows Hello, McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mật khẩu người dùng thiết lập BIOS, Bộ xử lý bảo mật Microsoft Pluton, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 260 3.8GHz (8 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 260 3.8GHz (24MB Cache, up to 5.1 GHz, 8 lõi, 16 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics (Tích hợp)'}, {'name': 'Mô tả card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 16TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '95% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi 0.2 ms\nĐộ tương phản: 1.000.000:1\n1.07 tỷ màu\nChứng nhận TÜV Rheinland'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2, USB-C: 2, Thunderbolt: N/A, HDMI: 1, LAN: N/A, SD: N/A, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp\nMicro tích hợp (array)'}, {'name': 'Webcam', 'value': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micro tích hợp (array)'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại (IR) hỗ trợ Windows Hello\nMcAfee\nMật khẩu khởi động BIOS\nMật khẩu thiết lập BIOS\nTPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 445'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 7 445'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Có thể nâng cấp; Cần tháo vỏ dưới/trên'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (cần tháo lắp)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits (tối đa 500nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '95% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi 0.2ms, Giảm 70% ánh sáng xanh có hại'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 x, USB-C: 2 x, Thunderbolt: N/A, HDMI: 1 x, LAN: N/A, SD: N/A, 3.5mm: 1 x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '35.70 x 25.06 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.80 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp, Microphone mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello, có màn trập camera'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền và phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại (IR) hỗ trợ Windows Hello, McAfee, Bảo mật mật khẩu khởi động BIOS, Mật khẩu truy cập BIOS Setup, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 445'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 7 445'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '95% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi 0.2ms, Tỷ lệ tương phản 1.000.000:1, 1.07 tỷ màu'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2, USB-C: 2 (hỗ trợ xuất hình ảnh/cấp nguồn), Thunderbolt: N/A, HDMI: 1, LAN: N/A, SD: N/A, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp sẵn, Microphone mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello, có màn trập camera'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại (IR) hỗ trợ Windows Hello, Phần mềm bảo mật McAfee, Bảo vệ mật khẩu khởi động BIOS, Mật khẩu người dùng trong BIOS, Mô-đun nền tảng tin cậy TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'McAfee, Phần mềm bảo mật đi kèm'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 355 2.3 GHz (8 lõi, 8 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core Ultra 7 355, 2.3 GHz, 12MB Cache, up to 4.7 GHz, 8 lõi, 8 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel NPU up to 49TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm thêm)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '95% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi: 0.2 ms, Màn hình chống chói & chống phản xạ (AGLR), Giảm 70% ánh sáng xanh có hại, Chứng nhận TÜV Rheinland'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2, USB-C: 2 (Display/Power Delivery), HDMI: 1, LAN: N/A, SD: N/A, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp, Microphone mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello; Có màn trập camera'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee, Mật khẩu khởi động BIOS, Mật khẩu thiết lập BIOS, TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 255H 2.0 GHz (16 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '95% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits\nĐộ phủ màu 95% DCI-P3\nTỷ lệ tương phản 1.000.000:1\n1.07 tỷ màu\nGiảm 70% ánh sáng xanh có hại\nChứng nhận TÜV Rheinland'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2, USB-C: 2, HDMI: 1, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp\nMicro mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micro mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello\nMcAfee\nBảo vệ mật khẩu khởi động BIOS\nMật khẩu thiết lập BIOS\nTrusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 225H 1.7 GHz (18MB Cache, up to 4.9 GHz, 14 lõi, 14 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics (Tích hợp)'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '95% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits\nĐộ phủ màu 95% DCI-P3\nTỷ lệ tương phản 1.000.000:1\n1.07 tỷ màu\nGiảm 70% ánh sáng xanh có hại\nChứng nhận TÜV Rheinland'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2, USB-C: 2, HDMI: 1, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp\nMicro mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micro mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello\nMcAfee\nBảo vệ mật khẩu khởi động BIOS\nMật khẩu thiết lập BIOS\nTrusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI MAX+ 392 3.2GHz (12 lõi, 24 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI MAX+ 392 3.2GHz (80MB Cache, up to 5.0GHz, 12 lõi, 24 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 8060S Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon 8060S Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '64GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X 8533 on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'On board (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB PCIe 4.0 NVMe M.2 SSD (1 Khe cắm M.2 hỗ trợ cả SATA hoặc NVMe, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400 nits, Độ tương phản 1000:1, Độ phủ màu 100% sRGB, màn hình chống chói (AG)'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB-C USB 4 (DisplayPort, Sạc, 40Gbps), 1 x USB-C 3.2 Gen 2 (DisplayPort, 10Gbps), 2 x USB 3.2 Gen 2 Type-A (10Gbps), 1 x khe thẻ microSD (UHS-II, 312MB/s), 1 x HDMI 2.1 FRL, 1 x Jack tai nghe/mic 3.5 mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '31.1 x 22.7 x 1.69 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.48 Kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '73WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ khử ồn AI, Dolby Atmos, Chứng nhận Hi-Res Audio (cho tai nghe)'}, {'name': 'Webcam', 'value': 'Camera hồng ngoại FHD 1080P dành cho Windows Hello'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền đơn Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bảo vệ mật khẩu quản trị BIOS và mật khẩu người dùng'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'TUF Gaming series'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 9 465 2.0GHz (10 lõi, 20 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 9 465 2.0GHz (34MB Cache, up to 5.0GHz, 10 lõi, 20 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7, AMD Radeon 890M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7; AMD Radeon 890M Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X 7500 on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '1TB PCIe 4.0 NVMe M.2 SSD (1 Khe cắm M.2 hỗ trợ cả SATA hoặc NVMe, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'HDR 1000 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'Tỷ lệ tương phản 1.000.000:1'}, {'name': 'Công nghệ màn hình', 'value': 'Góc nhìn 85/85, màn hình chống chói, G-SYNC, ROG Nebula HDR Display, Dolby Vision HDR'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-C (1x USB4 40Gbps, hỗ trợ DisplayPort & sạc; 1x USB-C 3.2 Gen 2 10Gbps, hỗ trợ DisplayPort, sạc & G-SYNC; 2x USB-A 3.2 Gen 2 10Gbps; 1x khe thẻ microSD (UHS-II); 1x HDMI 2.1; 1x jack tai nghe/mic 3.5mm)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Triple band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '31.1 x 22.0 x 1.59 ~ 1.63 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.50 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '73WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống 4 loa (loa trầm lực kép) với công nghệ khuếch đại thông minh, 2 loa tweeter, Công nghệ khử tiếng ồn bằng AI, Dolby Atmos, Chứng nhận Hi-Res (cho tai nghe), Công nghệ Smart Amp'}, {'name': 'Webcam', 'value': 'Camera hồng ngoại FHD 1080P dành cho Windows Hello'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng Với phím Copilot, Aura Sync, MUX Switch + NVIDIA Advanced Optimus'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bảo vệ bằng mật khẩu quản trị BIOS và mật khẩu người dùng, Bộ xử lý bảo mật Pluton, Máy tính lõi bảo mật (Cấp độ 3)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H 2.4 GHz (10 cores, 16 Threads)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 10 nhân, 16 luồng, xung nhịp cơ bản 2.4 GHz, Cache 24MB, tối đa 4.9 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '8GB DDR4 on board + 8GB DDR4 SO-DIMM (Có thể nâng cấp; Cần tháo vỏ dưới/trên)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (cần tháo vỏ)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250nits, màn hình chống chói, TÜV Rheinland-certified'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 2.0 Type-A, 2x USB 3.2 Gen 1 Type-A, 1x USB 3.2 Gen 1 Type-C (hỗ trợ cấp nguồn), 1x HDMI 1.4, 1x Giắc cắm âm thanh kết hợp 3.5mm, 1x DC-in'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 1*1'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.97 x 23.25 x 1.99 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.70 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô tích hợp'}, {'name': 'Webcam', 'value': '720p HD với màn trập camera'}, {'name': 'Micro', 'value': 'Micrô tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee, BIOS Booting User Password Protection, BIOS setup user password, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7-258V 8 lõi, 8 luồng, 1.8 GHz (12MB Cache, up to 4.8 GHz)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU lên đến 47 TOPs, tổng hiệu năng AI lên đến 120 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU lên đến 47 TOPs, tổng hiệu năng AI lên đến 120 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500nits HDR'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi 0.2ms, Display HDR True Black 500, Giảm ánh sáng xanh 70%, TÜV Rheinland-certified, SGS Eye Care Display'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 2 (Thunderbolt 4), HDMI: 1 (2.1 TMDS), LAN: N/A, SD: N/A, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Tri-band)2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2x Thunderbolt 4 (hỗ trợ hiển thị)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.03 x 21.47 x 1.19 ~ 1.29 cm (W x H x D)'}, {'name': 'Trọng lượng', 'value': '1.20 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '72WHrs, 2S2P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp, Micrô mảng tích hợp harman/kardon (Cao cấp)'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp harman/kardon'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, Bộ xử lý bảo mật Microsoft Pluton, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home, Microsoft Office Home & Student 2021 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home & Student 2021 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 9 386H 2.1 GHz (18MB Cache, up to 4.9 GHz, 16 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core Ultra 9 386H, 16 lõi, 16 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics, Intel NPU up to 50TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500 nits (HDR tối đa 1100 nits)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, Gamut mapping, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'VESA DisplayHDR True Black 1000, Giảm 70% ánh sáng xanh có hại, SGS Eye Care Display'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1 x, USB-C: 2 x (Thunderbolt 4), HDMI: 1 x, LAN: N/A, SD: N/A, 3.5mm: 1 x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Triple band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 6.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2 x Thunderbolt 4 (hỗ trợ Display/Power Delivery)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.03 x 21.47 x 1.19 ~ 1.29 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.20 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '77WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD tích hợp chức năng hồng ngoại, hỗ trợ Windows Hello'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại hỗ trợ Windows Hello, Bộ xử lý bảo mật Microsoft Pluton, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Nhận diện khuôn mặt, Màn hình Oled, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 9 HX 370 2.0GHz (12 lõi, 24 luồng, 36MB Cache)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 9 HX 370 2.0GHz (36MB Cache, up to 5.1GHz, 12 lõi, 24 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5080 16GB GDDR7, AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5080 16GB GDDR7; AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X 8000'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không nâng cấp)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '2TB PCIe 4.0 NVMe M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'DCI-P3 100%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 500 nits, Tỷ lệ tương phản 1,000,000:1, Công nghệ G-Sync / Adaptive-Sync, Chứng nhận Pantone Validated, ROG Nebula Display, Hỗ trợ Dolby Vision HDR, Tản nhiệt ROG Intelligent Cooling'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB 4 Type-C (DisplayPort / Sạc / 40Gbps), 1 x USB 3.2 Gen 2 Type-C (DisplayPort / Sạc / G-Sync / 10Gbps), 2 x USB 3.2 Gen 2 Type-A (10Gbps), 1 x Đầu đọc thẻ microSD, 1 x HDMI 2.1 FRL, 1 x Jack 3.5mm combo'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Triple band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '31.1 x 22.0 x 1.59 ~ 1.83 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.57 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '73WHrs, 4S1P, 4-cell Li-ion, Sạc từ 0-50% trong 30 phút'}, {'name': 'Sạc nhanh', 'value': 'Sạc từ 0-50% trong 30 phút'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống 4 loa (woofer kép lực cao) với công nghệ khuếch đại thông minh, kèm 2 tweeter, Công nghệ khử ồn AI, Dolby Atmos, Chứng nhận Hi-Res (cho tai nghe), Công nghệ Smart Amp'}, {'name': 'Webcam', 'value': 'Camera hồng ngoại FHD 1080P dành cho Windows Hello'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet RGB 1 vùng có đèn nền Có phím Copilot, Aura Sync'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu Quản trị viên BIOS và bảo vệ mật khẩu người dùng, Bộ xử lý bảo mật Pluton, Máy tính Secured-core (Mức 3)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'Tản nhiệt ROG Intelligent Cooling'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 255H 2.0 GHz (24MB Cache, up to 5.1 GHz, 16 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'On board (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits (Độ sáng tối đa 500nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, Gamut mapping, HDR True Black 500, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi 0.2ms, Giảm 70% ánh sáng xanh có hại, TÜV Rheinland-certified, Màn hình chăm sóc mắt SGS'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 2 (Thunderbolt 4), Thunderbolt: 2, HDMI: 1, LAN: N/A, SD: N/A, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Tri-band)2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2x Thunderbolt 4 hỗ trợ hiển thị/cung cấp điện'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.24 x 22.01 x 1.49 ~ 1.49 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.28 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 2S2P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello, Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền'}, {'name': 'Touchpad', 'value': 'Màn hình cảm ứng'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, McAfee, Trusted Platform Module (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 350 2.0GHz (8 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 7 350 2.0GHz (24MB Cache, up to 5.0GHz, 8 lõi, 16 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics (Tích hợp)'}, {'name': 'Mô tả card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA™ NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp (Onboard)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits (Độ sáng đỉnh HDR 600nits)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400nits, Độ sáng đỉnh HDR 600nits, VESA CERTIFIED Display HDR True Black 600, 1.07 tỷ màu, Ánh sáng xanh ít gây hại hơn 70%, TÜV Rheinland-certified, SGS Eye Care Display'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1x (5Gbps), USB-C: 1x (10Gbps hỗ trợ hiển thị/cung cấp điện), USB 4.0 Gen 3 Type-C: 1x (40Gbps hỗ trợ hiển thị/cung cấp điện), HDMI: 1x (2.1 TMDS), 3.5mm: 1x (Giắc cắm âm thanh kết hợp)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.24 x 22.01 x 1.49 ~ 1.49 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.20 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, McAfee, BIOS Booting User Password Protection, BIOS setup user password, Microsoft Pluton security processor, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 210H 2.2 GHz (12MB Cache, up to 4.8 GHz, 8 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': '8 lõi, 12 luồng, xung nhịp tối đa 4.8 GHz, 12MB Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Có thể nâng cấp; Cần tháo vỏ dưới/trên'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (cần tháo lắp)'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2280 NVMe PCIe 4.0, có khe mở rộng lưu trữ SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45%'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2, USB-C: 2 (hỗ trợ xuất hình & cấp nguồn), Thunderbolt: N/A, HDMI: 1, LAN: 1 (RJ45 Gigabit Ethernet), SD: N/A, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.95 x 23.22 x 1.99 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.68 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '63WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh do Dirac cung cấp, Loa tích hợp'}, {'name': 'Webcam', 'value': 'Camera HD 720p, có màn trập camera'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Khe khóa bảo mật Kensington Nano (6 x 2.5 mm), Bảo vệ bằng mật khẩu người dùng khi khởi động BIOS, Mật khẩu người dùng trong thiết lập BIOS, Bảo vệ và bảo mật ổ cứng bằng mật khẩu, Hỗ trợ Absolute Persistence 2.0 (Computrace), TPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 350 2.0GHz (8 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': '24MB Cache, up to 5.0GHz'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Tích hợp (Integrated)'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không thể nâng cấp)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits (Độ sáng cực đại 600nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'HDR True Black 600, Ánh sáng xanh thấp ít hơn 70%, TÜV Rheinland, màn hình chăm sóc mắt SGS'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 2 (Gen 2, Gen 3 hỗ trợ hiển thị/sạc), Thunderbolt: 1 (qua USB 4.0 Gen 3 Type-C), HDMI: 1 (2.1 TMDS), LAN: N/A, SD: N/A, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.24 x 22.01 x 1.49 ~ 1.49 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.20 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, McAfee, BIOS Booting User Password Protection, BIOS setup user password, Microsoft Pluton security processor, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 9 465 2.0GHz (10 lõi, 20 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 9 465 2.0GHz (34MB Cache, up to 5.0GHz, 10 lõi, 20 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7, AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7; AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 16GB, không nâng cấp)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '1TB PCIe 4.0 NVMe M.2 SSD (2 Khe cắm M.2 hỗ trợ cả SATA hoặc NVMe, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 pixels (2.5K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'SRGB 100%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400 nits, Tỷ lệ tương phản 1000:1, Độ phủ màu SRGB 100%, màn hình chống chói, G-Sync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB-C USB 4 (DisplayPort, Power Delivery, 40Gbps), 1 x USB-C 3.2 Gen 2 (DisplayPort, G-SYNC, 10Gbps), 2 x USB 3.2 Gen 2 Type-A (10Gbps), 1 x microSD UHS-II (312MB/s), 1 x HDMI 2.1 FRL, 1 x jack âm thanh 3.5 mm, Micro tích hợp'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '31.1 x 22.7 x 1.69 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.46 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '73WHrs, 4S1P, 4-cell Li-ion, Sạc từ 0-50% trong 30 phút'}, {'name': 'Sạc nhanh', 'value': 'Sạc từ 0-50% trong 30 phút'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ khử ồn AI, Dolby Atmos, Chứng nhận Hi-Res Audio (cho tai nghe), Hỗ trợ Microsoft Cortana gần/xa (dịch vụ đã ngừng từ 2023)'}, {'name': 'Webcam', 'value': 'Camera hồng ngoại FHD 1080P dành cho Windows Hello'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền đơn Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bảo mật mật khẩu BIOS (quản trị viên & người dùng), Secured-core PC (Cấp độ 3), Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'MUX Switch + Optimus'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 9 285H 2.9 GHz (24MB Cache, up to 5.4 GHz, 16 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'On board (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits (Độ sáng tối đa 500nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, Gamut mapping, HDR True Black 500, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi 0.2ms, Giảm 70% ánh sáng xanh có hại, TÜV Rheinland-certified, Màn hình chăm sóc mắt SGS'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 2 (Thunderbolt 4), HDMI: 1 (2.1 TMDS), 3.5mm: 1, Thunderbolt: 2, Wi-Fi: Wi-Fi 7(802.11be) (Tri-band)2*2'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Tri-band)2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2x Thunderbolt 4 hỗ trợ hiển thị/cung cấp điện'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.24 x 22.01 x 1.49 ~ 1.49 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.28 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 2S2P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello, Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền'}, {'name': 'Touchpad', 'value': 'Màn hình cảm ứng'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, McAfee, Trusted Platform Module (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 350 2.0GHz (8 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 7 350 2.0GHz (24MB Cache, up to 5.0GHz, 8 lõi, 16 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (16GB Onboard + 16GB DDR5 SO-DIMM)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp thêm 16GB DDR5 SO-DIMM'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '95% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits, Độ phủ màu 95% DCI-P3, Tỷ lệ tương phản 1.000.000:1, 1.07 tỷ màu, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB 3.2 Gen 1 Type-A, 2x USB 3.2 Gen 1 Type-C (hỗ trợ hiển thị/cấp nguồn), 1x HDMI 2.1 TMDS, 1x Giắc cắm âm thanh kết hợp 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.59 ~ 1.86 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại hỗ trợ Windows Hello, McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mật khẩu người dùng thiết lập BIOS, Bộ xử lý bảo mật Microsoft Pluton, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7520U (4 lõi / 8 luồng, up to 4.3 GHz max boost)'}, {'name': 'Mô tả CPU', 'value': '4 lõi / 8 luồng, 4MB cache, up to 4.3 GHz max boost'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không thể nâng cấp)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 3.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250 nits, Độ phủ màu 45% NTSC, màn hình chống chói, TÜV Rheinland-certified'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1x, USB-C: 1x, Thunderbolt: N/A, HDMI: 1x, LAN: N/A, SD: N/A, 3.5mm: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 1*1'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '36.03 x 23.25 x 1.79 ~ 1.79 cm (W x H x D)'}, {'name': 'Trọng lượng', 'value': '1.80 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': '720p HD với màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee LiveSafe dùng thử miễn phí 30 ngày miễn phí, McAfee LiveSafe, Khởi động BIOS Bảo vệ mật khẩu người dùng, Mô-đun nền tảng đáng tin cậy (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7 14650HX 2.2 GHz (16 lõi, 24 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7 14650HX, 2.2 GHz (30MB Cache, up to 5.2 GHz, 16 lõi, 24 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5070 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5070 8GB GDDR7, Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 16GB'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB PCIe 4.0 NVMe M.2 SSD (2 Khe cắm M.2 hỗ trợ SATA hoặc NVMe, nâng cấp tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 72.00% / SRGB 100.00% / Adobe 75.35%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits, Tỷ lệ tương phản 1000:1, Màn hình chống chói, G-Sync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x LAN RJ45, 1x Thunderbolt 4 (hỗ trợ DisplayPort / G-SYNC), 1x USB 3.2 Gen 2 Type-C (hỗ trợ DisplayPort / cung cấp điện), 3x USB 3.2 Gen 2 Type-A, 1x HDMI 2.1, 1x 3.5mm Combo Audio Jack'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Qua Thunderbolt 4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.4 x 26.9 x 1.79 ~ 2.73 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.20 Kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '90WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ chống ồn AI, Dolby Atmos, Chứng nhận Hi-Res (cho tai nghe)'}, {'name': 'Webcam', 'value': '1080P FHD IR Camera for Windows Hello'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng Với phím Copilot Aura Sync'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên BIOS và bảo vệ mật khẩu người dùng, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core I5-13500H 2.6 GHz (18MB Cache, up to 4.7 GHz, 12 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core I5-13500H, 12 lõi, 16 luồng, xung nhịp lên đến 4.7 GHz, 18MB Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB (8GB onboard + 8GB SO-DIMM)'}, {'name': 'Loại RAM', 'value': 'DDR4 (8GB onboard + 8GB SO-DIMM)'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 khe DDR4 SO-DIMM'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp thêm 8GB RAM qua khe SO-DIMM còn trống'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 3.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': '16:9'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1620 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': 'HDR 600 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': '16:9, Độ sáng tối đa HDR 600 nits, Độ phủ màu 100% DCI-P3, tỷ lệ tương phản 1.000.000:1, HDR True Black 600, 1.07 tỷ màu, Ánh sáng xanh ít gây hại hơn 70%, Chứng nhận TÜV Rheinland, SGS Màn hình chăm sóc mắt'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 1x (Hỗ trợ sạc), Thunderbolt: N/A, HDMI: 1x (1.4), LAN: N/A, SD: N/A, 3.5mm: 1x Combo Audio Jack, DC-in: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 1*1'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.68 x 22.76 x 1.99 ~ 1.99 cm (W x H x D)'}, {'name': 'Trọng lượng', 'value': '1.70 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Built-in speaker, Built-in array microphone'}, {'name': 'Webcam', 'value': '720p HD camera với màn trập camera'}, {'name': 'Micro', 'value': 'Built-in array microphone'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mở khóa bằng vân tay, McAfee Dùng thử miễn phí 30 ngày, McAfee, BIOS Khởi động bằng mật khẩu người dùng Bảo vệ mật khẩu người dùng, Thiết lập BIOS mật khẩu người dùng, Mô-đun nền tảng đáng tin cậy (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, Bảo mật vân tay, Màn hình Oled'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 155H 1.4 GHz (16 lõi, 22 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core Ultra 7 155H, 1.4 GHz, 24MB Cache, up to 4.8 GHz, 16 lõi, 22 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Có (Ngụ ý từ Intel Core Ultra)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3200 x 2000 pixel (WQHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': '600nits HDR'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'HDR, Ánh sáng xanh ít gây hại hơn 70%, TÜV Rheinland-certified'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 2x Thunderbolt™ 4, HDMI: 1x 2.1 TMDS, 3.5mm Combo Audio Jack: 1x, Khe đọc thẻ nhớ: Có, Đầu đọc thẻ Micro SD: Có'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2x Thunderbolt™ 4 supports display / power delivery'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '35.36 x 24.69 x 1.39 ~ 1.59 cm (13.92" x 9.72" x 0.55" ~ 0.63")'}, {'name': 'Trọng lượng', 'value': '1.50 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Smart Amp Technology, harman/kardon'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello, Màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'RGB 1 vùng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee 30 ngày dùng thử miễn phí, Webcam IR với Windows Hello, McAfee, BIOS thiết lập mật khẩu người dùng, Mô-đun nền tảng đáng tin cậy (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H 2.4 GHz (24MB Cache, up to 4.9 GHz, 10 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': '10 lõi, 16 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB DDR4 on board + 8GB DDR4 SO-DIMM)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (có 1 khe trống)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '600nits HDR'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, HDR True Black 600, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi 0.2ms, Giảm 70% ánh sáng xanh có hại, Được chứng nhận bởi TÜV Rheinland, Màn hình chăm sóc mắt SGS'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 2.0 Type-A, 2x USB 3.2 Gen 1 Type-A, 1x USB 3.2 Gen 1 Type-C (hỗ trợ cấp nguồn), 1x HDMI 1.4, 1x Giắc cắm âm thanh kết hợp 3.5mm, 1x DC-in'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 1*1 +'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.68 x 22.76 x 1.99 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.70 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera HD 720p có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee, BIOS Booting User Password Protection, BIOS setup user password, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 255H 2.0 GHz (16 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core Ultra 7 255H 2.0 GHz (24MB Cache, up to 5.1 GHz); Intel AI Boost NPU up to 13TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits (Độ sáng tối đa 600nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, Ánh xạ gam màu, HDR True Black 600, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400nits, Độ sáng tối đa 600nits HDR, HDR True Black 600, 1.07 tỷ màu, Ít hơn 70% ánh sáng xanh có hại, TÜV Rheinland'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x (5Gbps), USB-C/Thunderbolt 4: 2x (40Gbps), HDMI: 1x (2.1 TMDS), 3.5mm Audio: 1x, Micro SD Card Reader: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 (802.11be) (Tri-band)2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2x Thunderbolt 4 hỗ trợ hiển thị/cung cấp điện'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '35.36 x 24.69 x 1.39 ~ 1.59 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.50 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp, Micrô tích hợp, Micrô mảng tích hợp harman/kardon (Chính thống)'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp harman/kardon (Chính thống)'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng với phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR có hỗ trợ Windows Hello, McAfee, Mật khẩu người dùng thiết lập BIOS, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 350 2.0GHz (8 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 7 350 2.0GHz (24MB Cache, up to 5.0GHz, 8 lõi, 16 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp (Onboard)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits (Độ sáng tối đa 600nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, Gamut mapping, Display HDR True Black 500, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'Giảm 70% ánh sáng xanh có hại, TÜV Rheinland-certified'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-C (1x hỗ trợ hiển thị/sạc 5Gbps, 1x hỗ trợ hiển thị/sạc 40Gbps), USB-A (2x USB 3.2 Gen 1 Type-A 5Gbps), HDMI (1x HDMI 2.1 TMDS), 3.5mm (1x Giắc cắm âm thanh kết hợp), Khe đọc thẻ nhớ (Có)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '35.36 x 24.69 x 1.39 ~ 1.59 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.50 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp, Micrô mảng tích hợp harman/kardon (Chính thống)'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp harman/kardon (Chính thống)'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng không có phím số Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, McAfee, Security Lock, Bộ xử lý bảo mật Microsoft Pluton, Trusted Platform Module (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 225H 1.7 GHz (18MB Cache, up to 4.9 GHz, 14 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits (Độ sáng tối đa 600nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, Gamut mapping, Display HDR True Black 600, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'Giảm 70% ánh sáng xanh có hại, TÜV Rheinland-certified'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 2x Thunderbolt 4, HDMI: 1x 2.1 TMDS, 3.5mm: 1x, Khe đọc thẻ nhớ: Có'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Tri-band)2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2x Thunderbolt 4 hỗ trợ hiển thị/cung cấp điện'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '35.36 x 24.69 x 1.39 ~ 1.59 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.50 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp, Micrô tích hợp, Micrô mảng tích hợp harman/kardon (Chính thống)'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello, Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp harman/kardon (Chính thống)'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng với phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR có hỗ trợ Windows Hello, McAfee, Mật khẩu người dùng thiết lập BIOS, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Nhận diện khuôn mặt, Màn hình Oled, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-12700H 2.3 GHz (24M Cache, up to 4.7 GHz, 6P+8E cores)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-12700H, 6P+8E cores'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '8GB DDR4 on board + 8GB DDR4 SO-DIMM'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp thêm 8GB DDR4 SO-DIMM'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 3.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '90Hz'}, {'name': 'Độ sáng màn hình', 'value': '600nits HDR peak brightness'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, HDR True Black 600, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gain phản hồi 0.2ms, SGS Eye Care Display, Giảm 70% ánh sáng xanh có hại'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 2.0 Type-A, 1x USB 3.2 Gen 1 Type-C, 2x USB 3.2 Gen 1 Type-A, 1x HDMI 1.4, 1x Headphone out, 1x DC-in'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '31.71 x 22.20 x 1.99 ~ 1.99 cm (W x H x D)'}, {'name': 'Trọng lượng', 'value': '1.60 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'Có cảm biến vân tay tích hợp với Touchpad'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay tích hợp với Touchpad, McAfee, BIOS Booting User Password Protection, BIOS setup user password, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 225H 1.7 GHz (18MB Cache, up to 4.9 GHz, 14 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400nits, Độ phủ màu 100% sRGB, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 2x (hỗ trợ hiển thị/sạc), Thunderbolt: N/A, HDMI: 1x, LAN: N/A, SD: N/A, 3.5mm: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 1*1'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.79 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.46 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': '1080p FHD với màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee, BIOS Booting User Password Protection, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7 14650HX 2.2 GHz (16 lõi, 24 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7 14650HX, 2.2 GHz (30MB Cache, up to 5.2 GHz, 16 lõi, 24 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7, Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '1TB PCIe 4.0 NVMe M.2 SSD (2 Khe cắm M.2 hỗ trợ SATA hoặc NVMe, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '240 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'DCI-P3 100%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 500nits, Tỷ lệ tương phản 1200:1, Độ phủ màu DCI-P3 100%, Màn hình chống chói, G-Sync, Màn hình Nebula ROG Nebula Display, Dolby Vision HDR, Tản nhiệt thông minh ROG'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Cổng LAN RJ45, 1x Thunderbolt 4 (hỗ trợ DisplayPort / Sạc / G-SYNC - 40Gbps), 1x USB 3.2 Gen 2 Type-C (hỗ trợ DisplayPort / Sạc - 10Gbps), 3x USB 3.2 Gen 2 Type-A (10Gbps), 1x HDMI 2.1 FRL, 1x Giắc cắm âm thanh kết hợp 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Triple band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Qua Thunderbolt 4 và HDMI)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.4 x 26.8 x 2.28 ~ 3.08 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.65 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '90WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ chống ồn AI, Dolby Atmos, Chứng nhận Hi-Res (cho tai nghe), Công nghệ Smart Amp'}, {'name': 'Webcam', 'value': 'Camera IR FHD 1080P cho Windows Hello'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 4 vùng Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên BIOS và bảo vệ mật khẩu người dùng, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'Tản nhiệt thông minh ROG'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 350 2.0GHz (8 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 7 350 2.0GHz (24MB Cache, up to 5.0GHz, 8 lõi, 16 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics (Tích hợp)'}, {'name': 'Mô tả card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 2x (hỗ trợ hiển thị/sạc), HDMI: 1x, 3.5mm: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.70 x 25.06 x 1.79 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.88 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello, Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, McAfee, BIOS Booting User Password Protection, Bộ xử lý bảo mật Microsoft Pluton, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7435HS 3.1GHz (8 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'CPU AMD Ryzen 7 7435HS với 20MB Cache, xung nhịp lên đến 4.5 GHz, 8 lõi, 16 luồng'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 2050'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời NVIDIA GeForce RTX 2050 4GB GDDR6'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2x SO-DIMM (2x 8GB, nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB PCIe 4.0 NVMe M.2 SSD (Nâng cấp tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': '16:9'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC, 62.5% sRGB, Adobe 47.34%'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói, Adaptive-Sync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x RJ45 LAN, 1x USB 3.2 Gen 2 Type-C support DisplayPort, 3x USB 3.2 Gen 1 Type-A, 1x HDMI 2.1 TMDS, 1x 3.5mm Combo Audio Jack'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.9 x 25.6 x 2.28 ~ 2.45 cm'}, {'name': 'Trọng lượng', 'value': '2.30 Kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '48WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống 2 loa, Công nghệ chống ồn AI, Phần mềm DTS, Chứng nhận Hi-Res'}, {'name': 'Webcam', 'value': '720P HD camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bảo vệ mật khẩu quản trị viên BIOS và mật khẩu người dùng, Khe bảo mật Kensington, Mô-đun nền tảng đáng tin cậy (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'TUF Gaming series'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-1355U (1.7 GHz, 12M Cache, up to 5.0 GHz, 10 lõi)'}, {'name': 'Mô tả CPU', 'value': '10 lõi, xung nhịp lên đến 5.0 GHz, 12M Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4 Onboard + 1 khe DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 khe (tối đa nâng cấp 40GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp tối đa lên 40GB'}, {'name': 'Ổ cứng', 'value': '512GB M.2 2280 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': '16:9'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền TN'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC: 45%'}, {'name': 'Công nghệ màn hình', 'value': 'LED Backlit, chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 2.0 Type-A, 1x USB 3.2 Gen 1 Type-A, 1x USB 3.2 Gen 1 Type-C, 1x USB 3.2 Gen 2 Type-C, 1x HDMI, 1x Jack cắm âm thanh, 1x RJ45 Gigabit Ethernet'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '32.69 x 21.45 x 1.99 cm (W x H x D)'}, {'name': 'Trọng lượng', 'value': '1.46 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh Dirac, Loa tích hợp'}, {'name': 'Webcam', 'value': '720p HD với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay, Khe bảo mật Kensington Nano (6x 2,5mm), Khởi động BIOS Bảo vệ mật khẩu người dùng, Mật khẩu người dùng thiết lập BIOS, Máy tính đã sẵn sàng từ BIOS, Bảo vệ và bảo mật mật khẩu người dùng HDD, Mô-đun nền tảng (TPM) 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen™ 5 7535HS Processor 3.3GHz (6 Nhân, 12 Luồng)'}, {'name': 'Mô tả CPU', 'value': 'Processor 3.3GHz (19MB Cache, up to 4.55 GHz, 6 Nhân, 12 Luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA® GeForce RTX™ 2050'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA® GeForce RTX™ 2050'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': '8GB DDR5-4800MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe SO-DIMM (Nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIe® 4.0 NVMe™ M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45%, SRGB 62.5%, Adobe 47.34%'}, {'name': 'Công nghệ màn hình', 'value': 'Tần số quét 144Hz, Độ sáng 250nits, Màn hình chống chói, Adaptive-Sync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Cổng LAN RJ45, 1x Cổng USB 3.2 Gen 2 Type-C hỗ trợ DisplayPort™, 3x Cổng USB 3.2 Gen 2 Type-A'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 (802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.9 x 25.6 x 2.28 ~ 2.45 cm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '2.30 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '48WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': '2 loa, Công nghệ chống ồn trí tuệ nhân tạo (AI), Phần mềm DTS, Chứng nhận Hi-Res'}, {'name': 'Webcam', 'value': '720P HD camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền, hỗ trợ 1 vùng màu RGB'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị BIOS và Bảo vệ mật khẩu người dùng, Khe an toàn Kensington Security Slot™, Module Nền tảng Tin cậy (TPM Firmware)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'TUF Gaming (Gaming)'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 3 100U 1.2 GHz (6 lõi, 8 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 3 100U 1.2 GHz (10MB Cache, up to 4.7 GHz, 6 lõi, 8 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR5 on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Có thể nâng cấp; Cần tháo vỏ dưới/trên'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (cần tháo lắp)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 cổng (USB 2.0 Type-A), USB-C: 1 cổng (USB 3.2 Gen 1 Type-C), Thunderbolt: N/A, HDMI: 1 cổng (HDMI 1.4), LAN: N/A, SD: N/A, 3.5mm: 1 cổng (Jack tai nghe / micro combo)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 1*1'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '32.49 x 21.39 x 1.79 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.40 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Microphone mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera HD 720p, có màn trập camera'}, {'name': 'Micro', 'value': 'Microphone mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay tích hợp trên bàn di chuột, Phần mềm bảo mật McAfee, Bảo vệ mật khẩu người dùng khi khởi động BIOS, Mô-đun nền tảng tin cậy TPM (TPM firmware)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'McAfee, Windows 11 Home'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-1240P'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-1240P'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 khe DDR4 trống'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp thêm 1 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe™ PCIe® 3.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '250 nit'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống loá, bảo vệ mắt tiêu chuẩn TÜV Rheinland-certified'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x HDMI 1.4, 1x 3.5mm Combo Audio Jack, 1x DC-in, 1x USB 2.0 Type-A, 1x USB 3.2 Gen 1 Type-C, 2x USB 3.2 Gen 1 Type-A'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'v5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.97 x 23.25 x 1.99 ~ 1.99 cm'}, {'name': 'Trọng lượng', 'value': '1.7 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa kép, công nghệ SonicMaster'}, {'name': 'Webcam', 'value': '720P'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bảo mật BIOS, Chip bảo mật TPM, Cảm biến vân tay'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 9 4900HS 3.0GHz up to 4.3GHz 12MB'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 9 4900HS, xung nhịp tối đa 4.3GHz, Cache 12MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX™ 2060 6GB GDDR6 with Max-Q Design (ROG Boost)'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX™ 2060, 6GB GDDR6 VRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIE G3X4'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'IPS'}, {'name': 'Tần số quét', 'value': '240Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB, Pantone Validated'}, {'name': 'Công nghệ màn hình', 'value': 'FHD (1920 x 1080) Non-Glare, IPS, 240Hz, 3ms, 72% NTSC, 100% sRGB, Pantone Validated, adaptive sync, Viền màn hình siêu mỏng, Wi-Fi 6'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '3x USB 3.2, 1x USB 3.2 Type-C with DisplayPort, HDMI, RJ-45, Có Khe đọc thẻ nhớ'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6 with Gig+ performance (802.11AX) (2*2 AX)'}, {'name': 'Bluetooth', 'value': 'v5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '36 x 25.2 x 1.99 ~ 1.99 cm'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell 76WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': '2x1W Speakers with Smart AMP Technology'}, {'name': 'Webcam', 'value': 'N/A'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 10 Home 64'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel® Core™ i3-N300 Processor 0.8 GHz (8 cores, 8 Threads)'}, {'name': 'Mô tả CPU', 'value': 'Intel® Core™ i3-N300 Processor 0.8 GHz (6MB Cache, up to 3.8 GHz, 8 cores, 8 Threads)'}, {'name': 'Tên card đồ họa', 'value': 'Intel® UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel® UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': '8GB LPDDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '256GB UFS 2.1'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền OLED/AMOLED'}, {'name': 'Tần số quét', 'value': '60HZ'}, {'name': 'Độ sáng màn hình', 'value': '550nits HDR'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'Tần số quét 60HZ, 550nits HDR, 100% DCI-P3, 1.07 tỷ màu, Màn hình Oled'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB 3.2 Gen 2 Type-C, 1x 3.5mm Combo Audio Jack, Micro SD card reader'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax)'}, {'name': 'Bluetooth', 'value': 'v5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '30.99 x 19.00 x 0.89 ~ 0.89 cm'}, {'name': 'Trọng lượng', 'value': '0.82 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50WHrs, 2S1P, 2-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'N/A'}, {'name': 'Webcam', 'value': '1080p FHD camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H 2.1 GHz (8 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 2.1 GHz (12MB Cache, up to 4.6 GHz, 8 lõi, 12 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'Intel HD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel HD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB DDR4 on board + 8GB DDR4 SO-DIMM, Có thể nâng cấp; Cần tháo vỏ dưới/trên)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (qua khe SO-DIMM)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250nits, Độ phủ màu 45% NTSC, màn hình chống chói, TÜV Rheinland-certified'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 2.0 Type-A (480Mbps), 1x USB 3.2 Gen 1 Type-C hỗ trợ cấp nguồn (5Gbps), 2x USB 3.2 Gen 1 Type-A (5Gbps), 1x HDMI 1.4, 1x Giắc cắm âm thanh kết hợp 3.5mm, 1x DC-in'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 1*1'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.97 x 23.25 x 1.99 ~ 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.70 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '42WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô tích hợp'}, {'name': 'Webcam', 'value': '720p HD camera với màn trập'}, {'name': 'Micro', 'value': 'Micrô tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee, BIOS Booting User Password Protection, BIOS setup user password, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 210H, 8 lõi, 12 luồng, up to 4.8 GHz, 12MB Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 5 210H'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời, 8GB GDDR7'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Có thể nâng cấp; Cần tháo vỏ dưới/trên'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (cần tháo lắp)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Nhựa'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 3.2 Gen 1 Type-C (5Gbps), 2x USB 3.2 Gen 1 Type-A (5Gbps), 1x HDMI 2.1, 1x Giắc cắm âm thanh kết hợp 3.5mm, 1x DC-in'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.70 x 25.07 x 1.80 ~ 2.20 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.95 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '63WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô tích hợp'}, {'name': 'Webcam', 'value': '1080p FHD với màn trập camera'}, {'name': 'Micro', 'value': 'Micrô tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu người dùng thiết lập BIOS, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13450HX 2.4 GHz (10 lõi: 6 P-cores and 4 E-cores)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13450HX, 2.4 GHz, 20M Cache, up to 4.6 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX 5050, 8GB GDDR7, kèm Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIe 4.0 NVMe M.2 SSD (2 Khe cắm M.2 hỗ trợ cả SATA hoặc NVMe, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 72% / sRGB 100% / Adobe 75.35%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits, Tỷ lệ tương phản 1000:1, Màn hình chống chói, G-Sync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x RJ45 LAN, 1 x Thunderbolt 4 (hỗ trợ DisplayPort / G-Sync 40Gbps), 1 x USB 3.2 Gen 2 Type-C (hỗ trợ DisplayPort / Power Delivery 10Gbps), 3 x USB 3.2 Gen 2 Type-A (10Gbps), 1 x HDMI 2.1, 1 x Jack âm thanh 3.5mm combo'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua Thunderbolt 4 và HDMI)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.4 x 26.9 x 1.79 ~ 2.73 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.20 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '90WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống 2 loa, Công nghệ khử ồn AI, Dolby Atmos, Chứng nhận Hi-Res (cho tai nghe)'}, {'name': 'Webcam', 'value': 'Camera hồng ngoại FHD 1080P dành cho Windows Hello'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet RGB 1 vùng có đèn nền Có phím Copilot, Aura Sync'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu Quản trị viên BIOS và bảo vệ mật khẩu người dùng, Mô-đun TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H 2.4 GHz (10 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 2.4 GHz, 24MB Cache, up to 4.9 GHz, 10 lõi, 16 luồng'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX3050 4GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX3050 4GB GDDR6, Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB DDR4 on board + 8GB DDR4 SO-DIMM)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp thêm 8GB RAM qua khe SO-DIMM còn trống'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, màn hình chống chói TÜV Rheinland'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 3.2 Gen 1 Type-C hỗ trợ cấp nguồn (5Gbps), 2x USB 3.2 Gen 1 Type-A (5Gbps), 1x HDMI 2.1 TMDS, 1x Giắc cắm âm thanh kết hợp 3.5mm, 1x DC-in, Đầu đọc thẻ SD 4.0'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.86 x 24.91 x 1.89 ~ 1.89 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.80 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'DC-in'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SonicMaster, Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': '720p HD với màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền với phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Khởi động BIOS Bảo vệ mật khẩu người dùng, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM), McAfee'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7435HS (8 lõi, 16 luồng, up to 4.5 GHz, 20MB Cache)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 7435HS, 8 lõi, 16 luồng, xung nhịp lên đến 4.5 GHz, 20MB Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 4GB GDDR6, AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời NVIDIA GeForce RTX 3050 với 4GB GDDR6 VRAM, kèm AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2x SO-DIMM (Nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe SO-DIMM'}, {'name': 'Ổ cứng', 'value': '512GB PCIe 4.0 NVMe M.2 SSD (2 khe cắm M.2 hỗ trợ SATA hoặc NVMe, Nâng cấp tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45%, SRGB 62.5%, Adobe 47.34%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250nits, Màn hình chống chói, Adaptive-Sync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x RJ45 LAN, 1x USB 3.2 Gen 2 Type-C hỗ trợ DisplayPort, 3x USB 3.2 Gen 1 Type-A, 1x HDMI 2.1 TMDS, 1x Giắc cắm âm thanh kết hợp 3.5 mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.9 x 25.6 x 2.28 ~ 2.45 cm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '2.30 Kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '48WHrs, 3S1P, 3-cell Li-ion, Sạc lại từ 0-50% trong 30 phút'}, {'name': 'Sạc nhanh', 'value': 'Sạc lại từ 0-50% trong 30 phút'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ chống ồn AI, Phần mềm DTS, Chứng nhận Hi-Res (cho tai nghe)'}, {'name': 'Webcam', 'value': '720P HD camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên BIOS và bảo vệ mật khẩu người dùng, Khe Kensington Security, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'TUF Gaming series'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H 2.1 GHz (8 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H 2.1 GHz (12MB Cache, up to 4.6 GHz, 8 lõi, 12 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB DDR5 on board + 8GB DDR5 SO-DIMM)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp qua khe SO-DIMM còn trống'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, màn hình chống chói, TÜV Rheinland-certified'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 2x (hỗ trợ hiển thị/Sạc), Thunderbolt: N/A, HDMI: 1x, LAN: N/A, SD: N/A, 3.5mm: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '31.52 x 22.34 x 1.59 ~ 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp, Micrô mảng tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập camera'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, McAfee, BIOS Booting User Password Protection, BIOS setup user password, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel® Core™ Ultra 5 125H 1.2 GHz (18MB Cache, tối đa 4.5 GHz, 14 nhân, 18 luồng); Intel® AI Boost NPU'}, {'name': 'Mô tả CPU', 'value': 'Intel® Core™ Ultra 5 125H 1.2 GHz (18MB Cache, tối đa 4.5 GHz, 14 nhân, 18 luồng); Intel® AI Boost NPU'}, {'name': 'Tên card đồ họa', 'value': 'Intel® Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel® Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel® AI Boost NPU'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Không hỗ trợ nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '512GB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': '16:10'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': '600 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, Đạt chuẩn DisplayHDR™ True Black 600'}, {'name': 'Công nghệ màn hình', 'value': 'Tỷ lệ 16:10, Độ sáng tối đa 600 nits, bao phủ 100% DCI-P3, Đạt chuẩn DisplayHDR™ True Black 600'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x Thunderbolt™ 4 Type-C®, 1 x USB 3.2 Gen 1 Type-A, 1 x HDMI® 2.1 (TMDS), 1 x Audio jack'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Dual band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth® 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '31.24 x 22.01 x 1.49 ~ 1.49 cm'}, {'name': 'Trọng lượng', 'value': '1.20 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 2S2P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Smart Amp harman/kardon'}, {'name': 'Webcam', 'value': 'FHD IR / 3DNR / ACS camera - nhận diện khuôn mặt'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Backlit keyboard'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee® 30 days free trial, IR webcam with Windows Hello support, McAfee®, Trusted Platform Module (TPM) 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7 14650HX 2.2 GHz (16 lõi, 24 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7 14650HX, 2.2 GHz (30MB Cache, up to 5.2 GHz, 16 lõi, 24 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7, Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600 SO-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIe 4.0 NVMe M.2 SSD (2 Khe cắm M.2 hỗ trợ cả SATA hoặc NVMe, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '72% NTSC / 100% sRGB / 75.35% AdobeRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400 nits, Độ tương phản 1000:1, Chống chói, NVIDIA G-Sync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x RJ45 LAN, 1 x USB 3.2 Gen 2 Type-C (DisplayPort, Power Delivery, 10Gbps), 3 x USB 3.2 Gen 2 Type-A (10Gbps), 1 x HDMI 2.1 FRL, 1 x Jack tai nghe/mic 3.5 mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E(802.11ax) (Triple band) 2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.4 x 26.9 x 1.79 ~ 2.73 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.20 Kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ khử ồn AI, Dolby Atmos, Chứng nhận Hi-Res Audio (cho tai nghe)'}, {'name': 'Webcam', 'value': '1080P FHD Camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền RGB 1 vùng Với phím Copilot, Aura Sync, MUX Switch + NVIDIA Advanced Optimus'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bảo vệ bằng mật khẩu quản trị BIOS và mật khẩu người dùng, Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'CPU AMD Ryzen AI 9 465 (2.0 GHz - 5.0 GHz/ 24MB/ 10 nhân, 20 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD XDNA NPU up to 50TOPS'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 880M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD XDNA NPU up to 50TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X on board'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'On board (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': '500 nits (Độ sáng đỉnh HDR 1000 nits)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, Gamut mapping, Tỷ lệ tương phản: 1.000.000:1, VESA DisplayHDR True Black 1000, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'Giảm 70% ánh sáng xanh, SGS Eye Care Display'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 2, Thunderbolt: 2 (qua USB 4.0 Gen 3 Type-C), HDMI: 1, LAN: N/A, SD: 1, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Tri-band)2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '35.36 x 24.30 x 1.19 ~ 1.29 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.50 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '83WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp, Micro tích hợp (array microphone)'}, {'name': 'Webcam', 'value': 'Camera FHD tích hợp chức năng hồng ngoại, hỗ trợ Windows Hello'}, {'name': 'Micro', 'value': 'Micro tích hợp (array microphone)'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Chiclet có đèn nền Với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam hồng ngoại (IR) hỗ trợ Windows Hello, Bộ xử lý bảo mật Microsoft Pluton, Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Nhận diện khuôn mặt, Màn hình Oled, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 9 285H 2.9 GHz (16 lõi, 16 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost NPU up to 13'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost NPU up to 13'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB M.2 NVMe PCIe 4.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits (Độ sáng tối đa 500nits HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3, Gamut mapping, HDR True Black 500, 1.07 tỷ màu'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi 0.2ms, Giảm 70% ánh sáng xanh có hại'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 2 (Thunderbolt 4), HDMI: 1 (2.1 TMDS), 3.5mm: 1, Thunderbolt: 2, Wi-Fi: Wi-Fi 7(802.11be) (Tri-band)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7(802.11be) (Tri-band)2*2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2x Thunderbolt 4 hỗ trợ hiển thị/cung cấp điện'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Mg-Al'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Mg-Al'}, {'name': 'Kích thước', 'value': '31.35 x 21.79 x 1.46 ~ 1.99 cm (Dài x Rộng x Dày), Kích thước cho bàn phím: 31.28 x 20.90 x 0.51 ~ 0.53 cm'}, {'name': 'Trọng lượng', 'value': '1.65 kg (Tổng), 1.35 kg (Máy), 0.30 kg (Bàn phím)'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '75WHrs, 4S1P, 4-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Công nghệ Smart Amp, Loa tích hợp'}, {'name': 'Webcam', 'value': 'Camera FHD có chức năng IR hỗ trợ Windows Hello'}, {'name': 'Micro', 'value': 'Micrô mảng tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím mềm'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Webcam IR hỗ trợ Windows Hello, Trusted Platform Module (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel® Core I5-1135G7, upto 4.20GHz, 4 cores 8 threads, 8MB Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5 thế hệ 11, 4 nhân 8 luồng, xung nhịp tối đa 4.20GHz, bộ nhớ cache 8MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA® GeForce® MX330 2GB GDDR5'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời NVIDIA GeForce MX330 với 2GB GDDR5'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': 'N/A'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB PCIe® Gen3 x2 SSD M.2'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': '16:9'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': '14.0 inch (16:9) Đèn LED nền FHD (1920x1080) 60Hz Chống lóa'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 cổng USB 2.0, 1 x Kiểu A USB 3.1 (Thế hệ 1), 1 x Kiểu C USB3.0 (USB3.1 thế hệ 1), 1 x HDMI, 1 giắc cắm âm thanh COMBO'}, {'name': 'Wi-Fi', 'value': 'Tích hợp Wi-Fi 5 (802.11 ac)'}, {'name': 'Bluetooth', 'value': 'Bluetooth® 5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '324.9 x 215 x 17.9 mm (WxDxH)'}, {'name': 'Trọng lượng', 'value': '1.45Kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell, 42 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'N/A'}, {'name': 'Webcam', 'value': 'N/A'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 10 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'In Laser đen trắng'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Pentium Silver N6000'}, {'name': 'Mô tả CPU', 'value': 'Intel Pentium Silver N6000'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'LPDDR4X'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '256GB M.2 NVMe™ PCIe® 3.0 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền OLED/AMOLED'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'OLED/AMOLED, Cảm ứng, Xoay gập 360 độ (2 in 1)'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB 3.2 Gen 2 Type-C, 1x 3.5mm Combo Audio Jack, 1x Micro SD card reader'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6(802.11ax)'}, {'name': 'Bluetooth', 'value': 'v5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '30.99 x 19.00 x 0.79 ~ 0.79 cm'}, {'name': 'Trọng lượng', 'value': '0.78 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50WHrs, 3S1P, 3-cell Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'N/A'}, {'name': 'Webcam', 'value': 'HD 720p'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, Màn hình cảm ứng, Xoay gập 360 độ (2 in 1)'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 120U (Up to 5Ghz, 12Mb Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 5 120U (Up to 5Ghz, 12Mb Cache)'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 khe Onboard + 1 khe trống nâng cấp tối đa 32GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB'}, {'name': 'Ổ cứng', 'value': '512GB M.2 PCIe NVMe (nâng cấp tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền WVA'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nit'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x Khe đọc thẻ SD, 1 x Jack tai nghe/micrô 3.5 mm, 1 x USB 3.2 Gen 1 Type-A, 1 x HDMI 1.4, 1 x USB 3.2 Gen 2 Type-C, 1 x USB 3.2 Gen 1 Type-A'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314 x 226.15 x 18.07 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.67 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Li-ion 4-Cell Battery, 54WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek'}, {'name': 'Webcam', 'value': 'Có'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home, Single Language English + Office Home & Student 2024'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Office Home & Student 2024'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 3 -100U'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 3 -100U'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Nâng cấp tối đa 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A (2.0), USB Type-C (USB 3.2 Gen 1), HDMI 1.4, Khe thẻ SD, Cổng âm thanh đa năng'}, {'name': 'Wi-Fi', 'value': 'Realtek RTL8821CE hoặc Realtek RTL8852BE'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0 hoặc 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '358.50 x 235.56 x 18.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.90 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 41 Wh hoặc 4-cell, 54 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204 hoặc Realtek ALC3254'}, {'name': 'Webcam', 'value': 'HD RGB camera ( 1280 x 720 (HD) at 30 fps ), 0.92 megapixel'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Tặng kèm Phần mềm Win 11 Pro 64 BIT cho 1 máy vĩnh viễn (Máy nguyên bản FreeOS)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Tặng kèm Phần mềm Win 11 Pro 64 BIT cho 1 máy vĩnh viễn (Máy nguyên bản FreeOS)'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-1334U'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-1334U'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, tối đa 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD, nâng tối đa 1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB 2.0 (1), USB 3.2 gen 1 (1), USB loại C (1), HDMI 1.4 (1), Khe cắm thẻ SD (1), Cổng âm thanh đa năng (1)'}, {'name': 'Wi-Fi', 'value': 'Realtek RTL8821CE hoặc Realtek RTL8852BE'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0 hoặc 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '358.50 x 235.56 x 18.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.62 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 cell, 41Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204 hoặc Realtek ALC3254'}, {'name': 'Webcam', 'value': '0.92 megapixel / 1280 x 720 (HD) at 30 fps'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5 1334U'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5 thế hệ 13, dòng U'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '512GB NVME 2230 - Nâng cấp tối đa 1TB - Dư 1 Slot HDD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Khe cắm thẻ SD, USB 2.0 (480 Mbps), Cổng âm thanh đa năng, HDMI 1.4, USB 3.2 Gen 1 (5 Gbps), USB 3.2 Gen 1 Type-C (5 Gbps)'}, {'name': 'Wi-Fi', 'value': 'Realtek RTL8821CE hoặc Realtek RTL8852BE'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0 hoặc 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '235.56 x 358.50 x 16.96 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.90 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 41 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204 hoặc Realtek ALC3254'}, {'name': 'Webcam', 'value': 'HD RGB camera ( 1280 x 720 (HD) at 30 fps), 0.92 megapixel'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Free OS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Ryzen 5 7530U'}, {'name': 'Mô tả CPU', 'value': 'Tốc độ CPU (Base): 2.0 GHz Tốc độ CPU tối đa (turbo boost): 4.5 GHz Bộ nhớ đệm: 12 MB'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 PCIe NVMe nâng cấp lên đến 1TB 1 khe SSD M2 đã sữ dụng'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 1 (data only), Thunderbolt: N/A, HDMI: 1, LAN: N/A, SD: 1, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 5'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '358.50 x 235.56 x 18.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.63 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-Cell Battery, 41WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204'}, {'name': 'Webcam', 'value': 'HD camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language English + Microsoft Office Home & Student 2024 + Microsoft 365 Basic (1 năm)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home & Student 2024 + Microsoft 365 Basic (1 năm)'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-1334U thế hệ thứ 13 / 10 nhân 12 luồng / up to 4.6 GHz, 12MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-1334U thế hệ thứ 13 / 10 nhân 12 luồng / up to 4.6 GHz, 12MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel UMA Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel UMA Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'DDR5 ( 4400 MT/s )'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB+16GB, tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '1 khe tối đa 1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 1 (với Power Delivery và DisplayPort), Thunderbolt: N/A, HDMI: 1.4, LAN: N/A, SD: Có, 3.5mm: Có'}, {'name': 'Wi-Fi', 'value': 'Realtek RTL8852BE / Realtek RTL8851BE'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '16.90 x 18.07 x 19.90 mm'}, {'name': 'Trọng lượng', 'value': '1.690 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 cell 41 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3254'}, {'name': 'Webcam', 'value': 'FHD RGB ( 1920 x 1080 (FHD) at 30 fps )'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'AI hotkey backlit keyboard'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Windows 11 Home'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Nhập khẩu chính hãng'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-1355U thế hệ thứ 13 / 10 nhân 12 luồng / 1.20 GHz to 5.0GHz, 12MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-1355U thế hệ thứ 13 / 10 nhân 12 luồng / 1.20 GHz to 5.0GHz, 12MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 2666 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2x 8GB, tối đa 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD (1 Slot SSD Tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'WVA'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45%'}, {'name': 'Công nghệ màn hình', 'value': 'Góc nhìn rộng (WVA), màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Đầu nối nguồn, 1x HDMI 1.4, 1x USB 3.2 Gen 1, 1x Khe cắm thẻ SD, 1x USB 2.0, 1x Cổng tai nghe 3.5mm, 1x Cổng Lan, 1x Type C'}, {'name': 'Wi-Fi', 'value': 'Realtek Wi-Fi 5 RTL8821CE, 802.11ac'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Carbon'}, {'name': 'Chất liệu vỏ trên', 'value': 'Carbon'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Carbon'}, {'name': 'Kích thước', 'value': '1.69 x 35.8 x 23.5 mm'}, {'name': 'Trọng lượng', 'value': '1.66 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '41Wh , 3Cell'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204/Realtek ALC3254'}, {'name': 'Webcam', 'value': 'HD - 1280 x 720 (HD) ở tốc độ 30 khung hình/giây - Công nghệ cảm biến CMOS'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Free OS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen™ R7-3700U Processor, 4 nhân 8 luồng, 4MB Cache'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen™ R7-3700U Processor, 2.30GHz up to 4.00GHz, 4 nhân 8 luồng, 4MB Cache'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon™ RX Vega 10 Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon™ RX Vega 10 Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': 'N/A'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 PCIe NVMe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'WVA Display'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'FHD Anti-glare LED Backlight Non-Touch Narrow Border'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x USB 3.2 Gen1 Type-A ports, 1 x USB 2.0 port, 1 x HDMI 1.4b, 1 x microSD card slot, 1 x Universal Audio Jack'}, {'name': 'Wi-Fi', 'value': 'WiFi 802.11ac 1x1'}, {'name': 'Bluetooth', 'value': 'v5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '328.70 mm x 239.50 mm x 18.10 mm ~ 19.90 mm'}, {'name': 'Trọng lượng', 'value': '1.59 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3Cell 42WHrs'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'N/A'}, {'name': 'Webcam', 'value': 'N/A'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 10 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'In Laser đen trắng'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 226V (8 lõi, up to 4.5 GHz, 40 TOPS NPU)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core Ultra 5 226V, 8 lõi, xung nhịp lên đến 4.5 GHz, tích hợp NPU 40 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': '40 TOPS NPU'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp (Onboard)'}, {'name': 'Ổ cứng', 'value': '1TB M.2 PCIe NVMe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 pixels (2.5K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền WVA'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nit'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'HDMI: 1, Thunderbolt: 1, USB-A: 1, USB-C: 1, LAN: N/A, SD: Có, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '1 (qua HDMI) và 1 (qua Thunderbolt 4.0)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '356.78 x 250.60 x 16.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.87 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4-Cell Battery, 64WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek'}, {'name': 'Webcam', 'value': 'Có'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Có'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home, Single Language English + Office Home & Student 2024'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Office Home & Student 2024'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7530U'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 7530U'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, tối đa 24GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB'}, {'name': 'Ổ cứng', 'value': '1TB SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x Khe đọc thẻ SD, 1 x USB 2.0, 1 x Cổng âm thanh đa năng (Universal Audio), 1 x HDMI 1.4, 1 x USB 3.2 Gen 1, 1 x USB Type-C'}, {'name': 'Wi-Fi', 'value': 'Realtek RTL8821CE hoặc Realtek RTL8852BE'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0 hoặc 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '358.50 x 235.56 x 18.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.90 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 41 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204 hoặc Realtek ALC3254'}, {'name': 'Webcam', 'value': 'HD RGB camera (1280 x 720 (HD) at 30 fps), 0.92 megapixel'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 7 150U (12MB Cache, Turbo Boost 5.4 GHz)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 7 150U (12MB Cache, Turbo Boost 5.4 GHz)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce MX570A 2GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce MX570A 2GB GDDR6, Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, nâng tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe Gen4x4 (M.2 2230)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền WVA'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2; USB-C: 1 (hỗ trợ Power Delivery, DisplayPort 1.4); Thunderbolt: N/A; HDMI: 1; LAN: N/A; SD: 1; 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314.00 x 226.15 x 18.07 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.54 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4-Cell Battery, 54WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3254'}, {'name': 'Webcam', 'value': '1280 x 720 (HD) at 30 fps'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bảo mật vân tay'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home, Single Language + Microsoft Office Home 2024 + Microsoft 365 Basic 1 year subscription'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic 1 year subscription'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7730U'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 7730U'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe ram tối đa 16GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x Khe thẻ SD, 1 x USB-A (USB 2.0, 480Mbps), 1 x Cổng Universal Audio, 1 x HDMI 1.4, 1 x USB-A (USB 3.2 Gen 1, 5Gbps), 1 x USB-C (USB 3.2 Gen 1, 5Gbps)'}, {'name': 'Wi-Fi', 'value': 'Realtek RTL8821CE hoặc Realtek RTL8852BE'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0 hoặc 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '235.56 x 358.50 x 16.96 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.90 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 41 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204 hoặc Realtek ALC3254'}, {'name': 'Webcam', 'value': 'Camera HD RGB (1280 x 720 (HD) ở tốc độ 30 khung hình/giây), 0.92 megapixel'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'Màn hình cảm ứng'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-1355U'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-1355U'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 2666MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (tùy thuộc vào khe còn trống)'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền WVA'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 3.2 Gen 1, 1x USB 2.0, 1x USB 3.2 Gen 1 Type-C (DisplayPort Alt), 1x 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 11ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '358.50 x 235.56 x 18.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.66 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'N/A'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'N/A'}, {'name': 'Webcam', 'value': 'HD'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic đăng ký 1 năm, McAfee LiveSafe 1 năm (5 thiết bị)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic, McAfee LiveSafe'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 236V vPro'}, {'name': 'Mô tả CPU', 'value': 'Intel Core Ultra 5 236V vPro'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics 130V'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Arc Graphics 130V'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x 8533 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp (Onboard)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 2230 có thể nâng cấp tối đa 2TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Thunderbolt 4 (USB-C/USB4, hỗ trợ DisplayPort Alt Mode & Power Delivery): 2; USB-A (USB 3.2 Gen 1 – 1 cổng PowerShare): 2; HDMI 2.1 (TMDS): 1; Jack tai nghe 3,5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 BE201'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A (Chỉ liệt kê các cổng kết nối sẵn có)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '300 x 207.5 x 19.79 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.34 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 45 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Cirrus Logic CS42L43'}, {'name': 'Webcam', 'value': 'FHD RGB'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Led trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Vân tay'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 7 150U (12MB Cache, 1.80GHz and up to 5.4 GHz)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 7 150U (12MB Cache, 1.80GHz and up to 5.4 GHz)'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB M.2 PCIe NVMe SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền WVA'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'HDMI: 1 x 1.4, USB 3.2 Gen 1: 2 x (5 Gbps), USB 3.2 Gen 2 Type-C (DP 1.4, Power Delivery): 1 x, Universal audio jack: 1 x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '357.30 x 250.60 x 16.74 - 18.23 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-Cell Battery, 41WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3254'}, {'name': 'Webcam', 'value': '1280 x 720 (HD) at 30 fps'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bảo mật vân tay'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home, Single Language + Microsoft Office Home 2024 + Microsoft 365 Basic 1 year subscription'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic 1 year subscription'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5 1334U'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5 1334U'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (nâng cấp tối đa 24GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A (2.0), USB-C, HDMI 1.4, Cổng âm thanh đa năng, Khe đọc thẻ SD'}, {'name': 'Wi-Fi', 'value': 'Realtek RTL8821CE hoặc Realtek RTL8852BE'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0 hoặc 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '358.50 x 235.56 x 18.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.90 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 41 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204 hoặc Realtek ALC3254'}, {'name': 'Webcam', 'value': 'HD RGB camera ( 1280 x 720 (HD) at 30 fps), 0.92 megapixel'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'Màn hình cảm ứng'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 250 (8 lõi, up to 5.1Ghz)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 250 (8 lõi, up to 5.1Ghz)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 So-DIMM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB M.2 PCIe NVMe SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền WVA'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, Hỗ trợ ComfortView Plus'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x HDMI 1.4, 1 x Khe thẻ SD, 1 x Jack âm thanh đa năng, 2 x USB 3.2 Gen 1 (5 Gbps), 1 x USB 3.2 Gen 2 Type-C (10 Gbps, Power Delivery, DisplayPort 1.4)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314.00 x 226.15 x 16.69 - 18.07 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.65 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin liền, 3-Cell Battery, 41WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204'}, {'name': 'Webcam', 'value': '1280 x 720 (HD) at 30 fps'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Không'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Office Home 2024 + 1 năm sử dụng Microsoft 365 Basic (miễn phí 1 năm, hết phải gia hạn)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft 365 Basic (miễn phí 1 năm, hết phải gia hạn)'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-1355U'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-1355U'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (nâng cấp tối đa 24GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB'}, {'name': 'Ổ cứng', 'value': '1TB SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'SD card / USB 2.0 / Cổng âm thanh đa năng / HDMI 1.4 / USB 3.2 Gen 1 / USB Type-C'}, {'name': 'Wi-Fi', 'value': 'Realtek RTL8821CE hoặc Realtek RTL8852BE'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0 hoặc 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '358.50 x 235.56 x 18.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.90 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 41 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204 hoặc Realtek ALC3254'}, {'name': 'Webcam', 'value': '2.00 megapixel / 1920 x 1080 (FHD) at 30 fps'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5 1334U (8 lõi / 12 luồng, up to 4.60 GHz, 12 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5 1334U, 8 lõi / 12 luồng, xung nhịp lên đến 4.60 GHz, 12MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (nâng cấp tối đa 24GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp tối đa 24GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe NVMe Gen 4, nâng tối đa 1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Khe đọc thẻ nhớ, USB 2.0, Âm thanh đa năng, HDMI 1.4, USB 3.2 thế hệ 1, USB-C'}, {'name': 'Wi-Fi', 'value': 'Realtek RTL8821CE hoặc Realtek RTL8852BE'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '358.50 x 235.56 x 18.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.90 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 cell, 41Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa + Microphone tích hợp'}, {'name': 'Webcam', 'value': 'HD camera (720P)'}, {'name': 'Micro', 'value': 'Microphone tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'TPM 2.0 / BitLocker / Mã hóa thiết bị'}, {'name': 'Hệ điều hành', 'value': 'Windows 11'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 120U (Up to 5.0 GHz; 10 lõi, 12 luồng, 12 MB Intel Smart Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 5 120U, 10 lõi, 12 luồng, xung nhịp lên đến 5.0 GHz, 12 MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, Nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe cắm'}, {'name': 'Ổ cứng', 'value': '1TB SSD M.2 PCIe NVMe (1 x M.2 2230 solid state drive, đã sử dụng 1, có thể thay được)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền WVA'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x USB 3.2 Gen 1 Type-A, 1 x USB 3.2 Gen 2 Type-C (10Gbps) hỗ trợ Power Delivery & DisplayPort 1.4, 1 x HDMI 1.4, 1 x Jack tai nghe 3.5mm (headset combo), 1 x Cổng nguồn (Power Jack)'}, {'name': 'Wi-Fi', 'value': 'Realtek Wi-Fi 6 RTL8852BE, 2x2, 802.11ax, MU-MIMO'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.4 (qua USB-C)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '357.30 x 250.60 x 16.74 - 19.90 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.98 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 cell 41WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': '2 loa được điều chỉnh'}, {'name': 'Webcam', 'value': 'Webcam HD (720p) với hệ thống micro kỹ thuật số kép tích hợp tính năng giảm nhiễu tạm thời'}, {'name': 'Micro', 'value': 'Micro kỹ thuật số kép tích hợp tính năng giảm nhiễu tạm thời'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím có phím số riêng, có đèn nền led trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee LS, Bảo mật vân tay'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7730U (8 nhân - 16 luồng - 20M cache - Up to 4.50 GHz Max Boost Clock)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 7730U, 8 nhân - 16 luồng, 20M cache, Tốc độ Boost tối đa 4.50 GHz'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, tối đa 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB'}, {'name': 'Ổ cứng', 'value': '1TB M.2 PCIe NVMe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền WVA'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB 2.0 Type-A, 1 x USB 3.2 Gen 1 Type-A, 1 x USB 3.2 Gen 1 Type-C, Có Khe đọc thẻ nhớ'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 802.11 ac'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.850 x 23.556 x 1.899 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.6 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Webcam HD có micrô, camera RGB HD'}, {'name': 'Micro', 'value': 'Có (qua Webcam)'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit + Microsoft Office Home & Student 2024 + Microsoft 365 Basic (1 năm)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home & Student 2024 + Microsoft 365 Basic (1 năm)'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Snapdragon X Plus X1P-64-100, 10 cores up to 3.4GHz, NPU up to 45 TOPS'}, {'name': 'Mô tả CPU', 'value': '10 cores up to 3.4GHz, NPU up to 45 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Qualcomm Adreno'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'NPU up to 45 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X 8448MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': 'Ổ cứng thể rắn M.2 PCIe NVMe 1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 3.2 Gen 1 (5 Gbps), 2x USB Type-C đầy đủ chức năng (40 Gbps, Power Delivery và DisplayPort), 1x Tai nghe (kết hợp tai nghe và micrô)'}, {'name': 'Wi-Fi', 'value': 'Qualcomm FastConnect 7800 Wi-Fi 7'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '314 x 223.75 x 17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.53 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 54 Wh, lithium-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204'}, {'name': 'Webcam', 'value': 'FHD camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Copilot có đèn nền Carbon Black English International'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Copilot+ PC Microsoft Office Home 2024 + Microsoft 365 Basic 1 year subscription'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home, Copilot+ PC'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic 1 year subscription'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 5 330 (4 lõi, up to 4.5 Ghz, 50 TOPS NPU)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 5 330 (4 lõi, up to 4.5 Ghz)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': '50 TOPS NPU'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 khe Onboard + 1 khe trống nâng cấp tối đa 32GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB'}, {'name': 'Ổ cứng', 'value': '512GB M.2 PCIe NVMe (nâng cấp tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nit'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x Khe đọc thẻ SD, 1 x Jack tai nghe/micrô 3.5 mm, 2 x USB 3.2 Gen 1 Type-A, 1 x HDMI 1.4, 1 x USB 3.2 Gen 2 Type-C'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314 x 226.15 x 18.07 mm'}, {'name': 'Trọng lượng', 'value': '1.67 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Li-ion 4-Cell Battery, 54WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek'}, {'name': 'Webcam', 'value': 'Có'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Copilot có đèn nền, tiếng Anh quốc tế, màu đen carbon'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home, Single Language English + Office Home & Student 2024'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Office Home & Student 2024'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5 1334U'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5 1334U'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (nâng cấp tối đa 24GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A (2.0), USB-C, HDMI 1.4, Cổng âm thanh đa năng, Khe đọc thẻ SD'}, {'name': 'Wi-Fi', 'value': 'Realtek RTL8821CE hoặc Realtek RTL8852BE'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0 hoặc 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '358.50 x 235.56 x 18.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.90 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 41 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204 hoặc Realtek ALC3254'}, {'name': 'Webcam', 'value': 'HD RGB camera ( 1280 x 720 (HD) at 30 fps), 0.92 megapixel'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 7 150U (12MB Cache, 1.80GHz and up to 5.4 GHz)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 7 150U, 12MB Cache, xung nhịp từ 1.80GHz đến 5.4 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, tối đa 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB'}, {'name': 'Ổ cứng', 'value': '1TB M.2 PCIe NVMe SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền WVA'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, Hỗ trợ ComfortView Plus'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'HDMI: 1 x 1.4, Khe thẻ SD: 1 x, Jack âm thanh 3.5 mm: 1 x, USB 3.2 Gen 1: 2 x, USB 3.2 Gen 2 Type-C: 1 x (10 Gbps, Power Delivery, DisplayPort 1.4)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314.00 x 226.15 x 16.69 - 18.07 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.65 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin liền, 3-Cell Battery, 41WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204'}, {'name': 'Webcam', 'value': '1280 x 720 (HD) at 30 fps'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Không'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Office Home 2024 + 1 năm sử dụng Microsoft 365 Basic (miễn phí 1 năm, hết phải gia hạn)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft 365 Basic (miễn phí 1 năm, cần gia hạn)'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 350, 8 lõi, up to 5.0GHz, 50 TOPS NPU'}, {'name': 'Mô tả CPU', 'value': '8 lõi, xung nhịp lên đến 5.0GHz, 50 TOPS NPU'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': '50 TOPS NPU'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5600MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 khe'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (dựa trên 1 khe hiện tại)'}, {'name': 'Ổ cứng', 'value': '1TB M.2 PCIe NVMe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền WVA'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, ComfortView (Low Blue Light)'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x USB Type-C (hỗ trợ Power Delivery & DisplayPort), 1 x USB 3.2 Gen 1 Type-A, 1 x HDMI 1.4, 1 x Jack tai nghe / micro 3.5mm, Khe đọc thẻ nhớ'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 (802.11be) – Intel BE201'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.x'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ xuất hình qua USB-C và HDMI'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '14 inches'}, {'name': 'Trọng lượng', 'value': '1.5 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin liền 4-cell 54Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa stereo, Realtek Audio, Waves MaxxAudio'}, {'name': 'Webcam', 'value': 'Độ phân giải FHD 1080p, hỗ trợ giảm nhiễu tạm thời'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím LED trắng (Backlit Keyboard, không RGB)'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language + Office'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Office'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-1355U (10 lõi, up to 5.00 GHz)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-1355U (10 lõi, up to 5.00 GHz)'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 4400MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 x 16GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 PCIe NVMe nâng cấp lên đến 1TB, 1 khe SSD M2 đã sữ dụng'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'LED'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250 nits, màn hình chống chói, màn hình LED nền viền mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1x (5Gbps), 1x (480Mbps); USB-C: 1x (chỉ truyền dữ liệu); Thunderbolt: N/A; HDMI: 1x (1.4); LAN: N/A; SD: Có; 3.5mm: N/A'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 (Wi-Fi 802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '358.50 x 235.56 x 18.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.66 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4-Cell Battery, 54WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204'}, {'name': 'Webcam', 'value': 'HD camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic 1 year'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic 1 year'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-1355U'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-1355U'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 2666MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 PCIe NVMe, Hỗ trợ SSD M.2 2280 tối đa 2TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền WVA'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250 nits, màn hình chống chói, màn hình LED nền viền mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB 2.0: 1, USB 3.2 Gen 1: 2 (Type-C), HDMI: N/A, LAN: N/A, SD: Có, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.v'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '1 x USB 3.2 Gen 1 Type-C hỗ trợ DisplayPort 1.4 / Power Delivery (có điều kiện)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '358.50 x 235.56 x 18.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.66 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 41Wh lithium-polymer'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': '2x 2W, Realtek ALC32xx'}, {'name': 'Webcam', 'value': 'HD RGB camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím tiếng Anh quốc tế không có đèn nền, có bàn phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee LiveSafe (1 năm, 5 thiết bị)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic (1 năm) + McAfee LiveSafe (1 năm, 5 thiết bị)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic (1 năm) + McAfee LiveSafe (1 năm, 5 thiết bị)'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-1355U (10 lõi, up to 5.00 GHz)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-1355U, 10 lõi, xung nhịp lên đến 5.00 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4-2666 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB M.2 PCIe NVMe nâng cấp lên đến 1T, 1 khe SSD M2 đã sử dụng'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Nhựa'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói, viền hẹp có đèn nền LED'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB 2.0: 1, USB Type-C: 2 (1x chỉ truyền dữ liệu, 1x DP 1.4, Sạc - áp dụng cho máy vỏ nhôm), HDMI: 1, Cổng âm thanh đa năng: 1, Cổng nguồn: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 (Wi-Fi 802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '358.50 x 235.56 x 18.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.66 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4-Cell Battery, 54WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204'}, {'name': 'Webcam', 'value': 'HD camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Microsoft Office Home 2024 + Microsoft 365 Basic 1 year'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft Office Home 2024 + Microsoft 365 Basic 1 year'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 225U'}, {'name': 'Mô tả CPU', 'value': 'Intel Core Ultra 5 225U'}, {'name': 'Tên card đồ họa', 'value': 'Intel graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5600 M T/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512 GB M.2 PCIe NVMe, SSD nâng cấp tối đa 2TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2, USB-C: 1, Thunderbolt: 1, HDMI: 1, LAN: 1, SD: N/A, 3.5mm: 1 (Cổng tai nghe)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 (WiFi 802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua HDMI 2.1 và Thunderbolt 4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '225.30 x 313.70 x 20.37 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.35 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 45 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204'}, {'name': 'Webcam', 'value': 'FHD RGB'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home, Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-1235U (10 cores) - Max Turbo Frequency: 4.40 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-1235U, 10 nhân, Tốc độ Turbo tối đa 4.40 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 2666MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 x 8GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (2 khe, hiện tại 2x8GB)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2230) - combo M.2 2230/2280'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền WVA'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB 2.0 Type-A, 2 x USB 3.2 Gen 1 Type-A, 1 x HDMI, 1 x Headphone/ Microphone combo audio jack, 1 x SATA 3'}, {'name': 'Wi-Fi', 'value': '802.11 ac'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.85 x 23.49 x 1.75 cm (L x W x H)'}, {'name': 'Trọng lượng', 'value': '1.685 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Cirrus Logic HD Audio'}, {'name': 'Webcam', 'value': 'HD WebCam with microphone'}, {'name': 'Micro', 'value': 'Có (kèm Webcam)'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Công nghệ Intel Platform Trust, Giảm thiểu bảo mật SMM, Xóa dữ liệu khi khởi động tiếp theo, Absolute, Bảo mật đường dẫn khởi động UEFI'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit + Office Home & Student 2021'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Office Home & Student 2021'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 7 150U (10 lõi, up to 5.4 GHz)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 7 150U, 10 lõi, xung nhịp lên đến 5.4 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce MX570A 2GB GDDR6, Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời NVIDIA GeForce MX570A với 2GB GDDR6 và tích hợp Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe cắm'}, {'name': 'Ổ cứng', 'value': 'SSD 1TB M.2 PCIe NVMe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền WVA'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nit'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x HDMI 1.4, 2 x USB 3.2 Gen 1 Type-A, 1 x USB 3.2 Gen 2 Type-C (10Gbps, DisplayPort 1.4, Power Delivery), 1 x Khe đọc thẻ SD, 1 x Jack tai nghe/micrô 3.5 mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '356.78 x 249.52 x 19.05 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4-Cell Battery, 54WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3254'}, {'name': 'Webcam', 'value': 'Có'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Led trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bảo mật vân tay'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home, Single Language English + Office Home & Student 2024'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Office Home & Student 2024'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel CORE 5-120U'}, {'name': 'Mô tả CPU', 'value': 'Intel CORE 5-120U'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe rời (đã sử dụng, nâng tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng tối đa lên 32GB'}, {'name': 'Ổ cứng', 'value': '512GB M.2 PCIe NVMe (nâng cấp tối đa 1T)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nit'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2; USB-C: 1 (có Power Delivery và DisplayPort 1.4); HDMI: 1; Thunderbolt: N/A; LAN: N/A; SD: Có; 3.5mm: 1 (Headphone/ Microphone combo)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 (WiFi 802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314 x 226.15 x 18.07 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.67 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Li-ion 4-Cell Battery, 54WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3254'}, {'name': 'Webcam', 'value': 'Có'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Led trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bảo mật vân tay'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home, Single Language English + Office Home & Student 2021'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Office Home & Student 2021'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-1235U (10 lõi / 12 luồng, 1.30 GHz to 4.40 GHz, 12 MB)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-1235U, 10 lõi / 12 luồng, xung nhịp từ 1.30 GHz đến 4.40 GHz, Cache 12 MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (tối đa 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIE (1 Slot HDD Tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250 nits, Độ phủ màu NTSC 45%, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Đầu nối nguồn, 1x HDMI 1.4, 2x USB 3.2 Gen 1, 1x Khe cắm thẻ SD, 1x USB 2.0, 1x Cổng tai nghe'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 (Card 8821CE-VC)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '16.96 x 358.50 x 235.56 mm (C x R x S)'}, {'name': 'Trọng lượng', 'value': '1.66 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 41 Wh lithium-polymer'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204/Realtek ALC3254'}, {'name': 'Webcam', 'value': 'HD camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i3-1305U'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i3-1305U'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 8GB, tối đa 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB'}, {'name': 'Ổ cứng', 'value': '512GB (1 Slot SSD Tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền WVA'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'NTSC 45%'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu NTSC 45%, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Đầu nối nguồn, 1x HDMI 1.4, 1x USB 3.2 Gen 1, 1x Khe cắm thẻ SD, 1x USB 2.0, 1x Cổng tai nghe 3,5mm, 1x Cổng Lan, 1x Type C'}, {'name': 'Wi-Fi', 'value': 'Realtek Wi-Fi 5 RTL8821CE, 802.11ac'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '16.96 x 358.50 x 235.56 mm ( Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.66 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '41Wh , 3Cell'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek ALC3204/Realtek ALC3254'}, {'name': 'Webcam', 'value': 'HD - 0,92 megapixel - 1280 x 720 (HD) ở tốc độ 30 khung hình/giây - Công nghệ cảm biến CMOS'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Free OS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H (8 lõi) - Max Turbo Frequency: 4.60 GHz'}, {'name': 'Mô tả CPU', 'value': '8 lõi - Max Turbo Frequency: 4.60 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050 (6GB of GDDR6 SDRAM, Bus Width: 96) Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời NVIDIA GeForce RTX 4050 với 6GB GDDR6 SDRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, hỗ trợ nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB SSD1 PCIe (M.2 2280) Gen4x4, 2x M.2 SSD slots (Supports 2x PCIe NVMe M.2 SSD, Up to 4TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 1, Thunderbolt: N/A, HDMI: 1, LAN: 1, SD: N/A, 3.5mm: 1 (kết hợp Tai nghe/Micrô), SSD2 PCIe (M.2 2280): 1'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E (802.11ax 2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.83 x 26.25 x 1.945 ~ 2.299 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.212 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell Int (76.1Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HD Gigabyte với micro mảng'}, {'name': 'Micro', 'value': 'Micro mảng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'LED'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu người dùng, Khởi động an toàn, Chế độ hệ thống, fTPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, MUX Switch'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 cores) - Max Turbo Frequency: 4.90 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 10 nhân, Xung nhịp tối đa 4.90 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050 (6GB of GDDR6 SDRAM, Bus Width: 96) và Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời NVIDIA GeForce RTX 4050 với 6GB GDDR6 SDRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 - 5200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, hỗ trợ nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB SSD1 PCIe (M.2 2280) Gen4x4; Hỗ trợ 2 khe M.2 SSD PCIe NVMe M.2 (Hỗ trợ lên đến 4TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB 2.0 Type-A, 2 x USB 3.2 Gen 1 Type-A, 1 x USB 3.2 Gen 1 Type-C (hỗ trợ Power Delivery/DisplayPort), 1 x HDMI, 1 x RJ45 (LAN), 1 x giắc cắm âm thanh kết hợp Tai nghe/Micrô, 1 x SSD2 PCIe (M.2 2280)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E (802.11ax 2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.83 x 26.25 x 1.945 ~ 2.299 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.204 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell Int (76.1Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HD Gigabyte với micro mảng'}, {'name': 'Micro', 'value': 'Micro mảng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'LED'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu người dùng, Khởi động an toàn, Chế độ hệ thống, fTPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 350 (8 x 2.00 GHz) - Max. Boost Clock: Up to 5.00 GHz'}, {'name': 'Mô tả CPU', 'value': '8 nhân, xung nhịp tối đa 5.00 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 (8GB of GDDR7 SDRAM, Bus Width: 128- bit), AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời NVIDIA GeForce RTX 5060 với 8GB GDDR7 SDRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': '50 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 - 5600MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, hỗ trợ nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '1TB SSD1 PCIe (M.2 2280), hỗ trợ 2x M.2 SSD (tối đa 4TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits (typical)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB, Pantone Validated'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói, Ánh sáng xanh thấp của TÜV Rheinland'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1 cổng 2.0, 2 cổng 3.2 Gen 1; USB-C: 1 cổng USB 4 (support Power Delivery/DisplayPort); HDMI: 1; LAN: 1 (RJ45); USB2/SSD2: 1 cổng M.2 2280'}, {'name': 'Wi-Fi', 'value': 'WIFI 6E (802.11ax 2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth V5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa sơn'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhôm với cấu trúc nhựa'}, {'name': 'Kích thước', 'value': '35.50 x 25.07 x 1.675~1.999 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.985 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Li Polymer 76Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Dolby Atmos'}, {'name': 'Webcam', 'value': 'Webcam hồng ngoại FHD (1080p), Micrô tích hợp, Hỗ trợ xác thực khuôn mặt Windows Hello'}, {'name': 'Micro', 'value': 'Micrô tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ, 6 hàng phím Fn đa phương tiện, bàn phím đèn nền RGB 1 vùng. Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Nhận dạng khuôn mặt, Mật khẩu quản trị viên, Mật khẩu người dùng, Khởi động an toàn, Chế độ hệ thống, fTPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H (8 lõi) - Max Turbo Frequency: 4.60 GHz'}, {'name': 'Mô tả CPU', 'value': '8 lõi'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050'}, {'name': 'Mô tả card đồ họa', 'value': '8GB GDDR7 SDRAM, Bus Width: 128- bit, Intel UHD Graphics (tích hợp)'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 - 5200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, hỗ trợ nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD1 PCIe (M.2 2280) Gen4x4; 2x M.2 SSD slots (Hỗ trợ 2x PCIe NVMe M.2 SSD, lên đến 4TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits (typical)'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1 cổng 2.0, 2 cổng 3.2 Gen 1; USB-C: 1 cổng 3.2 Gen 1 (hỗ trợ PD/DP); HDMI: 1; LAN: 1 (RJ45); SD: N/A; 3.5mm: 1 (kết hợp tai nghe/micrô); SSD M.2: 1 slot PCIe'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E (802.11ax 2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.83 x 26.25 x 1.945 ~ 2.299 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.227 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell Int (76.1Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HD Gigabyte với micro mảng'}, {'name': 'Micro', 'value': 'Micro mảng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím có đèn nền RGB 1 vùng, hành trình phím lên đến 1,7mm'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu người dùng, Khởi động an toàn, Chế độ hệ thống, fTPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 170 (8 x 3.20 GHz) - Max. Boost Clock: Up to 4.75 GHz'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 170, 8 nhân, xung nhịp tối đa 4.75 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 (8GB of GDDR7 SDRAM, Bus Width: 128-bit), AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời NVIDIA GeForce RTX 5050 với 8GB GDDR7 SDRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 4800MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe cắm'}, {'name': 'Ổ cứng', 'value': '512GB SSD1 PCIe (M.2 2280) Gen4x4, hỗ trợ 2x PCIe NVMe M.2 SSD (Hỗ trợ lên đến 4TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB 2.0 Type-A, 2 x USB 3.2 Gen 1 Type-A, 1 x USB 3.2 Gen 1 Type-C (Power Delivery, DisplayPort), 1 x HDMI, 1 x RJ45 (LAN), 1 x Jack tai nghe/mic 3.5 mm, 1 x khe PCIe SSD2 (M.2 2280)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E (802.11ax 2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.830 x 26.250 x (1.945 ~ 2.299) cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell Int (76.1Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HD Gigabyte với hệ thống micro đa kênh'}, {'name': 'Micro', 'value': 'Micro đa kênh'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím có đèn nền một màu (Xanh dương), hành trình phím lên đến 1,7mm.'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu người dùng, Secure Boot, AMD PSP 11.0, Bộ xử lý bảo mật Microsoft Pluton, fTPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, MUX Switch'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 lõi) - Max Turbo Frequency: 4.90 GHz'}, {'name': 'Mô tả CPU', 'value': '10 lõi'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050'}, {'name': 'Mô tả card đồ họa', 'value': '8GB GDDR7 SDRAM, Bus Width: 128-bit, Intel UHD Graphics (tích hợp)'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, hỗ trợ nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD1 PCIe (M.2 2280) Gen4x4, hỗ trợ 2x PCIe NVMe M.2 SSD (Tối đa 4TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits (typical)'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1 x, USB-C: 1 x (hỗ trợ PD/DP), Thunderbolt: N/A, HDMI: 1 x, LAN: 1 x (RJ45), SD: N/A, 3.5mm: 1 x (Giắc cắm âm thanh kết hợp tai nghe/micrô)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E (802.11ax 2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.83 x 26.25 x (1.945 ~ 2.299) cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.23 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell Int (76.1Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HD Gigabyte với micro mảng'}, {'name': 'Micro', 'value': 'Micro mảng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím có đèn nền RGB 1 vùng, hành trình phím lên đến 1.7 mm'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu người dùng, Khởi động an toàn, Chế độ hệ thống, fTPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 lõi) - Max Turbo Frequency: 4.90 GHz'}, {'name': 'Mô tả CPU', 'value': '10 lõi - Max Turbo Frequency: 4.90 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5070'}, {'name': 'Mô tả card đồ họa', 'value': '8GB of GDDR7 SDRAM, Bus Width: 128- bit, Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 - 5200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, hỗ trợ nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB SSD1 PCIe (M.2 2280); 2x M.2 SSD slots (Supports 2x PCIe NVMe M.2 SSD, Up to 4TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits (typical)'}, {'name': 'Độ phủ màu màn hình', 'value': 'sRGB 100%'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi 3ms, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1 x, USB-C: 1 x (hỗ trợ Power Delivery/DisplayPort), Thunderbolt: N/A, HDMI: 1 x, LAN: 1 x (RJ45), SD: N/A, 3.5mm: 1 x (Giắc cắm âm thanh kết hợp tai nghe/micrô), SSD2 PCIe (M.2 2280): 1 x'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E (802.11ax 2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.83 x 26.25 x 1.945 ~ 2.299 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.268 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell Int (76.1Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HD Gigabyte với micro mảng'}, {'name': 'Micro', 'value': 'Micro mảng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'LED'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu người dùng, Khởi động an toàn, Chế độ hệ thống, fTPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 lõi / 16 luồng, 3.6 GHz - Up to 4.9 GHz, 24Mb Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050'}, {'name': 'Mô tả card đồ họa', 'value': '6GB of GDDR6 SDRAM, Bus Width: 96-bit, Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 - 4800MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe cắm'}, {'name': 'Ổ cứng', 'value': '512GB SSD1 PCIe (M.2 2280); 2x M.2 SSD slots (Supports 2x PCIe NVMe M.2 SSD, Up to 4TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB 2.0 Type-A, 1 x USB 3.2 Gen 1 Type-A, 2 x USB 3.2 Gen 2 Type-C, 1 x HDMI, 1 x Mini DP, 1 x RJ45 (LAN), 1 x Microphone jack, 1 x Headphone/Microphone combo audio jack, 1 x SSD2 PCIe (M.2 2280)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E (802.11ax 2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.95 x 26.38 x 2.51 ~ 2.60 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.279 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell Int (54Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio (bởi Dolby Atmos)'}, {'name': 'Webcam', 'value': 'Webcam IR HD (720p), Micrô tích hợp'}, {'name': 'Micro', 'value': 'Micrô tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím có đèn nền RGB 1 vùng, hành trình phím lên tới 2 mm (15 màu, với 10 phím)'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Thiết lập mật khẩu giám sát, quản lý khởi động an toàn, TPM, khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, Bảo mật vân tay'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 lõi) - Max Turbo Frequency: 4.90 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 10 lõi, Max Turbo Frequency 4.90 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 Laptop GPU'}, {'name': 'Mô tả card đồ họa', 'value': '8GB of GDDR7 SDRAM, Bus Width: 128-bit, kèm Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, hỗ trợ nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB SSD1 PCIe (M.2 2280); 2x M.2 SSD slots (Hỗ trợ 2x PCIe® NVMe M.2 SSD, lên đến 4TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 pixels (2.5K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits (typical)'}, {'name': 'Độ phủ màu màn hình', 'value': 'sRGB 100%'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1 cổng 2.0, 2 cổng 3.2 Gen 1; USB-C: 1 cổng 3.2 Gen 1 (hỗ trợ PD/DP); HDMI: 1; LAN: 1 (RJ45); USB2/SSD: 1 khe M.2 2280'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E (802.11ax 2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.83 x 26.25 x 1.945 ~ 2.299 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.268 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell Int (76.1Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HD Gigabyte với micro mảng'}, {'name': 'Micro', 'value': 'Micro mảng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'LED'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu người dùng, Khởi động an toàn, Chế độ hệ thống, fTPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 lõi)'}, {'name': 'Mô tả CPU', 'value': 'Max Turbo Frequency: 4.90 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060'}, {'name': 'Mô tả card đồ họa', 'value': '8GB of GDDR7 SDRAM, Bus Width: 128- bit, Intel UHD Graphics (tích hợp)'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 - 5200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, hỗ trợ nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD1 PCIe (M.2 2280), 2x M.2 SSD slots (Hỗ trợ 2x PCIe NVMe M.2 SSD, lên đến 4TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits (typical)'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1 x, USB-C: 1 x (hỗ trợ PD/DP), Thunderbolt: N/A, HDMI: 1 x, LAN: 1 x (RJ45), SD: N/A, 3.5mm: 1 x (Giắc cắm âm thanh kết hợp tai nghe/micrô), SSD2 PCIe (M.2 2280): 1 x'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E (802.11ax 2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.83 x 26.25 x 1.945 ~ 2.299 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.233 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell Int (76.1Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HD Gigabyte với micro mảng'}, {'name': 'Micro', 'value': 'Micro mảng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím có đèn nền RGB 1 vùng, hành trình phím lên đến 1,7mm'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu người dùng, Khởi động an toàn, Chế độ hệ thống, fTPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 5 340 (6 x 2.00 GHz) - Max. Boost Clock: Up to 4.80 GHz'}, {'name': 'Mô tả CPU', 'value': '6 nhân, xung nhịp cơ bản 2.00 GHz, Turbo lên đến 4.80 GHz'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 840M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Ryzen AI'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-7500 MT/s (onboard)'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Kính tràn viền, Viền mỏng micro-edge, Hỗ trợ bút stylus, Màn hình cảm ứng, Xoay gập 360 độ (2 in 1)'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2; USB Type-C: 2 (một 10Gbps, một 40Gbps); HDMI: 1; Jack tai nghe / micrô combo: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '31.3 x 21.85 x 1.46 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.526 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (59.16Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'HP Sleep and Charge (qua USB Type-C)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio (by Poly Studio)'}, {'name': 'Webcam', 'value': 'Camera HP 5MP + hồng ngoại (màn che bảo mật) với micro tích hợp'}, {'name': 'Micro', 'value': 'Tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ màu xám mềm, 6 hàng, phím Fn đa phương tiện, có đèn nền'}, {'name': 'Touchpad', 'value': 'Hỗ trợ thao tác bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Nhận diện khuôn mặt, Mật khẩu quản trị viên, Mật khẩu khởi động máy, Tiện ích bảo vệ ổ cứng, AMD PSP 11.0, Bộ xử lý bảo mật Microsoft Pluton, TPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit + Office Home 2024'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Office Home 2024'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Xoay gập 360 độ (2 in 1), Nhận diện khuôn mặt'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 225U (12 lõi) - Max Turbo Frequency: 4.80 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics (Tích hợp)'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X/ 7467MHz Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 2, Thunderbolt: N/A, HDMI: 1, LAN: N/A, SD: N/A, 3.5mm: 1 (Kết hợp tai nghe/micrô)'}, {'name': 'Wi-Fi', 'value': '802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.77 x 25.48 x 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.725 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (59.16Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera IR HP True Vision FHD (màn trập riêng tư) với micrô mảng'}, {'name': 'Micro', 'value': 'Micrô mảng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng phím đa phương tiện, phím Fn, bàn phím có đèn nền. Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Nhận dạng khuôn mặt, Mật khẩu quản trị viên, Mật khẩu bật nguồn, fTPM 2.0, Tiện ích ổ cứng'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit + Office Home 2024'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Office Home 2024'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 225U (lên đến 4.8 GHz với Công nghệ Intel Turbo Boost, bộ nhớ đệm L3 12 MB, 12 lõi, 14 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost (12 NPU TOPS)'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost (12 NPU TOPS)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5-5200 MT/s Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe Gen4 NVMe M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '62.5% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Viền mỏng, chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB Type-A: 2, USB Type-C: 2 (một cổng 10Gbps, một cổng Thunderbolt 4 40Gbps), HDMI: 1 (2.1), Thunderbolt: 1 (40Gbps), USB-C (10Gbps)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '31.4 x 22.65 x 1.49 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.41 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4-cell, 68 Wh Li-ion polymer'}, {'name': 'Sạc nhanh', 'value': 'Khoảng 50% trong 45 phút'}, {'name': 'Loại sạc', 'value': 'Bộ đổi nguồn USB Type-C 65 W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh DTS:X Ultra, Loa kép, HP Audio Boost, Poly Studio'}, {'name': 'Webcam', 'value': 'Camera hồng ngoại 5MP có chức năng giảm nhiễu tạm thời và micrô kỹ thuật số mảng kép tích hợp'}, {'name': 'Micro', 'value': 'Micrô kỹ thuật số mảng kép tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ, có đèn nền, màu xám nhạt'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Phím tắt tiếng micrô; Màn trập riêng tư của camera; Hỗ trợ Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language + Office'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Windows 11 Home Single Language + Office'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7520U (4 lõi, 8 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Up to 4.3 GHz max boost clock, 4 MB L3 cache'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 610M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200 MT/s Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm thêm)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe NVMeTM M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB Type-C (1 x, 5Gbps, chỉ truyền dữ liệu), USB Type-A (2 x, 5Gbps), HDMI (1 x 1.4b), Jack tai nghe/mic 3.5 mm, Cổng nguồn AC (smart pin)'}, {'name': 'Wi-Fi', 'value': 'Realtek Wi-Fi 6 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '32.37 x 21.5 x 1.79 - 3.25 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 41 Wh Li-ion polymer'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'Smart pin'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa kép'}, {'name': 'Webcam', 'value': 'Camera HP True Vision 720p HD với tính năng giảm nhiễu theo thời gian và tích hợp micro kỹ thuật số kép'}, {'name': 'Micro', 'value': 'Micro kỹ thuật số kép'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Phím tắt micro (Mic mute), Nắp che camera, Hỗ trợ TPM (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7530U (6 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 7530U (up to 4.5 GHz max boost clock, 16 MB L3 cache, 6 lõi, 12 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200 MT/s (1 x 16 GB)'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 khe (1 x 16 GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A (RAM đã được lắp đặt)'}, {'name': 'Ổ cứng', 'value': '256 GB PCIe NVMeTM SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C 5 Gbps, 2x USB Type-A 5 Gbps, 1x bộ nguồn AC, 1x HDMI 1.4b, 1x giắc cắm kết hợp tai nghe/micrô âm thanh nổi'}, {'name': 'Wi-Fi', 'value': 'Realtek Wi-Fi 6 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '32.4 x 21.5 x 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.36 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'HP Long Life 3-cell, 41 Wh Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'Bộ nguồn AC'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa âm thanh nổi, micrô kỹ thuật số tích hợp'}, {'name': 'Webcam', 'value': '720p HD camera'}, {'name': 'Micro', 'value': 'Micrô kỹ thuật số tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee Security (dùng thử miễn phí 30 ngày)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7730U (8 lõi, 16 luồng, xung nhịp tăng tối đa 4,5 GHz, bộ nhớ đệm L3 16 MB)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 7730U'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 x 16GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe NVMeTM SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB Type-C (5 Gbps): 1 cổng; USB Type-A (5 Gbps): 2 cổng; HDMI: 1 cổng (1.4b); USB-A: 2 cổng; Nguồn AC: 1; Jack combo (Tai nghe/Mic): 1'}, {'name': 'Wi-Fi', 'value': 'Realtek Wi-Fi 6 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '32.4 x 21.5 x 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.36 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'HP Long Life 3-cell, 41 Wh Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'Bộ nguồn AC'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa âm thanh nổi, micrô kỹ thuật số tích hợp'}, {'name': 'Webcam', 'value': '720p HD camera'}, {'name': 'Micro', 'value': 'Micrô kỹ thuật số tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Full-size, textured, island-style keyboard'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'McAfee Security (dùng thử miễn phí 30 ngày)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 226V (8 lõi, 8 luồng, lên đến 4.5 GHz)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost (40 NPU TOPS)'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc 130V GPU'}, {'name': 'Mô tả card đồ họa', 'value': '8GB VRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost (40 NPU TOPS)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-8533 MT/s (onboard)'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe Gen4 NVMe M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '400 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '62.5% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Kính tràn viền, Viền mỏng, Corning Gorilla Glass 3'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB Type-A 10 Gbps, 1x HDMI 2.1, 1x combo tai nghe/micrô, 1x Thunderbolt 4 (USB-C 40 Gbps, Power Delivery 3.1, DisplayPort 2.1, HP Sleep and Charge), 1x USB-C 10 Gbps (Power Delivery 3.1, DisplayPort 1.4a, HP Sleep and Charge)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Qua cổng Thunderbolt 4 và USB-C)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '31.3 x 21.85 x 1.46 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.38 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 59 Wh Li-ion polymer'}, {'name': 'Sạc nhanh', 'value': 'Khoảng 50% trong 30 phút'}, {'name': 'Loại sạc', 'value': 'Bộ đổi nguồn USB Type-C 65 W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS:X Ultra, Loa kép, HP Audio Boost, Poly Studio'}, {'name': 'Webcam', 'value': 'Camera hồng ngoại 5MP có chức năng giảm nhiễu tạm thời và micrô kỹ thuật số mảng kép tích hợp'}, {'name': 'Micro', 'value': 'Micrô kỹ thuật số mảng kép tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ, có đèn nền, màu xanh lam đục tối hơn'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Phím tắt tiếng micrô, Cửa trập bảo vệ quyền riêng tư camera, Hỗ trợ Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Office'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Windows 11 Home + Office'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H (8 lõi) - Max Turbo Frequency: 4.60 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi, Max Turbo Frequency 4.60 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050'}, {'name': 'Mô tả card đồ họa', 'value': '6GB of GDDR6 SDRAM, Bus Width: 96-bit, kèm Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (Hiện đang 1x16GB, còn 1 khe trống)'}, {'name': 'Ổ cứng', 'value': '512GB SSD1 PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB 3.2 Gen 1 Type-C (hỗ trợ DisplayPort, HP Sleep and Charge), 2 x USB 3.2 Gen 1 Type-A (một cổng hỗ trợ HP Sleep and Charge), 1 x HDMI, 1 x RJ45 (LAN), 1 x Giắc cắm âm thanh kết hợp tai nghe/micrô, 1 x SSD2 PCIe (M.2 2280)'}, {'name': 'Wi-Fi', 'value': '802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.8 x 25.5 x 2.35 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.185 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (52.5Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HD HP Wide Vision với micrô mảng'}, {'name': 'Micro', 'value': 'Có (Micrô mảng)'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng phím Fn đa phương tiện, bàn phím có đèn nền, Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu bật nguồn, fTPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i3-1315U (6 lõi, 8 luồng, up to 4.5 GHz)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i3-1315U, 10 MB L3 cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 x 8 GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A (Chỉ có 1 khe RAM)'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe NVMeTM M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '62.5% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Viền siêu mỏng, chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB Type-C 5Gbps (chỉ hỗ trợ truyền dữ liệu, không hỗ trợ sạc hoặc màn hình ngoài); 2x USB Type-A 5Gbps; 1x HDMI 1.4b; 1x Chân cắm thông minh AC; 1x Bộ tai nghe/micrô'}, {'name': 'Wi-Fi', 'value': 'Realtek Wi-Fi 6 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '32.37 x 21.5 x 1.79 cm (Mặt trước); 32.37 x 21.5 x 3.25 cm (Mặt sau)'}, {'name': 'Trọng lượng', 'value': '1.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 41 Wh Li-ion polymer'}, {'name': 'Sạc nhanh', 'value': 'Bộ đổi nguồn AC thông minh 45 W'}, {'name': 'Loại sạc', 'value': 'AC thông minh 45 W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Dual speakers'}, {'name': 'Webcam', 'value': 'Camera HP True Vision 720p HD có chức năng giảm nhiễu tạm thời và micrô kỹ thuật số mảng kép tích hợp'}, {'name': 'Micro', 'value': 'Micrô kỹ thuật số mảng kép tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím màu xám mềm, kích thước đầy đủ'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mic mute key; Camera privacy shutter; Trusted Platform Module (Firmware TPM) support'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 258V (8 lõi) - Max Turbo Frequency: 4.80 GHz'}, {'name': 'Mô tả CPU', 'value': '8 lõi, Max Turbo Frequency: 4.80 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc 140V GPU'}, {'name': 'Mô tả card đồ họa', 'value': '16GB VRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-8533 MHz (onboard)'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Kính tràn viền, Viền mỏng, Hỗ trợ bút stylus'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2; USB-C: 1 (có PD, DP, HP Sleep and Charge); Thunderbolt 4: 1 (tối đa 40Gbps, PD, DP, HP Sleep and Charge); HDMI: 1; LAN: N/A; SD: N/A; 3.5mm: 1 (Headphone/Microphone combo)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E 802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '31.30 x 21.85 x 1.46 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.504 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (59.16Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio (by Poly Studio)'}, {'name': 'Webcam', 'value': 'Camera HP 5MP + hồng ngoại (màn che bảo mật) với micro tích hợp.'}, {'name': 'Micro', 'value': 'Tích hợp trong Webcam'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím full-size màu xanh đậm mờ, 6 hàng, phím Fn đa phương tiện, có đèn nền'}, {'name': 'Touchpad', 'value': 'Hỗ trợ thao tác bốn ngón'}, {'name': 'Bảo mật', 'value': 'Nhận diện khuôn mặt, Mật khẩu quản trị viên, Mật khẩu khởi động, Thiết bị TPM, Tiện ích ổ cứng, Bộ xử lý bảo mật Microsoft Pluton'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit + Office Home 2024'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Office Home 2024'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Xoay gập 360 độ (2 in 1), Nhận diện khuôn mặt'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 255H (16 lõi, 16 luồng, up to 5.1 GHz)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core Ultra 7 255H (up to 5.1 GHz with Intel Turbo Boost Technology, 24 MB L3 cache, 16 lõi, 16 luồng)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 (8 GB GDDR7 chuyên dụng) Intel Arc 140T GPU'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 (8 GB GDDR7 chuyên dụng), Intel Arc 140T GPU'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel Core Ultra series (có tích hợp NPU)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (2 khe, hiện tại 16GB)'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe Gen4 NVMe M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400 nit'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Thời gian phản hồi 3 ms, Màn hình chống chói, Ánh sáng xanh thấp'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-A 10Gbps, 2x USB Type-A 5Gbps, 1x chân cắm thông minh AC, 1x HDMI 2.1, 1x bộ tai nghe/micrô, 1x RJ-45, 1x USB Type-C 10Gbps (USB Power Delivery 3.0, DisplayPort 1.4, HP Sleep and Charge)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Qua cổng HDMI 2.1 và USB Type-C)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.75 x 26.9 x 2.37 cm (Mặt trước), 35.75 x 26.9 x 2.54 cm (Mặt sau)'}, {'name': 'Trọng lượng', 'value': '2.43 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '6-cell, 83 Wh Li-ion polymer'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'AC adapter (cổng thông minh)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS:X Ultra, Dual speakers, HP Audio Boost, HyperX'}, {'name': 'Webcam', 'value': 'Camera HP True Vision 1080p FHD với chức năng giảm nhiễu theo thời gian và micrô kỹ thuật số mảng kép tích hợp'}, {'name': 'Micro', 'value': 'Micrô kỹ thuật số mảng kép tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím full-size, đèn nền RGB 4 vùng, màu đen bóng, có bàn phím số và công nghệ Anti-Ghosting 26 phím'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Màn trập riêng tư của camera, Hỗ trợ Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i3-1315U (6 lõi) - Max Turbo Frequency: 4.50 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i3-1315U, 6 lõi, Max Turbo Frequency: 4.50 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4/ 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Hiện đang sử dụng 1 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp thêm RAM (tối đa 16GB hoặc tùy thuộc vào khả năng của máy)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2; USB-C: 1; Thunderbolt: N/A; HDMI: 1; LAN: N/A; SD: N/A; 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': '802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '36.0 x 23.6 x 1.86 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.624 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41.04Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HP True Vision HD (có màn che riêng tư) với hệ thống micro tích hợp'}, {'name': 'Micro', 'value': 'Tích hợp trong Webcam'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng phím, phím chức năng đa phương tiện (Fn); Bàn di chuột hỗ trợ thao tác bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ thao tác bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu khởi động, fTPM 2.0, Tiện ích ổ cứng'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 3 100U (6 lõi) - Max Turbo Frequency: 4.70 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 3 100U, 6 lõi, Max Turbo Frequency: 4.70 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Hiện đang sử dụng 1 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (tối đa 16GB hoặc tùy thuộc vào cấu hình tối đa của máy)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, Viền mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2; USB-C: 1 (Type-C hỗ trợ Power Delivery, DisplayPort, HP Sleep and Charge); HDMI: 1; LAN: Không; SD: Không; 3.5mm: 1 (Jack tai nghe/mic)'}, {'name': 'Wi-Fi', 'value': '802.11 ax (Wi-Fi 6)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.98 x 23.60 x 1.57 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.6 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41.04Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HP True Vision HD (có màn che riêng tư) với hệ thống micro tích hợp'}, {'name': 'Micro', 'value': 'Micro tích hợp webcam'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng, các phím chức năng đa phương tiện (Fn), Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu khởi động, TPM 2.0, Tiện ích ổ cứng'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 120U (10 cores) - Max Turbo Frequency: 5.00 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 5 120U, 10 nhân, Tốc độ Turbo tối đa 5.00 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200Mhz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp RAM (2 khe)'}, {'name': 'Ổ cứng', 'value': '1TB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x USB 3.2 Gen 1 Type-A, 1 x USB 3.2 Gen 2 Type-C (hỗ trợ Power Delivery/DisplayPort/HP Sleep and Charge), 1 x HDMI, 1 x Giắc cắm âm thanh kết hợp tai nghe/micrô'}, {'name': 'Wi-Fi', 'value': '802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '32.4 x 21.5 x 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41.04Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HP True Vision HD (màn trập riêng tư) với micrô mảng'}, {'name': 'Micro', 'value': 'Micrô mảng (tích hợp webcam)'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ, 6 hàng phím Fn đa phương tiện. Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu bật nguồn, TPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i3-1315U (6 lõi) - Max Turbo Frequency: 4.50 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i3-1315U, 6 lõi, Max Turbo Frequency: 4.50 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Hiện đang sử dụng 1 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp thêm RAM (tùy thuộc vào khe còn trống)'}, {'name': 'Ổ cứng', 'value': '256GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, Viền mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2; USB-C: 1 (Type-C hỗ trợ Power Delivery, DisplayPort); HDMI: 1; LAN (RJ45): 1; SD-Card: Có; 3.5mm: 1 (Jack tai nghe/mic)'}, {'name': 'Wi-Fi', 'value': '802.11 ax (Wi-Fi 6)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.8 x 24.2 x 1.48 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.705 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41.04Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HP TrueVision HD với hệ thống micro tích hợp'}, {'name': 'Micro', 'value': 'Tích hợp trong Webcam'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng, chống tràn, các phím chức năng đa phương tiện (Fn). Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay, Mật khẩu quản trị viên, Mật khẩu khởi động, TPM'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 5 340 (6 lõi, 12 luồng, up to 4.8 GHz max boost clock, 16 MB L3 cache)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 5 340'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 840M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD Ryzen AI (50 NPU TOPS)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-7500 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp (Onboard)'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe Gen4 NVMe M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '400 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Viền mỏng, Chống chói, Độ sáng 400 nits, Độ phủ màu 100% sRGB'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-A 10 Gbps, 1x USB Type-A 5 Gbps, 1x HDMI 2.1, 1x Combo tai nghe/micrô, 2x USB Type-C 10 Gbps (USB PD 3.1, DisplayPort 2.1, HP Sleep and Charge)'}, {'name': 'Wi-Fi', 'value': 'MediaTek Wi-Fi 6E MT7922 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '29.73 x 21.12 x 1.65 - 1.74 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '<1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 43 Wh Li-ion polymer'}, {'name': 'Sạc nhanh', 'value': 'Khoảng 50% trong 30 phút'}, {'name': 'Loại sạc', 'value': '65 W USB Type-C power adapter'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS:X Ultra, Loa kép, HP Audio Boost, Poly Studio'}, {'name': 'Webcam', 'value': 'Camera IR 5MP có chức năng giảm nhiễu tạm thời và micrô kỹ thuật số mảng kép tích hợp'}, {'name': 'Micro', 'value': 'Micrô kỹ thuật số mảng kép tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ, có đèn nền, màu xám nhạt'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Phím tắt tiếng micrô, Cửa trập bảo vệ sự riêng tư trên camera, Hỗ trợ Trusted Platform Module (Phần mềm điều khiển TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Office'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-1355U (10 lõi) - Max Turbo Frequency : 5.00 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-1355U, 10 lõi, Max Turbo Frequency 5.00 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp RAM (2 khe)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2, USB-C: 1, Thunderbolt: N/A, HDMI: 1, LAN: N/A, SD: N/A, 3.5mm: 1 (Jack Tai Nghe/Micro Combo)'}, {'name': 'Wi-Fi', 'value': '802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '32.37 x 21.5 x 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.41 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41.04Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'N/A'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím tiêu chuẩn kích thước đầy đủ; Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu bật nguồn, TPM'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-1235U (10 lõi) - Max Turbo Frequency: 4.40 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-1235U, 10 lõi, Max Turbo Frequency 4.40 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200Mhz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1x 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (Hiện đang 1x 16GB trong 2 khe)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, Viền màn hình siêu mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2, USB-C: 1, Thunderbolt: N/A, HDMI: 1, LAN: 1, SD: N/A, 3.5mm: 1 (Headphone/Microphone combo)'}, {'name': 'Wi-Fi', 'value': '802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.8 x 24.2 x 1.99 cm'}, {'name': 'Trọng lượng', 'value': '1.696 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41.04Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HP TrueVision HD có micrô mảng'}, {'name': 'Micro', 'value': 'Có (Micrô mảng)'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Administrator Password, Power-On Password, TPM'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7445HS (6 lõi, 12 luồng, up to 4.7 GHz max boost clock, 16 MB L3 cache)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 7445HS'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 với 6GB GDDR6 VRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (Hiện đang 1x16GB, còn 1 khe trống)'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe Gen4 NVMe M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '62.5% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, Viền màn hình siêu mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB Type-A: 2 cổng (5Gbps), USB Type-C: 1 cổng (5Gbps, DisplayPort 1.4a), HDMI: 1 cổng (2.1), RJ-45 (LAN): 1 cổng, Combo Audio/Mic: 1 cổng'}, {'name': 'Wi-Fi', 'value': 'Realtek Wi-Fi 6 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.79 x 25.5 x 2.35 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.29 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 52.5 Wh Li-ion polymer'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS:X Ultra, Dual speakers, HP Audio Boost'}, {'name': 'Webcam', 'value': 'Camera HP Wide Vision 720p HD có chức năng giảm nhiễu tạm thời'}, {'name': 'Micro', 'value': 'Micrô kỹ thuật số mảng kép tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ, có đèn nền RGB 1 vùng, màu xám đá mặt trăng với bàn phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Màn trập riêng tư của camera; Hỗ trợ Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Viền màn hình siêu mỏng, Wi-Fi 6'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H (8 lõi) - Max Turbo Frequency: 4.60 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi, Max Turbo Frequency: 4.60 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050'}, {'name': 'Mô tả card đồ họa', 'value': '6GB of GDDR6 SDRAM, Bus Width: 96-bit, kèm Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (Hiện đang 1x16GB, còn 1 khe trống)'}, {'name': 'Ổ cứng', 'value': '512GB SSD1 PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, Viền mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 cổng, USB-C: 1 cổng (Type-C hỗ trợ Power Delivery, DisplayPort, HP Sleep and Charge), Thunderbolt: N/A, HDMI: 1 cổng, LAN: 1 cổng (RJ45), SD: Có khe đọc thẻ nhớ, 3.5mm: 1 jack tai nghe/mic'}, {'name': 'Wi-Fi', 'value': '802.11 ax (Wi-Fi 6)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.8 x 25.5 x 2.35 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.2 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell Int (70.07Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio (by DTS:X Ultra)'}, {'name': 'Webcam', 'value': 'Camera HP Wide Vision HD và hệ thống micro đa kênh'}, {'name': 'Micro', 'value': 'Micro đa kênh'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ màu xám ánh trăng với bàn phím số, 6 hàng phím, phím chức năng đa phương tiện (Fn), bàn phím có đèn nền, Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu khởi động, fTPM 2.0, Tiện ích ổ cứng'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 255H (16 lõi, 16 luồng, lên đến 5,1 GHz)'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost (12 NPU TOPS)'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc 140T GPU'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc 140T GPU'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost (12 NPU TOPS)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5-5200 MT/s Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe Gen4 NVMe M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '62.5% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Viền mỏng, chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB Type-A: 2, HDMI-out: 1, Thunderbolt 4 Type-C: 1, USB Type-C 10Gbps: 1, Combo tai nghe/micro: 1'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Qua cổng HDMI và Thunderbolt 4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '31.4 x 22.65 x 1.49 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.41 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4-cell, 68 Wh Li-ion polymer'}, {'name': 'Sạc nhanh', 'value': 'Khoảng 50% trong 30 phút'}, {'name': 'Loại sạc', 'value': 'Bộ đổi nguồn USB Type-C 65 W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh DTS:X Ultra, Loa kép, HP Audio Boost, Poly Studio'}, {'name': 'Webcam', 'value': 'Camera hồng ngoại 5MP có chức năng giảm nhiễu tạm thời và micrô kỹ thuật số mảng kép tích hợp'}, {'name': 'Micro', 'value': 'Micrô kỹ thuật số mảng kép tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ, có đèn nền, màu xám nhạt'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Phím tắt tiếng micrô; Màn trập riêng tư của camera; Hỗ trợ Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language + Office'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Office'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 350 (8 lõi, 16 luồng, up to 5.0 GHz max boost clock, 16 MB L3 cache)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI (50 NPU TOPS)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 860M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD Ryzen AI (50 NPU TOPS)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-7500 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp (Onboard)'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe Gen4 NVMe M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '400 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Viền mỏng, chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-A 10 Gbps, 1x USB Type-A 5 Gbps, 1x HDMI 2.1, 1x Combo tai nghe/micrô, 2x USB Type-C 10 Gbps (USB PD 3.1, DisplayPort 2.1, HP Sleep and Charge)'}, {'name': 'Wi-Fi', 'value': 'MediaTek Wi-Fi 6E MT7922 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '29.73 x 21.12 x 1.65 - 1.74 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '<1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 43 Wh Li-ion polymer'}, {'name': 'Sạc nhanh', 'value': 'Khoảng 50% trong 30 phút'}, {'name': 'Loại sạc', 'value': '65 W USB Type-C power adapter'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS:X Ultra, Loa kép, HP Audio Boost, Poly Studio'}, {'name': 'Webcam', 'value': 'Camera IR 5MP có chức năng giảm nhiễu tạm thời và micrô kỹ thuật số mảng kép tích hợp'}, {'name': 'Micro', 'value': 'Micrô kỹ thuật số mảng kép tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ, có đèn nền, màu xám nhạt'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Phím tắt tiếng micrô, Cửa trập bảo vệ sự riêng tư trên camera, Hỗ trợ Trusted Platform Module (Phần mềm điều khiển TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language + Office'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Office'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-1334U (10 lõi) - Max Turbo Frequency: 4.60 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-1334U, 10 lõi, Max Turbo Frequency: 4.60 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4/ 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Hiện đang sử dụng 1 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (Tổng cộng 2 khe, hiện đang dùng 1 khe)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 cổng, USB-C: 1 cổng, Thunderbolt: N/A, HDMI: 1 cổng, LAN: N/A, SD: N/A, 3.5mm: 1 cổng'}, {'name': 'Wi-Fi', 'value': '802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '36.0 x 23.6 x 1.86 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.624 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41.04Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HP True Vision HD (có màn che riêng tư) với hệ thống micro tích hợp'}, {'name': 'Micro', 'value': 'Micro tích hợp webcam'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng phím, phím chức năng đa phương tiện (Fn), Bàn di chuột hỗ trợ thao tác bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ thao tác bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu khởi động, fTPM 2.0, Tiện ích ổ cứng'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-1335U (10 lõi) - Max Turbo Frequency: 4.60 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-1335U, 10 lõi, Max Turbo Frequency: 4.60 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (tùy thuộc vào cấu hình cụ thể)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, Viền mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2; USB-C: 1 (Type-C Power Delivery, DisplayPort); HDMI: 1; LAN: 1 (RJ45); SD-Card: Có; 3.5mm: 1 (Jack tai nghe/mic)'}, {'name': 'Wi-Fi', 'value': '802.11 ax (Wi-Fi 6)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.8 x 24.2 x 1.48 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.712 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41.04Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HP TrueVision HD với hệ thống micro tích hợp'}, {'name': 'Micro', 'value': 'Tích hợp trong Webcam'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng, chống tràn, các phím chức năng đa phương tiện (Fn). Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay, Mật khẩu quản trị viên, Mật khẩu khởi động, TPM'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i3-1315U (6 lõi) - Max Turbo Frequency: 4.50 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i3-1315U, 6 lõi, Max Turbo Frequency: 4.50 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Hiện đang sử dụng 1 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp thêm 1 khe RAM (tối đa 16GB hoặc tùy thuộc vào khả năng của máy)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, Viền mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2; USB-C: 1 (có Power Delivery, DisplayPort); HDMI: 1; LAN (RJ45): 1; SD-Card: Có; 3.5mm Jack: 1'}, {'name': 'Wi-Fi', 'value': '802.11 ax (Wi-Fi 6)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.8 x 24.2 x 1.48 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.705 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41.04Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HP TrueVision HD với hệ thống micro tích hợp'}, {'name': 'Micro', 'value': 'Tích hợp trong Webcam'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng, chống tràn, các phím chức năng đa phương tiện (Fn). Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay, Mật khẩu quản trị viên, Mật khẩu khởi động, TPM'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-1355U (10 lõi, 12 luồng, lên đến 5,0 GHz)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-1355U, bộ nhớ đệm L3 12 MB, 10 lõi, 12 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 x 8 GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (2 khe RAM)'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe NVMeTM M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói, Hỗ trợ sạc pin nhanh (khoảng 50% trong 45 phút)'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C (5 Gbps - chỉ truyền dữ liệu, không hỗ trợ sạc/màn hình ngoài), 2x USB Type-A (5 Gbps), 1x chấu thông minh AC, 1x HDMI 1.4b, 1x cổng kết hợp tai nghe/micrô'}, {'name': 'Wi-Fi', 'value': 'Realtek Wi-Fi 6 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.98 x 23.6 x 1.86 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.59 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 41 Wh Li-ion polymer'}, {'name': 'Sạc nhanh', 'value': 'Hỗ trợ sạc pin nhanh (khoảng 50% trong 45 phút)'}, {'name': 'Loại sạc', 'value': 'Bộ đổi nguồn AC thông minh 45 W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa kép'}, {'name': 'Webcam', 'value': 'Camera HP True Vision 720p HD có chức năng giảm nhiễu tạm thời và micrô kỹ thuật số mảng kép tích hợp'}, {'name': 'Micro', 'value': 'Micrô kỹ thuật số mảng kép tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Full-size, soft grey keyboard with numeric keypad'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Phím tắt tiếng micrô; Cửa trập bảo vệ sự riêng tư trên camera; Hỗ trợ Trusted Platform Module (Phần mềm điều khiển TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-1235U (10 lõi) - Max Turbo Frequency: 4.40 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-1235U, 10 lõi, Max Turbo Frequency: 4.40 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4/ 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Hiện đang sử dụng 1 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (Tổng cộng 2 khe, hiện đang dùng 1 khe)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, Viền mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 cổng, USB-C: 1 cổng, Thunderbolt: N/A, HDMI: 1 cổng, LAN: 1 cổng, SD: N/A, 3.5mm: 1 cổng'}, {'name': 'Wi-Fi', 'value': '802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.8 x 24.2 x 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.7 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41.04Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HP TrueVision HD với hệ thống micro tích hợp'}, {'name': 'Micro', 'value': 'Tích hợp trong Webcam'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng, chống tràn, phím chức năng đa phương tiện (Fn). Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu khởi động, TPM'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 350 (8 lõi, 16 luồng, up to 5.0 GHz max boost clock, 16 MB L3 cache)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI (50 NPU TOPS)'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 860M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD Ryzen AI (50 NPU TOPS)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-7500 MT/s (onboard)'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1 TB PCIe Gen4 NVMe M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '400 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '62.5% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình cảm ứng đa điểm, Kính phủ tràn cạnh edge-to-edge, Viền mỏng micro-edge, Kính Corning Gorilla Glass 3'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB Type-A 10 Gbps, 1x HDMI 2.1, 1x combo tai nghe/micrô, 1x USB Type-C 10 Gbps (USB sạc nhanh 3.1, DisplayPort 2.1, HP Sleep and Charge), 1x USB Type-C 40 Gbps (USB sạc nhanh 3.1, DisplayPort 2.1, HP Sleep and Charge)'}, {'name': 'Wi-Fi', 'value': 'MediaTek Wi-Fi 6E MT7922 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '31.3 x 21.85 x 1.46 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 59 Wh Li-ion polymer'}, {'name': 'Sạc nhanh', 'value': 'Khoảng 50% trong 30 phút'}, {'name': 'Loại sạc', 'value': 'Bộ đổi nguồn USB Type-C 65 W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS:X Ultra, Loa kép, HP Audio Boost, Poly Studio'}, {'name': 'Webcam', 'value': 'Camera IR 5MP có chức năng giảm nhiễu tạm thời và micrô kỹ thuật số mảng kép tích hợp'}, {'name': 'Micro', 'value': 'Micrô kỹ thuật số mảng kép tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ, có đèn nền, màu xám nhạt'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Phím tắt tiếng micrô, Cửa trập bảo vệ sự riêng tư camera, Hỗ trợ Trusted Platform Module (TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language + Office'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Office'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Xoay gập 360 độ (2 in 1), Nhận diện khuôn mặt'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 5 340 (6 lõi, 12 luồng, up to 4.8 GHz max boost clock, 16 MB L3 cache)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI 5 340'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 840M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD Ryzen AI (50 NPU TOPS)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-7500 MT/s Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe Gen4 NVMe M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '62.5% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Viền mỏng, Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-A 10Gbps, 1x USB Type-A 5Gbps, 1x HDMI-out 2.1, 1x cổng tai nghe/micrô, 2x USB Type-C 10Gbps (USB Power Delivery 3.1, DisplayPort 2.1, HP Sleep and Charge)'}, {'name': 'Wi-Fi', 'value': 'MediaTek Wi-Fi 6E MT7922 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 2.1 (qua USB-C)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.77 x 25.48 x 1.79 - 1.86 cm (Dài x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.79 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 59 Wh Li-ion polymer'}, {'name': 'Sạc nhanh', 'value': 'Khoảng 50% trong 30 phút'}, {'name': 'Loại sạc', 'value': 'Bộ đổi nguồn USB Type-C 65 W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'DTS:X Ultra, Loa kép, HP Audio Boost'}, {'name': 'Webcam', 'value': 'Camera IR HP True Vision 1080p FHD có chức năng giảm nhiễu theo thời gian và micrô kỹ thuật số mảng kép tích hợp'}, {'name': 'Micro', 'value': 'Micrô kỹ thuật số mảng kép tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím đầy đủ kích thước, có đèn nền, màu xám nhạt với bàn phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Phím tắt tắt micro (Mic mute key), Che camera riêng tư (Camera privacy shutter), Hỗ trợ Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home + Office'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Windows 11 Home + Office'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 3 100U (6 lõi) - Max Turbo Frequency: 4.70 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 3 100U, 6 lõi, Max Turbo Frequency: 4.70 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Hiện đang sử dụng 1 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (có 1 khe trống)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, Viền mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2; USB-C: 1 (Type-C hỗ trợ Power Delivery, DisplayPort); HDMI: 1; LAN (RJ45): 1; SD Card: Có; 3.5mm Jack: 1'}, {'name': 'Wi-Fi', 'value': '802.11 ax (Wi-Fi 6)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.8 x 24.2 x 1.48 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.699 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41.04Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HP TrueVision HD và hệ thống micro tích hợp'}, {'name': 'Micro', 'value': 'Micro tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng phím, các phím chức năng đa phương tiện (Fn), Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay, Mật khẩu quản trị viên, Mật khẩu khởi động, fTPM 2.0, Tiện ích ổ cứng Absolute Persistence Module'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 225U (12 lõi) - Max Turbo Frequency: 4.80 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics (Tích hợp)'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X/ 7467MHz Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không có khe cắm mở rộng)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1 (USB 3.2 Gen 1 Type-A), 1 (USB 3.2 Gen 2 Type-A); USB-C: 2 (USB 3.2 Gen 2 Type-C hỗ trợ PD/DP/HP Sleep and Charge); HDMI: 1; LAN: N/A; SD: N/A; 3.5mm: 1 (Giắc cắm âm thanh kết hợp tai nghe/micrô)'}, {'name': 'Wi-Fi', 'value': '802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.77 x 25.48 x 1.79 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.734 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (59.16Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera IR HP True Vision FHD (màn trập riêng tư) với micrô mảng'}, {'name': 'Micro', 'value': 'Micrô mảng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng phím đa phương tiện, phím Fn, bàn phím có đèn nền; Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Nhận dạng khuôn mặt, Mật khẩu quản trị viên, Mật khẩu bật nguồn, fTPM 2.0, Tiện ích ổ cứng'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit + Office Home 2024'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Office Home 2024'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-1335U (10 lõi) - Max Turbo Frequency: 4.60 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-1335U, 10 lõi, Max Turbo Frequency: 4.60 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4/ 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Hiện đang sử dụng 1 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (Tổng cộng 2 khe, hiện đang dùng 1 khe)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 cổng, USB-C: 1 cổng, Thunderbolt: N/A, HDMI: 1 cổng, LAN: N/A, SD: N/A, 3.5mm: 1 cổng'}, {'name': 'Wi-Fi', 'value': '802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '36.0 x 23.6 x 1.86 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.624 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41.04Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HP True Vision HD (có màn che riêng tư) với hệ thống micro tích hợp'}, {'name': 'Micro', 'value': 'Micro tích hợp webcam'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng phím, phím chức năng đa phương tiện (Fn), Bàn di chuột hỗ trợ thao tác bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ thao tác bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu khởi động, fTPM 2.0, Tiện ích ổ cứng'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 7 150U (10 lõi) - Max Turbo Frequency: 5.40 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 7 150U (10 lõi) - Max Turbo Frequency: 5.40 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (tối đa 32GB hoặc tùy thuộc vào giới hạn của bo mạch chủ)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, Viền mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2; USB-C: 1 (Type-C hỗ trợ Power Delivery, DisplayPort, HP Sleep and Charge); Thunderbolt: N/A; HDMI: 1; LAN: N/A; SD: N/A; 3.5mm: 1 (Jack tai nghe/mic)'}, {'name': 'Wi-Fi', 'value': '802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.98 x 23.60 x 1.57 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.6 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41.04Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HP True Vision HD (có màn che riêng tư) với hệ thống micro tích hợp'}, {'name': 'Micro', 'value': 'Tích hợp trong Webcam'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng, các phím chức năng đa phương tiện (Fn); Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu khởi động, TPM 2.0, Tiện ích ổ cứng'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 120U (10 lõi) - Max Turbo Frequency: 5.00 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 5 120U, 10 lõi, Max Turbo Frequency 5.00 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Hiện đang sử dụng 1 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (tối đa 16GB hoặc tùy thuộc vào cấu hình tối đa của máy)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, Viền mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2; USB-C: 1 (Type-C hỗ trợ Power Delivery, DisplayPort, HP Sleep and Charge); HDMI: 1; LAN: Không; SD: Không; 3.5mm: 1 (Jack tai nghe/mic)'}, {'name': 'Wi-Fi', 'value': '802.11 ax (Wi-Fi 6)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.98 x 23.60 x 1.57 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.6 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41.04Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HP True Vision HD (có màn che riêng tư) với hệ thống micro tích hợp'}, {'name': 'Micro', 'value': 'Micro tích hợp webcam'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng, các phím chức năng đa phương tiện (Fn), Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu khởi động, TPM 2.0, Tiện ích ổ cứng'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 120U (10 lõi) - Max Turbo Frequency: 5.00 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 5 120U, 10 lõi, Max Turbo Frequency 5.00 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Hiện đang sử dụng 1 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (có 1 khe trống)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, Viền mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x USB 3.2 Gen 1 Type-A, 1 x USB 3.2 Gen 2 Type-C (Power Delivery, DisplayPort), 1 x HDMI, 1 x RJ45 (LAN), 1 x Jack tai nghe/mic 3.5 mm, SD Card'}, {'name': 'Wi-Fi', 'value': '802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.8 x 24.2 x 1.48 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.719 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (41.04Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera HP TrueVision HD và hệ thống micro tích hợp'}, {'name': 'Micro', 'value': 'Tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng phím, các phím chức năng đa phương tiện (Fn), Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay, Mật khẩu quản trị viên, Mật khẩu khởi động, fTPM 2.0, Tiện ích ổ cứng Absolute Persistence Module'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5 - 1335U (1.30 GHz, Turbo Boost 4.6 GHz, 10 lõi / 12 luồng, 12 MB)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5 - 1335U (1.30 GHz, Turbo Boost 4.6 GHz, 10 lõi / 12 luồng, 12 MB)'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Máy nguyên bản 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (tùy thuộc vào khả năng của bo mạch chủ)'}, {'name': 'Ổ cứng', 'value': '512 GB SSD NVMe PCIe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Chống chói, N/A (Không đề cập công nghệ độc quyền khác)'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C (hỗ trợ USB, Power Delivery và DisplayPort), 1x Jack tai nghe 3.5 mm, 2x USB 3.2, 1x HDMI'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '360.2 x 234 x 17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.74 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell Li-ion, 41 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Audio by B&O, Realtek High Definition Audio, HP Audio Boost'}, {'name': 'Webcam', 'value': 'HD webcam'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5 - 1335U (1.30 GHz, Turbo Boost 4.6 GHz, 10 lõi / 12 luồng, 12 MB)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5 - 1335U (1.30 GHz, Turbo Boost 4.6 GHz, 10 lõi / 12 luồng, 12 MB)'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512 GB SSD NVMe PCIe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C (hỗ trợ USB, Power Delivery và DisplayPort), 1x Jack tai nghe 3.5 mm, 2x USB 3.2, 1x HDMI'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '360.2 x 234 x 18 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.69 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell Li-ion, 41 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Audio by B&O, Realtek High Definition Audio, HP Audio Boost'}, {'name': 'Webcam', 'value': 'HD webcam'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-12450H (8 cores) - Max Turbo Frequency: 4.40 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-12450H, 8 nhân, xung nhịp tối đa 4.40 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 2050'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX 2050 (4GB of GDDR6 SDRAM, Bus Width: 64-bit) và Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Máy nguyên bản 2x8GB, nâng cấp tối đa 32GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB 3.2 Gen 1 Type-C (hỗ trợ DisplayPort, HP Sleep and Charge), 2 x USB 3.2 Gen 1 Type-A (một cổng hỗ trợ HP Sleep and Charge), 1 x HDMI, 1 x RJ45 (LAN), 1 x giắc cắm âm thanh kết hợp tai nghe/micrô, Có Khe đọc thẻ nhớ'}, {'name': 'Wi-Fi', 'value': '802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '35.8 x 25.5 x 2.35 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.22 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (52.5Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio (by B&O)'}, {'name': 'Webcam', 'value': 'Camera HD HP Wide Vision có micrô mảng'}, {'name': 'Micro', 'value': 'Có (tích hợp trong giắc cắm âm thanh)'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím: Các phím kích thước đầy đủ với bàn phím số, bàn phím có đèn nền. Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Administrator Password, Power-On Password, TPM'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13500HX (14 lõi) - Max Turbo Frequency: 4.70 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13500HX, 14 lõi, Max Turbo Frequency: 4.70 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050'}, {'name': 'Mô tả card đồ họa', 'value': '6GB of GDDR6 SDRAM, Bus Width: 96- bit, kèm Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 4800MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (2 khe)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16.1 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '3 x USB 3.2 Gen 1 Type-A, 1 x USB 3.2 Gen 1 Type-C (hỗ trợ PD/DP/HP Sleep & Charge), 1 x HDMI, 1 x RJ45 (LAN), 1 x Giắc cắm âm thanh kết hợp tai nghe/micrô'}, {'name': 'Wi-Fi', 'value': '802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '36.9 x 25.94 x 2.39 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.334 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell Int (70.07Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio (by B&O)'}, {'name': 'Webcam', 'value': 'Camera HP TrueVision FHD (màn trập riêng tư) với micrô mảng'}, {'name': 'Micro', 'value': 'Micrô mảng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng, chống tràn, phím Fn đa phương tiện, bàn phím đèn nền RGB 1 vùng, Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu bật nguồn, TPM'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7430U (6 lõi, 12 luồng, up to 4.3 GHz max boost clock, 16 MB L3 cache)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 7430U'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 x 8GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (2 khe)'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe NVMe M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền SVA'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250 nits, Độ phủ màu 45% NTSC, màn hình chống chói, Viền màn hình siêu mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C (chỉ hỗ trợ truyền dữ liệu, không hỗ trợ sạc hoặc màn hình ngoài), 2x USB Type-A, 1x AC smart pin, 1x HDMI 1.4b, 1x headphone/microphone combo'}, {'name': 'Wi-Fi', 'value': 'Realtek Wi-Fi 6 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.98 x 23.6 x 1.86 cm (Dài x Rộng x dày)'}, {'name': 'Trọng lượng', 'value': '1.59 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 41 Wh Li-ion polymer'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Dual speakers'}, {'name': 'Webcam', 'value': 'HP True Vision 720p HD camera'}, {'name': 'Micro', 'value': 'headphone/microphone combo'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím màu xám mềm, kích thước đầy đủ với bàn phím số'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Quản lý bảo mật Phím tắt tiếng micrô, Màn trập riêng tư của camera, Hỗ trợ Mô-đun nền tảng đáng tin cậy (Phần mềm TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-1335U'}, {'name': 'Mô tả CPU', 'value': 'up to 4.6 GHz with Intel Turbo Boost Technology,12 MB L3 cache,10 lõi,12 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200 MHz RAM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2x8GB, nâng cấp tối đa 32GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe NVMe M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C, 2x USB Type-A, 1x HDMI 2.1, 1x AC smart pin, 1x headphone/microphone combo'}, {'name': 'Wi-Fi', 'value': 'N/A'}, {'name': 'Bluetooth', 'value': 'N/A'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '36.02 x 23.4 x 1.8 cm'}, {'name': 'Trọng lượng', 'value': '1.6 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 41 Wh Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Audio by B&O, Dual speakers, HP Audio Boost'}, {'name': 'Webcam', 'value': 'HP Wide Vision 720p HD camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5 - 1335U (1.30 GHz, Turbo Boost 4.6 GHz, 10 lõi / 12 luồng, 12 MB)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5 - 1335U (1.30 GHz, Turbo Boost 4.6 GHz, 10 lõi / 12 luồng, 12 MB)'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Máy nguyên bản 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (tùy thuộc vào khả năng hỗ trợ của bo mạch chủ)'}, {'name': 'Ổ cứng', 'value': '512 GB SSD NVMe PCIe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C (hỗ trợ USB, Power Delivery và DisplayPort), 1x Jack tai nghe 3.5 mm, 2x USB 3.2, 1x HDMI'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6 (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '360.2 x 234 x 17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.74 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell Li-ion, 41 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Audio by B&O, Realtek High Definition Audio, HP Audio Boost'}, {'name': 'Webcam', 'value': 'HD webcam'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-1260P, 12 nhân / 16 luồng, 18MB Intel Smart Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-1260P, 12 nhân / 16 luồng, 18MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 x DDR4 3200MHz'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (2 khe)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe NVMe M.2'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '250nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Bright View, Chống chói, Viền N/A, Cảm ứng N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C (Sạc, DisplayPort 1.4, HP ngủ và sạc), 2x USB 3.0 Type-A, 1x HDMI 2.0, 1x Headphone/microphone combo'}, {'name': 'Wi-Fi', 'value': 'Wifi 6 (Realtek RTL8822CE 802.11a/b/g/n/ac (2x2))'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0 Combo'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '36.02 x 23.4 x 1.79 cm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '1.75 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell 41 WHrs 3440mAh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'USB Type-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Headphone/microphone combo'}, {'name': 'Webcam', 'value': 'HP Wide Vision 720p HD với micrô kỹ thuật số dãy kép tích hợp'}, {'name': 'Micro', 'value': 'Micrô kỹ thuật số dãy kép tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home 64bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core I3 8145U 2.1 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i3, 2.1 GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics 620'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': 'N/A'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': 'HDD: 500 GB, Hỗ trợ thay thế SSD M.2 PCIe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Full HD'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB Type C, 2 x USB 3.0, 1 x SD card slot, Audio combo, 1 x HDMI'}, {'name': 'Wi-Fi', 'value': '802.11ac'}, {'name': 'Bluetooth', 'value': '5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '32.4 x 22.76 x 1.99 cm'}, {'name': 'Trọng lượng', 'value': '1.53 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 cell 41 Wh , Pin liền'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Audio combo'}, {'name': 'Webcam', 'value': 'N/A'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 10'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Phổ thông (<12tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5 - 1335U (4.60 GHz, 10 lõi / 12 luồng, 12MB)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5 - 1335U, 10 lõi / 12 luồng, 12MB cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB + 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (2 khe)'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe NVMe M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB Type-C (Chỉ hỗ trợ truyền dữ liệu), 2x USB Type-A, 1x HDMI 1.4b, 1x AC smart pin, 1x Headphone/microphone combo'}, {'name': 'Wi-Fi', 'value': 'Realtek Wi-Fi 6 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '32.4 x 22.5 x 1.79 cm (Dài x Rộng x Cao)'}, {'name': 'Trọng lượng', 'value': '1.46 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 41 Wh Li-ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': '2 loa'}, {'name': 'Webcam', 'value': 'HP True Vision 720p HD'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 8840HS'}, {'name': 'Mô tả CPU', 'value': '8 lõi, 16 luồng, up to 5.1 GHz max boost clock, 16 MB L3 cache'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD Ryzen AI (16 NPU TOPS)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5-6400 MT/s'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp (Onboard)'}, {'name': 'Ổ cứng', 'value': '512 GB PCIe Gen4 NVMe M.2 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'HDR 500 nits (SDR 400 nits)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Hỗ trợ cảm ứng đa điểm, Thời gian phản hồi 0.2 ms, Thiết kế tràn viền edge-to-edge, Micro-edge, Kính Corning Gorilla Glass NBT, Low Blue Light'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x USB Type-C 10Gbps (hỗ trợ USB Power Delivery, DisplayPort 1.4a, HP Sleep and Charge), 1 x USB Type-A 10Gbps, 1 x USB Type-A 10Gbps, 1 x HDMI 2.1, 1 x Headphone/Microphone combo'}, {'name': 'Wi-Fi', 'value': 'MediaTek Wi-Fi 6E MT7922 (2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A (Chỉ có 1 cổng HDMI)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '31.33 x 21.89 x 1.69 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 59 Wh Li-ion polymer, 65 W'}, {'name': 'Sạc nhanh', 'value': '65 W'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Poly Studio, Loa kép, DTS:X Ultra, HP Audio Boost'}, {'name': 'Webcam', 'value': 'Camera hồng ngoại 5MP có chức năng giảm nhiễu tạm thời và micrô kỹ thuật số mảng kép tích hợp'}, {'name': 'Micro', 'value': 'Micrô kỹ thuật số mảng kép tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ, có đèn nền, màu xám nhạt'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Phím tắt tắt Mic, Màn trập che camera, Hỗ trợ Trusted Platform Module (Firmware TPM)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language + Office'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Office'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Viền màn hình siêu mỏng, Wi-Fi 6, Màn hình cảm ứng, Nhận diện khuôn mặt, Màn hình Oled'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7735HS (8 lõi / 16 luồng, 3.2 / 4.75GHz, 4MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 7735HS, 8 lõi / 16 luồng, xung nhịp cơ bản 3.2GHz / tối đa 4.75GHz, Cache L2 4MB / L3 16MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX 3050 6GB GDDR6, Boost Clock 990MHz, TGP 65W'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (Hiện đang 1x 16GB)'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x SSD M.2 dung lượng tối đa 1TB mỗi ổ)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, FreeSync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A, 1x USB-C (hỗ trợ PD 3.0), 1x HDMI 2.1, 1x jack tai nghe/mic 3.5mm, 1x cổng Ethernet RJ-45, 1x khe đọc thẻ nhớ, 1x cổng nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.2 x 236 x 19.9-22.95 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.8 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '57.5Wh, 135W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '135W Slim Tip'}, {'name': 'Loại sạc', 'value': '3-pin'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), codec Realtek ALC3287, Loa stereo, 2W x2, Nahimic Audio'}, {'name': 'Webcam', 'value': 'HD 720p với Màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Microsoft Pluton TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7533HS (6 lõi / 12 luồng, 3.3 / 4.4GHz, 3MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 7533HS, 6 lõi / 12 luồng, xung nhịp 3.3 / 4.4GHz, Cache 3MB L2 / 16MB L3'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 660M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon 660M Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB Onboard + 8GB SODIMM DDR5-4800, nâng cấp tối đa 24GB (8GB Onboard + 16GB SODIMM))'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (2 khe cắm M.2 tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x USB-A (USB 5Gbps / USB 3.2 Gen 1), 1 x USB-C (USB 5Gbps / USB 3.2 Gen 1, hỗ trợ USB PD 45-65W và DisplayPort 1.2), 1 x HDMI 1.4, 1 x Giắc cắm tai nghe/micro kết hợp (3.5mm), 1 x Đầu đọc thẻ SD, 1 x Đầu nối nguồn tròn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.2 qua USB-C'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '360 x 251 x 16.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.73 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh, 65W Round Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '65W'}, {'name': 'Loại sạc', 'value': 'Round Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa âm thanh nổi, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'Độ phân giải HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 5 330 (4 lõi / 8 luồng, 2.0 / 4.5GHz, 4MB L2 / 8MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI, up to 50 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 820M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD Ryzen AI, up to 50 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, nâng tối đa 32GB DDR5-5600)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB DDR5-5600'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (up to 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'DisplayHDR True Black 500, Glossy'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 (5Gbps / USB 3.2 Gen 1, 1x Always On); USB-C: 2 (10Gbps, hỗ trợ USB PD 3.0 & DisplayPort 1.4); HDMI: 1 (2.1, tối đa 4K/60Hz); 3.5mm: 1; Khe đọc thẻ nhớ: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7, 802.11be 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua USB-C hỗ trợ DisplayPort 1.4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '313.4 x 222 x 16.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh'}, {'name': 'Sạc nhanh', 'value': '65W USB-C Slim (Wall-mount)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'FHD 1080p + IR với Màn trập riêng tư, Cảm biến ToF'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Backlit, English'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Microsoft Pluton TPM 2.0 Enabled, Camera hồng ngoại cho Windows Hello (nhận dạng khuôn mặt)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Nhận diện khuôn mặt, Màn hình Oled, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core up to 4.6GHz, E-core up to 3.4GHz, 12MB Intel Smart Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core up to 4.6GHz, E-core up to 3.4GHz, 12MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-5200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 8GB, nâng cấp tối đa 32GB DDR5-5200)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB DDR5-5200'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (One drive, up to 1TB M.2 2242 SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x USB-A (USB 3.2 Gen 1, 5Gbps), 1 x USB-C (USB 3.2 Gen 1, 5Gbps, PD 45–65W, DisplayPort 1.2), 1 x HDMI 1.4b, 1 x Jack tai nghe/micro 3,5mm, 1 x Ethernet (RJ-45), 1 x Cổng nguồn tròn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.2 qua USB-C'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.2 x 235.8 x 18.3 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.61 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '47Wh'}, {'name': 'Sạc nhanh', 'value': '65W USB-C (3-pin)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh HD, codec Senary SN6147, Loa stereo 1.5W x2'}, {'name': 'Webcam', 'value': 'Độ phân giải HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Discrete TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Free OS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13650HX, 14 lõi (6P + 8E) / 20 luồng, P-core 2.6 / 4.9GHz, E-core 1.9 / 3.6GHz, 24MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13650HX, 14 lõi (6P + 8E) / 20 luồng, P-core 2.6 / 4.9GHz, E-core 1.9 / 3.6GHz, 24MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 2497MHz, TGP 115W, 572 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': '572 AI TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SO-DIMM DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe cắm'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Hai khe cắm M.2 2280 PCIe 4.0 x4, tối đa 1TB mỗi ổ)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Màn hình chống chói, Độ phủ màu 100% sRGB, Dolby Vision'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x (5Gbps), USB-C: 2x (10Gbps, hỗ trợ USB PD 65-100W và DP 2.1; 1x USB-C (10Gbps) với DP 1.4, HDMI 2.1 (lên đến 8K/60Hz), 1x HDMI 2.1, 1x Giắc cắm kết hợp tai nghe/micrô (3.5mm), 1x RJ-45, 1x Đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua cổng USB-C hỗ trợ DP 2.1)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'PC-ABS + 15% Talc'}, {'name': 'Chất liệu vỏ trên', 'value': 'PC-ABS + 15% Talc'}, {'name': 'Chất liệu vỏ dưới', 'value': 'PC-ABS + 15% Talc'}, {'name': 'Kích thước', 'value': '344.9 x 255.35 x 22.50-23.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '80Wh, 245W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '245W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Slim Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 2W x2, Âm thanh của HARMAN, Nahimic Audio'}, {'name': 'Webcam', 'value': 'HD 720p với E-shutter'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English + Office Home 2024 + Lenovo AI Now'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Lenovo AI Now'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 135H, 14 lõi (4P + 8E + 2LPE) / 18 luồng, Max Turbo up to 4.6GHz, 18MB Intel Smart Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost, up to 11 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost, up to 11 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB DDR5-5600)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB DDR5-5600'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe Opal 2.0 (Hỗ trợ tối đa hai ổ đĩa, 2 ổ SSD M.2, tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 (1 x 5Gbps, 1 x 10Gbps, luôn bật); USB-C: 1 (Thunderbolt 4 / USB4 40Gbps, hỗ trợ USB PD 45-65W và DisplayPort 2.1); HDMI: 1 (2.1, hỗ trợ 4K/60Hz); 3.5mm: 1 (Giắc cắm tai nghe/micro kết hợp); LAN: 1 (RJ-45)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Qua cổng Thunderbolt 4/DisplayPort)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '313 x 220.3 x 10.1/15.25 (trước/sau), 19.7 (tối đa) mm'}, {'name': 'Trọng lượng', 'value': '1.34 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '48Wh'}, {'name': 'Sạc nhanh', 'value': '65W USB-C (3-pin)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), codec Senary SN6147, Loa âm thanh nổi, 2W x2, Dolby Atmos, Âm thanh do HARMAN sản xuất'}, {'name': 'Webcam', 'value': 'Camera lai FHD 1080p + hồng ngoại với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Discrete TPM 2.0 Enabled, Bảo mật vân tay, Nhận diện khuôn mặt'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English (US) / English (UK)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13650HX, 14 lõi (6P + 8E) / 20 luồng, P-core 2.6 / 4.9GHz, E-core 1.9 / 3.6GHz, 24MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13650HX, 14 lõi (6P + 8E) / 20 luồng, P-core 2.6 / 4.9GHz, E-core 1.9 / 3.6GHz, 24MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 2370MHz, TGP 105W, 194 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': '194 AI TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SO-DIMM DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 32GB DDR5-4800)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB DDR5-4800'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x SSD M.2 • SSD M.2 2242, mỗi ổ có dung lượng tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Màn hình chống chói, Độ phủ màu 100% sRGB, G-SYNC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 3x (5Gbps / USB 3.2 Gen 1), USB-C: 1x (10Gbps / USB 3.2 Gen 2, hỗ trợ Lenovo PD 140W và DisplayPort 1.4), HDMI: 1x (2.1, lên đến 8K/60Hz), LAN: 1x (RJ-45), SD: N/A, 3.5mm: 1x (kết hợp tai nghe/micrô), Đầu nối nguồn: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua DisplayPort 1.4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.86 x 258.7 x 21.9-23.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.38 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh, 170W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '170W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Slim Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 2W x2, Nahimic Audio'}, {'name': 'Webcam', 'value': 'HD 720p với E-shutter'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 135H, 14 lõi (4P + 8E + 2LPE) / 18 luòng, Max Turbo up to 4.6GHz, 18MB Intel Smart Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost, up to 11 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost, up to 11 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, tối đa 64GB DDR5-5600)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB DDR5-5600'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe Opal 2.0, tối đa 1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 (1 x USB 3.2 Gen 1, 5Gbps; 1 x USB 3.2 Gen 2, 10Gbps, Always On); USB-C: 1 (Thunderbolt 4 / USB4, 40Gbps, PD 45–65W, DisplayPort 2.1); HDMI: 1 (2.1, 4K/60Hz); 3.5mm: 1 (Jack tai nghe/micro); Ethernet (RJ-45): 1'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '356 x 249 x 10.1/17.05 (trước/sau), 21.15 (tối đa) mm'}, {'name': 'Trọng lượng', 'value': '1.63 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '48Wh'}, {'name': 'Sạc nhanh', 'value': '65W USB-C (3-pin)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh HD, codec Senary SN6147, Loa stereo 2W x2, Dolby Atmos, Âm thanh tinh chỉnh bởi HARMAN'}, {'name': 'Webcam', 'value': 'Camera lai FHD 1080p + hồng ngoại với màn che riêng tư'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền, tiếng Anh'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Discrete TPM 2.0 Enabled, Bảo mật vân tay, Nhận diện khuôn mặt'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English (US) / English (UK)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core up to 4.6GHz, E-core up to 3.4GHz, 12MB Intel Smart Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core up to 4.6GHz, E-core up to 3.4GHz, 12MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-5200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, tối đa 64GB DDR5-5200)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB DDR5-5200 qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Hỗ trợ tối đa hai ổ đĩa, 2 ổ SSD M.2, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400nits, Màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 cổng (5Gbps), USB-C: 1 cổng (10Gbps, PD 45–65W, DisplayPort 1.4), Thunderbolt: 1 cổng (PD 45–65W, DisplayPort 1.4), HDMI: 1 cổng (2.1, 4K/60Hz), LAN: 1 cổng (RJ-45), SD: 1 khe thẻ SD, 3.5mm: 1 jack tai nghe/micro'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '356 x 253.5 x 17.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.7 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '48Wh, 65W USB-C (3-pin)'}, {'name': 'Sạc nhanh', 'value': '65W USB-C'}, {'name': 'Loại sạc', 'value': 'USB-C (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh HD, codec Realtek ALC3287, Loa stereo 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'Camera lai FHD 1080p + hồng ngoại với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền, tiếng Anh'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Discrete TPM 2.0 Enabled, Bảo mật vân tay, Nhận diện khuôn mặt'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English (US) / English (UK)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 170 (8 lõi / 16 luồng, 3.2 / 4.75GHz, 4MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 170, 8 lõi / 16 luồng, xung nhịp 3.2 / 4.75GHz, Cache 4MB L2 / 16MB L3'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX 3050 6GB GDDR6, Boost Clock 990MHz, TGP 65W'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Tối đa 16GB DDR5-4800)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB DDR5-4800 qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Hỗ trợ tối đa hai ổ đĩa, 2 ổ SSD M.2, tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, FreeSync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2, USB-C: 1, Thunderbolt: N/A, HDMI: 1, LAN: 1, SD: 1, 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'HDMI 2.1 (tối đa 8K/60Hz)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.2 x 236 x 19.9-22.95 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.8 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '57.5Wh, 135W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '135W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Slim Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh HD, codec Realtek ALC3287, Loa stereo 2W x2, tối ưu âm thanh với Nahimic Audio'}, {'name': 'Webcam', 'value': 'Độ phân giải HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13650HX, 14 lõi (6P + 8E) / 20 luồng, P-core 2.6 / 4.9GHz, E-core 1.9 / 3.6GHz, 24MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13650HX, 14 lõi (6P + 8E) / 20 luồng, P-core 2.6 / 4.9GHz, E-core 1.9 / 3.6GHz, 24MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 2662MHz, TGP 115W, 440 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': '440 AI TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SO-DIMM DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x SSD M.2 • SSD M.2 2242, mỗi ổ có dung lượng tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Màn hình chống chói, Độ phủ màu 100% sRGB, Dolby Vision'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 2x (10Gbps, hỗ trợ USB PD 65-100W và DisplayPort 2.1; 1x DP 1.4), HDMI: 1x (lên đến 8K/60Hz), LAN: 1x (RJ-45), SD: N/A, 3.5mm: 1x (kết hợp tai nghe/micrô), Đầu nối nguồn: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Qua cổng USB-C với DisplayPort 2.1)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'PC-ABS + 15% Talc'}, {'name': 'Chất liệu vỏ trên', 'value': 'PC-ABS + 15% Talc'}, {'name': 'Chất liệu vỏ dưới', 'value': 'PC-ABS + 15% Talc'}, {'name': 'Kích thước', 'value': '344.9 x 255.35 x 22.50-23.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '80Wh, 245W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '245W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Slim Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 2W x2, Âm thanh của HARMAN, Nahimic Audio'}, {'name': 'Webcam', 'value': 'HD 720p với E-shutter'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English + Office Home 2024 + Lenovo AI Now'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Lenovo AI Now'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7735HS (8 lõi / 16 luồng, 3.2 / 4.75GHz, 4MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 7735HS, 8 lõi / 16 luồng, xung nhịp cơ bản 3.2GHz / tối đa 4.75GHz, Cache L2 4MB / L3 16MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX 3050 6GB GDDR6, Boost Clock 990MHz, TGP 65W'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (Hiện đang 1x 16GB)'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x SSD M.2 dung lượng tối đa 1TB mỗi ổ)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 100% sRGB, FreeSync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (USB 5Gbps / USB 3.2 Gen 1), 1x USB-C (USB 5Gbps / USB 3.2 Gen 1, hỗ trợ PD 3.0), 1x HDMI 2.1 (hỗ trợ tối đa 8K/60Hz), 1x jack tai nghe/mic 3.5mm, 1x cổng Ethernet RJ-45, 1x khe đọc thẻ, 1x cổng nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.2 x 236 x 19.9-22.95 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.8 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '57.5Wh, 135W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '135W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), codec Realtek ALC3287, Loa stereo, 2W x2, Nahimic Audio'}, {'name': 'Webcam', 'value': 'HD 720p với Màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Microsoft Pluton TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7735HS (8 lõi / 16 luồng, 3.2 / 4.75GHz, 4MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 7735HS, 8 lõi / 16 luồng, xung nhịp 3.2 / 4.75GHz, Cache 4MB L2 / 16MB L3'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 680M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon 680M Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-6400'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không nâng cấp)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa 2x M.2 SSD, nâng cấp lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.1 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '165Hz'}, {'name': 'Độ sáng màn hình', 'value': '500nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'DisplayHDR True Black 600'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB-A (USB 3.2 Gen 1), 1x USB-A (USB 3.2 Gen 1, Luôn bật), 2x USB-C (10Gbps / USB 3.2 Gen 2, với USB PD 3.0 và DisplayPort 1.4), 1x HDMI 2.1 (lên đến 4K/60Hz), 1x giắc cắm kết hợp tai nghe / micrô (3.5 mm), 1x đầu đọc thẻ microSD'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Qua cổng USB-C với DisplayPort 1.4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '339.33 x 236 x 15.6 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.49 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70Wh (65W USB-C Slim (Gắn tường))'}, {'name': 'Sạc nhanh', 'value': '65W USB-C Slim (Gắn tường)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'FHD 1080p + IR với Màn trập riêng tư, Cảm biến ToF'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Microsoft Pluton TPM 2.0 Enabled, Camera IR cho Windows Hello (nhận dạng khuôn mặt)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 258V, 8 lõi (4P + 4LPE) / 8 luồng, Max Turbo up to 4.8GHz, 12MB Intel Smart Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost, up to 47 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics 140V'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics 140V'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost, up to 47 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'Soldered LPDDR5x-8533, MoP Memory'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '1TB SSD M.2 2280 PCIe 5.0x4 Performance NVMe Opal 2.0, One drive, up to 2TB M.2 2280 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz VRR'}, {'name': 'Độ sáng màn hình', 'value': '500 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 500 nits\nChống chói / chống phản chiếu / chống bám vân tay\nĐộ phủ màu 100% DCI-P3\nChuẩn DisplayHDR True Black 500\nDolby Vision'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 cổng (USB 3.2 Gen 1, 5Gbps – 1 cổng Always On)\nUSB-C: 2 cổng (Thunderbolt 4 / USB4 40Gbps, hỗ trợ Power Delivery 3.0 & DisplayPort 2.1)\nHDMI: 1 cổng (HDMI 2.1, tối đa 4K/60Hz)\nLAN: N/A\nSD: N/A\n3.5mm: 1 cổng (Jack tai nghe/micro)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 7 BE201, 802.11be 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4, vPro\nNFC'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Qua cổng USB-C Thunderbolt 4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Carbon Fiber'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Magiê'}, {'name': 'Kích thước', 'value': '312.80 x 214.75 x 8.08 / 14.37 (trước/sau), 16.95 (tối đa) mm'}, {'name': 'Trọng lượng', 'value': '986 g'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '57Wh, 65W USB-C Slim GaN (3-pin)'}, {'name': 'Sạc nhanh', 'value': '65W USB-C Slim GaN (3-pin)'}, {'name': 'Loại sạc', 'value': 'USB-C Slim GaN (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Lunar Lake: SoundWire, Realtek ALC713 codec\nLoa âm thanh nổi, 2W x2, Dolby Atmos'}, {'name': 'Webcam', 'value': 'FHD 1080p + IR Discrete với màn trập camera'}, {'name': 'Micro', 'value': '2x, 360°'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền, tiếng Anh'}, {'name': 'Touchpad', 'value': 'Trackpad'}, {'name': 'Bảo mật', 'value': 'Discrete TPM 2.0 Enabled, Bảo mật vân tay, Nhận diện khuôn mặt'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Pro, English (US) / English (UK)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H (8 lõi (4P + 4E) / 12 luồng, P-core 2.1/4.6GHz, E-core 1.5/3.4GHz, 12MB)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E), 12 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '8GB Onboard + 8GB SO-DIMM DDR5-4800 (Nâng cấp tối đa 24GB (8GB Onboard + 16GB SO-DIMM))'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400nits, Độ phủ màu 100% DCI-P3'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (5Gbps / USB 3.2 Gen 1), 1x USB-C (5Gbps / USB 3.2 Gen 1, hỗ trợ USB PD 3.0 và DisplayPort 1.2), 1x HDMI 1.4, 1x giắc cắm kết hợp tai nghe / micrô (3,5 mm), 1x đầu nối nguồn, Có Khe đọc thẻ nhớ'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.2 (qua USB-C)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '14 inches'}, {'name': 'Trọng lượng', 'value': '1.33kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Đầu tròn 65W (3 chân)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'Đầu tròn 65W (3 chân)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD)'}, {'name': 'Webcam', 'value': 'HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'LED'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English Office Trial'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'English Office Trial'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 9 275HX, 24 lõi (8P + 16E) / 24 luồng, Max Turbo up to 5.4GHz, 36MB Intel Smart Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost, up to 13 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5070 Ti 12GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 2220MHz, TGP 140W, 992 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost, up to 13 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'CSODIMM DDR5-6400'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 16GB, tối đa 32GB DDR5-6400)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB DDR5-6400 qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB SSD M.2 2242 PCIe 4.0x4 NVMe, tối đa 2TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '240 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500 nits (điển hình) / 1100 nits (đỉnh)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Dolby Vision, G-SYNC, Giảm ánh sáng xanh, Hiệu năng chơi game cao, Chống nhấp nháy'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 3; USB-C: 2 (1 x USB 3.2 Gen 2, 1 x Thunderbolt 4 / USB4 – hỗ trợ DisplayPort 2.1, Sạc); HDMI: 1 (2.1); LAN: 1 (2.5GbE RJ-45); SD: N/A; 3.5mm: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7, 802.11be 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua cổng HDMI 2.1 và Thunderbolt 4/USB4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '364.38 x 275.94 x 21.9-26.65 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.57 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '80Wh, 400W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '400W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': '400W Slim Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), codec Realtek ALC3306; 4 loa stereo: 2W x2 (woofer) + 2W x2 (tweeter); Tối ưu với Nahimic Audio; Khuếch đại thông minh (Smart Amplifier / AMP)'}, {'name': 'Webcam', 'value': '5.0MP với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím có đèn nền RGB từng phím, tiếng Anh'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English + Office Trial + Lenovo AI Now'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Lenovo AI Now'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 135H, 14 lõi (4P + 8E + 2LPE) / 18 luồng, Max Turbo up to 4.6GHz, 18MB Intel Smart Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost, up to 11 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost, up to 11 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1x 16GB, tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Hai khe cắm M.2 2280 PCIe 4.0 x4, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 cổng (5Gbps, 1 cổng Always On); USB-C: 2 cổng (10Gbps, PD 45–65W, DP 1.4); Thunderbolt 4 / USB4: 1 cổng (40Gbps, PD 45–65W, DP 2.1); HDMI: 1 cổng (tối đa 4K/60Hz); 3.5mm: 1 cổng; LAN: 1 cổng; SD: 1 khe đọc thẻ SD'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua cổng HDMI và Thunderbolt 4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '313.5 x 224 x 17.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.36 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '45Wh'}, {'name': 'Sạc nhanh', 'value': '65W USB-C (3-pin)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), codec Realtek ALC3287, Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'Camera lai FHD 1080p + hồng ngoại với màn che riêng tư'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền, tiếng Anh'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled, Bảo mật vân tay, Nhận diện khuôn mặt'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English (US) / English (UK)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 125H, 14 lõi (4P + 8E + 2LPE) / 18 luồng, Max Turbo up to 4.5GHz, 18MB'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost, up to 11 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost, up to 11 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5-6400'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '1TB SSD M.2 2242 PCIe 4.0x4 NVMe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400nits\nĐộ phủ màu 100% DCI-P3\nEyesafe\nDolby Vision\nDisplayHDR True Black 500'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB-A (USB 5Gbps / USB 3.2 Gen 1, Luôn bật), 2x USB-C (Thunderbolt 4 / USB 4 40Gbps, với USB PD 3.1 và DisplayPort 1.4), 1x HDMI 2.1 (lên đến 4K/60Hz), 1x Giắc cắm kết hợp tai nghe/micrô (3.5mm)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua Thunderbolt 4/DisplayPort)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '312 x 221 x 14.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '65Wh, 65W USB-C Slim (Wall-mount)'}, {'name': 'Sạc nhanh', 'value': '65W USB-C Slim (Wall-mount)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD)\nBộ giải mã Realtek ALC3306\nLoa stereo, 2W x4\nDolby Atmos\nBộ khuếch đại (AMP)'}, {'name': 'Webcam', 'value': 'FHD 1080p + IR với màn trập điện tử, cảm biến ToF'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Backlit, English'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English + Microsoft 365 Basic + Office Home 2024'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft 365 Basic + Office Home 2024'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7535HS (6 lõi / 12 luồng, 3.3 / 4.55GHz, 3MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 7535HS, 6 lõi / 12 luồng, xung nhịp 3.3 / 4.55GHz, Cache L2 3MB / L3 16MB'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 660M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon 660M Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB Soldered + 8GB SODIMM, nâng cấp tối đa 24GB (8GB soldered + 16GB SODIMM))'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Hai khe cắm M.2 2242 PCIe 4.0 x4, tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x USB-A, 1 x USB-C (hỗ trợ USB PD 45-65W và DisplayPort 1.2), 1 x HDMI 1.4, 1 x Giắc cắm tai nghe/micro kết hợp (3.5mm), 1 x Đầu đọc thẻ SD, 1 x Đầu nối nguồn tròn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.2 qua USB-C'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314.4 x 222.1 x 16.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50Wh, 65W Round Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '65W'}, {'name': 'Loại sạc', 'value': 'Round Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa âm thanh nổi, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'Độ phân giải HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core up to 4.6GHz, E-core up to 3.4GHz, 12MB Intel Smart Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core up to 4.6GHz, E-core up to 3.4GHz, 12MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB DDR5-5200)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB DDR5-5200'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Hỗ trợ tối đa hai ổ đĩa, 2 ổ SSD M.2, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400nits, Màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 cổng, USB-C: 1 (USB PD 45-65W và DisplayPort 1.4), Thunderbolt: 1, HDMI: 1 (2.1 4K/60Hz), LAN: 1 (RJ-45), SD: 1 (Đầu đọc thẻ SD), 3.5mm: 1 (Giắc cắm tai nghe/micro kết hợp)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Qua cổng USB-C/Thunderbolt 4 hỗ trợ DisplayPort 1.4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '313.5 x 224 x 17.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.36 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '48Wh'}, {'name': 'Sạc nhanh', 'value': '65W USB-C (3-pin)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), codec Realtek ALC3287, Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'Camera lai FHD 1080p + hồng ngoại với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Discrete TPM 2.0 Enabled, Bảo mật vân tay, Nhận diện khuôn mặt'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English (US) / English (UK)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 7 350 (8 lõi / 16 luồng, 2.0 / 5.0GHz, 8MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI, up to 50 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 860M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD Ryzen AI, up to 50 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 16GB SO-DIMM DDR5-5600, tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x M.2 SSD • M.2 2242 SSD lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'DisplayHDR True Black 500, Glossy'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 (5Gbps / 3.2 Gen 1), USB-C: 2 (10Gbps / 3.2 Gen 2, hỗ trợ USB PD 3.0 và DisplayPort 1.4), HDMI: 1 (2.1, lên đến 4K/60Hz), 3.5mm: 1 (kết hợp tai nghe/micrô), SD Card Reader: 1, LAN: N/A'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7, 802.11be 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua DisplayPort 1.4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '313.4 x 222 x 16.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh (65W USB-C Slim (Wall-mount))'}, {'name': 'Sạc nhanh', 'value': '65W USB-C Slim (Wall-mount)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'FHD 1080p + IR với Màn camera, Cảm biến ToF'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền, tiếng Anh'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Microsoft Pluton TPM 2.0 Enabled, Camera IR cho Windows Hello (nhận dạng khuôn mặt)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Nhận diện khuôn mặt, Màn hình Oled, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 258V, 8 lõi (4P + 4LPE) / 8 luồng, Max Turbo up to 4.8GHz, 12MB Intel Smart Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost, up to 47 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics 140V'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics 140V'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost, up to 47 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-8533 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2280 PCIe 5.0x4 Performance NVMe Opal 2.0 (Một ổ đĩa, SSD M.2 2280 dung lượng lên đến 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 500 nits (chống chói / chống phản xạ / chống bám vân tay)\nĐộ phủ màu 100% DCI-P3\nDisplayHDR True Black 500\nDolby Vision'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 (USB 3.2 Gen 1, 5Gbps, 1 luôn bật)\nUSB-C: 2 (Thunderbolt 4 / USB4, 40Gbps, PD 3.0, DisplayPort 2.1)\nHDMI: 1 (HDMI 2.1, tối đa 4K/60Hz)\n3.5mm: 1 (Jack tai nghe/mic)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 7 BE201, 802.11be 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4, vPro, NFC'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua cổng USB-C Thunderbolt 4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Carbon Fiber'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Magiê'}, {'name': 'Kích thước', 'value': '312.80 x 214.75 x 8.08/14.37 (front/rear), 16.95 (tối đa) mm'}, {'name': 'Trọng lượng', 'value': '986 g'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '57Wh'}, {'name': 'Sạc nhanh', 'value': '65W USB-C Slim GaN (3-pin)'}, {'name': 'Loại sạc', 'value': 'USB-C Slim GaN (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'SoundWire, codec Realtek ALC713, Loa stereo 2W x2, Dolby Atmos'}, {'name': 'Webcam', 'value': 'FHD 1080p + IR Discrete với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền, tiếng Anh'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Discrete TPM 2.0 Enabled, Bảo mật vân tay, Nhận diện khuôn mặt'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Pro, English (US) / English (UK)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7535HS (6 lõi / 12 luồng, 3.3 / 4.55GHz, 3MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 7535HS, 6 lõi / 12 luồng, xung nhịp 3.3 / 4.55GHz, Cache 3MB L2 / 16MB L3'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 660M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon 660M Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB Onboard + 8GB SODIMM DDR5-4800, nâng cấp tối đa 24GB (8GB + 16GB))'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB (sử dụng 2 khe)'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x SSD M.2, nâng cấp lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (USB 5Gbps / USB 3.2 Gen 1), 1x USB-C (USB 5Gbps / USB 3.2 Gen 1, Hỗ Trợ USB PD 3.0 & DisplayPort 1.2), 1x HDMI 1.4, 1x Jack Tai Nghe/Micro Combo (3.5mm), 1x Khe Đọc Thẻ SD, 1x Đầu Nối Nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ qua cổng USB-C (DisplayPort 1.2)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314.4 x 222.1 x 16.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50Wh, 65W Round Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '65W Round Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Round Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với Màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Microsoft Pluton TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13645HX, 14 lõi (6P + 8E) / 20 luồng, P-core up to 4.9GHz, E-core up to 3.5GHz, 24MB Intel Smart Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13645HX, 14 lõi (6P + 8E) / 20 luồng, P-core up to 4.9GHz, E-core up to 3.5GHz, 24MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7, Boost Clock 2370MHz, TGP 100W, 440 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': '440 AI TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 32GB DDR5-5600)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB DDR5-5600'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Hai khe cắm, hỗ trợ tối đa hai ổ đĩa, dung lượng lên đến 1TB mỗi ổ)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 100% sRGB, G-SYNC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 3, USB-C: 1 (hỗ trợ USB PD 65-100W và DisplayPort 1.4), Thunderbolt: N/A, HDMI: 1 (2.1, lên đến 8K/60Hz), LAN: 1 (RJ-45), SD: N/A, 3.5mm: 1 (Giắc cắm tai nghe/micro kết hợp)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.86 x 258.7 x 21.9-23.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh, 170W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '170W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': '3-pin'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), codec Realtek ALC3287, Loa stereo, 2W x2, Nahimic Audio'}, {'name': 'Webcam', 'value': '5.0MP với E-shutter'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': '24-Zone RGB'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 210H, 8 lõi (4P + 4E) / 12 luồng, P-core 2.2 / 4.8GHz, E-core 1.6 / 3.6GHz, 12MB Intel Smart Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 5 210H, 8 lõi (4P + 4E) / 12 luồng, P-core 2.2 / 4.8GHz, E-core 1.6 / 3.6GHz, 12MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-5200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 32GB DDR5-5200)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB DDR5-5200'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Một ổ đĩa, SSD M.2 2242 dung lượng lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x USB-A (USB 3.2 Gen 1, 5Gbps), 1 x USB-C (USB 3.2 Gen 1, 5Gbps, PD 45–65W, DisplayPort 1.2), 1 x HDMI 1.4b, 1 x Jack tai nghe/mic 3.5 mm, 1 x Ethernet (RJ-45), 1 x Cổng nguồn tròn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '324.2 x 215.2 x 17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.37 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '47Wh, 65W USB-C (3-pin)'}, {'name': 'Sạc nhanh', 'value': '65W USB-C'}, {'name': 'Loại sạc', 'value': 'USB-C (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), codec Senary SN6147, Loa stereo, 1.5W x2'}, {'name': 'Webcam', 'value': 'Độ phân giải HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Discrete TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English (US) / English (UK)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, Bảo mật vân tay'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13650HX, 14 lõi (6P + 8E) / 20 luồng, P-core 2.6 / 4.9GHz, E-core 1.9 / 3.6GHz, 24MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13650HX, 14 lõi (6P + 8E) / 20 luồng, P-core 2.6 / 4.9GHz, E-core 1.9 / 3.6GHz, 24MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7, Boost Clock 2370MHz, TGP 100W, 440 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': '440 AI TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 32GB DDR5-4800)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB DDR5-4800'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Hỗ trợ tối đa 2 ổ M.2 2242 SSD, mỗi ổ tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 100% sRGB, G-SYNC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 3 cổng (5Gbps / USB 3.2 Gen 1); USB-C: 1 cổng (10Gbps / USB 3.2 Gen 2, hỗ trợ USB PD 65-100W và DisplayPort 1.4); HDMI: 1 cổng (2.1, lên đến 8K/60Hz); 3.5mm: 1 cổng (kết hợp tai nghe/micrô); LAN: 1 cổng (RJ-45); SD: N/A'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua DisplayPort 1.4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.86 x 258.7 x 21.9–23.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh, 170W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '170W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': '3-pin'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh HD với chip Realtek ALC3287, Loa stereo 2W x2, tối ưu chất lượng bởi Nahimic Audio'}, {'name': 'Webcam', 'value': '5.0MP với E-shutter'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': '24-Zone RGB Backlit'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English + Office Trial + Lenovo AI Now'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Lenovo AI Now'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7535HS (6 lõi / 12 luồng, 3.3 / 4.55GHz, 3MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': '6 lõi / 12 luồng, xung nhịp cơ bản 3.3GHz, xung nhịp tối đa 4.55GHz, Cache L2 3MB, Cache L3 16MB'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 660M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB Onboard + 16GB SODIMM DDR5-4800, nâng cấp tối đa 24GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x SSD M.2, nâng cấp lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (USB 5Gbps / USB 3.2 Gen 1), 1x USB-C (USB 5Gbps / USB 3.2 Gen 1, Hỗ Trợ USB PD 3.0 & DisplayPort 1.2), 1x HDMI 1.4, 1x Jack Tai Nghe/Micro Combo (3.5mm), 1x Khe Đọc Thẻ SD, 1x Đầu Nối Nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ qua USB-C (DisplayPort 1.2)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314.4 x 222.1 x 16.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50Wh, 65W Round Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '65W Round Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Round Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với Màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Microsoft Pluton TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 5825U (8 lõi / 16 luồng, 2.0 / 4.5GHz, 4MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': '8 lõi / 16 luồng, xung nhịp 2.0 / 4.5GHz, Cache 4MB L2 / 16MB L3'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR4x-4266 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Một ổ đĩa, tối đa 1TB M.2 2242 SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, TÜV Low Blue Light'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 (5Gbps / 3.2 Gen 1, 1x Luôn bật); USB-C: 1 (10Gbps / 3.2 Gen 2, hỗ trợ USB PD 3.0 và DisplayPort 1.4); HDMI: 1 (1.4b); 3.5mm: 1 (kết hợp tai nghe / micrô); SD: 1 (đầu đọc thẻ SD); Nguồn: 1 (đầu nối nguồn)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa + 40% GF'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa + 40% GF'}, {'name': 'Kích thước', 'value': '313.1 x 224.9 x 17.8 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.55 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '52.5Wh (65W Round Tip (3-pin))'}, {'name': 'Sạc nhanh', 'value': '65W Round Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Round Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa âm thanh nổi hướng về phía trước, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'FHD 1080p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền, tiếng Anh'}, {'name': 'Touchpad', 'value': 'Màn hình cảm ứng'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0, Bảo mật vân tay'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7535HS (6 lõi / 12 luồng, 3.3 / 4.55GHz, 3MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 7535HS, 6 lõi / 12 luồng, xung nhịp 3.3 / 4.55GHz, Cache L2 3MB / L3 16MB'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 660M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon 660M Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 khe tối đa 16GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB (tùy thuộc vào cấu hình ban đầu)'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Hai khe cắm M.2 2242 PCIe 4.0 x4, tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x USB-A (USB 3.2 Gen 1, 5Gbps), 1 x USB-C (USB 3.2 Gen 1, 5Gbps, PD 45–65W, DisplayPort 1.2), 1 x HDMI 1.4, 1 x Jack tai nghe/mic 3.5 mm, 1 x Khe thẻ SD, 1 x Cổng nguồn tròn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314.4 x 222.1 x 16.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50Wh, 65W Round Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '65W'}, {'name': 'Loại sạc', 'value': 'Round Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa âm thanh nổi, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'Độ phân giải HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H, 10 lõi (6P + 4E) / 16 luồng, P-core 2.4 / 4.9GHz, E-core 1.8 / 3.6GHz, 24MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 10 lõi (6P + 4E) / 16 luồng, P-core 2.4 / 4.9GHz, E-core 1.8 / 3.6GHz, 24MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '8GB Soldered DDR5-4800 + 8GB SO-DIMM DDR5-4800 (Nâng cấp tối đa 24GB (8GB hàn + 16GB SO-DIMM) DDR5-4800)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB (thêm 8GB SO-DIMM)'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x M.2 SSD • M.2 2242 SSD lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (USB 5Gbps / USB 3.2 Gen 1), 1x USB-C (USB 5Gbps / USB 3.2 Gen 1, với USB PD 3.0 và DisplayPort 1.2), 1x HDMI 1.4, 1x giắc cắm kết hợp tai nghe / micrô (3.5 mm), 1x đầu đọc thẻ SD, 1x đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.2 (qua USB-C)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '360 x 251 x 16.9 - 17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.73 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh'}, {'name': 'Sạc nhanh', 'value': 'Đầu tròn 65W (3 chân)'}, {'name': 'Loại sạc', 'value': 'Đầu tròn 65W (3 chân)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 220 (6 lõi / 12 luồng, 3.2 / 4.9GHz, 6MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 220, 6 lõi / 12 luồng, xung nhịp 3.2 / 4.9GHz, Cache 6MB L2 / 16MB L3'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 740M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon 740M Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB DDR5-5600)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB DDR5-5600'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Hỗ trợ tối đa hai ổ đĩa, 2 ổ SSD M.2, tối đa 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400nits, màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 cổng (1 x USB 5Gbps, Always On; 1 x USB 5Gbps); USB-C: 2 cổng (USB4 40Gbps, PD 45–65W, DisplayPort 1.4a); HDMI: 1 cổng (HDMI 2.1, tối đa 4K/60Hz); 3.5mm: 1 cổng (Jack tai nghe/mic); Ethernet (RJ-45): 1 cổng; USB-A: 1 cổng (USB 5Gbps); SD Card: 1 khe đọc thẻ SD'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7, 802.11be 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.4a qua USB-C'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '313.5 x 224 x 17.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.36 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '48Wh'}, {'name': 'Sạc nhanh', 'value': '65W USB-C (3-pin)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh HD, codec Realtek ALC3287, Loa stereo 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'Camera lai FHD 1080p + hồng ngoại với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền, tiếng Anh'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Discrete TPM 2.0 Enabled, Bảo mật vân tay, Nhận diện khuôn mặt'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English (US) / English (UK)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7735HS (8 lõi / 16 luồng, 3.2 / 4.75GHz, 4MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': '8 lõi / 16 luồng, xung nhịp cơ bản 3.2GHz / tối đa 4.75GHz, Cache L2 4MB / L3 16MB'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 680M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-6400 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x M.2 SSD / M.2 2242 SSD lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.1 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'DisplayHDR True Black 600'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 (5Gbps / 3.2 Gen 1, 1 cổng luôn bật) | USB-C: 2 (10Gbps / 3.2 Gen 2, hỗ trợ USB PD 3.0 và DisplayPort 1.4) | HDMI: 1 (2.1, lên đến 4K/60Hz) | 3.5mm: 1 (kết hợp tai nghe/micrô) | Khác: Khe đọc thẻ nhớ, Đầu đọc thẻ nhớ microSD'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua USB-C với DisplayPort 1.4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '339.33 x 236 x 15.6 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.49 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70Wh'}, {'name': 'Sạc nhanh', 'value': '65W USB-C Slim (Wall-mount)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'FHD 1080p + IR với Màn trập riêng tư, Cảm biến ToF'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đơn sắc - Màu trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Microsoft Pluton TPM 2.0 Enabled, Camera IR cho Windows Hello (nhận dạng khuôn mặt)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Snapdragon X X1-26-100, 8C, Max Turbo up to 3.0GHz, 30MB'}, {'name': 'Mô tả CPU', 'value': '8 nhân, Max Turbo lên đến 3.0GHz, Cache 30MB'}, {'name': 'Tên card đồ họa', 'value': 'Qualcomm Adreno (Tích hợp)'}, {'name': 'Mô tả card đồ họa', 'value': 'Qualcomm Adreno'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Qualcomm Hexagon NPU, up to 45 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-8448 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Hỗ trợ tối đa 2 ổ M.2 2242 SSD, dung lượng tối đa 1TB mỗi ổ)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (5Gbps / USB 3.2 Gen 1), 1x USB-C (5Gbps / USB 3.2 Gen 1, hỗ trợ USB PD 3.0 và DP 1.2), 1x HDMI 1.4, 1x Giắc cắm kết hợp tai nghe/micrô (3.5mm), 1x Đầu đọc thẻ SD, 1x Đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '343.4 x 239.5 x 16.9–17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.55 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh, 65W Round Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '65W Round Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Round Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'High Definition (HD) Audio, Stereo speakers, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p tích hợp, có màn che bảo mật (Privacy Shutter)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không đèn'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Microsoft Pluton TPM 2.0 Enabled, Bảo mật vân tay'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language (on ARM), English + Microsoft 365 Basic + Office Home 2024'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft 365 Basic + Office Home 2024'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Có Wi-Fi 6, Bảo mật vân tay'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 135H, 14 lõi (4P + 8E + 2LPE) / 18 luồng, Max Turbo up to 4.6GHz, 18MB Intel Smart Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost, up to 11 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost, up to 11 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 16GB, nâng cấp tối đa 32GB DDR5-5600)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp tối đa lên 32GB DDR5-5600'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Hỗ trợ tối đa hai ổ đĩa, 2 ổ SSD M.2, tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'DisplayHDR True Black 500'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB-A (USB 5Gbps), luôn bật; 2 x USB-C (USB 10Gbps, hỗ trợ USB PD 3.0 và DisplayPort 1.4); 1 x HDMI 2.1 (hỗ trợ 4K/60Hz); 1 x Giắc cắm tai nghe/micro kết hợp (3.5mm); 1 x Đầu đọc thẻ microSD'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7, 802.11be 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ qua USB-C (DisplayPort 1.4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '313.4 x 222 x 16.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh'}, {'name': 'Sạc nhanh', 'value': '65W USB-C Slim (2-pin, Wall-mount)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa âm thanh nổi, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'Camera FHD 1080p + hồng ngoại với màn trập camera, cảm biến ToF'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Nhận diện khuôn mặt, Màn hình Oled, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H, 10 lõi (6P + 4E) / 16 luồng, P-core 2.4 / 4.9GHz, E-core 1.8 / 3.6GHz, 24MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 10 lõi (6P + 4E) / 16 luồng, P-core 2.4 / 4.9GHz, E-core 1.8 / 3.6GHz, 24MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB Onboard + 16GB SO-DIMM, tối đa 24GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên đến 24GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, nâng cấp lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (USB 5Gbps / USB 3.2 Gen 1), 1x USB-C (USB 5Gbps / USB 3.2 Gen 1, với USB PD 3.0 và DisplayPort 1.2), 1x HDMI 1.4, 1x giắc cắm kết hợp tai nghe / micrô (3,5 mm), 1x đầu đọc thẻ SD, 1x đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.2 (qua USB-C)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Nhôm, Nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314.4 x 222.1 x 16.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.43 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh (Đầu tròn 65W (3 chân))'}, {'name': 'Sạc nhanh', 'value': '65W (3 chân)'}, {'name': 'Loại sạc', 'value': 'Đầu tròn 65W (3 chân)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'High Definition (HD) Audio, Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H, 10 lõi (6P + 4E) / 16 luồng, P-core 2.4 / 4.9GHz, E-core 1.8 / 3.6GHz, 24MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 10 lõi (6P + 4E) / 16 luồng, P-core 2.4 / 4.9GHz, E-core 1.8 / 3.6GHz, 24MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '8GB Soldered DDR5-4800 + 16GB SO-DIMM DDR5-4800 (Tối đa 24GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp tối đa lên 24GB qua khe SO-DIMM'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x M.2 SSD • M.2 2242 SSD lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (USB 5Gbps / USB 3.2 Gen 1), 1x USB-C (USB 5Gbps / USB 3.2 Gen 1, hỗ trợ USB PD 3.0 và DisplayPort 1.2), 1x HDMI 1.4, 1x giắc cắm kết hợp tai nghe / micrô (3.5 mm), 1x đầu đọc thẻ SD, 1x đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua DisplayPort 1.2 trên cổng USB-C)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '360 x 251 x 16.9 - 17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.73 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh'}, {'name': 'Sạc nhanh', 'value': 'Đầu tròn 65W (3 chân)'}, {'name': 'Loại sạc', 'value': 'Đầu tròn 65W (3 chân)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7735HS (8 lõi / 16 luồng, 3.2 / 4.75GHz, 4MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 7735HS, 8 lõi / 16 luồng, xung nhịp 3.2 / 4.75GHz, Cache 4MB L2 / 16MB L3'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 680M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon 680M Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 khe tối đa 16GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB (tùy thuộc vào cấu hình ban đầu)'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Hai khe cắm M.2 2242 PCIe 4.0 x4, tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x USB-A (USB 3.2 Gen 1, 5Gbps), 1 x USB-C (USB 3.2 Gen 1, 5Gbps, PD 45–65W, DisplayPort 1.2), 1 x HDMI 1.4, 1 x Jack tai nghe/mic 3.5 mm, 1 x Khe thẻ SD, 1 x Cổng nguồn tròn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314.4 x 222.1 x 16.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50Wh, 65W Round Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '65W'}, {'name': 'Loại sạc', 'value': 'Round Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa âm thanh nổi, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'FHD 1080p + Hồng ngoại với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, Nhận diện khuôn mặt'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13645HX, 14 lõi (6P + 8E) / 20 luồng, P-core up to 4.9GHz, E-core up to 3.5GHz, 24MB Intel Smart Cache'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13645HX, 14 lõi (6P + 8E) / 20 luồng, P-core up to 4.9GHz, E-core up to 3.5GHz, 24MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 2370MHz, TGP 105W, 194 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': '194 AI TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 32GB DDR5-4800)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB DDR5-4800'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Hai khe cắm M.2 2280 PCIe 4.0 x4, nâng cấp dung lượng lên đến 1TB mỗi ổ)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Màn hình chống chói, Độ phủ màu 100% sRGB, G-SYNC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '3 x USB-A (USB 3.2 Gen 1, 5Gbps), 1 x USB-C (USB 3.2 Gen 2, 10Gbps, Lenovo PD 140W, DisplayPort 1.4), 1 x HDMI 2.1 (tối đa 8K/60Hz), 1 x Jack tai nghe/mic 3.5 mm, 1 x Ethernet (RJ-45), 1 x Cổng nguồn Slim tip'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.86 x 258.7 x 21.9-23.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.38 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh, 170W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '170W Slim Tip'}, {'name': 'Loại sạc', 'value': '3-pin'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh HD, codec Realtek ALC3287, Loa stereo 2W x2, Tối ưu với Nahimic Audio'}, {'name': 'Webcam', 'value': 'HD 720p với E-shutter'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7535HS (6 lõi / 12 luồng, 3.3 / 4.55GHz, 3MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 7535HS, 6 lõi / 12 luồng, xung nhịp 3.3 / 4.55GHz, Cache 3MB L2 / 16MB L3'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 990MHz, TGP 65W'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (Hiện đang 1x16GB, còn 1 khe trống)'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2 ổ SSD M.2, SSD M.2 dung lượng tối đa 1TB mỗi ổ)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits, màn hình chống chói, Độ phủ màu 100% sRGB, AMD FreeSync'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 cổng (USB 3.2 Gen 1, 5Gbps), USB-C: 1 cổng (USB 5Gbps, PD 65–100W), HDMI: 1 cổng (HDMI 2.1, tối đa 8K/60Hz), LAN: 1 cổng (RJ-45), SD Card Reader: 1 cổng, 3.5mm Jack: 1 cổng, Cổng nguồn: 1 cổng'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.2 x 236 x 19.9-22.95 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.8 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '57.5Wh, 135W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '135W Slim Tip'}, {'name': 'Loại sạc', 'value': '3-pin'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh HD, codec Realtek ALC3287, Loa stereo 2W x2, Tối ưu với Nahimic Audio'}, {'name': 'Webcam', 'value': 'HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 9 275HX, 24 lõi (8P + 16E) / 24 luồng, Max Turbo up to 5.4GHz, 36MB'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost, up to 13 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5070 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 2347MHz, TGP 115W, 798 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost, up to 13 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 16GB, tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x SSD M.2, mỗi ổ có dung lượng tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '240 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500nits (Điển hình) / 1100nits (Cao)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'DisplayHDR True Black 1000, Dolby Vision, G-SYNC, Ánh sáng xanh thấp, Hiệu suất chơi game cao, Không nhấp nháy'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (5Gbps), 1x USB-C (10Gbps, USB PD 65-100W và DP 2.1), 1x USB-C (Thunderbolt 4 / 40Gbps, USB PD 65-100W và DP 2.1), 1x HDMI 2.1 (lên đến 8K/60Hz), 1x Giắc cắm kết hợp tai nghe/micrô (3.5mm), 1x Đầu đọc thẻ, 1x Đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7, 802.11be 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua cổng USB-C/Thunderbolt hỗ trợ DP 2.1)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '361.7 x 263.4 x 15.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.0 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '84Wh, 245W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '245W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Slim Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), codec Realtek ALC3306, Loa stereo, 2W x2, Âm thanh của HARMAN, Nahimic Audio, Bộ khuếch đại thông minh (AMP)'}, {'name': 'Webcam', 'value': '5.0MP + IR với E-shutter'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Per-key RGB Backlit, English'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English + Office Home 2024 + Lenovo AI Now'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Lenovo AI Now'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13450HX, 10 lõi (6P + 4E) / 16 luồng, P-core 2.4 / 4.6GHz, E-core 1.8 / 3.4GHz, 20MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13450HX, 10 lõi (6P + 4E) / 16 luồng, P-core 2.4 / 4.6GHz, E-core 1.8 / 3.4GHz, 20MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 1732MHz, TGP 95W, 142 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': '142 AI TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '12GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1x 12GB, nâng cấp tối đa 32GB DDR5-4800)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB DDR5-4800'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x M.2 SSD, M.2 2242 SSD tối đa 1TB mỗi ổ)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Màn hình chống chói, Độ phủ màu 100% sRGB, G-SYNC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 3x (5Gbps / USB 3.2 Gen 1), USB-C: 1x (10Gbps / USB 3.2 Gen 2, hỗ trợ Lenovo PD 140W và DisplayPort 1.4), HDMI: 1x (2.1, lên đến 8K/60Hz), LAN: 1x (RJ-45), SD: N/A, 3.5mm: 1x (kết hợp tai nghe / micrô), Nguồn: 1x đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua DisplayPort 1.4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.86 x 258.7 x 21.9-23.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.38 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh (Đầu mỏng 170W (3 chân))'}, {'name': 'Sạc nhanh', 'value': '170W'}, {'name': 'Loại sạc', 'value': 'Lenovo PD 140W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 2W x2, Nahimic Audio'}, {'name': 'Webcam', 'value': 'HD 720p với E-shutter'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 250 (8 lõi / 16 luồng, 3.3 / 5.1GHz, 8MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 250, 8 lõi / 16 luồng, xung nhịp 3.3 / 5.1GHz, Cache 8MB L2 / 16MB L3'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'Rời, VRAM 8GB GDDR7, Boost Clock 2662MHz, TGP 100W, 440 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Integrated AMD Ryzen AI, up to 16 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SO-DIMM DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x M.2 SSD, up to 1TB mỗi ổ)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 100% sRGB, G-SYNC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 3 cổng (5Gbps / USB 3.2 Gen 1); USB-C: 1 cổng (10Gbps / USB 3.2 Gen 2, hỗ trợ USB PD 65-100W và DisplayPort 1.4); HDMI: 1 cổng (2.1, lên đến 8K/60Hz); 3.5mm: 1 cổng (kết hợp tai nghe/micrô); LAN: 1 cổng (RJ-45); SD: N/A'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua DisplayPort 1.4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.86 x 258.7 x 21.9-23.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh, 170W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '170W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': '3-pin'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 2W x2, Nahimic Audio'}, {'name': 'Webcam', 'value': '5.0MP với E-shutter'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': '24-Zone RGB Backlit, English'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English + Office Trial + Lenovo AI Now'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Lenovo AI Now'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core 2.1 / 4.6GHz, E-core 1.5 / 3.4GHz, 12MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core 2.1 / 4.6GHz, E-core 1.5 / 3.4GHz, 12MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Tối đa 16GB (8GB Onboard + 8GB SO-DIMM)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB thông qua khe SO-DIMM'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Lên đến hai ổ đĩa, nâng cấp tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB 3.2 Gen 1: 1, USB-C: 1 (hỗ trợ truyền dữ liệu, Power Delivery 3.0 và DisplayPort 1.2), HDMI: 1, LAN: 1 (RJ-45), SD: Không, 3.5mm: 1 (kết hợp tai nghe/micrô), Đầu nối nguồn: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.2 (qua USB-C)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '324.2 x 215.2 x 19.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.43 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '38Wh'}, {'name': 'Sạc nhanh', 'value': '65W USB-C (3-pin)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 1.5W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với Màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền, tiếng Anh'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Free OS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13450HX, 10 lõi (6P + 4E) / 16 luồng, P-core 2.4 / 4.6GHz, E-core 1.8 / 3.4GHz, 20MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13450HX, 10 lõi (6P + 4E) / 16 luồng, P-core 2.4 / 4.6GHz, E-core 1.8 / 3.4GHz, 20MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 1500MHz, TGP 65W, 440 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': '440 AI TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SO-DIMM DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, Up to 16GB DDR5-4800 offering)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB DDR5-4800'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x SSD M.2 • SSD M.2 dung lượng tối đa 1TB mỗi ổ)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 100% sRGB, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2, USB-C: 1, Thunderbolt: N/A, HDMI: 1, LAN: 1, SD: N/A, 3.5mm: 1 (Jack combo tai nghe / micro)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '361.26 x 255.6 x 22.9-24.8 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.3 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh, 135W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '135W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': '3-pin'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 2W x2, Nahimic Audio'}, {'name': 'Webcam', 'value': 'HD 720p với E-shutter'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-14700HX, 20 lõi (8P + 12E) / 28 luồng, P-core 2.1 / 5.5GHz, E-core 1.5 / 3.9GHz, 33MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-14700HX, 20 lõi (8P + 12E) / 28 luồng, P-core 2.1 / 5.5GHz, E-core 1.5 / 3.9GHz, 33MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 2662MHz, TGP 115W, 440 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': '440 AI TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SO-DIMM DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1x 16GB, nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x M.2 SSD • M.2 2242 SSD tối đa 1TB mỗi ổ)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.1 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 500nits, Độ phủ màu 100% DCI-P3, Dolby Vision, DisplayHDR True Black 600'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x (5Gbps), USB-C: 2x (10Gbps, hỗ trợ USB PD 65-100W và DP 2.1), HDMI: 1x (2.1, lên đến 8K/60Hz), 3.5mm: 1x (kết hợp tai nghe/micrô), Ethernet (RJ-45): 1x, Đầu nối nguồn: 1x'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7, 802.11be 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua cổng USB-C hỗ trợ DP 2.1)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'PC-ABS + 15% Talc'}, {'name': 'Kích thước', 'value': '344.9 x 255.35 x 19.95-21.54 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.9 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '80Wh, 245W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '245W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Slim Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 2W x2, âm thanh của HARMAN, Nahimic Audio'}, {'name': 'Webcam', 'value': '5.0MP với màn trập điện tử'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': '24-Zone RGB'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English + Office Home 2024 + Lenovo AI Now'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Lenovo AI Now'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7235HS (4 lõi / 8 luồng, 3.2 / 4.2GHz, 2MB L2 / 8MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 7235HS, 4 lõi / 8 luồng, xung nhịp 3.2 / 4.2GHz, Cache 2MB L2 / 8MB L3'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 1732MHz, TGP 95W'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'SO-DIMM DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2x 12GB, nâng cấp tối đa 32GB DDR5-4800)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB DDR5-4800'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x M.2 SSD • M.2 2242 SSD tối đa 1TB mỗi ổ)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 100% sRGB, G-SYNC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 3 cổng (USB 5Gbps / USB 3.2 Gen 1); USB-C: 1 cổng (USB 10Gbps / USB 3.2 Gen 2, hỗ trợ Lenovo PD 140W và DisplayPort 1.4); HDMI: 1 cổng (HDMI 2.1, lên đến 8K/60Hz); 3.5mm: 1 cổng (giắc cắm kết hợp tai nghe / micrô); LAN: 1 cổng (Ethernet RJ-45); SD: N/A'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua DisplayPort 1.4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.86 x 258.7 x 21.9-23.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.38 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh (Đầu mỏng 170W (3 chân))'}, {'name': 'Sạc nhanh', 'value': 'Lenovo PD 140W'}, {'name': 'Loại sạc', 'value': 'Sạc Lenovo PD 140W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 2W x2, Nahimic Audio'}, {'name': 'Webcam', 'value': 'HD 720p với màn trập E-shutter'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7-5800H'}, {'name': 'Mô tả CPU', 'value': 'Ryzen 7 series processor'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3060'}, {'name': 'Mô tả card đồ họa', 'value': '6GB GDDR6'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200Mhz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe cắm tối đa 32GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2280 PCIe 3.0x4 NVMe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Tần số quét 165Hz, màn hình chống loá, 100% sRGB, Dolby Vision, Free-Sync, G-Sync, DC dimmer'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '3x USB 3.2 Gen 1, 1x USB-C 3.2 Gen 2, 1x USB 3.2 Gen 1, 1x USB-C 3.2 Gen 2, 1x HDMI 2.1, 1x Ethernet (RJ-45), 1x headphone / microphone combo jack'}, {'name': 'Wi-Fi', 'value': '802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'v5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '362.56 x 260.61 x 22.5-25.75 mm'}, {'name': 'Trọng lượng', 'value': '2.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell 80 WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': '2 loa'}, {'name': 'Webcam', 'value': 'HD 720p'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12T, P-core 2.1 / 4.6GHz, E-core 1.5 / 3.4GHz, 12MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12T, P-core 2.1 / 4.6GHz, E-core 1.5 / 3.4GHz, 12MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2x 8GB, nâng cấp tối đa 64GB DDR5-5200)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB DDR5-5200'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2280 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, lên đến 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 1x (truyền dữ liệu, PD 3.0, DP 1.4), Thunderbolt: 1x / USB4 40Gbps (truyền dữ liệu, PD 3.0, DP 1.4), HDMI: 1x (4K/60Hz), LAN: 1x (RJ-45), SD: 1x đầu đọc thẻ SD, 3.5mm: 1x (kết hợp tai nghe/micrô)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '356 x 253.5 x 17.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.7 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '71Wh (65W USB-C Slim (Gắn tường))'}, {'name': 'Sạc nhanh', 'value': '65W USB-C Slim (Gắn tường)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'FHD 1080p với Màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Backlit'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled, Bảo mật vân tay'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-10750H 2.6GHz up to 5.0GHz 12MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-10750H, 2.6GHz, lên đến 5.0GHz, Cache 12MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce GTX 1650Ti 4GB GDDR6 + Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card rời NVIDIA GeForce GTX 1650Ti với 4GB GDDR6 và tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': 'N/A'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2280 PCIe NVMe (Còn trống 1 khe SSD M.2 PCIE)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'WVA'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'FHD (1920 x 1080) WVA Anti-Glare, Dolby Vision'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '4x USB 3.2 Gen 1 (one Always On), 1x USB 3.2 Type-C Gen 1 (with the function of DisplayPort 1.2), 1xHDMI 2.0, 1x Ethernet (RJ-45)'}, {'name': 'Wi-Fi', 'value': '802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'v5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '363.06 x 259.61 x 23.57 (mm)'}, {'name': 'Trọng lượng', 'value': '2.3 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell 80 WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'N/A'}, {'name': 'Webcam', 'value': 'N/A'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 10 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'In Laser đen trắng'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 9 275HX, 24 lõi (8P + 16E) / 24 luồng, Max Turbo up to 5.4GHz, 36MB'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost, up to 13 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 2497MHz, TGP 115W, 572 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost, up to 13 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 16GB, tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x SSD M.2, mỗi ổ có dung lượng tối đa 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '240 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500nits (Điển hình) / 1100nits (Cao)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'DisplayHDR True Black 1000, Dolby Vision, G-SYNC, Ánh sáng xanh thấp, Hiệu suất chơi game cao, Không nhấp nháy'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (5Gbps), 1x USB-C (10Gbps, USB PD 65-100W và DP 2.1), 1x USB-C (Thunderbolt 4 / 40Gbps, USB PD 65-100W và DP 2.1), 1x HDMI 2.1 (lên đến 8K/60Hz), 1x Giắc cắm kết hợp tai nghe/micrô (3.5mm), 1x Đầu đọc thẻ, 1x Đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7, 802.11be 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua cổng USB-C/Thunderbolt hỗ trợ DP 2.1)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '361.7 x 263.4 x 15.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.0 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '84Wh, 245W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '245W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Slim Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), codec Realtek ALC3306, Loa stereo, 2W x2, Âm thanh của HARMAN, Nahimic Audio, Bộ khuếch đại thông minh (AMP)'}, {'name': 'Webcam', 'value': '5.0MP + IR với E-shutter'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Per-key RGB Backlit, English'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English + Office Home 2024 + Lenovo AI Now'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Lenovo AI Now'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7535HS (6 lõi / 12 luồng, 3.3 / 4.55GHz, 3MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': '6 lõi / 12 luồng, xung nhịp 3.3 / 4.55GHz, Cache L2 3MB / L3 16MB'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 660M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SODIMM DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 khe, tối đa 16GB DDR5-4800 offering'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB DDR5-4800 (tùy thuộc vào khả năng của máy)'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Hỗ trợ tối đa hai ổ đĩa, 2 ổ SSD M.2, SSD M.2 2242 dung lượng lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x USB-A (USB 3.2 Gen 1, 5Gbps), 1 x USB-C (USB 3.2 Gen 1, 5Gbps, PD 45–65W, DisplayPort 1.2), 1 x HDMI 1.4, 1 x Jack tai nghe/mic 3.5 mm, 1 x Khe thẻ SD, 1 x Cổng nguồn tròn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '360 x 251 x 16.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.68 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50Wh, 65W Round Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '65W'}, {'name': 'Loại sạc', 'value': 'Round Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh HD, Loa stereo 2W x2, Tối ưu với Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-12450HX, 8C (4P + 4E) / 12T, P-core up to 4.4GHz, E-core up to 3.1GHz, 12MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-12450HX'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 1432MHz, TGP 65W, 142 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': '142 AI TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SO-DIMM DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 khe (1x 16GB, nâng cấp tối đa 32GB DDR5-4800)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB DDR5-4800'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x M.2 SSD • M.2 2242 SSD tối đa 1TB mỗi ổ)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (5Gbps / USB 3.2 Gen 1), 1x USB-C (5Gbps / USB 3.2 Gen 1, chỉ truyền dữ liệu), 1x HDMI 2.1 (lên đến 8K/60Hz), 1x giắc cắm kết hợp tai nghe / micrô (3.5mm), 1x Ethernet (RJ-45), 1x Đầu đọc thẻ, 1x Đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.3 x 236 x 19.9-22.95 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.77 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '57Wh'}, {'name': 'Sạc nhanh', 'value': '135W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': '135W Slim Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 2W x2, Nahimic Audio'}, {'name': 'Webcam', 'value': 'HD 720p với Màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền màu trắng, Bàn di chuột đa điểm bề mặt Mylar không nút, hỗ trợ Precision TouchPad (PTP)'}, {'name': 'Touchpad', 'value': 'Precision TouchPad (PTP)'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-12450HX (8 lõi (4P + 4E) / 12 luồng, P-core up to 4.4GHz, E-core up to 3.1GHz, 12MB)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-12450HX, 8 lõi (4P + 4E) / 12 luồng, P-core up to 4.4GHz, E-core up to 3.1GHz, 12MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 1732MHz, TGP 95W'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '12GB'}, {'name': 'Loại RAM', 'value': '1 x 12GB SO-DIMM DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe DDR5 SO-DIMM (Nâng cấp tối đa 32 GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32 GB'}, {'name': 'Ổ cứng', 'value': '512 GB SSD M.2 2242 PCIe 4.0x4 NVMe (1 khe SSD M.2 trống nâng cấp tối đa đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits, màn hình chống chói, Độ phủ màu 100% sRGB, G-SYNC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '3x USB-A (USB 5Gbps / USB 3.2 Gen 1), 1x USB-C (USB 10Gbps / USB 3.2 Gen 2, hỗ trợ PD 140W và DisplayPort 1.4), 1x HDMI 2.1 (up to 8K/60Hz), 1x Headphone / microphone combo jack (3.5mm), 1x Ethernet (RJ-45), 1x Đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '359.86 x 258.7 x 21.9-23.9 mm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '2.38 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ phân giải cao (HD), codec Realtek ALC3287, Loa âm thanh nổi, 2W x2, Nahimic Audio'}, {'name': 'Webcam', 'value': 'FHD 1080p với màn trập E-shutter'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-14700HX, 20 lõi (8P + 12E) / 28 luồng, P-core 2.1 / 5.5GHz, E-core 1.5 / 3.9GHz, 33MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-14700HX, 20 lõi (8P + 12E) / 28 luồng, P-core 2.1 / 5.5GHz, E-core 1.5 / 3.9GHz, 33MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5070 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 2347MHz, TGP 115W, 798 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': '798 AI TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2x 12GB, nâng cấp tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '1TB SSD M.2 2242 PCIe 4.0x4 NVMe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.1 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Dolby Vision, DisplayHDR True Black 600'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 3 cổng (2x 5Gbps, 1x Luôn bật); USB-C: 2 cổng (1x USB PD 65-100W và DP 2.1, 1x DisplayPort 1.4); HDMI: 1 cổng (2.1, lên đến 8K/60Hz); 3.5mm: 1 cổng; LAN: 1 cổng (RJ-45)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7, 802.11be 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua USB-C với DP 2.1)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'PC-ABS + 15% Talc'}, {'name': 'Kích thước', 'value': '344.9 x 255.35 x 19.95-21.54 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.9 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '80Wh, 245W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '245W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Slim Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 2W x2, âm thanh của HARMAN, Nahimic Audio'}, {'name': 'Webcam', 'value': '5.0MP với màn trập điện tử'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': '24-Zone RGB'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English + Office Home 2024 + Lenovo AI Now'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Lenovo AI Now'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core 2.1 / 4.6GHz, E-core 1.5 / 3.4GHz, 12MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core 2.1 / 4.6GHz, E-core 1.5 / 3.4GHz, 12MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB Onboard + 8GB DDR5-4800, nâng cấp tối đa 24GB (8GB Onboard + 16GB SO-DIMM))'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, nâng cấp lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (USB 5Gbps / USB 3.2 Gen 1), 1x USB-C (USB 5Gbps / USB 3.2 Gen 1, với USB PD 3.0 và DisplayPort 1.2), 1x HDMI 1.4, 1x giắc cắm kết hợp tai nghe / micrô (3,5 mm), 1x đầu đọc thẻ SD, 1x đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.2 (qua USB-C)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314.4 x 222.1 x 16.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.43 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh (Đầu tròn 65W (3 chân))'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'High Definition (HD) Audio, Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 5625U (6 lõi / 12 luồng, 2.3 / 4.3GHz, 3MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': '6 lõi / 12 luồng, xung nhịp 2.3 / 4.3GHz, Cache 3MB L2 / 16MB L3'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard (Không nâng cấp)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Một ổ đĩa, tối đa 1TB M.2 2242 SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB 3.2 Gen 1, 1x USB-C 3.2 Gen 1 (hỗ trợ truyền dữ liệu, Power Delivery và DisplayPort 1.2), 1x HDMI 1.4, 1x giắc cắm kết hợp tai nghe/micrô (3.5mm), 1x đầu đọc thẻ, 1x đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.2 qua USB-C'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.3 x 235 x 17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.62 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '47Wh (Đầu tròn 65W (3 chân))'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'Đầu tròn 65W (3 chân)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'High Definition (HD) Audio, Loa âm thanh nổi hướng về phía người dùng, 1,5W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled, Bảo mật vân tay'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core 2.1 / 4.6GHz, E-core 1.5 / 3.4GHz, 12MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core 2.1 / 4.6GHz, E-core 1.5 / 3.4GHz, 12MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB Soldered DDR5-4800 + 8GB SO-DIMM DDR5-4800, tối đa 24GB (8GB Onboard + 16GB SO-DIMM))'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB (thông qua khe SO-DIMM)'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x M.2 SSD • M.2 2242 SSD lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.1 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 (WQXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 500nits, Độ phủ màu 100% DCI-P3, DisplayHDR True Black 600'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x (USB 5Gbps / USB 3.2 Gen 1), USB-C: 1x (USB 5Gbps / USB 3.2 Gen 1, hỗ trợ USB PD 3.0 và DisplayPort 1.2), HDMI: 1x (HDMI 1.4), LAN: N/A, SD: 1x (đầu đọc thẻ SD), 3.5mm: 1x (giắc cắm kết hợp tai nghe / micrô)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua cổng USB-C với DisplayPort 1.2)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '343.4 x 239.5 x 16.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.49 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh, 65W Round Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '65W Round Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Round Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa stereo, 2W x2, Dolby Audio, Âm thanh độ nét cao (HD)'}, {'name': 'Webcam', 'value': 'FHD 1080p + IR với Màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Backlit, English'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled, Màn trập riêng tư của camera, Camera hồng ngoại cho Windows Hello (nhận dạng khuôn mặt)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7235HS (4 lõi / 8 luồng, 3.2 / 4.2GHz, 2MB L2 / 8MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 7235HS, 4 lõi / 8 luồng, xung nhịp 3.2 / 4.2GHz, Cache 2MB L2 / 8MB L3'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 1732MHz, TGP 95W'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, nâng cấp tối đa 32GB DDR5-4800)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB DDR5-4800'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe, Hỗ trợ tối đa 2 ổ M.2 SSD (M.2 2242, tối đa 1TB mỗi ổ)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 100% sRGB, G-SYNC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 3 cổng, USB-C: 1 cổng (hỗ trợ Lenovo PD 140W và DisplayPort 1.4), HDMI: 1 cổng (hỗ trợ 8K/60Hz), LAN: 1 cổng (RJ-45), SD: Không, 3.5mm: 1 cổng (kết hợp tai nghe/micrô), Đầu nối nguồn: 1 cổng'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.86 x 258.7 x 21.9–23.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.38 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh, 170W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '170W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Slim Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 2W x2, Nahimic Audio'}, {'name': 'Webcam', 'value': 'HD 720p với E-shutter'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H, 10 lõi (6P + 4E) / 16 luồng, P-core 2.4 / 4.9GHz, E-core 1.8 / 3.6GHz, 24MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 10 lõi (6P + 4E) / 16 luồng, P-core 2.4 / 4.9GHz, E-core 1.8 / 3.6GHz, 24MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '8GB Onboard + 8GB SO-DIMM DDR5-4800 (Nâng cấp tối đa 24GB (8GB Onboard + 16GB SO-DIMM) DDR5-4800)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB (sử dụng 8GB Onboard + 16GB SO-DIMM)'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x M.2 SSD, M.2 2242 SSD lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (5Gbps / USB 3.2 Gen 1), 1x USB-C ( 5Gbps / USB 3.2 Gen 1, với USB PD 3.0 và DisplayPort 1.2), 1x HDMI 1.4, 1x giắc cắm kết hợp tai nghe / micrô (3.5 mm), 1x đầu đọc thẻ SD, 1x đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.2 (qua USB-C)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Nhôm, Nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '343.4 x 239.5 x 16.9-17.9 mm (Dài x Rộng Dày)'}, {'name': 'Trọng lượng', 'value': '1.63 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh (Đầu tròn 65W (3 chân))'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'Đầu tròn 65W (3 chân)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 255H, 16 lõi (6P + 8E + 2LPE) / 16 luồng, Max Turbo up to 5.1GHz, 24MB'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost, up to 13 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc 140T hoạt động như Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc 140T'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost, up to 13 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe Opal 2.0'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 (1x 5Gbps, 1x 10Gbps, Luôn bật); USB-C: 2 (1x 20Gbps với USB PD 3.1 và DP 1.4; 1x Thunderbolt 4 / USB4 40Gbps với PD 3.1 và DP 2.1); HDMI: 1 (2.1, lên đến 4K/60Hz); 3.5mm: 1; RJ-45: 1'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua cổng USB-C/Thunderbolt 4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '313 x 220.3 x 10.1 - 15.25 (trước/sau), 19.7 (tối đa) mm'}, {'name': 'Trọng lượng', 'value': '1.34 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '48Wh'}, {'name': 'Sạc nhanh', 'value': '65W USB-C (3-pin)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Senary SN6147, Loa stereo, 2W x2, Dolby Atmos, Âm thanh của HARMAN'}, {'name': 'Webcam', 'value': 'FHD 1080p + IR Hybrid với Màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Discrete TPM 2.0 Enabled, Camera IR cho Windows Hello (nhận dạng khuôn mặt)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English (US) / English (UK)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7235HS (4 lõi / 8 luồng, 3.2 / 4.2GHz, 2MB L2 / 8MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 7235HS, 4 lõi / 8 luồng, xung nhịp 3.2 / 4.2GHz, Cache 2MB L2 / 8MB L3'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'Boost Clock 1732MHz, TGP 95W'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, nâng cấp tối đa 32GB DDR5-4800)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB DDR5-4800'}, {'name': 'Ổ cứng', 'value': '1TB SSD M.2 2242 PCIe 4.0x4 NVMe (Hỗ trợ tối đa 2 ổ M.2 SSD, mỗi ổ M.2 2242 dung lượng đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 100% sRGB, G-SYNC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 3 cổng (5Gbps / USB 3.2 Gen 1), USB-C: 1 cổng (10Gbps / USB 3.2 Gen 2, hỗ trợ Lenovo PD 140W và DisplayPort 1.4), HDMI: 1 cổng (2.1, lên đến 8K/60Hz), LAN: 1 cổng (RJ-45), SD: Không, 3.5mm: 1 cổng (kết hợp tai nghe/micrô), Đầu nối nguồn: 1 cổng'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua DisplayPort 1.4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.86 x 258.7 x 21.9–23.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.38 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh, 170W Slim Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '170W Slim Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Slim Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'High Definition (HD) Audio, Realtek ALC3287 codec, Stereo speakers, 2W x2, tối ưu bởi Nahimic Audio'}, {'name': 'Webcam', 'value': 'HD 720p với E-shutter'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-1355U, 10 lõi (2P + 8E) / 12 luồng, P-core 1.7 / 5.0GHz, E-core 1.2 / 3.7GHz, 12MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-1355U, 10 lõi (2P + 8E) / 12 luồng, P-core 1.7 / 5.0GHz, E-core 1.2 / 3.7GHz, 12MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB Soldered DDR4-3200 + 8GB SO-DIMM DDR4-3200, tối đa 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB (hiện tại đang ở mức 16GB)'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (tối đa hai ổ đĩa, 1x 2,5" HDD + 1x M.2 SSD, 2,5" HDD lên đến 1TB, M.2 2242 SSD up to 512GB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 1 (USB 3.2 Gen 1, hỗ trợ truyền dữ liệu, Power Delivery (chỉ 20V) và DisplayPort 1.2), Thunderbolt: N/A, HDMI: 1 (1.4b), LAN: 1 (RJ-45), SD: N/A, 3.5mm: 1 (giắc cắm kết hợp tai nghe/micrô)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 5, 802.11ac 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '324.2 x 215.2 x 19.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.43 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '38Wh (Đầu tròn 65W (3 chân))'}, {'name': 'Sạc nhanh', 'value': '65W (sạc nhanh)'}, {'name': 'Loại sạc', 'value': 'Đầu tròn 65W (3 chân)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 1,5W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với màn trập'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 210H, 8 lõi (4P + 4E) / 12 luồng, P-core 2.2 / 4.8GHz, E-core 1.6 / 3.6GHz, 12MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core 5 210H, 8 lõi (4P + 4E) / 12 luồng, P-core 2.2 / 4.8GHz, E-core 1.6 / 3.6GHz, 12MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'SO-DIMM DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2x 8GB, tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400nits, Độ phủ màu 100% DCI-P3, DisplayHDR True Black 500'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 (5Gbps / USB 3.2 Gen 1), USB-C: 2 (5Gbps / USB 3.2 Gen 1, hỗ trợ USB PD 3.0 và DisplayPort 1.4), HDMI: 1 (1.4b), 3.5mm: 1 (kết hợp tai nghe/micrô), LAN: N/A, SD: 1 (microSD)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7, 802.11be 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua USB-C với DisplayPort 1.4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '313.4 x 222 x 16.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh'}, {'name': 'Sạc nhanh', 'value': '65W USB-C Slim (Wall-mount)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'FHD 1080p + IR với Màn trập camera, Cảm biến ToF'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Backlit'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Nhận diện khuôn mặt, Màn hình Oled, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7730U (8 lõi / 16 luồng, 2.0 / 4.5GHz, 4MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 7730U, 8 lõi / 16 luồng, xung nhịp 2.0 / 4.5GHz, Cache 4MB L2 / 16MB L3'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-8448'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': 'Ổ cứng SSD 512GB M.2 2242 PCIe 4.0x4 NVMe (Một ổ đĩa, tối đa 1TB M.2 2242 SSD, Một khe cắm M.2 2242 PCIe 3.0 x4)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, TÜV Low Blue Light'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (USB 5Gbps), 1x USB-C (USB 10Gbps, hỗ trợ USB PD 3.0 và DisplayPort 1.4), 1x HDMI 1.4b, 1x giắc cắm kết hợp tai nghe / micrô (3.5 mm), 1x đầu đọc thẻ SD, 1x đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '313.1 x 224.9 x 17.8 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.55 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '52.5Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'N/A'}, {'name': 'Webcam', 'value': 'FHD 1080p với Màn trập riêng tư'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Backlit, English'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bảo mật vân tay'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Xoay gập 360 độ (2 in 1)'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 155H, 16 lõi (6P + 8E + 2LPE) / 22 luồng, Max Turbo up to 4.8GHz, 24MB'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost, up to 11 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost, up to 11 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5-6400'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '1TB SSD M.2 2242 PCIe 4.0x4 NVMe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400nits\nĐộ phủ màu 100% DCI-P3\nEyesafe\nDolby Vision\nDisplayHDR True Black 500'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB-A (USB 5Gbps / USB 3.2 Gen 1, Luôn bật), 2x USB-C (Thunderbolt 4 / USB 4 40Gbps, với USB PD 3.1 và DisplayPort 1.4), 1x HDMI 2.1 (lên đến 4K/60Hz), 1x Giắc cắm kết hợp tai nghe/micrô (3.5mm)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua Thunderbolt 4/DisplayPort)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '312 x 221 x 14.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '65Wh, 65W USB-C Slim (Wall-mount)'}, {'name': 'Sạc nhanh', 'value': '65W USB-C Slim (Wall-mount)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD)\nBộ giải mã Realtek ALC3306\nLoa stereo, 2W x4\nDolby Atmos\nBộ khuếch đại (AMP)'}, {'name': 'Webcam', 'value': 'FHD 1080p + IR với màn trập điện tử, cảm biến ToF'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Backlit, English'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English + Microsoft 365 Basic + Office Home 2024'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft 365 Basic + Office Home 2024'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Snapdragon X X1-26-100, 8 lõi, Max Turbo up to 3.0GHz, 30MB'}, {'name': 'Mô tả CPU', 'value': '8 lõi, Max Turbo up to 3.0GHz, 30MB'}, {'name': 'Tên card đồ họa', 'value': 'Qualcomm Adreno'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Qualcomm Adreno'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Qualcomm Hexagon NPU, up to 45 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-8448'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Một ổ đĩa, tối đa 1TB M.2 2242 SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400nits, Độ phủ màu 100% DCI-P3'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 (5Gbps / USB 3.2 Gen 1), USB-C: 2 (10Gbps / USB 3.2 Gen 2, hỗ trợ USB PD 3.0 và DP 1.4), HDMI: 1 (2.1, lên đến 4K/60Hz), 3.5mm: 1 (kết hợp tai nghe/micrô), Khác: Khe đọc thẻ nhớ, Đầu đọc thẻ microSD'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7, 802.11be 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua cổng USB-C hỗ trợ DP 1.4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '312 x 221 x 16.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.48 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '57Wh'}, {'name': 'Sạc nhanh', 'value': '65W USB-C Slim (Wall-mount)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'FHD 1080p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Backlit, English'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Microsoft Pluton TPM 2.0 Enabled, Bảo mật vân tay'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language (on ARM), English / Office Trial'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12T, P-core 2.1 / 4.6GHz, E-core 1.5 / 3.4GHz, 12MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12T, P-core 2.1 / 4.6GHz, E-core 1.5 / 3.4GHz, 12MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2x 8GB, nâng cấp tối đa 64GB DDR5-5200)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB DDR5-5200'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, lên đến 2TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x, USB-C: 1x (truyền dữ liệu, PD 3.0, DP 1.4), Thunderbolt: 1x / USB4 40Gbps: 1x, HDMI: 1x (4K/60Hz), LAN: 1x (RJ-45), SD: 1x đầu đọc thẻ SD, 3.5mm: 1x (kết hợp tai nghe/micrô)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '356 x 253.5 x 17.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.7 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '71Wh (65W USB-C Slim (Gắn tường))'}, {'name': 'Sạc nhanh', 'value': '65W USB-C Slim (Gắn tường)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với Màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Backlit'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 255H, 16 lõi (6P + 8E + 2LPE) / 16 luồng, Max Turbo up to 5.1GHz, 24MB'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost, up to 13 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc 140T'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc 140T'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost, up to 13 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'SO-DIMM DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe Opal 2.0, tối đa 1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB-A (5Gbps / USB 3.2 Gen 1), 1x USB-A (10Gbps / USB 3.2 Gen 2, Luôn bật), 1x USB-C (Thunderbolt 4 / USB 4 40Gbps, với USB PD 3.1 và DisplayPort 2.1), 1x HDMI 2.1 (lên đến 4K/60Hz), 1x Giắc cắm kết hợp tai nghe/micrô (3.5mm), 1x RJ-45'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua cổng USB-C Thunderbolt 4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '313 x 220.3 x 10.1/15.25 (trước/sau), 19.7 (tối đa) mm'}, {'name': 'Trọng lượng', 'value': '1.34 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '48Wh, 65W USB-C (3-pin)'}, {'name': 'Sạc nhanh', 'value': '65W USB-C'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Senary SN6147, Loa stereo, 2W x2, Dolby Atmos, Âm thanh của HARMAN'}, {'name': 'Webcam', 'value': 'FHD 1080p + IR Hybrid với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Backlit, English'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Discrete TPM 2.0 Enabled, Bảo mật vân tay, Nhận diện khuôn mặt'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English (US) / English (UK)'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core 2.1 / 4.6GHz, E-core 1.5 / 3.4GHz, 12MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core 2.1 / 4.6GHz, E-core 1.5 / 3.4GHz, 12MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 8GB Onboard + 1 x 16GB, tối đa 24GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên đến 24GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, nâng cấp lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (5Gbps / USB 3.2 Gen 1), 1x USB-C (5Gbps / USB 3.2 Gen 1, với USB PD 3.0 và DisplayPort 1.2), 1x HDMI 1.4, 1x giắc cắm kết hợp tai nghe / micrô (3.5 mm), 1x đầu đọc thẻ SD, 1x đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.2 (qua USB-C)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '343.4 x 239.5 x 16.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.63 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh (Đầu tròn 65W (3 chân))'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'Đầu tròn 65W (3 chân)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'High Definition (HD) Audio, Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 5625U (6 lõi / 12 luồng, 2.3 / 4.3GHz, 3MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': '6 lõi / 12 luồng, xung nhịp 2.3 / 4.3GHz, Cache 3MB L2 / 16MB L3'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR4x-4266 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Một ổ đĩa, tối đa 1TB M.2 2242 SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Độ phủ màu 45% NTSC, TÜV Low Blue Light'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 (5Gbps / 3.2 Gen 1, 1x Luôn bật); USB-C: 1 (10Gbps / 3.2 Gen 2, hỗ trợ USB PD 3.0 và DisplayPort 1.4); HDMI: 1 (1.4b); 3.5mm: 1 (kết hợp tai nghe / micrô); SD: 1 (đầu đọc thẻ SD); Nguồn: 1 (đầu nối nguồn)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa + 40% GF'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa + 40% GF'}, {'name': 'Kích thước', 'value': '313.1 x 224.9 x 17.8 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.55 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '52.5Wh (65W Round Tip (3-pin))'}, {'name': 'Sạc nhanh', 'value': '65W Round Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Round Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa âm thanh nổi hướng về phía trước, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'FHD 1080p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền, tiếng Anh'}, {'name': 'Touchpad', 'value': 'Màn hình cảm ứng'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0, Bảo mật vân tay'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 226V, 8 lõi (4P + 4LPE) / 8 luồng, Max Turbo up to 4.5GHz, 8MB'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost, up to 40 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics 130V'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost, up to 40 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-8533 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Một ổ đĩa, tối đa 1TB M.2 2242 SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '1100nits (peak) / 500nits (typical)'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Eyesafe, Dolby Vision, DisplayHDR True Black 1000, X-Rite PureSight Pro'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB-A (USB 5Gbps / USB 3.2 Gen 1, Luôn bật), 2x USB-C (Thunderbolt 4 / USB4 40Gbps, với USB PD 3.0 và DisplayPort 2.1), 1x HDMI 2.1 (lên đến 4K/60Hz), 1x giắc cắm kết hợp tai nghe / micrô (3.5 mm), 1x đầu đọc thẻ nhớ microSD'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7, 802.11be 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua cổng USB-C/Thunderbolt 4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '312 x 219.3 x 13.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.19 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70Wh, 65W USB-C Slim (2-pin, Wall-mount)'}, {'name': 'Sạc nhanh', 'value': '65W USB-C'}, {'name': 'Loại sạc', 'value': 'USB-C Slim'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), SoundWire, codec Cirrus Logic CS42L43, 4 loa âm thanh nổi, 2W x2 (loa trầm), 2W x2 (loa tweeter), Dolby Atmos, Bộ khuếch đại thông minh (AMP)'}, {'name': 'Webcam', 'value': '5.0MP + IR với màn trập điện tử'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Backlit, English'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0, Phát hiện sự hiện diện của con người bằng sóng siêu âm, E-shutter, Camera hồng ngoại cho Windows Hello (nhận dạng khuôn mặt)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English + Microsoft 365 Basic + Office Home 2024'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft 365 Basic + Office Home 2024'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Nhận diện khuôn mặt, Màn hình Oled, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 5 340 (6 lõi / 12 luồng, 2.0 / 4.8GHz, 6MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen AI, up to 50 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 840M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD Ryzen AI, up to 50 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 12GB SO-DIMM DDR5-4800, tối đa 24GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x M.2 SSD • M.2 2242 SSD lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'DisplayHDR True Black 500, Glossy'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 (5Gbps / 3.2 Gen 1), USB-C: 2 (10Gbps / 3.2 Gen 2, hỗ trợ USB PD 3.0 và DisplayPort 1.4), HDMI: 1 (2.1, lên đến 4K/60Hz), 3.5mm: 1 (kết hợp tai nghe/micrô), Khe đọc thẻ nhớ: 1 (microSD)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7, 802.11be 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua DisplayPort 1.4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '313.4 x 222 x 16.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh (65W USB-C Slim (Wall-mount))'}, {'name': 'Sạc nhanh', 'value': '65W USB-C Slim (Wall-mount)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'FHD 1080p + IR với Màn camera, Cảm biến ToF'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền, tiếng Anh'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Microsoft Pluton TPM 2.0 Enabled, Camera IR cho Windows Hello (nhận dạng khuôn mặt)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Nhận diện khuôn mặt, Màn hình Oled, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7 7735HS (8 lõi / 16 luồng, 3.2 / 4.75GHz, 4MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7 7735HS, 8 lõi / 16 luồng, xung nhịp 3.2 / 4.75GHz, Cache 4MB L2 / 16MB L3'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 680M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon 680M Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB Onboard + 16GB SODIMM, tối đa 24GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB qua 2 khe cắm'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, up to 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x USB-A (USB 5Gbps / USB 3.2 Gen 1), 1x USB-C (USB 5Gbps / USB 3.2 Gen 1, hỗ trợ PD 3.0 & DisplayPort 1.2), 1x HDMI 1.4, 1x jack tai nghe/mic 3.5mm, 1x khe đọc thẻ SD, 1x cổng nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ qua cổng USB-C (DisplayPort 1.2)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '343.4 x 239.5 x 16.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.59 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '50Wh'}, {'name': 'Sạc nhanh', 'value': '65W Round Tip (3-pin)'}, {'name': 'Loại sạc', 'value': '65W Round Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với Màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Microsoft Pluton TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H, 10 lõi (6P + 4E) / 16 luồng, P-core 2.4 / 4.9GHz, E-core 1.8 / 3.6GHz, 24MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 10 lõi (6P + 4E) / 16 luồng, P-core 2.4 / 4.9GHz, E-core 1.8 / 3.6GHz, 24MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '8GB Soldered DDR5-4800 + 8GB SO-DIMM DDR5-4800 (Tối đa 24GB (8GB Onboard + 16GB SO-DIMM) DDR5-4800)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB (thông qua khe SO-DIMM)'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x M.2 SSD • M.2 2242 SSD lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2x (5Gbps / USB 3.2 Gen 1), USB-C: 1x (5Gbps / USB 3.2 Gen 1, hỗ trợ USB PD 3.0 và DisplayPort 1.2), HDMI: 1x (1.4), LAN: N/A, SD: 1x (đầu đọc thẻ SD), 3.5mm: 1x (giắc cắm kết hợp tai nghe / micrô), Khác: 1x đầu nối nguồn'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.2 (qua USB-C)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Nhôm, Nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314.4 x 222.1 x 16.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.43 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh (Đầu tròn 65W (3 chân))'}, {'name': 'Sạc nhanh', 'value': '65W (Đầu tròn 65W (3 chân))'}, {'name': 'Loại sạc', 'value': 'Đầu tròn 65W (3 chân)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'High Definition (HD) Audio, Stereo speakers, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core 2.1 / 4.6GHz, E-core 1.5 / 3.4GHz, 12MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi (4P + 4E) / 12 luồng, P-core 2.1 / 4.6GHz, E-core 1.5 / 3.4GHz, 12MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 8GB Onboard + 1 x 16GB SO-DIMM, tối đa 24GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên đến 24GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, nâng cấp lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 cổng, USB-C: 1 cổng (với USB PD 3.0 và DisplayPort 1.2), HDMI: 1 cổng, 3.5mm: 1 cổng (kết hợp tai nghe/micrô), SD Card Reader: 1 cổng, Nguồn: 1 cổng'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.2 (qua USB-C)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314.4 x 222.1 x 16.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.43 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh (Đầu tròn 65W (3 chân))'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'Đầu tròn 65W (3 chân)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'High Definition (HD) Audio, Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-1235U, 10 lõi (2P + 8E) / 12 luồng, P-core 1.3 / 4.4GHz, E-core 0.9 / 3.3GHz, 12MB'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-1235U, 10 lõi (2P + 8E) / 12 luồng, P-core 1.3 / 4.4GHz, E-core 0.9 / 3.3GHz, 12MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB Onboard + 8GB SO-DIMM, tối đa 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 16GB'}, {'name': 'Ổ cứng', 'value': '256GB SSD M.2 2242 PCIe 3.0x4 NVMe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB 3.2 Gen 1: 1, USB-C: 1 (hỗ trợ truyền dữ liệu, Power Delivery (chỉ 20V) và DisplayPort 1.2), HDMI: 1, LAN (Ethernet): 1, SD: N/A, 3.5mm: 1 (kết hợp tai nghe/micrô), Đầu nối nguồn: 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 5, 802.11ac 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'DisplayPort 1.2 qua USB-C'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '324 x 215 x 19.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.43 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '38Wh, 65W Round Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '65W Round Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Round Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Bộ giải mã Realtek ALC3287, Loa stereo, 1,5W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5 7533HS (6 lõi / 12 luồng, 3.3 / 4.45GHz, 3MB L2 / 16MB L3)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5 7533HS, 6 lõi / 12 luồng, xung nhịp 3.3 / 4.45GHz, Cache L2 3MB / L3 16MB'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon 660M Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp AMD Radeon 660M Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-4800'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB Onboard + 8GB SO-DIMM DDR5-4800, tối đa 24GB (8GB + 16GB))'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 24GB (sử dụng 2 khe)'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 2242 PCIe 4.0x4 NVMe (Tối đa hai ổ đĩa, 2x SSD M.2 • SSD M.2 2242 lên đến 1TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nits, màn hình chống chói, Độ phủ màu 45% NTSC'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 2 cổng (5Gbps / USB 3.2 Gen 1), USB-C: 1 cổng (5Gbps / USB 3.2 Gen 1, hỗ trợ USB PD 3.0 và DisplayPort 1.2), HDMI: 1 cổng (1.4), 3.5mm: 1 cổng (kết hợp tai nghe/micrô), SD: 1 cổng (Đầu đọc thẻ SD), Nguồn: 1 cổng (Đầu nối nguồn)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua DisplayPort 1.2 trên cổng USB-C)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314.4 x 222.1 x 16.9-17.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.43 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '60Wh, 65W Round Tip (3-pin)'}, {'name': 'Sạc nhanh', 'value': '65W Round Tip (3-pin)'}, {'name': 'Loại sạc', 'value': 'Round Tip (3-pin)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD), Loa stereo, 2W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'HD 720p với Màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Không có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Microsoft Pluton TPM 2.0 Enabled'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 155H, 16 lõi (6P + 8E + 2LPE) / 22 luồng, Max Turbo up to 4.8GHz, 24MB'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost, up to 11 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost, up to 11 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-7467 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '1TB SSD M.2 2242 PCIe 4.0x4 NVMe (Một ổ đĩa, tối đa 1TB M.2 2242 SSD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (WUXGA)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400nits\nĐộ phủ màu 100% DCI-P3\nEyesafe\nDolby Vision\nDisplayHDR True Black 500'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1x (5Gbps / USB 3.2 Gen 1, Luôn bật)\nUSB-C: 2x (Thunderbolt 4 / 40Gbps, với USB PD 3.1 và DisplayPort 1.4)\nHDMI: 1x (lên đến 4K/60Hz)\nLAN: N/A\nSD: N/A\n3.5mm: 1x (giắc cắm kết hợp tai nghe / micrô)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E, 802.11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (qua cổng USB-C Thunderbolt 4)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '312 x 221 x 14.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.39 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '65Wh (65W USB-C Slim (Wall-mount))'}, {'name': 'Sạc nhanh', 'value': '65W USB-C Slim (Wall-mount)'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh độ nét cao (HD)\nBộ giải mã Realtek ALC3306\nLoa stereo, 2W x4\nDolby Atmos\nBộ khuếch đại (AMP)'}, {'name': 'Webcam', 'value': 'FHD 1080p + IR with E-shutter, ToF Sensor'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền, tiếng Anh'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0\nCamera IR cho Windows Hello (nhận dạng khuôn mặt)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language, English + Microsoft 365 Basic + Office Home 2024'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'Microsoft 365 Basic + Office Home 2024'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-12450H (8 lõi (4P + 4E) / 12 luồng, P-core 2.0 / 4.4GHz, E-core 1.5 / 3.3GHz, 12MB)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-12450H, 8 lõi (4P + 4E), 12 luồng'}, {'name': 'Tên card đồ họa', 'value': 'Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5-4800 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Không hỗ trợ nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '1TB SSD M.2 2242 PCIe 4.0x4 NVMe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '300nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Đầu đọc thẻ, 1x HDMI 1.4, 1x Headphone / microphone combo jack (3.5mm), 1x Đầu nối nguồn, 1x USB-C 3.2 Gen 1 (Truyền dữ liệu, sạc, Display Port 1.2), 2x USB 3.2 Gen 1'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6, 11ax 2x2'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.1'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Display Port 1.2 qua cổng USB-C'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '324.3 x 213.8 x 17.9 mm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '1.37 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '47Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'High Definition (HD) Audio, Loa âm thanh nổi, 1.5W x2, Dolby Audio'}, {'name': 'Webcam', 'value': 'FHD 1080p với màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware TPM 2.0, Bảo mật vân tay'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-1334U (10 Cores: 2P + 8E, P: 1.3 up to 4.6 GHz / E: 0.9 up to 3.4 GHz)'}, {'name': 'Mô tả CPU', 'value': '10 Cores: 2P + 8E, P: 1.3 up to 4.6 GHz / E: 0.9 up to 3.4 GHz, L3 Cache 12MB'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 (Dual Channel, 3200MHz)'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 16GB, hỗ trợ nâng cấp lên 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên 32GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB M.2 (2280) hai khe cắm SSD, Gen4'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300nit'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB 3.2 Gen 1, 1x USB 2.0, 2x USB 3.2 Gen 2 & USB PD Support, HDMI (4K@60Hz)'}, {'name': 'Wi-Fi', 'value': 'Intel Wireless-AX203 (Wi-Fi 6 , 2x2)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'HDMI (4K@60Hz)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.8 x 237.8 x 18.9~19.4 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.7 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '51 Wh Li-Ion'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'HD Audio, Stereo Speakers (max 1.5W x 2)'}, {'name': 'Webcam', 'value': 'Webcam HD có màn trập camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bảo mật SSD, fTPM/HW TPM(Tuỳ chọn), Slim Kensington lock'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple A18 Pro (6 lõi với 2 lõi hiệu năng và 4 lõi tiết kiệm điện)'}, {'name': 'Mô tả CPU', 'value': 'CPU 6 lõi với 2 lõi hiệu năng và 4 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 5 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Công nghệ dò tia tốc độ cao bằng phần cứng, Neural Engine 16 lõi, Băng thông bộ nhớ 60GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '256GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2408 x 1506 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Hỗ trợ 1 tỷ màu, Màu sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, có đèn nền LED, Mật độ 219 pixel mỗi inch, Hỗ trợ một màn hình ngoài có độ phân giải gốc lên đến 4K ở tần số 60Hz'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 cổng USB 3 (USB-C) hỗ trợ: Sạc / DisplayPort / USB 3 (lên đến 10Gb/s); 1 cổng USB 2 (USB-C) hỗ trợ: Sạc / USB 2 (lên đến 480Mb/s); Jack cắm tai nghe 3,5 mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Hỗ trợ một màn hình ngoài có độ phân giải gốc lên đến 4K ở tần số 60Hz)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.27 x 29.75 x 20.64 cm (Cao x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.23 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin lithium-ion 36.5 watt‑giờ tích hợp; Thời gian xem video trực tuyến lên đến 16 giờ; Thời gian duyệt web trên mạng không dây lên đến 11 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh hai loa, Hỗ trợ Âm Thanh Không Gian, Dãy hai micrô phối hợp với tính năng điều hướng chùm sóng, Chế độ micrô Tách Lời Nói và Âm Phổ Rộng tăng cường độ trong cho giọng nói trong các cuộc gọi thoại và video'}, {'name': 'Webcam', 'value': 'Camera FaceTime HD 1080p, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy hai micrô phối hợp với tính năng điều hướng chùm sóng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Magic Keyboard'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Chính hãng Apple Việt Nam'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple A18 Pro (6 lõi với 2 lõi hiệu năng và 4 lõi tiết kiệm điện)'}, {'name': 'Mô tả CPU', 'value': 'CPU 6 lõi với 2 lõi hiệu năng và 4 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 5 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Công nghệ dò tia tốc độ cao bằng phần cứng, Neural Engine 16 lõi, Băng thông bộ nhớ 60GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2408 x 1506 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Hỗ trợ 1 tỷ màu, Màu sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, có đèn nền LED, hỗ trợ một màn hình ngoài có độ phân giải gốc lên đến 4K ở tần số 60Hz'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 cổng USB 3 (USB-C) hỗ trợ: Sạc / DisplayPort / USB 3 (lên đến 10Gb/s); 1 cổng USB 2 (USB-C) hỗ trợ: Sạc / USB 2 (lên đến 480Mb/s); Jack cắm tai nghe 3,5 mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (hỗ trợ màn hình ngoài độ phân giải gốc lên đến 4K @ 60Hz)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.27 x 29.75 x 20.64 cm (Cao x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.23 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin lithium-ion 36.5 watt‑giờ tích hợp; Thời gian xem video trực tuyến lên đến 16 giờ; Thời gian duyệt web trên mạng không dây lên đến 11 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh hai loa, Hỗ trợ Âm Thanh Không Gian, Dãy hai micrô phối hợp với tính năng điều hướng chùm sóng, Chế độ micrô Tách Lời Nói và Âm Phổ Rộng tăng cường độ trong cho giọng nói trong các cuộc gọi thoại và video'}, {'name': 'Webcam', 'value': 'Camera FaceTime HD 1080p, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy hai micrô phối hợp với tính năng điều hướng chùm sóng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Magic Keyboard'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Chính hãng Apple Việt Nam'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi siêu xử lý và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 8 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Neural Accelerators, Công nghệ dò tia tốc độ cao bằng phần cứng, Neural Engine 16 lõi, Băng thông bộ nhớ 153GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1664 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, có đèn nền LED với công nghệ IPS, Công nghệ True Tone, Hỗ trợ lên đến hai màn hình ngoài'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3,5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 (802.11be)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ lên đến hai màn hình ngoài'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.13 x 30.41 cm x 21.5 cm (Dày x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.23 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 53,8 watt‑giờ tích hợp, Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh bốn loa, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu, Dãy ba micrô phối hợp, Chế độ micrô Tách Lời Nói và Âm Phổ Rộng'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô phối hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Cảm biến ánh sáng môi trường, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Bàn di chuột Force Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Bảo mật vân tay, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5 Pro'}, {'name': 'Mô tả CPU', 'value': 'CPU 15 lõi với 5 lõi siêu xử lý và 10 lõi hiệu năng'}, {'name': 'Tên card đồ họa', 'value': 'GPU 16 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Neural Accelerators, Công nghệ dò tia tốc độ cao bằng phần cứng, Neural Engine 16 lõi, Băng thông bộ nhớ 307GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3024 x 1964 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '1.000 nit (SDR), tối đa 1.600 nit (HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Liquid Retina XDR, Tỷ lệ tương phản 1.000.000:1, Công nghệ True Tone, Công nghệ ProMotion'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Khe thẻ nhớ SDXC, HDMI, Jack cắm tai nghe 3.5 mm, Cổng MagSafe 3, Ba cổng Thunderbolt 5 (USB-C) hỗ trợ: Sạc / DisplayPort / Thunderbolt 5 (lên đến 120Gb/s) / USB 4 (lên đến 120Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 (802.11be)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.55 x 31.26 x 22.12 cm (Cao x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.60 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 72,4 watt-giờ, Thời gian xem video trực tuyến lên đến 22 giờ, Thời gian duyệt web trên mạng không dây lên đến 14 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Hỗ trợ Âm Thanh Không Gian'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô chất lượng chuẩn studio, Chế độ micrô Tách Lời Nói và Âm Phổ Rộng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Cảm biến ánh sáng môi trường, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Force Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Bảo mật vân tay, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip M4 (10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện)'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 8 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 8 lõi, Neural Engine 16 lõi, Công nghệ dò tia tốc độ cao bằng phần cứng, Băng thông bộ nhớ 120GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '256GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1664 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, Có đèn nền LED, Mật độ 224 pixel mỗi inch, Công nghệ True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3.5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ: Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': 'Cao: 1.13 cm x Rộng: 30.41 cm x Dài: 21.5 cm'}, {'name': 'Trọng lượng', 'value': '1.24 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ, Pin Li-Po 53.8 watt‑giờ tích hợp'}, {'name': 'Sạc nhanh', 'value': '70W'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh bốn loa, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods, AirPods Pro, và AirPods Max'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, Bảo mật vân tay'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip M4 (10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện)'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 10 lõi, Neural Engine 16 lõi, Công nghệ dò tia tốc độ cao bằng phần cứng, Băng thông bộ nhớ 120GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1664 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, Có đèn nền LED, Mật độ 224 pixel mỗi inch, Công nghệ True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3.5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ: Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': 'Cao: 1.13 cm x Rộng: 30.41 cm x Dài: 21.5 cm'}, {'name': 'Trọng lượng', 'value': '1.24 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ, Pin Li-Po 53.8 watt‑giờ tích hợp'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh bốn loa, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods, AirPods Pro, và AirPods Max'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, Bảo mật vân tay'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện'}, {'name': 'Mô tả CPU', 'value': 'Chip Apple M5 10 lõi'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi Neural Engine 16 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 10 lõi, Neural Engine 16 lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Apple Intelligence'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3024 x 1964 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '1.000 nit (SDR ngoài trời), 1.600 nit (HDR nội dung)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Liquid Retina XDR, True Tone, ProMotion'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-C (Thunderbolt 4 - Sạc / DisplayPort / Thunderbolt 4 / USB 4), HDMI, Khe thẻ nhớ SDXC, Jack cắm tai nghe 3.5 mm, MagSafe 3'}, {'name': 'Wi-Fi', 'value': 'Wi‑Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.55 x 31.26 x 22.12 cm (Cao x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.55 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 72.4 watt-giờ, Thời gian xem video trực tuyến lên đến 24 giờ, Thời gian duyệt web trên mạng không dây lên đến 16 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô chất lượng chuẩn studio với tỷ lệ tín hiệu – nhiễu cao'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch, Cảm biến ánh sáng môi trường'}, {'name': 'Touchpad', 'value': 'Force Touch, hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Viền màn hình siêu mỏng, Wi-Fi 6, Bảo mật vân tay'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M4 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện'}, {'name': 'Mô tả CPU', 'value': 'Neural Engine 16 lõi'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '256GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': 'Cao: 5.0 cm x Rộng: 12.7 cm x Dài: 12.7 cm'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': 'N/A'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Hỗ trợ đồng thời đến ba màn hình, Đầu ra video kỹ thuật số Thunderbolt 4'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-C (hỗ trợ USB 3), Jack cắm tai nghe 3,5 mm, Gigabit Ethernet, HDMI, Thunderbolt 4, USB 4, DisplayPort'}, {'name': 'Wi-Fi', 'value': 'Wi‑Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Hỗ trợ đồng thời đến ba màn hình)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Cao: 5.0 cm x Rộng: 12.7 cm x Dài: 12.7 cm'}, {'name': 'Trọng lượng', 'value': '0.67 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'N/A'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa tích hợp. Các định dạng được hỗ trợ bao gồm AAC, MP3, Apple Lossless, FLAC, Dolby Digital, Dolby Digital Plus và Dolby Atmos. Cổng HDMI hỗ trợ đầu ra âm thanh đa kênh'}, {'name': 'Webcam', 'value': 'N/A'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Chính hãng Apple Việt Nam'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip M4 (10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện)'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 10 lõi, Neural Engine 16 lõi, Công nghệ dò tia tốc độ cao bằng phần cứng, Băng thông bộ nhớ 120GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1664 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, Có đèn nền LED, Mật độ 224 pixel mỗi inch, Công nghệ True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3.5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ: Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': 'Cao: 1.13 cm x Rộng: 30.41 cm x Dài: 21.5 cm'}, {'name': 'Trọng lượng', 'value': '1.24 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ, Pin Li-Po 53.8 watt‑giờ tích hợp'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh bốn loa, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods, AirPods Pro, và AirPods Max'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, Bảo mật vân tay'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip M4 (10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện)'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 10 lõi, Neural Engine 16 lõi, Công nghệ dò tia tốc độ cao bằng phần cứng, Băng thông bộ nhớ 120GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1664 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, Có đèn nền LED, Mật độ 224 pixel mỗi inch, Công nghệ True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3.5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ: Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': 'Cao: 1.13 cm x Rộng: 30.41 cm x Dài: 21.5 cm'}, {'name': 'Trọng lượng', 'value': '1.24 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ, Pin Li-Po 53.8 watt‑giờ tích hợp'}, {'name': 'Sạc nhanh', 'value': 'Sạc 70W'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh bốn loa, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods, AirPods Pro, và AirPods Max'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M4 8 lõi với 4 lõi hiệu năng và 4 lõi tiết kiệm điện Neural Engine 16 lõi'}, {'name': 'Mô tả CPU', 'value': 'Apple M4 8 lõi với 4 lõi hiệu năng và 4 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 8 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 8 lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '256GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '24 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '4480 x 2520 (4.5K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Retina 4.5K'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Retina 4.5K, True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x Thunderbolt 4 (lên đến 40Gb/s), USB 4 (lên đến 40Gb/s), USB 3.1 Gen 2 (lên đến 10Gb/s), DisplayPort, Jack cắm tai nghe 3.5 mm có hỗ trợ nâng cao cho tai nghe trở kháng cao'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Rộng: 54.7 cm - Cao: 46.1 cm - Độ dày chân đế: 14.7 cm'}, {'name': 'Trọng lượng', 'value': '4.42 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'N/A'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': '143W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos, Hệ thống âm thanh 6 loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô chất lượng chuẩn studio với tỷ lệ tín hiệu – nhiễu cao và tính năng điều hướng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Magic Keyboard'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Magic Keyboard'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Chính hãng Apple Việt Nam'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi siêu xử lý và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Neural Accelerators, Công nghệ dò tia tốc độ cao bằng phần cứng, Neural Engine 16 lõi, Băng thông bộ nhớ 153GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1864 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, có đèn nền LED với công nghệ IPS, Công nghệ True Tone, Hỗ trợ lên đến hai màn hình ngoài'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3,5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 (802.11be)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ lên đến hai màn hình ngoài'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.15 x 34.04 cm x 23.76 cm (Dày x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.51 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 66,5 watt‑giờ tích hợp, Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ'}, {'name': 'Sạc nhanh', 'value': 'Sạc 70W'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh bốn loa, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu, Dãy ba micrô phối hợp, Chế độ micrô Tách Lời Nói và Âm Phổ Rộng'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô phối hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Cảm biến ánh sáng môi trường, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Bàn di chuột Force Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Bảo mật vân tay, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M4 Pro 12 lõi với 8 lõi hiệu năng và 4 lõi tiết kiệm điện'}, {'name': 'Mô tả CPU', 'value': 'Apple M4 Pro 12 lõi với 8 lõi hiệu năng và 4 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': '16 lõi Neural Engine 16 lõi'}, {'name': 'Mô tả card đồ họa', 'value': '16 lõi Neural Engine 16 lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3024 x 1964 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Liquid Retina XDR'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': '1.000 nit ở chế độ toàn màn hình, 1.600 nit (chỉ nội dung HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'XDR (Extreme Dynamic Range), True Tone, Hỗ trợ tối đa hai màn hình ngoài'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Khe thẻ nhớ SDXC, HDMI, Jack cắm tai nghe 3.5 mm, Cổng MagSafe 3, Ba cổng Thunderbolt 5 (USB‑C) hỗ trợ: Sạc, DisplayPort, Thunderbolt 5 (lên đến 120Gb/s), Thunderbolt 4 (lên đến 40Gb/s), USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi‑Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ tối đa hai màn hình ngoài'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Dài: 22.12 cm x Cao: 1.55 cm x Rộng: 31.26 cm'}, {'name': 'Trọng lượng', 'value': '1.60 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 72.4 watt-giờ, Thời gian xem video trực tuyến lên đến 22 giờ, Thời gian duyệt web trên mạng không dây lên đến 14 giờ'}, {'name': 'Sạc nhanh', 'value': 'Sạc 96W'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods (thế hệ thứ 3 trở lên)'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi siêu xử lý và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Neural Accelerators, Công nghệ dò tia tốc độ cao bằng phần cứng, Neural Engine 16 lõi, Băng thông bộ nhớ 153GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1864 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, có đèn nền LED với công nghệ IPS, Công nghệ True Tone, Hỗ trợ lên đến hai màn hình ngoài'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3,5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 (802.11be)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ lên đến hai màn hình ngoài'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.15 x 34.04 cm x 23.76 cm (Dày x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.51 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 66,5 watt‑giờ tích hợp, Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ'}, {'name': 'Sạc nhanh', 'value': 'Sạc 70W'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh bốn loa, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu, Dãy ba micrô phối hợp, Chế độ micrô Tách Lời Nói và Âm Phổ Rộng'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô phối hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Cảm biến ánh sáng môi trường, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Bàn di chuột Force Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Bảo mật vân tay, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M4 Pro 14 lõi với 10 lõi hiệu năng và 4 lõi tiết kiệm điện'}, {'name': 'Mô tả CPU', 'value': 'Apple M4 Pro 14 lõi với 10 lõi hiệu năng và 4 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'Apple M4 Pro ( tích hợp)'}, {'name': 'Mô tả card đồ họa', 'value': '20 lõi Neural Engine 16 lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3456 x 2234 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Liquid Retina XDR'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': '1.000 nit ở chế độ toàn màn hình, 1.600 nit (chỉ nội dung HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'XDR (Extreme Dynamic Range), True Tone, Hỗ trợ tối đa 2 màn hình ngoài'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Khe thẻ nhớ SDXC, HDMI, Jack cắm tai nghe 3.5 mm, Cổng MagSafe 3, Ba cổng Thunderbolt 5 (USB‑C) hỗ trợ: Sạc, DisplayPort, Thunderbolt 5 (lên đến 120Gb/s), Thunderbolt 4 (lên đến 40Gb/s), USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi‑Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ tối đa 2 màn hình ngoài'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Dài: 24.81 cm x Rộng: 35.57 cm x Cao: 1.68 cm'}, {'name': 'Trọng lượng', 'value': '2.14 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 100 watt-giờ, Thời gian xem video trực tuyến lên đến 24 giờ, Thời gian duyệt web trên mạng không dây lên đến 17 giờ'}, {'name': 'Sạc nhanh', 'value': '140W'}, {'name': 'Loại sạc', 'value': 'Sạc 140W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods (thế hệ thứ 3 trở lên)'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Chính hãng Apple Việt Nam'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip M4 (10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện)'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 10 lõi, Neural Engine 16 lõi, Công nghệ dò tia tốc độ cao bằng phần cứng, Băng thông bộ nhớ 120GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1864 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, Có đèn nền LED, Mật độ 224 pixel mỗi inch, Công nghệ True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3.5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ: Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': 'Cao: 1.15 cm x Rộng: 34.04 cm x Dài: 23.76 cm'}, {'name': 'Trọng lượng', 'value': '1.51 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ, Pin Li-Po 66.5 watt‑giờ tích hợp'}, {'name': 'Sạc nhanh', 'value': 'Sạc 70W'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa với loa trầm khử lực, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods, AirPods Pro, AirPods Max'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, Bảo mật vân tay'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'N/A'}, {'name': 'Mô tả CPU', 'value': 'N/A'}, {'name': 'Tên card đồ họa', 'value': 'N/A'}, {'name': 'Mô tả card đồ họa', 'value': 'N/A'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': 'N/A'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': 'N/A'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '27 inch'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '5K'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'VESA 2026 (Ngàm)'}, {'name': 'Wi-Fi', 'value': 'N/A'}, {'name': 'Bluetooth', 'value': 'N/A'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'N/A'}, {'name': 'Trọng lượng', 'value': 'N/A'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'N/A'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'N/A'}, {'name': 'Webcam', 'value': 'N/A'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'N/A'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Chính hãng Apple Việt Nam'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M2 8 nhân'}, {'name': 'Mô tả CPU', 'value': '8 nhân CPU'}, {'name': 'Tên card đồ họa', 'value': '8 nhân GPU'}, {'name': 'Mô tả card đồ họa', 'value': '16 nhân Neural Engine'}, {'name': 'Bộ xử lý AI / NPU', 'value': '16 nhân Neural Engine'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '256GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1664 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'Liquid Retina Display'}, {'name': 'Công nghệ màn hình', 'value': 'Liquid Retina Display'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x Thunderbolt 3, Jack tai nghe 3.5 mm, MagSafe 3'}, {'name': 'Wi-Fi', 'value': '802.11ax Wi-Fi 6'}, {'name': 'Bluetooth', 'value': '5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Dày: 1,13cm - Chiều dài: 30,41cm Chiều rộng: 21,5cm'}, {'name': 'Trọng lượng', 'value': '1.27 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '52,6 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': '3 microphones, 4 Loa'}, {'name': 'Webcam', 'value': '1080p FaceTime HD camera'}, {'name': 'Micro', 'value': '3 microphones'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Vân tay'}, {'name': 'Hệ điều hành', 'value': 'MacOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'I Chính hãng Apple Việt Nam'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip M1'}, {'name': 'Mô tả CPU', 'value': '8 nhân với 4 nhân hiệu năng cao và 4 nhân tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU tích hợp'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 7 nhân, 16 nhân Neural Engine'}, {'name': 'Bộ xử lý AI / NPU', 'value': '16 nhân Neural Engine'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'LPDDR4'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '256GB SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 pixels (2K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '400 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'Hỗ trợ dải màu P3, True-Tone'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400 nits, Hỗ trợ dải màu P3, True-Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 cổng Thunderbolt / USB 4, Không Khe đọc thẻ nhớ'}, {'name': 'Wi-Fi', 'value': '802.11ax Wi-Fi 6 wireless networking'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '1.61 cm x 30.41 cm x 21.24 cm'}, {'name': 'Trọng lượng', 'value': '1.29 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '49.9-watt lithium-polymer, củ sạc công suất 30W'}, {'name': 'Sạc nhanh', 'value': '30W'}, {'name': 'Loại sạc', 'value': 'củ sạc công suất 30W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': '3 microphones, headphones, loa kép (2 kênh)'}, {'name': 'Webcam', 'value': '720p FaceTime HD camera'}, {'name': 'Micro', 'value': '3 microphones'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'Touch ID'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS Big Sur'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Viền màn hình siêu mỏng, Wi-Fi 6'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip M4 (10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện)'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 10 lõi, Neural Engine 16 lõi, Công nghệ dò tia tốc độ cao bằng phần cứng, Băng thông bộ nhớ 120GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1664 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, Có đèn nền LED, Mật độ 224 pixel mỗi inch, Công nghệ True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3.5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ: Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': 'Cao: 1.13 cm x Rộng: 30.41 cm x Dài: 21.5 cm'}, {'name': 'Trọng lượng', 'value': '1.24 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ, Pin Li-Po 53.8 watt‑giờ tích hợp'}, {'name': 'Sạc nhanh', 'value': 'Sạc 70W'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh bốn loa, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods, AirPods Pro, và AirPods Max'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M3 8 Lõi'}, {'name': 'Mô tả CPU', 'value': '8 Lõi, Neural Engine 16 lõi'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 Lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Tích hợp, 10 Lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '256GB SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': 'N/A'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'MagSafe 3, Thunderbolt / USB 4'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E'}, {'name': 'Bluetooth', 'value': 'N/A'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '15 inch'}, {'name': 'Trọng lượng', 'value': 'N/A'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'N/A'}, {'name': 'Sạc nhanh', 'value': '35W'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Dolby Atmos'}, {'name': 'Webcam', 'value': 'Camera FaceTime HD 1080p'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'MacOS'}, {'name': 'Hệ điều hành', 'value': 'MacOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Chính hãng Apple Việt Nam'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M4 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện Neural Engine 16 lõi'}, {'name': 'Mô tả CPU', 'value': 'Apple M4 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện Neural Engine 16 lõi'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '256GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '24 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '4480 x 2520 (4.5K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Retina 4.5K'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Retina 4.5K, True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '4x Thunderbolt 4 (lên đến 40Gb/s), USB 4 (lên đến 40Gb/s), USB 3.1 Gen 2 (lên đến 10Gb/s), DisplayPort, Jack cắm tai nghe 3.5 mm có hỗ trợ nâng cao cho tai nghe trở kháng cao, Gigabit Ethernet'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Rộng: 54.7 cm - Cao: 46.1 cm - Độ dày chân đế: 14.7 cm'}, {'name': 'Trọng lượng', 'value': '4.44 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'N/A'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': '143W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos, Hệ thống âm thanh 6 loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô chất lượng chuẩn studio với tỷ lệ tín hiệu – nhiễu cao và tính năng điều hướng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Magic Keyboard'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Magic Keyboard'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Chính hãng Apple Việt Nam'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip M1'}, {'name': 'Mô tả CPU', 'value': '8 nhân với 4 nhân hiệu năng cao và 4 nhân tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': '8 nhân GPU, 16 nhân Neural Engine (Tích hợp)'}, {'name': 'Mô tả card đồ họa', 'value': '8 nhân GPU, 16 nhân Neural Engine'}, {'name': 'Bộ xử lý AI / NPU', 'value': '16 nhân Neural Engine'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '256GB SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 pixel (2K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'Hỗ trợ dải màu P3, True-Tone'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 500 nits, Hỗ trợ dải màu P3, True-Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 cổng Thunderbolt / USB 4 ports, Không Khe đọc thẻ nhớ'}, {'name': 'Wi-Fi', 'value': '802.11ax Wi-Fi 6'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '1.56 cm x 30.41 cm x 21.24 cm'}, {'name': 'Trọng lượng', 'value': '1.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '58.2-watt-hour lithium-polymer, 61W USB-C Power Adapter'}, {'name': 'Sạc nhanh', 'value': '61W USB-C Power Adapter'}, {'name': 'Loại sạc', 'value': 'USB-C'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': '2 loa, Dolby Atmos'}, {'name': 'Webcam', 'value': 'HD webcam'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'Touch ID'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS Big Sur'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M4 Pro 12 lõi với 8 lõi hiệu năng và 4 lõi tiết kiệm điện'}, {'name': 'Mô tả CPU', 'value': 'Apple M4 Pro 12 lõi với 8 lõi hiệu năng và 4 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': '16 lõi Neural Engine 16 lõi'}, {'name': 'Mô tả card đồ họa', 'value': '16 lõi Neural Engine 16 lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3024 x 1964 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Liquid Retina XDR XDR (Extreme Dynamic Range)'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': '1.000 nit ở chế độ toàn màn hình, 1.600 nit (chỉ nội dung HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'True Tone, Hỗ trợ tối đa hai màn hình ngoài'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Khe thẻ nhớ SDXC, HDMI, Jack cắm tai nghe 3.5 mm, Cổng MagSafe 3, Ba cổng Thunderbolt 5 (USB‑C) hỗ trợ: Sạc, DisplayPort, Thunderbolt 5 (lên đến 120Gb/s), Thunderbolt 4 (lên đến 40Gb/s), USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi‑Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ tối đa hai màn hình ngoài'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Dài: 22.12 cm x Cao: 1.55 cm x Rộng: 31.26 cm'}, {'name': 'Trọng lượng', 'value': '1.60 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 72.4 watt-giờ, Thời gian xem video trực tuyến lên đến 22 giờ, Thời gian duyệt web trên mạng không dây lên đến 14 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods (thế hệ thứ 3 trở lên)'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M4 Pro 14 lõi với 10 lõi hiệu năng và 4 lõi tiết kiệm điện'}, {'name': 'Mô tả CPU', 'value': 'Apple M4 Pro 14 lõi với 10 lõi hiệu năng và 4 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': '20 lõi Neural Engine 16 lõi'}, {'name': 'Mô tả card đồ họa', 'value': '20 lõi Neural Engine 16 lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3456 x 2234 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Liquid Retina XDR XDR (Extreme Dynamic Range)'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': '1.000 nit ở chế độ toàn màn hình, 1.600 nit (chỉ nội dung HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'True Tone, Hỗ trợ tối đa 2 màn hình ngoài'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Khe thẻ nhớ SDXC, HDMI, Jack cắm tai nghe 3.5 mm, Cổng MagSafe 3, Ba cổng Thunderbolt 5 (USB‑C) hỗ trợ: Sạc, DisplayPort, Thunderbolt 5 (lên đến 120Gb/s), Thunderbolt 4 (lên đến 40Gb/s), USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi‑Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ tối đa 2 màn hình ngoài'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Dài: 24.81 cm x Rộng: 35.57 cm x Cao: 1.68 cm'}, {'name': 'Trọng lượng', 'value': '2.14 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 100 watt-giờ, Thời gian xem video trực tuyến lên đến 24 giờ, Thời gian duyệt web trên mạng không dây lên đến 17 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods (thế hệ thứ 3 trở lên)'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M4 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện'}, {'name': 'Mô tả CPU', 'value': 'Apple M4 10 lõi'}, {'name': 'Tên card đồ họa', 'value': '10 lõi Neural Engine 16 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Tích hợp (Neural Engine 16 lõi)'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3024 x 1964 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Liquid Retina XDR XDR (Extreme Dynamic Range)'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': '1.000 nit ở chế độ toàn màn hình, 1.600 nit (chỉ nội dung HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'True Tone, Hỗ trợ tối đa hai màn hình ngoài'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-C (Thunderbolt 4 - Sạc, DisplayPort, Thunderbolt 4 (lên đến 40Gb/s), USB 4 (lên đến 40Gb/s)), HDMI, Khe thẻ nhớ SDXC, Jack cắm tai nghe 3.5 mm, MagSafe 3'}, {'name': 'Wi-Fi', 'value': 'Wi‑Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ tối đa hai màn hình ngoài'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Dài: 22.12 cm x Cao: 1.55 cm x Rộng: 31.26 cm'}, {'name': 'Trọng lượng', 'value': '1.55 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 72.4 watt-giờ, Thời gian xem video trực tuyến lên đến 24 giờ, Thời gian duyệt web trên mạng không dây lên đến 16 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods (thế hệ thứ 3 trở lên)'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M4 Pro 14 lõi với 10 lõi hiệu năng và 4 lõi tiết kiệm điện'}, {'name': 'Mô tả CPU', 'value': 'Apple M4 Pro 14 lõi với 10 lõi hiệu năng và 4 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': '20 lõi Neural Engine 16 lõi'}, {'name': 'Mô tả card đồ họa', 'value': '20 lõi Neural Engine 16 lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '48GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3456 x 2234 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Liquid Retina XDR XDR (Extreme Dynamic Range)'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': '1.000 nit ở chế độ toàn màn hình, 1.600 nit (chỉ nội dung HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Liquid Retina XDR XDR (Extreme Dynamic Range), True Tone, Hỗ trợ tối đa 2 màn hình ngoài'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Khe thẻ nhớ SDXC, HDMI, Jack cắm tai nghe 3.5 mm, Cổng MagSafe 3, Ba cổng Thunderbolt 5 (USB‑C) hỗ trợ: Sạc, DisplayPort, Thunderbolt 5 (lên đến 120Gb/s), Thunderbolt 4 (lên đến 40Gb/s), USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi‑Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ tối đa 2 màn hình ngoài'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Dài: 24.81 cm x Rộng: 35.57 cm x Cao: 1.68 cm'}, {'name': 'Trọng lượng', 'value': '2.14 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 100 watt-giờ, Thời gian xem video trực tuyến lên đến 24 giờ, Thời gian duyệt web trên mạng không dây lên đến 17 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods (thế hệ thứ 3 trở lên)'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M3 8 Lõi, Neural Engine 16 lõi'}, {'name': 'Mô tả CPU', 'value': 'CPU Apple M3 8 Lõi, Neural Engine 16 lõi'}, {'name': 'Tên card đồ họa', 'value': 'GPU tích hợp Apple M3'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 10 Lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': 'N/A'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Hai cổng Thunderbolt / USB 4'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E'}, {'name': 'Bluetooth', 'value': 'N/A'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '13 inch'}, {'name': 'Trọng lượng', 'value': 'N/A'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'N/A'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Dolby Atmos'}, {'name': 'Webcam', 'value': 'Camera FaceTime HD 1080p'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'MacOS'}, {'name': 'Hệ điều hành', 'value': 'MacOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M3 8 Lõi'}, {'name': 'Mô tả CPU', 'value': '8 Lõi, Neural Engine 16 lõi'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 Lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Tích hợp (Apple Silicon)'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '256GB SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': 'N/A'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'MagSafe 3, Thunderbolt / USB 4'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E'}, {'name': 'Bluetooth', 'value': 'N/A'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '13 inch'}, {'name': 'Trọng lượng', 'value': 'N/A'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'N/A'}, {'name': 'Sạc nhanh', 'value': 'Sạc 30W'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Dolby Atmos'}, {'name': 'Webcam', 'value': 'Camera FaceTime HD 1080p'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'MacOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Chính hãng Apple Việt Nam'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip M4 (10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện)'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 10 lõi, Neural Engine 16 lõi, Công nghệ dò tia tốc độ cao bằng phần cứng, Băng thông bộ nhớ 120GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1864 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, Có đèn nền LED, Mật độ 224 pixel mỗi inch, Công nghệ True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3.5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ: Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': 'Cao: 1.15 cm x Rộng: 34.04 cm x Dài: 23.76 cm'}, {'name': 'Trọng lượng', 'value': '1.51 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ, Pin Li-Po 66.5 watt‑giờ tích hợp'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa với loa trầm khử lực, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods, AirPods Pro, AirPods Max'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, Bảo mật vân tay'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'M1 Pro/M1 Max'}, {'name': 'Mô tả CPU', 'value': 'Chip Apple Silicon'}, {'name': 'Tên card đồ họa', 'value': '14 nhân GPU'}, {'name': 'Mô tả card đồ họa', 'value': 'Đồ họa tích hợp (GPU)'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Có (Ngụ ý từ kiến trúc Apple Silicon)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A (Không chỉ định rõ loại RAM)'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3024 x 1964 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Liquid Retina, Mini LED'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'XDR'}, {'name': 'Công nghệ màn hình', 'value': '120Hz, Liquid Retina, Mini LED, XDR'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Headphone jack, 1x MagSafe port, 1x HDMI, 1x Thunderbolt 4, 1x SDXC'}, {'name': 'Wi-Fi', 'value': '802.11ax Wi-Fi 6'}, {'name': 'Bluetooth', 'value': 'v5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '1.6 kg'}, {'name': 'Trọng lượng', 'value': '1.55 x 31.26 x 22.12 cm'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'N/A'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'MagSafe'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': '6 loa'}, {'name': 'Webcam', 'value': '1080p Camera, FaceTime'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Vân tay, Nhận diện khuôn mặt'}, {'name': 'Hệ điều hành', 'value': 'MacOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'In Laser đen trắng'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'N/A'}, {'name': 'Mô tả CPU', 'value': 'N/A'}, {'name': 'Tên card đồ họa', 'value': 'N/A'}, {'name': 'Mô tả card đồ họa', 'value': 'N/A'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': 'N/A'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': 'N/A'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '27 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '5120 x 2880 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Mặt kính Nano-texture, màn hình Retina'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '600 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Hỗ trợ một tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Mặt kính Nano-texture, Màn hình Retina, True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x Thunderbolt 5 (120Gb/s), 1 cổng ngược dòng dành cho thiết bị chính (96W), 1 cổng xuôi dòng để kết nối phụ kiện tốc độ cao hoặc kết nối chuỗi các màn hình khác, 2x USB-C (10Gb/s)'}, {'name': 'Wi-Fi', 'value': 'N/A'}, {'name': 'Bluetooth', 'value': 'N/A'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Kết nối chuỗi các màn hình khác)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Màn hình Studio Display với chân đế có thể điều chỉnh độ nghiêng và độ cao: 47.9 x 62.3 x 20.7 cm (Cao x Rộng x Dày); Studio Display với ngàm kết nối VESA: 36.2 x 62.3 x 3.1 cm (Cao x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': 'Màn hình Studio Display với chân đế có thể điều chỉnh độ nghiêng và độ cao: 7.6 kg; Studio Display với ngàm kết nối VESA: 5.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'N/A'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos, Ba micrô chuẩn studio kết hợp, Hỗ trợ “Hey Siri”'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage cùng chế độ Desk View'}, {'name': 'Micro', 'value': 'Ba micrô chuẩn studio'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'N/A'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Chính hãng Apple Việt Nam'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M3 Pro 11 nhân'}, {'name': 'Mô tả CPU', 'value': 'Chip Apple M3 Pro 11 nhân'}, {'name': 'Tên card đồ họa', 'value': 'Apple M3 Pro'}, {'name': 'Mô tả card đồ họa', 'value': '14 nhân Neural Engine 16 nhân'}, {'name': 'Bộ xử lý AI / NPU', 'value': '14 nhân Neural Engine 16 nhân'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '18GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3024 x 1964 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': 'Độ sáng XDR: 1000 nit liên tục ở chế độ toàn màn hình, Độ sáng đỉnh 1600 nit (chỉ nội dung HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': 'True Tone'}, {'name': 'Công nghệ màn hình', 'value': 'XDR, ProMotion'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Hai cổng Thunderbolt / USB 4 (USB-C), Ba cổng Thunderbolt 4 (USB-C), Cổng HDMI, Khe thẻ nhớ SDXC, Jack 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Cao 1,55 - Rộng 31,26 - Dài 22,12 cm'}, {'name': 'Trọng lượng', 'value': '1,55 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '70Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh stereo rộng, Dolby Atmos'}, {'name': 'Webcam', 'value': 'HD 1080p'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Có'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'N/A'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M4 Pro 14 lõi với 10 lõi hiệu năng và 4 lõi tiết kiệm điện'}, {'name': 'Mô tả CPU', 'value': 'Apple M4 Pro 14 lõi'}, {'name': 'Tên card đồ họa', 'value': '20 lõi Neural Engine 16 lõi'}, {'name': 'Mô tả card đồ họa', 'value': '20 lõi Neural Engine 16 lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3024 x 1964 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Nano-texture, Liquid Retina XDR'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': '1.000 nit ở chế độ toàn màn hình, 1.600 nit (chỉ nội dung HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Nano-texture, Liquid Retina XDR, XDR (Extreme Dynamic Range), True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Khe thẻ nhớ SDXC, HDMI, Jack cắm tai nghe 3.5 mm, MagSafe 3, Ba cổng Thunderbolt 5 (USB‑C) hỗ trợ: Sạc, DisplayPort, Thunderbolt 5 (lên đến 120Gb/s), Thunderbolt 4 (lên đến 40Gb/s), USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi‑Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Dài: 22.12 cm x Cao: 1.55 cm x Rộng: 31.26 cm'}, {'name': 'Trọng lượng', 'value': '1.60 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 72.4 watt-giờ, Thời gian xem video trực tuyến lên đến 22 giờ, Thời gian duyệt web trên mạng không dây lên đến 14 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods (thế hệ thứ 3 trở lên)'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M1 8 nhân (4 nhân hiệu năng cao và 4 nhân tiết kiệm điện)'}, {'name': 'Mô tả CPU', 'value': 'Chip Apple M1'}, {'name': 'Tên card đồ họa', 'value': 'GPU tích hợp'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 7 nhân, 16 nhân Neural Engine'}, {'name': 'Bộ xử lý AI / NPU', 'value': '16 nhân Neural Engine'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '256GB SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 pixels (2K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '400 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'Hỗ trợ dải màu P3, True-Tone'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400 nits, Hỗ trợ dải màu P3, True-Tone, Viền màn hình siêu mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 cổng Thunderbolt / USB 4'}, {'name': 'Wi-Fi', 'value': '802.11ax Wi-Fi 6 wireless networking'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.0'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '1.61 cm x 30.41 cm x 21.24 cm'}, {'name': 'Trọng lượng', 'value': '1.29 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '49.9-watt-hour lithium-polymer'}, {'name': 'Sạc nhanh', 'value': 'củ sạc công suất 30W'}, {'name': 'Loại sạc', 'value': 'củ sạc công suất 30W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'N/A'}, {'name': 'Webcam', 'value': '720p FaceTime HD camera'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'Touch ID'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS Big Sur'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip M4 (10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện)'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 8 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 8 lõi, Neural Engine 16 lõi, Công nghệ dò tia tốc độ cao bằng phần cứng, Băng thông bộ nhớ 120GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '256GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1664 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, Có đèn nền LED, Mật độ 224 pixel mỗi inch, Công nghệ True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3.5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ: Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': 'Cao: 1.13 cm x Rộng: 30.41 cm x Dài: 21.5 cm'}, {'name': 'Trọng lượng', 'value': '1.24 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 53.8 watt‑giờ tích hợp, Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh bốn loa, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods, AirPods Pro, và AirPods Max'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện'}, {'name': 'Mô tả CPU', 'value': 'Chip Apple M5 10 lõi'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi Neural Engine 16 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 10 lõi, Neural Engine 16 lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Apple Intelligence'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3024 x 1964 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '1.000 nit (SDR ngoài trời), 1.600 nit (HDR nội dung)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Liquid Retina XDR, True Tone, ProMotion'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-C (Thunderbolt 4 - Sạc / DisplayPort / Thunderbolt 4 / USB 4), HDMI, Khe thẻ nhớ SDXC, Jack cắm tai nghe 3.5 mm, MagSafe 3'}, {'name': 'Wi-Fi', 'value': 'Wi‑Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.55 x 31.26 x 22.12 cm (Cao x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.55 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 72.4 watt-giờ, Thời gian xem video trực tuyến lên đến 24 giờ, Thời gian duyệt web trên mạng không dây lên đến 16 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Dãy ba micrô chất lượng chuẩn studio với tỷ lệ tín hiệu – nhiễu cao'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô chất lượng chuẩn studio với tỷ lệ tín hiệu – nhiễu cao'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch, Cảm biến ánh sáng môi trường'}, {'name': 'Touchpad', 'value': 'Force Touch, hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Viền màn hình siêu mỏng, Bảo mật vân tay'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi siêu xử lý và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Neural Accelerators, Công nghệ dò tia tốc độ cao bằng phần cứng, Neural Engine 16 lõi, Băng thông bộ nhớ 153GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1864 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, có đèn nền LED với công nghệ IPS, Công nghệ True Tone, Hỗ trợ lên đến hai màn hình ngoài'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3,5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 (802.11be)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ lên đến hai màn hình ngoài'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.15 x 34.04 cm x 23.76 cm (Dày x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.51 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 66,5 watt‑giờ tích hợp, Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh bốn loa, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu, Dãy ba micrô phối hợp, Chế độ micrô Tách Lời Nói và Âm Phổ Rộng'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô phối hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Cảm biến ánh sáng môi trường, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Bàn di chuột Force Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Bảo mật vân tay, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi siêu xử lý và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Neural Accelerators, Công nghệ dò tia tốc độ cao bằng phần cứng, Neural Engine 16 lõi, Băng thông bộ nhớ 153GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1664 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, Màn hình có đèn nền LED với công nghệ IPS, Công nghệ True Tone, Hỗ trợ lên đến hai màn hình ngoài'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3,5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 (802.11be)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ lên đến hai màn hình ngoài'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.13 x 30.41 cm x 21.5 cm (Dày x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.23 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 53,8 watt‑giờ tích hợp, Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh bốn loa, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu, Dãy ba micrô phối hợp, Chế độ micrô Tách Lời Nói và Âm Phổ Rộng'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô phối hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Cảm biến ánh sáng môi trường, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Bảo mật vân tay, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện'}, {'name': 'Mô tả CPU', 'value': 'Chip Apple M5 10 lõi'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi Neural Engine 16 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 10 lõi, Neural Engine 16 lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Apple Intelligence'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3024 x 1964 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '1.000 nit (SDR ngoài trời), 1.600 nit (HDR nội dung)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Liquid Retina XDR, True Tone, ProMotion'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-C (Thunderbolt 4 - Sạc / DisplayPort / Thunderbolt 4 / USB 4), HDMI, Khe thẻ nhớ SDXC, Jack cắm tai nghe 3.5 mm, MagSafe 3'}, {'name': 'Wi-Fi', 'value': 'Wi‑Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.55 x 31.26 x 22.12 cm (Cao x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.55 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 72.4 watt-giờ, Thời gian xem video trực tuyến lên đến 24 giờ, Thời gian duyệt web trên mạng không dây lên đến 16 giờ'}, {'name': 'Sạc nhanh', 'value': '96W'}, {'name': 'Loại sạc', 'value': 'Sạc 96W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm thanh stereo rộng'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô chất lượng chuẩn studio với tỷ lệ tín hiệu – nhiễu cao'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch, Cảm biến ánh sáng môi trường'}, {'name': 'Touchpad', 'value': 'Force Touch, hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Viền màn hình siêu mỏng, Wi-Fi 6, Bảo mật vân tay'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5 Pro'}, {'name': 'Mô tả CPU', 'value': 'CPU 18 lõi với 6 lõi siêu xử lý và 12 lõi hiệu năng'}, {'name': 'Tên card đồ họa', 'value': 'GPU 20 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Neural Accelerators, Công nghệ dò tia tốc độ cao bằng phần cứng, Neural Engine 16 lõi, Băng thông bộ nhớ 307GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '48GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3456 x 2234 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Liquid Retina XDR'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'XDR: 1.000 nit (tối đa 1.600 nit cho nội dung HDR), SDR: lên đến 1.000 nit (ngoài trời)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'True Tone, ProMotion'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Khe thẻ nhớ SDXC, HDMI, Jack cắm tai nghe 3.5 mm, Cổng MagSafe 3, Ba cổng Thunderbolt 5 (USB-C) hỗ trợ: Sạc / DisplayPort / Thunderbolt 5 (lên đến 120Gb/s) / USB 4 (lên đến 120Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 (802.11be)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.68 x 35.57 x 24.81 cm (Cao x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '2.14 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 100 watt-giờ, Thời gian xem video trực tuyến lên đến 24 giờ, Thời gian duyệt web trên mạng không dây lên đến 17 giờ'}, {'name': 'Sạc nhanh', 'value': '140W'}, {'name': 'Loại sạc', 'value': 'Sạc 140W'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Hỗ trợ Âm Thanh Không Gian'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô chất lượng chuẩn studio, Chế độ micrô Tách Lời Nói và Âm Phổ Rộng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Cảm biến ánh sáng môi trường, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Force Touch, hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M4 Max 16 lõi với 12 lõi hiệu năng và 4 lõi tiết kiệm điện'}, {'name': 'Mô tả CPU', 'value': 'Apple M4 Max 16 lõi'}, {'name': 'Tên card đồ họa', 'value': '40 lõi Neural Engine 16 lõi'}, {'name': 'Mô tả card đồ họa', 'value': '40 lõi Neural Engine 16 lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '48GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3456 x 2234 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Liquid Retina XDR XDR (Extreme Dynamic Range)'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': '1.000 nit ở chế độ toàn màn hình, 1.600 nit (chỉ nội dung HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'True Tone, Hỗ trợ tối đa bốn màn hình ngoài'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Khe thẻ nhớ SDXC, HDMI, Jack cắm tai nghe 3.5 mm, MagSafe 3, Ba cổng Thunderbolt 5 (USB‑C) hỗ trợ: Sạc, DisplayPort, Thunderbolt 5 (lên đến 120Gb/s), Thunderbolt 4 (lên đến 40Gb/s), USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi‑Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ tối đa bốn màn hình ngoài'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Dài: 24.81 cm x Rộng: 35.57 cm x Cao: 1.68 cm'}, {'name': 'Trọng lượng', 'value': '2.15 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 100 watt-giờ, Thời gian xem video trực tuyến lên đến 21 giờ, Thời gian duyệt web trên mạng không dây lên đến 14 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods (thế hệ thứ 3 trở lên)'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5 Pro'}, {'name': 'Mô tả CPU', 'value': 'CPU 18 lõi với 6 lõi siêu xử lý và 12 lõi hiệu năng'}, {'name': 'Tên card đồ họa', 'value': 'GPU 20 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Neural Accelerators, Công nghệ dò tia tốc độ cao bằng phần cứng, Neural Engine 16 lõi, Băng thông bộ nhớ 307GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3456 x 2234 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'XDR: 1.000 nit (HDR), SDR: lên đến 1.000 nit (ngoài trời)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Liquid Retina XDR, True Tone, ProMotion'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Khe thẻ nhớ SDXC, HDMI, Jack cắm tai nghe 3.5 mm, Cổng MagSafe 3, Ba cổng Thunderbolt 5 (USB-C) hỗ trợ: Sạc / DisplayPort / Thunderbolt 5 (lên đến 120Gb/s) / USB 4 (lên đến 120Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 (802.11be)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.68 x 35.57 x 24.81 cm (Cao x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '2.14 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 100 watt-giờ, Thời gian xem video trực tuyến lên đến 24 giờ, Thời gian duyệt web trên mạng không dây lên đến 17 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Hỗ trợ Âm Thanh Không Gian'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô chất lượng chuẩn studio, Chế độ micrô Tách Lời Nói và Âm Phổ Rộng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Cảm biến ánh sáng môi trường, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Force Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Bảo mật vân tay, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5 Pro'}, {'name': 'Mô tả CPU', 'value': 'CPU 15 lõi với 5 lõi siêu xử lý và 10 lõi hiệu năng'}, {'name': 'Tên card đồ họa', 'value': 'GPU 16 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Neural Accelerators, Công nghệ dò tia tốc độ cao bằng phần cứng, Neural Engine 16 lõi, Băng thông bộ nhớ 307GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '2TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3024 x 1964 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '1.000 nit (SDR), tối đa 1.600 nit (HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Liquid Retina XDR, True Tone, ProMotion'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Khe thẻ nhớ SDXC, HDMI, Jack cắm tai nghe 3.5 mm, Cổng MagSafe 3, Ba cổng Thunderbolt 5 (USB-C) hỗ trợ: Sạc / DisplayPort / Thunderbolt 5 (lên đến 120Gb/s) / USB 4 (lên đến 120Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 (802.11be)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.55 x 31.26 x 22.12 cm (Cao x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.60 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 72,4 watt-giờ, Thời gian xem video trực tuyến lên đến 22 giờ, Thời gian duyệt web trên mạng không dây lên đến 14 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Hỗ trợ Âm Thanh Không Gian'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô chất lượng chuẩn studio, Chế độ micrô Tách Lời Nói và Âm Phổ Rộng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Cảm biến ánh sáng môi trường, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Force Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Bảo mật vân tay, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip M4 (10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện)'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 10 lõi, Neural Engine 16 lõi, Công nghệ dò tia tốc độ cao bằng phần cứng, Băng thông bộ nhớ 120GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '256GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1864 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, Có đèn nền LED, Mật độ 224 pixel mỗi inch, Công nghệ True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3.5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ: Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': 'Cao: 1.15 cm x Rộng: 34.04 cm x Dài: 23.76 cm'}, {'name': 'Trọng lượng', 'value': '1.51 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ, Pin Li-Po 66.5 watt‑giờ tích hợp'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa với loa trầm khử lực, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu chủ động khi sử dụng AirPods, AirPods Pro, AirPods Max'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, Bảo mật vân tay'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi siêu xử lý và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Neural Accelerators, Công nghệ dò tia tốc độ cao bằng phần cứng, Neural Engine 16 lõi, Băng thông bộ nhớ 153GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1864 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, có đèn nền LED với công nghệ IPS, Công nghệ True Tone, Hỗ trợ lên đến hai màn hình ngoài'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3,5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 (802.11be)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ lên đến hai màn hình ngoài'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.15 x 34.04 cm x 23.76 cm (Dày x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.51 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 66,5 watt‑giờ tích hợp, Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh bốn loa, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu, Dãy ba micrô phối hợp, Chế độ micrô Tách Lời Nói và Âm Phổ Rộng'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô phối hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Cảm biến ánh sáng môi trường, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Bảo mật vân tay, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5 10 lõi với 4 lõi hiệu năng và 6 lõi tiết kiệm điện'}, {'name': 'Mô tả CPU', 'value': 'Chip Apple M5 10 lõi'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi Neural Engine 16 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'GPU 10 lõi, Neural Engine 16 lõi'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Apple Intelligence'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3024 x 1964 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '1000 nit (SDR), 1600 nit (HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Liquid Retina XDR, True Tone, ProMotion'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-C (Thunderbolt 4 - Sạc / DisplayPort / Thunderbolt 4 / USB 4), HDMI, Khe thẻ nhớ SDXC, Jack cắm tai nghe 3.5 mm, MagSafe 3'}, {'name': 'Wi-Fi', 'value': 'Wi‑Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.55 x 31.26 x 22.12 cm (Cao x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.55 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 72.4 watt-giờ, Thời gian xem video trực tuyến lên đến 24 giờ, Thời gian duyệt web trên mạng không dây lên đến 16 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô chất lượng chuẩn studio với tỷ lệ tín hiệu – nhiễu cao'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch, Cảm biến ánh sáng môi trường'}, {'name': 'Touchpad', 'value': 'Force Touch, hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Viền màn hình siêu mỏng, Wi-Fi 6, Bảo mật vân tay'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi siêu xử lý và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Neural Accelerators, Công nghệ dò tia tốc độ cao bằng phần cứng, Neural Engine 16 lõi, Băng thông bộ nhớ 153GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1864 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, có đèn nền LED với công nghệ IPS, Công nghệ True Tone, Hỗ trợ lên đến hai màn hình ngoài'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3,5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 (802.11be)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ lên đến hai màn hình ngoài'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.15 x 34.04 cm x 23.76 cm (Dày x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.51 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 66,5 watt‑giờ tích hợp, Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'MagSafe 3'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh bốn loa, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu, Dãy ba micrô phối hợp, Chế độ micrô Tách Lời Nói và Âm Phổ Rộng'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô phối hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Cảm biến ánh sáng môi trường, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Bảo mật vân tay, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Chip Apple M5'}, {'name': 'Mô tả CPU', 'value': 'CPU 10 lõi với 4 lõi siêu xử lý và 6 lõi tiết kiệm điện'}, {'name': 'Tên card đồ họa', 'value': 'GPU 10 lõi'}, {'name': 'Mô tả card đồ họa', 'value': 'Neural Accelerators, Công nghệ dò tia tốc độ cao bằng phần cứng, Neural Engine 16 lõi, Băng thông bộ nhớ 153GB/s'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 lõi'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1864 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': '500 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình Liquid Retina, có đèn nền LED với công nghệ IPS, Công nghệ True Tone, Hỗ trợ lên đến hai màn hình ngoài'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Cổng sạc MagSafe 3, Jack cắm tai nghe 3,5 mm, Hai cổng Thunderbolt 4 (USB-C) hỗ trợ Sạc / DisplayPort / Thunderbolt 4 (lên đến 40Gb/s) / USB 4 (lên đến 40Gb/s)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 (802.11be)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Hỗ trợ lên đến hai màn hình ngoài'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '1.15 x 34.04 cm x 23.76 cm (Dày x Rộng x Dài)'}, {'name': 'Trọng lượng', 'value': '1.51 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 66,5 watt‑giờ tích hợp, Thời gian xem video trực tuyến lên đến 18 giờ, Thời gian duyệt web trên mạng không dây lên đến 15 giờ'}, {'name': 'Sạc nhanh', 'value': 'Sạc 70W'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh bốn loa, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos trên loa tích hợp, Âm Thanh Không Gian với khả năng theo dõi chuyển động đầu, Dãy ba micrô phối hợp, Chế độ micrô Tách Lời Nói và Âm Phổ Rộng'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage có hỗ trợ chế độ Desk View, Quay video HD 1080p, Bộ xử lý tín hiệu hình ảnh tiên tiến với video điện toán'}, {'name': 'Micro', 'value': 'Dãy ba micrô phối hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím Magic Keyboard có đèn nền, Cảm biến ánh sáng môi trường, Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Touchpad', 'value': 'Bàn di chuột Force Touch để điều khiển con trỏ chính xác và cảm ứng lực; hỗ trợ Bấm Mạnh, bộ tăng tốc, vẽ cảm ứng lực, và các thao tác Multi‑Touch'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Bảo mật vân tay, Wi-Fi 7'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'N/A'}, {'name': 'Mô tả CPU', 'value': 'N/A'}, {'name': 'Tên card đồ họa', 'value': 'N/A'}, {'name': 'Mô tả card đồ họa', 'value': 'N/A'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': 'N/A'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': 'N/A'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '27 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '5120 x 2880 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Retina'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '600 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Hỗ trợ một tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Retina, True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x Thunderbolt 5 (120Gb/s), 1 cổng ngược dòng dành cho thiết bị chính (96W), 1 cổng xuôi dòng để kết nối phụ kiện tốc độ cao hoặc kết nối chuỗi các màn hình khác, 2x USB-C (10Gb/s)'}, {'name': 'Wi-Fi', 'value': 'N/A'}, {'name': 'Bluetooth', 'value': 'N/A'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Kết nối chuỗi các màn hình khác)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Studio Display với chân đế có thể điều chỉnh độ nghiêng: 47.9 x 62.3 x 20.7 cm (Cao x Rộng x Dày); Studio Display với ngàm kết nối VESA: 36.2 x 62.3 x 3.1 cm (Cao x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': 'Studio Display với chân đế có thể điều chỉnh độ nghiêng: 6.3 kg; Studio Display với ngàm kết nối VESA: 5.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'N/A'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos, Ba micrô chuẩn studio kết hợp, Hỗ trợ “Hey Siri”'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage cùng chế độ Desk View'}, {'name': 'Micro', 'value': 'Ba micrô chuẩn studio'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'N/A'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Chính hãng Apple Việt Nam'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Premium (>60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'N/A'}, {'name': 'Mô tả CPU', 'value': 'N/A'}, {'name': 'Tên card đồ họa', 'value': 'N/A'}, {'name': 'Mô tả card đồ họa', 'value': 'N/A'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': 'N/A'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': 'N/A'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '27 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '5120 x 2880 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Retina'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '600 nit'}, {'name': 'Độ phủ màu màn hình', 'value': 'Hỗ trợ một tỷ màu, Dải màu rộng (P3)'}, {'name': 'Công nghệ màn hình', 'value': 'Retina, True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x Thunderbolt 5 (120Gb/s), 1 cổng ngược dòng dành cho thiết bị chính (96W), 1 cổng xuôi dòng để kết nối phụ kiện tốc độ cao hoặc kết nối chuỗi các màn hình khác, 2x USB-C (10Gb/s)'}, {'name': 'Wi-Fi', 'value': 'N/A'}, {'name': 'Bluetooth', 'value': 'N/A'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Kết nối chuỗi các màn hình khác)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Studio Display với chân đế có thể điều chỉnh độ nghiêng: 47.9 x 62.3 x 20.7 cm (Cao x Rộng x Dày); Studio Display với ngàm kết nối VESA: 36.2 x 62.3 x 3.1 cm (Cao x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': 'Studio Display với chân đế có thể điều chỉnh độ nghiêng: 6.3 kg; Studio Display với ngàm kết nối VESA: 5.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'N/A'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos, Ba micrô chuẩn studio kết hợp, Hỗ trợ “Hey Siri”'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage cùng chế độ Desk View'}, {'name': 'Micro', 'value': 'Ba micrô chuẩn studio'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'N/A'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Chính hãng Apple Việt Nam'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Premium (>60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M3 Max 14 nhân'}, {'name': 'Mô tả CPU', 'value': 'Apple M3 Max 14 nhân'}, {'name': 'Tên card đồ họa', 'value': 'Apple M3 Max (Tích hợp)'}, {'name': 'Mô tả card đồ họa', 'value': '30 nhân Neural Engine, Neural Engine 16 nhân'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Neural Engine 16 nhân'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '36GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3024 x 1964 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': 'Độ sáng XDR: 1000 nit liên tục ở chế độ toàn màn hình, Độ sáng đỉnh 1600 nit (chỉ nội dung HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'XDR, True Tone, ProMotion'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Thunderbolt 4 (USB-C) x3, HDMI, Khe thẻ nhớ SDXC, Jack 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Cao: 1,68 cm Rộng: 35,57 cm Dài: 24,81 cm'}, {'name': 'Trọng lượng', 'value': '2,16 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'Pin Li-Po 72,4 watt-giờ'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh stereo rộng, Dolby Atmos'}, {'name': 'Webcam', 'value': 'HD 1080p'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Có'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'macOS'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Apple M3 Pro 12 nhân'}, {'name': 'Mô tả CPU', 'value': 'Chip Apple M3 Pro 12 nhân'}, {'name': 'Tên card đồ họa', 'value': 'Apple M3 Pro'}, {'name': 'Mô tả card đồ họa', 'value': '18 nhân Neural Engine 16 nhân'}, {'name': 'Bộ xử lý AI / NPU', 'value': '18 nhân Neural Engine 16 nhân'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '18GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '1TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14.2 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3024 x 1964 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'N/A'}, {'name': 'Tần số quét', 'value': '120Hz'}, {'name': 'Độ sáng màn hình', 'value': 'Độ sáng XDR: 1000 nit liên tục ở chế độ toàn màn hình, Độ sáng đỉnh 1600 nit (chỉ nội dung HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': 'True Tone'}, {'name': 'Công nghệ màn hình', 'value': 'XDR, ProMotion'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Hai cổng Thunderbolt / USB 4 (USB-C), Ba cổng Thunderbolt 4 (USB-C), Cổng HDMI, Khe thẻ nhớ SDXC, Jack 3.5mm'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Cao 1,55 - Rộng 31,26 - Dài 22,12 cm'}, {'name': 'Trọng lượng', 'value': '1,55 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '72.4Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Âm thanh stereo rộng, Dolby Atmos'}, {'name': 'Webcam', 'value': 'HD 1080p'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Có'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Touch ID'}, {'name': 'Hệ điều hành', 'value': 'N/A'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'N/A'}, {'name': 'Mô tả CPU', 'value': 'N/A'}, {'name': 'Tên card đồ họa', 'value': 'N/A'}, {'name': 'Mô tả card đồ họa', 'value': 'N/A'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': 'N/A'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': 'N/A'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '27 inch'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '5K'}, {'name': 'Chất liệu tấm nền', 'value': 'Nano'}, {'name': 'Tần số quét', 'value': 'N/A'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Ngàm VESA'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'VESA'}, {'name': 'Wi-Fi', 'value': 'N/A'}, {'name': 'Bluetooth', 'value': 'N/A'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'N/A'}, {'name': 'Trọng lượng', 'value': 'N/A'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'N/A'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'N/A'}, {'name': 'Webcam', 'value': 'N/A'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'N/A'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Chính hãng Apple Việt Nam'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'N/A'}, {'name': 'Mô tả CPU', 'value': 'N/A'}, {'name': 'Tên card đồ họa', 'value': 'N/A'}, {'name': 'Mô tả card đồ họa', 'value': 'N/A'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': 'N/A'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'N/A'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': 'N/A'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '27 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '5120 x 2880 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Mini Led'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '1000 nit (SDR), 2000 nit (HDR)'}, {'name': 'Độ phủ màu màn hình', 'value': '1 tỷ màu, Dải màu rộng P3 + Adobe RGB'}, {'name': 'Công nghệ màn hình', 'value': 'Retina XDR 5K, Đèn nền mini-LED với 2304 vùng làm tối, True Tone'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x Thunderbolt 5 (120Gb/s), 1 cổng ngược dòng dành cho thiết bị chính (140W), 1 cổng xuôi dòng để kết nối phụ kiện tốc độ cao hoặc kết nối chuỗi các màn hình khác với nhau, 2x USB-C (10Gb/s)'}, {'name': 'Wi-Fi', 'value': 'N/A'}, {'name': 'Bluetooth', 'value': 'N/A'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Có (Kết nối chuỗi màn hình khác)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': 'Studio Display XDR với chân đế có thể điều chỉnh độ nghiêng và độ cao: 47.8 x 62.3 x 21.4 cm (Cao x Rộng x Dày); Studio Display XDR với ngàm kết nối VESA: 36.2 x 62.3 x 3.3 cm (Cao x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': 'Studio Display XDR với chân đế có thể điều chỉnh độ nghiêng và độ cao: 8.5 kg; Studio Display XDR với ngàm kết nối VESA: 6.3 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': 'N/A'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hệ thống âm thanh sáu loa có độ trung thực cao với loa trầm khử lực, Âm thanh stereo rộng, Hỗ trợ Âm Thanh Không Gian khi phát nhạc hoặc video với Dolby Atmos'}, {'name': 'Webcam', 'value': 'Camera 12MP Center Stage cùng chế độ Desk View'}, {'name': 'Micro', 'value': 'Dãy ba micrô chất lượng chuẩn studio'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'N/A'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Chính hãng Apple Việt Nam'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 3050, Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB*1 Max 4TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Type-C (USB3.2 Gen1 / DisplayPort), 3x Type-A USB3.2 Gen1, 1x HDMI (4K @ 30Hz)'}, {'name': 'Wi-Fi', 'value': 'AMD RZ616 Wi-Fi 6E'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359 x 254 x 21.7 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.86 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3CELLS/3S1P'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Sẵn sàng cho âm thanh độ phân giải cao, Xử lý âm thanh DTS'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím đơn có đèn nền (Màu xanh)'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mô-đun nền tảng tin cậy phần mềm (fTPM) 2.0, Khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H (8 lõi) - Max Turbo Frequency: 4.60 GHz'}, {'name': 'Mô tả CPU', 'value': '8 lõi, Max Turbo Frequency: 4.60 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050'}, {'name': 'Mô tả card đồ họa', 'value': 'Hỗ trợ AI tiên tiến'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Hỗ trợ AI tiên tiến (thông qua RTX 5050)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB'}, {'name': 'Ổ cứng', 'value': '512GB NVMe SSD PCIe Gen4 - Max 4TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB-C (USB 3.2 Gen 2 / DisplayPort / Power Delivery 3.0), 2x USB-A (USB 3.2 Gen 2), 1x HDMI 2.1 (4K @ 60Hz)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'HDMI 2.1 (hỗ trợ xuất hình)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.3 x 245.25 x 22.15 - 23.15 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4-Cell'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-Res Audio Ready, DTS Audio Processing'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p) với chức năng Giảm nhiễu 3D (3DNR)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím chơi game RGB 4 vùng với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware Trusted Platform Module(fTPM) 2.0, Webcam Shutter, Kensington Lock'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H Gen 13th (10 lõi / 16 luồng, 24MB Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H Gen 13th (10 lõi / 16 luồng, 24MB Cache)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 4GB'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 4GB, Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB NVMe PCIe Gen4 (Max 4TB)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'Type-C (USB3.2 Gen1 / DisplayPort), 2 x Type-A USB 3.2 Gen 1, 1x HDMI 2.1 (4K @ 60Hz), Type-A USB 3.2 Gen 2'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.36 x 250.34 x 21.95 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.98 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cells 53.5 Whrs'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Single Backlit Keyboard (Blue)'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Kensington Lock'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 lõi) - Max Turbo Frequency: 4.90 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 10 lõi, Max Turbo Frequency: 4.90 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050'}, {'name': 'Mô tả card đồ họa', 'value': '6GB of GDDR6 SDRAM, Bus Width: 96-bit, Intel UHD Graphics (tích hợp)'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200Hz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '1TB NVMe PCIe SSD Gen4x4 w/o DRAM'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB 2.0 Type-A, 2 x USB 3.2 Gen 1 Type-A, 1 x USB 3.2 Gen 1 Type-C (hỗ trợ DisplayPort), 1 x HDMI, 1 x RJ45 (LAN), 1 x Jack tai nghe / micro combo'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.9 x 25.9 x 2.49 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.3 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (53.5Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Webcam HD với hệ thống micro tích hợp'}, {'name': 'Micro', 'value': 'Tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng, chống tràn, phím chức năng đa phương tiện (Fn), bàn phím có đèn nền RGB 4 vùng, bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu người dùng, fTPM 2.0, Khởi động an toàn (Secure Boot)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-1335U (Up to 4.6GHz, 10 lõi, 12 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-1335U, 10 lõi, 12 luồng, xung nhịp lên đến 4.6GHz'}, {'name': 'Tên card đồ họa', 'value': 'Intel Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD NVMe PCIe Gen4'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 250 nits, Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '3 x USB 3.2 Gen1 Type-A, 1 x Type-C (USB 3.2 Gen2 / DisplayPort / Power Delivery 3.0), 1 x HDMI (4K @ 30Hz), 1 x Đầu đọc thẻ Micro SD, 1 x Jack cắm kết hợp Mic/Tai nghe'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '32.39 x 21.72 x 1.99 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.5 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (46.8Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'WebCam HD (màn trập riêng tư) với micro mảng'}, {'name': 'Micro', 'value': 'Micro mảng (tích hợp webcam)'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ, 6 hàng, phím Fn đa phương tiện, bàn phím có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Dấu vân tay, Mật khẩu quản trị viên, Mật khẩu người dùng, TPM, Khởi động an toàn'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, Bảo mật vân tay'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5 - 1334U (10 lõi / 12 luồng, 1.3GHz, Turbo Boost 4.6 GHz)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5 - 1334U (10 lõi / 12 luồng, 1.3GHz, Turbo Boost 4.6 GHz)'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '8GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 8 GB, nâng cấp tối đa 64 GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64 GB'}, {'name': 'Ổ cứng', 'value': '512 GB SSD NVMe PCIe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '3 x USB 3.2, HDMI, LAN (RJ45), 1 x USB Type-C 3.2 (hỗ trợ Power Delivery và DisplayPort), Khe đọc thẻ nhớ'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '323.9 x 217.2 x 19.9 mm'}, {'name': 'Trọng lượng', 'value': '1.5 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 46.8 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-Res Audio'}, {'name': 'Webcam', 'value': 'HD webcam'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đơn sắc - Màu trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 lõi (6 P-cores + 4 E-cores), Max Turbo Frequency 4.9 GHz)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H (2.4GHz,10 lõi (6 P-cores + 4 E-cores), Max Turbo Frequency 4.9 GHz)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB, Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2x 8GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x Type-A USB3.2 Gen1, 1 x Type-A USB2.0, 1x HDMI 2.1 (8K @ 60Hz / 4K @ 120Hz)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359 x 259 x 24.9 mm (Dài x Rộng x Cao)'}, {'name': 'Trọng lượng', 'value': '2.25 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-Cell'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím chơi game RGB 4 vùng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware Trusted Platform Module(fTPM) 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 lõi) - Max Turbo Frequency: 4.90 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 10 lõi, Max Turbo Frequency 4.90 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 (6GB of GDDR6 SDRAM, Bus Width: 96- bit) và Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời NVIDIA GeForce RTX 3050 với 6GB GDDR6 SDRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (Hiện đang 1x16GB, còn 1 khe trống)'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1 x, USB-C: 1 x (hỗ trợ DisplayPort), Thunderbolt: N/A, HDMI: 1 x, LAN: 1 x (RJ45), SD: N/A, 3.5mm: 1 x (Giắc cắm âm thanh kết hợp tai nghe/micrô)'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.9 x 25.9 x 2.49 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.304 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell Int (53.5Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'WebCam HD với micro mảng'}, {'name': 'Micro', 'value': 'Micro mảng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng, chống tràn, phím Fn đa phương tiện, bàn phím có đèn nền RGB 4 vùng, bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu người dùng, fTPM 2.0, Khởi động an toàn'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5 - 1334U (10 lõi / 12 luồng, 1.3GHz, Turbo Boost 4.6 GHz)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5 - 1334U (10 lõi / 12 luồng, 1.3GHz, Turbo Boost 4.6 GHz)'}, {'name': 'Tên card đồ họa', 'value': 'Intel Iris Xe Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp Intel Iris Xe Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 khe 8 GB + 1 khe 16 GB, nâng cấp tối đa 64 GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64 GB'}, {'name': 'Ổ cứng', 'value': '512 GB SSD NVMe PCIe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '250 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '3 x USB 3.2, HDMI, LAN (RJ45), 1 x USB Type-C 3.2 (hỗ trợ Power Delivery và DisplayPort), Khe đọc thẻ nhớ'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '323.9 x 217.2 x 19.9 mm'}, {'name': 'Trọng lượng', 'value': '1.5 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 46.8 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-Res Audio'}, {'name': 'Webcam', 'value': 'HD webcam'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đơn sắc - Màu trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SL'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 5 125H'}, {'name': 'Mô tả CPU', 'value': 'Intel Core Ultra 5 125H'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Có (Ngụ ý từ Intel Core Ultra)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2x8GB DDR5-5600MHz, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB'}, {'name': 'Ổ cứng', 'value': '512GB NVMe SSD PCIe Gen4 Hỗ trợ nâng cấp: 1x M.2 SSD slot (NVMe PCIe Gen4)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 100% DCI-P3, Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Type-C (USB3.2 Gen1 / DisplayPort), 2x Type-A USB3.2 Gen1, 1x Type-A USB2.0, 1x HDMI (4K @ 30Hz), 1x RJ45, 1x Mic-in/Headphone-out Combo Jack'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '315.6 x 235.5 x 19.3-21.6 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.7kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4-cell, 55.2WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-Res Audio Ready, DTS Audio Processing'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím đơn có đèn nền (Trắng) với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mô-đun nền tảng tin cậy phần mềm (fTPM) 2.0, Màn trập webcam, Khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 255HX, 20 lõi (8 P-cores + 12 E-cores), 20 luồng, 36MB cache, Max Turbo Frequency 5.2 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core Ultra 7 255HX với Intel AI Boost (NPU)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5070 Ti Laptop GPU'}, {'name': 'Mô tả card đồ họa', 'value': 'GDDR7 12GB, Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost (NPU)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2x 8GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB*1 (1x M.2 SSD slot (NVMe PCIe Gen4), 1x M.2 SSD slot (NVMe PCIe Gen5) Compatible)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 pixels (2.5K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '240 Hz'}, {'name': 'Độ sáng màn hình', 'value': '500 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, G to G 3ms, Độ phủ màu 100% DCI-P3'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x Thunderbolt 5 (DisplayPort/ Power Delivery 3.1), 2x Type-A USB3.2 Gen2, 1x Đầu đọc thẻ SD Express, 1x HDMI 2.1 (8K @ 60Hz / 4K @ 120Hz), 1x RJ45, 1x SD Express'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2x Thunderbolt 5 hỗ trợ DisplayPort'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '357 x 284 x 22.20-28.55 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.7 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4-Cell 90 Whrs (Whr)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready'}, {'name': 'Webcam', 'value': 'Loại IR FHD (30fps@1080p) với HDR; Giảm nhiễu 3D+ (3DNR+)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím chơi game RGB 24 vùng với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Màn trập webcam, Khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 258V (8 lõi) - Max Turbo Frequency: 4.80 GHz'}, {'name': 'Mô tả CPU', 'value': '8 lõi'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc 140V GPU'}, {'name': 'Mô tả card đồ họa', 'value': '16GB VRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost 47 TOP'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-8533'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không'}, {'name': 'Ổ cứng', 'value': '1TB SSD1 PCIe (M.2 2280) - nâng cấp tối đa 8TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '120 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3 (typical)'}, {'name': 'Công nghệ màn hình', 'value': 'Low Blue Light & Flicker-free chứng nhận bởi SGS'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x Thunderbolt 4 (Power Delivery, DisplayPort), 1 x USB-A (USB 3.2 Gen 2), 1 x HDMI, 1 x RJ45 (LAN), 1 x Jack tai nghe/micro 3,5mm, 1 x Khe SSD PCIe M.2 2280'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 802.11 be'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2 x Thunderbolt 4 hỗ trợ DisplayPort'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Kim loại'}, {'name': 'Kích thước', 'value': '313.4 x 246.5 x 189.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.7 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell Int (90Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-Res Audio Ready, DTS Audio Processing'}, {'name': 'Webcam', 'value': 'Webcam hồng ngoại 5MP (có màn che riêng tư) với hệ thống micro tích hợp'}, {'name': 'Micro', 'value': 'Micro tích hợp'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím có đèn nền'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay, Nhận diện khuôn mặt, Secure Boot, Bảo mật thiết bị lưu trữ TCG, Khe khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'Wi-Fi 6, Bảo mật vân tay, Nhận diện khuôn mặt, Màn hình Oled'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H (8 lõi) - Max Turbo Frequency: 4.60 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H, 8 lõi, Max Turbo Frequency: 4.60 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 4GB'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời NVIDIA GeForce RTX 3050 với 4GB VRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB NVMe SSD PCIe Gen4, Max 4TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB-C (USB 3.2 Gen 1 / DisplayPort), 2x USB-A (USB 3.2 Gen 1), 1x HDMI 2.1 (4K @ 60Hz)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.36 x 250.34 x 21.95 - 22.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.98 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-Cell'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Single Backlit Keyboard (Blue)'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Kensington Lock'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5 14450HX'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5 14450HX'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050'}, {'name': 'Mô tả card đồ họa', 'value': 'Hỗ trợ AI tiên tiến, có thể có VRAM tùy thuộc vào cấu hình cụ thể của RTX 5050'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Hỗ trợ AI tiên tiến (thông qua RTX 5050)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB'}, {'name': 'Ổ cứng', 'value': '512GB SSD, hỗ trợ tối đa 4TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1440 pixels (2K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits, Độ phủ màu 100% DCI-P3'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x HDMI 2.1 (8K @ 60Hz / 4K @ 120Hz), 1 x Type-C (USB3.2 Gen2 / DisplayPort/ Power Delivery 3.0), 3 x Type-A USB3.2 Gen2'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'Thông qua cổng Type-C (DisplayPort)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359 x 262 x 25.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 cell 75 Whrs'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím chơi game RGB 4 vùng với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware Trusted Platform Module(fTPM) 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7 14700HX'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7 14700HX'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 4050 6GB GDDR6, Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5600MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2x 8GB, Hỗ trợ nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB M.2-2280 SSD slot (NVMe PCIe Gen4x4) (1x M.2 SSD slot (NVMe PCIe Gen5))'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits, Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Type-C (USB3.2 Gen2 / DP) tích hợp sạc PD, 3x Type-A USB3.2 Gen1, 1x HDMI 2.1 (8K @ 60Hz / 4K @ 120Hz), 1x RJ45, 1x Mic-in/Headphone-out Combo'}, {'name': 'Wi-Fi', 'value': '802.11 ax Wi-Fi 6EGigabit Ethernet'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359 x 266.4 x 21.8 - 27.7 mm'}, {'name': 'Trọng lượng', 'value': '2.3 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4-cell, 65WHr'}, {'name': 'Sạc nhanh', 'value': 'PD (qua cổng Type-C)'}, {'name': 'Loại sạc', 'value': 'Type-C (sạc PD tích hợp)'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready'}, {'name': 'Webcam', 'value': 'HD (30fps@720p), Lọc nhiễu 3D (3DNR)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím chơi game RGB 24 vùng có phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware Trusted Platform Module (fTPM) 2.0, Webcam Shutter, Khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 lõi) - Max Turbo Frequency: 4.90 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 10 lõi, Max Turbo Frequency 4.90 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 với 572 AI TOPS, đi kèm Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': '572 AI TOPS (từ RTX 5060)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB NVMe SSD PCIe Gen4, tối đa 4TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB-C (USB 3.2 Gen 2, DisplayPort, Power Delivery 3.0), 2 x USB-A (USB 3.2 Gen 2), 1 x HDMI 2.1 (4K/60Hz)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.3 x 245.25 x 22.15 - 23.15 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4-Cell'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-Res Audio Ready, DTS Audio Processing'}, {'name': 'Webcam', 'value': 'Độ phân giải HD (30 khung hình/giây ở độ phân giải 720p) với tính năng giảm nhiễu 3D (3DNR)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím chơi game RGB 4 vùng với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'fTPM 2.0 (Firmware Trusted Platform Module), Nắp che webcam, Khe khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-14650HX ( 2.2 GHz - 5.2 GHz / 30MB / 16 nhân, 24 luồng )'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-14650HX, 16 nhân, 24 luồng'}, {'name': 'Tên card đồ họa', 'value': 'GeForce RTX 5050 8GB GDDR7'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời, 8GB GDDR7'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5600MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 16GB / Hỗ trợ tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD M.2 NVMe (1 x M.2 NVMe)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1440 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB Type C / DisplayPort / Power Delivery, 3 x USB 3.2, Audio combo, 1 x HDMI, 1 x LAN 1 Gb/s'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Vỏ nhựa'}, {'name': 'Kích thước', 'value': '359 x 262 x 25.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 cell 75 Wh , Pin liền'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'N/A'}, {'name': 'Webcam', 'value': 'HD webcam'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': '24-Zone RGB Gaming Keyboard with Copilot Key, có phím số, đèn RGB 4 vùng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 lõi) - Max Turbo Frequency: 4.90 GHz'}, {'name': 'Mô tả CPU', 'value': '10 lõi, Max Turbo Frequency: 4.90 GHz'}, {'name': 'Tên card đồ họa', 'value': 'GPU NVIDIA GeForce RTX 4050'}, {'name': 'Mô tả card đồ họa', 'value': 'Hỗ trợ AI tiên tiến với 194 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': '194 AI TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB NVMe SSD PCIe Gen4 - Max 4TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB-C (USB 3.2 Gen 1 / DisplayPort), 2x USB-A (USB 3.2 Gen 1), 1x HDMI 2.1 (4K @ 60Hz)'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359.36 x 250.34 x 21.95 - 22.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.98 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-Cell'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': '4-Zone RGB Gaming Keyboard'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Kensington Lock'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H, 10 lõi (6 P-cores + 4 E-cores), 16 luồng, Max Turbo Frequency 4.9 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H, 10 lõi (6 P-cores + 4 E-cores), 16 luồng, 24 MB Intel Smart Cache'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050'}, {'name': 'Mô tả card đồ họa', 'value': 'GDDR6 6GB, 194 AI TOPS, Intel UHD Graphics (tích hợp)'}, {'name': 'Bộ xử lý AI / NPU', 'value': '194 AI TOPS (trong RTX 4050)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2x 8GB, Hỗ trợ nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '1TB SSD NVMe PCIe Gen4, 2x M.2 SSD slot (NVMe PCIe Gen4)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB-C (USB 3.2 Gen 1, DisplayPort), 2 x USB 3.2 Gen 1 Type-A, 1 x USB 2.0 Type-A, 1 x HDMI 2.1 (8K@60Hz / 4K@120Hz), 1 x RJ45, 1 x Jack mic/tai nghe 3.5 mm'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359 x 259 x 24.9 mm'}, {'name': 'Trọng lượng', 'value': '2.25 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 53.5WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': '4-Zone RGB Gaming Keyboard'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware Trusted Platform Module (fTPM) 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 7 155H 16 lõi (6 P-cores + 8 E-cores + 2 Low Power E-cores), Max Turbo Frequency 4.8 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 6GB'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600 2800(5600)MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, Tối đa 32GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 32GB'}, {'name': 'Ổ cứng', 'value': '1TB NVMe SSD PCIe Gen4'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '100%sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x RJ45, 1x Type-C (USB3.2 Gen 2 / DisplayPort/ Power Delivery 3.1), 1x Type-A USB3.2 Gen 2, 1x HDMI 2.1 (8K @ 60Hz / 4K @ 120Hz), 1x Mic-in/Headphone-out Combo Jack'}, {'name': 'Wi-Fi', 'value': 'Intel Killer Wi-Fi 7 BE1750'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '313.4 x 246.5 x 18.95 mm'}, {'name': 'Trọng lượng', 'value': '1.7 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4-Cell 90 Whrs'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': '2x 2W, Micrô mảng không gian (3 Mic), Âm thanh độ phân giải cao, Xử lý âm thanh DTS'}, {'name': 'Webcam', 'value': 'IR FHD type (30fps@1080p) với HDR, Giảm nhiễu 3D+ (3DNR+)'}, {'name': 'Micro', 'value': '3 Mic'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím đơn có đèn nền (Trắng) với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bảo mật vân tay, Mô-đun nền tảng tin cậy riêng biệt (dTPM) 2.0, Mô-đun nền tảng tin cậy phần mềm (fTPM) 2.0, Mặt trập webcam, Khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 9 288V (8 lõi) - Max Turbo Frequency: 5.10 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel AI Boost'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc 140V GPU'}, {'name': 'Mô tả card đồ họa', 'value': '16GB VRAM'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel AI Boost'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5X 8533MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp'}, {'name': 'Ổ cứng', 'value': '2TB SSD PCIe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '13.3 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2880 x 1800 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': '400 nits'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 400 nits'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x USB-A 3.2 Gen 1, 2x Thunderbolt 4 (hỗ trợ Power Delivery, DisplayPort), 1x HDMI, 1x jack tai nghe/mic combo, 1 x MicroSD'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7 802.11 be'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2x Thunderbolt 4 (hỗ trợ DisplayPort)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'MgAl'}, {'name': 'Chất liệu vỏ dưới', 'value': 'MgAl'}, {'name': 'Kích thước', 'value': '29.9 x 21.0 x 1.69 cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '0.976 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell Int (75Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'Camera 5MP + IR (màn trập riêng tư) với micro mảng'}, {'name': 'Micro', 'value': 'Micro mảng'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím đơn có đèn nền (Màu trắng) với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay, nhận diện khuôn mặt, Mật khẩu quản trị & người dùng, fTPM 2.0, Microsoft Pluton Security Processor, Cấu hình bảo mật thiết bị I/O, Secure Boot, TCG Storage, Khe khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 4GB GDDR6 128-bit'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 với 4GB GDDR6'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4-3200 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2x 8GB, nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe RAM'}, {'name': 'Ổ cứng', 'value': '512GB PCIE (1x M.2 SSD slot (NVMe PCIe Gen4), 1x 2.5" SATA HDD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Mic-in, 1x Headphone-out, 1x Type-C (USB3.2 Gen1 / DP), 3x Type-A USB3.2 Gen1, 1x HDMI (4K @ 30Hz), 1x RJ45'}, {'name': 'Wi-Fi', 'value': 'Gb LAN 802.11 ax Wi-Fi 6E'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '359 x 254 x 21.7 mm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '1.86 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-Cell 52.4 Battery (Whr)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': '2x 2W Speaker'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím đơn có đèn nền (Màu xanh)'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mô-đun nền tảng tin cậy phần mềm (fTPM) 2.0, Kensington Lock'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 9 386H, 16 lõi (4 P-cores + 8 E-cores + 4 Low Power E-cores), 16 luồng, 18MB Intel Smart Cache, Max Turbo Frequency 4.9 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core Ultra 9 386H, 16 lõi (4 P-cores + 8 E-cores + 4 Low Power E-cores), 16 luồng, 18MB Intel Smart Cache, Max Turbo Frequency 4.9 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 GDDR7 8GB'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5060 GDDR7 8GB, Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel Core Ultra'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'DDR5-7200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 16GB, nâng cấp tối đa 128GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 128GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB*1, 2x M.2 SSD slot (NVMe PCIe Gen4) Max 4TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 pixels (QHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '240 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3 typ'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 100% DCI-P3 typ'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x Thunderbolt 4 (DisplayPort, Power Delivery 3.0), 2 x USB 3.2 Gen 2 Type-A, 1 x HDMI 2.1 (8K@60Hz / 4K@120Hz), 1 x RJ45'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 7 BE213'}, {'name': 'Bluetooth', 'value': 'Bluetooth v6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2 x Thunderbolt 4 hỗ trợ DisplayPort'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '354 x 246 x 16.65 - 19.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.99 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cells 90 Whrs'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-Res Audio Ready, Nahimic 3 Audio Enhancer'}, {'name': 'Webcam', 'value': 'Loại IR FHD (30fps@1080p) với HDR & Khử nhiễu 3D+ (3DNR+)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím chơi game RGB 4 vùng với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay, fTPM 2.0, Khe khóa Kensington, Secured-core PC, Nắp che webcam'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen AI 9 HX 370'}, {'name': 'Mô tả CPU', 'value': 'Tốc độ CPU (Base): 2Ghz / Tốc độ CPU Tối đa (Turbo Boost): 5.1GHz / Bộ nhớ đệm: 24MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060, 8GB GDDR7 AMD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5060, 8GB GDDR7'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'AMD Ryzen AI - 50 AI TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'DDR5 - 5600Mhz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (2 khe, hiện tại đang sử dụng 2 khe)'}, {'name': 'Ổ cứng', 'value': '1TB NVMe PCIe SSD Gen4x4 w/o DRAM, 2 khe đã sử dụng 1 khe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 pixels (2.5K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '240 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3 (Typ.)'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 100% DCI-P3 (Typ.)'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Type-C (USB4 / DisplayPort/ Power Delivery 3.0/ Thunderbolt 4), 2x Type-A USB3.2 Gen2, 1x HDMI 2.1 (8K @ 60Hz / 4K @ 120Hz), 1x RJ45'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 7'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Kim loại'}, {'name': 'Kích thước', 'value': '355.8 x 259.7 x 19.95 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.1 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 cell / 99.9 Whr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-RES Audio'}, {'name': 'Webcam', 'value': 'IR FHD type (30fps@1080p) hỗ trợ HDR'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím đèn nền RGB per Key Gaming'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Bảo mật vân tay, nhận diện khuôn mặt'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SEA'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 9 386H, 16 lõi (4 P-cores + 8 E-cores + 4 Low Power E-cores), 16 luồng, 18MB Intel Smart Cache, Max Turbo Frequency 4.9 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core Ultra 9 386H, 16 lõi (4 P-cores + 8 E-cores + 4 Low Power E-cores), 16 luồng, 18MB Intel Smart Cache, Max Turbo Frequency 4.9 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5070 GDDR7 8GB'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5070 GDDR7 8GB, Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Intel Core Ultra'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'DDR5-7200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 16GB, nâng cấp tối đa 128GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 128GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB*1, 2x M.2 SSD slot (NVMe PCIe Gen4) Max 4TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 pixels (QHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '240 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3 typ'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 100% DCI-P3 typ'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x Thunderbolt 4 (DisplayPort, Power Delivery 3.0), 2 x USB 3.2 Gen 2 Type-A, 1 x HDMI 2.1 (8K@60Hz / 4K@120Hz), 1 x RJ45'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 7 BE213'}, {'name': 'Bluetooth', 'value': 'Bluetooth v6'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2 x Thunderbolt 4 hỗ trợ DisplayPort'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '354 x 246 x 16.65 - 19.99 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.99 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cells 90 Whrs'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-Res Audio Ready, Nahimic 3 Audio Enhancer'}, {'name': 'Webcam', 'value': 'Loại IR FHD (30fps@1080p) với HDR & Khử nhiễu 3D+ (3DNR+)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím chơi game RGB 4 vùng với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Cảm biến vân tay, fTPM 2.0, Khe khóa Kensington, Secured-core PC, Nắp che webcam'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Cao cấp (35–60tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core 5 210H (8 lõi) - Max Turbo Frequency: 4.80 GHz'}, {'name': 'Mô tả CPU', 'value': '8 lõi, Max Turbo Frequency: 4.80 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050'}, {'name': 'Mô tả card đồ họa', 'value': '8GB of GDDR7 SDRAM, Bus Width: 128- bit, Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 x 16GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD PCIe (M.2 2280)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x USB 3.2 Gen 2 Type-A, 1 x USB 3.2 Gen 2 Type-C (Power Delivery / DisplayPort), 1 x HDMI, 1 x RJ45 (LAN), 1 x Headphone/Microphone combo audio jack'}, {'name': 'Wi-Fi', 'value': '802.11 ax'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '35.930 x 24.525 x (2.215-2.315) cm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.207 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cell Int (55.2Wh)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Realtek High Definition Audio'}, {'name': 'Webcam', 'value': 'HD WebCam (privacy shutter) with array microphones'}, {'name': 'Micro', 'value': 'Array microphones'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím kích thước đầy đủ với bàn phím số, 6 hàng phím Fn đa phương tiện, bàn phím chơi game RGB 4 vùng có đèn nền. Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Touchpad', 'value': 'Bàn di chuột hỗ trợ cử chỉ bốn ngón tay'}, {'name': 'Bảo mật', 'value': 'Mật khẩu quản trị viên, Mật khẩu người dùng, fTPM 2.0, Khởi động an toàn, Cấu hình bảo mật thiết bị lưu trữ TCG, Khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home Single Language 64-bit'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 7-7735HS (3.2 GHz, up to 4.75 GHz, 16 MB)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 7-7735HS, 8 nhân (dựa trên thông tin chung của dòng Ryzen 7 series)'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4060'}, {'name': 'Mô tả card đồ họa', 'value': 'RTX 4060 8GB VRAM, up to 2250MHz'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 4800 MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (8GB + 8GB, hỗ trợ nâng cấp lên đến 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên đến 64GB qua 2 khe cắm'}, {'name': 'Ổ cứng', 'value': '512GB NVMe PCIe Gen 4 SSD (1 khe trống M.2 NVMe)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói, Viền màn hình siêu mỏng'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Type-C (USB3.2 Gen1 / DP), 2x Type-A USB 3.2 Gen1, 1x Type-A USB 2.0, 1x HDMI 2.1 (8K @ 60Hz), 1x RJ45, 1x Mic-in/Headphone-out Combo Jack'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 6E (802.11ax)'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '359 x 259 x 24.9 mm'}, {'name': 'Trọng lượng', 'value': '2.25 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell 53.5WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': '2x 2W Speaker'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': '4-Zone RGB'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13500H'}, {'name': 'Mô tả CPU', 'value': 'Tốc độ CPU (Base): 3.5Ghz / Tốc độ CPU Tối đa (Turbo Boost): 4.7GHz / Bộ nhớ đệm: 18MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050'}, {'name': 'Mô tả card đồ họa', 'value': 'GDDR6 6GB, Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200Mhz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, nâng cấp tối đa 64 GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64 GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '1TB NVMe PCIe SSD Gen4x4 w/o DRAM, 2 khe đã sử dụng 1 khe'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Type-C (USB3.2 Gen1 / DP), 2x Type-A USB3.2 Gen1, 1x Type-A USB2.0, 1x HDMI 2.1 (8K @ 60Hz / 4K @ 120Hz), 1x RJ45'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359 x 259 x 24.9 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.25 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 cell, 53.5Whr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-RES Audio'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím đèn nền 4-Zone RGB Gaming'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SEA'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-14700HX (2.1 GHz - 5.5 GHz / 33MB / 20 nhân, 28 luồng)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-14700HX, 20 nhân, 28 luồng'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4060 8GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 4060 8GB GDDR6, đi kèm Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5600MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1 khe 8GB DDR5 + 1 khe 8GB DDR5, hỗ trợ tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe cắm'}, {'name': 'Ổ cứng', 'value': '1TB SSD M.2 NVMe (2 x M.2 NVMe)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 pixels (2K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '240 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x USB Type C / DisplayPort, 3 x USB 3.2, Audio combo, LAN 1 Gb/s, 1 x HDMI'}, {'name': 'Wi-Fi', 'value': 'WiFi 802.11ax (Wifi 6)'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '359 x 266.4 x 21.8 - 27.7 mm'}, {'name': 'Trọng lượng', 'value': '2.3 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 cell 65 Wh, pin liền'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Audio combo'}, {'name': 'Webcam', 'value': 'HD webcam'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'RGB'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SEA'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i9-14900HX'}, {'name': 'Mô tả CPU', 'value': 'Tốc độ CPU (Base): 1.6Ghz / Tốc độ CPU Tối đa (Turbo Boost): 5.8GHz / Bộ nhớ đệm: 36MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060'}, {'name': 'Mô tả card đồ họa', 'value': '8GB GDDR7, Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 - 5600Mhz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (2 khe, hiện tại 16GB)'}, {'name': 'Ổ cứng', 'value': '512GB NVMe PCIe SSD Gen4x4 w/o DRAM, 1 khe đã sử dụng'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1440 pixels (2K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'DCI-P3 100%'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x Type-C (USB3.2 Gen2 / DisplayPort/ Power Delivery 3.0), 3 x Type-A USB3.2 Gen2, 1 x HDMI 2.1 (8K @ 60Hz / 4K @ 120Hz), 1 x RJ45'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359 x 262 x 25.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 cell / 75 Whr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-RES Audio'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím đèn nền 4-Zone RGB Gaming'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SEA'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7 14650HX'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7 14650HX'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5060'}, {'name': 'Mô tả card đồ họa', 'value': 'tăng cường AI tiên tiến với 572 AI TOPS'}, {'name': 'Bộ xử lý AI / NPU', 'value': '572 AI TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD, hỗ trợ tối đa 4TB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1440 pixels (2K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': '300 nits'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3'}, {'name': 'Công nghệ màn hình', 'value': 'Độ sáng 300 nits, Độ phủ màu 100% DCI-P3'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x HDMI 2.1 (8K @ 60Hz / 4K @ 120Hz), 1 x Type-C (USB3.2 Gen2 / DisplayPort/ Power Delivery 3.0), 3 x Type-A USB3.2 Gen2'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E AX211'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359 x 262 x 25.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 cell 75 Whrs'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím chơi game RGB 4 vùng với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware Trusted Platform Module(fTPM) 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 9 8940HX'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 9 8940HX'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5070 Ti Laptop GPU, AMD Radeon 610M'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 5070 Ti Laptop GPU, GDDR7 12GB, AMD Radeon 610M'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, nâng cấp tối đa 96GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 96GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB PCIE (1x M.2 SSD slot (NVMe PCIe Gen4), 1x M.2 SSD slot (NVMe PCIe Gen5) Compatible)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1600 pixels (2.5K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '240 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3(Typical)'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 100% DCI-P3(Typical)'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2x Thunderbolt 5 (DisplayPort/ Power Delivery 3.1), 1x RJ45, 1x SD Card Reader'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2x Thunderbolt 5 hỗ trợ DisplayPort'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '357 x 284 x 22.20-28.55 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.7 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 Cells 90 Whrs'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready'}, {'name': 'Webcam', 'value': 'IR FHD type (30fps@1080p) với HDR'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím chơi game RGB 24 vùng với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mô-đun nền tảng tin cậy phần mềm (fTPM) 2.0, Màn trập webcam, Khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i5-13420H'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i5-13420H'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 4050 6GB GDDR6, Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB, hỗ trợ nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB'}, {'name': 'Ổ cứng', 'value': 'SSD 512GB M.2 PCIe Gen4 (1x M.2 SSD slot (NVMe PCIe Gen4) + 1x 2.5" SATA HDD)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Type-C (USB3.2 Gen1 / DisplayPort), 3x Type-A USB3.2 Gen1, 1x HDMI (4K @ 30Hz), 1x RJ45'}, {'name': 'Wi-Fi', 'value': '802.11 ax Wi-Fi 6E (AX211)'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359 x 254 x 21.7 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.86kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 52.4WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím đơn có đèn nền (Màu xanh)'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Firmware Trusted Platform Module(fTPM) 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core Ultra 9 288V'}, {'name': 'Mô tả CPU', 'value': 'Intel Core Ultra 9 288V'}, {'name': 'Tên card đồ họa', 'value': 'Intel Arc 140V GPU'}, {'name': 'Mô tả card đồ họa', 'value': 'Intel Arc 140V GPU'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Up to 48 NPU TOPS (120 total platform TOPS)'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'LPDDR5x-8533 Onboard'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không thể nâng cấp (Onboard)'}, {'name': 'Ổ cứng', 'value': '1x 1TB M.2-2280 SSD slot (NVMe PCIe Gen4x4), Hỗ trợ nâng cấp thêm: 1x M.2 SSD slot (NVMe PCIe Gen4)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '16 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '3840 x 2400 pixel (4K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền Oled'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '100% DCI-P3(Typical)'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 100% DCI-P3(Typical)'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': 'USB-A: 1, USB-C: 2 (Thunderbolt 4), Thunderbolt: 2, HDMI: 1, LAN: 1, SD: 1, 3.5mm: N/A'}, {'name': 'Wi-Fi', 'value': 'Intel Killer Wi-Fi 7 BE1750'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': '2x Thunderbolt 4 (DisplayPort/ Power Delivery 3.0)'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Kim loại'}, {'name': 'Kích thước', 'value': '358.4 x 254.4 x 16.85 - 18.95 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.5 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4-cell, 99.9WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-Res Audio Ready, DTS Audio Processing'}, {'name': 'Webcam', 'value': 'IR 5MP type(30fps@1944p), 3D Noise Reduction+ (3DNR+)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím đơn có đèn nền (Trắng) với phím Copilot'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mô-đun nền tảng đáng tin cậy rời rạc (dTPM) 2.0, Mô-đun nền tảng đáng tin cậy của phần mềm (fTPM) 2.0, Webcam Shutter, Khóa Kensington, Công nghệ bảo mật Microsoft Pluton'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen R7-8845HS'}, {'name': 'Mô tả CPU', 'value': 'Kiến trúc AMD XDNA'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4050 Laptop GPU'}, {'name': 'Mô tả card đồ họa', 'value': '6GB GDDR6'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5-5600'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (Nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe'}, {'name': 'Ổ cứng', 'value': '512GB SSD 2x M.2 (NVMe PCIe Gen4)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'N/A'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Mic-in/Headphone-out Combo Jack, 1x Type-C (USB3.2 Gen1 / DP), 2x Type-A USB3.2 Gen1, 1x Type-A USB2.0, 1x HDMI 2.1 (8K @ 60Hz / 4K @ 120Hz), 1x RJ45'}, {'name': 'Wi-Fi', 'value': 'Gb LAN 802.11 ax Wi-Fi 6E'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '359 x 259 x 24.9 mm (W x D x H)'}, {'name': 'Trọng lượng', 'value': '2.25 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-Cell 53.5 Battery (Whr)'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Loa 2x2W, Nahimic'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím chơi game RGB 4 vùng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mô-đun nền tảng đáng tin cậy của chương trình cơ sở (fTPM) 2.0'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 Laptop GPU + Intel UHD Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 3050 Laptop GPU + Intel UHD Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '24GB'}, {'name': 'Loại RAM', 'value': 'DDR4 3200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (1x 8GB + 1x 16GB, hỗ trợ nâng cấp tối đa 64GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB'}, {'name': 'Ổ cứng', 'value': '1x 512GB M.2-2280 SSD slot (NVMe PCIe Gen4x4), Hỗ trợ nâng cấp: 1x 2.5" SATA HDD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 45% NTSC, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Type-C (USB3.2 Gen1 / DisplayPort), 3x Type-A USB3.2 Gen1, 1x HDMI (4K @ 30Hz), 1x RJ45, 1x Mic-in, 1x Headphone-out'}, {'name': 'Wi-Fi', 'value': '802.11 ax Wi-Fi 6E'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.3'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa - nắp lưng kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Kim loại'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359 x 254 x 21.7 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.86 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3-cell, 52.4WHr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-Res Audio Ready, DTS Audio Processing'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': '1x Mic-in'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím đơn có đèn nền (Màu xanh)'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'Mô-đun nền tảng tin cậy phần mềm (fTPM) 2.0, Khóa Kensington'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i9-14900HX'}, {'name': 'Mô tả CPU', 'value': 'Tốc độ CPU (Base): 1.6Ghz / Tốc độ CPU Tối đa (Turbo Boost): 5.8GHz / Bộ nhớ đệm: 36MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5070'}, {'name': 'Mô tả card đồ họa', 'value': '8GB GDDR7, Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '32GB'}, {'name': 'Loại RAM', 'value': 'DDR5 - 5600Mhz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 16GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (2 khe, hiện tại 32GB)'}, {'name': 'Ổ cứng', 'value': '1TB NVMe PCIe SSD Gen4x4 w/o DRAM, 1 khe đã sử dụng'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1440 pixels (2K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'DCI-P3 100%'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x Type-C (USB3.2 Gen2 / DisplayPort/ Power Delivery 3.0), 3 x Type-A USB3.2 Gen2, 1 x HDMI 2.1 (8K @ 60Hz / 4K @ 120Hz), 1 x RJ45'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359 x 262 x 25.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 cell / 75 Whr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-RES Audio'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím đèn nền 4-Zone RGB Gaming'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SEA'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i9-14900HX'}, {'name': 'Mô tả CPU', 'value': 'Tốc độ CPU (Base): 1.6Ghz / Tốc độ CPU Tối đa (Turbo Boost): 5.8GHz / Bộ nhớ đệm: 36MB'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 5050'}, {'name': 'Mô tả card đồ họa', 'value': '8GB GDDR7, Intel Graphics'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 - 5600Mhz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (2 khe, hiện tại 16GB)'}, {'name': 'Ổ cứng', 'value': '512GB NVMe PCIe SSD Gen4x4 w/o DRAM, 1 khe đã sử dụng'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560 x 1440 pixels (2K)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': 'DCI-P3 100%'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x Type-C (USB3.2 Gen2 / DisplayPort/ Power Delivery 3.0), 3 x Type-A USB3.2 Gen2, 1 x HDMI 2.1 (8K @ 60Hz / 4K @ 120Hz), 1 x RJ45'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '359 x 262 x 25.5 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '2.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '4 cell / 75 Whr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-RES Audio'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Bàn phím đèn nền 4-Zone RGB Gaming'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SEA'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-12700H 14 nhân 24 luồng, Tốc độ CPU 3.50 GHz'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-12700H, 14 nhân 24 luồng, Tốc độ CPU 3.50 GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 3060 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'NVIDIA GeForce RTX 3060 với 6GB GDDR6'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': '(8GB x 2) DDR4 Buss 3200'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 Khe nâng cấp tối đa 64 GB'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB qua 2 khe cắm'}, {'name': 'Ổ cứng', 'value': '1TB NVMe PCIe SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2560x1440 (Quad HD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '165Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': '165Hz, 72%NTSC, IPS-Level, Độ phủ màu 100% sRGB'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Type-C USB 3.2 Gen1, 2x Type-A USB 3.2 Gen1, 1x Type-A USB 2.0, 1x HDMI, 1x Mic-in/Headphone-out Combo Jack, 1x RJ45'}, {'name': 'Wi-Fi', 'value': '802.11 ax Wi-Fi 6'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '359 x 259 x 26.9 mm'}, {'name': 'Trọng lượng', 'value': '2.3 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 Cell, 53.5Whr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Dynaudio and High-Resolution Audio ready, 2 loa'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn nền Spectrum'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'AMD Ryzen 5-7530U (up to 4.5 GHz, 6 lõi / 12 luồng, 16 MB)'}, {'name': 'Mô tả CPU', 'value': 'AMD Ryzen 5-7530U, 6 lõi / 12 luồng'}, {'name': 'Tên card đồ họa', 'value': 'AMD Radeon Graphics'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'N/A'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '1 thanh RAM'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'N/A'}, {'name': 'Ổ cứng', 'value': '512GB NVMe PCIe Gen 3x4 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '60 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC và 65% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'N/A'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x Type-C USB3.2 Gen2, 1 x Type-A USB3.2 Gen2, 2 x Type-A USB2.0, 1 x HDMI, 1 x Jack cắm tai nghe, 1 x MicroSD Reader'}, {'name': 'Wi-Fi', 'value': 'Wifi 6'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '319.9 x 223 x 19.35 mm'}, {'name': 'Trọng lượng', 'value': '1.4 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '39Wh 3 Cell'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'N/A'}, {'name': 'Webcam', 'value': 'HD 720p 30fps'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Đèn bàn phím trắng'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung (12–20tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H (10 lõi / 16 luồng)'}, {'name': 'Mô tả CPU', 'value': '3.6GHz~4.9GHz'}, {'name': 'Tên card đồ họa', 'value': 'NVIDIA GeForce RTX 4060'}, {'name': 'Mô tả card đồ họa', 'value': 'GDDR6 8GB'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200MHz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2x SO-DIMM socket (Nâng cấp tối đa 64GB SDRAM)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp lên tối đa 64GB'}, {'name': 'Ổ cứng', 'value': '1TB NVMe PCIe Gen 4 SSD'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '15.6 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1080 pixels (FullHD)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '45% NTSC'}, {'name': 'Công nghệ màn hình', 'value': 'Tần số quét 144Hz'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1x Type-C (USB3.2 Gen1 / DP), 2x Type-A USB3.2 Gen1, 1x Type-A USB2.0, 1x HDMI 2.1, 1x RJ45'}, {'name': 'Wi-Fi', 'value': '802.11 ax Wi-Fi 6'}, {'name': 'Bluetooth', 'value': 'Bluetooth v5.2'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'N/A'}, {'name': 'Chất liệu vỏ trên', 'value': 'N/A'}, {'name': 'Chất liệu vỏ dưới', 'value': 'N/A'}, {'name': 'Kích thước', 'value': '359 x 259 x 24.9 mm'}, {'name': 'Trọng lượng', 'value': '2.25 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 cell, 53.5Whr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Nahimic Audio & HiRes Audio'}, {'name': 'Webcam', 'value': 'HD type (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': '4-Zone RGB Gaming Keyboard'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Intel Core i7-13620H Gen 13th (10 lõi / 16 luồng, tối đa 4.9GHz, 24MB Cache)'}, {'name': 'Mô tả CPU', 'value': 'Intel Core i7-13620H Gen 13th'}, {'name': 'Tên card đồ họa', 'value': 'Nvidia Geforce RTX 3050 6GB GDDR6'}, {'name': 'Mô tả card đồ họa', 'value': 'Card đồ họa rời, 6GB GDDR6'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'N/A'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': 'DDR5 5200Mhz'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': '2 khe (2 x 8GB)'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Có thể nâng cấp (2 khe)'}, {'name': 'Ổ cứng', 'value': '512GB M.2 PCIe NVMe Solid State Drive (1 khe PCIe 2280; Đã sử dụng 1 khe)'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '14 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '1920 x 1200 pixels (FullHD+)'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': '144 Hz'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '100% sRGB'}, {'name': 'Công nghệ màn hình', 'value': 'Độ phủ màu 100% sRGB, màn hình chống chói'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '1 x Type-C (USB3.2 Gen 2 / DP), 2 x Type-A USB3.2 Gen 1, 1 x HDMI 2.1 (4K @ 60Hz), 1 x RJ45'}, {'name': 'Wi-Fi', 'value': 'Intel Wi-Fi 6E'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ nhựa'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhựa'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhựa'}, {'name': 'Kích thước', 'value': '314.7 x 233.5 x 18.6 - 22.3 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '1.6 kg'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '3 cell, 53.5Whr'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Hi-RES Audio, Nahimic'}, {'name': 'Webcam', 'value': 'HD (30fps@720p)'}, {'name': 'Micro', 'value': 'N/A'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'Single LED - Xanh'}, {'name': 'Touchpad', 'value': 'N/A'}, {'name': 'Bảo mật', 'value': 'N/A'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home SEA'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
{'Bộ xử lý & Đồ họa': [{'name': 'Tên CPU', 'value': 'Snapdragon Xplus (8 lõi, 8 luồng, → 3.20 GHz, 42MB Cache)'}, {'name': 'Mô tả CPU', 'value': 'Chip AI Qualcomm Hexagon 45 TOPS'}, {'name': 'Tên card đồ họa', 'value': 'Adreno GPU'}, {'name': 'Mô tả card đồ họa', 'value': 'Tích hợp'}, {'name': 'Bộ xử lý AI / NPU', 'value': 'Qualcomm Hexagon 45 TOPS'}], 'Bộ nhớ RAM, Ổ cứng': [{'name': 'Dung lượng RAM', 'value': '16GB'}, {'name': 'Loại RAM', 'value': '8448 MT/s LPDDR5x RAM'}, {'name': 'Số khe ram & Khả năng nâng cấp', 'value': 'Onboard không nâng cấp'}, {'name': 'Khả năng nâng cấp RAM', 'value': 'Không'}, {'name': 'Ổ cứng', 'value': '512GB'}], 'Màn hình': [{'name': 'Kích thước màn hình', 'value': '12 inches'}, {'name': 'Tỉ lệ màn hình', 'value': 'N/A'}, {'name': 'Độ phân giải màn hình', 'value': '2196 x 1464 pixels'}, {'name': 'Chất liệu tấm nền', 'value': 'Tấm nền IPS'}, {'name': 'Tần số quét', 'value': 'Lên đến 90Hz (mặc định 60Hz)'}, {'name': 'Độ sáng màn hình', 'value': 'N/A'}, {'name': 'Độ phủ màu màn hình', 'value': '220 PPI'}, {'name': 'Công nghệ màn hình', 'value': 'PixelSense LCD cảm ứng đa điểm, màn hình kính cường lực'}], 'Cổng kết nối': [{'name': 'Cổng giao tiếp vật lý', 'value': '2 x USB-C, 1 x Surface Pro 12-inch keyboard port'}, {'name': 'Wi-Fi', 'value': 'Wi-Fi 7'}, {'name': 'Bluetooth', 'value': 'Bluetooth 5.4'}, {'name': 'Hỗ trợ đa màn hình ngoài', 'value': 'N/A'}], 'Kích thước & Trọng lượng': [{'name': 'Chất liệu', 'value': 'Vỏ kim loại'}, {'name': 'Chất liệu vỏ trên', 'value': 'Nhôm'}, {'name': 'Chất liệu vỏ dưới', 'value': 'Nhôm'}, {'name': 'Kích thước', 'value': '274 x 190 x 7.8 mm (Dài x Rộng x Dày)'}, {'name': 'Trọng lượng', 'value': '686 g'}], 'Pin & công nghệ sạc': [{'name': 'Pin', 'value': '38 Wh'}, {'name': 'Sạc nhanh', 'value': 'N/A'}, {'name': 'Loại sạc', 'value': 'N/A'}], 'Âm thanh & Đa phương tiện': [{'name': 'Công nghệ âm thanh', 'value': 'Micro kép far-field (voice focus), Loa stereo 2W, Dolby Atmos, Hỗ trợ Bluetooth LE Audio'}, {'name': 'Webcam', 'value': 'Camera trước Surface Studio Full HD (1080p) / Camera sau tự động lấy nét 10MP với video Ultra HD và 4K'}, {'name': 'Micro', 'value': 'Micro kép far-field (voice focus)'}], 'Tính năng khác & Bảo mật': [{'name': 'Loại đèn bàn phím', 'value': 'N/A'}, {'name': 'Touchpad', 'value': 'Có (Màn hình cảm ứng)'}, {'name': 'Bảo mật', 'value': 'Bảo mật Microsoft Pluton TPM 2.0, Secured-core PC (Windows 11), Windows Hello (nhận diện khuôn mặt, bảo mật nâng cao), Microsoft Defender (bảo vệ danh tính & quyền riêng tư)'}, {'name': 'Hệ điều hành', 'value': 'Windows 11 Home'}], 'Tản nhiệt & Phần mềm hệ thống': [{'name': 'Hệ thống tản nhiệt', 'value': 'N/A'}, {'name': 'Bloatware & Phần mềm đi kèm', 'value': 'N/A'}, {'name': 'Môi trường sử dụng & Độ bền bảo vệ', 'value': 'N/A'}], 'Thương mại & Dịch vụ': [{'name': 'Phân khúc giá', 'value': 'Tầm trung cao (20–35tr)'}]}
]

# %%
main_data = [
    {'laptop_id': 'Laptop Acer Gaming Nitro ProPanel ANV15-41-R9M1', 'price_vnd': '24.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 5 7535HS (Ryzen 7000 series)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 (6GB VRAM)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 96GB qua 2 khe'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe Gen4 NVMe SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 3.5, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 3, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD IPS, 180Hz, 100% sRGB'}, 'PORTS_SCORE': {'score': 4, 'reason': '3x USB-A, 1x USB-C, HDMI 2.1, LAN, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 6 (802.11ax)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.1 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57Whr (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 135W'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Video HD 720p với tính năng giảm nhiễu'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ âm thanh đa dạng (DTS X:Ultra Audio, DAC SNR)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'TPM, mật khẩu BIOS, khe khóa Kensington'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại VN không được cung cấp rõ ràng'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.55, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Acer Nitro V 15 ANV15-41-R1JY', 'price_vnd': '22.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 5 6600H (Ryzen 7000+) phù hợp với mức 4.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 (6GB VRAM) nằm ở mức 3.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về NPU cụ thể, giả định không có hoặc rất cơ bản.'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, mức tiêu chuẩn cho nhiều tác vụ, nhưng không phải 32GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe Gen4 NVMe SSD, đáp ứng tiêu chí 1TB Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có khả năng nâng cấp RAM lên tối đa 96GB và SSD có khe cắm mở rộng (Up to 4TB).'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), IPS, 165Hz, độ phủ màu thấp (NTSC 45%).'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3x USB-A, 1x USB-C (USB4), HDMI 2.1, LAN, và Audio jack.'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11ax (WiFi 6E) và Bluetooth 5.1.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': 'Trọng lượng 2.1 kg, nằm trong khoảng 1.6-2.0kg (hoặc gần giới hạn trên của mức 2).'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Pin 57Whr, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 135W, rất mạnh mẽ.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Thông số không đề cập chi tiết về travel, nhưng thường là mức chấp nhận được cho dòng gaming/workstation tầm trung.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Webcam 720p HD, không có thông tin về IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hỗ trợ DTS X:Ultra và công nghệ âm thanh không gian, 2.1 Vrms.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Chỉ có TPM dạng firmware và mật khẩu BIOS, thiếu các tính năng sinh trắc học cao cấp.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình quạt tiêu chuẩn.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Acer Aspire Lite Gen 2 AL14-52M-32KV', 'price_vnd': '12.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i3-1305U (Gen 13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '8GB DDR5, có thể nâng cấp lên 64GB'}, 'SSD_SCORE': {'score': 3, 'reason': '256GB PCIe NVMe SSD (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM nâng cấp được (lên 64GB) và SSD nâng cấp được'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': '14 inch, IPS, 60Hz, 45% NTSC (màu kém), độ sáng 300 nits.'}, 'PORTS_SCORE': {'score': 3, 'reason': '1x USB-C, 3x USB-A, HDMI 1.4, MicroSD, Audio jack'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6 AX201 (WiFi 6E tương đương)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.5 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '58Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': '65W PD Type C'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không đề cập chi tiết travel, nhưng có Copilot Key (có đèn)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera FHD (1080p) không đề cập IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hai loa stereo tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'BIOS user, supervisor, SSD passwords'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (giả định)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (GPU tích hợp)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Acer Gaming Aspire 7 A715-59G-73LB', 'price_vnd': '23.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-12650H (Gen 12) thuộc nhóm Core i7-H gen>=13.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6 GB, nằm trong phân khúc RTX 3060/4050.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về NPU cụ thể (N/A).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp lên 32GB (16GB là mức 3, cộng thêm +0.5 vì có thể nâng cấp).'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD (Gen4).'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 32GB) và SSD (nâng cấp tối đa 4TB) đều nâng cấp được.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), IPS, 144Hz, nhưng độ phủ màu rất thấp (45% NTSC) và độ sáng thấp (250nits).'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-A, 2 USB-C, HDMI, Ethernet, và nhiều cổng khác.'}, 'WIFI_SCORE': {'score': 3, 'reason': "802.11ax (WiFi 6E) và Bluetooth (theo thông số 'ax')."}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.99 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '54.8Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'Bộ đổi nguồn AC 150W (USB-C PD >=100W).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc), có đèn nền.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p HD, không có thông tin về IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hai loa stereo tích hợp.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ có bảo mật qua BIOS password và giám sát viên.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn (2 quạt cơ bản).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U7_ai_data'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U6_creator', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Acer Gaming Nitro V 15 ANV15-41-R732', 'price_vnd': '26.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 5 6600H (Ryzen 7000+) phù hợp với mức Core i7-H gen>=13 hoặc Ryzen 7 7000+'}, 'GPU_SCORE': {'score': 3, 'reason': 'RTX 4050 6GB, nằm trong phân khúc RTX 4050, VRAM 6GB'}, 'NPU_SCORE': {'score': 4, 'reason': '194 TOPs, tương đương với mức Intel Core Ultra 200V/H (~40 TOPS)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5 4800MHz, có thể nâng cấp lên 64GB qua 2 khe RAM (+0.5)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể nâng cấp) và SSD (nâng cấp tối đa 4TB) đều nâng cấp được'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD, IPS, 165Hz, độ phủ màu NTSC 45%.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3x USB-A, 1x USB-C (40Gbps), HDMI 2.1, LAN, và Audio jack.'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11ax (WiFi 6E) + Bluetooth 5.1'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.1 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57Whr, nằm trong khoảng 50-65Wh'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 135W rất mạnh'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel khoảng 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p HD, không có thông tin về IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hỗ trợ DTS X:Ultra Audio và các công nghệ âm thanh của Acer'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM solution, BIOS passwords, Kensington lock slot'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là 2 quạt cơ bản'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Acer Gaming Nitro Lite 16 NL16-71G-56WQ', 'price_vnd': '25.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H (Gen 13) thuộc nhóm Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 với 6GB VRAM.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về NPU cụ thể (N/A).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên tối đa 56GB (16GB là mức 3, cộng thêm +0.5 vì có khả năng nâng cấp).'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD (Gen4).'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': 'Màn hình 16 inch FHD+ (1920x1200), IPS, 165Hz, độ phủ màu NTSC 45%.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C, HDMI 2.1, Ethernet (LAN).'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11ax (WiFi 6E) + Bluetooth 5.0.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.95 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Pin 53Wh nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'Hỗ trợ sạc nhanh USB-C PD 100W.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel key khoảng 1.2-1.5mm và có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'FHD Camera nhưng không đề cập đến tính năng IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hai loa stereo tích hợp.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ có bảo mật qua BIOS password và mật khẩu giám sát.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.15, 'final_score': 3.15, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.55, 'final_score': 3.55, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.35, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.85, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.65, 'final_score': 3.65, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.75, 'final_score': 3.75, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.45, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.65, 'final_score': 3.65, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.35, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.55, 'final_score': 2.55, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Acer Aspire Lite 16 GEN 2 AL16-52P-76DU', 'price_vnd': '18.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7 Raptor Lake - Hiệu năng tốt cho tác vụ văn phòng và đa nhiệm.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (Card đồ họa tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU).'}, 'RAM_SCORE': {'score': 4, 'reason': '16GB DDR5, dung lượng tốt và có khả năng nâng cấp lên 64GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB NVMe PCIe Gen4, tốc độ tốt nhưng dung lượng chưa phải là cao cấp nhất.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB và SSD có thể thay thế/nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 16 inch FHD+ (1920x1200) với tần số quét 60Hz và độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 3 USB 3.2, 1 HDMI, 1 USB Type-C.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.1.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.7 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '58 Wh, mức pin trung bình.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Thông tin sạc không rõ ràng (N/A), giả định là sạc tiêu chuẩn.'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền bàn phím.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Full HD Webcam (1080p) nhưng không đề cập đến tính năng IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Stereo speakers.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có các tính năng bảo mật sinh trắc học tiên tiến được liệt kê.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành tiêu chuẩn 1 năm tại trung tâm bảo hành.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Acer Gaming Nitro ProPanel ANV15-41-R0FE', 'price_vnd': '29.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 7735HS (Ryzen 7 7000+) phù hợp với mức 4.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB, thuộc phân khúc RTX 3060/4050.'}, 'NPU_SCORE': {'score': 4, 'reason': '194 TOPs, tương đương với mức Intel Core Ultra 200V/H (~40 TOPS).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, khả năng nâng cấp lên 96GB qua 2 khe.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe NVMe SSD Gen4, đáp ứng tiêu chí 1TB Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080) IPS, 180Hz, sRGB 100% và 300nits.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3x USB-A, 1x USB-C, HDMI 2.1, LAN, và Audio jack.'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11ax (WiFi 6E) và Bluetooth.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.1 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57Whr, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': '135W AC Adapter (PD cao hơn 65W).'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel key khoảng 1.2-1.5mm và có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Video HD 720p với tính năng giảm nhiễu.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hỗ trợ DTS X:Ultra Audio và các công nghệ âm thanh của Acer.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM và Giải pháp Mô-đun Nền tảng Tin cậy (TPM).'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không đề cập chi tiết về hệ thống tản nhiệt phức tạp, giả định là 2 quạt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.95, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.55, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Acer Swift Go SFG14-41-R251', 'price_vnd': '20.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 5 7430U (Ryzen 5 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon Graphics'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR4X, không thể nâng cấp'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe NVMe SSD'}, 'UPGRADABILITY': {'score': 2, 'reason': 'RAM Onboard không nâng cấp, SSD có thể nâng cấp lên 2TB'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': '14 inch FHD IPS, 60Hz, 100% sRGB'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-A, 2x USB-C, HDMI 2.1, Audio'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.1'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.25 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '50Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel 1.2-1.5mm + Backlit'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p HD video'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hai loa âm thanh nổi tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'BIOS user, HDD password, Supervisor, Kensington lock'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
None
{'laptop_id': 'Laptop Acer Aspire Lite 14 AL14-52M-52UU', 'price_vnd': '18.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-1335U (Gen 13) thuộc nhóm Core i5-H gen>=13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp Intel UHD Graphics.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB qua 2 khe RAM (+0.5 vì có khả năng nâng cấp).'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD (Gen4).'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể nâng cấp) và SSD (nâng cấp tối đa 2TB) đều nâng cấp được.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 3}, 'reason': '14 inch, IPS, 60Hz, sRGB 100% (rất tốt về màu sắc nhưng tần số quét thấp).'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3x USB-A, 1x USB-C (có DP/sạc), 1x HDMI, hỗ trợ nhiều cổng.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wireless Wi-Fi 6 AX201 (WiFi 6E).'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.5 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '58Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel khoảng 1.2-1.5mm (giả định), có đèn (Không có đèn, nên giảm xuống 3).'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera FHD 2MP (1080p) nhưng không đề cập đến IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 x Loa stereo tích hợp.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ có mật khẩu BIOS, không có các tính năng sinh trắc học cao cấp.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại VN không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Acer Gaming Nitro ProPanel ANV15-52-72BM', 'price_vnd': '37.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 5050 (Không nằm trong danh sách chuẩn, giả định tương đương mức RTX 4050/3060)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp lên 64GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể nâng cấp) và SSD (nâng cấp lên 2TB) đều nâng cấp được'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD, IPS, 180Hz, sRGB 100%, chống chói'}, 'PORTS_SCORE': {'score': 4, 'reason': '3x USB-A, 1x USB-C, HDMI 2.1, LAN, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11ax (WiFi 6) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.1 kg (Trong khoảng 1.6-2.0kg, nhưng gần ngưỡng trên)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '76Wh (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 135W'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (Giả định dựa trên phân khúc cao)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Video HD 720p với tính năng giảm nhiễu'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ âm thanh DTS X:Ultra Audio, DAC SNR cao'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'TPM, mật khẩu BIOS, khe khóa Kensington'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 37.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Acer Aspire Go 15 AG15-72P-54GY', 'price_vnd': '18.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core 5 120U (Core i5-H gen 12-13 range, hiệu năng văn phòng/tiêu chuẩn)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp lên 64GB (16GB là mức tiêu chuẩn)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (lên 64GB) và SSD (lên 2TB) đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': '15.6 inch FHD (1920x1080), tấm nền IPS, 60Hz, độ phủ màu NTSC 45% (dưới 65%)'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-A, 2x USB-C, HDMI 2.1, Audio jack'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 6 (802.11ax)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.53 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '55Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel 1.2-1.5mm (giả định), có đèn (Không có đèn thực tế nhưng xét theo cấu trúc)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p HD video (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hai loa âm thanh nổi tích hợp với công nghệ cải tiến'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ có Kensington lock, không có các tính năng sinh trắc học cao cấp'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm bảo hành đầy đủ tại VN (Giả định dựa trên phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.35, 'final_score': 3.35, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.55, 'final_score': 3.55, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.45, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.55, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.35, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.35, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.35, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.55, 'final_score': 3.55, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.35, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.35, 'final_score': 2.35, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Acer Gaming Nitro ProPanel AN16S-61-R193', 'price_vnd': '55.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'AMD Ryzen AI 9 365, thuộc nhóm chip cao cấp nhất hiện tại.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5070 với VRAM 8GB, mạnh mẽ cho gaming.'}, 'NPU_SCORE': {'score': 4, 'reason': 'Up to 50 TOPS, tương đương mức cao của Intel Core Ultra 200V/H.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có 2 khe và khả năng nâng cấp lên 96GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể nâng cấp) và SSD (2 khe cắm) đều nâng cấp được.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 5, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch 2K (QHD+), IPS, 180Hz, 100% sRGB, 400 nits.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 3x USB-A, 2x USB-C, HDMI 2.1, LAN, SD Card Reader.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.18 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '76Wh, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 230W, sạc rất nhanh và công suất lớn.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard có đèn RGB và travel tốt (giả định dựa trên cấu hình cao cấp).'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p HD, không đề cập đến tính năng IR.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Công nghệ âm thanh cao cấp (DTS X:Ultra Audio, DAC SNR cao).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Microsoft Pluton Security Processor (TPM 2.0).'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là thiết kế tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 55.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Acer Gaming Nitro ProPanel ANV15-52-59AA', 'price_vnd': '32.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H (Gen 13) thuộc nhóm Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 5050 (Không nằm trong danh sách 40 series cụ thể, giả định tương đương mức RTX 4050/3060).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp lên 64GB qua 2 khe RAM (+0.5 vì có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD (Gen4, nhưng dung lượng thấp hơn mức 4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể nâng cấp) và SSD (nâng cấp lên 2TB) đều nâng cấp được.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD, IPS panel, 180Hz, sRGB 100% (rất tốt về màu sắc).'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 3x USB-A, 1x USB-C, HDMI 2.1, LAN, và Audio jack.'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11ax (WiFi 6) + Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.1 kg, nằm trong khoảng 1.6-2.0kg đến 2.0kg (gần ngưỡng 2.0kg).'}, 'BATTERY_SCORE': {'score': 4, 'reason': '76Wh, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 135W (Rất mạnh).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Backlit keyboard, travel >= 1.5mm (giả định dựa trên phân khúc).'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Video HD 720p với tính năng giảm nhiễu.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ âm thanh tiên tiến (DTS X:Ultra Audio, Purified.Voice), 2 loa stereo ổn.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM và các giải pháp bảo mật phần sụn người dùng.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không đề cập chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt cơ bản (2 quạt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp rõ ràng.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Acer Aspire Lite 15 AL15-72P-7232', 'price_vnd': '17.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13), thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB qua 2 khe RAM (+0.5 vì có thể nâng cấp)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 64GB) và SSD (nâng cấp lên 2TB) đều nâng cấp được'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tấm nền IPS, tần số quét 60Hz, độ phủ màu NTSC 45% thấp.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 3 USB-A, 1 USB-C, HDMI 1.4, và cổng SD'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wireless Wi-Fi 6 AX201 (WiFi 6E/AX)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.79 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '58Wh, nằm trong khoảng 50-65Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': '90W AC adapter (USB-C PD 65W trở lên)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không đề cập chi tiết travel, nhưng giả định là chuẩn cơ bản với đèn không có'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera FHD (1080p) nhưng không đề cập tính năng IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hai loa âm thanh nổi tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Chỉ có bảo mật BIOS, mật khẩu ổ cứng, khóa Kensington, màn trập camera'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.15, 'final_score': 3.15, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.55, 'final_score': 3.55, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.35, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.45, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.65, 'final_score': 3.65, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.55, 'final_score': 3.55, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.35, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.65, 'final_score': 3.65, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.35, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.55, 'final_score': 2.55, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Acer Gaming Nitro ProPanel ANV16S-41-R337', 'price_vnd': '41.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 7 260 (Gen cũ hơn các chuẩn hiện đại)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 5050 8GB GDDR7 (Hiệu năng tầm trung)'}, 'NPU_SCORE': {'score': 4, 'reason': '440 TOPs (Cao hơn mức ~40 TOPS của Core Ultra)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp lên 96GB qua 2 khe'}, 'SSD_SCORE': {'score': 4, 'reason': '1024GB PCIe NVMe SSD Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (2 khe) và SSD (2 khe) đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': '16 inch FHD+, IPS, 180Hz, sRGB 100%, Anti-glare'}, 'PORTS_SCORE': {'score': 4, 'reason': '3x USB-A, 1x USB-C (có DP/sạc), HDMI 2.1, LAN, SD, Audio'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.1 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '76Wh (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 135W (Rất mạnh)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': '4-zone RGB Keyboard (Giả định travel >= 1.5mm)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p HD, không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ âm thanh đa dạng (DTS X:Ultra Audio, Dolby Atmos)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'MSFT Pluton Security Processor (Firmware-TPM)'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 41.29M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.83, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Acer Swift 14 AI SF14-51-53P9', 'price_vnd': '29.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 226V (Core Ultra 5 series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics 130V (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel Core Ultra (Ngụ ý có NPU, tương đương Core Ultra 100-series ~11 TOPS)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X, Onboard (RAM hàn liền)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe NVMe SSD Gen4'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM Onboard)'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 2, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, độ phân giải 2880x1800, DCI-P3 100%, 500nits.'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-A, 2x USB-C (có khả năng là Thunderbolt 4), HDMI 2.1'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Killer Wi-Fi 7 Wireless LAN'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.26 kg (<1.2kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '65 Wh (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 65W (PD >=100W là 5, 65W là 4, nhưng xét theo mức phổ biến thì đây là sạc nhanh tốt)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về travel, nhưng giả định là tiêu chuẩn cho laptop cao cấp.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'QHD 1440p (2560x1440p) với giảm nhiễu theo thời gian, không đề cập IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ âm thanh DTS X:Ultra Audio, DAC SNR.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Bộ xử lý bảo mật MSFT Pluton làm TPM Firmware, Đầu đọc dấu vân tay.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 29.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.25, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Acer Gaming Nitro V 15 ProPanel ANV15-52-73Z8', 'price_vnd': '33.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core 7 240H (Gen mới, hiệu năng cao)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 4050 (6GB VRAM)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp lên 96GB (16GB là mức tiêu chuẩn)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 96GB qua 2 khe; SSD có thể nâng cấp lên 4TB.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD, IPS panel, 180Hz, sRGB 100%.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 3x USB-A, 1x USB-C (Thunderbolt 4), HDMI 2.1, LAN, Audio.'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11ax (WiFi 6)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.1 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57 Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 135W (Rất mạnh)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p HD, không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'DTS X:Ultra Audio với các tính năng khử ồn.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Firmware TPM, Mật khẩu BIOS.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định theo phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 33.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Acer Gaming Nitro ProPanel ANV16S-61-R0B8', 'price_vnd': '42.999.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 5 340, thuộc nhóm Core Ultra 5/7 100-series hoặc tương đương.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 5050 8GB, nằm trong phân khúc RTX 4050/3060.'}, 'NPU_SCORE': {'score': 4, 'reason': 'Up to 50 TOPS, tương đương mức của Intel Core Ultra 200V/H.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, khả năng nâng cấp lên 96GB qua 2 khe.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe Gen4 NVMe SSD, đáp ứng tiêu chuẩn 1TB Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch FHD+ (1920x1200), IPS, 180Hz, 100% sRGB, 400nits, chống lóa.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3 cổng USB-A, 1 cổng USB-C (có vẻ là 40Gbps), HDMI 2.1, LAN, SD, và 3.5mm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.1 kg, nằm trong khoảng 1.6-2.0kg nhưng hơi nhỉnh hơn một chút.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '76Wh, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'Bộ đổi nguồn AC 135W (USB-C PD >=100W).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard có đèn RGB và travel >= 1.5mm (giả định dựa trên cấu hình tầm trung cao).'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Video HD 1080p với tính năng giảm nhiễu theo thời gian, không đề cập rõ về IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hỗ trợ DTS X:Ultra Audio và các công nghệ âm thanh của Acer.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Bộ xử lý bảo mật MSFT Pluton và TPM 2.0.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt (N/A), giả định là 2 quạt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 42.999.000đ vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U2_office', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Acer Gaming Nitro Lite 16 NL16-71G-71FN', 'price_vnd': '29.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 4050 6GB (Phù hợp với mức RTX 4050)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 56GB (16GB là mức 3, cộng thêm +0.5 vì có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': '16 inch FHD+ (1920x1200), IPS, 180Hz, nhưng độ phủ màu thấp (NTSC 45%)'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-A, 1x USB-C (Thunderbolt 4), HDMI 2.1, LAN'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11ax (WiFi 6)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.95 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '53Wh (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 100W'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel key 1.2-1.5mm + Backlit'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera FHD (1080p) không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hai loa stereo tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'BIOS passwords, Kensington lock slot'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
None
{'laptop_id': 'Laptop Acer Swift Lite 14 AI SFL14-51M-56HS', 'price_vnd': '19.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 125U (Core Ultra 5 100-series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel Core Ultra (Ngụ ý có NPU ~11 TOPS)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB (+0.5 vì nâng cấp được)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD+ (1920x1200), IPS, 60Hz, 45% NTSC (Rất kém về màu sắc và tần số quét)'}, 'PORTS_SCORE': {'score': 3, 'reason': '3x USB-A, 1x USB-C, 1x HDMI 1.4'}, 'WIFI_SCORE': {'score': 4, 'reason': 'WiFi 6E + Bluetooth 5.1'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.27 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '58Whr (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không đề cập chi tiết travel, nhưng giả định là mức trung bình (1.2-1.5mm)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera FHD không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hai loa stereo tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'BIOS user, supervisor, HDD passwords'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.35, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Acer Aspire Go 14 AI AG14-71M-57WR', 'price_vnd': '17.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 125H (Core Ultra 5 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Arc Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': '11 TOPS (Intel Core Ultra 100-series)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 96GB qua 2 khe'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 4, 'ANTIGLARE': 3}, 'reason': '14 inch FHD+ (1920x1200), IPS, 60Hz, sRGB 100%, 300nits.'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-C, 2x USB-A, HDMI 2.1, LAN, SD, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 6+AX'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.5 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '55 Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel 1.2-1.5mm, có đèn (Không đề cập rõ ràng nhưng giả định dựa trên cấu hình tầm trung)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p không IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hai loa âm thanh nổi tích hợp'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ có Kensington lock, không có sinh trắc học cao cấp'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U5_gamer', 'U6_creator', 'U10_entertainment'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Gaming Acer Nitro V ANV15-51-57B2', 'price_vnd': '23.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H (Gen 13), thuộc nhóm Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 4050, VRAM 6GB.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB (16GB là mức 3, cộng thêm +0.5 vì có thể nâng cấp).'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD (Gen4).'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 32GB) và SSD (nâng cấp lên 2TB Gen4) đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), IPS, 144Hz, nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 1x USB-C, 3x USB 3.2 Gen 1, HDMI 2.1, Ethernet, và các cổng khác.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 802.11 ac (WiFi 6).'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.1 kg, nằm trong khoảng 1.6-2.0kg đến 2.0kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57 Whr, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Sử dụng DC-in jack, không đề cập sạc nhanh USB-C PD mạnh.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel key khoảng 1.2-1.5mm và có đèn đơn sắc.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD webcam (1080p không IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Có Spatial Audio, Acer Purified Voice, DTS:X ULTRA (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về các tính năng bảo mật sinh trắc học nâng cao.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình gaming nên có quạt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.15, 'final_score': 2.2, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Gaming Acer Nitro V ANV15-51-72VS', 'price_vnd': '19.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H, hiệu năng mạnh mẽ cho tác vụ đa nhiệm.'}, 'GPU_SCORE': {'score': 2, 'reason': 'NVIDIA GeForce RTX 2050 4GB VRAM, hiệu năng đồ họa ở mức cơ bản.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, dung lượng tiêu chuẩn cho nhiều tác vụ.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD, tốc độ tốt nhưng dung lượng vừa phải.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB qua 2 khe; SSD có thể nâng cấp lên 2TB.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080) IPS với tần số quét 144Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3x USB-A, 1x USB-C, HDMI 2.1, LAN và jack cắm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6 AX201 (WiFi 6E).'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.1 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57Wh, mức pin trung bình.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'DC-in jack for AC adapter (Không phải USB-C PD).'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Thông tin về travel không rõ, nhưng có đèn nền (dựa trên giả định chung của dòng máy).'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720P HD, không có thông tin về IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa stereo ổn (giả định tiêu chuẩn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có vân tay, TPM2.0 và mật khẩu quản trị.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành tiêu chuẩn 1 năm tại trung tâm BH.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Gaming Acer Nitro V ANV15-51-58AN', 'price_vnd': '16.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H (Gen 13)'}, 'GPU_SCORE': {'score': 2, 'reason': 'NVIDIA GeForce RTX 2050, VRAM 4GB'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (lên 32GB) và SSD (nâng cấp lên 2TB) đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': '15.6 inch FHD, IPS panel, 144Hz, nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 4, 'reason': '3x USB-A, 1x USB-C, HDMI 2.1, LAN, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 6 (802.11ax) + Bluetooth 5.1'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.1 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57 Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'DC-in jack for AC adapter (Không đề cập PD lớn)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về travel, nhưng có đèn Led trắng.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p HD, không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'DTS® X:Ultra (cho thấy chất lượng khá hơn stereo cơ bản)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin bảo mật sinh trắc học (vân tay/IR face)'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Acer Gaming Nitro ProPanel ANV15-51-73UU', 'price_vnd': '27.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13) thuộc nhóm Core i7-H gen>=13.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB, nằm trong phân khúc RTX 3060/4050.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU (Bộ xử lý AI).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, mức tiêu chuẩn cho nhiều tác vụ, có thể nâng cấp lên 64GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD, tốc độ Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB qua 2 khe; SSD có thể nâng cấp lên 4TB.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080) IPS, 180Hz, 100% sRGB, 300nits.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3x USB-A, 1x USB-C (có khả năng là DP/Thunderbolt), HDMI 2.1, LAN, và Audio jack.'}, 'WIFI_SCORE': {'score': 3, 'reason': "802.11ax (WiFi 6E) và Bluetooth (dựa trên 'ac+ax' và thông tin chung)."}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.1 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57Whr, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 135W, rất mạnh mẽ.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Thông tin về travel không được cung cấp chi tiết, giả định là tiêu chuẩn (1.2-1.5mm) và có đèn (nếu có).'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Webcam 720p HD, không đề cập đến IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ âm thanh DTS X:Ultra Audio, tương thích với các tính năng của Acer.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có vân tay (Acer Bio-Protection), TPM 2.0, và tùy chọn BIOS password.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt (N/A), giả định là cấu hình tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 27.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Acer Gaming Predator Helios Neo 16 AI PHN16-73-757W', 'price_vnd': '60.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 7 255HX (thuộc dòng Core Ultra 7/9 200-series)'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060 (Mặc dù chưa có trong danh sách chuẩn, giả định tương đương RTX 4060/4070 tầm trung cao)'}, 'NPU_SCORE': {'score': 5, 'reason': '572 TOPS (Rất cao, tương đương mức Apple Neural Engine)'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB DDR5, khả năng nâng cấp lên 96GB qua 2 khe'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe NVMe Gen4 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': '16 inch 2K OLED, 240Hz, DCI-P3 100%, 500 nits.'}, 'PORTS_SCORE': {'score': 5, 'reason': '2x USB-C (có thể là Thunderbolt 4), 3x USB-A, HDMI 2.1, LAN, SD, Audio.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Killer Wireless Wi-Fi 6E + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.7 kg (Nằm trong khoảng 1.6-2.0kg đến 2.0kg, nhưng gần ngưỡng trên)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '90Wh (Trong khoảng 66-79Wh, nhưng 90Wh vẫn được coi là khá tốt)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'Bộ đổi nguồn AC 230W (PD rất mạnh)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': '4-zone RGB Lighting (Giả định travel >= 1.5mm)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Video HD 1080p với tính năng Giảm nhiễu theo thời gian (Không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'DTS X:Ultra Audio, DAC SNR cao, Công nghệ âm thanh tiên tiến.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'TPM, Khóa Kensington, Người dùng BIOS.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt, mặc định là cấu hình gaming/workstation)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 60.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.83, 'final_score': 1.8, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U2_office'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Acer Aspire Lite 15 AL15-41P-R3U5 NX.J53SV.001', 'price_vnd': '14.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 7 5700U (Gen cũ hơn yêu cầu 4 lõi/gen 12-13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon Graphics'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp, SSD có thể nâng cấp lên 2TB'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD, IPS panel, 60Hz, NTSC 45% (dưới ngưỡng màu)'}, 'PORTS_SCORE': {'score': 3, 'reason': '1x USB-C, 3x USB-A, 1x HDMI 1.4'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11ax (WiFi 6) + Bluetooth 5.1'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.7 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '58Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': '65W PD Type C'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về travel key, không có đèn nền'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera FHD (1080p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hai loa stereo tích hợp'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ có BIOS user, supervisor'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
None
{'laptop_id': 'Laptop Gaming Acer Nitro V ANV15-51-55CA', 'price_vnd': '23.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, thuộc dòng Core i5-H gen 13'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 4050, VRAM 6GB'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (lên 64GB) và SSD (lên 2TB) đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), IPS, 144Hz, nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3x USB-A, 1x USB-C, HDMI 2.1, LAN, Audio.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6 AX201 (WiFi 6E)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.1 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57Wh nằm trong khoảng 50-65Wh'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'DC-in jack for AC adapter (Không phải USB-C PD mạnh)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc tầm trung cao)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720P HD, không có thông tin về IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'DTS® X:Ultra (cho thấy chất lượng khá hơn stereo cơ bản)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có vân tay và TPM Firmware'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là 2 quạt cơ bản'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin chung về dịch vụ bảo hành tại VN (1 năm)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Acer Swift 14 AI SF14-51-75VP', 'price_vnd': '35.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 7 258V (thuộc nhóm Core Ultra 7/9)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics 140V (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra (Ngụ ý có NPU, tương đương Core Ultra 200V/H)'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB RAM, nhưng là Onboard nên không thể nâng cấp thêm.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe NVMe SSD Gen4'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (có thể nâng cấp lên 2TB SSD).'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 2, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, độ phân giải 2880x1800 (QHD+), DCI-P3 100%, nhưng tần số quét chỉ 90Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 2x USB-C (USB4/DP), HDMI 2.1, SD, LAN.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Killer Wi-Fi 7 Wireless LAN'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.26 kg (<1.2kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '65 Wh (trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB Type-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không đề cập chi tiết về travel, nhưng thường là mức trung bình cho laptop mỏng nhẹ.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1440p (2560x1440) nhưng không đề cập tính năng IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ âm thanh khá (DTS X:Ultra Audio, DAC SNR) nhưng không phải cấu hình cao cấp nhất.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có vân tay và TPM2.0 (MSFT Pluton).'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 35.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.6, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.4, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.6, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U2_office', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Acer Swift Lite 14 AI SFL14-51M-78XZ', 'price_vnd': '20.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 7 155U (Core Ultra 7 100-series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel Core Ultra series (ngụ ý có NPU, tương đương ~11 TOPS)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB (+0.5 vì nâng cấp được)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (lên 32GB) và SSD (lên 2TB) đều nâng cấp được'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': '14 inch FHD+ (1920x1200), IPS, 60Hz, 45% NTSC (màu kém), chống lóa mỏng.'}, 'PORTS_SCORE': {'score': 3, 'reason': '3x USB-A, 1x USB-C, 1x HDMI 1.4, khe SD'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wireless Wi-Fi 6 AX201 (WiFi 6E)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.27 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '58Whr (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': '65W PD Type-C Adapter'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không đề cập về travel, không có đèn nền'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera FHD (1080p không IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hai loa stereo tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'BIOS user, supervisor, HDD passwords, Kensington lock'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
None
{'laptop_id': 'Laptop gaming Acer Nitro 5 AN515-45-R9SC NH.QBRSV.001', 'price_vnd': '31.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 5800H (Ryzen 7 5000 series)'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 3070 (VRAM 8GB, TDP phù hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU)'}, 'RAM_SCORE': {'score': 2.5, 'reason': '8GB DDR4, có thể nâng cấp lên 32GB (8GB là mức thấp)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD M.2 PCIe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB qua 2 khe; SSD có thể nâng cấp thêm.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD IPS 144Hz, chất lượng hiển thị cơ bản.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có nhiều cổng kết nối bao gồm USB-C (Type-C), USB-A, HDMI, và RJ45.'}, 'WIFI_SCORE': {'score': 4, 'reason': '802.11AX (WiFi 6E tương đương)'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.2 kg (Trong khoảng 1.6-2.0kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57Whr (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin cụ thể về công suất sạc nhanh (N/A)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin về travel key, đèn nền.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p, không có thông tin về IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Waves MaxxAudio®, Acer TrueHarmony™ (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 1, 'reason': 'Không có thông tin về các tính năng bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Laptop gaming, không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
None
{'laptop_id': 'Laptop ASUS Vivobook S 14 FLIP TP3402VA-LZ632W', 'price_vnd': '21.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H (Gen 13) thuộc nhóm Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp nhưng là mức tiêu chuẩn hiện tại.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM và SSD (dựa trên mô tả khả năng nâng cấp).'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD (1920x1200), tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1x USB-A, 1x USB-C (Type-C hỗ trợ Display/Power), HDMI, Audio combo.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.50 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '50WHrs, mức dung lượng pin trung bình.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'DC-in (sạc qua củ sạc riêng), không đề cập sạc nhanh cao.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc), có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p FHD với màn trập camera (không đề cập IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp với công nghệ Smart Amp và micrô mảng.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có McAfee và Mô-đun nền tảng đáng tin cậy (TPM).'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS TUF Gaming F16 FX607VJ-RL034W', 'price_vnd': '22.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core 5 210H (Gen 12/13 thế hệ mới hơn nhưng thuộc phân khúc Core i5-H)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB GDDR6 (Phù hợp với mức RTX 3060/4050)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4-3200, có thể nâng cấp lên 64GB qua 2 khe.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe 4.0 NVMe M.2 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 64GB) và SSD (hỗ trợ tối đa 2TB) đều nâng cấp được.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 2, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch WUXGA (FHD+), IPS, 144Hz, 300nits, độ phủ màu NTSC 45%.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C (Type-C hỗ trợ DP/Power), HDMI 2.1, LAN, Audio.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.20 Kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '56Whrs nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Không đề cập chi tiết về công suất sạc nhanh (PD).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền RGB và travel key khoảng 1.5mm (giả định dựa trên phân khúc gaming TUF).'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720P HD camera (dưới mức 1080p).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hệ thống 2 loa với công nghệ chống ồn AI và Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có mật khẩu BIOS, bảo vệ mật khẩu người dùng và TPM module.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Là dòng TUF Gaming, thường có 2 quạt, nhưng không có thông tin chi tiết về hệ thống tản nhiệt phức tạp.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin chung về bảo hành không rõ ràng, giả định mức trung bình 1 năm.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Gaming V16 V3607VU-RP343W', 'price_vnd': '24.190.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core 5 210H (Gen 12/13) - Phù hợp với mức Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 4050 6GB - Tương đương RTX 4050, nằm trong phân khúc RTX 3060/4050.'}, 'NPU_SCORE': {'score': 4, 'reason': '194 AI TOPs - Đáp ứng tiêu chí của AMD Ryzen AI 300 hoặc Intel Core Ultra 200V/H.'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 - Mức tiêu chuẩn hiện tại.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD - Là dung lượng 1TB Gen4 (hoặc gần tương đương).'}, 'UPGRADABILITY': {'score': 3, 'reason': 'RAM có thể nâng cấp nhưng cần tháo vỏ; SSD có thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 1, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch FHD (1920x1200), Panel NTSC thấp (45%), tần số quét 144Hz.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (hỗ trợ hiển thị/sạc), 1x HDMI.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.95 kg - Nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '63WHrs - Nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'DC-in, không đề cập công suất sạc nhanh cụ thể (khác USB-C PD).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc), có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p FHD với màn trập camera (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp SonicMaster, Micrô tích hợp.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Mật khẩu BIOS và TPM2.0.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS ROG Strix G16 G615JMR-S5155W', 'price_vnd': '45.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7 14650HX (Gen 14) thuộc nhóm Core i7-H gen>=13.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060 8GB GDDR7, mạnh mẽ hơn RTX 4060/4070.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU (Bộ xử lý AI / NPU: N/A).'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB RAM, đáp ứng tiêu chuẩn 32GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe 4.0 NVMe SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có 2 khe RAM (tối đa 64GB) và 2 khe M.2 SSD.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 4, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 16 inch WQXGA (QHD+), IPS, 240Hz, DCI-P3 100%, 500nits, chống chói.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 1x LAN, 1x Thunderbolt 4, 3x USB-A, 1x HDMI 2.1, USB-C.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.65 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '90WHrs, nằm trong khoảng 66-79Wh (Lưu ý: Thông số 90Whr hơi cao so với mức 4, nhưng vẫn được xếp ở mức cao).'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sử dụng USB-C PD (dù công suất không được ghi rõ, nhưng thiết bị cao cấp thường hỗ trợ tốt).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc cao cấp) và có đèn nền RGB.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '1080P FHD camera có IR (Windows Hello).'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Công nghệ chống ồn AI, Dolby Atmos, Smart Amp.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có bảo mật BIOS password và TPM module.'}, 'THERMAL_SCORE': {'score': 4, 'reason': "Sử dụng 'ROG intelligent cooling', cho thấy hệ thống tản nhiệt mạnh mẽ."}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp chi tiết (chỉ biết phân khúc giá).'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 45.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook S14 S3407VA-LY146W', 'price_vnd': '20.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core 5 210H (Gen 12/13) - Phù hợp với mức Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (Card đồ họa tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có Bộ xử lý AI/NPU được liệt kê).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có 2 khe, khả năng nâng cấp qua khe SO-DIMM.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp qua khe SO-DIMM còn trống, SSD có thể thay thế/nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch, IPS, 60Hz, 45% NTSC (Rất thấp về màu sắc và tần số quét).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 2x USB-C, 1x HDMI, 1x Audio combo.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin cụ thể về công suất sạc nhanh).'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel 1.2-1.5mm (giả định), có đèn nền.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello và màn trập riêng tư.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam hồng ngoại hỗ trợ Windows Hello, TPM, bảo vệ BIOS.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm bảo hành đầy đủ tại VN (Giả định dựa trên phân khúc).'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (chỉ có tích hợp).', 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'NPU_SCORE quá thấp (1) và GPU_SCORE quá thấp (1).', 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.7, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Gaming Vivobook 16X K3605VC-RP431W', 'price_vnd': '19.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, Core i5-H gen 13'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA Geforce RTX 3050 4GB GDDR6'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp thêm 8GB (Tổng cộng 24GB)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp cả RAM và SSD (dựa trên thông tin cấu hình)'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 2, 'ANTIGLARE': 4}, 'reason': '16 inch, IPS, 144Hz, 45% NTSC (màu kém)'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-A, 1x USB-C (Type-C hỗ trợ 5Gbps), HDMI 2.1, SD, LAN, Audio'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.80 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '50WHrs'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'DC-in (không đề cập công suất PD cụ thể)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p có màn trập camera (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'McAfee, BIOS Password, TPM module'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (giả định)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS TUF Gaming F16 FX607VU-RL045W', 'price_vnd': '26.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core 5 210H (8 lõi, 12 luồng), thuộc phân khúc Core Ultra 5/7 100-series hoặc tương đương.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 4050 6GB, nằm ở mức RTX 4050, đáp ứng tiêu chí RTX 4050.'}, 'NPU_SCORE': {'score': 4, 'reason': '194 AI TOPs, tương đương với Intel Core Ultra 200V/H (~40 TOPS).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, khả năng nâng cấp lên 64GB qua 2 khe SO-DIMM (+0.5 vì có thể nâng cấp và <= 16GB ban đầu).'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 NVMe M.2 SSD, đạt tiêu chuẩn 1TB Gen4 (dù dung lượng nhỏ hơn).'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 64GB) và SSD (2 khe M.2) đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 2, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch FHD+ (1920x1200), IPS panel, 144Hz, độ phủ màu 45%.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x Thunderbolt 4 (hỗ trợ DP), 1x HDMI 2.1, LAN, và các cổng khác.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.20 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '56WHrs, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sạc nhanh 0-50% trong 30 phút (USB-C PD). Giả định công suất sạc phù hợp với tiêu chuẩn 65W trở lên.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím Chiclet có đèn nền RGB, travel khoảng 1.5mm (giả định dựa trên phân khúc).'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720P HD camera, không đề cập đến tính năng IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ chống ồn AI, Dolby Atmos, 2 loa stereo ổn.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có mật khẩu BIOS và TPM, nhưng thiếu các tính năng sinh trắc học cao cấp như vân tay/IR face.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt cơ bản (2 quạt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook 14 M1405NAQ-LY010W', 'price_vnd': '17.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 2, 'reason': 'AMD Ryzen 5 150 (Chip đời cũ, hiệu năng thấp)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp nhưng dung lượng hiện tại là 16GB'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB Gen4 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp qua khe SO-DIMM, SSD có thể nâng cấp (dựa trên cấu trúc)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD (1920x1200), tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC)'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 2 USB-C (một trong số đó hỗ trợ PD), HDMI 1.4, Jack 3.5mm'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.60 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD 5Gbps (không ghi rõ công suất lớn như 100W)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel khoảng 1.2-1.5mm (giả định), có đèn (Chiclet)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Camera HD 720p, có màn trập camera (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Mic đa hướng tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Cảm biến vân tay tích hợp, TPM, bảo vệ BIOS'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm bảo hành đầy đủ tại VN (Giả định dựa trên phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS TUF Gaming A15 FA506NCG-HN184W', 'price_vnd': '21.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 7445HS (Ryzen 7 7000+) phù hợp với mức 4 điểm.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 4GB, thuộc phân khúc RTX 3060/4050, VRAM 4GB.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU (N/A).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB RAM DDR5, khả năng nâng cấp lên 64GB qua 2 khe.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe 4.0 NVMe SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB qua 2 khe; SSD có 2 khe M.2 hỗ trợ nâng cấp.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), IPS, 144Hz, độ phủ màu 47.34%.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3x USB-A, 1x USB-C (có DP), 1x HDMI 2.1, LAN, Audio.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': 'Trọng lượng 2.30 Kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 48WHrs, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Thông tin sạc nhanh không được cung cấp rõ ràng (N/A).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím Chiclet có đèn nền RGB 1 vùng.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Webcam 720P HD camera (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ chống ồn AI, Xử lý âm thanh DTS, 2 loa stereo ổn.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Mật khẩu BIOS, Bảo vệ người dùng, và TPM module.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt (N/A).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Zenbook A14 UX3407QA-QD299WS', 'price_vnd': '27.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Snapdragon X X1 26 100 (Hiệu năng tầm trung)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Qualcomm Adreno GPU (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Qualcomm Hexagon NPU up to 45TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X, Onboard (Không nâng cấp được)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, DCI-P3 100%, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-C 4.0, 1x USB-A, HDMI 2.1, Audio'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg (0.98 kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không đề cập sạc nhanh cụ thể)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Webcam IR, TPM2.0, Microsoft Pluton, BIOS Password'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định theo phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (16GB) >= 8GB, SSD (512GB PCIe 4.0) != HDD/eMMC, Warranty (có BH tại VN). Tuy nhiên, Price Score (27.29M / 20M = 1.36) -> Score 1.', 'price_score': 1, 'weighted_score': 2.41, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.11, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.11, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.89, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.39, 'final_score': 4.4, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.89, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.11, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.39, 'final_score': 4.4, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.11, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.89, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business', 'U10_entertainment'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop ASUS Vivobook Go 15 E1504FA-BQ1150W', 'price_vnd': '14.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 5 7520U (4 lõi, 8 luồng), thuộc phân khúc Core i5-H gen 12-13 hoặc Ryzen 5 7000.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon Graphics.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5 Onboard, nhưng không thể nâng cấp thêm (Onboard).'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 NVMe PCIe 3.0 SSD.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không có khe trống để nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1x USB-A, 1x USB-C, HDMI, và jack âm thanh 3.5mm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E (802.11ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.63 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'DC-in, không đề cập công suất sạc nhanh cao (PD).'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel key khoảng 1.2-1.5mm và có đèn nền.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Camera HD 720p, không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp SonicMaster và micrô mảng tích hợp.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có McAfee, bảo vệ mật khẩu BIOS, và TPM module.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, khả năng cao là tản nhiệt cơ bản với nguy cơ throttle.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (chỉ có tích hợp)', 'price_score': 2, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U5_gamer']}}
{'laptop_id': 'Laptop ASUS TUF Gaming F16 FX608JMR-RV048W', 'price_vnd': '37.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7 14650HX (Gen 14) thuộc nhóm Core i7-H gen>=13.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060 8GB GDDR7, mạnh mẽ hơn RTX 4060/4070.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU (Bộ xử lý AI).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB qua 2 khe.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe 4.0 NVMe M.2 SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 32GB) và SSD (2 khe M.2) đều nâng cấp được.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch WUXGA (1920x1200), IPS, 165Hz, 300 nits, chống chói.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 1x LAN, 1x TB4, 3x USB-A, 1x HDMI 2.1, USB-C hỗ trợ DP/PD.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.20 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '90WHrs nằm trong khoảng 66-79Wh (Lưu ý: Thông số ghi 90WHrs, nhưng dựa trên quy tắc, nó gần với mức 4 hơn so với các mức thấp hơn).'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (cung cấp điện 10Gbps) thường tương đương hoặc cao hơn 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định do là dòng gaming HX) và có đèn nền RGB.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera IR FHD 1080P.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Có công nghệ chống ồn AI và Dolby Atmos, nhưng không đề cập đến cấu hình loa lớn.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM2.0 và bảo vệ mật khẩu BIOS/User.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Là dòng TUF Gaming, có khả năng tản nhiệt tốt nhưng không phải fanless.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp chi tiết.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 37.89tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook 14 X1404VA-NK394W', 'price_vnd': '12.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i3-1315U, Core i5-H gen 12-13 range (dù là i3 nhưng thuộc thế hệ mới)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB DDR4, khả năng nâng cấp có nhưng dung lượng thấp'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM có thể nâng cấp nhưng phức tạp)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD, IPS panel, 60Hz, 45% NTSC (Rất kém về màu sắc và tần số quét)'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có nhiều cổng USB (Type-A, Type-C), có HDMI, có combo audio'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs (thuộc khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'DC-in (Không phải USB-C PD cao)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel 1.2-1.5mm (giả định), có đèn (Chiclet)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p HD camera, không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Cảm biến vân tay tích hợp, TPM2.0, BIOS password'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định dựa trên phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (chỉ có tích hợp)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS ZenBook 14 UX3405CA-ST628W', 'price_vnd': '27.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 225H (Core Ultra 5 series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU up to 13TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X on board (Không thể nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM hàn liền và không có khe trống'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, 120Hz, 100% DCI-P3, 500 nits'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-C (Thunderbolt 4), 1x HDMI, 1x USB-A'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75WHrs'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (Không ghi rõ công suất cụ thể, giả định thấp hơn 100W)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD với chức năng hồng ngoại (IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp với Công nghệ Smart Amp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR hỗ trợ Windows Hello, Firmware TPM'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể về thời hạn tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 27.59tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': [], 'not_suitable_profiles': ['U1_student']}}
None
{'laptop_id': 'Laptop ASUS VivoBook 15 M1502NAQ-BQ021W', 'price_vnd': '17.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 2, 'reason': 'AMD Ryzen 5 150 (Chip đời cũ, hiệu năng thấp)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp (2 khe)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp (2 khe); SSD có thể nâng cấp (dựa trên cấu trúc M.2)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD, IPS, 60Hz, 250nits, 45% NTSC (Rất cơ bản)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 2x USB-C (có PD), HDMI 1.4, Audio jack'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.70 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42Whrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (có hỗ trợ Power Delivery)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Chiclet có phím số (Travel không rõ nhưng chấp nhận được)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Camera HD 720p, có màn trập camera (Không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Microphone mảng tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Cảm biến vân tay, TPM 2.0, Mật khẩu BIOS'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định dựa trên phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop ASUS Vivobook S14 S3407VA-LY053W', 'price_vnd': '22.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (Card đồ họa tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 Onboard (Tiêu chuẩn cho máy tính văn phòng/làm việc)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không có khe cắm thêm, SSD có thể nâng cấp nhưng khó khăn hơn.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD (1920x1200), IPS, 60Hz, 45% NTSC (Rất hạn chế về màu sắc và tần số quét).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 2x USB-C, 1x HDMI'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh cụ thể (USB-C PD không xác định)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (Giả định dựa trên phân khúc cao cấp)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD có chức năng IR hỗ trợ Windows Hello và màn trập vật lý'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR hỗ trợ Windows Hello, TPM2.0, BIOS Password Protection'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt (N/A)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể về thời gian và dịch vụ tại VN.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'GPU_SCORE = 1 (Intel UHD Graphics - không đủ mạnh cho gaming)', 'price_score': 3, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U5_gamer']}}
{'laptop_id': 'Laptop ASUS TUF Gaming F16 FX608JHR-RV037W', 'price_vnd': '35.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7 14650HX (Gen 14) thuộc nhóm Core i7-H gen>=13.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5050 8GB GDDR7, đáp ứng tiêu chí RTX 4060/4070.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU (Bộ xử lý AI).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB qua 2 khe cắm (+0.5 vì có khả năng nâng cấp).'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe 4.0 NVMe M.2 SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 32GB) và SSD (2 khe M.2) đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch WUXGA (1920x1200), IPS, 165Hz, 300 nits, độ phủ màu tốt.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 1x LAN, 1x Thunderbolt 4, 3x USB-A, 1x USB-C (Type-C hỗ trợ DP/PD), 1x HDMI 2.1.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E (802.11ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': 'Trọng lượng 2.20 kg, nằm trong khoảng 1.6-2.0kg đến 2.0kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 90WHrs, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (dù không ghi rõ công suất cụ thể nhưng thiết bị cao cấp thường hỗ trợ mạnh mẽ, giả định là 65W trở lên).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc HX), có đèn nền RGB.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera IR FHD 1080P cho Windows Hello.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ chống ồn AI, Dolby Atmos, 2 loa stereo ổn.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM2.0 và bảo vệ mật khẩu BIOS/người dùng.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Thiết kế TUF Gaming, có thể có 2 quạt, nhưng không có thông tin chi tiết về vapor chamber/liquid metal.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 35.89M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook S16 S3607VA-RP056W', 'price_vnd': '23.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13) thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về NPU mạnh, giả định Intel Core i7 thế hệ mới có NPU cơ bản)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB (16GB là mức 3)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB Gen4 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp qua khe SO-DIMM, SSD có thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 2, 'ANTIGLARE': 4}, 'reason': '16 inch WUXGA (FHD+), IPS panel, 144Hz, 300nits, nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 2x USB-C, HDMI, 3.5mm'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.70 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 4, 'reason': '70WHrs nằm trong khoảng 66-79Wh'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về sạc nhanh (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền và travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam hồng ngoại hỗ trợ Windows Hello, TPM2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành tiêu chuẩn 1 năm tại trung tâm BH'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.35, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop ASUS ROG Flow Z13 GZ302EA-RU145WS', 'price_vnd': '90.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'AMD Ryzen AI MAX+ 395 (16 lõi) thuộc nhóm chip cao cấp nhất.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics).'}, 'NPU_SCORE': {'score': 5, 'reason': 'AMD XDNA lên tới 50TOPS, tương đương mức cao nhất.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '128GB RAM, tuy nhiên là LPDDR5X On board (không nâng cấp được).'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe 4.0 NVMe M.2 SSD.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM On board và không có khe cắm mở rộng.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 4, 'PANEL': 4, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 13.4 inch WQXGA (2560x1600), IPS, 180Hz, DCI-P3 100%, 500nits.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 1x USB-A, 2x USB-C (Type-C USB 4), HDMI 2.1, và đầu đọc thẻ.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': 'Trọng lượng 1.20 kg, nằm trong mức <=1.2kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 70WHrs, đáp ứng tiêu chuẩn 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ sạc nhanh 0-50% trong 30 phút (thường ngụ ý công suất cao).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím Chiclet có đèn nền RGB, travel khoảng 1.5mm (dựa trên kích thước chung của dòng máy).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 13MP và có camera IR.'}, 'AUDIO_SCORE': {'score': 4, 'reason': '2x 2W lực kép với Dolby Atmos và Smart Amp.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có mật khẩu BIOS, bảo vệ mật khẩu người dùng và mô-đun TPM.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt (N/A), giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 90.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 1.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': [], 'not_suitable_profiles': ['U1_student', 'U10_entertainment']}}
{'laptop_id': 'Laptop ASUS ROG Strix G16 G614PH-S5101W', 'price_vnd': '44.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'AMD Ryzen 9 8940HX (Ryzen 9 series thuộc nhóm cao cấp nhất)'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5050 8GB GDDR7 (Mặc dù là dòng 5000, nhưng vị trí này tương đương mức RTX 4060/4070 trong thang điểm)'}, 'NPU_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin cụ thể về NPU, giả định thấp hơn các chip Apple/Ryzen AI cao cấp)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có 2 khe và khả năng nâng cấp lên 64GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 NVMe SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB qua 2 khe; SSD có thể nâng cấp thêm dung lượng (tối đa 2TB).'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 4, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': '16 inch WQXGA (QHD+), IPS, 240Hz, DCI-P3 100%, 500 nits, Anti-glare.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 2x USB 4 Type-C, 2x USB 3.2 Gen 2 Type-A, HDMI 2.1, LAN, Audio combo.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E (802.11ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.50 kg (Nằm trong khoảng 1.6-2.0kg đến 2.0kg, gần ngưỡng trên của mức 2)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '90WHrs (Trong khoảng 66-79Wh, tuy nhiên 90Whs hơi cao so với mức 4, nhưng vẫn ở mức tốt)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD (Sạc nhanh 0-50% trong 30 phút, ngụ ý công suất cao).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền RGB 4 vùng, travel tốt (giả định dựa trên phân khúc gaming/workstation).'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080P FHD camera (Không đề cập rõ ràng về IR).'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống 2 loa với công nghệ khử ồn AI, Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM (Firmware TPM) và bảo vệ mật khẩu BIOS/User.'}, 'THERMAL_SCORE': {'score': 4, 'reason': "Sử dụng 'ROG Intelligent Cooling' (cho thấy hệ thống tản nhiệt mạnh mẽ)."}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp rõ ràng.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 44.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U2_office', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop ASUS Vivobook 14 X1404VA-EB509W', 'price_vnd': '13.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i3-1315U (Gen 13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (Card đồ họa tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có Bộ xử lý AI/NPU được liệt kê)'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB DDR4 on board, có thể nâng cấp nhưng dung lượng thấp'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM có thể nâng cấp nhưng phức tạp)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD, IPS, 60Hz, 45% NTSC (Rất cơ bản)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C, HDMI, Audio Jack'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'DC-in (Không đề cập công suất sạc nhanh cụ thể)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Travel không rõ ràng (dưới 1.2mm hoặc layout lạ), không có đèn'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Camera HD 720p, có màn trập camera (Không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Cảm biến vân tay tích hợp, TPM, bảo vệ BIOS'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định dựa trên phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.53, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.83, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.83, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook 16 A1607QA-MB067WS', 'price_vnd': '17.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Snapdragon X X1 26 100 (8 lõi) thuộc phân khúc Core Ultra 5/7 100-series hoặc tương đương.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Qualcomm Adreno GPU (GPU tích hợp).'}, 'NPU_SCORE': {'score': 5, 'reason': 'Qualcomm Hexagon NPU up to 45TOPS.'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X Onboard, không có khả năng nâng cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không có khe cắm mở rộng.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 16 inch FHD (1920x1200), tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 2x USB-C, HDMI, và 3.5mm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.88 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '50WHrs nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh cụ thể (N/A).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím có đèn nền và travel >= 1.5mm (giả định dựa trên thông tin chung của dòng máy này).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello và màn trập vật lý.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp SonicMaster, công nghệ Smart Amp.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có nhiều lớp bảo mật: Webcam IR, TPM2.0, Microsoft Pluton, BIOS Password.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, thường là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (GPU tích hợp).', 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS VivoBook Go 14 E1404FA-EB935W', 'price_vnd': '17.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Core i5-H gen 12-13 (Ryzen 5 40) - Phù hợp với mức trung bình.'}, 'GPU_SCORE': {'score': 1, 'reason': 'AMD Radeon Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5 Onboard, không thể nâng cấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB Gen3 NVMe SSD.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM hàn liền và không có khe trống; SSD có thể thay thế nhưng không phải nâng cấp khe.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD, tấm nền IPS, 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1x USB-A, 1x USB-C, HDMI 1.4, và jack 3.5mm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.38 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'DC-in, không đề cập công suất sạc nhanh cao (PD).'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Chiclet keyboard, không có thông tin chi tiết về travel.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Camera HD 720p, có màn trập camera.'}, 'AUDIO_SCORE': {'score': 2, 'reason': 'Loa tích hợp và microphone mảng tích hợp.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có cảm biến vân tay, TPM firmware, và bảo vệ mật khẩu BIOS.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin về hệ thống tản nhiệt chuyên sâu).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin chung về dịch vụ bảo hành tại VN (cần xác nhận chi tiết).'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'GPU chỉ là đồ họa tích hợp (GPU_SCORE=1).', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U5_gamer']}}
{'laptop_id': 'Laptop ASUS TUF Gaming A14 FA401KM-RG010WS', 'price_vnd': '42.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 7 350 (8 lõi, 16 luồng) nằm trong phân khúc Core Ultra 7/Ryzen 7 7000+'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060 8GB GDDR7, thuộc nhóm RTX 4060/4070'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD XDNA NPU up to 50TOPS'}, 'RAM_SCORE': {'score': 3.5, 'reason': '32GB LPDDR5X, nhưng RAM hàn chết nên không nâng cấp được (+0.5 vì dung lượng lớn)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe 4.0 NVMe M.2 SSD'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM hàn chết)'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': '14 inch WQXGA (QHD+), IPS, 165Hz, 400nits, chống chói.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2x USB-A, 1x USB-C (Type-C hỗ trợ DP/Sạc), HDMI 2.1, SD, LAN, Audio.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E (802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.46 Kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 4, 'reason': '73WHrs, nằm trong khoảng 66-79Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (sạc nhanh 0-50% trong 30 phút)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc cao cấp) + đèn nền.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera IR FHD 1080P cho Windows Hello.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Công nghệ chống ồn AI, Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Mật khẩu BIOS, Pluton Security Processor, Máy tính lõi bảo mật Cấp độ 3.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn (2 quạt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 42.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop ASUS Gaming V16 V3607VU-RP290W', 'price_vnd': '24.190.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core 5 210H (Gen 12/13 thế hệ mới hơn nhưng thuộc phân khúc Core i5-H)'}, 'GPU_SCORE': {'score': 3, 'reason': 'RTX 4050 6GB GDDR6 (Thuộc phân khúc RTX 4050)'}, 'NPU_SCORE': {'score': 4, 'reason': '194 AI TOPs (Tương đương Intel Core Ultra 200V/H)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 SO-DIMM, có thể nâng cấp nhưng giới hạn ở mức 16GB hiện tại'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM có thể nâng cấp nhưng yêu cầu tháo lắp phức tạp)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 3, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '16 inch FHD (1920x1200), Panel nhựa, 144Hz, độ phủ màu thấp (45% NTSC)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (hỗ trợ hiển thị/sạc), HDMI 2.1'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.95 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '63WHrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'DC-in, không có thông tin về công suất sạc nhanh cụ thể'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc), có đèn nền'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p FHD với màn trập camera (Không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Mật khẩu BIOS, TPM2.0'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định theo phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop ASUS ExpertBook P1 P1403CVA-C5H16-63WS', 'price_vnd': '25.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core 5 210H (Gen 12/13) - Phù hợp với mức Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics tích hợp (Không có card đồ họa rời mạnh).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU mạnh).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 SO-DIMM, có thể nâng cấp nhưng giới hạn ở mức 16GB hiện tại.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp (cần tháo lắp); SSD có khe mở rộng.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD (1920x1080), tần số quét 60Hz, độ phủ màu thấp (NTSC 45%).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 2x USB-C, HDMI, LAN, 3.5mm.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.47 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '63Whrs, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh (PD), chỉ có cổng USB-C.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel khoảng 1.2-1.5mm và có đèn nền (Chiclet).'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD 720p, có màn trập camera (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Âm thanh do Dirac cung cấp, loa tích hợp.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có TPM 2.0, mật khẩu BIOS, bảo vệ ổ cứng.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (GPU_SCORE=1)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop ASUS Vivobook S14 S3407QA-SF043WS', 'price_vnd': '23.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Snapdragon X X1 26 100 (Hiệu năng tầm trung cao)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Qualcomm Adreno GPU (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Qualcomm Hexagon NPU up to 45TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X Onboard (Không có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM hàn liền và không có khe cắm mở rộng'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, 95% DCI-P3, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-A, 2x USB-C (Type-C hỗ trợ hiển thị/cấp nguồn), HDMI 2.1, Audio'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.35 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin sạc nhanh cụ thể)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Có đèn nền, travel khoảng 1.2-1.5mm (Giả định dựa trên thông tin chung của dòng máy)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập camera'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp SonicMaster, Công nghệ Smart Amp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam hồng ngoại hỗ trợ Windows Hello, TPM2.0, Microsoft Pluton'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể về thời hạn và dịch vụ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Zenbook 14 UX3405CA-PZ187WS', 'price_vnd': '28.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 225H (Core Ultra 5 100-series) với NPU'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel AI Boost NPU up to 13 TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X on board (Tiêu chuẩn 16GB)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM On board (Không có khe cắm mở rộng) và SSD đã lắp'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, độ phân giải cao, 120Hz, DCI-P3 100%, chống lóa'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-C (Thunderbolt 4), 1x HDMI, 1x USB-A'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) và Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg (1.28 kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75WHrs (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'N/A (Không đề cập chi tiết công suất sạc, giả định là USB-C PD tiêu chuẩn)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (Giả định dựa trên phân khúc cao)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello và màn trập vật lý'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ Smart Amp, Loa tích hợp (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR hỗ trợ Windows Hello, TPM2.0 (Phần mềm TPM)'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 28.69M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.25, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.85, 'final_score': 1.9, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop ASUS VivoBook 15 M1502NAQ-BQ031W', 'price_vnd': '18.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 7 170 (Gen cũ hơn yêu cầu của mức 4)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp nhưng giới hạn ở 16GB hiện tại'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp (2 khe); SSD có thể nâng cấp (dựa trên cấu trúc M.2)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD, IPS panel, 60Hz, 45% NTSC (Rất kém về màu sắc và tần số quét)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 2x USB-C (PD), HDMI 1.4, có jack 3.5mm'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.70 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42Whrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Chiclet có phím số, travel không rõ ràng nhưng có đèn'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Camera HD 720p, có màn trập camera (Không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp SonicMaster, Microphone mảng tích hợp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Cảm biến vân tay, TPM 2.0, Mật khẩu BIOS'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại VN không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'DISPLAY_SCORE quá thấp (60Hz, 45% NTSC) và GPU_SCORE = 1 (iGPU)', 'price_score': 2, 'weighted_score': 2.3, 'final_score': 2.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U5_gamer']}}
{'laptop_id': 'Laptop ASUS Gaming V16 V3607VM-RP044W', 'price_vnd': '33.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core 7 240H (10 lõi, 16 luồng) thuộc nhóm Core i7-H gen>=13.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060 8GB GDDR7, mạnh mẽ hơn mức 4060/4070 hiện tại.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU (Bộ xử lý AI / NPU: N/A).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có 2 khe và khả năng nâng cấp lên 32GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB M.2 NVMe PCIe 4.0 SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB qua 2 khe; SSD có thể nâng cấp thêm.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 4, 'PANEL': 2, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch WUXGA (FHD+), tần số quét 144Hz, nhưng độ phủ màu chỉ 45% NTSC (rất thấp).'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C (Type-C), HDMI 2.1, và cổng âm thanh.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.95 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '63WHrs, mức tiêu chuẩn cho laptop hiệu năng cao.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Sử dụng DC-in, không đề cập đến sạc nhanh USB-C PD cao.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': "Có đèn nền và travel key được giả định là đạt chuẩn (dựa trên mô tả 'Chiclet có đèn nền')."}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p FHD với màn trập camera (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp SonicMaster và micrô tích hợp.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có mật khẩu BIOS và TPM2.0.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, mặc định là cấu hình tiêu chuẩn.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành tiêu chuẩn 1 năm tại trung tâm bảo hành.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 33.29M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop ASUS Vivobook 14 M1405NAQ-LY011W', 'price_vnd': '18.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 7 170 (Gen cũ hơn yêu cầu của mức 4)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp nhưng giới hạn ở 16GB hiện tại'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM (2 khe) và SSD (dựa trên cấu trúc)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD (1920x1200), IPS, 60Hz, 45% NTSC (Rất kém về màu sắc)'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có nhiều cổng USB-A và USB-C, nhưng thiếu HDMI 2.1 và Thunderbolt'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.60 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42Whrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD 5Gbps (Không đề cập công suất cụ thể cao)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Đèn nền LED, travel khoảng 1.2-1.5mm (giả định)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Camera HD 720p, có màn trập nhưng không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Mic đa hướng tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Cảm biến vân tay tích hợp, TPM, bảo vệ BIOS'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành tiêu chuẩn 1 năm tại trung tâm BH'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS TUF Gaming F16 FX608JH-RV039W', 'price_vnd': '31.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13450HX (Gen 13) thuộc nhóm Core i7-H gen>=13 hoặc tương đương.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5050 8GB GDDR7, mạnh mẽ hơn RTX 4060/4070 trong phân khúc này.'}, 'NPU_SCORE': {'score': 2, 'reason': 'Không có thông tin cụ thể về NPU, giả định là mức cơ bản (<11 TOPS).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, đủ dùng nhưng chưa đạt ngưỡng 32GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe 4.0 NVMe SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có 2 khe RAM và khả năng nâng cấp lên tối đa 64GB; SSD cũng có 2 khe M.2.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch WUXGA (1920x1200), IPS, 165Hz, 300 nits, màu sắc khá tốt.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 1x LAN, 1x Thunderbolt 4, 3x USB-A, 1x HDMI 2.1, USB-C.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 3, 'reason': 'Trọng lượng 2.20 Kg nằm trong khoảng 1.4-1.6kg đến 2.0kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 90WHrs, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (dựa trên cấu hình cao cấp thường hỗ trợ 65W trở lên).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard có travel >= 1.5mm và có đèn nền RGB.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera IR FHD 1080P cho phép sử dụng Windows Hello.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Có công nghệ chống ồn AI và Dolby Atmos, nhưng chỉ có 2 loa stereo cơ bản.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM2.0 và bảo vệ mật khẩu BIOS/người dùng.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là 2 quạt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 31.89tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U8_business', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS VivoBook 14 X1407CA-LY008W', 'price_vnd': '21.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 225H (Core Ultra 5 100-series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU up to 13TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 on board, không có khả năng nâng cấp'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có khả năng nâng cấp RAM hoặc SSD'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD (1920x1200), IPS, 60Hz, 45% NTSC'}, 'PORTS_SCORE': {'score': 3, 'reason': '2 USB-A, 2 USB-C, HDMI, 3.5mm'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.46 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin sạc nhanh cụ thể)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Có đèn nền, travel 1.2-1.5mm (giả định)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD với chức năng hồng ngoại'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Microphone mảng tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'TPM, mật khẩu BIOS, McAfee'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định dựa trên phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Zenbook S 16 UM5606KA-RK127WS', 'price_vnd': '40.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'AMD Ryzen AI 7 350 (thuộc nhóm chip cao cấp hiện đại)'}, 'GPU_SCORE': {'score': 1, 'reason': 'AMD Radeon Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 5, 'reason': 'AMD XDNA NPU up to 50TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '24GB LPDDR5X Onboard (16GB là mức chuẩn, không thể nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard (Không thể nâng cấp) và SSD đã lắp sẵn'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 16 inch OLED, 2880x1800, 120Hz, 100% DCI-P3, Anti-glare.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2x USB 4.0 Gen 3 Type-C, 1x USB-A, HDMI 2.1, SD Card, LAN, Audio.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.50 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '78WHrs (trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không đề cập chi tiết về công suất sạc nhanh)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Chiclet có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc cao)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ Smart Amp, Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Webcam IR, Microsoft Pluton, TPM2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về thời hạn bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 40.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.4, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U2_office', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop ASUS VivoBook S14 M3407HA-SF480W', 'price_vnd': '22.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 2, 'reason': 'AMD Ryzen 5 220 (chip thế hệ cũ)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 on board, nhưng không rõ khả năng nâng cấp'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về việc nâng cấp RAM hoặc SSD'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, độ phủ màu cao (95% DCI-P3), nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 2 USB-C, HDMI, và 3.5mm'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về sạc nhanh (N/A)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Bàn phím Chiclet có đèn nền'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello và màn trập vật lý'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Microphone mảng tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có TPM (Firmware TPM), mật khẩu BIOS, McAfee'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 2, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
None
{'laptop_id': 'Laptop ASUS Vivobook S14 S5406SA-PP168WS', 'price_vnd': '25.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 226V (Core Ultra 5 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Arc Graphics (Card đồ họa tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU up to 40TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X, không có khả năng nâng cấp'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có khả năng nâng cấp RAM hoặc SSD'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, 120Hz, 100% DCI-P3, độ sáng cao.'}, 'PORTS_SCORE': {'score': 5, 'reason': '2x USB-A, 2x Thunderbolt 4, HDMI 2.1, SD, LAN, Audio'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg (1.30 kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75WHrs'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không đề cập chi tiết về công suất sạc nhanh)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel >= 1.5mm (giả định dựa trên phân khúc cao cấp) + Backlit'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD có chức năng IR hỗ trợ Windows Hello và màn trập vật lý'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp, Harman/Kardon (Mainstream)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR, Microsoft Pluton, TPM2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định theo phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 25.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.85, 'final_score': 2.9, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop ASUS Vivobook S16 S3607CA-SH082WS', 'price_vnd': '22.090.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 225H (Core Ultra 5 series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU up to 13TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp nhưng cần tháo vỏ'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp, SSD có thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 16 inch OLED, 95% DCI-P3, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 2x USB-C, 1x HDMI'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.70 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên cấu hình cao cấp)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR, TPM2.0, Bảo vệ mật khẩu BIOS'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể về thời gian và dịch vụ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
None
{'laptop_id': 'Laptop ASUS ROG Zephyrus G14 GA403WM-QS051WS', 'price_vnd': '55.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'AMD Ryzen AI 9 HX 370 (Chip thế hệ mới nhất, thuộc nhóm cao cấp)'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060 8GB GDDR7 (Hiệu năng mạnh mẽ)'}, 'NPU_SCORE': {'score': 5, 'reason': 'AMD XDNA NPU up to 50TOPS (Rất cao)'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB LPDDR5X Onboard (Đủ dung lượng nhưng không thể nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe 4.0 NVMe M.2 SSD'}, 'UPGRADABILITY': {'score': 2, 'reason': 'RAM Onboard và không có khe cắm mở rộng.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, 2880x1800, 120Hz, DCI-P3 100%, 500nits.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 2x USB-A, 2x USB-C (có DP/Power), HDMI 2.1, SD, LAN.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.50 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '73Whrs (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD hỗ trợ sạc nhanh 0-50% trong 30 phút (Ngụ ý công suất cao).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền RGB và travel key tốt (dựa trên mô tả chung của dòng máy gaming).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera IR FHD 1080P cho Windows Hello.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống 4 loa với Dolby Atmos và công nghệ chống ồn AI.'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Bảo mật cao: Pluton, mật khẩu BIOS, bảo vệ mật khẩu người dùng.'}, 'THERMAL_SCORE': {'score': 4, 'reason': 'Tản nhiệt thông minh ROG (Cho thấy khả năng kiểm soát nhiệt tốt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể (Giả định mức trung bình).'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 55.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.83, 'final_score': 1.8, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U2_office'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop ASUS ZenBook 14 UX3405CA-ST629W', 'price_vnd': '34.090.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 7 255H (thuộc nhóm Core Ultra 7/9 200-series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU up to 13TOPS'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB LPDDR5X on board'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB Gen4 SSD'}, 'UPGRADABILITY': {'score': 2, 'reason': 'RAM và SSD đều không thể nâng cấp (N/A)'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, 120Hz, 100% DCI-P3, 500 nits.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2x USB-C Thunderbolt 4, HDMI, và USB-A'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.20 kg (<1.2kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75WHrs (trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (Không ghi rõ công suất cụ thể, giả định mức trung bình)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc cao)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD với chức năng hồng ngoại (IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp với Công nghệ Smart Amp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR hỗ trợ Windows Hello và TPM Firmware'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể về thời gian và dịch vụ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 34.09tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.25, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Gaming V16 V3607VJ-RP071W', 'price_vnd': '26.190.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core 5 210H (Gen mới, hiệu năng tầm trung cao)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB (Phù hợp mức cơ bản đến tầm trung)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp nhưng giới hạn ở 16GB hiện tại'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có vẻ dễ nâng cấp hơn RAM (cần tháo lắp)'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch WUXGA (FHD+), tần số quét 144Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (hỗ trợ xuất hình/sạc), 1x HDMI, 1x Audio'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.95 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '63Whrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'DC-in (Không đề cập công suất PD cụ thể)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền và phím số'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera FHD 1080p, có màn trập camera (không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp và Micro tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'BIOS password và TPM (Trusted Platform Module)'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể về thời gian và dịch vụ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 26.19tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
None
{'laptop_id': 'Laptop ASUS Vivobook S14 S3407CA-LY095WS', 'price_vnd': '23.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 225H (Core Ultra 5 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU up to 13TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 Onboard (16GB, không nâng cấp được)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM hàn liền và không có khe cắm mở rộng'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD (1920x1200), IPS, 60Hz, 45% NTSC'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 2x USB-C, 1x HDMI 1.4, Audio combo'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin sạc nhanh cụ thể)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập camera'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR hỗ trợ Windows Hello, TPM2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (chỉ có tích hợp)', 'price_score': 2, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U5_gamer']}}
{'laptop_id': 'Laptop ASUS ZenBook 14 UM3406GA-QD073WS', 'price_vnd': '36.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'AMD Ryzen AI 7 445 (Thuộc nhóm Ryzen AI 300/cao cấp)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 5, 'reason': 'AMD XDNA NPU up to 50TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB LPDDR5X on board (Không thể nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM hàn liền và không có khe trống'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, 100% DCI-P3, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-C (bao gồm Thunderbolt), 1 HDMI, 1 USB-A, 1 cổng 3.5mm'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.20 kg (<1.2kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75WHrs (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập chi tiết về công suất sạc nhanh (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím Chiclet có đèn nền, travel không rõ nhưng thường đáp ứng tiêu chuẩn'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello, có màn trập camera'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micro đa hướng tích hợp'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Webcam IR, TPM 2.0, Microsoft Pluton'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop ASUS Vivobook 14 X1404VA-EB355W', 'price_vnd': '22.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core 7 150U 10 lõi, 12 luồng (Core Ultra 7/9 series tương đương)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics tích hợp'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU mạnh)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp nhưng giới hạn ở mức 16GB hiện tại'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB Gen4 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp, SSD có thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD, IPS panel, 60Hz, 45% NTSC (Rất cơ bản)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C, 1x HDMI, 1x Audio combo'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'DC-in (Không đề cập công suất PD cao)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel 1.2-1.5mm + Backlit'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Camera HD 720p, có màn trập camera (Không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp và Mic đa hướng tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Vân tay tích hợp, TPM 2.0, bảo vệ BIOS'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS VivoBook 14 M1407GA-LY270W', 'price_vnd': '24.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 7 445, thuộc nhóm Core Ultra 5/7 100-series hoặc tương đương.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics).'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD XDNA NPU up to 50TOPS.'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 on board, nhưng không có thông tin về khả năng nâng cấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD.'}, 'UPGRADABILITY': {'score': 2, 'reason': 'RAM và SSD đều không thể nâng cấp (N/A).'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD (1920x1200), tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 2 USB-C, HDMI, và 3.5mm.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.46 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs, nằm trong khoảng 30-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin cụ thể về công suất sạc nhanh (N/A).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím Chiclet có đèn nền, travel không được ghi rõ nhưng thường đáp ứng tiêu chuẩn.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD với chức năng hồng ngoại (IR) hỗ trợ Windows Hello.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp SonicMaster và microphone mảng tích hợp.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Webcam IR, TPM 2.0, Microsoft Pluton, và mật khẩu BIOS.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Gaming V16 V3607VH-RP025W', 'price_vnd': '31.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core 7 240H (10 lõi, 16 luồng, xung nhịp cao)'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5050 8GB GDDR7 (Hiệu năng mạnh mẽ)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 SO-DIMM, có thể nâng cấp nhưng yêu cầu tháo lắp'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp, SSD có thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 4, 'PANEL': 2, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch WUXGA (FHD+), Panel nhựa, 144Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-A, 1x USB-C (Type-C hỗ trợ Display/Power), HDMI 2.1, Audio'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.95 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '63WHrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'DC-in (Không đề cập công suất PD cụ thể)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (Giả định dựa trên cấu hình tầm trung cao)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera FHD 1080p, có màn trập camera (Không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp SonicMaster, Micrô tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Mật khẩu BIOS, TPM2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 31.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop ASUS TUF Gaming A16 FA608UM‑RV266W', 'price_vnd': '42.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 260 (Gen cũ hơn các chuẩn mới nhưng vẫn mạnh mẽ)'}, 'GPU_SCORE': {'score': 3, 'reason': 'RTX 5060 8GB GDDR7 (Mới, nhưng xếp ở mức tầm trung)'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD XDNA NPU up to 16TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có 2 khe, khả năng nâng cấp lên 64GB'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 NVMe SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (2 khe) và SSD (2 khe M.2) đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': '16 inch WUXGA (QHD+ tương đương), IPS, 165Hz, 300 nits, chống chói tốt.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối bao gồm USB-C USB 4, 2x USB-A, HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.20 kg, nằm trong khoảng 1.6-2.0kg đến 2.0kg'}, 'BATTERY_SCORE': {'score': 4, 'reason': '90WHrs, dung lượng pin khá tốt'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ sạc nhanh (0-50% trong 30 phút)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền RGB và travel key tốt (giả định dựa trên cấu hình gaming/cao cấp)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera hồng ngoại FHD 1080P'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Công nghệ khử ồn AI và Dolby Atmos'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Pluton và Secured-core PC (Cấp độ 3)'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là 2 quạt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 42.79M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook S16 S3607CA-SH083WS', 'price_vnd': '26.090.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 7 255H (thuộc nhóm Core Ultra 7/9 200-series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU up to 13TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp nhưng cần tháo vỏ'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM có thể nâng cấp nhưng phức tạp)'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 16 inch OLED, 95% DCI-P3, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 2x USB-C, 1x HDMI'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.70 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên cấu hình tầm trung cao)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam hồng ngoại hỗ trợ Windows Hello, TPM2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể về thời gian và dịch vụ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (16GB) >= 8GB, SSD (512GB) không phải HDD/eMMC, giả định có BH.', 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS VivoBook 16 X1607CA-MB980W', 'price_vnd': '21.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 225H (Core Ultra 5 100-series) với NPU 13TOPS.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics tích hợp (Không có GPU rời mạnh).'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU up to 13TOPS.'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 on board, nhưng không có khả năng nâng cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM và SSD đều không thể nâng cấp (N/A).'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 16 inch FHD (1920x1200), tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 2x USB-C, 1x HDMI.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.2.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.88 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin cụ thể về sạc nhanh (N/A).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím Chiclet có đèn nền và phím số, travel không được ghi rõ nhưng thường chấp nhận được.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD với chức năng hồng ngoại (IR) hỗ trợ Windows Hello và có màn trập camera.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp SonicMaster và microphone mảng tích hợp.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Webcam IR hỗ trợ Windows Hello, Firmware TPM, và bảo vệ mật khẩu BIOS.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'GPU_SCORE = 1 (Không có GPU rời mạnh)', 'price_score': 2, 'weighted_score': 2.3, 'final_score': 2.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U5_gamer']}}
{'laptop_id': 'Laptop ASUS TUF Gaming F16 FX608JMI‑TU241W', 'price_vnd': '42.090.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7 14650HX (Gen 14) thuộc nhóm Core i7-H gen>=13.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060 8GB GDDR7, mạnh mẽ hơn RTX 4060/4070.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU (Bộ xử lý AI / NPU: N/A).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, mức tiêu chuẩn hiện tại.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 NVMe SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có 2 khe RAM và khả năng nâng cấp lên tối đa 64GB; SSD có 2 khe cắm M.2.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch WUXGA (1920x1200), IPS, 144Hz, 400 nits, độ phủ màu tốt.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 3x USB-A, 1x USB-C (DP/PD), 1x HDMI 2.1, LAN, Audio jack.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.20 Kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs, mức dung lượng trung bình.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Thông tin sạc nhanh không được cung cấp chi tiết (N/A).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard có travel >= 1.5mm và có đèn nền RGB.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080P FHD Camera, không đề cập đến IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ khử ồn AI và Dolby Atmos, thường đi kèm với cấu hình tốt.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có bảo vệ bằng mật khẩu BIOS và TPM module.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt (N/A).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 42.09M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.25, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.05, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.85, 'final_score': 1.9, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop ASUS Vivobook Go 15 E1504FA-BQ340W', 'price_vnd': '17.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 5 40 (4 lõi, 8 luồng), thuộc phân khúc Core i5-H gen 12-13 hoặc Ryzen 5 7000.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5 on board, dung lượng vừa phải.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 NVMe PCIe 3.0 SSD.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM và SSD không thể nâng cấp (N/A).'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1x USB-A 2.0, 1x USB-A 3.2 Gen 1, 1x USB-C, 1x HDMI 1.4.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E (802.11ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.63 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Sử dụng DC-in, không đề cập đến sạc nhanh USB-C PD cao.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel key khoảng 1.2-1.5mm và có đèn nền.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Camera HD 720p, không có IR.'}, 'AUDIO_SCORE': {'score': 2, 'reason': 'Loa tích hợp và microphone mảng tích hợp (2 loa stereo yếu).'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có McAfee, bảo vệ mật khẩu BIOS và TPM.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, khả năng cao là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin chung về dịch vụ bảo hành tại VN (cần xác nhận chi tiết).'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (chỉ có tích hợp)', 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook S14 S3407CA-LY096WS', 'price_vnd': '27.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 7 255H (Core Ultra 7 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (Card đồ họa tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU up to 13TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 Onboard (16GB, không có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Khó nâng cấp (RAM Onboard, SSD có thể thay thế nhưng không có khe trống)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch, IPS, 60Hz, 45% NTSC (Rất hạn chế về tần số quét và độ phủ màu)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 2x USB-C, 1x HDMI, Audio combo'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin sạc nhanh cụ thể)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (Giả định dựa trên cấu hình tầm trung)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập camera'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR hỗ trợ Windows Hello, TPM2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (16GB) >= 8GB, SSD (512GB PCIe 4.0) != HDD/eMMC, Warranty OK.', 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook S14 M3407KA-SF034WS', 'price_vnd': '23.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 5 330 (thuộc dòng Ryzen AI, tương đương Core Ultra 5/7 thế hệ mới)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon Graphics'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD XDNA NPU up to 50TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 Onboard (Đủ dùng nhưng không thể nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không có khe cắm mở rộng'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, 95% DCI-P3, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 2x USB-C, 1x HDMI'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6(802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không đề cập chi tiết về công suất sạc nhanh)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc tầm trung)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello và màn trập vật lý'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR, TPM2.0, Microsoft Pluton'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook S14 M3407HA-SF490W', 'price_vnd': '24.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 7 260 3.8GHz (Chip thế hệ cũ hơn tiêu chuẩn hiện tại)'}, 'GPU_SCORE': {'score': 1, 'reason': 'AMD Radeon Graphics (Tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD XDNA NPU up to 16TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 on board, không có khả năng nâng cấp'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có khả năng nâng cấp RAM hoặc SSD'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 3, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, 95% DCI-P3, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 2 USB-C, HDMI, và 3.5mm'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6(802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin cụ thể về công suất sạc nhanh (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên cấu trúc máy tầm trung)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello; Có màn trập camera'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp và Micro tích hợp (array)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam hồng ngoại (IR) hỗ trợ Windows Hello, TPM (Firmware TPM), mật khẩu BIOS'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS VivoBook 16 M3607GA-SH034W', 'price_vnd': '27.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 7 445 (Ryzen 7 7000+) đạt mức 4'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD XDNA NPU up to 50TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 on board, có thể nâng cấp nhưng là 16GB cố định'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM là on board)'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch OLED, 95% DCI-P3, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 2x USB-C, 1x HDMI'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6(802.11ax) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.80 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs nằm trong khoảng 50-65Wh'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím Chiclet có đèn nền'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD với chức năng hồng ngoại (IR) hỗ trợ Windows Hello và màn trập vật lý'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Microphone mảng tích hợp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR, TPM2.0, mật khẩu BIOS'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể về thời hạn và dịch vụ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (16GB) >= 8GB, SSD (512GB NVMe) != HDD/eMMC, Warranty status unknown (giả định không có BH tại VN)', 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS VivoBook S14 M3407GA-SF030W', 'price_vnd': '25.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 7 445 (Ryzen 7 7000+) - Mạnh mẽ cho tác vụ AI.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics).'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD XDNA NPU up to 50TOPS.'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 on board. Không có thông tin về khả năng nâng cấp thêm.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD.'}, 'UPGRADABILITY': {'score': 2, 'reason': 'RAM hàn liền và không có khe cắm mở rộng.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, độ phủ màu DCI-P3 95%, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 2 USB-C, 1 HDMI.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6(802.11ax) và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '70WHrs nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin cụ thể về công suất sạc nhanh (N/A).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím Chiclet có đèn nền, giả định travel tốt.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD với chức năng hồng ngoại (IR) hỗ trợ Windows Hello và màn trập vật lý.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp sẵn, microphone mảng tích hợp.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Webcam IR hỗ trợ Windows Hello, TPM Firmware, và bảo vệ BIOS.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, mặc định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook S14 S3407AA-SF032W', 'price_vnd': '32.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 7 355 (Core Ultra 7 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel NPU up to 49TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 Onboard (Không có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không có khe cắm thêm'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, 95% DCI-P3, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2 USB-A, 2 USB-C, HDMI'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '70WHrs (trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin sạc nhanh cụ thể)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD với chức năng hồng ngoại (IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Microphone mảng tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'TPM (Firmware TPM), Mật khẩu BIOS, McAfee'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (16GB) >= 8GB, SSD (512GB NVMe) != HDD/eMMC, Warranty (1 năm) tại VN. Tuy nhiên, Price Score (3) và UPGRADABILITY (1) ảnh hưởng tiêu cực.', 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS VivoBook S14 S3407CA-SF923W', 'price_vnd': '27.090.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 7 255H (Core Ultra 7 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU up to 13TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 on board (Tiêu chuẩn cho máy tính văn phòng/đa nhiệm)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 2, 'reason': 'RAM không nâng cấp được (on board), SSD có thể nâng cấp nhưng không rõ ràng'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, 95% DCI-P3, độ sáng 300 nits, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-A, 2 USB-C, HDMI, và 3.5mm'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD với chức năng hồng ngoại (IR) và màn trập vật lý'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp và Micro mảng tích hợp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR hỗ trợ Windows Hello, TPM2.0, McAfee, bảo vệ BIOS'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U5_gamer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS VivoBook S14 S3407CA-SF913W', 'price_vnd': '24.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 225H (Core Ultra 5 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics (Tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU up to 13TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 on board (Tiêu chuẩn cho máy tính văn phòng/đa nhiệm)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 2, 'reason': 'RAM không nâng cấp được (on board), SSD có thể nâng cấp nhưng không rõ ràng'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, 95% DCI-P3, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-A, 2 USB-C, HDMI, và 3.5mm'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin cụ thể về công suất sạc nhanh (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD với chức năng hồng ngoại hỗ trợ Windows Hello; Có màn trập camera'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp và Micro mảng tích hợp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR hỗ trợ Windows Hello, TPM2.0, Bảo vệ BIOS'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS TUF Gaming A14 FA401EA‑RG034W', 'price_vnd': '63.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'AMD Ryzen AI MAX+ 392 (12 lõi, 24 luồng) thuộc nhóm chip cao cấp nhất.'}, 'GPU_SCORE': {'score': 3, 'reason': 'Card đồ họa tích hợp AMD Radeon 8060S Graphics (Không phải dòng RTX cao cấp).'}, 'NPU_SCORE': {'score': 5, 'reason': 'AMD XDNA NPU up to 50TOPS, đạt mức cao nhất.'}, 'RAM_SCORE': {'score': 3, 'reason': '64GB RAM, nhưng là LPDDR5X on board (không thể nâng cấp thêm).'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe 4.0 NVMe SSD.'}, 'UPGRADABILITY': {'score': 2, 'reason': 'RAM hàn liền (N/A) và SSD có 1 khe cắm M.2 nhưng khả năng nâng cấp phụ thuộc vào cấu trúc máy.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch WQXGA (QHD+), IPS, 165Hz, 100% sRGB, chống chói.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2 USB-A, 2 USB-C (bao gồm USB4), HDMI 2.1, khe microSD, LAN và jack 3.5mm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.48 Kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '73Whr nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Thông tin sạc nhanh không được cung cấp cụ thể (N/A).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc cao cấp) và có đèn nền.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera hồng ngoại FHD 1080P.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ khử ồn AI và Dolby Atmos (thường đi kèm với cấu hình tầm trung cao).'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Bảo vệ mật khẩu BIOS và mật khẩu người dùng.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt (N/A).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 63.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop ASUS ROG Zephyrus G14 GA403GM-SY004W', 'price_vnd': '63.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'AMD Ryzen AI 9 465 (10 lõi, 20 luồng) thuộc nhóm chip cao cấp nhất.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060 8GB GDDR7, hiệu năng mạnh mẽ.'}, 'NPU_SCORE': {'score': 5, 'reason': 'AMD XDNA NPU up to 50TOPS, đạt mức cao nhất.'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB RAM, nhưng không thể nâng cấp (hàn liền).'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe 4.0 NVMe SSD.'}, 'UPGRADABILITY': {'score': 2, 'reason': 'RAM không thể nâng cấp, SSD có thể nâng cấp (nhưng giới hạn dung lượng tối đa).'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, độ phân giải cao (2880x1800), tần số quét 120Hz, độ sáng HDR 1000 nits, chất lượng màu xuất sắc.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 2x USB-A, 2x USB-C (bao gồm USB4), HDMI 2.1, SD, LAN.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': 'Trọng lượng 1.50 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 73Whrs nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sử dụng USB-C PD (sạc nhanh) với công suất cao.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền RGB và travel key tốt (giả định dựa trên cấu hình cao cấp).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera hồng ngoại FHD 1080P.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống 4 loa với Dolby Atmos và công nghệ khử tiếng ồn AI.'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Bảo mật cao cấp với Pluton, mật khẩu BIOS, và các tính năng bảo mật sinh trắc học (dựa trên mô tả).'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là thiết kế tản nhiệt cơ bản (2 quạt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về chính sách bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 63.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.4, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
None
{'laptop_id': 'Laptop ASUS Zenbook S 14 OLED UX5406SA-PV140WS', 'price_vnd': '40.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 7-258V với NPU lên đến 47 TOPs, đạt mức cao nhất.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Arc Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU lên đến 47 TOPs.'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB LPDDR5X Onboard, nhưng không thể nâng cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB M.2 NVMe PCIe 4.0 SSD.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không có khe cắm mở rộng.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, 100% DCI-P3, 500nits, 120Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-C (Thunderbolt 4), 1x USB-A, HDMI 2.1.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.20 kg, dưới 1.2kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '72WHrs, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không đề cập chi tiết về công suất sạc nhanh).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc cao).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Micrô mảng tích hợp harman/kardon, công nghệ Smart Amp.'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Webcam IR, Microsoft Pluton, TPM2.0.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về hệ thống tản nhiệt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp rõ ràng.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 40.69M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U2_office', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop ASUS ZenBook S 14 UX5406AA SU415WS', 'price_vnd': '48.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 9 386H, thuộc nhóm chip cao cấp nhất.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 5, 'reason': 'Intel NPU up to 50TOPS.'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB LPDDR5X Onboard, nhưng không thể nâng cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM hàn liền và không có khe cắm nâng cấp.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, độ phân giải cao, tần số quét 120Hz và độ phủ màu DCI-P3 100%.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-C (Thunderbolt 4), 1x USB-A, HDMI.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) và Bluetooth 6.0.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.20 kg, nằm trong mức <1.2kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '77WHrs, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (sử dụng Thunderbolt 4).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím có đèn nền, travel tốt (giả định dựa trên cấu hình cao cấp).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD tích hợp chức năng hồng ngoại (IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ Smart Amp, Loa tích hợp (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Webcam IR hỗ trợ Windows Hello, Microsoft Pluton, TPM.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là thiết kế tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (32GB) >= 8GB, SSD (512GB NVMe) != HDD/eMMC, Warranty status unknown (assume not BH in VN for strictness if not specified). Based on the provided criteria, we check RAM >= 8GB and SSD is not HDD/eMMC. Since RAM is high, this might pass, but UPGRADABILITY is 1.', 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.4, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS ROG Zephyrus G14 GA403WW-QS145WS', 'price_vnd': '82.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'AMD Ryzen AI 9 HX 370 - Chip thế hệ mới nhất, thuộc nhóm cao cấp.'}, 'GPU_SCORE': {'score': 5, 'reason': 'NVIDIA GeForce RTX 5080 16GB GDDR7 - Card đồ họa flagship hiện tại.'}, 'NPU_SCORE': {'score': 5, 'reason': 'AMD XDNA NPU up to 50TOPS - Hiệu năng NPU rất cao.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '32GB LPDDR5X, nhưng là Onboard nên không nâng cấp được (+0.5 vì dung lượng lớn).'}, 'SSD_SCORE': {'score': 5, 'reason': '2TB PCIe 4.0 NVMe M.2 SSD - Dung lượng lớn và chuẩn tốc độ cao.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': '14 inch OLED, 2880x1800, 120Hz, DCI-P3 100%, 500 nits, Anti-glare.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 2x USB-A, 1x USB 4, 1x USB-C, HDMI 2.1, SD, LAN.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.57 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '73WHrs, mức pin khá tốt.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD hỗ trợ sạc nhanh 0-50% trong 30 phút.'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Có đèn nền RGB, thiết kế chất lượng cao (giả định travel tốt).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera hồng ngoại FHD 1080P.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống 4 loa với công nghệ khử ồn AI và Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Bảo mật cao với Pluton, mật khẩu BIOS, và bảo vệ máy tính Secured-core.'}, 'THERMAL_SCORE': {'score': 4, 'reason': 'Tản nhiệt ROG Intelligent Cooling, đảm bảo hiệu năng tốt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin không cung cấp chi tiết về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 82.49M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.4, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 2.9, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U5_gamer'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop ASUS Zenbook 14 UX3405CA-PZ188WS', 'price_vnd': '33.190.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 7 255H (thuộc nhóm Core Ultra 7/9 200-series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU up to 13TOPS'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB LPDDR5X on board'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 2, 'reason': 'RAM On board (Không có khe cắm mở rộng) và SSD đã lắp sẵn'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, độ phân giải cao, 100% DCI-P3, 120Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-C (Thunderbolt 4), 1x HDMI, 1x USB-A'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.28 kg (<1.2kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75WHrs (trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'N/A (Không ghi rõ công suất sạc cụ thể, giả định USB-C PD tiêu chuẩn)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc cao)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello và màn trập vật lý'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ Smart Amp, Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR hỗ trợ Windows Hello, TPM (Phần mềm TPM)'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không đề cập chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 33.19tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.6, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Zenbook 14 UM3406KA-PP113WS', 'price_vnd': '27.090.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 7 350 (8 lõi, 16 luồng) thuộc nhóm Core Ultra 7/Ryzen 7 7000+'}, 'GPU_SCORE': {'score': 1, 'reason': 'AMD Radeon Graphics (Tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD XDNA™ NPU up to 50TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X, Onboard, không thể nâng cấp'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, 2880x1800, 120Hz, 100% DCI-P3, 400nits'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1x USB-A, 1x USB-C (hỗ trợ hiển thị/sạc), HDMI 2.1, 3.5mm'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.20 kg <= 1.2kg'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75WHrs (trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không đề cập chi tiết về công suất sạc nhanh)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc cao)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello; Có màn trập camera'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ Smart Amp, Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Webcam IR hỗ trợ Windows Hello, McAfee, BIOS Password, Microsoft Pluton, TPM'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại VN không được cung cấp rõ ràng'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 27.09M > Max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop ASUS ExpertBook P1 P1503CVA-C5H16-63WS', 'price_vnd': '20.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core 5 210H (8 lõi, 12 luồng) thuộc phân khúc Core Ultra 5/7 100-series hoặc tương đương.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Chỉ sử dụng Card đồ họa tích hợp Intel Graphics.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về NPU cụ thể hoặc không được liệt kê.'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, mức tiêu chuẩn cho nhiều tác vụ, có khả năng nâng cấp nhưng không phải là cấu hình cao nhất.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD Gen4, tốc độ PCIe 4.0.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp (cần tháo lắp); SSD có khe mở rộng lưu trữ.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tần số quét 60Hz, độ phủ màu thấp (NTSC 45%).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 2 USB-C, HDMI, LAN, và 3.5mm.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': 'Trọng lượng 1.68 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Pin 63Whrs, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về sạc nhanh (N/A).'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Keyboard Chiclet có phím số, travel không được ghi rõ nhưng thường ở mức chấp nhận được.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD 720p, có màn trập camera (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Âm thanh do Dirac cung cấp, có loa tích hợp.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Hỗ trợ TPM 2.0, mật khẩu BIOS, bảo vệ ổ cứng bằng mật khẩu.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'GPU_SCORE = 1 (Chỉ dùng card tích hợp)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Zenbook 14 UM3406KA-PP590WS', 'price_vnd': '32.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 7 350 (Ryzen 7 series) phù hợp với mức 4 lõi/gen >=13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics).'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD XDNA NPU up to 50TOPS, tương đương mức 4 (Ryzen AI 300).'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB RAM, nhưng là LPDDR5X Onboard (Không thể nâng cấp).'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB M.2 NVMe PCIe 4.0 SSD.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard (Không thể nâng cấp) và SSD đã lắp sẵn.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, 2880x1800 QHD+, 120Hz, 100% DCI-P3, chống lóa.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1 USB-A, 2 USB-C, HDMI 2.1, và 3.5mm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.20 kg, nằm trong mức <=1.2kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75WHrs, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh cụ thể (N/A).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền và travel >=1.5mm (giả định dựa trên phân khúc cao).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello và màn trập vật lý.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp với Công nghệ Smart Amp.'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Bảo mật toàn diện: Webcam IR, TPM2.0, Microsoft Pluton, BIOS Password.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn (2 quạt cơ bản).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: ratio = 32.39M / 20M = 1.62 (> 1.25)', 'price_score': 1, 'weighted_score': 2.41, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.41, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.61, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.11, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.51, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.31, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.41, 'final_score': 4.4, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.51, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.71, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.11, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U2_office', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop ASUS TUF Gaming A14 FA401GM-RG013W', 'price_vnd': '53.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'AMD Ryzen AI 9 465 (10 lõi, 20 luồng) thuộc nhóm chip cao cấp hiện tại.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060 8GB GDDR7 là card đồ họa mạnh mẽ.'}, 'NPU_SCORE': {'score': 5, 'reason': 'AMD XDNA NPU up to 50TOPS đáp ứng tiêu chí cao nhất.'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB RAM là mức tốt, nhưng không thể nâng cấp thêm.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe 4.0 NVMe SSD.'}, 'UPGRADABILITY': {'score': 2, 'reason': 'RAM hàn liền và không thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch 2.5K IPS 165Hz với độ sáng 400 nits và chống chói.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có nhiều cổng kết nối đa dạng bao gồm USB-C (USB 4, DP, PD), USB-A, HDMI 2.1, và microSD.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': 'Trọng lượng 1.46 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 73Whrs, mức dung lượng khá tốt.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'Hỗ trợ sạc nhanh qua USB-C PD (sạc 0-50% trong 30 phút).'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Bàn phím có đèn nền, travel khoảng 1.2-1.5mm.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera hồng ngoại FHD 1080P.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hỗ trợ Dolby Atmos và công nghệ khử ồn AI.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM2.0 và bảo mật mật khẩu BIOS.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 53.49M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.4, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U2_office', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop ASUS Zenbook 14 UX3405CA-PZ204WS', 'price_vnd': '34.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 9 285H (thuộc nhóm Intel Core Ultra 7/9 200-series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU up to 13 (gần mức Intel Core Ultra 200V/H)'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB LPDDR5X on board (16GB là mức 3, nhưng 32GB vượt trội hơn)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM On board (Không có khe cắm mở rộng) và SSD đã lắp sẵn'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'OLED, 14 inch, 120Hz, DCI-P3 100%, Anti-glare'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2x USB-C (Thunderbolt 4), 1x HDMI 2.1, USB-A, LAN, Audio'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.28 kg (<1.2kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75WHrs (trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (Không ghi rõ công suất cụ thể, giả định thấp hơn 100W)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc cao)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello và màn trập vật lý'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp với Công nghệ Smart Amp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR hỗ trợ Windows Hello, TPM2.0 (qua phần mềm), McAfee'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 34.89M > Max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.4, 'final_score': 5.0, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.3, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.7, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': [], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop ASUS Vivobook S14 M3407KA-SF032WS', 'price_vnd': '24.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 7 350 (8 lõi, 16 luồng) thuộc nhóm Core Ultra 5/7 100-series hoặc tương đương.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics).'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD XDNA NPU up to 50TOPS.'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB DDR5, rất tốt.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp thêm 16GB DDR5 SO-DIMM (RAM) và SSD có khả năng nâng cấp (dựa trên cấu trúc). '}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, độ phủ màu DCI-P3 95%, nhưng tần số quét chỉ là 60Hz.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 2x USB-C, 1x HDMI 2.1, và Audio combo.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs, mức trung bình.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh cụ thể (N/A).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím Chiclet có đèn nền.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello và màn trập vật lý.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp.'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Có nhiều tính năng bảo mật cao: Webcam IR, TPM2.0, Microsoft Pluton.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.17, 'final_score': 2.2, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop ASUS Vivobook GO 15 E1504FA-NJ454W', 'price_vnd': '13.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 5 7520U (4 lõi/8 luồng), thuộc phân khúc Core i5-H gen 12-13 hoặc Ryzen 5 7000.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5 Onboard, nhưng không thể nâng cấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 NVMe PCIe 3.0 SSD.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM hàn liền và không có khe trống; SSD có thể thay thế nhưng không phải nâng cấp theo nghĩa mở rộng.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 1, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tấm nền không rõ, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1x USB-A, 1x USB-C, 1x HDMI.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E (802.11ax) và Bluetooth 5.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.80 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'DC-in, không đề cập đến sạc nhanh cao (PD).'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin về travel key, không có đèn nền.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p HD với màn trập camera (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp SonicMaster và micrô mảng tích hợp.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có khởi động BIOS bảo vệ mật khẩu và Firmware TPM, có phần mềm bảo mật cơ bản.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, thường là thiết kế mỏng nhẹ.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (GPU_SCORE=1)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS TUF Gaming F16 FX608JPR-RV044W', 'price_vnd': '42.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7 14650HX (Gen 14) thuộc nhóm Core i7-H gen>=13.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5070 8GB GDDR7, mạnh mẽ.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU (N/A).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, khả năng nâng cấp lên 64GB qua 2 khe.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe 4.0 NVMe M.2 SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 64GB) và SSD (nâng cấp tối đa 2TB) đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch WUXGA (1920x1200), IPS, 165Hz, 300 nits, độ phủ màu tốt.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 1x LAN, 1x TB4, 3x USB-A, 1x HDMI 2.1, USB-C.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E (802.11ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.20 Kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '90WHrs, nằm trong khoảng 66-79Wh (Lưu ý: Thông số 90Whr hơi cao so với mức 4, nhưng vẫn được đánh giá cao).'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (Giả định cao do cấu hình cao cấp, thường là 100W trở lên).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc HX), có đèn nền RGB.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '1080P FHD IR Camera for Windows Hello.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Công nghệ chống ồn AI, Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM2.0 và bảo vệ mật khẩu BIOS/User.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là 2 quạt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 42.29M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 1.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.56, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.84, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.16, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.44, 'final_score': 4.4, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.16, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.16, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.44, 'final_score': 4.4, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.84, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': [], 'not_suitable_profiles': ['U1_student', 'U10_entertainment']}}
{'laptop_id': 'Laptop ASUS Vivobook 15 OLED A1505VA MA468W', 'price_vnd': '20.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13500H, hiệu năng mạnh mẽ cho tác vụ đa nhiệm.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp thêm 8GB (Tổng cộng 24GB).'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 NVMe PCIe 3.0 SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM qua khe SO-DIMM còn trống.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch OLED, độ phân giải cao (2880x1620), 120Hz, phủ màu 100% DCI-P3.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C, 1x HDMI.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.70 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '50WHrs.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'DC-in (không phải USB-C PD).'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel key khoảng 1.2-1.5mm (giả định), có đèn nền (N/A nhưng thường có).'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p HD camera, không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Built-in speaker và built-in array microphone.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có mở khóa bằng vân tay và TPM.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp rõ ràng.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS VivoBook S 16 OLED S5606MA-MX051W', 'price_vnd': '26.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 7 155H (Core Ultra 7 series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Có NPU (Ngụ ý từ Intel Core Ultra)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X Onboard (Tiêu chuẩn 16GB)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và SSD hàn liền (Không có khả năng nâng cấp)'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch WQHD+, OLED, 120Hz, 100% DCI-P3, 600nits'}, 'PORTS_SCORE': {'score': 5, 'reason': '2x USB-A, 2x Thunderbolt 4, HDMI 2.1, SD, LAN, Audio'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.50 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75WHrs (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD (Không ghi rõ công suất nhưng Thunderbolt 4 thường hỗ trợ mạnh)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel >= 1.5mm (Giả định dựa trên phân khúc cao cấp)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD có chức năng IR hỗ trợ Windows Hello và màn trập vật lý'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Smart Amp Technology, harman/kardon (4 loa giả định)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR với Windows Hello, TPM2.0, BIOS mật khẩu'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 26.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.25, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.85, 'final_score': 1.9, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop ASUS Vivobook 15 OLED A1505VA-L1688W', 'price_vnd': '21.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (Card đồ họa tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp (1 khe trống)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp cả RAM và SSD (dựa trên thông tin cấu hình)'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch OLED, FullHD, 60Hz nhưng có độ phủ màu tuyệt vời.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 1 USB-C, HDMI 1.4, Audio combo'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.70 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '50WHrs'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'DC-in (Không đề cập công suất PD cao)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel 1.2-1.5mm (giả định), có đèn'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD 720p không IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'BIOS Password, TPM2.0, McAfee'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook S16 S5606CA-RI171WS', 'price_vnd': '28.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 7 255H (thuộc nhóm Intel Core Ultra 7/9 200-series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU up to 13TOPS (gần mức Intel Core Ultra 200V/H)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X Onboard (16GB, nhưng là Onboard nên không nâng cấp được)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không có khe cắm mở rộng'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': '16 inch OLED, 120Hz, 100% DCI-P3, 400nits'}, 'PORTS_SCORE': {'score': 5, 'reason': '2x USB-A, 2x Thunderbolt 4, HDMI 2.1, SD, LAN, Audio'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg (1.50 kg - hơi nhỉnh một chút nhưng vẫn nằm trong phạm vi chấp nhận được của 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75WHrs (trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'N/A (Không đề cập chi tiết công suất sạc, giả định là chuẩn USB-C PD tiêu chuẩn)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel >= 1.5mm (giả định dựa trên phân khúc cao cấp) + Backlit'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD + IR hỗ trợ Windows Hello + Màn trập vật lý'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Micrô mảng tích hợp harman/kardon (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR hỗ trợ Windows Hello + TPM2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định theo phân khúc tầm trung cao)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 28.89M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook S 16 OLED M5606KA-RI016WS', 'price_vnd': '28.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'AMD Ryzen AI 7 350 (Ryzen AI series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 5, 'reason': 'AMD XDNA NPU up to 50TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '24GB LPDDR5X, nhưng Onboard nên không nâng cấp được.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 16 inch OLED, độ phân giải cao, 120Hz, DCI-P3 100%, chống lóa.'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-A, 1x USB-C (có hỗ trợ 40Gbps), HDMI 2.1, có cổng khác.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.50 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75WHrs nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C hỗ trợ 40Gbps (sạc nhanh tiềm năng, nhưng không ghi rõ công suất).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền RGB, travel tốt (giả định dựa trên phân khúc cao).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello và màn trập vật lý.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Micrô mảng tích hợp harman/kardon.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Webcam IR, TPM2.0, Microsoft Pluton.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (24GB) >= 8GB, SSD (512GB NVMe) != HDD/eMMC, Warranty status unknown (Giả định không có BH tại VN)', 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook S 16 S5606CA-RI114WS', 'price_vnd': '25.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 225H (Core Ultra 5 series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel AI Boost NPU up to 13 TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X Onboard (16GB, không nâng cấp được)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Cả RAM và SSD đều hàn liền/không nâng cấp được'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 16 inch OLED, 120Hz, 100% DCI-P3, độ sáng cao.'}, 'PORTS_SCORE': {'score': 5, 'reason': '2x USB-A, 2x Thunderbolt 4, HDMI 2.1, SD Card, LAN, Audio'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.50 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75WHrs (trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (Không ghi rõ công suất cụ thể nhưng thường là mức tốt)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền RGB 1 vùng, travel tốt (giả định dựa trên phân khúc cao)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello và màn trập vật lý'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Micrô mảng tích hợp Harman/Kardon'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR, TPM2.0, Mật khẩu BIOS, McAfee'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định theo phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM >= 8GB (16GB), SSD là PCIe 4.0 SSD (không phải HDD/eMMC), có BH tại VN.', 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
None
{'laptop_id': 'Laptop ASUS Vivobook 14 A1407CA-LY008WS', 'price_vnd': '20.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 225H (Core Ultra 5 100-series) với NPU'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel AI Boost NPU up to 13 TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 on board, không rõ khả năng nâng cấp'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 2, 'reason': 'RAM và SSD không thể nâng cấp (N/A)'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': '14 inch, IPS, 60Hz, 100% sRGB, chống chói'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 2x USB-C, 1x HDMI'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.46 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin sạc nhanh cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p FHD với màn trập camera (không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'McAfee, BIOS Password, TPM module'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (giả định)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U5_gamer', 'U6_creator', 'U10_entertainment'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS ROG Strix G16 G615JHR-S5069W', 'price_vnd': '43.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7 14650HX (Gen 14) thuộc nhóm Core i7-H gen>=13.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5050 8GB GDDR7, đáp ứng tiêu chí RTX 4060/4070.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU (Bộ xử lý AI / NPU: N/A).'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB DDR5, đạt mức 32GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB PCIe 4.0 NVMe M.2 SSD, đạt tiêu chí 1TB Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có 2 khe RAM và khả năng nâng cấp lên tối đa 64GB; SSD có 2 khe M.2.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 4, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 16 inch WQXGA (QHD+), IPS, 240Hz, DCI-P3 100%, 500nits, chống chói.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 1x LAN, 1x TB4, 3x USB-A, 1x HDMI 2.1, USB-C hỗ trợ DP/Sạc.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.65 kg, nằm trong khoảng 1.6-2.0kg (gần giới hạn trên).'}, 'BATTERY_SCORE': {'score': 4, 'reason': '90WHrs, nằm trong khoảng 66-79Wh (Lưu ý: Thông số 90Whr hơi cao so với thang điểm 4, nhưng vẫn ở mức tốt).'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (sử dụng Thunderbolt 4) thường cung cấp công suất cao, giả định >=100W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím Chiclet có đèn nền RGB, travel >= 1.5mm (giả định dựa trên phân khúc HX).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera IR FHD 1080P cho Windows Hello.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Công nghệ chống ồn AI, Dolby Atmos, Smart Amp (cho thấy cấu hình âm thanh khá tốt).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có mật khẩu BIOS, bảo vệ mật khẩu người dùng và mô-đun TPM.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Tản nhiệt thông minh ROG, nhưng không phải fanless hoàn toàn.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 43.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook 16 M1607KA-MB091WS', 'price_vnd': '20.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 7 350 (Ryzen AI 300 series tương đương)'}, 'GPU_SCORE': {'score': 1, 'reason': 'AMD Radeon Graphics (Tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD XDNA NPU up to 50TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 Onboard (Tiêu chuẩn)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không có khe cắm mở rộng'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': '16 inch FHD (1920x1200), IPS, 60Hz, 45% NTSC (Rất thấp về màu sắc)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 2x USB-C, HDMI, 3.5mm'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.88 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không đề cập công suất sạc cụ thể)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': "Có đèn nền, travel >= 1.5mm (Giả định dựa trên mô tả 'Chiclet')"}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD có chức năng IR hỗ trợ Windows Hello và màn trập vật lý'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR, TPM2.0, Microsoft Pluton'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS TUF Gaming A15 FA506NFR-HN075W', 'price_vnd': '17.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 7435HS (Ryzen 7 7000+) đạt mức 4'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 2050 4GB, nằm ở mức RTX 3060/4050 tầm trung'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về NPU cụ thể (N/A)'}, 'RAM_SCORE': {'score': 4, 'reason': '16GB DDR5, khả năng nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe 4.0 NVMe SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 32GB) và SSD (nâng cấp lên 1TB) đều nâng cấp được'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 2, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), IPS, 144Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có nhiều cổng kết nối: 3x USB-A, 1x HDMI 2.1, 1x LAN, USB-C hỗ trợ DP.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.30 Kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 4, 'reason': '48WHrs nằm trong khoảng 66-79Wh'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về sạc nhanh (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím có travel >= 1.5mm (giả định dựa trên phân khúc gaming/tuf) và có đèn nền RGB.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Webcam 720P HD camera'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hệ thống 2 loa, có công nghệ chống ồn AI và phần mềm DTS.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có bảo vệ mật khẩu BIOS, TPM Firmware và Khe bảo mật Kensington.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Là dòng TUF Gaming, thường có 2 quạt, nhưng không có thông tin chi tiết về hệ thống tản nhiệt phức tạp.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS ExpertBook B1402CVA-NK0157W', 'price_vnd': '13.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-1355U (Gen 13), thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (Card đồ họa tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 2.5, 'reason': '8GB DDR4, khả năng nâng cấp lên 40GB (+0.5 vì có thể nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM và SSD'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 1, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD, tấm nền TN, 60Hz, độ phủ màu thấp (NTSC 45%)'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có nhiều cổng kết nối bao gồm USB-A, USB-C, HDMI và LAN'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.46 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về sạc nhanh (N/A)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về travel key, chỉ có đèn nền (N/A)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p HD với màn trập camera (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp với công nghệ Dirac'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có cảm biến vân tay, TPM 2.0 và bảo vệ BIOS'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (GPU_SCORE=1)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS TUF Gaming A15 FA506NF-HN005W', 'price_vnd': '15.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 5 7535HS (Ryzen 7000 series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'NVIDIA GeForce RTX 2050 (Hiệu năng thấp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '8GB DDR5, có thể nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe 4.0 NVMe SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB qua 2 khe; SSD có thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD IPS 144Hz, màu sắc ở mức trung bình.'}, 'PORTS_SCORE': {'score': 4, 'reason': '3x USB-A, 1x USB-C (có DP), 1x LAN'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.30 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '48WHrs (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Không đề cập công suất sạc nhanh cụ thể'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc TUF Gaming)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720P HD camera (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa với công nghệ chống ồn AI và phần mềm DTS'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM Firmware và Bảo vệ mật khẩu BIOS/User'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là 2 quạt cơ bản'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp rõ ràng'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS VivoBook 14 X1404VA-EB609W', 'price_vnd': '15.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 2, 'reason': 'Intel Core 3 100U 1.2 GHz, chip dòng U thế hệ cũ.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics tích hợp.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có Bộ xử lý AI/NPU được liệt kê).'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB DDR5 on board, khả năng nâng cấp nhưng dung lượng thấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD.'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có vẻ dễ nâng cấp hơn RAM (cần tháo lắp).'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD, tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 2, 'reason': 'Chỉ có 2 cổng USB-A (USB 2.0), 1 cổng USB-C, 1 cổng HDMI.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.2.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.40 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'DC-in, không có thông tin về công suất sạc nhanh cao.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Keyboard Chiclet, không có thông tin chi tiết về travel.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Camera HD 720p, có màn trập camera (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp SonicMaster và microphone mảng tích hợp.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có cảm biến vân tay, TPM firmware, bảo vệ mật khẩu BIOS.'}, 'THERMAL_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về hệ thống tản nhiệt chuyên biệt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời', 'price_score': 3, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'GPU_SCORE=1, NPU_SCORE=1 (Tổng thể yếu)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.6, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U5_gamer']}}
{'laptop_id': 'Laptop ASUS VivoBook X1502ZA-BQ127W', 'price_vnd': '13.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5-1240P (Gen 12) - Phù hợp với mức Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB DDR4, khả năng nâng cấp nhưng dung lượng thấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 NVMe PCIe 3.0 SSD'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM có thể nâng cấp thêm 1 khe).'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD, tấm nền IPS, 250 nits độ sáng, 45% NTSC (màu kém), tần số quét không rõ ràng.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 1x USB-C, HDMI 1.4, và các cổng khác.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth v5.0.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.7 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42WHrs, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Có cổng DC-in, không đề cập đến USB-C PD cao.'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin về travel key, không có đèn nền.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720P, không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa kép, công nghệ SonicMaster.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Bảo mật BIOS, TPM, Cảm biến vân tay.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (chỉ có tích hợp)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Gaming ROG Zephyrus G15 GA502IV-AZ079T', 'price_vnd': '35.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 9 4900HS (Ryzen 7000+ tier)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 2060 6GB (Tương đương RTX 3060/4050 tầm trung)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, mức tiêu chuẩn'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe Gen3x4'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có thể nâng cấp được (RAM không rõ khả năng)'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 5, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD IPS 240Hz với độ phủ màu 100% sRGB.'}, 'PORTS_SCORE': {'score': 4, 'reason': '3x USB 3.2, 1x USB-C (có DisplayPort), HDMI, RJ-45, có khe thẻ nhớ.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Intel Wi-Fi 6 (802.11AX)'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.1 kg (Trong khoảng 1.6-2.0kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '76Whr (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về công suất sạc nhanh.'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin về travel key và đèn nền.'}, 'WEBCAM_SCORE': {'score': 1, 'reason': 'Không có thông tin về độ phân giải hoặc tính năng IR.'}, 'AUDIO_SCORE': {'score': 2, 'reason': '2x1W Speakers with Smart AMP Technology'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin về các tính năng bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook Slate OLED T3304GA-LQ021WS', 'price_vnd': '12.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 2, 'reason': 'Intel Core i3-N300, chip cấp thấp'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel® UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB LPDDR5, dung lượng thấp'}, 'SSD_SCORE': {'score': 2, 'reason': '256GB UFS 2.1, dung lượng nhỏ'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 3, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 3}, 'reason': 'Màn hình 13.3 inch OLED, FullHD, 60Hz, DCI-P3 100%'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-C, 1x USB-A (ngụ ý qua Type-C), có Micro SD'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth v5.0'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg (0.82 kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '50WHrs'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin sạc nhanh cụ thể'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin về travel key'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p FHD camera'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa stereo ổn (dựa trên cấu hình cơ bản)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin bảo mật sinh trắc học'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB (8GB)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời', 'price_score': 3, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB (8GB)', 'price_score': 2, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB (8GB)', 'price_score': 3, 'weighted_score': 2.3, 'final_score': 2.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 8GB (8GB - Cần >= 8GB)', 'price_score': 3, 'weighted_score': 2.6, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.7, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U5_gamer', 'U6_creator', 'U7_ai_data']}}
{'laptop_id': 'Laptop ASUS Vivobook 15 X1502VA-BQ885W', 'price_vnd': '16.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H (Gen 13) thuộc nhóm Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel HD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp nhưng là mức tiêu chuẩn hiện tại.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp qua khe SO-DIMM, SSD có thể nâng cấp (dù không rõ khe trống).'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 1x USB-C (có hỗ trợ PD), 1x HDMI, 1x Audio combo.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.70 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '42Whrs, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ (5Gbps), tuy nhiên không ghi rõ công suất tối đa.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Keyboard Chiclet có phím số, travel không được xác định rõ nhưng thường ở mức chấp nhận được.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p HD camera, không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp SonicMaster và micrô tích hợp.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có TPM2.0 và tùy chọn bảo mật BIOS password.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop ASUS Gaming V16 V3607VH-RP024W', 'price_vnd': '25.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core 5 210H (Gen 12/13 thế hệ mới hơn nhưng không phải dòng H cao cấp nhất)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 5050 8GB GDDR7 (Mức trung bình, không thuộc nhóm cao cấp 40 series)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp nhưng giới hạn ở mức 16GB hiện tại'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 3, 'reason': "RAM có thể nâng cấp, SSD có thể nâng cấp (dựa trên mô tả 'Cần tháo vỏ')"}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 3, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch FHD (1920x1200), tấm nền nhựa, tần số quét 144Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 1x USB-C, 1x HDMI 2.1, Audio combo.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.95 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '63WHrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'DC-in (Không đề cập công suất PD cao)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền và travel >= 1.5mm (Giả định dựa trên thông tin chung của dòng máy này)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p FHD với màn trập camera (Không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp SonicMaster, Micrô tích hợp (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Mật khẩu BIOS và TPM (Trusted Platform Module)'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm bảo hành đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS TUF Gaming F16 FX608JH-RV131W', 'price_vnd': '30.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13450HX (Gen 13, 10 lõi)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 5050 8GB GDDR7 (Mức trung bình)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB DDR5, khả năng nâng cấp lên 64GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe 4.0 NVMe SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB qua 2 khe; SSD có thể nâng cấp thêm dung lượng'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '16 inch WUXGA (1920x1200), IPS, 165Hz, 300 nits, DCI-P3 100%.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng: 1x LAN, 1x TB4, 3x USB-A, 1x HDMI 2.1, USB-C PD'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.20 kg (Trong khoảng 1.6-2.0kg đến 2.0kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '90WHrs (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 10Gbps (PD 100W tiềm năng)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (Giả định dựa trên phân khúc HX)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera hồng ngoại FHD 1080P'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hệ thống 2 loa với công nghệ khử ồn AI và Dolby Atmos'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'TPM2.0 và bảo vệ mật khẩu BIOS/User'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin không cung cấp chi tiết về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 30.59M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop ASUS Vivobook 16X K3605VC-RP491W', 'price_vnd': '21.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13), thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX3050 4GB GDDR6'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp thêm 8GB (Tổng cộng 24GB)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 2, 'ANTIGLARE': 4}, 'reason': '16 inch WUXGA (FHD+), IPS panel, 144Hz, nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-A, 1x USB-C (PD), HDMI 2.1, SD, LAN, Audio'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.80 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '50WHrs'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (cấp nguồn 5Gbps)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p HD với màn trập camera (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp SonicMaster, Micrô mảng tích hợp'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'BIOS Password, TPM, McAfee (Thiếu vân tay/IR Face)'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.65, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.45, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS TUF Gaming A15 FA506NCR-HN047W', 'price_vnd': '18.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 7435HS (Ryzen 7 7000+) phù hợp với mức 4.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 4GB, thuộc phân khúc RTX 3060/4050, VRAM 4GB.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về NPU cụ thể (N/A).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, khả năng nâng cấp lên 32GB (16GB là mức 3, cộng thêm +0.5 vì có thể nâng cấp).'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe 4.0 NVMe SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB qua 2 khe SO-DIMM; SSD có thể nâng cấp lên 1TB.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), IPS, 144Hz, độ phủ màu trung bình.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có nhiều cổng kết nối bao gồm USB-A, USB-C (có DP), HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': 'Trọng lượng 2.30 Kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 48WHrs, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sử dụng USB-C PD (sạc nhanh 0-50% trong 30 phút).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard có travel >= 1.5mm (giả định dựa trên phân khúc gaming/tầm trung cao) và có đèn nền RGB.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Webcam 720P HD camera (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa stereo ổn với công nghệ chống ồn AI và phần mềm DTS.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có mật khẩu BIOS, bảo vệ mật khẩu người dùng và mô-đun TPM.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là 2 quạt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành không được cung cấp cụ thể, giả định là 1 năm với trung tâm BH đầy đủ tại VN.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Vivobook S14 S3407VA-LY046W', 'price_vnd': '18.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H (Gen 13) thuộc nhóm Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp thêm 8GB (Tổng cộng 24GB).'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp qua khe SO-DIMM còn trống và SSD có thể thay thế/nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch FHD (1920x1200), IPS, 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 2x USB-C, 1x HDMI.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.39 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '70WHrs nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về sạc nhanh (N/A).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền và travel keyboard (giả định travel >= 1.5mm dựa trên phân khúc).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello và có màn trập vật lý.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa tích hợp, Micrô mảng tích hợp.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Webcam IR hỗ trợ Windows Hello, TPM2.0 và tùy chọn bảo vệ BIOS.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Zenbook 14 Oled UX3405MA-PP151W', 'price_vnd': '25.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 125H (Core Ultra 5 series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel® Arc Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel® AI Boost NPU (~11 TOPS)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X on board, không thể nâng cấp'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không thể nâng cấp cả RAM và SSD'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': '14 inch, OLED, 120Hz, 100% DCI-P3, Anti-glare'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x Thunderbolt 4, 1x USB-A, 1x HDMI 2.1, Audio jack'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg (1.20 kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75WHrs (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (Không ghi rõ công suất cụ thể, giả định thấp hơn 100W)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel >=1.5mm (Giả định dựa trên phân khúc cao cấp), Backlit'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD IR / nhận diện khuôn mặt'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Smart Amp harman/kardon (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'IR webcam với Windows Hello support, TPM 2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (16GB) >= 8GB, SSD (512GB NVMe) != HDD/eMMC, Warranty (có BH tại VN)', 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS TUF Gaming F16 FX608JHI-TU209W', 'price_vnd': '40.090.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7 14650HX (Gen 14) thuộc nhóm Core i7-H gen>=13.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5050 8GB GDDR7, đáp ứng tiêu chí RTX 4060/4070.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU (Bộ xử lý AI / NPU: N/A).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, mức tiêu chuẩn hiện tại.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe 4.0 NVMe SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có 2 khe RAM và khả năng nâng cấp lên tối đa 64GB; SSD có 2 khe cắm M.2.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch WUXGA (1920x1200), IPS, 144Hz, 400 nits, độ phủ màu tốt.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 3x USB-A, 1x USB-C (DP/PD), 1x HDMI 2.1, LAN, Audio jack.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.20 Kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '70WHrs nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ (dù không ghi rõ công suất cụ thể, nhưng thiết bị cao cấp thường hỗ trợ tốt).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc HX), có đèn nền RGB.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080P FHD Camera, không đề cập đến IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ khử ồn AI, Dolby Atmos (thường đi kèm với cấu hình cao).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có bảo vệ bằng mật khẩu BIOS và TPM module.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Thiết kế máy gaming/workstation thường có 2 quạt, nhưng không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 40.09tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS ZenBook S16 UM5606GA-SS384WS', 'price_vnd': '48.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'AMD Ryzen AI 9 465 với NPU lên đến 50TOPS'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon 880M Graphics'}, 'NPU_SCORE': {'score': 5, 'reason': 'AMD XDNA NPU up to 50TOPS'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB LPDDR5X on board'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM On board (Không có khe cắm mở rộng) và SSD không rõ khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 16 inch OLED, 2880x1800, 120Hz, 100% DCI-P3, 500 nits'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-C (bao gồm Thunderbolt), 1 HDMI, 1 SD, 1 USB-A'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) và Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.50 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '83WHrs (trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không đề cập chi tiết về công suất sạc nhanh)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím Chiclet có đèn nền'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD tích hợp chức năng hồng ngoại (IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ Smart Amp, Loa tích hợp, Micro array'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR hỗ trợ Windows Hello, Pluton, TPM'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 48.49M > Max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS Zenbook DUO UX8406CA-PZ109WS', 'price_vnd': '55.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 9 285H (thuộc nhóm Intel Core Ultra 7/9 200-series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost NPU up to 13 (gần mức Intel Core Ultra 200V/H)'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB LPDDR5X Onboard (16GB là mức chuẩn, không có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB M.2 NVMe PCIe 4.0 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không có khe cắm mở rộng'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': '14 inch OLED, 2880x1800, 120Hz, 100% DCI-P3, Anti-glare'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2x USB-C (Thunderbolt 4), HDMI 2.1, USB-A, LAN, Audio'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg (1.65 kg, nhưng vẫn nằm trong phạm vi chấp nhận được của phân khúc cao)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75WHrs (trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (Không ghi rõ công suất cụ thể, giả định thấp hơn 100W)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Bàn phím mềm (không đề cập travel distance cụ thể)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD có chức năng IR hỗ trợ Windows Hello'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Công nghệ Smart Amp, Loa tích hợp (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Webcam IR hỗ trợ Windows Hello, Trusted Platform Module (TPM)'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (32GB) vượt ngưỡng, nhưng UPGRADABILITY (1) rất thấp và PRICE_SCORE (ratio ~0.22) quá thấp.', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.4, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop ASUS VivoBook A415EP-EB116T', 'price_vnd': '17.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5-1135G7, Core i5 thế hệ 11'}, 'GPU_SCORE': {'score': 2, 'reason': 'NVIDIA GeForce MX330 2GB GDDR5 (GPU cấp thấp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU)'}, 'RAM_SCORE': {'score': 1, 'reason': '<8GB (Không có dung lượng cụ thể, giả định mặc định thấp)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe Gen3 SSD'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có thể nâng cấp (RAM không rõ khả năng)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 1, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': '14 inch FHD, Panel NTSC 45%, 60Hz, Glossy mỏng'}, 'PORTS_SCORE': {'score': 3, 'reason': '2 USB 2.0, 1 USB 3.1, HDMI, Audio combo'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 5 (802.11 ac) + Bluetooth 5.0'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.45Kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 2, 'reason': '42 Wh (Trong khoảng 40-49Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin sạc nhanh cụ thể (Giả định là sạc tiêu chuẩn)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Travel không rõ, không có đèn bàn phím'}, 'WEBCAM_SCORE': {'score': 1, 'reason': 'Không có thông tin chi tiết về Webcam'}, 'AUDIO_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về hệ thống âm thanh'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin về các tính năng bảo mật sinh trắc học'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 2, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 8GB', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB', 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 8GB', 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop ASUS Vivobook Slate T3300', 'price_vnd': '16.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 1, 'reason': 'Intel Pentium Silver N6000, chip rất cơ bản.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU).'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB RAM, mức tối thiểu.'}, 'SSD_SCORE': {'score': 2, 'reason': '256GB SSD, tốc độ PCIe 3.0.'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': '13.3 inch FHD OLED/AMOLED, tần số quét 60Hz.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-C, 1x USB-A, 1x SD card reader, 1x Audio jack.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth v5.2.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg (0.78 kg).'}, 'BATTERY_SCORE': {'score': 3, 'reason': '50WHrs.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về sạc nhanh cụ thể.'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về travel key.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p, không có IR.'}, 'AUDIO_SCORE': {'score': 2, 'reason': '2 loa stereo ổn (giả định).'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin về các tính năng bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin về hệ thống tản nhiệt chuyên biệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB (8GB), SSD < 256GB (256GB - Cần kiểm tra lại nếu đây là giới hạn cứng của profile)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (Chỉ có iGPU).', 'price_score': 3, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB (8GB).', 'price_score': 3, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB (8GB).', 'price_score': 2, 'weighted_score': 2.2, 'final_score': 2.2, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 8GB (8GB - Giới hạn thấp nhất), SSD < 256GB (256GB - Giới hạn thấp nhất).', 'price_score': 3, 'weighted_score': 2.6, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U5_gamer', 'U6_creator', 'U7_ai_data', 'U10_entertainment']}}
{'laptop_id': 'Laptop Dell 14 DC14250 DC4C5386W', 'price_vnd': '21.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core 5 120U (Core i5-H gen 12-13 range)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 PCIe NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp cả RAM (lên 32GB) và SSD (lên 1TB)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD+ (1920x1200), tấm nền WVA, 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 1 USB-C, HDMI 1.4, khe SD.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 + Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.67 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '54Whr (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin sạc nhanh cụ thể)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không rõ ràng'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Có webcam, độ phân giải không xác định rõ (giả định 1080p không IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin bảo mật sinh trắc học cao cấp'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không rõ ràng (Giả định 1 năm trung tâm BH đầy đủ tại VN)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.25, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.35, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Dell Pro 15 Essential PV15250 VKVKD - Nhập khẩu chính hãng', 'price_vnd': '13.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 2, 'reason': 'Intel Core 3 -100U, thuộc nhóm chip cũ/cơ bản.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics tích hợp.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU).'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB RAM, dưới mức khuyến nghị 16GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD, tốc độ Gen4 (giả định vì không ghi rõ gen, nhưng 512GB là mức 3).'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM lên tối đa 16GB.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 3, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tấm nền IPS, tần số quét 120Hz, nhưng độ phủ màu rất thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có USB-A, USB-C, HDMI, SD, Audio.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 5.0 hoặc 5.3 (dựa trên Bluetooth 5.0/5.3, giả định WiFi tương đương).'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.90 kg, nằm trong khoảng 1.2-1.4kg (gần ngưỡng 1.2kg).'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Pin 41Wh hoặc 54Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về sạc nhanh cụ thể (N/A).'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin về travel key, chỉ có đèn N/A.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD RGB camera (1280x720), không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek ALC3204/3254 (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 1, 'reason': 'Không có thông tin về bảo mật sinh trắc học (vân tay/IR face).'}, 'THERMAL_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về hệ thống tản nhiệt).'}, 'WARRANTY_SCORE': {'score': 2, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB (8GB)', 'price_score': 3, 'weighted_score': 2.3, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB (8GB)', 'price_score': 2, 'weighted_score': 2.0, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.6, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.2, 'final_score': 2.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U8_business'], 'not_suitable_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment']}}
{'laptop_id': 'Laptop Dell Inspiron 15 3530 J9XFD - Nhập khẩu chính hãng', 'price_vnd': '17.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-1334U (Core i5-H gen 12-13 range, phù hợp với mức 4)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về NPU, giả định là Intel Core Ultra 100-series level)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp lên tối đa 16GB (Điểm 3 + 0.5 vì có khả năng nâng cấp nhưng giới hạn ở 16GB)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4, đáp ứng tiêu chí 512GB Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có USB-A, USB-C, HDMI, SD, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 5.x hoặc 6 (dựa trên chipset Realtek)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.62 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41Wh nằm trong khoảng 30-65Wh'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về công suất sạc nhanh (PD)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin về travel key, đèn nền'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1280x720 (HD) không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek ALC3204/ALC3254 (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về các tính năng bảo mật sinh trắc học'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin về hệ thống tản nhiệt chuyên biệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành tiêu chuẩn 1 năm tại trung tâm BH'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.25, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell 15 DC15250 KR0N9 - Nhập khẩu chính hãng', 'price_vnd': '16.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5-H gen 13 (dòng U), hiệu năng tầm trung'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB NVME Gen4, dung lượng vừa phải'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp cả RAM và SSD'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 3, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': '15.6 inch FHD IPS, tần số quét 120Hz, độ phủ màu thấp (45% NTSC)'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có USB-A, USB-C, HDMI 1.4, SD Card'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 5.x hoặc 6 (dựa trên chipset Realtek)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.90 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 2, 'reason': '41 Wh, mức pin khá khiêm tốn'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh, chỉ có cổng USB-C 5Gbps'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về travel key và đèn nền'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '1080p nhưng không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek ALC3204/3254 (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 1, 'reason': 'Không có thông tin về các tính năng bảo mật sinh trắc học'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin về hệ thống tản nhiệt chuyên sâu'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin chung về dịch vụ bảo hành tại VN (cần xác nhận chi tiết)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Dell 15 DC15255 DC5R5802W1', 'price_vnd': '18.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Ryzen 5 7530U (Ryzen 5 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4 3200MHz (Tiêu chuẩn cho nhiều tác vụ)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 PCIe NVMe (Gen4, dung lượng vừa phải)'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (có ghi chú nâng cấp lên 1TB)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 3, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD IPS, 120Hz, nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có USB-A, USB-C (data only), HDMI, SD, 3.5mm.'}, 'WIFI_SCORE': {'score': 2, 'reason': 'Wi-Fi 5 + Bluetooth 5.0'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.63 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41Whr (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin sạc nhanh cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về travel key, không có đèn nền.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD camera (720p tương đương)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek ALC3204 (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ sử dụng mật khẩu, không có các tính năng sinh trắc học cao cấp.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm bảo hành đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell Inspiron 14 5440 D0F3W - Nhập khẩu chính hãng', 'price_vnd': '18.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5-1334U thế hệ 13, hiệu năng văn phòng/tiêu chuẩn.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UMA Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể).'}, 'RAM_SCORE': {'score': 4, 'reason': '24GB DDR5, dung lượng lớn và có khả năng nâng cấp lên 32GB.'}, 'SSD_SCORE': {'score': 3, 'reason': 'Thông số không ghi rõ dung lượng và chuẩn Gen, giả định là SSD Gen4 512GB hoặc tương đương.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB; SSD có khe cắm để nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': 'Màn hình 14 inch FHD (1920x1080), tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1 USB-A, 1 USB-C (có PD/DP), HDMI 1.4, SD, 3.5mm.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 5.3 (Bluetooth 5.3).'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.690 kg nằm trong khoảng 1.2-1.4kg (gần ngưỡng).'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Pin 41 Wh, mức tiêu chuẩn.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (không rõ công suất cụ thể, giả định ở mức trung bình).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard có đèn nền AI hotkey backlit.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'FHD (1080p) nhưng không đề cập đến tính năng IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek ALC3254 (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ chạy Windows 11 Home, không đề cập các tính năng sinh trắc học cao cấp.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, thường là thiết kế cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin chung về nhập khẩu chính hãng, không có chi tiết về thời hạn bảo hành tại VN.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (GPU tích hợp).', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell Vostro 3530 2H1TPI7', 'price_vnd': '19.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-1355U thế hệ 13, thuộc nhóm Core i7-H gen>=13 (dù là U series nhưng vẫn mạnh mẽ)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp lên tối đa 16GB (đạt mức 16GB)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM lên tối đa 16GB và có slot SSD trống (Slot SSD Tối đa 1TB)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 3, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD (1920x1080), tấm nền WVA, tần số quét 120Hz, độ phủ màu thấp (NTSC 45%)'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1x USB-A, 1x USB-C, HDMI 1.4, SD, LAN, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 5 (802.11ac) + Bluetooth 5.0'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.66 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41Wh (thuộc khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về sạc nhanh, giả định là sạc tiêu chuẩn (DC adapter)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về travel, nhưng thường đáp ứng tiêu chuẩn cơ bản của dòng máy văn phòng'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD - 1280 x 720 (HD) không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek ALC3204/ALC3254 (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin cụ thể về các tính năng bảo mật sinh trắc học cao cấp'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin về hệ thống tản nhiệt chuyên biệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (chỉ có tích hợp)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell Vostro 3405 70227396', 'price_vnd': '15.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen™ R7-3700U (Gen cũ hơn yêu cầu của mức 4)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon™ RX Vega 10 Graphics'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU)'}, 'RAM_SCORE': {'score': 1, 'reason': 'Dung lượng RAM không được cung cấp, giả định dưới 8GB vì không có thông tin cụ thể.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD M.2 PCIe NVMe'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có khả năng nâng cấp (RAM không rõ ràng)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch FHD, tấm nền VA, tần số quét không rõ, chất lượng màu thấp.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 1 HDMI, 1 khe SD, 1 jack Audio.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 802.11ac (WiFi 6)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.59 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Pin 42WHrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về sạc nhanh (USB-C PD).'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin về travel key, đèn nền.'}, 'WEBCAM_SCORE': {'score': 1, 'reason': 'Không có thông tin chi tiết về webcam (giả định cơ bản).'}, 'AUDIO_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về cấu hình loa.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin về các tính năng bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin về hệ thống tản nhiệt chuyên biệt.'}, 'WARRANTY_SCORE': {'score': 2, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM giả định < 16GB (Deal Breaker U4)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (Deal Breaker U5)', 'price_score': 0, 'weighted_score': 1.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM giả định < 16GB (Deal Breaker U7)', 'price_score': 2, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM giả định < 8GB (Deal Breaker U9)', 'price_score': 3, 'weighted_score': 2.7, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U5_gamer', 'U7_ai_data', 'U10_entertainment']}}
{'laptop_id': 'Laptop Dell 16 Plus DB16250 DB6U5387W1', 'price_vnd': '31.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 226V (Core Ultra 5 100-series, có NPU 40 TOPS)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': '40 TOPS NPU (Tương đương Intel Core Ultra 200V/H)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X, Onboard (Không thể nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB M.2 PCIe NVMe'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Cả RAM và SSD đều không thể nâng cấp (Onboard)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 4, 'PANEL': 2, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 16 inch 2.5K nhưng chỉ có tấm nền WVA, tần số quét 60Hz và độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1 USB-A, 1 USB-C (Thunderbolt), HDMI, SD, 3.5mm.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 + Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.87 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '64WHr (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không đề cập sạc nhanh cụ thể)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền và travel không được xác định rõ ràng.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Có webcam, độ phân giải không rõ (giả định 1080p cơ bản).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có bảo mật, nhưng không liệt kê các tính năng sinh trắc học cao cấp như vân tay/IR face.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell 15 DC15255 HV1N4 - Nhập khẩu chính hãng', 'price_vnd': '17.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 5 7530U (Ryzen 5 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp lên 24GB'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp cả RAM và SSD'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': '15.6 inch FHD, IPS panel, 60Hz, 45% NTSC color gamut.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1x USB-C, 1x USB 3.2 Gen 1, 1x USB 2.0, HDMI 1.4, SD Card, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 5.x hoặc 6 (dựa trên chipset Realtek)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.90 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 2, 'reason': '41 Wh (dưới 40Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh cụ thể (chủ yếu là USB-C)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về travel key và đèn nền'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD RGB camera (1280 x 720)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek ALC3204/ALC3254 (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 1, 'reason': 'Không có thông tin về các tính năng bảo mật sinh trắc học'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin về hệ thống tản nhiệt chuyên biệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp chi tiết về thời hạn và dịch vụ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell Inspiron 14 5440 N5440-C7U165W11IBD2', 'price_vnd': '27.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core 7 150U (Gen mới, hiệu năng tốt cho tác vụ văn phòng/đa nhiệm)'}, 'GPU_SCORE': {'score': 2, 'reason': 'NVIDIA GeForce MX570A 2GB GDDR6 (Card đồ họa rời cấp thấp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB (16GB là mức tiêu chuẩn)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe Gen4x4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB, SSD có thể nâng cấp (dựa trên cấu hình)'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD (1920x1080), tấm nền VA, tần số quét 60Hz, chất lượng màu cơ bản.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 1 USB-C (có PD/DP), HDMI, SD, 3.5mm'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.54 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '54Whr (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C hỗ trợ Power Delivery (PD), nhưng không ghi rõ công suất cụ thể'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Đèn trắng, travel khoảng 1.2-1.5mm (giả định)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1280 x 720 (HD), không đề cập IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek ALC3254 (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Bảo mật vân tay'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: ratio = 27.49M / 20M = 1.3745. Ratio > 1.25.', 'price_score': 1, 'weighted_score': 2.41, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.11, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.44, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.22, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.44, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.11, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.78, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Dell 15 DC15255 G8MK9 - Nhập khẩu chính hãng', 'price_vnd': '18.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 7 7730U (Ryzen 7 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp lên tối đa 16GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM giới hạn)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': '15.6 inch FHD, IPS panel, 60Hz, 45% NTSC (Rất thấp về màu sắc)'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 1 USB-C, HDMI 1.4, khe SD'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 5.x hoặc 6 (dựa trên chipset Realtek)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.90 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 2, 'reason': '41 Wh (Trong khoảng 40-49Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin sạc nhanh cụ thể (DC adapter giả định)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về travel key'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '1080p không IR (Camera HD RGB 720p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa stereo ổn (Realtek ALC3204/3254)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin bảo mật sinh trắc học'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin tản nhiệt chi tiết'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức trung bình 1 năm bảo hành tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell 15 DC15250 71073959', 'price_vnd': '23.090.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-1355U (Core i7-H gen>=13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp nhưng đã đạt mức 16GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': "Có thể nâng cấp RAM và SSD (dựa trên thông tin 'Có thể nâng cấp')"}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 3, 'COLOR': 2, 'ANTIGLARE': 2}, 'reason': '15.6 inch FHD, Tấm nền VA, 120Hz, chất lượng màu cơ bản.'}, 'PORTS_SCORE': {'score': 3, 'reason': '1x USB-A, 1x USB-C (Type-C DisplayPort Alt), 1x USB 2.0, 1x 3.5mm'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 11ax + Bluetooth v5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.66 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Không có thông số Wh cụ thể, giả định trong khoảng 50-65Wh'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (không có thông số công suất cụ thể)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Bàn phím không có đèn nền, travel không rõ ràng'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD (1080p không xác nhận IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa stereo ổn (giả định)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về bảo mật sinh trắc học'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định 1 năm bảo hành tiêu chuẩn'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell Pro 13 Plus PB13250-236V-16512W', 'price_vnd': '34.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 236V vPro (Core Ultra 5 series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics 130V (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về TOPS, nhưng thuộc dòng Core Ultra)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5x, Onboard (RAM không thể nâng cấp)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 Gen4 (có thể nâng cấp lên 2TB)'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có khả năng nâng cấp, RAM hàn liền.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 2, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '13.3 inch FHD+ (1920x1200), IPS, 60Hz, 45% NTSC (Rất kém về màu sắc và tần số quét)'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có Thunderbolt 4, 2x USB-A, HDMI 2.1'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 BE201 + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.34 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 2, 'reason': '45 Wh (dưới 50Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ qua Thunderbolt 4'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Led trắng, travel không rõ (giả định 1.2-1.5mm)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'FHD RGB (1080p nhưng không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Cirrus Logic CS42L43 (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Vân tay'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định dựa trên phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 34.49M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Dell 16 DC16250 C7U161W11BLU', 'price_vnd': '27.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core 7 150U (Gen 12/13 U-series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB M.2 PCIe NVMe SSD (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB qua 2 khe; SSD hiện tại là Gen4.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '16 inch FHD+ (1920x1200), tấm nền VA, 60Hz, độ sáng 300 nits, chất lượng màu thấp.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (DP 1.4/PD), HDMI 1.4, Audio jack.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2 kg (Trong khoảng 1.6-2.0kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41WHr (Trong khoảng 30-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD hỗ trợ (không ghi rõ công suất cụ thể)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Đèn trắng, travel không xác định nhưng thường đạt chuẩn cơ bản.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1280 x 720 (HD), không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek ALC3254 (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Bảo mật vân tay.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm bảo hành đầy đủ tại VN.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell 15 DC15250 1XVHG - Nhập khẩu chính hãng', 'price_vnd': '17.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5-H gen 13 (1334U)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp lên 24GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có USB-A, USB-C, HDMI, SD, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 5.x hoặc tương đương (Realtek RTL8821CE/RTL8852BE)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.90 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 2, 'reason': '41 Wh (dưới 40Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin sạc nhanh cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel key khoảng 1.2-1.5mm (giả định), có đèn (N/A)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '1080p không IR (HD RGB camera 720p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa stereo ổn (Realtek ALC3204/ALC3254)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin bảo mật sinh trắc cụ thể'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định dựa trên phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell 14 DC14255 R7165W11SLU', 'price_vnd': '26.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 2, 'reason': 'AMD Ryzen 7 250, chip thế hệ cũ.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB qua 2 khe.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 PCIe NVMe SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (lên 32GB) và SSD đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 2, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': '14 inch FHD+ (1920x1200), tấm nền VA, 60Hz, độ sáng 300 nits.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 1 USB-C (có PD/DP), HDMI 1.4, khe SD, và jack âm thanh.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.65 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41WHr nằm trong khoảng 30-65Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C Type-C hỗ trợ Power Delivery (PD), nhưng không có thông số cụ thể về công suất.'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin về travel key, không có đèn nền.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '1280 x 720 (HD), không có IR.'}, 'AUDIO_SCORE': {'score': 2, 'reason': 'Sử dụng Realtek ALC3204 (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có các tính năng bảo mật sinh trắc học như vân tay/IR Face.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 2, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp rõ ràng.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Dell 15 DC15250 H5YXJ - Nhập khẩu chính hãng', 'price_vnd': '22.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-1355U (Core i7-H gen>=13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp lên 24GB (+0.5 vì có thể nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có USB-A, USB-C, HDMI 1.4, SD card.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 5.0 hoặc 5.3 (dựa trên Bluetooth 5.0/5.3)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.90 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 2, 'reason': '41 Wh (dưới 40Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin sạc nhanh cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin về travel key, đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p (FHD) nhưng không có thông tin về IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek ALC3204/ALC3254 (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 1, 'reason': 'Không có thông tin về các tính năng bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'GPU tích hợp (Intel UHD Graphics) không đáp ứng yêu cầu GPU rời.', 'price_score': 2, 'weighted_score': 2.3, 'final_score': 2.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U5_gamer']}}
{'laptop_id': 'Laptop Dell 15 DC15250 H02DF - Nhập khẩu chính hãng', 'price_vnd': '17.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5 1334U (Gen 13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '24GB DDR4, có thể nâng cấp'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe NVMe Gen 4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp, SSD có thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 3, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD, IPS panel, 120Hz, nhưng độ phủ màu thấp (45% NTSC)'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có USB-C, USB 3.2 Gen 1, HDMI 1.4, nhưng thiếu nhiều cổng USB-A và Thunderbolt'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 5.3 + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.90 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41Wh (trong khoảng 30-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin sạc nhanh cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về travel key'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD camera (720P), không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa + Microphone tích hợp'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'TPM 2.0 / BitLocker / Mã hóa thiết bị'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U5_gamer'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell 16 DC16250 71076092', 'price_vnd': '25.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core 5 120U, thuộc dòng Core i5-H gen 12-13 (dù là U series nhưng vẫn nằm trong phân khúc này)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics tích hợp'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 4, 'reason': '16GB DDR5 5200MHz, có thể nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD M.2 PCIe NVMe Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': 'Màn hình 16 inch FHD (1920x1080), tấm nền VA, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 1 USB-C (có PD/DP), HDMI, và jack 3.5mm.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 6 (802.11ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.98 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '3 cell 41WHr (Giá trị pin không quá cao)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C hỗ trợ Power Delivery (PD), nhưng không ghi rõ công suất cụ thể'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có phím số riêng, có đèn nền LED'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Webcam HD (720p), không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa được điều chỉnh'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có McAfee LS và Bảo mật vân tay'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp rõ ràng'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Price 25.49M > Max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Dell 15 DC15255 X9YM41', 'price_vnd': '20.090.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 7730U (Ryzen 7 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon Graphics'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp lên tối đa 16GB (Điểm 3 + 0.5 vì khả năng nâng cấp giới hạn)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB M.2 PCIe NVMe Gen4'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ có thể nâng cấp RAM (lên 16GB) và SSD (giả định có khe trống hoặc thay thế được)'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 3, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD (1920x1080), tấm nền VA, 120Hz.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 3 cổng kết nối (2x USB-A, 1x USB-C) và khe đọc thẻ nhớ.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 802.11 ac + Bluetooth 5.0'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.6 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41Wh (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin sạc nhanh cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền bàn phím'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Webcam HD có micrô, camera RGB HD (Không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ sử dụng mật khẩu (Không có vân tay/IR face)'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell Inspiron 14 5441 N4O10441W1', 'price_vnd': '27.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Snapdragon X Plus với NPU 45 TOPS, tương đương mức Intel Core Ultra 5/7.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp Qualcomm Adreno.'}, 'NPU_SCORE': {'score': 5, 'reason': 'NPU up to 45 TOPS, đạt mức cao nhất.'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X, nhưng không thể nâng cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB Gen4 NVMe.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard không nâng cấp, SSD có thể nâng cấp nhưng không có khe trống rõ ràng.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD+ (1920x1200), IPS, 60Hz, 45% NTSC (Rất thấp).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-C đầy đủ chức năng, 1x USB-A, hỗ trợ DisplayPort qua USB-C.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Qualcomm FastConnect 7800 Wi-Fi 7 + Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.53 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '54 Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ (dù không ghi rõ công suất cụ thể).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền (Carbon Black).'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'FHD camera, không đề cập đến IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek ALC3204 (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Copilot+ PC, bao gồm các tính năng bảo mật của Microsoft.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (16GB) >= 8GB, SSD (1TB NVMe) != HDD/eMMC, Warranty status unknown (giả định không có BH tại VN). Tuy nhiên, do giá vượt ngưỡng tối đa (20tr) nên bị đánh dấu.', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Dell 14 DC14255 DC4AI5278W1', 'price_vnd': '23.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 5 330 (có NPU 50 TOPS)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 4, 'reason': '50 TOPS NPU'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có 1 khe trống nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 PCIe NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM và SSD'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 3, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD+ (1920x1200), IPS, 120Hz, nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2 USB-A, 1 USB-C, HDMI 1.4, SD, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 + Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.67 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '54Whr (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': "Có đèn nền, travel >= 1.5mm (giả định dựa trên mô tả 'Copilot có đèn nền')"}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Có webcam (không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có các tính năng bảo mật sinh trắc học cao cấp'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.15, 'final_score': 2.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Dell 15 DC15250 1XVHG V2 - Nhập khẩu chính hãng', 'price_vnd': '19.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5-H gen 13 (1334U)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB DDR4, có thể nâng cấp'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': '15.6 inch FHD, IPS panel, 60Hz, 45% NTSC (màu kém)'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có USB-A, USB-C, HDMI, SD, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 5.x hoặc tương đương (Realtek RTL8821CE/RTL8852BE)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.90 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 2, 'reason': '41 Wh (dưới 40Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin sạc nhanh cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin về travel key, không có đèn nền'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD RGB camera (1280x720), không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek ALC3204/ALC3254 (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin bảo mật sinh trắc học'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (GPU tích hợp)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell 14 DC14250 C7U161W11SLU', 'price_vnd': '28.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core 7 150U (Gen 12/13 U-series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp Intel Graphics'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp lên tối đa 16GB'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB M.2 PCIe NVMe SSD Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp, SSD có thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD+ (1920x1200), tấm nền VA, 60Hz, độ sáng 300 nits.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có PD/DP), HDMI 1.4, SD Card, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.65 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41WHr (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ (dù không ghi rõ công suất cụ thể)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không rõ ràng'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '1280 x 720 (HD), không có IR'}, 'AUDIO_SCORE': {'score': 2, 'reason': 'Realtek ALC3204 (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có các tính năng bảo mật sinh trắc học nâng cao'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell 14 DC14255 71083617', 'price_vnd': '28.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 7 350 với 8 lõi và 50 TOPS NPU'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 4, 'reason': '50 TOPS NPU (Cao hơn mức ~40 TOPS của Core Ultra)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 5600MHz, có thể nâng cấp nhưng giới hạn ở 1 khe'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB M.2 PCIe NVMe Gen4'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ có khả năng nâng cấp RAM (1 khe) và SSD (có thể nâng cấp)'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 3, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': '14 inch FHD+ (1920x1200), tấm nền WVA, 120Hz, 100% sRGB.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-C, 1x USB-A, 1x HDMI, 1x Jack 3.5mm'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) và Bluetooth 5.x'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.5 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Pin 54Wh nằm trong khoảng 50-65Wh'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (Không rõ công suất cụ thể, giả định thấp hơn 100W)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Backlit Keyboard, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'FHD 1080p, hỗ trợ giảm nhiễu tạm thời (không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Realtek Audio'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có các tính năng bảo mật sinh trắc học tiên tiến (vân tay/IR face)'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.17, 'final_score': 1.2, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
None
None
{'laptop_id': 'Laptop Dell 15 DC15250 DC5I7748W1', 'price_vnd': '23.090.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-1355U (Gen 13), thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, mức tiêu chuẩn hiện tại'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 PCIe NVMe (Gen4)'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (có khe trống), RAM không rõ khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 1, 'HZ': 3, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tấm nền nhựa, 120Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có USB-A, USB-C (2 cổng), HDMI.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.66 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '54WHr, nằm trong khoảng 50-65Wh'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C hỗ trợ sạc (không ghi rõ công suất PD)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không rõ ràng'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD camera (1080p không xác định, không có IR)'}, 'AUDIO_SCORE': {'score': 2, 'reason': 'Realtek ALC3204 (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ sử dụng mật khẩu, không có các tính năng sinh trắc học cao cấp.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, có thể bị throttle.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (chỉ có tích hợp)', 'price_score': 2, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U6_creator'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U5_gamer']}}
{'laptop_id': 'Laptop Dell Pro 14 PC14250-225U-16512WH', 'price_vnd': '26.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 225U (Core Ultra 5 100-series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về TOPS, giả định Intel Core Ultra 5)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB qua 2 khe'}, 'SSD_SCORE': {'score': 3, 'reason': '512 GB M.2 PCIe NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD+ (1920x1200), IPS, 60Hz, 45% NTSC (Rất kém về màu sắc và tần số quét)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2 USB-A, 1 USB-C (Thunderbolt 4), HDMI, LAN'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (WiFi 802.11ax) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.35 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 2, 'reason': '45 Wh (Trong khoảng 40-49Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin về công suất sạc)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về travel key, chỉ có đèn N/A'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'FHD RGB (1080p nhưng không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek ALC3204 (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin bảo mật sinh trắc học cụ thể'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'GPU_SCORE = 1 (GPU tích hợp)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Dell Inspiron 15 3520', 'price_vnd': '15.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5-1235U, Core i5-H gen 12-13'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp nhưng đã đạt mức 16GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM (2 khe) và SSD'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 3, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD, Tấm nền VA, 120Hz, độ phủ màu chưa rõ ràng.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 1 HDMI, 1 cổng SATA 3'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 802.11 ac + Bluetooth 5.0'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.685 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin sạc nhanh cụ thể (chủ yếu là USB-C thông thường)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel khoảng 1.2-1.5mm (giả định), có đèn (N/A trong spec, giả định cơ bản)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD WebCam with microphone (1080p không IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa stereo ổn (Cirrus Logic HD Audio)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Công nghệ Intel Platform Trust, giảm thiểu bảo mật SMM'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định dựa trên phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U6_creator', 'U10_entertainment'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell 16 DC16251 DC6C7557W1', 'price_vnd': '30.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core 7 150U (Gen mới, hiệu năng văn phòng/tiêu chuẩn)'}, 'GPU_SCORE': {'score': 2, 'reason': 'NVIDIA GeForce MX570A 2GB GDDR6 (Card rời tầm thấp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD PCIe NVMe Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp, SSD có thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 4, 'PANEL': 2, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch FHD+ (1920x1200) tấm nền VA, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có DP/PD), HDMI, SD, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 + Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2 kg (Trong khoảng 1.6-2.0kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '54Whr (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (Không rõ công suất cụ thể)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel key 1.2-1.5mm + Backlit'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Có webcam (Không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa stereo ổn (Realtek ALC3254)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Bảo mật vân tay'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định dựa trên phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U6_creator', 'U7_ai_data'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Dell Inspiron 14 5440 N4I5211W1', 'price_vnd': '21.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel CORE 5-120U, thuộc dòng Core i5-H gen 12-13 (dù là U series nhưng dựa trên cấu trúc naming)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (Card đồ họa tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 PCIe NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB, SSD có thể nâng cấp lên 1TB'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD+ (1920x1200), tấm nền IPS, 60Hz, độ sáng 250 nits, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có PD/DP), HDMI, SD, 3.5mm'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (WiFi 802.11ax) + Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.67 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '54Whr, nằm trong khoảng 50-65Wh'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (không ghi rõ công suất cụ thể, giả định mức trung bình)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel khoảng 1.2-1.5mm + Backlit'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Có webcam (không đề cập chi tiết về IR hay độ phân giải cao hơn 1080p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek ALC3254 (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Bảo mật vân tay'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin về hệ thống tản nhiệt chi tiết)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell Inspiron 15 3520 6R6NK V2 - Nhập khẩu chính hãng', 'price_vnd': '12.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5-1235U, Core i5-H gen 12-13'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp nhưng giới hạn ở 16GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe (Gen4)'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (có thể thay thế ổ cứng)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 3, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD, IPS, 120Hz, NTSC 45% (màu kém)'}, 'PORTS_SCORE': {'score': 3, 'reason': '1x HDMI, 2x USB 3.2 Gen 1, 1x USB 2.0, SD Card'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 + Bluetooth 5.0'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.66 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41 Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin sạc nhanh cụ thể)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Travel không rõ ràng (giả định thấp hơn mức 1.5mm)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD camera (720p tương đương)'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa stereo ổn (Realtek ALC3204/ALC3254)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin bảo mật sinh trắc học cao cấp'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (chỉ có tích hợp)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Dell Vostro 3530 2H1TPI3 - Nhập khẩu chính hãng', 'price_vnd': '9.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i3-1305U, thuộc dòng Core i5-H gen 12-13 (dù là i3 nhưng vẫn nằm trong phân khúc U series hiện đại)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU)'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB DDR4, khả năng nâng cấp lên 16GB (+0.5 vì có thể nâng cấp)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB Gen4 (hoặc Gen3 tùy cấu hình cụ thể, giả định Gen4 dựa trên thông số chung)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM lên 16GB và có slot SSD thứ hai.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 3, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tấm nền VA, tần số quét 120Hz, độ phủ màu thấp (NTSC 45%).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có USB-A, HDMI, USB-C, SD, LAN, Audio.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 5 (802.11ac) và Bluetooth 5.0.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.66 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về sạc nhanh (N/A).'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về travel key, chỉ có đèn N/A.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p (FHD) nhưng không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek ALC3204/ALC3254 (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin về các tính năng bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin về hệ thống tản nhiệt chuyên biệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (chỉ có tích hợp)', 'price_score': 2, 'weighted_score': 2.3, 'final_score': 2.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U5_gamer']}}
{'laptop_id': 'Laptop Gigabyte Gaming A16 GA6H-CMHH2VN893SH', 'price_vnd': '26.190.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, thuộc dòng H thế hệ 13.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 4050 (6GB VRAM).'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB qua 2 khe.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD Gen4x4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 64GB) và SSD (2 khe M.2) đều nâng cấp được.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': '16 inch FHD+ (1920x1200), tấm nền IPS, 165Hz, nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1 USB-A, 1 USB-C, HDMI, LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E + Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.212 kg, nằm trong khoảng 1.6-2.0kg (gần giới hạn trên).'}, 'BATTERY_SCORE': {'score': 4, 'reason': '76.1Wh, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về công suất sạc nhanh (N/A).'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Có đèn LED, travel khoảng 1.5mm (giả định dựa trên phân khúc).'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD với micro mảng (không đề cập IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có TPM 2.0 và các mật khẩu hệ thống cơ bản.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Gigabyte Gaming A16 GA6H-CMHI2VN893SH', 'price_vnd': '27.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H, thế hệ 13, hiệu năng mạnh mẽ.'}, 'GPU_SCORE': {'score': 3, 'reason': 'RTX 4050 (6GB VRAM), mức hiệu năng tầm trung.'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về NPU, giả định là mức cơ bản của Intel).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB qua 2 khe.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD Gen4x4, tốc độ cao.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch FHD+ (1920x1200), IPS, tần số quét 165Hz nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có nhiều cổng kết nối bao gồm USB-A, USB-C (có PD/DP), HDMI và LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': 'Trọng lượng 2.204 kg, nằm trong khoảng 1.6-2.0kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 76.1Wh, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C hỗ trợ Power Delivery (PD), nhưng không có thông tin công suất cụ thể.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Keyboard có đèn LED, travel khoảng 1.5mm (giả định dựa trên phân khúc).'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD với micro mảng, không đề cập đến IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có TPM 2.0 và các mật khẩu hệ thống cơ bản.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Gigabyte AERO X16 EG61H-X161VH93VNC94DH', 'price_vnd': '40.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 7 350, thuộc nhóm Core Ultra 7/9 hoặc Ryzen 7 7000+'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060 (8GB GDDR7 SDRAM), tương đương RTX 4060/4070'}, 'NPU_SCORE': {'score': 4, 'reason': '50 TOPS, tương đương mức của Intel Core Ultra 200V/H'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB (16GB là mức 3, cộng thêm +0.5 vì có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (2 khe, nâng lên 64GB) và SSD (hỗ trợ 2x M.2) đều có thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 4, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': '16 inch WQXGA (QHD+), IPS panel, 165Hz, 100% sRGB, chống chói'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có nhiều cổng kết nối: USB-A, USB-C (USB 4), HDMI, LAN, M.2 SSD'}, 'WIFI_SCORE': {'score': 4, 'reason': 'WiFi 6E + Bluetooth V5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.985 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '76Wh, nằm trong khoảng 50-65Wh'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Không đề cập chi tiết về công suất sạc nhanh (PD), giả định ở mức trung bình'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím kích thước đầy đủ, có đèn nền RGB'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Webcam hồng ngoại FHD (1080p)'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Dolby Atmos, có khả năng cao là cấu hình âm thanh tốt hơn 2 loa stereo cơ bản'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Nhận dạng khuôn mặt, TPM 2.0, mật khẩu quản trị viên'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về hệ thống tản nhiệt, giả định là 2 quạt cơ bản'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp rõ ràng'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 40.29M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': [], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Gigabyte Gaming A16 GA6H-CTHH3VN893SH', 'price_vnd': '29.090.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H (Gen 13), hiệu năng tốt cho tác vụ đa nhiệm.'}, 'GPU_SCORE': {'score': 2, 'reason': 'NVIDIA GeForce RTX 5050 (Không nằm trong danh sách hiệu năng cao, GPU tích hợp Intel UHD Graphics).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, đủ dùng nhưng chưa phải mức tối ưu 32GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD Gen4x4, tốc độ cao.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB qua 2 khe; SSD có 2 slot M.2 trống.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch WUXGA (1920x1200), IPS, tần số quét 165Hz, độ sáng 300nits.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 1 USB-A, 1 USB-C (có PD/DP), HDMI, LAN, và khe M.2 SSD.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E và Bluetooth v5.2.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': 'Trọng lượng 2.227 kg, thuộc phân khúc nặng hơn.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 76.1Wh, mức dung lượng khá tốt.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Thông tin sạc nhanh không rõ ràng (N/A), giả định là sạc tiêu chuẩn.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key 1.7mm (rất tốt) và có đèn nền RGB.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD với micro mảng, không đề cập đến IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM 2.0 và các lớp bảo mật cơ bản (mật khẩu, khởi động an toàn).'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, mặc định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 29.09tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Gigabyte Gaming A16 GA65H-5THP3VN893SH', 'price_vnd': '30.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 7 170, 8 nhân, xung nhịp tối đa 4.75 GHz (Phù hợp với mức Core i5-H gen 12-13 hoặc Ryzen 5 7000)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 5050 (8GB GDDR7 SDRAM). Đây là một GPU tầm trung hiện đại.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5 4800MHz. Đủ dùng nhưng chưa phải là mức 32GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD Gen4x4. Dung lượng 512GB Gen4 là tốt.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có 2 khe RAM và hỗ trợ nâng cấp lên tối đa 64GB; SSD hỗ trợ thêm 2 khe.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': 'Màn hình 16 inch FHD+ (1920x1200), IPS, tần số quét 165Hz. Chất lượng hiển thị ở mức trung bình.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có nhiều cổng kết nối bao gồm USB-A, USB-C (có PD/DP), HDMI, LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E + Bluetooth v5.2.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.1 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '76.1Wh nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (không rõ công suất cụ thể, giả định thấp hơn 100W).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key 1.7mm (>=1.5mm) và có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD với micro đa kênh (không đề cập rõ về IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM 2.0 và Microsoft Pluton.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, mặc định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Gigabyte Gaming A16 GA6H-CTHI3VN893SH', 'price_vnd': '31.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13), mạnh mẽ cho tác vụ đa nhiệm.'}, 'GPU_SCORE': {'score': 2, 'reason': 'NVIDIA GeForce RTX 5050 (Không nằm trong các dòng cao cấp được liệt kê).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, khả năng nâng cấp lên 64GB qua 2 khe.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD Gen4x4, tốc độ cao.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB; SSD có thể thêm ổ thứ hai.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 2, 'ANTIGLARE': 4}, 'reason': '16 inch FHD+ (1920x1200), IPS, 165Hz, nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1x USB-A, 1x USB-C (hỗ trợ PD/DP), HDMI, LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E và Bluetooth v5.2.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.23 kg, hơi nặng so với mức tối ưu (<1.2kg).'}, 'BATTERY_SCORE': {'score': 4, 'reason': '76.1Wh, dung lượng pin khá tốt.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C hỗ trợ PD (dù công suất không được ghi rõ).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key 1.7mm, có đèn nền RGB.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD với micro mảng (không đề cập IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có fTPM 2.0 và các lớp bảo mật cơ bản.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Gigabyte Gaming A16 GA6H-CWHI3VNC94SH', 'price_vnd': '37.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 5070 (Không nằm trong danh sách chuẩn, giả định tương đương mức RTX 4060/4070 tầm trung)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD Gen4, có hỗ trợ thêm slot SSD Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (lên 64GB) và SSD (thêm slot) đều nâng cấp được'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': '16 inch WQXGA (QHD+), IPS, 165Hz, sRGB 100%, chống chói.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có USB-A, USB-C (PD/DP), HDMI, LAN, và khe M.2 SSD'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E + Bluetooth v5.2'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.268 kg (Trong khoảng 1.6-2.0kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '76.1Wh (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (Không rõ công suất cụ thể nhưng thường là chuẩn tốt)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc cao)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD với micro mảng (1080p không IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'fTPM 2.0, mật khẩu quản trị viên, khởi động an toàn'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể về thời hạn và dịch vụ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 37.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Gigabyte G6 MF-H2PH853KH', 'price_vnd': '21.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13) thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 4050 (6GB VRAM)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB qua 2 khe cắm (+0.5 vì có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4 (có hỗ trợ thêm slot NVMe)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (2 khe) và SSD (2 slot) đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': '16 inch FHD+ (1920x1200), IPS, 165Hz, nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có nhiều cổng kết nối bao gồm 2x USB-C, HDMI, Mini DP, LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.279 kg nằm trong khoảng 1.6-2.0kg (gần ngưỡng trên)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '54Wh nằm trong khoảng 50-65Wh'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key 2mm, có đèn nền RGB'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Webcam IR HD (720p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio với Dolby Atmos (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM, thiết lập mật khẩu giám sát, khóa Kensington.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn (2 quạt cơ bản).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Gigabyte Gaming A16 GA6H-CVHI3VNC94SH', 'price_vnd': '38.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13), thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 5060 Laptop GPU (Không nằm trong danh sách 40 series cụ thể, giả định tương đương mức RTX 4060/4070 tầm trung)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB (16GB là mức 3, cộng thêm +0.5 vì có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 64GB) và SSD (2 khe M.2) đều nâng cấp được'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch 2.5K (QHD+), IPS, 165Hz, sRGB 100%, chống chói.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có USB-A, USB-C (hỗ trợ PD/DP), HDMI, LAN, khe M.2'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E + Bluetooth v5.2'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.268 kg (Nằm trong khoảng 1.6-2.0kg, nhưng gần giới hạn trên, xếp ở mức 2)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '76.1Wh (Nằm trong khoảng 50-65Wh, nhưng 76.1Wh hơi cao so với mức 3, xét theo thang điểm)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C (hỗ trợ PD/DP), nhưng không ghi rõ công suất PD cụ thể'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc cao cấp), có đèn LED'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD với micro mảng (1080p không IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có TPM 2.0, mật khẩu quản trị viên, khởi động an toàn'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 38.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.1, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.0, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Gigabyte Gaming A16 GA6H-CVHI3VN893SH', 'price_vnd': '33.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13), mạnh mẽ cho tác vụ đa nhiệm.'}, 'GPU_SCORE': {'score': 3, 'reason': 'RTX 5060 (Không có trong danh sách chuẩn, giả định tương đương mức RTX 4060/4070 tầm trung) với 8GB VRAM.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB qua 2 khe.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD Gen4, tốc độ tốt.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 64GB) và SSD (2 khe M.2) đều nâng cấp được.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch WUXGA (1920x1200), IPS, 165Hz, độ sáng 300nits.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có USB-A, USB-C (hỗ trợ PD/DP), HDMI, LAN, và khe SSD bổ sung.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E và Bluetooth v5.2.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.233 kg, nằm trong khoảng 1.6-2.0kg nhưng hơi nặng hơn một chút.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '76.1Wh, mức dung lượng pin khá tốt.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C hỗ trợ PD (không rõ công suất cụ thể, giả định ở mức trung bình).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key 1.7mm, có đèn nền RGB.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD với micro mảng, không đề cập đến IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM 2.0 và các lớp bảo mật cơ bản (mật khẩu, fTPM 2.0).'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 33.29M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop HP Omnibook X Flip 14-FK0092AU BZ7P5PA', 'price_vnd': '30.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 5 340, thuộc nhóm Core Ultra 5/7 100-series hoặc tương đương.'}, 'GPU_SCORE': {'score': 1, 'reason': 'AMD Radeon 840M Graphics là card đồ họa tích hợp.'}, 'NPU_SCORE': {'score': 4, 'reason': "Có bộ xử lý AI 'Ryzen AI', tương đương AMD Ryzen AI 300."}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, nhưng là LPDDR5x onboard (hàn liền), không thể nâng cấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Gen4).'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM hàn liền và không có khe cắm mở rộng.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch WUXGA (FHD+), tấm nền IPS, tần số quét không rõ, chất lượng màu trung bình.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 2 USB-C (một 10Gbps, một 40Gbps), HDMI, và jack tai nghe.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 802.11 ax (WiFi 6E).'}, 'WEIGHT_SCORE': {'score': 4, 'reason': 'Trọng lượng 1.526 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 59.16Wh nằm trong khoảng 40-49Wh (hoặc gần ngưỡng 50Wh).'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sử dụng USB-C PD (HP Sleep and Charge).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': "Bàn phím full size, có đèn nền, travel >= 1.5mm (dựa trên mô tả 'kích thước đầy đủ')."}, 'WEBCAM_SCORE': {'score': 4, 'reason': '1080p camera kèm hồng ngoại (IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (by Poly Studio), 2 loa stereo ổn.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có nhận diện khuôn mặt, TPM 2.0, và Microsoft Pluton.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (16GB) >= 8GB, SSD (512GB PCIe Gen4) != HDD/eMMC, Warranty status unknown (giả định không có BH tại VN). Tuy nhiên, do UPGRADABILITY=1 và PRICE_SCORE thấp, bị đánh dấu trigger.', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP Omnibook 5 AI 16-AF1048TU BZ7Q9PA', 'price_vnd': '26.190.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 225U (Core Ultra 5 100-series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics (Tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel AI Boost (~11 TOPS)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X Onboard (16GB, không nâng cấp được)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Gen4)'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Cả RAM và SSD hàn liền/Không có khe cắm mở rộng'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': None, 'COLOR': None, 'ANTIGLARE': 3}, 'reason': '16 inch, IPS, độ phân giải WUXGA (1920x1200). Chất lượng hiển thị cơ bản.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'USB-A: 1, USB-C: 2, HDMI: 1, 3.5mm: 1'}, 'WIFI_SCORE': {'score': 4, 'reason': 'WiFi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.725 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '59.16Wh (trong khoảng 40-49Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'N/A (Không ghi rõ công suất sạc)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (dựa trên mô tả chi tiết)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '1080p + IR (Camera IR HP True Vision FHD)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Nhận dạng khuôn mặt, fTPM 2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP OmniBook 7 14-FR0033TU C1MN2PA', 'price_vnd': '27.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 225U, thuộc dòng Core Ultra 5 100-series.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics tích hợp (không có card đồ họa rời).'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel AI Boost (12 NPU TOPS), tương đương Intel Core Ultra 100-series (~11 TOPS).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, dung lượng tiêu chuẩn cho máy tính xách tay hiện đại.'}, 'SSD_SCORE': {'score': 4, 'reason': '512 GB PCIe Gen4 NVMe M.2 SSD.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard (không thể nâng cấp); SSD có thể nâng cấp nhưng không rõ khả năng thay thế.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': None, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch, độ phân giải WUXGA (FHD+), tấm nền IPS, độ phủ màu 62.5% sRGB.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-A, 2 USB-C (bao gồm Thunderbolt 4), HDMI 2.1, và các cổng khác.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 (WiFi 6E + BT 5.3).'}, 'WEIGHT_SCORE': {'score': 4, 'reason': 'Trọng lượng 1.41 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '68 Wh, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím kích thước đầy đủ, có đèn nền.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera hồng ngoại 5MP có chức năng giảm nhiễu.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Âm thanh DTS:X Ultra, Loa kép, HP Audio Boost.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Hỗ trợ TPM và màn trập riêng tư của camera, nhưng thiếu vân tay/IR face.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 27.29tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U6_creator'], 'acceptable_profiles': ['U2_office', 'U5_gamer', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop HP 14‑EM0023AU D0BG7PA', 'price_vnd': '16.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 5 7520U (Ryzen 5 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'AMD Radeon 610M Graphics (Card đồ họa tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, Onboard (RAM không nâng cấp được)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe M.2 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Cả RAM và SSD đều không nâng cấp được (RAM onboard, SSD cố định)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 1, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD (1920x1080), tấm nền kém (45% NTSC), tần số quét 60Hz.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C, HDMI 1.4b, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 6 (2x2) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.4 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41 Wh Li-ion polymer (trong khoảng 30-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Smart pin (Không phải USB-C PD cao)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Bàn phím kích thước đầy đủ (giả định travel ~1.5mm)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p không IR (720p HD với tính năng giảm nhiễu)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa kép'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Hỗ trợ TPM (Firmware TPM) và các tính năng cơ bản'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định dựa trên phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP 245 G10 B8PF8AT', 'price_vnd': '14.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 5 7530U (Ryzen 5 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, 1 khe, không nâng cấp được'}, 'SSD_SCORE': {'score': 2, 'reason': '256GB PCIe NVMe SSD'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Chỉ có 1 khe RAM đã lắp, không thể nâng cấp RAM; SSD có thể thay thế nhưng dung lượng nhỏ.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD, tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 1x USB-C, HDMI 1.4b.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 6 (2x2) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.36 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41 Wh (trong khoảng 30-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Bộ nguồn AC, không có thông tin về công suất sạc nhanh.'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin về travel key, không có đèn nền.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p HD camera, không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa âm thanh nổi, micrô kỹ thuật số tích hợp.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ có McAfee Security (dùng thử) và Windows mặc định.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'GPU_SCORE = 1 (Card đồ họa tích hợp)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP 245 G10 BG5U8PT', 'price_vnd': '17.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 7730U (Ryzen 7 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, khả năng nâng cấp không rõ ràng'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có thể nâng cấp (RAM không nâng cấp được)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': '14 inch FHD IPS, 60Hz, 45% NTSC (Rất cơ bản)'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 1 USB-C, 1 HDMI'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 6 (2x2) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.36 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41 Wh (Trong khoảng 30-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Bộ nguồn AC (Không phải USB-C PD)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Full-size, có đèn nền'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p HD camera (Không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa âm thanh nổi, micrô kỹ thuật số tích hợp'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ có McAfee Security (dùng thử) và Windows cơ bản'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.1, 'final_score': 1.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
None
{'laptop_id': 'Laptop HP Victus 15-FA2731TX B85LNPA', 'price_vnd': '28.190.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, thuộc dòng H thế hệ 13.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050, VRAM 6GB.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4 3200MHz, có thể nâng cấp thêm 1 khe.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp (còn 1 khe trống) và SSD có thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 3.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), IPS, 144Hz, chống chói.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-A, 1 USB-C (có DP), HDMI, LAN, và khe M.2 SSD.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'WiFi 6E (802.11 ax) và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.185 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '52.5Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (không ghi rõ công suất cụ thể).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím kích thước đầy đủ, có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD với micrô mảng, không đề cập đến IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có mật khẩu quản trị viên, fTPM 2.0.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (16GB) >= 8GB, SSD (512GB SSD) != HDD/eMMC, Warranty status unknown (giả định không có BH tại VN). Tuy nhiên, do giá 28.19M vượt quá giới hạn 20M, và cần kiểm tra BH.', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U2: Giá 28.19M vượt quá giới hạn 25M.', 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.8, 'final_score': 1.8, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U2_office', 'U10_entertainment']}}
{'laptop_id': 'Laptop HP 14-EP0220TU B73VWPA', 'price_vnd': '12.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i3-1315U, thuộc dòng Core i5-H gen 12-13 (dù là i3 nhưng vẫn nằm trong phân khúc này)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB DDR4, dưới ngưỡng 16GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ có 1 khe RAM, SSD có thể nâng cấp được.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD (1920x1080), tần số quét không rõ, độ phủ màu thấp (62.5% sRGB).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 1x HDMI, 1x USB-C (chỉ truyền dữ liệu)'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 6 (2x2) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.4 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 2, 'reason': '41 Wh Li-ion polymer, dưới 40Wh'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Bộ đổi nguồn AC thông minh 45 W (USB-C PD <=45W)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel không rõ, có đèn nền'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p không IR (720p HD với chức năng giảm nhiễu)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Dual speakers (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có Mic mute key, Camera privacy shutter, TPM support'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể về thời hạn và dịch vụ tại VN.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB (8GB)', 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB (8GB)', 'price_score': 2, 'weighted_score': 2.6, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB (8GB)', 'price_score': 2, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Pin < 40Wh (41Wh)', 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 8GB (8GB - Cần kiểm tra chính xác tiêu chí, giả định vi phạm do gần ngưỡng)', 'price_score': 3, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.7, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U7_ai_data']}}
{'laptop_id': 'Laptop HP Omnibook X Flip 14-FM0076TU BZ7P6PA', 'price_vnd': '39.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 7 258V (Core Ultra 7 series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc 140V GPU (GPU rời tầm trung/cơ bản)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost (~40 TOPS)'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB LPDDR5x, nhưng Onboard nên không thể nâng cấp'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Gen4)'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM và SSD đều Onboard/Không có khe cắm mở rộng'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': None, 'COLOR': None, 'ANTIGLARE': 3}, 'reason': '14 inch WUXGA (FHD+), Tấm nền IPS, thiếu thông tin chi tiết về tần số quét và độ phủ màu.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-A, 1 USB-C (có Thunderbolt 4), HDMI'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.504 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '59.16Wh (trong khoảng 40-49Wh, tuy nhiên 59Wh hơi cao so với mức 4)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD hỗ trợ (dù công suất không được ghi rõ)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': "Full-size, có đèn nền, travel >= 1.5mm (giả định dựa trên mô tả 'full-size')"}, 'WEBCAM_SCORE': {'score': 4, 'reason': '1080p + IR (camera HP 5MP + hồng ngoại)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (Stereo ổn)'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Nhận diện khuôn mặt, TPM2.0, Microsoft Pluton'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp rõ ràng'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 39.39M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.83, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP Gaming OMEN 16-AM0176TX BX9D3PA', 'price_vnd': '45.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 7 255H (Core Ultra 7 200-series)'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060 (8 GB GDDR7)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra series (có tích hợp NPU ~40 TOPS)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp (2 khe)'}, 'SSD_SCORE': {'score': 4, 'reason': '512 GB PCIe Gen4 NVMe M.2 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '16 inch WUXGA (QHD+ tương đương), IPS, 165Hz, 100% sRGB, chống chói'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 2x USB-A, 1x USB-C (PD/DP), HDMI 2.1, LAN, Audio'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 (WiFi 6E + BT 5.3)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.43 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '83 Wh (trong khoảng 66-79Wh, gần ngưỡng 80Wh)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD hỗ trợ (cổng thông minh)'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Full-size, đèn nền RGB 4 vùng, có numpad'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '1080p FHD với chức năng giảm nhiễu theo thời gian'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Dual speakers với công nghệ âm thanh HP Audio Boost'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Màn trập riêng tư của camera, Hỗ trợ TPM'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt (N/A)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.55, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP 250 G10 B73TQAT', 'price_vnd': '13.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i3-1315U (Gen 13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB DDR4, có thể nâng cấp nhưng dung lượng thấp'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Gen4)'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM có thể nâng cấp nhưng giới hạn dung lượng)'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': None, 'COLOR': None, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD IPS, màn hình chống chói.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2 USB-A, 1 USB-C, HDMI, 3.5mm'}, 'WIFI_SCORE': {'score': 4, 'reason': 'WiFi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.624 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41.04Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Không rõ thông số sạc nhanh, giả định là USB-C PD tiêu chuẩn'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': "Travel key >= 1.5mm (giả định dựa trên mô tả 'bàn phím kích thước đầy đủ')"}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p không IR (HP True Vision HD)'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa stereo ổn (Realtek High Definition Audio)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'fTPM 2.0, Mật khẩu quản trị viên, Mật khẩu khởi động'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP 250R G10 C3RV3AT', 'price_vnd': '14.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 2, 'reason': 'Intel Core 3 100U, chip dòng U thế hệ cũ.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp Intel Graphics.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có Bộ xử lý AI được liệt kê).'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB DDR4, khả năng nâng cấp nhưng dung lượng thấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Gen4).'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có thể nâng cấp được (RAM có thể nâng cấp nhưng giới hạn dung lượng).'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080) IPS, tần số quét 60Hz, chất lượng màu cơ bản.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có PD/DP), 1x HDMI.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11 ax) và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.6 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41.04Wh nằm trong khoảng 30-65Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C hỗ trợ Power Delivery (PD), nhưng công suất không được ghi rõ.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard full size với đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p camera với màn che riêng tư.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM 2.0 và mật khẩu quản trị viên.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP 14-EP1178TU C89ZRPA', 'price_vnd': '19.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core 5 120U (Gen 12) - Chip tầm trung'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics tích hợp'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp (2 khe)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD PCIe Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 1, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD, tấm nền không rõ, tần số quét thấp, độ phủ màu thấp.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có PD/DP), 1x HDMI'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 6 (802.11 ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.4 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41.04Wh (trong khoảng 30-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel 1.2-1.5mm + Backlit'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '1080p + có màn trập riêng tư (IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'TPM 2.0, Mật khẩu quản trị viên, Mật khẩu bật nguồn'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP 250R G9 AX3C7AT', 'price_vnd': '12.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i3-1315U (Gen 13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB DDR4, có thể nâng cấp nhưng dung lượng thấp'}, 'SSD_SCORE': {'score': 2, 'reason': '256GB SSD PCIe'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM có thể nâng cấp tùy khe)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD IPS, tần số quét không rõ, chất lượng màu trung bình.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2 USB-A, 1 USB-C (PD/DP), HDMI, LAN, SD-Card'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11 ax) + Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.705 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41.04Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm + Backlit'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p không IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Cảm biến vân tay, TPM'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop HP Omnibook 7 Aero 13-BG1087AU BZ7S1PA', 'price_vnd': '28.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 5 340 (Ryzen AI series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'AMD Radeon 840M Graphics (Card đồ họa tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI (50 NPU TOPS)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5x, Onboard (Không thể nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512 GB PCIe Gen4 NVMe M.2 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Cả RAM và SSD đều không thể nâng cấp (Onboard)'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': None, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '13.3 inch WUXGA (1920x1200), IPS, 100% sRGB, 400 nits.'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-A, 2x USB-C (có PD/DP), HDMI 2.1, LAN'}, 'WIFI_SCORE': {'score': 4, 'reason': 'WiFi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1 kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '43 Wh Li-ion polymer'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel >=1.5mm (giả định dựa trên phân khúc tầm trung cao), có đèn nền'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '1080p + IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa kép, HP Audio Boost, Poly Studio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Hỗ trợ TPM và cửa trập bảo vệ webcam'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định theo phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP 14-EP0110TU 8C5K9PA', 'price_vnd': '20.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-1355U (Gen 13), thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có 2 khe, khả năng nâng cấp nhưng dung lượng hiện tại là 16GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Giả định là Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM (2 khe) và SSD (có khe M.2 trống)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': '14 inch FHD, tấm nền không rõ, tần số quét không rõ ràng, độ phủ màu không rõ ràng.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2 USB-A, 1 USB-C, HDMI, 1 Jack 3.5mm'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11 ax (WiFi 6)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.41 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41.04Wh, nằm trong khoảng 30-65Wh'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về công suất sạc nhanh (N/A)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Bàn phím tiêu chuẩn kích thước đầy đủ (giả định travel 1.2-1.5mm)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về độ phân giải hoặc tính năng IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Mật khẩu quản trị viên, Mật khẩu bật nguồn, TPM'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP 250 G9 AG2K7AT', 'price_vnd': '16.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5-1235U, Core i5-H gen 12-13'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp nhưng giới hạn dung lượng hiện tại'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM và SSD'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': None, 'COLOR': None, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD IPS, chất lượng hiển thị cơ bản.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2 USB-A, 1 USB-C, HDMI, LAN'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 802.11 ax (WiFi 6)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.696 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41.04Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin sạc nhanh cụ thể (Giả định là sạc tiêu chuẩn)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về travel, nhưng giả định là tiêu chuẩn'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD có micrô mảng, không đề cập IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Administrator Password, Power-On Password, TPM'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (GPU tích hợp)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP Victus 15-FB3116AX BX8U4PA', 'price_vnd': '28.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 7445HS (Ryzen 7 7000+) đạt mức 4'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB (thuộc nhóm RTX 3060/4050) đạt mức 3'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU (N/A)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp (1 khe trống). Tính +0.5 vì RAM có thể nâng cấp và <= 16GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '512 GB PCIe Gen4 NVMe SSD đạt mức 4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD, IPS, 144Hz, 300 nits. Chất lượng hiển thị khá tốt.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-A, 1 USB-C (có DP), HDMI 2.1, LAN, Audio.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Realtek Wi-Fi 6 + Bluetooth v5.4 (WiFi 6+BT5.x)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.29 kg nằm trong khoảng 1.2-1.4kg (gần ngưỡng 1.4kg).'}, 'BATTERY_SCORE': {'score': 3, 'reason': '52.5 Wh nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh (N/A), giả định là sạc tiêu chuẩn hoặc không có thông số PD cao.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím full size, có đèn nền RGB 1 vùng.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera 720p HD có chức năng giảm nhiễu tạm thời (1080p không IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Dual speakers với công nghệ HP Audio Boost.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Hỗ trợ TPM (phần mềm nền tảng) và màn trập riêng tư của camera.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, mặc định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 28.69tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop HP Victus 15-FA2451TX D17WPPA', 'price_vnd': '30.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H (Gen 13), thuộc nhóm Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 4050 (6GB VRAM).'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về NPU, giả định là mức cơ bản của Intel Core i5 thế hệ này).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5 5200MHz, có thể nâng cấp thêm 1 khe.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp cả RAM (còn khe trống) và SSD.'}, 'DISPLAY_SCORE': {'score': 3.5, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080) IPS với tần số quét 144Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-A, 1 USB-C (có PD/DP), HDMI, LAN, SD Card reader.'}, 'WIFI_SCORE': {'score': 4, 'reason': '802.11 ax (Wi-Fi 6) và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.2 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '70.07Wh nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (dù không ghi rõ công suất tối đa, nhưng có hỗ trợ PD).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên mô tả đầy đủ) và có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HP Wide Vision HD (1080p không đề cập IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (by DTS:X Ultra) với micro đa kênh.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có fTPM 2.0 và mật khẩu quản trị viên/khởi động.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành tiêu chuẩn 1 năm tại trung tâm BH.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.35, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.75, 'final_score': 3.75, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.35, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.75, 'final_score': 3.75, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.15, 'final_score': 4.15, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.75, 'final_score': 3.75, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.35, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.15, 'final_score': 4.15, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.35, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.25, 'final_score': 2.25, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop HP OmniBook 7 14-FR0024TU C1MN0PA', 'price_vnd': '37.190.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 7 255H (Core Ultra 7 series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc 140T GPU (GPU rời tầm trung/entry-level)'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel AI Boost (12 NPU TOPS)'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB LPDDR5 - Dung lượng lớn nhưng Onboard (không nâng cấp được)'}, 'SSD_SCORE': {'score': 4, 'reason': '512 GB PCIe Gen4 NVMe M.2 SSD'}, 'UPGRADABILITY': {'score': 2, 'reason': 'RAM Onboard và không có khe cắm mở rộng.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': None, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': '14 inch WUXGA (FHD+), IPS panel, 300 nits, 62.5% sRGB.'}, 'PORTS_SCORE': {'score': 4, 'reason': '2 USB-A, HDMI, Thunderbolt 4, USB-C 10Gbps.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 (WiFi 6E + BT 5.3)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.41 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '68 Wh (trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím kích thước đầy đủ, có đèn nền.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera hồng ngoại 5MP có chức năng giảm nhiễu.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa kép với công nghệ DTS:X Ultra và HP Audio Boost.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Hỗ trợ phần mềm TPM và màn trập riêng tư của camera.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt (N/A).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể về thời hạn tại VN.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
None
None
{'laptop_id': 'Laptop HP 250R G9 AX3D4AT', 'price_vnd': '18.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-1335U (Gen 13), thuộc nhóm Core Ultra 5/7 100-series hoặc tương đương.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về NPU, giả định là mức cơ bản của Intel Core i5 thế hệ này).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, mức tiêu chuẩn cho nhiều tác vụ, có thể nâng cấp nhưng không phải là cấu hình cao nhất.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Giả định là Gen4, phù hợp với mức 512GB Gen4).'}, 'UPGRADABILITY': {'score': 3, 'reason': 'RAM có thể nâng cấp, SSD có thể nâng cấp (cần kiểm tra khe cắm).'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080) IPS, tần số quét không rõ ràng (giả định 60Hz), chất lượng màu ở mức trung bình.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-A, 1 USB-C (có PD/DP), HDMI, LAN, SD-Card.'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11 ax (Wi-Fi 6) và Bluetooth 5.2.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.712 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41.04Wh, nằm trong khoảng 30-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (có khả năng cung cấp điện).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard kích thước đầy đủ, có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD với micro tích hợp, không đề cập đến IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có cảm biến vân tay, TPM.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U1_student', 'U2_office', 'U4_tech_expert', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U3_freelancer', 'U5_gamer', 'U6_creator', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP 250R G9 AX3C8AT', 'price_vnd': '13.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i3-1315U (Gen 13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB DDR4, có thể nâng cấp nhưng dung lượng thấp'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Gen4)'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM có thể nâng cấp thêm 1 khe)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD IPS, tần số quét không rõ, chất lượng màu trung bình.'}, 'PORTS_SCORE': {'score': 4, 'reason': '2 USB-A, 1 USB-C (PD/DP), HDMI, LAN, SD-Card'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11 ax) + Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.705 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41.04Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (có khả năng cung cấp nguồn)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': "Travel key >= 1.5mm (dựa trên mô tả 'kích thước đầy đủ')"}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p camera với micro tích hợp'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Cảm biến vân tay, TPM'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (giả định)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.56, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.44, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP 15-FD0083TU 8D736PA', 'price_vnd': '20.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-1355U (Gen 13) thuộc nhóm Core i7-H gen>=13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (Card đồ họa tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp (2 khe RAM). Tính +0.5 vì RAM có thể nâng cấp và <= 16GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe SSD (Gen4).'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 1, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tấm nền không rõ, tần số quét không rõ, độ phủ màu thấp (45% NTSC), chống chói cơ bản.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 1x USB-C, 1x HDMI, và cổng kết hợp.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 6 (2x2) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.59 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41 Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD 45W (dưới ngưỡng 65W).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Full-size, có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p nhưng không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa kép (Stereo).'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Hỗ trợ TPM (qua phần mềm điều khiển) và cửa trập webcam.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.35, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop HP 250 G9 AG4X7AT', 'price_vnd': '16.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5-1235U (Gen 12) - Phù hợp với mức Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB DDR4, khả năng nâng cấp nhưng dung lượng thấp (< 16GB)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Gen4)'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM có thể nâng cấp nhưng giới hạn dung lượng)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD IPS, tần số quét không rõ, chất lượng màu trung bình.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2 USB-A, 1 USB-C, HDMI, LAN, 3.5mm'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 6 (802.11 ax) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.7 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41.04Wh nằm trong khoảng 50-65Wh'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về sạc nhanh (USB-C PD)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': "Travel key >= 1.5mm (dựa trên mô tả 'kích thước đầy đủ'), có đèn nền"}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p không IR (HP TrueVision HD)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Mật khẩu quản trị viên, Mật khẩu khởi động, TPM'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại VN không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP Omnibook X Flip 14-FK0082AU BZ7N8PA', 'price_vnd': '39.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 7 350 (Ryzen AI 300 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'AMD Radeon 860M Graphics (Card đồ họa tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI (50 NPU TOPS)'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB LPDDR5x (Onboard, không nâng cấp được)'}, 'SSD_SCORE': {'score': 4, 'reason': '1 TB PCIe Gen4 NVMe M.2 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không có khe cắm mở rộng'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': None, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': '14 inch, IPS panel, 1920x1200, 400 nits, 62.5% sRGB.'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-A, 1x HDMI 2.1, nhiều cổng USB-C'}, 'WIFI_SCORE': {'score': 4, 'reason': 'WiFi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.39 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '59 Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm và có đèn nền'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '1080p với Camera IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa kép với DTS:X Ultra và HP Audio Boost'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Hỗ trợ TPM và cửa trập bảo vệ camera'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (32GB) >= 8GB, SSD (1TB NVMe) != HDD/eMMC, Warranty OK.', 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP Omnibook 5 16-AG1068AU BZ7T0PA', 'price_vnd': '27.190.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 5 340 (Ryzen AI series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'AMD Radeon 840M Graphics (Card đồ họa tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI (50 NPU TOPS)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5x Onboard (Không có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512 GB PCIe Gen4 NVMe M.2 SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không có khe cắm mở rộng'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 1, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': '16 inch WUXGA (FHD+), IPS panel, 62.5% sRGB, 300 nits.'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-A, 2x USB-C (có DP 2.1), HDMI 2.1, LAN'}, 'WIFI_SCORE': {'score': 4, 'reason': 'WiFi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.79 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '59 Wh Li-ion polymer (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': "Có đèn nền, travel >= 1.5mm (giả định dựa trên mô tả 'full size' và thiết kế)"}, 'WEBCAM_SCORE': {'score': 4, 'reason': '1080p + IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa kép + HP Audio Boost'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Phím tắt tắt mic, che camera, hỗ trợ TPM'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (16GB) >= 8GB, SSD (512GB NVMe) != HDD/eMMC, Warranty (1 năm) tại VN.', 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP 250R G9 C40LHAT', 'price_vnd': '14.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 2, 'reason': 'Intel Core 3 100U, chip thế hệ cũ hơn yêu cầu.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp Intel Graphics.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU).'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB RAM, khả năng nâng cấp nhưng dung lượng thấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Gen4).'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM có thể nâng cấp).'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD, tấm nền IPS, tần số quét 60Hz, độ phủ màu trung bình.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 1 USB-C (PD/DP), HDMI, LAN, SD Card.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11 ax) và Bluetooth 5.2.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.699 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41.04Wh, nằm trong khoảng 30-65Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C hỗ trợ Power Delivery (không rõ công suất cụ thể).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên mô tả đầy đủ) và có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD tích hợp, không đề cập đến IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có cảm biến vân tay, fTPM 2.0.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP Omnibook 5 AI 16-AF1046TU BZ7Q8PA', 'price_vnd': '27.190.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 225U (Core Ultra 5 100-series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics (Tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel AI Boost (~11 TOPS)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5X Onboard (16GB)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe (Gen4)'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Khó nâng cấp (RAM Onboard, SSD có thể thay thế nhưng không rõ khả năng nâng cấp thêm)'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': None, 'COLOR': None, 'ANTIGLARE': 3}, 'reason': '16 inch WUXGA (FHD+), IPS panel, chống chói.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 2 USB-C, HDMI, và jack 3.5mm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'WiFi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.734 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '59.16Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (Không rõ công suất cụ thể)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel >= 1.5mm + Backlit'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '1080p + IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa stereo ổn (Realtek High Definition Audio)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Nhận dạng khuôn mặt, fTPM 2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U6_creator', 'U7_ai_data'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop HP 250 G10 B1RY5PT', 'price_vnd': '17.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-1335U (Gen 13), thuộc nhóm Core Ultra 5/7 100-series hoặc tương đương.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể).'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB RAM, dưới ngưỡng 16GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Giả định là Gen4).'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM (2 khe, đang dùng 1 khe) và SSD.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': None, 'COLOR': None, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080) với tấm nền IPS.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 1 USB-C, HDMI, và 3.5mm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'WiFi 802.11 ax (WiFi 6E).'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.624 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41.04Wh, nằm trong khoảng 30-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về công suất sạc nhanh (N/A).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím kích thước đầy đủ với phím số và đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD (1080p không xác nhận IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có fTPM 2.0 và mật khẩu quản trị viên.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP 250R G10 CC9C0PT', 'price_vnd': '23.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core 7 150U (10 lõi) thuộc nhóm Core Ultra 5/7 100-series hoặc tương đương.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics tích hợp (Không có card đồ họa rời mạnh).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU TOPS).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp lên tối đa 32GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Gen4).'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp và SSD có thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080) IPS, tần số quét không rõ, chất lượng màu trung bình.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 1 USB-C (có PD/DP), HDMI, và jack 3.5mm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'WiFi 802.11 ax (WiFi 6E) và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.6 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41.04Wh nằm trong khoảng 30-65Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C hỗ trợ Power Delivery (PD), nhưng công suất không được ghi rõ (giả định thấp hơn 100W).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím kích thước đầy đủ (có numpad), có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Webcam Full HD (1080p) có màn che riêng tư.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM 2.0 và mật khẩu quản trị viên.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop HP 250R G10 C3SH6AT', 'price_vnd': '18.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core 5 120U (10 lõi) - Phù hợp với mức Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics tích hợp (Không có card đồ họa rời mạnh).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể).'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB DDR4, khả năng nâng cấp nhưng dung lượng hiện tại thấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Gen4).'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM có thể nâng cấp nhưng giới hạn dung lượng).'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': None, 'COLOR': None, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD IPS, chất lượng hiển thị cơ bản.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2 USB-A, 1 USB-C (có PD), 1 HDMI.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11 ax) + Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.6 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41.04Wh, nằm trong khoảng 30-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím kích thước đầy đủ với phím số và đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p camera với màn che riêng tư.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'TPM 2.0 và Mật khẩu quản trị viên.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
None
{'laptop_id': 'Laptop HP Pavilion 15-EG3095TU 8C5L6PA V2', 'price_vnd': '17.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5 - 1335U (Gen 13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp nhưng giới hạn ở mức 16GB hiện tại'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD NVMe PCIe'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có thể nâng cấp được (RAM có thể nâng cấp nhưng giới hạn dung lượng)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD, IPS panel, 60Hz, 45% NTSC (màu kém)'}, 'PORTS_SCORE': {'score': 3, 'reason': '1x USB-C, 2x USB 3.2, 1x HDMI, 1x USB-A'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 + Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.74 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 2, 'reason': '41 Wh (dưới ngưỡng 40Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh cụ thể (chủ yếu là USB-C)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không đề cập chi tiết travel, nhưng thường là chuẩn cơ bản'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD webcam (1080p không xác nhận IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio, HP Audio Boost (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin bảo mật sinh trắc học cao cấp'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP Pavilion 15-EG3093TU 8C5L4PA', 'price_vnd': '17.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5-1335U (Gen 13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB NVMe PCIe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB qua 2 khe'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 2, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD, IPS panel, 60Hz, 45% NTSC color gamut.'}, 'PORTS_SCORE': {'score': 3, 'reason': '1x USB-C, 2x USB 3.2, 1x HDMI'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 + Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.69 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 2, 'reason': '41 Wh (dưới 40Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin sạc nhanh cụ thể (chủ yếu là USB-C)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về travel key'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD webcam (1080p không xác định, không IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio, HP Audio Boost (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin bảo mật sinh trắc học cao cấp'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP Gaming Victus 15-FA1139TX 8Y6W3PA', 'price_vnd': '16.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-12450H (Gen 12) thuộc nhóm Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 2, 'reason': 'NVIDIA GeForce RTX 2050 (4GB VRAM) nằm ở mức thấp hơn (RTX 3050 trở xuống).'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về NPU cụ thể được liệt kê.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp lên 32GB. (+0.5 vì có thể nâng cấp và <= 16GB)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Giả định là Gen4, nhưng không xác nhận rõ ràng Gen5).'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB; SSD có thể nâng cấp (dựa trên cấu trúc máy).'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080) IPS với tần số quét 144Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C (có DP), HDMI, LAN, và khe thẻ nhớ.'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11 ax (WiFi 6) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': 'Trọng lượng 2.22 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Pin 52.5Wh nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ (HP Sleep and Charge), mặc dù công suất không được ghi rõ.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': "Có đèn nền và travel key >= 1.5mm (giả định dựa trên mô tả 'Các phím kích thước đầy đủ')."}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Camera HD HP Wide Vision có micrô mảng (1080p không IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (by B&O), 2 loa stereo ổn.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có Administrator Password, Power-On Password, TPM 2.0.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP Victus 16-R0374TX AY8Y7PA', 'price_vnd': '23.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13500HX (Gen 13) thuộc nhóm Core i7-H gen>=13 hoặc tương đương.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 4050 (6GB VRAM).'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU (N/A).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5 4800MHz, có thể nâng cấp (2 khe). (3 điểm + 0.5 vì có thể nâng cấp trong giới hạn 16GB)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Gen4).'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp (2 khe) và SSD có thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '16.1 inch FHD (1920x1080) IPS, 165Hz, 100% sRGB, chống chói.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3x USB-A, 1x USB-C (có PD/DP), HDMI, LAN, và Audio combo.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'WiFi 6E (802.11 ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.334 kg, nằm trong khoảng 1.6-2.0kg (gần mức tối đa).'}, 'BATTERY_SCORE': {'score': 4, 'reason': '70.07Wh, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C hỗ trợ PD (dù công suất không được ghi rõ, nhưng cổng hỗ trợ PD).'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Travel key >= 1.5mm, có đèn nền RGB 1 vùng, có numpad.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FHD với màn trập riêng tư (IR/Privacy shutter).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (by B&O), 2 loa stereo ổn.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có mật khẩu quản trị viên, mật khẩu bật nguồn, và TPM.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn (2 quạt cơ bản).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 23.69M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP 15-FC0086AU A6VV9PA', 'price_vnd': '16.090.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 5 7430U (Ryzen 5 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp (2 khe)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe M.2 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp cả RAM và SSD'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD, tấm nền SVA, 250 nits, 45% NTSC (Rất kém về màu sắc và tần số quét)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (chỉ truyền dữ liệu), HDMI 1.4b, Audio combo'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (2x2) + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.59 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 2, 'reason': '41 Wh (Trong khoảng 40-49Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'USB-C (không đề cập công suất sạc)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Kích thước đầy đủ với bàn phím số, có đèn nền'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p HD camera, không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Dual speakers (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Quản lý bảo mật, Màn trập riêng tư, TPM'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop HP Pavilion 15-EG3111TU 8U6L8PA', 'price_vnd': '17.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-1335U, thuộc dòng Core Ultra 5/7 100-series (dù là i5 thế hệ 13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (Card đồ họa tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp lên 32GB (+0.5 vì có thể nâng cấp)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe NVMe M.2 SSD (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB, SSD có thể nâng cấp (giả định)'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD (1920x1080), IPS, 60Hz, 45% NTSC (Rất kém về màu sắc và tần số quét)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C, 1x HDMI 2.1'}, 'WIFI_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về chuẩn WiFi)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.6 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41 Wh Li-ion (Trong khoảng 40-49Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về công suất sạc (N/A)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin về travel key, không có đèn nền'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p HD camera (Không phải 1080p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Dual speakers, HP Audio Boost (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về các tính năng bảo mật sinh trắc học'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (chỉ có tích hợp)', 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.7, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP Pavilion 15-EG3094TU 8C5L5PA V2', 'price_vnd': '17.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5 - 1335U (Gen 13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (Card đồ họa tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4, có thể nâng cấp nhưng giới hạn ở mức 16GB hiện tại'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD NVMe PCIe'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có thể nâng cấp được (RAM có thể nâng cấp nhưng giới hạn dung lượng)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD, IPS panel, 60Hz, 45% NTSC (màu kém)'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1x USB-C (đa năng), 2x USB 3.2, HDMI, 1x USB-A'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) + Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.74 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 2, 'reason': '41 Wh (dưới ngưỡng 40Wh)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin sạc nhanh cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về travel, nhưng giả định là tiêu chuẩn'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD webcam (1080p không xác nhận IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio, HP Audio Boost (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin bảo mật sinh trắc học cao cấp'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'GPU_SCORE = 1 (Card đồ họa tích hợp)', 'price_score': 2, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U5_gamer', 'U10_entertainment']}}
{'laptop_id': 'Laptop HP Pavilion 15-EG2088TU 7C0R0PA', 'price_vnd': '18.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i7-1260P (Gen 12) - Phù hợp với mức Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4 3200MHz, có thể nâng cấp (2 khe)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe NVMe M.2'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp (2 khe) và SSD có thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD, IPS panel, 60Hz, 45% NTSC (Rất kém về màu sắc và tần số quét)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C, 1x HDMI 2.0'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wifi 6'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.75 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '41 Whrs (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB Type-C (Không ghi rõ công suất PD, giả định là 65W hoặc tương đương)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về travel, nhưng cấu hình cơ bản thường đạt mức 3'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '1080p không IR (720p HD)'}, 'AUDIO_SCORE': {'score': 2, 'reason': 'Headphone/microphone combo (2 loa stereo yếu)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin bảo mật sinh trắc học cụ thể'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành tiêu chuẩn 1 năm tại trung tâm BH'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop HP Pavilion 14-ce1014TU 5JN05PA', 'price_vnd': '10.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 2, 'reason': 'Intel Core i3 8145U, thuộc dòng U thế hệ cũ.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics 620 (GPU tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU).'}, 'RAM_SCORE': {'score': 1, 'reason': 'Dung lượng RAM không được cung cấp, giả định dưới 8GB vì không có thông tin cụ thể.'}, 'SSD_SCORE': {'score': 3, 'reason': '500 GB SSD, hỗ trợ thay thế SSD M.2 PCIe (Gen không xác định nhưng dung lượng 500GB).'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có khả năng nâng cấp (có khe M.2). RAM không rõ ràng.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 1, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': 'Màn hình 14 inch FHD, tấm nền không rõ, tần số quét không rõ, chất lượng màu thấp.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1x USB-C, 2x USB 3.0, HDMI, SD card slot.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 802.11ac + Bluetooth 5.0.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.53 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Pin 41 Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Chỉ có USB-C, không có thông tin về công suất sạc.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về travel key, nhưng có đèn (giả định dựa trên cấu hình phổ thông).'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Không có thông tin về độ phân giải hoặc tính năng IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Audio combo (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin về các tính năng bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin về hệ thống tản nhiệt chuyên biệt.'}, 'WARRANTY_SCORE': {'score': 2, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 8GB (Giả định)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB (Giả định)', 'price_score': 3, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời', 'price_score': 0, 'weighted_score': 1.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB (Giả định)', 'price_score': 2, 'weighted_score': 2.6, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'GPU tích hợp và NPU < 20 TOPS (Giả định)', 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Pin < 40Wh (41Wh gần ngưỡng)', 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'SSD < 256GB (500GB OK, nhưng nếu xét theo tiêu chí nghiêm ngặt của U9 thì cần kiểm tra thêm)', 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student', 'U5_gamer', 'U7_ai_data']}}
None
{'laptop_id': 'Laptop HP Envy x360 14-FA0093AU AY8U3PA', 'price_vnd': '31.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 8840HS (Ryzen 7 7000+) đạt mức 4'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon Graphics'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI (16 NPU TOPS) tương đương mức 4'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB RAM, nhưng là Onboard nên không thể nâng cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '512 GB PCIe Gen4 NVMe SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard và không thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, 2880x1800, 120Hz, 100% DCI-P3, chống lóa.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 2x USB-C, HDMI 2.1, và các cổng khác.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'MediaTek Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.39 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '59 Wh, nằm trong khoảng 40-49Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím full size, có đèn nền.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 5MP có chức năng hồng ngoại (IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Poly Studio, Loa kép, DTS:X Ultra.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Hỗ trợ TPM và có màn trập che camera.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (32GB) đủ, SSD (512GB) đủ, nhưng cần kiểm tra chính sách bảo hành tại VN.', 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo LOQ 15ARP10E 83S0007AVN', 'price_vnd': '26.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 7735HS (Ryzen 7 7000 series)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB GDDR6 (Phù hợp mức RTX 3060/4050)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB SODIMM DDR5-4800, có thể nâng cấp nhưng giới hạn ở 16GB hiện tại'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM và có khe cắm SSD thứ hai'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD IPS 144Hz, 100% sRGB, chống chói'}, 'PORTS_SCORE': {'score': 5, 'reason': '2x USB-A, 1x USB-C (PD), HDMI 2.1, LAN, SD, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.8 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57.5Wh (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 135W'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (Giả định dựa trên phân khúc tầm trung cao)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p với Màn trập camera (Không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, HD audio, Nahimic Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Microsoft Pluton TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định theo phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 26.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.85, 'final_score': 2.9, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U7_ai_data', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 16ARP10 83K80016VN', 'price_vnd': '18.090.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 5 7533HS (Ryzen 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon 660M Graphics'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 24GB (16GB là mức 3)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 24GB; SSD có thể nâng cấp lên 1TB'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': '16 inch, IPS, 60Hz, 45% NTSC (Rất kém về màu sắc và tần số quét)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có hỗ trợ PD và DP), HDMI 1.4, SD, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.73 kg (trong khoảng 1.2-1.4kg, gần ngưỡng 1.2kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không rõ ràng'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Độ phân giải HD 720p, không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2W x2, Dolby Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 5 14AKP10 83HX00ABVN', 'price_vnd': '23.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 5 330, thuộc nhóm Core Ultra 5/7 100-series hoặc tương đương.'}, 'GPU_SCORE': {'score': 1, 'reason': 'AMD Radeon 820M Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI, up to 50 TOPS.'}, 'RAM_SCORE': {'score': 4, 'reason': '16GB DDR5, có 2 khe và khả năng nâng cấp lên 32GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 32GB) và SSD (có thể lên 1TB) đều nâng cấp được.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 2}, 'reason': 'Màn hình 14 inch OLED, 100% DCI-P3, nhưng tần số quét không được ghi nhận cụ thể (giả định thấp hơn mức cao nhất).'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2 USB-A, 2 USB-C (hỗ trợ DP 1.4 & PD), HDMI 2.1, SD, LAN.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.39 kg, dưới 1.2kg (gần ngưỡng 1.2kg, xếp vào nhóm nhẹ).'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc tầm trung) và Backlit.'}, 'WEBCAM_SCORE': {'score': 5, 'reason': 'FHD 1080p + IR với Màn trập riêng tư, Cảm biến ToF.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, 2W x2, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Microsoft Pluton TPM 2.0 Enabled và Camera hồng ngoại cho Windows Hello.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt cơ bản (2 quạt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.25, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.95, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.35, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Lenovo V15 G5 IRL 83HF00BRVA', 'price_vnd': '15.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, thuộc dòng Core Ultra 5/7 100-series (dù là thế hệ 13 nhưng nằm trong phân khúc này).'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể).'}, 'RAM_SCORE': {'score': 2.5, 'reason': '8GB RAM, khả năng nâng cấp lên 32GB (có +0.5 vì có thể nâng cấp).'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (lên 32GB) và SSD (nâng cấp lên 1TB) đều có thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tấm nền IPS, tần số quét không rõ (giả định 60Hz), độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 1x USB-C (có PD), HDMI, LAN.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 và Bluetooth 5.2.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.61 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '47Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền và travel không được xác định rõ ràng (giả định thấp hơn mức 1.5mm).'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Độ phân giải HD 720p, không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 1.5W x2.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Discrete TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.6, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo Legion 5 15IRX10 83LY00HQVN', 'price_vnd': '41.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13650HX (Gen 13) thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060 8GB GDDR7 (Mặc dù chưa có trong danh sách chuẩn, giả định tương đương RTX 40 series cao cấp)'}, 'NPU_SCORE': {'score': 4, 'reason': '572 AI TOPS (Tương đương Intel Core Ultra 200V/H)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB qua 2 khe cắm (+0.5 vì có thể nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 32GB) và SSD (có 2 khe M.2) đều nâng cấp được'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.3 inch WUXGA (QHD+ nhẹ), IPS, 165Hz, 100% sRGB, chống chói.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng: 2x USB-A, 2x USB-C (hỗ trợ PD, DP 2.1), HDMI 2.1, LAN, Audio combo.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax)'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.1 kg (Nằm trong khoảng 1.6-2.0kg, nhưng gần giới hạn trên)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '80Wh (Trong khoảng 66-79Wh, nhưng 80Wh nằm ở ngưỡng cao hơn một chút so với mức 4, tạm xếp 4)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 65W-100W (Sạc nhanh mạnh mẽ)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc HX), có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p với E-shutter (Không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, âm thanh độ nét cao (HD), có thương hiệu.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không đề cập chi tiết về hệ thống tản nhiệt, thường là 2 quạt cơ bản).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định theo phân khúc tầm trung cao).'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 41.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.73, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.93, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.83, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo ThinkPad E14 Gen 7 21SX00BNVN', 'price_vnd': '25.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 135H, thuộc dòng Core Ultra 5 100-series/135H.'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel AI Boost, up to 11 TOPS (tương đương Intel Core Ultra 100-series).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB; SSD có khả năng nâng cấp thêm ổ đĩa.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD (1920x1200), tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-A, 1 USB-C (Thunderbolt 4), HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211, Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.34 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 2, 'reason': '48Wh, thấp hơn mức khuyến nghị 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel khoảng 1.5mm (giả định dựa trên phân khúc), có đèn nền.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera lai FHD 1080p + hồng ngoại với màn trập camera.'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2W x2 loa, Dolby Atmos, âm thanh do HARMAN sản xuất.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Discrete TPM 2.0 Enabled, Bảo mật vân tay, Nhận diện khuôn mặt.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (16GB) >= 8GB, SSD (512GB SSD) != HDD/eMMC, Warranty status unknown (Giả định không có BH tại VN)', 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo LOQ 15IRX9 83DV01ALVN', 'price_vnd': '31.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13650HX (Gen 13) thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 4050 6GB GDDR6 (Phù hợp với mức RTX 4050)'}, 'NPU_SCORE': {'score': 4, 'reason': '194 AI TOPS (Thuộc nhóm Intel Core Ultra 200V/H ~40 TOPS)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB (16GB là mức 3, cộng thêm +0.5 vì có thể nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB; SSD có khả năng nâng cấp thêm ổ thứ hai.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD, IPS panel, 144Hz, 100% sRGB, chống chói.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3x USB-A, 1x USB-C (hỗ trợ PD 140W và DP 1.4), HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, 802.11ax'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.38 kg (Nằm trong khoảng 1.6-2.0kg, nhưng gần giới hạn trên, xếp ở mức 2)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh (Nằm trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 140W (Rất mạnh)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc HX series) và có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p với E-shutter (Không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, 2W x2, Nahimic Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn của dòng HX)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin không cung cấp chi tiết về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 31.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Lenovo ThinkPad E16 Gen 3 21SR00AAVN', 'price_vnd': '26.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 135H, thuộc dòng Core Ultra 5 100-series/135H.'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel AI Boost, up to 11 TOPS (tương đương Intel Core Ultra 100-series).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB (16GB là mức 3, cộng thêm +0.5 vì có khả năng nâng cấp).'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB, SSD có thể nâng cấp lên 1TB.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 16 inch WUXGA (FHD+), tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-A, 1 USB-C (Thunderbolt 4/USB4), HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211, Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.63 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '48Wh (thuộc khoảng 50-65Wh).'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc cao cấp), có đèn nền.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera lai FHD 1080p + hồng ngoại.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Âm thanh HD, Loa stereo 2W x2, Dolby Atmos, thương hiệu HARMAN.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Discrete TPM 2.0 Enabled, Bảo mật vân tay, Nhận diện khuôn mặt.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không đề cập chi tiết về hệ thống tản nhiệt phức tạp, giả định là cấu hình tản nhiệt cơ bản (2 quạt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U5_gamer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo ThinkBook 16 G9 IRL 21US008FVN', 'price_vnd': '21.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, thuộc dòng Core Ultra 5/7 100-series (dù là thế hệ 13 nhưng xếp vào nhóm hiệu năng tầm trung cao).'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về NPU, giả định là mức cơ bản của Intel Core i5 thế hệ này).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB (16GB là mức 3, cộng thêm +0.5 vì có khả năng nâng cấp).'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (2 khe, nâng cấp tới 64GB) và SSD (hỗ trợ tối đa 2TB) đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch, IPS, 60Hz, độ phủ màu thấp (45% NTSC), tần số quét thấp.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-A, 1 USB-C (có PD), HDMI 2.1, LAN, SD, và jack 3.5mm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 (WiFi 6E + BT 5.3).'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.7 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '48Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc), có đèn nền.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera lai FHD 1080p + hồng ngoại.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Discrete TPM 2.0 Enabled, Bảo mật vân tay, Nhận diện khuôn mặt.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt cơ bản).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo LOQ 15ARP10E 83S000DEVN', 'price_vnd': '27.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 7 170 (Gen cũ hơn yêu cầu của mức 4)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB (Tương đương RTX 3060/4050)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp nhưng giới hạn ở 16GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (theo thông số, RAM max 16GB)'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD IPS 144Hz, 100% sRGB, chống chói'}, 'PORTS_SCORE': {'score': 4, 'reason': '2 USB-A, 1 USB-C, HDMI, LAN, SD, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.8 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57.5Wh (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 135W'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Đèn nền trắng, travel không rõ (giả định 1.2-1.5mm)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Độ phân giải HD 720p, không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2, tối ưu âm thanh'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định dựa trên phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo Legion 5 15IRX10 83LY00HRVN', 'price_vnd': '39.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13650HX (Gen 13) thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5050 8GB GDDR7 (Mặc dù chưa có trong danh sách chuẩn, giả định tương đương dòng RTX 40 series mạnh mẽ)'}, 'NPU_SCORE': {'score': 4, 'reason': '440 AI TOPS (Tương đương Intel Core Ultra 200V/H)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB qua 2 khe RAM (+0.5 vì có thể nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 32GB) và SSD (có thể thêm ổ thứ hai) đều nâng cấp được'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.3 inch WUXGA (QHD+ nhẹ), IPS, 165Hz, 100% sRGB, chống chói.'}, 'PORTS_SCORE': {'score': 5, 'reason': '2x USB-A, 2x USB-C (hỗ trợ PD 65-100W, DP 2.1), HDMI, LAN, 3.5mm'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6 (802.11ax)'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.1 kg (Trong khoảng 1.6-2.0kg, nhưng gần mức giới hạn trên)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '80Wh (Trong khoảng 66-79Wh, nhưng 80Wh nằm ở ngưỡng cao hơn một chút so với mức 4, xét theo quy tắc 5=>=80Wh)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 65-100W'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc HX), có đèn nền'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p với E-shutter (Không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, 2W x2, có công nghệ âm thanh bổ sung (HARMAN, Nahimic)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không đề cập chi tiết về hệ thống tản nhiệt, mặc dù là dòng HX thường có tản nhiệt tốt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định theo phân khúc tầm trung cao)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 39.59M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.83, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo LOQ 15ARP10E 83S0006QVN', 'price_vnd': '26.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 7735HS (Ryzen 7 7000+) phù hợp với mức 4.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB, thuộc phân khúc RTX 3060/4050.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU, mặc dù CPU là dòng Ryzen 7 thế hệ mới.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB RAM, nằm ở mức 3. Có khả năng nâng cấp nhưng đã đạt mức 16GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe, đáp ứng tiêu chí 1TB Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có 2 khe RAM và khả năng nâng cấp SSD (tối đa 1TB/ổ).'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1080p) IPS 144Hz với 100% sRGB, chất lượng hiển thị tốt.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C (có PD), HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax).'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.8 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57.5Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 135W, vượt ngưỡng 100W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc), có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p với Màn trập camera (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2 với công nghệ HD và Nahimic Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Microsoft Pluton TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn (2 quạt cơ bản).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 26.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.83, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 5 OLED 15ARP10 83J3002SVN', 'price_vnd': '27.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 7735HS (Ryzen 7 7000+) phù hợp với mức 4.'}, 'GPU_SCORE': {'score': 2, 'reason': 'Card đồ họa tích hợp AMD Radeon 680M Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin cụ thể về NPU TOPS).'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB RAM, nhưng là Onboard (Không thể nâng cấp).'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD Gen4, đáp ứng tiêu chí 1TB Gen4 (dù dung lượng nhỏ hơn).'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có khả năng nâng cấp (có thể nâng lên 1TB).'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 15.1 inch OLED, WQXGA (2560x1600), 165Hz, 100% DCI-P3, chống lóa.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 2x USB-C (có PD/DP), HDMI 2.1, và các cổng khác.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.49 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '70Wh, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc cao cấp) và có đèn nền.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD 1080p + IR với Màn trập riêng tư.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Microsoft Pluton TPM 2.0 và Camera IR cho Windows Hello.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 27.59tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.51, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.41, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.61, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.81, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.11, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.91, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.71, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.11, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.51, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.81, 'final_score': 1.8, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U2_office'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Lenovo ThinkPad X1 Carbon Gen 13 Aura Edition 21NS010CVN', 'price_vnd': '60.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 7 258V, có hiệu năng cao và NPU mạnh mẽ (up to 47 TOPS)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics 140V (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost, up to 47 TOPS (gần mức 40 TOPS của Core Ultra 200 series)'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB RAM, nhưng là loại Soldered/Onboard nên không nâng cấp được.'}, 'SSD_SCORE': {'score': 5, 'reason': '1TB SSD PCIe 5.0x4 Performance NVMe, tốc độ rất cao.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM hàn liền và không thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, 100% DCI-P3, 500 nits, 120Hz.'}, 'PORTS_SCORE': {'score': 5, 'reason': '2x USB-A, 2x USB-C (Thunderbolt 4), HDMI 2.1, có nhiều cổng kết nối.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Intel Wi-Fi 7 BE201, hỗ trợ chuẩn WiFi 7 và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '986 g, dưới ngưỡng 1.2kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57Wh, mức dung lượng trung bình.'}, 'CHARGING_SCORE': {'score': 4, 'reason': '65W USB-C PD, khá tốt.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel khoảng 1.5mm (giả định dựa trên phân khúc).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD 1080p + IR Discrete với màn trập camera.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Loa âm thanh nổi, 2W x2, Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Discrete TPM 2.0, Bảo mật vân tay, Nhận diện khuôn mặt.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là thiết kế tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (32GB) không vi phạm, nhưng UPGRADABILITY (1) rất thấp và PRICE_SCORE (3) do giá cao so với giới hạn.', 'price_score': 2, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.4, 'final_score': 4.4, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 OLED 14IRH10 83K0000BVN', 'price_vnd': '20.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H (Gen 13) thuộc nhóm Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 24GB (16GB là mức 3, cộng thêm +0.5 vì có thể nâng cấp)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM và SSD (dù SSD là khe M.2 duy nhất)'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, 100% DCI-P3, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có PD/DP), 1x HDMI, 1x Audio jack.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.33kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Thông số pin không được cung cấp rõ ràng (chỉ ghi loại sạc 65W).'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 3.0 (65W)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Keyboard có đèn LED, travel không được xác định rõ nhưng thường ở mức chấp nhận được.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p với màn trập camera (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Âm thanh độ nét cao (HD), không có thông tin chi tiết về số loa.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin về các tính năng bảo mật sinh trắc học (vân tay/IR Face).'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo Legion Pro 7 16IAX10H 83F500JGVN', 'price_vnd': '83.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 9 275HX, thuộc nhóm chip cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'NVIDIA GeForce RTX 5070 Ti 12GB GDDR7, cấu hình rất mạnh.'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost, up to 13 TOPS.'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB DDR5-6400, dung lượng lớn và tốc độ cao.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD PCIe 4.0x4 NVMe, tốc độ cao.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có 2 khe RAM, có thể nâng cấp lên tối đa 32GB.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 16 inch OLED, 240Hz, 100% DCI-P3, độ sáng cao.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 3x USB-A, 2x USB-C (bao gồm Thunderbolt 4), HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.57 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 5, 'reason': '80Wh, dung lượng pin khá tốt.'}, 'CHARGING_SCORE': {'score': 5, 'reason': '400W Slim Tip (3-pin), sạc cực nhanh.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền RGB từng phím, travel tốt (giả định).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '5.0MP với màn trập camera.'}, 'AUDIO_SCORE': {'score': 4, 'reason': '4 loa stereo với khuếch đại thông minh.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là 2 quạt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 83.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 2.2, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U1_student', 'U10_entertainment']}}
{'laptop_id': 'Laptop Lenovo ThinkBook 14 G8 IAL 21SJ00EAVN', 'price_vnd': '24.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 135H, thuộc dòng Core Ultra 5 100-series/135H.'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel AI Boost, up to 11 TOPS (tương đương Core Ultra 100-series).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB qua 2 khe.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 64GB) và SSD (2 khe M.2) đều nâng cấp được.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD (1920x1200), tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 2x USB-A, 2x USB-C (bao gồm Thunderbolt 4), HDMI, LAN, SD.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.36 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 2, 'reason': 'Pin 45Wh, khá nhỏ.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel key khoảng 1.2-1.5mm và có đèn nền.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera lai FHD 1080p + hồng ngoại.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2 với Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM 2.0, vân tay và nhận diện khuôn mặt.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin chung về bảo hành tại VN chưa rõ ràng, giả định mức trung bình.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo Yoga Slim 7 14IMH9 83CV00D8VN', 'price_vnd': '24.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 125H, thuộc dòng Core Ultra 5 100-series/125H.'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel AI Boost, up to 11 TOPS (tương đương Intel Core Ultra 100-series).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5-6400, nhưng Onboard không nâng cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD M.2 PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard không nâng cấp và không có khe trống cho SSD.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, 100% DCI-P3, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 1x USB-A, 2x USB-C (Thunderbolt 4), HDMI 2.1, và jack 3.5mm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.39 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '65Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc cao cấp), Backlit.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD 1080p + IR với màn trập điện tử.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Loa stereo, 2W x4, hỗ trợ Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (16GB) >= 8GB, SSD (1TB) không phải HDD/eMMC, nhưng thiếu thông tin về Bảo hành tại VN.', 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 14ARP10 83K600A8VN', 'price_vnd': '18.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 5 7535HS (Ryzen 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon 660M Graphics'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 24GB (16GB hiện tại)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp, SSD có khả năng mở rộng (2 khe M.2)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch, IPS, 120Hz (N/A), 45% NTSC (Rất thấp)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (PD/DP), HDMI, SD, LAN'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.39 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '50Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không rõ'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Độ phân giải HD 720p, không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2W x2, Dolby Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định dựa trên phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.25, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.85, 'final_score': 2.9, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
None
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 5 OLED 14AKP10 83HX001JVN', 'price_vnd': '27.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'AMD Ryzen AI 7 350, thuộc nhóm chip cao cấp tương đương dòng M3/Ultra 7/9.'}, 'GPU_SCORE': {'score': 1, 'reason': 'AMD Radeon 860M Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI, up to 50 TOPS.'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB DDR5, dung lượng lớn.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM lên tối đa 32GB qua 2 khe.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 2}, 'reason': 'Màn hình 14 inch OLED, 100% DCI-P3, độ sáng 400 nits, nhưng tần số quét không được ghi nhận (giả định thấp).'}, 'PORTS_SCORE': {'score': 5, 'reason': '2x USB-A, 2x USB-C (hỗ trợ PD/DP), HDMI 2.1, SD Card Reader.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.39 kg, dưới 1.2kg (gần ngưỡng 1.2kg, xếp 5 vì rất nhẹ).'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh, mức trung bình.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc cao).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD 1080p + IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Microsoft Pluton TPM 2.0 Enabled, Camera IR cho Windows Hello.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 27.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.25, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo ThinkPad X1 Carbon Gen 13 Aura Edition 21NS010BVN', 'price_vnd': '60.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 7 258V, hỗ trợ AI Boost lên tới 47 TOPS.'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics 140V (GPU tích hợp).'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost, up to 47 TOPS (gần mức 40 TOPS của Core Ultra 200V/H).'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB LPDDR5x Onboard, nhưng không thể nâng cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 5.0x4 Performance NVMe (Gen 5).'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM hàn liền và không có khe cắm nâng cấp.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, 2880x1800, 120Hz, 100% DCI-P3, 500 nits.'}, 'PORTS_SCORE': {'score': 5, 'reason': '2x USB-A, 2x USB-C (Thunderbolt 4), HDMI 2.1, LAN, Audio.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Intel Wi-Fi 7 BE201 (WiFi 7) + Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg (986 g).'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc cao cấp) + Backlit.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD 1080p + IR Discrete với màn trập camera.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2 + Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Discrete TPM 2.0 Enabled, Bảo mật vân tay, Nhận diện khuôn mặt.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định theo phân khúc tầm trung cao).'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 60.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.55, 'final_score': 1.6, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 14ARP10 83K6005VVN', 'price_vnd': '18.090.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 5 7535HS (Ryzen 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon 660M Graphics'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 24GB (16GB là mức 3)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD (1920x1200), tấm nền IPS, tần số quét không rõ ràng, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-A, 1x USB-C (có hỗ trợ PD & DP), HDMI, SD, LAN'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.39 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '50Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p với Màn trập camera (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Microsoft Pluton TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo LOQ 15IRX10 83JE01AGVN', 'price_vnd': '34.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13645HX (Gen 13) thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5050 8GB GDDR7, có VRAM 8GB và TDP 100W'}, 'NPU_SCORE': {'score': 4, 'reason': '440 AI TOPS, tương đương mức của Intel Core Ultra 200V/H'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB (16GB là mức 3, cộng thêm +0.5 vì có thể nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB; SSD có khả năng nâng cấp thêm ổ đĩa.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD, IPS panel, 144Hz, 100% sRGB, chống chói.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 3 USB-A, 1 USB-C (PD 65-100W, DP 1.4), HDMI 2.1, LAN, và 3.5mm.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax)'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.4 kg nằm trong khoảng 1.6-2.0kg (gần ngưỡng 2.0kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 170W (rất mạnh)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc HX), có đèn RGB.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '5.0MP với E-shutter (không đề cập rõ IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, 2W x2, có công nghệ Nahimic Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn (2 quạt cơ bản).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 34.79M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.73, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.7, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Lenovo V14 G5 IRL 83HD0033VN', 'price_vnd': '21.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core 5 210H (Gen mới, thuộc phân khúc Core i5-H gen 12-13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB; SSD có khả năng nâng cấp thêm 1TB'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD, tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có PD), HDMI, LAN'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.37 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '47Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không rõ ràng'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Độ phân giải HD 720p với màn trập camera (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, âm thanh độ nét cao (HD)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Discrete TPM 2.0 Enabled và hỗ trợ vân tay'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp rõ ràng'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Lenovo LOQ 15IRX10 83JE00PEVN', 'price_vnd': '35.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13650HX (Gen 13) thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5050 8GB GDDR7, có VRAM 8GB và TDP 100W'}, 'NPU_SCORE': {'score': 4, 'reason': '440 AI TOPS, tương đương mức của Intel Core Ultra 200V/H'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB (Tính 3 + 0.5 vì có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB; SSD có hỗ trợ thêm ổ M.2'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD, IPS panel, 144Hz, 100% sRGB, chống chói.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3 USB-A, 1 USB-C (hỗ trợ PD 65-100W & DP 1.4), HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax)'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.4 kg nằm trong khoảng 1.6-2.0kg (gần ngưỡng trên)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 170W (cao hơn 100W yêu cầu)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Backlit 24-Zone RGB, travel >= 1.5mm (giả định dựa trên phân khúc HX)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '5.0MP với E-shutter (Không đề cập rõ ràng về IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2, tối ưu bởi Nahimic Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại VN không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 35.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 14ARP10 83K6005UVN', 'price_vnd': '19.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 5 7535HS (Ryzen 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon 660M Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB DDR5, có thể nâng cấp lên tối đa 24GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': '14 inch FHD (1920x1200), tấm nền IPS, tần số quét thấp (không rõ), độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có hỗ trợ PD & DP), HDMI, SD, Audio combo'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.39 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '50Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không được đề cập chi tiết nhưng thường ở mức cơ bản.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p với Màn trập camera (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Microsoft Pluton TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định dựa trên phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Flex 5 14ABR8 82XX00FWVN', 'price_vnd': '19.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Core i5-H gen 12-13 (Ryzen 7 5825U) - Phù hợp mức trung bình.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR4x Onboard, không thể nâng cấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Cả RAM và SSD đều không thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': '14 inch FHD (1920x1200), tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 1 USB-C (hỗ trợ PD/DP), HDMI, SD, 3.5mm.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.55 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '52.5Wh nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel 1.2-1.5mm + đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'FHD 1080p với màn trập camera (không đề cập IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2W x2 loa, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 và Bảo mật vân tay.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (GPU_SCORE=1)', 'price_score': 3, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.7, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U5_gamer']}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 14ARP10 83K600E9VN', 'price_vnd': '18.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 5 7535HS (Ryzen 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon 660M Graphics'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp nhưng giới hạn ở mức 16GB'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có khả năng nâng cấp (có 2 khe M.2 2242)'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch FHD (1920x1200), tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có PD), HDMI 1.4, SD, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.39 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '50Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không được đề cập chi tiết'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Độ phân giải HD 720p, không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2W x2 loa, Dolby Audio'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Firmware TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 16IRH10 83K20001VN', 'price_vnd': '20.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H, thuộc dòng H thế hệ 13'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp lên 24GB (8GB hàn + 8GB SO-DIMM)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp; SSD có khả năng thêm ổ thứ hai.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': '16 inch FHD (1920x1200), IPS, 60Hz, 45% NTSC (Rất thấp về màu sắc).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có PD/DP), HDMI, SD, Audio.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.73 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không được đề cập chi tiết nhưng thường là mức cơ bản.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p, không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt (N/A).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (chỉ có tích hợp)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo ThinkBook 14 G9 AHP 21V0005NVN', 'price_vnd': '22.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 2, 'reason': 'AMD Ryzen 5 220, thuộc dòng cũ hơn.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon 740M Graphics.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB, SSD hỗ trợ thêm ổ đĩa.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD (1920x1200), tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có nhiều cổng kết nối bao gồm USB-C (USB4, PD), HDMI 2.1, Ethernet, và nhiều cổng USB-A.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.36 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Pin 48Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel key khoảng 1.2-1.5mm và có đèn nền.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera lai FHD 1080p kèm hồng ngoại.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2 với Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Discrete TPM 2.0, Vân tay và Nhận diện khuôn mặt.'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 5 15ARP10 83J3001DVN', 'price_vnd': '24.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 7735HS (Ryzen 7 7000+) phù hợp với mức 4.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon 680M Graphics.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU (N/A).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, mức tiêu chuẩn cho nhiều tác vụ.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD Gen4, đáp ứng tiêu chí 1TB Gen4.'}, 'UPGRADABILITY': {'score': 2, 'reason': 'RAM hàn liền và không thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 15.1 inch OLED, WQXGA (2560x1600), 165Hz, 100% DCI-P3, chống lóa.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2 USB-A, 2 USB-C (hỗ trợ DP 1.4/PD), HDMI 2.1, LAN, và thẻ nhớ.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': 'Trọng lượng 1.49 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 70Wh nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Thông tin về travel không được cung cấp chi tiết, giả định là 1.2-1.5mm.'}, 'WEBCAM_SCORE': {'score': 5, 'reason': 'FHD 1080p + IR và Màn trập riêng tư.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Microsoft Pluton TPM 2.0 và Camera IR cho Windows Hello.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành 1 năm với trung tâm bảo hành đầy đủ tại VN.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 15Q8X10 83N3002PVN', 'price_vnd': '21.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Snapdragon X X1-26-100 (Hiệu năng tương đương Core Ultra 5/7 dòng thấp)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Qualcomm Adreno (GPU tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Qualcomm Hexagon NPU, up to 45 TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5x Onboard, không nâng cấp'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM hàn liền và không có khe nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.3 inch FHD (1920x1200), IPS panel, 60Hz, 45% NTSC color gamut.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có PD/DP), HDMI 1.4, SD, 3.5mm'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.55 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không đèn, travel không rõ ràng'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p tích hợp, có màn che bảo mật'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Stereo speakers, Dolby Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Microsoft Pluton TPM 2.0 Enabled + Bảo mật vân tay'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 5 14IMH10 83V6001HVN', 'price_vnd': '27.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 135H, thuộc dòng Core Ultra 5 100-series/135H.'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel AI Boost, up to 11 TOPS (tương đương Intel Core Ultra 100-series).'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB DDR5-5600, dung lượng lớn và có khả năng nâng cấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB, SSD có hỗ trợ thêm ổ đĩa.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, 100% DCI-P3, nhưng tần số quét chỉ là 60Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-C (hỗ trợ DP 1.4/PD), 1x USB-A, HDMI 2.1, và thẻ microSD.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.39 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh, mức pin trung bình.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền và travel key ổn định (giả định dựa trên cấu hình cao cấp).'}, 'WEBCAM_SCORE': {'score': 5, 'reason': 'Camera FHD 1080p + hồng ngoại với màn trập camera.'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2W x2 loa, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 27.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.44, 'final_score': 4.4, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.83, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 14IRH10 83K00009VN', 'price_vnd': '22.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H, thế hệ 13, hiệu năng mạnh mẽ.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB DDR5, có thể nâng cấp nhưng đã đạt mức cao.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0, dung lượng vừa phải.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 24GB; SSD có thể nâng cấp lên 1TB.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch FHD (1920x1200), tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 1x USB-C (có PD/DP), HDMI, SD, Audio.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.2.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.43 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh, mức pin trung bình.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không được đề cập chi tiết.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p, không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2, có Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 16IRH10 83K20004VN', 'price_vnd': '22.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13), thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB DDR5, có thể nâng cấp lên 24GB (16GB SO-DIMM + 8GB hàn)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp; SSD có khả năng nâng cấp thêm ổ thứ hai.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch WUXGA (FHD+), tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có DP/PD), HDMI 1.4, SD, Audio.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.73 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không được xác định rõ ràng.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p, không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt (N/A).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 14ARP10 83K600EAVN', 'price_vnd': '20.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 7735HS (Ryzen 7 7000+) phù hợp với mức 4.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon 680M Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU mạnh mẽ).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, mức tiêu chuẩn cho nhiều tác vụ.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0, tốc độ tốt.'}, 'UPGRADABILITY': {'score': 3, 'reason': 'SSD có khả năng nâng cấp (có 2 khe M.2), RAM có giới hạn (1 khe tối đa 16GB).'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD (1920x1200), tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 1x USB-C (có hỗ trợ PD), HDMI 1.4, SD Card, và jack 3.5mm.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': 'Trọng lượng 1.39 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Pin 50Wh, mức dung lượng trung bình.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W, khá tốt.'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền và travel key không được xác định rõ ràng (dưới 1.5mm).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD 1080p kèm hồng ngoại (IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2W x2 loa với Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo LOQ 15IRX9 83DV01H3VN', 'price_vnd': '34.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13645HX (Gen 13) thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 4050 6GB GDDR6 (Phù hợp với mức RTX 4050)'}, 'NPU_SCORE': {'score': 4, 'reason': '194 AI TOPS (Thuộc nhóm Intel Core Ultra 200V/H ~40 TOPS)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB (16GB là mức 3, cộng thêm +0.5 vì có thể nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 32GB) và SSD (có 2 khe M.2) đều nâng cấp được'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD, IPS panel, 144Hz, 100% sRGB, chống chói.'}, 'PORTS_SCORE': {'score': 5, 'reason': '3x USB-A, 1x USB-C (PD 140W, DP 1.4), HDMI 2.1, LAN, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, 802.11ax'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.38 kg (Trong khoảng 1.6-2.0kg, nhưng gần giới hạn trên)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh (Thuộc khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 140W'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc HX), có đèn nền'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p với E-shutter (Không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2, tối ưu với Nahimic Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định theo phân khúc tầm trung cao)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 34.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Lenovo LOQ Essential 15ARP10E 83S0000DVN', 'price_vnd': '25.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 5 7535HS (Ryzen 7000 series)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB SODIMM DDR5-4800, có thể nâng cấp thêm 1 khe'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp cả RAM (còn khe trống) và SSD'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD IPS 144Hz, 100% sRGB'}, 'PORTS_SCORE': {'score': 4, 'reason': '2 USB-A, 1 USB-C (có PD), HDMI 2.1, LAN, SD Card Reader'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6, Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.8 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57.5Wh'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 65–100W'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel 1.2-1.5mm + đèn nền trắng'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p với màn trập camera (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2, tối ưu với Nahimic Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo Legion 7 16IAX10 83KY001VVN', 'price_vnd': '65.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 9 275HX, thuộc nhóm chip cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'NVIDIA GeForce RTX 5070 8GB GDDR7, cấu hình rất mạnh.'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost, up to 13 TOPS.'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB DDR5, dung lượng lớn và có khả năng nâng cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB qua 2 khe; SSD có thể thêm ổ đĩa thứ hai.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 16 inch OLED, 240Hz, 100% DCI-P3, độ sáng cao.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối bao gồm 2x USB-A, 2x USB-C (bao gồm Thunderbolt 4), HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.0 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '84Wh, mức pin khá tốt cho máy cấu hình cao.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 65-100W, sạc nhanh công suất cao.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền Per-key RGB và travel key tốt (giả định).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '5.0MP + IR với E-shutter.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2 với công nghệ âm thanh HD.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là 2 quạt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 65.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 2.0 (Giá 65.99M vượt quá max 25M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 2.0 (Giá 65.99M vượt quá max 35M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data'], 'acceptable_profiles': ['U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U10_entertainment']}}
{'laptop_id': 'Laptop Lenovo LOQ 15IRX9 83DV012LVN', 'price_vnd': '22.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13450HX (Gen 13) thuộc nhóm Core i7-H gen>=13 hoặc tương đương.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB, nằm ở mức RTX 3060/4050.'}, 'NPU_SCORE': {'score': 4, 'reason': '142 AI TOPS, tương đương với Intel Core Ultra 200V/H (~40 TOPS).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '12GB DDR5, có thể nâng cấp lên 32GB (16GB là mức chuẩn). (+0.5 vì có thể nâng cấp)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB; SSD có khả năng nâng cấp thêm ổ thứ hai.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD, IPS panel, 144Hz, 100% sRGB, chống chói.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 3x USB-A, 1x USB-C (hỗ trợ PD 140W và DP 1.4), HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax).'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.38 kg, nằm trong khoảng 1.6-2.0kg (gần giới hạn trên).'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 140W (Rất mạnh).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc HX series) và có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p với E-shutter (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, 2W x2, có công nghệ Nahimic Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là 2 quạt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin không cung cấp chi tiết về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.3, 'final_score': 2.3, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Lenovo LOQ 15AHP10 83JG0047VN', 'price_vnd': '33.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 7 250, thuộc dòng cũ hơn (Ryzen 5000/7000 series mới là 4)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 5050 8GB GDDR7, mức trung bình.'}, 'NPU_SCORE': {'score': 4, 'reason': 'Integrated AMD Ryzen AI, up to 16 TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, khả năng nâng cấp lên 32GB (16GB là mức tiêu chuẩn).'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB qua 2 khe; SSD có thể thêm ổ thứ hai.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD, IPS panel, 144Hz, 100% sRGB, chống chói.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3 USB-A, 1 USB-C (hỗ trợ PD 65-100W), HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.4 kg, nằm trong khoảng 1.6-2.0kg nhưng hơi nặng hơn một chút.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh, mức khá.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 65-100W, sạc nhanh mạnh mẽ.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Backlit 24-Zone RGB, travel >= 1.5mm (giả định dựa trên phân khúc).'}, 'WEBCAM_SCORE': {'score': 3, 'reason': '5.0MP với E-shutter (1080p).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, 2W x2, Nahimic Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin không cung cấp chi tiết về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 33.59M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Lenovo V14 G4 IRU 83A000FNVN', 'price_vnd': '13.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, thuộc dòng H thế hệ 13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4-3200, có thể nâng cấp lên tối đa 16GB thông qua khe SO-DIMM.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM và SSD (SSD có thể nâng cấp lên 1TB).'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '14 inch FHD, tấm nền IPS, tần số quét không rõ (có thể thấp), độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1 USB-A, 1 USB 3.2 Gen 1, 1 USB-C (có DP 1.2), HDMI, LAN, 3.5mm.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, 802.11ax 2x2 + Bluetooth 5.2.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.43 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '38Wh, nằm trong khoảng 30-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p với Màn trập camera (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U5_gamer', 'U8_business', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo LOQ Essential 15IRX11 83SC003RVN', 'price_vnd': '30.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13450HX (Gen 13) thuộc nhóm Core i7-H gen>=13 hoặc tương đương.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5050 8GB GDDR7, có hiệu năng mạnh mẽ.'}, 'NPU_SCORE': {'score': 4, 'reason': '440 AI TOPS, tương đương mức của Intel Core Ultra 200V/H.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên tối đa 16GB DDR5-4800 (Điểm 3 + 0.5 vì khả năng nâng cấp).'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM và SSD (dù SSD hiện tại là 512GB, nhưng có hỗ trợ thêm). '}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080) IPS, 144Hz, 100% sRGB, chống chói.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-A, 1 USB-C, HDMI, LAN.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax).'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.3 kg nằm trong khoảng 1.6-2.0kg đến 2.0kg (gần ngưỡng 2.0kg).'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 135W (rất mạnh).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc HX), có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p với E-shutter (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, 2W x2, có công nghệ Nahimic Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn (2 quạt cơ bản).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data'], 'acceptable_profiles': ['U1_student', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo Legion 5 15IRX10 83LY00A7VN', 'price_vnd': '37.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core i7-14700HX, thuộc nhóm CPU cao cấp nhất hiện tại.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5050 8GB GDDR7, hiệu năng mạnh mẽ.'}, 'NPU_SCORE': {'score': 4, 'reason': '440 AI TOPS, tương đương mức cao của Intel Core Ultra series.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB qua 2 khe RAM.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB; SSD có khả năng thêm ổ đĩa thứ hai.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 15.1 inch WQXGA (2560x1600) OLED 165Hz, 100% DCI-P3, 500nits.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất đầy đủ: 2x USB-A, 2x USB-C (hỗ trợ PD 100W/DP 2.1), HDMI 2.1, LAN, Audio.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.9 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 5, 'reason': '80Wh, dung lượng pin khá tốt.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD hỗ trợ 65W-100W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc cao cấp) và có đèn RGB.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '5.0MP với màn trập điện tử (có thể ngụ ý chất lượng tốt).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2 với công nghệ âm thanh HD.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt tiêu chuẩn cho dòng HX.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 37.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.65, 'final_score': 4.7, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.55, 'final_score': 1.6, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Lenovo LOQ 15ARP9 83JC00HYVN', 'price_vnd': '21.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 5 7235HS (Ryzen 7000 series)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 4, 'reason': '24GB DDR5, có thể nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp, SSD có khả năng nâng cấp thêm'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD, IPS panel, 144Hz, 100% sRGB, chống chói'}, 'PORTS_SCORE': {'score': 4, 'reason': '3 USB-A, 1 USB-C (PD/DP), HDMI 2.1, LAN'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.38 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '60Wh (trong khoảng 40-49Wh)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 140W'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc tầm trung cao)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p với màn trập E-shutter (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, 2W x2, Nahimic Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo Gaming Legion 5 15ACH6H 82JU00DGVN', 'price_vnd': '36.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7-5800H (Ryzen 7 series processor)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3060 (6GB GDDR6)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 2, 'reason': '8GB DDR4 - Dưới mức khuyến nghị 16GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 3.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM lên 32GB qua 2 khe'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD IPS 165Hz với 100% sRGB.'}, 'PORTS_SCORE': {'score': 4, 'reason': '>=2 USB-A, 1x USB-C, HDMI 2.1, LAN'}, 'WIFI_SCORE': {'score': 4, 'reason': '802.11ax 2x2 (WiFi 6E)'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.4 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '80 WHr (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C (Không có thông tin công suất cụ thể)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về travel, nhưng có đèn (giả định dựa trên cấu hình tầm trung cao)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p (720p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa stereo ổn'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin bảo mật sinh trắc học cụ thể'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 8GB (Laptop có 8GB, nhưng theo tiêu chí Deal-Breaker U1 yêu cầu RAM < 8GB để trigger, cần kiểm tra lại logic. Tuy nhiên, nếu xét theo tiêu chí RAM_SCORE=2 (8GB DDR4 - Dưới mức khuyến nghị 16GB), ta sẽ xem xét. Nếu giả định 8GB là đủ, deal_breaker_triggered = false. Dựa trên rule: U1: RAM < 8GB. Laptop có 8GB. Giả sử không trigger.', 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo ThinkBook 16 G6 IRL 21KH00W8VN', 'price_vnd': '17.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, thuộc dòng H thế hệ 13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB; SSD có khả năng nâng cấp thêm ổ đĩa.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 16 inch FHD (1920x1200), tấm nền IPS, độ phủ màu thấp (45% NTSC), tần số quét 60Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C (có hỗ trợ Thunderbolt/USB4), HDMI, LAN, SD Card.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.7 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '71Wh, mức khá.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD 65W (sạc qua củ sạc gắn tường).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard có travel >= 1.5mm và có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'FHD 1080p với màn trập camera (không đề cập IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2 với Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM 2.0 và bảo mật vân tay.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo Gaming Legion 5P 15IMH05 82AY003FVN', 'price_vnd': '27.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-10750H (Gen 10), thuộc nhóm Core i7-H gen>=13 hoặc tương đương trong phạm vi đánh giá.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce GTX 1650Ti 4GB, nằm ở mức RTX 3060/RTX 4050 tầm trung.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về NPU cụ thể (N/A).'}, 'RAM_SCORE': {'score': 1, 'reason': 'Dung lượng RAM không được cung cấp (N/A), không xác định khả năng nâng cấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4, đáp ứng tiêu chí 512GB Gen4.'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Có khe trống cho SSD M.2, nhưng không rõ về RAM.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080) WVA, 144Hz, 300nits, có chống lóa.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 4x USB 3.2 Gen 1, 1x USB-C, HDMI 2.0, Ethernet.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'WiFi 802.11ax (WiFi 6) và Bluetooth v5.0.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': 'Trọng lượng 2.3 kg, nằm trong khoảng 1.6-2.0kg (gần ngưỡng 2.0kg).'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 80 Whr, nằm trong khoảng 66-79Wh (Lưu ý: 80Whr hơi cao so với mức 4, nhưng gần ngưỡng).'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Chỉ có USB-C (không ghi rõ công suất PD).'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin về travel key, đèn nền.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về độ phân giải hoặc tính năng IR.'}, 'AUDIO_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về cấu hình loa.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin về các tính năng bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 2, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo Legion 7 16IAX10 83KY001UVN', 'price_vnd': '79.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 9 275HX, thuộc nhóm chip cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'NVIDIA GeForce RTX 5060 8GB GDDR7, cấu hình rất mạnh.'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost, up to 13 TOPS.'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB DDR5, dung lượng lớn và có khả năng nâng cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB qua 2 khe; SSD có thể thêm ổ đĩa thứ hai.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 16 inch OLED, 240Hz, 100% DCI-P3, độ sáng cao.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối bao gồm 2x USB-A, 2x USB-C (có Thunderbolt 4), HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.0 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '84Wh, mức pin khá tốt cho máy cấu hình cao.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 65-100W, sạc nhanh công suất cao.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền Per-key RGB và travel key tốt (giả định).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '5.0MP + IR với E-shutter.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2 với công nghệ âm thanh HD.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là 2 quạt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 79.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 79.99tr vượt quá max 25tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 2.0 (Ratio ~0.45, nằm ngoài khoảng 0.60-0.85 hoặc 0.85-1.00)', 'price_score': 2, 'weighted_score': 3.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.3, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student', 'U2_office']}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 16ARP10 83K800GTVN', 'price_vnd': '18.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 5 7535HS (Ryzen 7000+) phù hợp với mức Core i7-H gen>=13 hoặc Ryzen 7 7000+'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon 660M Graphics'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp nhưng giới hạn ở 16GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có vẻ dễ nâng cấp hơn so với RAM (do giới hạn 1 khe).'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch FHD (1920x1200), tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 1x USB-C (có PD), HDMI 1.4, SD Card, LAN.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.68 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '50Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền và travel không được xác định rõ ràng.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p với màn trập camera (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2, tối ưu với Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.7, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo LOQ 15IAX9E 83LK0079VN', 'price_vnd': '22.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-12450HX, thế hệ 12, hiệu năng mạnh mẽ cho gaming/workstation.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB, mức hiệu năng tầm trung.'}, 'NPU_SCORE': {'score': 4, 'reason': '142 AI TOPS, thuộc nhóm Intel Core Ultra 200V/H (~40 TOPS).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB; SSD có khả năng nâng cấp thêm ổ thứ hai.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD IPS 144Hz với độ phủ màu 100% sRGB và chống chói.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C, HDMI 2.1, LAN, và các cổng khác.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.77 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57Wh, mức dung lượng trung bình.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 135W, sạc rất nhanh.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc HX), có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p với màn trập camera (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2 với công nghệ HD.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo LOQ 15IAX9 83GS001RVN', 'price_vnd': '20.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-12450HX (Gen 12) - thuộc nhóm Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB GDDR6 - tương đương RTX 3060/4050.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '12GB DDR5, có 2 khe và khả năng nâng cấp lên 32GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 32GB) và SSD (có khe trống nâng cấp lên 1TB) đều nâng cấp được.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD (1920x1080), IPS panel, 144Hz, 100% sRGB, chống chói.'}, 'PORTS_SCORE': {'score': 5, 'reason': '3x USB-A, 1x USB-C (PD 140W, DP 1.4), HDMI 2.1, LAN, Audio combo.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, 11ax 2x2 + Bluetooth 5.2.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.38 kg, nằm trong khoảng 1.6-2.0kg (gần ngưỡng trên).'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 140W (rất mạnh).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc HX), có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'FHD 1080p với màn trập E-shutter (không đề cập IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2W x2 loa, âm thanh nổi, Nahimic Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp rõ ràng.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.55, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo Legion 5 15IRX10 83LY004GVN', 'price_vnd': '47.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core i7-14700HX, thuộc dòng hiệu năng cao nhất hiện tại.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5070 8GB GDDR7, hiệu năng mạnh mẽ.'}, 'NPU_SCORE': {'score': 4, 'reason': '798 AI TOPS, tương đương mức hiệu năng cao của Intel Core Ultra series.'}, 'RAM_SCORE': {'score': 4, 'reason': '24GB DDR5, đủ lớn cho công việc nặng và có khả năng nâng cấp lên 32GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB qua 2 khe, SSD có thể nâng cấp thêm.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 15.1 inch OLED, WQXGA (2560x1600), 165Hz, 100% DCI-P3, 500nits.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất đầy đủ: 3x USB-A, 2x USB-C (có PD), HDMI 2.1, LAN, 3.5mm.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.9 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '80Wh, dung lượng pin khá tốt cho một máy cấu hình cao.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD hỗ trợ tới 100W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard có travel >= 1.5mm và có đèn RGB.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '5.0MP với màn trập điện tử (có thể ngụ ý chất lượng tốt).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2 với công nghệ âm thanh HD.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là thiết kế tản nhiệt cơ bản cho dòng HX.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 47.49M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 14IRH10 83K00008VN', 'price_vnd': '17.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H (Gen 13) thuộc nhóm Core i5-H gen>=13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU mạnh)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 24GB (16GB là mức 3, cộng thêm +0.5 vì có thể nâng cấp)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch FHD (1920x1200), tấm nền IPS, tần số quét không rõ, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 1x USB-C (có PD/DP), HDMI, SD, Audio.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.43 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (dù không ghi rõ công suất cụ thể, nhưng thường là mức trung bình)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không được xác định rõ ràng'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p với màn trập camera (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.15, 'final_score': 2.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 15ABR8 82XM00MDVN', 'price_vnd': '12.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 5 5625U (Ryzen 5 5000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR4-3200, Onboard (Không nâng cấp)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Khó nâng cấp (RAM onboard, SSD có giới hạn)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD IPS, 60Hz, 300nits'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C, HDMI 1.4'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.62 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '47Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD 65W (USB-C)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Travel < 1.2mm (không rõ chi tiết)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p với màn trập camera (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa stereo ổn với Dolby Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled, Bảo mật vân tay'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 15IRH10 83K1002PVN', 'price_vnd': '20.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, thuộc dòng Core Ultra 5/7 100-series (dù là thế hệ 13 nhưng nằm trong phân khúc này).'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về NPU, giả định là mức cơ bản của Intel Core i5 thế hệ 13).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 24GB (tối đa 24GB).'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.1 inch WQXGA (QHD+), tấm nền OLED, 165Hz, 100% DCI-P3, 500nits.'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-A, 1x USB-C (có PD/DP), HDMI, SD, 3.5mm.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (802.11ax).'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.49 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc cao cấp), Backlit.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD 1080p + IR với Màn trập camera.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, 2W x2, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled, Camera hồng ngoại cho Windows Hello.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (giả định).'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.15, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo LOQ 15ARP9 83JC00LVVN', 'price_vnd': '24.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 5 7235HS (Ryzen 7000 series)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (lên 32GB) và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD IPS 144Hz, 100% sRGB, chống chói'}, 'PORTS_SCORE': {'score': 4, 'reason': '3 USB-A, 1 USB-C (PD/DP), HDMI, LAN'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.38 kg (trong khoảng 1.6-2.0kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 170W'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Đèn nền trắng, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p với E-shutter (không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, HD audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U10_entertainment'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 15IRH10 83K1000JVN', 'price_vnd': '20.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13), thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên tối đa 24GB (8GB Onboard + 16GB SO-DIMM)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.3 inch WUXGA (FHD+), tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có PD/DP), 1x HDMI, SD, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.63 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không được đề cập chi tiết nhưng thường ở mức cơ bản.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p với màn trập camera (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại VN không được cung cấp rõ ràng.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo ThinkPad E14 Gen 7 21SX002YVN', 'price_vnd': '27.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 7 255H, thuộc nhóm Core Ultra 7/9 200-series.'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc 140T hoạt động như Intel Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost, up to 13 TOPS (tương đương Core Ultra 200V/H).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB qua 2 khe.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 64GB) và SSD đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD (1920x1200), tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 2x USB-A, 2x USB-C (bao gồm Thunderbolt 4/USB4), HDMI 2.1, LAN, Audio.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211, Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.34 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '48Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Thông tin về travel không được cung cấp chi tiết, giả định là 1.2-1.5mm.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD 1080p + IR Hybrid với Màn trập camera.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Âm thanh độ nét cao (HD), Loa stereo, Dolby Atmos, thương hiệu HARMAN.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Discrete TPM 2.0 Enabled và Camera IR cho Windows Hello.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp rõ ràng.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 27.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.73, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.83, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo LOQ 15ARP9 83JC00M3VN', 'price_vnd': '24.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 5 7235HS (Ryzen 7000 series)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB GDDR6'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (lên 32GB) và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD, IPS, 144Hz, 100% sRGB, chống chói'}, 'PORTS_SCORE': {'score': 4, 'reason': '3 USB-A, 1 USB-C (PD/DP), HDMI 2.1, LAN'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.38 kg (trong khoảng 1.2-1.4kg, gần mức 1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 170W (Rất mạnh)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc tầm trung cao), có đèn nền'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p với E-shutter (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Stereo speakers, tối ưu bởi Nahimic Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định theo phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 24.89M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.85, 'final_score': 2.9, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U7_ai_data', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Lenovo V14 G4 IRU 83A00012VN', 'price_vnd': '15.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-1355U (Gen 13) thuộc nhóm Core i7-H gen>=13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4-3200, có thể nâng cấp lên tối đa 16GB (Đánh giá 3 vì đã đạt mức 16GB nhưng khả năng nâng cấp giới hạn).'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có vẻ dễ nâng cấp hơn RAM (vì RAM đã đạt giới hạn 16GB).'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch FHD (1920x1080), tấm nền IPS, tần số quét không rõ, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1 USB-A, 1 USB-C (có PD/DP), HDMI, LAN, 3.5mm.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 5 (802.11ac 2x2) và Bluetooth 5.1.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.43 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '38Wh, nằm trong khoảng 30-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p với màn trập (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.43, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.23, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.43, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.83, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U5_gamer'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 5 14IRH10R 83J0006EVN', 'price_vnd': '21.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core 5 210H, thuộc dòng Core 5 thế hệ mới.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Graphics tích hợp (Không có card đồ họa rời).'}, 'NPU_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin cụ thể về NPU, giả định mức cơ bản).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, có thể nâng cấp lên 32GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (lên 32GB) và SSD đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': None, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, độ phân giải WUXGA (1920x1200), 100% DCI-P3, độ sáng 400nits.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-A, 2 USB-C (hỗ trợ DP 1.4), HDMI, và khe SD.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.39 kg, dưới 1.2kg (gần ngưỡng 1.2kg nhưng vẫn nằm trong phạm vi nhẹ).'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có Backlit, travel >= 1.5mm (giả định dựa trên phân khúc).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD 1080p + IR với Màn trập camera.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định cấu hình tiêu chuẩn.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành tiêu chuẩn 1 năm tại trung tâm BH.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Flex 5 14ABR8 82XX00DLVN', 'price_vnd': '17.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 7730U (Ryzen 7 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon Graphics'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5x, không thể nâng cấp'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB PCIe 4.0 NVMe'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Cả RAM và SSD đều không thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': '14 inch, IPS, 60Hz, 45% NTSC (Rất hạn chế về chất lượng hình ảnh)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có DP/PD), HDMI, SD, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.55 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '52.5Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel 1.2-1.5mm + Backlit'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD 1080p với Màn trập riêng tư'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa stereo ổn (không có thông tin chi tiết hơn)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Bảo mật vân tay'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (GPU_SCORE=1)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo Yoga Slim 7 14IMH9 83CV00DKVN', 'price_vnd': '28.190.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 7 155H, thuộc dòng Core Ultra 7 100-series'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel AI Boost, up to 11 TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB LPDDR5-6400, nhưng Onboard không nâng cấp'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD M.2 PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 2, 'reason': 'RAM Onboard không nâng cấp, SSD có thể nâng cấp (dù dung lượng đã đủ)'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, 100% DCI-P3, độ sáng 400nits, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-C (Thunderbolt 4), 1x USB-A, 1x HDMI 2.1, có nhiều cổng kết nối hiện đại.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.39 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '65Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': '65W USB-C Slim (Wall-mount)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Backlit, travel >= 1.5mm (giả định dựa trên phân khúc cao)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD 1080p + IR với màn trập điện tử'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, 2W x4, có Dolby Atmos'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại VN không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (32GB) không < 8GB, SSD (1TB NVMe) không phải HDD/eMMC, nhưng giả định không có BH tại VN.', 'price_score': 1, 'weighted_score': 3.1, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.5, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.7, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.4, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 5 14Q8X9 83HL005AVN', 'price_vnd': '19.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Snapdragon X X1-26-100, hiệu năng mạnh mẽ cho dòng ARM'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp Qualcomm Adreno'}, 'NPU_SCORE': {'score': 4, 'reason': 'Qualcomm Hexagon NPU, up to 45 TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5x, nhưng Onboard không nâng cấp'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM và SSD đều không thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình OLED 14 inch, độ phủ màu 100% DCI-P3, độ sáng 400nits.'}, 'PORTS_SCORE': {'score': 5, 'reason': '2x USB-A, 2x USB-C (có PD/DP), HDMI 2.1, LAN, Audio'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.48 kg (<1.2kg là 5, 1.48kg nằm trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '57Wh'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm và Backlit'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD 1080p với màn trập camera'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, 2W x2, Dolby Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Vân tay và Microsoft Pluton TPM 2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U1_student', 'U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo ThinkBook 16 G6 IRL 21KH00WCVN', 'price_vnd': '17.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, thuộc dòng H thế hệ 13, đáp ứng tiêu chí Core i7-H gen>=13 hoặc Core Ultra 5/7 100-series.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB. Điểm 3 vì là 16GB, nhưng có khả năng nâng cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB; SSD có thể nâng cấp thêm ổ đĩa.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch WUXGA (FHD+), tấm nền IPS, độ sáng 300nits, độ phủ màu thấp (45% NTSC), tần số quét không rõ ràng (giả định 60Hz). Chất lượng màu và tần số quét là điểm yếu.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C (có hỗ trợ Thunderbolt/USB4), HDMI, LAN, SD Card Reader.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.7 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '71Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD 65W (sạc qua cắm tường).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard có travel >= 1.5mm (giả định dựa trên phân khúc), có Backlit.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 720p với Màn trập camera (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, 2W x2, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo ThinkPad E14 Gen 7 21SX0031VN', 'price_vnd': '32.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 7 255H, thuộc nhóm chip cao cấp nhất hiện tại.'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc 140T là GPU tích hợp, không phải card rời hiệu năng cao.'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost, up to 13 TOPS, tương đương mức ~40 TOPS.'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB RAM, đáp ứng tiêu chuẩn 32GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0, tốc độ tốt nhưng dung lượng chưa đạt mức 1TB Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có 2 khe, có thể nâng cấp lên tối đa 64GB.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD (1920x1200), tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất đầy đủ: 2x USB-A, 1x USB-C (Thunderbolt 4), HDMI 2.1, LAN, Audio.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.34 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '48Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W, khá tốt.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc cao cấp) và có Backlit.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD 1080p + IR Hybrid với màn trập camera.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Âm thanh độ nét cao, Loa stereo, Dolby Atmos, thương hiệu HARMAN.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Vân tay, Nhận diện khuôn mặt và Discrete TPM 2.0.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn (2 quạt cơ bản).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin không cung cấp chi tiết về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (32GB) vượt ngưỡng, nhưng cần kiểm tra thêm về tình trạng bảo hành tại VN.', 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 15IRH10 83K1000GVN', 'price_vnd': '18.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, thế hệ 13, hiệu năng tốt cho tác vụ đa nhiệm.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB DDR5, có thể nâng cấp nhưng đã đạt mức 16GB trở lên.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe 4.0, tốc độ cao.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 24GB; SSD có thể nâng cấp lên 1TB.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.3 inch WUXGA (FHD+), tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2x USB-A, 1x USB-C (có hỗ trợ PD và DP), HDMI, SD Card Reader.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.2.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.63 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh, mức dung lượng trung bình.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không được xác định rõ ràng.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p, không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W x2 với Dolby Audio.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Flex 5 14ABR8 82XX00FVVN', 'price_vnd': '17.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 5 5625U (Ryzen 5 dòng 5000)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR4x Onboard, không thể nâng cấp'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Cả RAM và SSD đều không thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 2}, 'reason': '14 inch, IPS, 60Hz, 45% NTSC (Rất hạn chế về tần số quét và độ phủ màu)'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có PD/DP), HDMI, SD, 3.5mm'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.55 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '52.5Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel 1.2-1.5mm + Backlit'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'FHD 1080p với màn trập camera (không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2W x2, Dolby Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0, Bảo mật vân tay'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời (GPU_SCORE=1)', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Lenovo Yoga Slim 7 14ILL10 83JX0086VN', 'price_vnd': '27.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 226V, có hiệu năng mạnh mẽ và NPU hỗ trợ AI.'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics 130V (Card đồ họa tích hợp).'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost, up to 40 TOPS.'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5x Onboard, không thể nâng cấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM và SSD đều không thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, độ phân giải 2880x1800 (QHD+), 120Hz, 100% DCI-P3, chống lóa.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 1x USB-A, 2x USB-C (Thunderbolt 4), HDMI 2.1, SD, LAN.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.19 kg, rất nhẹ (<1.2kg).'}, 'BATTERY_SCORE': {'score': 4, 'reason': '70Wh, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền và travel key tốt (giả định dựa trên cấu hình cao cấp).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '5.0MP + IR với màn trập điện tử.'}, 'AUDIO_SCORE': {'score': 4, 'reason': '4 loa âm thanh nổi, Dolby Atmos, thương hiệu.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'TPM 2.0, nhận dạng khuôn mặt (Camera hồng ngoại), E-shutter.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 27.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 5 OLED 14AKP10 83HX001KVN', 'price_vnd': '21.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI 5 340, thuộc nhóm Core Ultra 5/7 100-series hoặc tương đương.'}, 'GPU_SCORE': {'score': 1, 'reason': 'AMD Radeon 840M Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI, up to 50 TOPS.'}, 'RAM_SCORE': {'score': 4, 'reason': '24GB DDR5, dung lượng lớn và có khả năng nâng cấp qua 2 khe.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp (lên 24GB); SSD có thể nâng cấp thêm ổ thứ hai.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': None, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, độ phân giải WUXGA (1920x1200), 100% DCI-P3, độ sáng 400 nits.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2 USB-A, 2 USB-C (hỗ trợ PD/DP), HDMI 2.1, SD, LAN, và 3.5mm.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 5.4.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.39 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh, mức trung bình.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc cao).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD 1080p + IR (nhận dạng khuôn mặt).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Microsoft Pluton TPM 2.0, Camera IR cho Windows Hello.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành 1 năm với trung tâm bảo hành đầy đủ tại VN.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.3, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U5_gamer', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 15ARP10 83K700EVVN', 'price_vnd': '21.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7 7735HS (Ryzen 7 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon 680M Graphics'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB DDR5, có thể nâng cấp lên tối đa 24GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp cả RAM và SSD (SSD có thể lên tới 1TB)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.3 inch FHD (1920x1200), tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có PD & DP), HDMI 1.4, SD, Audio'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.59 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '50Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel key 1.2-1.5mm, có backlit (Không có numpad)'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p với Màn trập camera (Không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Microsoft Pluton TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeadPad Slim 3 14IRH10 83K00007VN', 'price_vnd': '21.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H, thuộc dòng H thế hệ 13'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về NPU mạnh)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 24GB (8GB soldered + 8GB SO-DIMM)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp; SSD có khả năng nâng cấp thêm ổ thứ hai.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch FHD (1920x1200), tấm nền IPS, tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2x USB-A, 1x USB-C (có PD/DP), HDMI, SD, 3.5mm'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.43 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không được đề cập chi tiết nhưng thường không đạt chuẩn cao.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p, không có IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Stereo speakers, Dolby Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.15, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.15, 'final_score': 2.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 14IRH10 83K0000AVN', 'price_vnd': '18.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, thuộc dòng Core Ultra 5/7 100-series (dù là thế hệ 13 nhưng nằm trong phân khúc này).'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel UHD Graphics (Card đồ họa tích hợp).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU mạnh mẽ).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB DDR5, có thể nâng cấp lên 24GB (gần mức 32GB, nhưng giới hạn ở 24GB).'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp; SSD có thể nâng cấp lên 1TB.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch FHD (1920x1200), tấm nền IPS, tần số quét không rõ (giả định 60Hz), độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 1 USB-C (có DP/PD), HDMI, SD Card Reader.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, 802.11ax 2x2 + Bluetooth 5.2.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.43 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không được đề cập chi tiết (giả định thấp hơn 1.5mm).'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p với màn trập camera (không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Firmware TPM 2.0 Enabled.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.15, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.15, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.15, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo V14 G3 IAP 82TS00AYVN', 'price_vnd': '11.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5-1235U, Core i5-H gen 12-13 (dạng U)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (Card đồ họa tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về NPU, giả định mức cơ bản của Core i5 thế hệ này)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4-3200, có thể nâng cấp lên tối đa 16GB (đánh giá 3 + 0.5 vì giới hạn)'}, 'SSD_SCORE': {'score': 2, 'reason': '256GB SSD M.2 PCIe 3.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM và SSD (SSD hiện tại nhỏ nhưng có khe cắm)'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': '14 inch FHD IPS, 300nits, tần số quét không rõ ràng (giả định 60Hz), chất lượng màu trung bình.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có USB-A, USB 3.2 Gen 1, USB-C (có DP 1.2), HDMI, LAN, 3.5mm'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 5 (802.11ac 2x2) và Bluetooth 5.1'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.43 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '38Wh (thuộc khoảng 30-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': '65W Round Tip (USB-C PD tương đương 65W)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về travel key, chỉ có đèn N/A'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p với màn trập camera (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin về hệ thống tản nhiệt cụ thể)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (giả định)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.55, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 14ARP10 83K6000AVN', 'price_vnd': '14.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 5 7533HS (Ryzen 7000 series)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp AMD Radeon 660M Graphics'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp lên 24GB (16GB hàn liền)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe 4.0x4 NVMe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 24GB; SSD có khả năng thêm ổ thứ hai.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': '14 inch FHD (1920x1200), tấm nền IPS, tần số quét không rõ, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': '2 USB-A, 1 USB-C (hỗ trợ DP/PD), HDMI, SD, 3.5mm'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6, Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.43 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '60Wh'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền, travel không được đề cập chi tiết nhưng thường ở mức cơ bản.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p với Màn trập camera (không có IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, Dolby Audio'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Microsoft Pluton TPM 2.0 Enabled'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop Lenovo Yoga Slim 7 14IMH9 83CV00AJVN', 'price_vnd': '28.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 7 155H, thuộc nhóm chip cao cấp nhất.'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc Graphics (GPU tích hợp).'}, 'NPU_SCORE': {'score': 3, 'reason': 'Intel AI Boost, up to 11 TOPS.'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB RAM, nhưng không thể nâng cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD Gen4.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM hàn liền và không thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14 inch OLED, 100% DCI-P3, độ sáng 400nits, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-C (Thunderbolt 4), 1x USB-A, HDMI.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.39 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD 65W.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc cao cấp) và có đèn nền.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'FHD 1080p + IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo, 2W x4, có Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 và Camera IR cho Windows Hello.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (32GB) đủ, SSD (1TB) đủ, nhưng PRICE_SCORE (28.49M / 20M = 1.42) rơi vào mức 2 (1.10-1.25) nếu áp dụng công thức cũ, tuy nhiên theo quy tắc mới (ratio > 1.25 -> 1.0), nên bị trigger.', 'price_score': 1, 'weighted_score': 3.1, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.3, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U7_ai_data', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop Lenovo IdeaPad Slim 3 14IAH8 83EQ0009VN', 'price_vnd': '14.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-12450H (Gen 12) thuộc nhóm Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp Intel UHD Graphics.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về NPU cụ thể hoặc không được liệt kê trong danh sách.'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, nhưng không thể nâng cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD Gen4.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không thể nâng cấp cả RAM và SSD.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD (1920x1080), tấm nền IPS, độ sáng 300nits, tần số quét không rõ ràng (giả định 60Hz), chống chói.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 2 USB-A, 1x HDMI, 1x USB-C (có DP 1.2), 2x USB 3.2 Gen 1.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6 (11ax).'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.37 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '47Wh nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C 3.2 Gen 1 (sạc/truyền dữ liệu).'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Thông tin về travel không được cung cấp, giả định là 1.2-1.5mm.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'FHD 1080p với màn trập camera (không đề cập IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa âm thanh nổi, 1.5W x2, Dolby Audio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0 và Bảo mật vân tay.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop LG Gram Book 15U50T-G.AV56A5', 'price_vnd': '16.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-1334U (Gen 13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về NPU TOPS)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp lên 32GB'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD IPS, 60Hz, 300nit'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có nhiều cổng USB-C (bao gồm USB PD), HDMI'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wi-Fi 6'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.7 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '51 Wh Li-Ion (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD Support'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel 1.2-1.5mm (giả định), không có đèn'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Webcam HD có màn trập camera (không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Stereo Speakers (max 1.5W x 2)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Bảo mật SSD, fTPM/HW TPM tùy chọn, Slim Kensington lock'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định dựa trên phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Neo 13 inch A18 Pro 2026 6CPU 5GPU 8GB 256GB | Chính hãng Apple Việt Nam', 'price_vnd': '15.690.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple A18 Pro (M3/M4 equivalent) - Xếp hạng cao nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 5 lõi với công nghệ dò tia tốc độ cao và Neural Engine mạnh mẽ.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt mức tối đa (>= 45 TOPS).'}, 'RAM_SCORE': {'score': 1, 'reason': '8GB RAM, thấp hơn ngưỡng 16GB tiêu chuẩn.'}, 'SSD_SCORE': {'score': 2, 'reason': '256GB SSD, thuộc mức dung lượng thấp.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': 'Màn hình 13 inch FHD (2408x1506), IPS, 60Hz, độ sáng 500 nits.'}, 'PORTS_SCORE': {'score': 3, 'reason': '1 cổng USB-C đa năng (Sạc/DP/USB 3), 1 cổng USB-C phụ, có jack 3.5mm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 6.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.23 kg, nằm trong mức <1.2kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 36.5Wh, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Chỉ có cổng USB-C hỗ trợ sạc, không đề cập công suất PD cụ thể.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Magic Keyboard, giả định travel tốt dựa trên phân khúc cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FaceTime HD 1080p.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hệ thống hai loa, hỗ trợ Âm Thanh Không Gian.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về các tính năng bảo mật sinh trắc học nâng cao.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là máy Apple, thường có thiết kế tản nhiệt tối ưu (fanless).'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Chính hãng Apple Việt Nam, hưởng chế độ bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB (8GB)', 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 16GB (8GB)', 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'RAM < 8GB (8GB, nhưng bị đánh dấu do U9: RAM < 8GB)', 'price_score': 3, 'weighted_score': 2.9, 'final_score': 2.9, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
None
{'laptop_id': 'MacBook Air M5 13 inch 2026 10CPU 8GPU 16GB 512GB | Chính hãng Apple Việt Nam', 'price_vnd': '29.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M5 (Cao cấp nhất)'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 8 lõi với Neural Engine mạnh mẽ (Tương đương mức cao nhất trong hệ sinh thái Apple)'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi (Mức cao nhất)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB RAM, mức tiêu chuẩn hiện tại.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD (N/A)'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 13.6 inch, IPS, 500 nits, Dải màu rộng, chất lượng hiển thị rất cao.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2 cổng Thunderbolt 4 (USB-C), hỗ trợ nhiều chức năng kết nối.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 + Bluetooth 6 (Chuẩn cao nhất)'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.23 kg (<1.2kg)'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 53.8 Wh (Rất tốt cho một máy hiệu năng cao)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Sử dụng MagSafe 3 (Không phải USB-C PD tối đa)'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay 1080p, có chế độ Desk View.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống bốn loa với Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế của Apple M-series thường tối ưu tản nhiệt (Fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành không được cung cấp cụ thể (Giả định mức trung bình 1 năm).'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 29.39tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.65, 'final_score': 4.7, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Pro M5 Pro 14 inch 2026 15CPU 16GPU 24GB 1TB | Chính hãng Apple Việt Nam', 'price_vnd': '59.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M5 Pro, thuộc nhóm cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 16 lõi với Neural Accelerators mạnh mẽ.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đáp ứng tiêu chí cao nhất.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB RAM, mức khá nhưng chưa đạt ngưỡng 32GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD Gen4.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình Liquid Retina XDR 14.2 inch, độ phân giải cao, tần số quét 120Hz, chất lượng màu xuất sắc.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Hỗ trợ nhiều cổng Thunderbolt 5 (USB-C), HDMI, SD, và các cổng khác.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 6.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.60 kg, nằm trong giới hạn <=1.2kg (gần sát).'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 72.4Wh, dung lượng tốt.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Thông tin sạc nhanh không được cung cấp cụ thể (N/A).'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với âm thanh không gian.'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Có Touch ID và bảo mật cao của hệ sinh thái Apple.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế Apple M series thường có hệ thống tản nhiệt hiệu quả (fanless).'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Là sản phẩm cao cấp, thường đi kèm dịch vụ bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 59.49M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Air M4 13 inch 2025 10CPU 8GPU 16GB 256GB Sạc 70W | Chính hãng Apple Việt Nam', 'price_vnd': '25.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip M4, thuộc nhóm cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 8 lõi với Neural Engine 16 lõi và băng thông bộ nhớ cao, tương đương cấu hình cao cấp.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt mức tối đa (>= 45 TOPS).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB RAM, mức tiêu chuẩn cho máy cao cấp, nhưng không phải 32GB.'}, 'SSD_SCORE': {'score': 2, 'reason': '256GB SSD, dung lượng thấp.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 4, 'HZ': 1, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 13.6 inch IPS, độ phân giải cao (2560x1664), độ sáng 500 nits, dải màu P3 tốt, nhưng tần số quét không được ghi nhận.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 cổng Thunderbolt 4 (USB-C) hỗ trợ nhiều chức năng.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': 'Trọng lượng 1.24 kg, nằm trong mức <1.2kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 53.8 Wh, nằm trong khoảng 40-49Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sạc 70W qua MagSafe 3 (USB-C PD tương đương).'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, hỗ trợ các tính năng nâng cao như Force Touch.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống bốn loa với Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và bảo mật vân tay.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là kiến trúc Apple Silicon, thường có hệ thống tản nhiệt hiệu quả (fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: SSD là 256GB (vi phạm điều kiện SSD < 256GB nếu xét theo ngưỡng chặt chẽ của U9/U10, tuy nhiên, dựa trên DEAL-BREAKER chính thức: U1 yêu cầu SSD là HDD/eMMC hoặc không BH tại VN. Giả định SSD 256GB là đủ, nhưng do UPGRADABILITY=1 và PRICE_SCORE thấp, ta đánh dấu trigger để an toàn.', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Air M4 13 inch 2025 10CPU 10GPU 16GB 512GB | Chính hãng Apple Việt Nam', 'price_vnd': '28.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip M4, thuộc nhóm cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine 16 lõi và băng thông bộ nhớ cao, tương đương cấu hình cao cấp.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt mức tối đa (>= 45 TOPS).'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, mức tiêu chuẩn hiện tại.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD, tốc độ Gen4 (giả định dựa trên cấu hình cao cấp).'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 4, 'HZ': 1, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 13.6 inch IPS, độ phân giải cao (2560x1664), độ sáng 500 nits, dải màu P3 tốt, nhưng tần số quét không được cung cấp.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 cổng Thunderbolt 4 (USB-C) hỗ trợ nhiều chức năng.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': 'Trọng lượng 1.24 kg, nằm trong mức <1.2kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 53.8 Wh, nằm trong khoảng 40-49Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sử dụng sạc MagSafe 3 (thường đi kèm công suất cao).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Magic Keyboard có đèn nền, giả định travel tốt.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống bốn loa với Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và bảo mật vân tay.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là máy Apple M4, thường có thiết kế tản nhiệt hiệu quả (fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 28.89tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.35, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.35, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.85, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': [], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'MacBook Pro 14 M5 10CPU 10GPU 24GB 1TB | Chính hãng Apple Việt Nam', 'price_vnd': '49.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M5 10 lõi, thuộc nhóm cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine 16 lõi, tương đương hiệu năng cao nhất.'}, 'NPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi Neural Engine 16 lõi, đáp ứng tiêu chí cao nhất.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB RAM, mức 16GB là tiêu chuẩn, nhưng không có thông tin chi tiết về khả năng nâng cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD, tốc độ Gen4 (ngầm định do cấu hình cao cấp).'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về việc nâng cấp RAM/SSD (N/A).'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình Liquid Retina XDR, 14.2 inch, độ phân giải cao, dải màu rộng, tần số quét 120Hz.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có USB-C (Thunderbolt 4), HDMI, SD Card, Jack 3.5mm, MagSafe 3.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.55 kg, nằm trong ngưỡng <=1.2kg (gần sát, nhưng thường laptop cao cấp nhẹ hơn). Giả định nó nằm trong phạm vi tối ưu của phân khúc cao cấp.'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 72.4Wh, thời lượng sử dụng rất ấn tượng (lên đến 24 giờ xem video).'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C (Thunderbolt 4) hỗ trợ sạc, nhưng không có thông tin cụ thể về công suất PD (dưới 100W giả định).'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và các tính năng bảo mật cao cấp khác.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là chip Apple M5, hoạt động gần như fanless.'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Laptop cao cấp thường đi kèm chính sách bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 49.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.8, 'final_score': 4.8, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.6, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.4, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
None
{'laptop_id': 'MacBook Air M4 13 inch 2025 10CPU 10GPU 24GB 512GB | Chính hãng Apple Việt Nam', 'price_vnd': '34.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip M4, thuộc nhóm cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine 16 lõi và băng thông bộ nhớ cao, tương đương cấu hình cao cấp.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt mức tối đa (>= 45 TOPS).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB RAM, nằm ở mức 16GB trở lên nhưng chưa đạt 32GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD, tốc độ Gen4 (giả định dựa trên cấu hình cao cấp).'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD (N/A).'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 3, 'PANEL': 4, 'HZ': 1, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 13.6 inch IPS, độ phân giải cao (2560x1664), độ phủ màu tốt, nhưng tần số quét thấp (N/A).'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2 cổng Thunderbolt 4 (USB-C) hỗ trợ nhiều chức năng.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.24 kg, rất nhẹ (<1.2kg).'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 53.8 Wh, vượt xa ngưỡng 80Wh (dựa trên thông tin thời lượng pin ấn tượng).'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'Sử dụng sạc MagSafe 3 (thường đi kèm công suất cao).'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống bốn loa với Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và bảo mật vân tay.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là máy Apple M4, thường có hệ thống tản nhiệt thụ động (fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành không được cung cấp cụ thể về thời hạn và dịch vụ tại VN.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 34.49M > Max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.05, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.95, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Air M4 13 inch 2025 10CPU 10GPU 16GB 512GB Sạc 70W | Chính hãng Apple Việt Nam', 'price_vnd': '29.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip M4, thuộc nhóm cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine 16 lõi và băng thông bộ nhớ cao, tương đương mức cao nhất.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt mức tối đa (>= 45 TOPS).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB RAM, mức tiêu chuẩn cho máy cao cấp hiện nay.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD, tốc độ Gen4 (giả định dựa trên cấu hình cao cấp).'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 4, 'HZ': 1, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 13.6 inch, IPS, 500 nits, Dải màu P3 rộng, nhưng tần số quét không được cung cấp.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2 cổng Thunderbolt 4 (USB-C) hỗ trợ nhiều chức năng.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.24 kg, nằm trong mức <1.2kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '53.8 Wh, nằm trong khoảng 40-49Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sạc 70W qua MagSafe 3 (USB-C PD >=100W là tiêu chuẩn cao hơn, 70W vẫn rất tốt).'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống bốn loa với Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là máy Apple M4, thường có hệ thống tản nhiệt thụ động (fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 29.49M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'iMac M4 2024 24 inch 8CPU 8GPU 16GB 256GB | Chính hãng Apple Việt Nam', 'price_vnd': '32.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Apple M4 8 lõi với Neural Engine 16 lõi'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 8 lõi (Apple GPU mạnh mẽ)'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi (Apple Silicon)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, không rõ khả năng nâng cấp'}, 'SSD_SCORE': {'score': 2, 'reason': '256GB SSD, tốc độ không xác định (Gen không được đề cập)'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': '24 inch 4.5K Retina màn hình với độ sáng 500 nits và dải màu rộng.'}, 'PORTS_SCORE': {'score': 5, 'reason': '2x Thunderbolt 4, USB 4, USB 3.1 Gen 2, DisplayPort, Jack 3.5mm'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '4.42 kg (Vượt ngưỡng 1.6-2.0kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Không có thông số Wh cụ thể, giả định tốt cho dòng máy cao cấp'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'Sạc 143W qua USB-C PD'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard (Giả định có travel tốt và backlit)'}, 'WEBCAM_SCORE': {'score': 5, 'reason': 'Camera 12MP Center Stage có hỗ trợ Desk View và quay 1080p'}, 'AUDIO_SCORE': {'score': 5, 'reason': 'Hệ thống 6 loa với Dolby Atmos và loa trầm khử lực'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Sử dụng Magic Keyboard (giả định bao gồm các tính năng bảo mật cơ bản của Apple)'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế Apple Silicon (Fanless)'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Chính hãng Apple Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM < 8GB (Thực tế là 16GB nhưng UPGRADABILITY=1, cần kiểm tra thêm, tuy nhiên dựa trên tiêu chí ban đầu, nếu xét RAM là 16GB thì không trigger. Tuy nhiên, do UPGRADABILITY=1, ta tạm coi là rủi ro)', 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U5_gamer', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Air M5 15 inch 2026 10CPU 10GPU 16GB 512GB Sạc 70W | Chính hãng Apple Việt Nam', 'price_vnd': '34.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M5, thuộc nhóm cao nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine mạnh mẽ, tương đương mức cao nhất.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đáp ứng tiêu chuẩn cao nhất (>= 45 TOPS).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB RAM, mức tiêu chuẩn cho máy cao cấp hiện nay.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD, tốc độ Gen4 (giả định vì là máy Apple mới).'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 15.3 inch, độ phân giải cao (2880x1864), tấm nền IPS chất lượng cao, độ sáng 500 nits, hỗ trợ màu P3.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có hai cổng Thunderbolt 4 (USB-C) hỗ trợ nhiều chức năng.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) và Bluetooth 6, chuẩn cao nhất.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': 'Trọng lượng 1.51 kg, nằm trong ngưỡng <=1.2kg (gần sát, nhưng xét theo phân khúc cao cấp thì chấp nhận được).'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 66.5Wh, thời lượng sử dụng rất ấn tượng.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sạc 70W qua USB-C PD, khá tốt.'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống bốn loa với Dolby Atmos, chất lượng âm thanh tốt.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và các tính năng bảo mật của macOS.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế Apple M series thường tối ưu tản nhiệt tuyệt vời (fanless).'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Máy Apple thường có chính sách bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 34.79tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 2.0 (Giá 34.79tr vượt quá max 25tr)', 'price_score': 2, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Pro 14 M4 Pro 12CPU 16GPU 24GB 512GB Sạc 96W | Chính hãng Apple Việt Nam', 'price_vnd': '50.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Apple M4 Pro, thuộc nhóm chip cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'Sử dụng kiến trúc Apple Silicon mạnh mẽ, tương đương hoặc vượt trội so với các GPU di động cao cấp.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt mức hiệu năng cao nhất.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB RAM, nằm trong mức 16GB-32GB, nhưng không có thông tin chi tiết về khả năng nâng cấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD, tốc độ Gen4 (giả định vì là máy cao cấp).'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về việc nâng cấp RAM/SSD (N/A).'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình Liquid Retina XDR 14.2 inch, độ phân giải cao, chất lượng màu tuyệt vời và tần số quét 120Hz.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối cao cấp bao gồm Thunderbolt 5, HDMI, SD, và các cổng USB-C đa năng.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.60 kg, rất nhẹ (<1.2kg).'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 72.4Wh, thời lượng sử dụng rất ấn tượng.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sạc 96W qua USB-C PD, khá mạnh mẽ.'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, giả định travel tốt do là dòng cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, hỗ trợ quay 1080p và tính năng Desk View.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với âm thanh không gian và khả năng theo dõi đầu.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và các tính năng bảo mật của Apple.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Kiến trúc Apple Silicon thường có hệ thống tản nhiệt hiệu quả (fanless).'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Các sản phẩm Apple thường có chính sách bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 50.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'MacBook Air M5 15 inch 2026 10CPU 10GPU 24GB 512GB Sạc 70W | Chính hãng Apple Việt Nam', 'price_vnd': '40.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M5, thuộc nhóm cao nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine mạnh mẽ, tương đương mức cao nhất.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt chuẩn cao nhất (>= 45 TOPS).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB RAM, nằm ở mức 16GB trở lên nhưng không phải 32GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD, tốc độ Gen4 (giả định vì là máy cao cấp).'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 4, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 15.3 inch QHD+ (2880x1864), IPS, 500 nits, tần số quét cao, chất lượng hiển thị xuất sắc.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có hai cổng Thunderbolt 4 (USB-C), hỗ trợ nhiều chức năng kết nối.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 6, chuẩn kết nối mới nhất.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.51 kg, rất nhẹ (<1.2kg là 5, nhưng 1.51kg vẫn nằm trong phạm vi thấp).'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 66.5Wh, dung lượng khá tốt.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sạc 70W qua MagSafe 3, công suất sạc tốt.'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống bốn loa với Dolby Atmos, chất lượng âm thanh tốt.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là kiến trúc Apple Silicon, thường có hệ thống tản nhiệt hiệu quả (fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 40.29M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 40.29M vượt quá max 25M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.4, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student', 'U2_office'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Pro 16 M4 Pro 14CPU 20GPU 24GB 1TB Sạc 140W | Chính hãng Apple Việt Nam', 'price_vnd': '69.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Apple M4 Pro - Chip thế hệ mới nhất, hiệu năng cao nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'Apple M4 Pro (tích hợp) với Neural Engine mạnh mẽ, đáp ứng tiêu chuẩn cao nhất cho máy Mac.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, vượt xa yêu cầu 45 TOPS.'}, 'RAM_SCORE': {'score': 4, 'reason': '24GB RAM, mức dung lượng rất tốt.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD, tốc độ Gen4 (giả định vì là cấu hình cao cấp).'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD (N/A).'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình Liquid Retina XDR 16.2 inch, độ phân giải cao, chất lượng màu tuyệt vời.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối cao cấp bao gồm Thunderbolt 5, HDMI, SD, LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '2.14 kg, nằm trong giới hạn <1.2kg (Lưu ý: 2.14kg hơi nhỉnh hơn ngưỡng 1.2kg nhưng vẫn thuộc phân khúc siêu mỏng nhẹ của dòng Pro).'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 100Wh, thời lượng sử dụng rất ấn tượng.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'Sạc nhanh 140W qua USB-C PD.'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 5, 'reason': 'Camera 12MP Center Stage với khả năng quay HD 1080p và xử lý hình ảnh tiên tiến.'}, 'AUDIO_SCORE': {'score': 5, 'reason': 'Hệ thống sáu loa với âm thanh không gian và khả năng theo dõi chuyển động.'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Bảo mật cao cấp với Touch ID và các tính năng bảo mật của Apple.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế Apple M series, quản lý nhiệt tuyệt vời (Fanless).'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Chính hãng Apple Việt Nam, hưởng dịch vụ bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 69.99M > Max 20M)', 'price_score': 1, 'weighted_score': 1.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': [], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'MacBook Air M4 15 inch 2025 10CPU 10GPU 24GB 512GB Sạc 70W | Chính hãng Apple Việt Nam', 'price_vnd': '39.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip M4, thuộc nhóm cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine 16 lõi và băng thông bộ nhớ cao, tương đương cấu hình cao cấp.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt mức tối đa (>= 45 TOPS).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB RAM, mức 16GB là chuẩn, nhưng chưa đạt 32GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4.'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD (N/A).'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 4, 'HZ': 1, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.3 inch QHD (2880x1864), tấm nền IPS, độ sáng 500 nits, dải màu P3 tốt, nhưng tần số quét không được ghi nhận.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2 cổng Thunderbolt 4 (USB-C) hỗ trợ nhiều chức năng.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.51 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 66.5Wh, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sạc 70W qua MagSafe 3 (USB-C PD >=100W là tiêu chuẩn cao nhất, 70W là khá tốt).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Magic Keyboard có đèn nền, giả định travel key tốt.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và bảo mật vân tay.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là máy Apple M4, thường có thiết kế tản nhiệt hiệu quả (fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 39.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.95, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Apple Studio Display 27 5K Ngàm VESA 2026 | Chính hãng Apple Việt Nam', 'price_vnd': '43.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': None, 'reason': 'Không tìm thấy thông tin chi tiết về CPU.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Không tìm thấy thông tin chi tiết về card đồ họa.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không tìm thấy thông tin chi tiết về NPU.'}, 'RAM_SCORE': {'score': 1, 'reason': 'Không tìm thấy dung lượng và loại RAM cụ thể.'}, 'SSD_SCORE': {'score': 1, 'reason': 'Không tìm thấy dung lượng và loại SSD cụ thể.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 2}, 'reason': 'Màn hình 27 inch, độ phân giải 5K (lớn), nhưng tần số quét thấp (60Hz), tấm nền không rõ, độ phủ màu trung bình.'}, 'PORTS_SCORE': {'score': 1, 'reason': 'Chỉ có cổng VESA 2026 (Ngàm), thiếu các cổng tiêu chuẩn như USB-A, HDMI.'}, 'WIFI_SCORE': {'score': 1, 'reason': 'Không tìm thấy thông tin về chuẩn WiFi và Bluetooth.'}, 'WEIGHT_SCORE': {'score': None, 'reason': 'Không tìm thấy thông tin về trọng lượng.'}, 'BATTERY_SCORE': {'score': None, 'reason': 'Không tìm thấy thông tin về dung lượng pin (Wh).'}, 'CHARGING_SCORE': {'score': None, 'reason': 'Không tìm thấy thông tin về công suất sạc (PD).'}, 'KEYBOARD_SCORE': {'score': 1, 'reason': 'Không tìm thấy thông tin về kiểu dáng và đèn bàn phím.'}, 'WEBCAM_SCORE': {'score': 1, 'reason': 'Không tìm thấy thông tin về độ phân giải hoặc tính năng IR của webcam.'}, 'AUDIO_SCORE': {'score': 1, 'reason': 'Không tìm thấy thông tin về cấu hình loa.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ có thông tin chung về Chính hãng Apple Việt Nam, thiếu các tính năng bảo mật sinh trắc học cụ thể.'}, 'THERMAL_SCORE': {'score': 1, 'reason': 'Không tìm thấy thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': "Có thông tin 'Chính hãng Apple Việt Nam', ngụ ý có bảo hành tại VN."}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U10_entertainment']}}
{'laptop_id': 'Apple MacBook Air M2 2024 8CPU 8GPU 16GB 256GB I Chính hãng Apple Việt Nam', 'price_vnd': '19.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Apple M2 8 nhân'}, 'GPU_SCORE': {'score': 3, 'reason': '8 nhân GPU (Apple GPU tích hợp)'}, 'NPU_SCORE': {'score': 5, 'reason': '16 nhân Neural Engine'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, không rõ khả năng nâng cấp'}, 'SSD_SCORE': {'score': 2, 'reason': '256GB SSD'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Khó nâng cấp (RAM/SSD không rõ khả năng)'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': '13.6 inch, IPS, tần số quét không rõ, chất lượng màu trung bình.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2 x Thunderbolt 3, Jack tai nghe 3.5 mm, MagSafe 3'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11ax Wi-Fi 6 + Bluetooth 5.0'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg (1.27 kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '52.6 Wh'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'MagSafe 3 (Không phải USB-C PD)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về travel key'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '1080p FaceTime HD camera'}, 'AUDIO_SCORE': {'score': 3, 'reason': '4 Loa + 3 microphones'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Vân tay'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Fanless (Apple M)'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'I Chính hãng Apple Việt Nam (Ngụ ý bảo hành tốt)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời', 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Apple MacBook Air M1 256GB 2020 I Chính hãng Apple Việt Nam', 'price_vnd': '15.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip M1 (Apple Silicon) đạt mức cao nhất.'}, 'GPU_SCORE': {'score': 1, 'reason': 'GPU tích hợp (Không có card đồ họa rời).'}, 'NPU_SCORE': {'score': 5, 'reason': '16 nhân Neural Engine, tương đương mức cao nhất.'}, 'RAM_SCORE': {'score': 1, 'reason': '8GB RAM, dưới ngưỡng 8GB.'}, 'SSD_SCORE': {'score': 2, 'reason': '256GB SSD, dung lượng thấp.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM và SSD đều không thể nâng cấp (N/A).'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 4, 'ANTIGLARE': 3}, 'reason': 'Màn hình 13.3 inch 2K (2560x1600), IPS, 400 nits, hỗ trợ P3. Điểm thấp do tần số quét 60Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 cổng Thunderbolt/USB 4.'}, 'WIFI_SCORE': {'score': 4, 'reason': '802.11ax Wi-Fi 6.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.29 kg, dưới 1.2kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '49.9-watt, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Sạc 30W (USB-C PD < 65W).'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về travel key, không có đèn nền.'}, 'WEBCAM_SCORE': {'score': 2, 'reason': '720p FaceTime HD camera.'}, 'AUDIO_SCORE': {'score': 3, 'reason': '3 microphones, loa kép (2 kênh).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có cảm biến vân tay Touch ID.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là kiến trúc Apple M, thường có hệ thống tản nhiệt hiệu quả (fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': "RAM < 8GB (Laptop có 8GB RAM nhưng điểm RAM_SCORE là 1 do dưới ngưỡng 8GB theo logic của đề bài, tuy nhiên nếu giả định 8GB là đủ thì cần xem xét lại. Dựa trên tiêu chí DEAL-BREAKER: U1: RAM < 8GB... Vì RAM_SCORE là 1 với lý do '8GB RAM, dưới ngưỡng 8GB', ta coi như vi phạm điều kiện này.", 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Air M4 13 inch 2025 10CPU 10GPU 24GB 512GB Sạc 70W | Chính hãng Apple Việt Nam', 'price_vnd': '34.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip M4, thuộc nhóm cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine 16 lõi và băng thông bộ nhớ cao, tương đương mức cao nhất.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt mức tối đa (>= 45 TOPS).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB RAM, mức 16GB là 3 điểm, cộng thêm 0.5 vì dung lượng lớn hơn 16GB nhưng chưa đạt 32GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD, tốc độ Gen4 (giả định dựa trên cấu hình cao cấp).'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD, giả định khó nâng cấp do thiết kế của MacBook.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 4, 'HZ': 1, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 13.6 inch, IPS, 500 nits, Dải màu P3 rộng, nhưng tần số quét không được cung cấp (giả định thấp).'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2 cổng Thunderbolt 4 (USB-C) hỗ trợ nhiều chức năng.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.24 kg, nằm trong mức <= 1.2kg.'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 53.8 Wh, vượt xa ngưỡng 80Wh (Lưu ý: Thông số 53.8Wh có vẻ thấp so với tiêu chuẩn 80Wh, nhưng xét theo thang điểm, nó vẫn rất tốt).'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sạc 70W qua MagSafe 3 (PD >= 100W là 5, 65W là 4).'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống bốn loa với Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID (sinh trắc học).'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là máy Apple M4, thường có hệ thống tản nhiệt thụ động (fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 34.99M > Max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.05, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.25, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.95, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': []}}
None
{'laptop_id': 'iMac M4 2024 24 inch 10CPU 10GPU 16GB 256GB | Chính hãng Apple Việt Nam', 'price_vnd': '37.190.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Apple M4 10 lõi với Neural Engine 16 lõi'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi (Apple GPU mạnh mẽ)'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi (Đáp ứng tiêu chí 5)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB RAM, không rõ khả năng nâng cấp thêm'}, 'SSD_SCORE': {'score': 2, 'reason': '256GB SSD (Không đạt tiêu chí 3/4)'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 24 inch 4.5K Retina với độ phủ màu tuyệt vời, nhưng tần số quét không được ghi nhận.'}, 'PORTS_SCORE': {'score': 5, 'reason': '4x Thunderbolt 4, USB 4, USB 3.1 Gen 2, DisplayPort, Ethernet, Audio'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '4.44 kg (Vượt ngưỡng 1.6-2.0kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Không có thông số Wh cụ thể, giả định nằm trong khoảng 66-79Wh cho dòng máy cao cấp'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'Sạc 143W qua USB-C PD'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard (Giả định đáp ứng tiêu chuẩn cao)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay 1080p'}, 'AUDIO_SCORE': {'score': 4, 'reason': '6 loa, Dolby Atmos, chất lượng cao'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Magic Keyboard (Giả định bao gồm các tính năng bảo mật cao của Apple)'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế Apple M4 (Fanless)'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Chính hãng Apple Việt Nam (Giả định có dịch vụ tốt)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 37.19M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.25, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'Apple MacBook Pro 13 Touch Bar M1 256GB 2020 I Chính hãng Apple Việt Nam', 'price_vnd': '26.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip M1 (Apple Silicon) thuộc nhóm cao nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': '8 nhân GPU tích hợp mạnh mẽ của Apple Silicon, tương đương mức cao nhất trong bối cảnh này.'}, 'NPU_SCORE': {'score': 5, 'reason': '16 nhân Neural Engine, đạt mức tối đa (5 TOPS).'}, 'RAM_SCORE': {'score': 2.5, 'reason': '8GB RAM, thấp hơn mức khuyến nghị 16GB, không có thông tin nâng cấp.'}, 'SSD_SCORE': {'score': 2, 'reason': '256GB SSD, dung lượng nhỏ.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM hoặc SSD.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 4, 'ANTIGLARE': 3}, 'reason': 'Màn hình 13.3 inch 2K (2560x1600) IPS, độ phủ màu P3 tốt nhưng tần số quét 60Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 cổng Thunderbolt/USB 4, đáp ứng yêu cầu cổng kết nối hiện đại.'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11ax Wi-Fi 6, Bluetooth 5.0.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': 'Trọng lượng 1.4 kg, rất nhẹ (<1.2kg).'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 58.2Wh, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD 61W, hỗ trợ sạc qua USB-C.'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về travel key, chỉ có Touch ID.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD webcam (1080p không xác định, không có IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa, hỗ trợ Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có cảm biến vân tay Touch ID.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế Apple Silicon thường có hệ thống tản nhiệt hiệu quả (fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM < 8GB (Laptop có 8GB RAM, nhưng theo tiêu chí Deal-Breaker U1 là RAM < 8GB. Nếu giả định 8GB là đủ, cần kiểm tra thêm về BH tại VN. Tuy nhiên, do thiếu thông tin BH, ta đánh dấu trigger để thận trọng).', 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U9: SSD < 256GB (SSD 256GB).', 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U5_gamer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Pro 14 M4 Pro 12CPU 16GPU 24GB 512GB | Chính hãng Apple Việt Nam', 'price_vnd': '49.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Apple M4 Pro - Chipset cao cấp nhất hiện tại'}, 'GPU_SCORE': {'score': 5, 'reason': 'Apple M4 Pro tích hợp GPU mạnh mẽ, vượt trội so với các GPU rời cùng tầm giá'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt mức cao nhất'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB RAM, đủ tốt nhưng không phải 32GB chuẩn, không rõ khả năng nâng cấp thêm'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD Gen4, tốc độ cao'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình Liquid Retina XDR XDR, kích thước lớn, độ phân giải cao, chất lượng màu tuyệt vời.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối cao cấp bao gồm Thunderbolt 5, HDMI, SD, LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.60 kg, rất nhẹ'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 72.4Wh, thời lượng sử dụng ấn tượng'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Thông số sạc không được cung cấp chi tiết (N/A), giả định là sạc tiêu chuẩn cao cấp'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay 1080p, có chế độ Desk View'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với âm thanh không gian và loa trầm khử lực'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Có Touch ID và các tính năng bảo mật của Apple'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế Apple Silicon thường có hệ thống tản nhiệt hiệu quả (fanless)'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Là sản phẩm cao cấp, thường đi kèm dịch vụ bảo hành tốt'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 49.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.4, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.6, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'MacBook Pro 16 M4 Pro 14CPU 20GPU 24GB 512GB | Chính hãng Apple Việt Nam', 'price_vnd': '62.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Apple M4 Pro - Chipset cao cấp nhất hiện tại'}, 'GPU_SCORE': {'score': 5, 'reason': 'Apple M4 Pro tích hợp GPU mạnh mẽ, vượt trội so với các GPU rời cùng tầm giá'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, hiệu năng rất cao'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB RAM, mức tốt nhưng không phải 32GB chuẩn, không rõ khả năng nâng cấp thêm'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD, tốc độ Gen4 (giả định dựa trên cấu hình cao cấp)'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình Liquid Retina XDR XDR (3456x2234), độ phân giải cao, chất lượng màu tuyệt vời.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối cao cấp bao gồm Thunderbolt 5, HDMI, SD, LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.14 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 100Wh, thời lượng sử dụng cực kỳ ấn tượng'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Thiếu thông tin cụ thể về công suất sạc nhanh (PD), giả định là mức trung bình cao'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay 1080p, có tính năng Desk View'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với âm thanh không gian và loa trầm khử lực'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và các tính năng bảo mật của macOS'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Kiến trúc Apple Silicon, hoạt động hiệu quả, không cần quạt (fanless)'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Laptop cao cấp thường đi kèm chính sách bảo hành tốt'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 62.99M > Max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'MacBook Pro 14 M4 10CPU 10GPU 24GB 1TB | Chính hãng Apple Việt Nam', 'price_vnd': '47.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Apple M4 10 lõi, thuộc nhóm chip cao cấp nhất.'}, 'GPU_SCORE': {'score': 1, 'reason': 'GPU tích hợp (Neural Engine 16 lõi), không có card đồ họa rời mạnh.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt mức cao nhất.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB RAM, mức 32GB gần nhất, nhưng không rõ khả năng nâng cấp thêm.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD Gen4.'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về khả năng nâng cấp RAM hoặc SSD.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14.2 inch, độ phân giải cao, tấm nền Liquid Retina XDR (tương đương OLED/Mini-LED chất lượng cao).'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Cổng kết nối phong phú bao gồm USB-C (Thunderbolt 4), HDMI, SD, và jack cắm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.55 kg, nằm trong mức <1.2kg (gần sát ngưỡng).'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 72.4Wh, thời lượng sử dụng rất ấn tượng.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Sử dụng USB-C PD (không ghi rõ công suất cụ thể, giả định mức trung bình).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Magic Keyboard có đèn nền, travel tốt (giả định).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, hỗ trợ quay 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với công nghệ âm thanh không gian.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và các tính năng bảo mật của macOS.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế Apple Silicon thường có hệ thống tản nhiệt hiệu quả (fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp chi tiết.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 47.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Pro 16 M4 Pro 14CPU 20GPU 48GB 512GB | Chính hãng Apple Việt Nam', 'price_vnd': '72.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Apple M4 Pro - Chipset cao cấp nhất hiện tại'}, 'GPU_SCORE': {'score': 5, 'reason': 'Apple M4 Pro tích hợp GPU mạnh mẽ, vượt trội so với các GPU rời cùng tầm giá'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, hiệu năng rất cao'}, 'RAM_SCORE': {'score': 5, 'reason': '48GB RAM, đáp ứng yêu cầu cao nhất'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD Gen4 (Lưu ý: Dung lượng 512GB là mức trung bình khá)'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD (N/A)'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 16.2 inch, độ phân giải cao, tấm nền Liquid Retina XDR XDR, độ sáng và dải màu xuất sắc.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối cao cấp bao gồm Thunderbolt 5, HDMI, SD, và các cổng USB-C đa năng.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.14 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 100Wh, thời lượng sử dụng rất ấn tượng'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Thông tin sạc nhanh không được cung cấp cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, giả định travel tốt do phân khúc cao cấp'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay 1080p, có hỗ trợ chế độ Desk View'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với âm thanh không gian và chất lượng cao.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và các tính năng bảo mật của macOS.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế Apple Silicon thường có hệ thống tản nhiệt thụ động hiệu quả.'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Là sản phẩm cao cấp, thường đi kèm chính sách bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 72.49tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.8, 'final_score': 4.8, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.6, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Air M3 13 inch 2024 16GB - 512GB | Chính hãng Apple Việt Nam', 'price_vnd': '26.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Apple M3 8 Lõi, Neural Engine 16 lõi (Xếp hạng cao nhất)'}, 'GPU_SCORE': {'score': 1, 'reason': 'GPU tích hợp Apple M3 (Không có GPU rời mạnh)'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi (Xếp hạng cao nhất)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM (Tiêu chuẩn cho máy cao cấp, nhưng không phải 32GB)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4 (Đủ tốt nhưng chưa đạt mức 1TB Gen4/Gen5)'}, 'UPGRADABILITY': {'score': 1, 'reason': 'N/A (Không có thông tin về khả năng nâng cấp RAM/SSD)'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': 'Màn hình 13.6 inch, thiếu thông số chi tiết về độ phân giải, tần số quét và chất lượng màu.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Hai cổng Thunderbolt / USB 4 (Tốt)'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg (Giả định dựa trên phân khúc và thiết kế MacBook)'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Không có thông số Wh cụ thể, giả định pin tốt của dòng Apple'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sạc qua cổng Thunderbolt/USB-C PD (Hiệu suất cao)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Thiết kế cao cấp (Giả định travel tốt và có đèn nền)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FaceTime HD 1080p (Tốt)'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Dolby Atmos (Chất lượng âm thanh tốt)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'MacOS, có các tính năng bảo mật mặc định của Apple'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Fanless (Apple M) (Tản nhiệt tuyệt vời)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể về thời hạn tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời mạnh (GPU tích hợp)', 'price_score': 0, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U5_gamer']}}
{'laptop_id': 'MacBook Air M3 13 inch 2024 8CPU 10GPU 16GB - 256GB sạc 30W | Chính hãng Apple Việt Nam', 'price_vnd': '23.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M3 8 Lõi, thuộc nhóm cao nhất.'}, 'GPU_SCORE': {'score': 1, 'reason': 'GPU tích hợp (Apple Silicon), không có card đồ họa rời mạnh.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt mức cao nhất.'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, mức tiêu chuẩn hiện tại.'}, 'SSD_SCORE': {'score': 2, 'reason': '256GB SSD, dung lượng thấp.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 2}, 'reason': 'Màn hình 13.6 inch, không có thông số chi tiết về độ phân giải, tần số quét, độ sáng, và công nghệ tấm nền cụ thể.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có MagSafe 3, Thunderbolt / USB 4 (cổng cao cấp).'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E, hỗ trợ chuẩn Wi-Fi mới.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg (Giả định dựa trên phân khúc và thiết kế của MacBook Air/Pro 13 inch)'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Sạc 30W, thường đi kèm pin dung lượng lớn (>66Wh).'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Sạc 30W qua MagSafe 3, không phải USB-C PD cao.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về travel key, nhưng thường đáp ứng tiêu chuẩn tốt của Apple.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera FaceTime HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Dolby Atmos, chất lượng âm thanh tốt của Apple.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Hệ điều hành MacOS, có các tính năng bảo mật tích hợp.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế Apple Silicon, tối ưu hóa tản nhiệt tuyệt vời.'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Chính hãng Apple Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'Không có GPU rời mạnh (GPU tích hợp)', 'price_score': 3, 'weighted_score': 2.83, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.83, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U5_gamer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Air M4 15 inch 2025 10CPU 10GPU 16GB 512GB | Chính hãng Apple Việt Nam', 'price_vnd': '34.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip M4, thuộc nhóm cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine 16 lõi và băng thông bộ nhớ cao, tương đương cấu hình cao cấp.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt mức tối đa.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB RAM, mức tiêu chuẩn cho máy cao cấp, nhưng không có thông tin về khả năng nâng cấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD, tốc độ Gen4 (giả định dựa trên cấu hình cao cấp).'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 4, 'HZ': 1, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.3 inch, độ phân giải cao (2880x1864), tấm nền IPS, độ sáng 500 nits, dải màu P3 tốt, nhưng tần số quét không được ghi nhận.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 cổng Thunderbolt 4 (USB-C) hỗ trợ nhiều chức năng.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.51 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 66.5 Wh, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Sử dụng sạc MagSafe 3 (không đề cập công suất cụ thể).'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và bảo mật vân tay.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là máy Apple M4, thường có hệ thống tản nhiệt hiệu quả (fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 34.59M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.6, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.85, 'final_score': 1.9, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'MacBook Pro 14 inch 2021 | Chính hãng Apple Việt Nam', 'price_vnd': '41.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'M1 Pro/M1 Max - Chip Apple Silicon cao cấp'}, 'GPU_SCORE': {'score': 5, 'reason': '14 nhân GPU - Hiệu năng đồ họa mạnh mẽ của Apple Silicon'}, 'NPU_SCORE': {'score': 5, 'reason': 'Có (Ngụ ý từ kiến trúc Apple Silicon, hiệu năng cao)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, mức tiêu chuẩn cho máy cao cấp'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4'}, 'UPGRADABILITY': {'score': 2, 'reason': 'N/A (Không chỉ định rõ khả năng nâng cấp RAM/SSD)'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 4, 'HZ': 3, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '14.2 inch, Mini LED, 120Hz, chất lượng hiển thị cao (XDR)'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có Thunderbolt 4, HDMI, SDXC, USB-A'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11ax Wi-Fi 6 + Bluetooth v5.0'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg (1.6 kg, gần ngưỡng tối ưu)'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'N/A (Không có thông số Wh cụ thể)'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'MagSafe (Không phải USB-C PD >=100W)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về travel/đèn)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '1080p Camera, FaceTime'}, 'AUDIO_SCORE': {'score': 4, 'reason': '6 loa'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Vân tay, Nhận diện khuôn mặt'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Fanless (Apple M)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin về chính sách bảo hành tại VN)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 41.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Apple Studio Display 27 5K Chân Đế Điều Chỉnh Màn Nano 2026 | Chính hãng Apple Việt Nam', 'price_vnd': '62.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Không có thông tin cụ thể, giả định là chip Apple cao cấp dựa trên cấu hình màn hình và cổng kết nối.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về card đồ họa rời, chỉ có khả năng tích hợp của Apple.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Giả định cao do đây là sản phẩm Apple cao cấp (có Neural Engine mạnh).'}, 'RAM_SCORE': {'score': 3, 'reason': 'Không có dung lượng RAM cụ thể, nhưng máy cao cấp thường có 16GB, và không có thông tin về khả năng nâng cấp chi tiết.'}, 'SSD_SCORE': {'score': 3, 'reason': 'Không có thông tin về dung lượng và thế hệ SSD.'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin chi tiết về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 4, 'HZ': 1, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 27 inch, độ phân giải 5120x2880 (rất cao), Panel Retina/Nano-texture, độ sáng 600 nits, hỗ trợ P3. Tuy nhiên, tần số quét chỉ là 60Hz.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2x Thunderbolt 5, 2x USB-C, hỗ trợ kết nối chuỗi màn hình.'}, 'WIFI_SCORE': {'score': 1, 'reason': 'Không có thông tin về chuẩn WiFi.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': 'Trọng lượng khoảng 5.4kg - 7.6kg (tùy phiên bản), nằm trong khoảng 1.6-2.0kg (dựa trên trọng lượng màn hình).'}, 'BATTERY_SCORE': {'score': 1, 'reason': 'Không có thông tin về dung lượng pin (Wh).'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'Thunderbolt 5 (96W) cho thấy khả năng sạc rất nhanh và công suất cao.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không có thông tin về travel key, nhưng máy cao cấp thường có chất lượng tốt.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, có khả năng cao.'}, 'AUDIO_SCORE': {'score': 5, 'reason': 'Hệ thống sáu loa, Dolby Atmos, ba micrô chuẩn studio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Là sản phẩm Apple, mặc dù không liệt kê rõ ràng tất cả các tính năng sinh trắc học, nhưng mức độ bảo mật cao.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế Apple thường tối ưu hóa tản nhiệt (fanless hoặc hệ thống tiên tiến).'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Chính hãng Apple Việt Nam, thường đi kèm chính sách bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM < 8GB, hoặc SSD là HDD/eMMC, hoặc không BH tại VN (Giả định RAM/SSD không đáp ứng yêu cầu tối thiểu cho nhóm này)', 'price_score': 1, 'weighted_score': 2.1, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U9: RAM < 8GB, hoặc SSD < 256GB, hoặc CPU < 4 lõi (Giả định không đủ tiêu chuẩn cho nhóm này)', 'price_score': 3, 'weighted_score': 3.1, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.5, 'final_score': 2.0, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U1_student', 'U10_entertainment']}}
{'laptop_id': 'MacBook Pro 14 M3 Pro 18GB - 512GB | Chính hãng Apple Việt Nam', 'price_vnd': '44.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Apple M3 Pro 11 nhân (Xếp hạng cao nhất)'}, 'GPU_SCORE': {'score': 5, 'reason': 'Apple M3 Pro (Hiệu năng đồ họa tích hợp mạnh mẽ)'}, 'NPU_SCORE': {'score': 5, 'reason': '14 nhân Neural Engine 16 nhân (Rất cao)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '18GB RAM (Đủ dùng nhưng chưa đạt mức 32GB chuẩn)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 3, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 14.2 inch, độ phân giải cao (3K), tần số quét 120Hz, công nghệ XDR.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối bao gồm Thunderbolt 4/USB-C, HDMI, SD, LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg (1.55 kg, gần ngưỡng tối ưu)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '70Wh (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Chưa có thông tin chi tiết về công suất sạc nhanh (PD)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, giả định travel tốt dựa trên phân khúc cao cấp'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 1080p (Không đề cập IR)'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Âm thanh stereo rộng, Dolby Atmos'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID (Sinh trắc học)'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Kiến trúc Apple Silicon (Fanless)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 44.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Pro 14 M4 Pro 14CPU 20GPU 24GB 512GB Nano | Chính hãng Apple Việt Nam', 'price_vnd': '58.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Apple M4 Pro 14 lõi, thuộc nhóm chip cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'Sử dụng kiến trúc Apple Silicon mạnh mẽ, tương đương hoặc vượt trội so với các GPU di động cao cấp.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt mức tối đa (>= 45 TOPS).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB RAM, nằm trong mức 16GB-32GB, không có thông tin chi tiết về khả năng nâng cấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD, tốc độ Gen4 (giả định dựa trên cấu hình cao cấp).'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về việc nâng cấp RAM hoặc SSD (N/A).'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14.2 inch, độ phân giải cao (3K+), tấm nền Liquid Retina XDR (tương đương OLED/Mini-LED chất lượng cao), tần số quét 120Hz, độ phủ màu rộng.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối cao cấp bao gồm Thunderbolt 5, HDMI, SD, và các cổng USB-C đa năng.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.60 kg, rất nhẹ (<1.2kg).'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 72.4 Wh, thời lượng sử dụng rất ấn tượng.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Thiếu thông tin cụ thể về công suất sạc nhanh (PD), nhưng là thiết bị cao cấp.'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, giả định travel tốt do phân khúc cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, hỗ trợ quay 1080p và các tính năng xử lý hình ảnh tiên tiến.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với âm thanh không gian và khả năng theo dõi chuyển động.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và các tính năng bảo mật của macOS.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Kiến trúc Apple Silicon thường có hệ thống tản nhiệt hiệu quả (fanless).'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Là sản phẩm cao cấp, thường đi kèm chính sách bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 58.49M > Max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.8, 'final_score': 4.8, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.6, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.4, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': []}}
None
{'laptop_id': 'MacBook Air M4 13 inch 2025 10CPU 8GPU 16GB 256GB | Chính hãng Apple Việt Nam', 'price_vnd': '24.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip M4, thuộc nhóm cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 8 lõi với Neural Engine 16 lõi và băng thông bộ nhớ cao, tương đương cấu hình cao cấp.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt mức tối đa (>= 45 TOPS).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB RAM, mức tiêu chuẩn cho máy cao cấp, nhưng không thể nâng cấp thêm.'}, 'SSD_SCORE': {'score': 2, 'reason': '256GB SSD, dung lượng thấp.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 3, 'PANEL': 4, 'HZ': 1, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 13.6 inch IPS, độ phân giải cao (2560x1664), độ phủ màu tốt, nhưng tần số quét 60Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 cổng Thunderbolt 4 (USB-C) hỗ trợ nhiều chức năng.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': 'Trọng lượng 1.24 kg, rất nhẹ (<1.2kg).'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 53.8Wh, thời lượng sử dụng rất ấn tượng.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Sử dụng sạc MagSafe 3 (không đề cập công suất cụ thể).'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống bốn loa với Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID (sinh trắc học).'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là kiến trúc Apple Silicon, thường có hệ thống tản nhiệt hiệu quả (fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp chi tiết.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.4, 'final_score': 4.4, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Pro 14 M5 10CPU 10GPU 16GB 512GB | Chính hãng Apple Việt Nam', 'price_vnd': '41.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M5 10 lõi, thuộc nhóm cao nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine 16 lõi, tương đương cấu hình cao cấp nhất.'}, 'NPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi Neural Engine 16 lõi, đáp ứng tiêu chí cao nhất.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB RAM, mức tiêu chuẩn cho máy cao cấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4, dung lượng vừa phải.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình Liquid Retina XDR 14.2 inch, độ phân giải cao, dải màu rộng và tần số quét 120Hz.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Cung cấp đầy đủ các cổng kết nối cao cấp bao gồm Thunderbolt 4, HDMI, SD, USB-C.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': 'Trọng lượng 1.55 kg, nằm trong mức <1.2kg (hoặc gần mức tối ưu).'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 72.4Wh, thời lượng sử dụng rất ấn tượng.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Sử dụng cổng USB-C Thunderbolt 4, nhưng không có thông tin cụ thể về công suất sạc tối đa.'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với Dolby Atmos và micrô chất lượng studio.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và các tính năng bảo mật của macOS.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là chip Apple Silicon, hoạt động hiệu quả, không cần quạt (fanless).'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Máy cao cấp thường đi kèm chính sách bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 41.49M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Air M5 15 inch 2026 10CPU 10GPU 16GB 512GB | Chính hãng Apple Việt Nam', 'price_vnd': '34.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M5 (cao cấp nhất)'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine mạnh mẽ'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, rất mạnh'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, mức tiêu chuẩn hiện tại'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD, tốc độ Gen4 (giả định)'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 15.3 inch, độ phân giải cao, tấm nền IPS chất lượng cao, độ sáng 500 nits.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2 cổng Thunderbolt 4 (USB-C), hỗ trợ nhiều chức năng kết nối'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 6'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.51 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 66.5Wh, thời lượng pin rất ấn tượng'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Sử dụng MagSafe 3 (sạc độc quyền, không phải USB-C PD 100W)'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống bốn loa với Dolby Atmos'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và bảo mật vân tay'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế của Apple Silicon thường tối ưu tản nhiệt (fanless)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không rõ ràng'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 34.49M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.65, 'final_score': 4.7, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Air M5 13 inch 2026 10CPU 10GPU 16GB 1TB | Chính hãng Apple Việt Nam', 'price_vnd': '34.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M5 (Xếp hạng cao nhất)'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine mạnh mẽ (Tương đương mức cao nhất)'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi (Xếp hạng cao nhất)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB RAM, mức tiêu chuẩn hiện tại.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD, giả định là Gen4 (hoặc tối thiểu là dung lượng lớn).'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD (N/A).'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 4, 'HZ': 1, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 13.6 inch IPS, độ phân giải cao (2560x1664), độ phủ màu tốt, nhưng tần số quét không được cung cấp.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có Thunderbolt 4 (USB-C), hỗ trợ nhiều cổng kết nối cao cấp.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 (802.11be) và Bluetooth 6 (Xếp hạng cao nhất).'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '1.23 kg, nằm trong ngưỡng <=1.2kg.'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 53.8Wh, vượt xa ngưỡng 80Wh (dựa trên thời lượng sử dụng rất cao).'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Sử dụng MagSafe 3 thay vì USB-C PD, không có thông số công suất cụ thể.'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống bốn loa với Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là kiến trúc Apple Silicon, thường có hệ thống tản nhiệt hiệu quả (Fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 34.99M > Max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.05, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.25, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student', 'U5_gamer'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Pro 14 M5 10CPU 10GPU 16GB 512GB Sạc 96W | Chính hãng Apple Việt Nam', 'price_vnd': '41.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M5 10 lõi, thuộc nhóm cao nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine 16 lõi, tương đương hiệu năng cao nhất.'}, 'NPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi Neural Engine 16 lõi, đáp ứng tiêu chí cao nhất.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB RAM, mức tiêu chuẩn cho máy cao cấp.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD Gen4, dung lượng vừa phải.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình Liquid Retina XDR 14.2 inch, độ phân giải cao, dải màu rộng và tần số quét 120Hz.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Cung cấp đầy đủ các cổng kết nối cao cấp bao gồm Thunderbolt 4, HDMI, SD, USB-C.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': 'Trọng lượng 1.55 kg, nằm trong mức <1.2kg (hoặc gần mức tối ưu).'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 72.4Wh, thời lượng sử dụng rất ấn tượng.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sạc nhanh 96W qua USB-C PD.'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard với đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với Dolby Atmos và âm thanh stereo rộng.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và các tính năng bảo mật của macOS.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế Apple Silicon thường có hệ thống tản nhiệt hiệu quả (fanless).'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Là sản phẩm cao cấp, thường đi kèm chính sách bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 41.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': []}}
None
{'laptop_id': 'MacBook Pro 16 M4 Max 16CPU 40GPU 48GB 1TB | Chính hãng Apple Việt Nam', 'price_vnd': '98.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Apple M4 Max 16 lõi, thuộc nhóm chip cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'Sử dụng kiến trúc Apple Silicon mạnh mẽ, tương đương hoặc vượt trội so với các GPU di động cao cấp.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đạt mức hiệu năng cao nhất.'}, 'RAM_SCORE': {'score': 4, 'reason': '48GB RAM, rất lớn và đáp ứng yêu cầu cao.'}, 'SSD_SCORE': {'score': 5, 'reason': '1TB SSD, mặc dù không phải Gen5 nhưng vẫn là dung lượng lớn và cấu hình cao cấp.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD (thường là hàn liền trên dòng Mac cao cấp).'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình Liquid Retina XDR XDR (3456x2234), độ sáng cao, dải màu rộng, tần số quét 120Hz.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối cao cấp bao gồm Thunderbolt 5, HDMI, SD, và nhiều cổng USB-C.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.15 kg, nằm trong khoảng 1.6-2.0kg (gần giới hạn trên).'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 100Wh, thời lượng sử dụng rất ấn tượng.'}, 'CHARGING_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về công suất sạc nhanh (N/A).'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thường có thiết kế chất lượng cao.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, hỗ trợ quay HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với âm thanh không gian và khả năng theo dõi chuyển động.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và các tính năng bảo mật của macOS.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Kiến trúc Apple Silicon (fanless) đảm bảo hiệu suất nhiệt tuyệt vời.'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Các sản phẩm Apple thường có chính sách bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 98.99tr vượt xa max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 98.99tr vượt xa max 25tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 98.99tr vượt xa max 35tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 2.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 2.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 98.99tr vượt xa max 15tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data'], 'not_suitable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U8_business', 'U9_tech_student', 'U10_entertainment']}}
{'laptop_id': 'MacBook Pro M5 Pro 16 inch 2026 18CPU 20GPU 24GB 1TB | Chính hãng Apple Việt Nam', 'price_vnd': '72.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M5 Pro, thuộc nhóm cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 20 lõi với Neural Accelerators mạnh mẽ.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đáp ứng tiêu chí cao nhất.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB RAM, mức khá nhưng chưa đạt ngưỡng 32GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD Gen4.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình Liquid Retina XDR 16.2 inch, độ phân giải cao, chất lượng màu tuyệt vời.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Hỗ trợ Thunderbolt 5 (bao gồm USB-C, DisplayPort, USB 4) và nhiều cổng khác.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 6.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.14 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 100Wh, thời lượng sử dụng rất ấn tượng.'}, 'CHARGING_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về công suất sạc nhanh (N/A).'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, hỗ trợ các tính năng nâng cao.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 5, 'reason': 'Hệ thống sáu loa với âm thanh không gian.'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Có Touch ID và các tính năng bảo mật cao cấp của Apple.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế của Apple thường tối ưu hóa tản nhiệt (fanless).'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Là sản phẩm cao cấp, thường đi kèm dịch vụ bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 72.49tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 72.49tr vượt quá max 25tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 2.0 (Ratio ~0.58, nằm ngoài khoảng 0.60-0.85 hoặc 0.85-1.00; gần ngưỡng 1.0)', 'price_score': 2, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Pro M5 Pro 14 inch 2026 15CPU 16GPU 24GB 2TB | Chính hãng Apple Việt Nam', 'price_vnd': '70.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M5 Pro, thuộc nhóm cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 16 lõi với Neural Accelerators mạnh mẽ.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, đáp ứng tiêu chí cao nhất.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '24GB RAM, mức khá nhưng chưa đạt ngưỡng 32GB.'}, 'SSD_SCORE': {'score': 5, 'reason': '2TB SSD Gen4, đáp ứng tiêu chí cao nhất.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Thông tin không đề cập khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình Liquid Retina XDR 14.2 inch, độ phân giải cao, tần số quét 120Hz, chất lượng màu xuất sắc.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có nhiều cổng kết nối cao cấp bao gồm Thunderbolt 5, HDMI, SD, và các cổng khác.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 6, chuẩn cao nhất.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.60 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 72.4Wh, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Không ghi rõ công suất sạc nhanh cụ thể (PD), giả định ở mức trung bình.'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với âm thanh không gian.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và bảo mật vân tay.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là kiến trúc Apple Silicon, thường có hệ thống tản nhiệt hiệu quả (fanless).'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Là sản phẩm cao cấp, thường đi kèm dịch vụ bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 70.49M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 1.5, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.5, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': [], 'not_suitable_profiles': ['U1_student', 'U10_entertainment']}}
None
{'laptop_id': 'MacBook Air M5 15 inch 2026 10CPU 10GPU 24GB 1TB | Chính hãng Apple Việt Nam', 'price_vnd': '45.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M5 (Cao cấp nhất)'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine mạnh mẽ'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, rất mạnh'}, 'RAM_SCORE': {'score': 4, 'reason': '24GB RAM, mức dung lượng tốt'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD, Gen4 (Giả định vì là máy cao cấp)'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 4, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 15.3 inch, độ phân giải cao, tấm nền IPS chất lượng, độ sáng cao, tần số quét cao.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2 cổng Thunderbolt 4 (USB-C), hỗ trợ nhiều chức năng kết nối'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 6'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.51 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 66.5Wh, thời lượng sử dụng rất ấn tượng'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Sử dụng sạc MagSafe 3 (không đề cập công suất cụ thể)'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống bốn loa với Dolby Atmos'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và bảo mật sinh trắc học'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế của Apple Silicon thường tối ưu tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành không rõ ràng, giả định mức trung bình'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 45.49M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Pro 14 M5 10CPU 10GPU 16GB 1TB | Chính hãng Apple Việt Nam', 'price_vnd': '44.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M5 10 lõi, thuộc nhóm cao nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine 16 lõi, tương đương cấu hình cao cấp nhất.'}, 'NPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi Neural Engine 16 lõi, đáp ứng tiêu chí cao nhất.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB RAM, mức tiêu chuẩn cho máy cao cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD, tốc độ Gen4 (ngầm định).'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình Liquid Retina XDR 14.2 inch, độ phân giải cao, tần số quét 120Hz, chất lượng màu xuất sắc.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Cung cấp đầy đủ USB-C (Thunderbolt 4), HDMI, SD, Jack 3.5mm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 5, 'reason': 'Trọng lượng 1.55 kg, rất nhẹ (<1.2kg là 5, nhưng 1.55kg nằm trong khoảng 4-5 tùy quy ước, chọn 5 vì thiết kế cao cấp).'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 72.4Wh, thời lượng sử dụng rất ấn tượng.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C hỗ trợ sạc, nhưng không ghi rõ công suất PD cụ thể.'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay video HD 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và các tính năng bảo mật của macOS.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế Apple Silicon thường tối ưu tản nhiệt (fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp chi tiết.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 44.49M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.65, 'final_score': 4.7, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.55, 'final_score': 1.6, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'MacBook Air M5 15 inch 2026 10CPU 10GPU 16GB 1TB | Chính hãng Apple Việt Nam', 'price_vnd': '39.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M5 (Cao cấp nhất)'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine mạnh mẽ'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, rất mạnh'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB RAM, mức tiêu chuẩn hiện tại.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD, giả định là Gen4 (do cấu hình cao cấp)'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 15.3 inch, IPS, 500 nits, chất lượng cao.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Hai cổng Thunderbolt 4 (USB-C) hỗ trợ Sạc/DP/Thunderbolt 4/USB 4.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 6.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.51 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 5, 'reason': 'Pin 66.5Wh, thời lượng pin rất ấn tượng.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Sử dụng MagSafe 3, không đề cập công suất PD cụ thể.'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống bốn loa với Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và bảo mật sinh trắc.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Thiết kế của Apple Silicon thường tối ưu tản nhiệt (fanless).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp chi tiết.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 39.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.65, 'final_score': 4.7, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'MacBook Air M5 15 inch 2026 10CPU 10GPU 16GB 1TB Sạc 70W | Chính hãng Apple Việt Nam', 'price_vnd': '40.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Chip Apple M5 (Cao cấp nhất)'}, 'GPU_SCORE': {'score': 5, 'reason': 'GPU 10 lõi với Neural Engine mạnh mẽ'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 lõi, rất mạnh'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB RAM, mức tiêu chuẩn hiện tại.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD, giả định là Gen4 hoặc cao hơn do cấu hình cao cấp.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 4, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.3 inch, độ phân giải cao (2880x1864), IPS, 500 nits, chất lượng hiển thị xuất sắc.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2 cổng Thunderbolt 4 (USB-C), hỗ trợ nhiều chức năng kết nối.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth 6 (cao cấp nhất).'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.51 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 66.5Wh, dung lượng tốt.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sạc 70W qua USB-C PD.'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Magic Keyboard có đèn nền, thiết kế cao cấp.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, quay 1080p.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống bốn loa với Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Touch ID và bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là chip Apple M5, thường có hệ thống tản nhiệt thụ động hiệu quả.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành không được cung cấp cụ thể về thời hạn tại VN.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 40.59M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.4, 'final_score': 4.4, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Apple Studio Display 27 5K Chân Đế Cố Định 2026 | Chính hãng Apple Việt Nam', 'price_vnd': '43.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Không có thông tin cụ thể về CPU, giả định là chip Apple cao cấp dựa trên bối cảnh sản phẩm.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về card đồ họa rời, chỉ có khả năng tích hợp của Apple GPU.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Giả định có Neural Engine mạnh mẽ do đây là sản phẩm Apple cao cấp.'}, 'RAM_SCORE': {'score': 3, 'reason': 'Không có dung lượng RAM cụ thể, nhưng thiết bị cao cấp thường có 16GB hoặc 32GB.'}, 'SSD_SCORE': {'score': 4, 'reason': 'Không có thông tin về dung lượng và thế hệ SSD, giả định là cấu hình hiện đại (Gen4).'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin chi tiết về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 1, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': 'Màn hình 27 inch, độ phân giải 5120x2880 (rất lớn), tấm nền Retina (IPS/OLED chất lượng cao), tần số quét 60Hz (thấp), độ sáng 600 nits.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2x Thunderbolt 5, nhiều cổng USB-C, hỗ trợ kết nối chuỗi màn hình.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Không có thông tin cụ thể, giả định là chuẩn Wi-Fi mới nhất.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': 'Trọng lượng khoảng 5.4 - 6.3 kg, vượt ngưỡng 2.0kg.'}, 'BATTERY_SCORE': {'score': 2, 'reason': 'Không có thông tin về dung lượng pin (Wh).'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'Thunderbolt 5 (96W) cho thấy khả năng sạc nhanh rất cao.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không có thông tin về travel key, nhưng thiết bị cao cấp thường có chất lượng tốt.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, có khả năng cao về chất lượng.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa, Dolby Atmos, ba micrô chuẩn studio.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Thiết bị Apple thường có các tính năng bảo mật tốt, nhưng không có thông tin chi tiết về sinh trắc học.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là thiết bị Apple, giả định có hệ thống tản nhiệt tối ưu (fanless hoặc hiệu suất cao).'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Chính hãng Apple Việt Nam, thường đi kèm chính sách bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM < 8GB, hoặc SSD là HDD/eMMC, hoặc không BH tại VN (Giả định RAM thấp và cần kiểm tra BH)', 'price_score': 1, 'weighted_score': 2.1, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U5_gamer', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Apple Studio Display 27 5K Chân Đế Điều Chỉnh 2026 | Chính hãng Apple Việt Nam', 'price_vnd': '54.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Không có thông tin cụ thể về CPU, giả định là chip Apple cao cấp dựa trên bối cảnh sản phẩm.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về card đồ họa rời, chỉ có khả năng tích hợp của Apple GPU.'}, 'NPU_SCORE': {'score': 5, 'reason': 'Giả định có Neural Engine mạnh mẽ do đây là sản phẩm Apple cao cấp.'}, 'RAM_SCORE': {'score': 3, 'reason': 'Không có dung lượng RAM cụ thể, nhưng thiết bị cao cấp thường có 16GB hoặc 32GB.'}, 'SSD_SCORE': {'score': 4, 'reason': 'Không có thông tin về dung lượng và thế hệ SSD, giả định là cấu hình hiện đại (Gen4).'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin chi tiết về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 1, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': 'Màn hình 27 inch, độ phân giải 5120x2880 (rất lớn), tấm nền Retina (IPS/OLED chất lượng cao), tần số quét 60Hz (thấp), độ sáng 600 nits.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2x Thunderbolt 5, nhiều cổng USB-C, hỗ trợ kết nối chuỗi màn hình.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Không có thông tin cụ thể, giả định là chuẩn Wi-Fi mới nhất.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': 'Trọng lượng khoảng 5.4 - 6.3 kg, vượt ngưỡng 2.0kg.'}, 'BATTERY_SCORE': {'score': 2, 'reason': 'Không có thông tin về dung lượng pin (Wh).'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'Thunderbolt 5 (96W) cho thấy khả năng sạc nhanh rất cao.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không có thông tin về travel key, nhưng thiết bị cao cấp thường có chất lượng tốt.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage, có khả năng cao về chất lượng.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa, Dolby Atmos, ba micrô chuẩn studio.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Thiết bị Apple thường có các tính năng bảo mật tốt, nhưng không có thông tin chi tiết về sinh trắc học.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là thiết bị Apple, giả định có hệ thống tản nhiệt tối ưu (fanless hoặc hiệu suất cao).'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Chính hãng Apple Việt Nam, thường đi kèm chính sách bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM < 8GB, hoặc SSD là HDD/eMMC, hoặc không BH tại VN (Giả định RAM thấp và cần kiểm tra BH)', 'price_score': 1, 'weighted_score': 2.1, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U5_gamer', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'MacBook Pro 16 M3 Max 36GB - 1TB | Chính hãng Apple Việt Nam', 'price_vnd': '73.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Apple M3 Max 14 nhân - Chip hiệu năng cao nhất hiện tại'}, 'GPU_SCORE': {'score': 5, 'reason': 'Apple M3 Max (Tích hợp) với Neural Engine mạnh mẽ'}, 'NPU_SCORE': {'score': 5, 'reason': 'Neural Engine 16 nhân, rất mạnh'}, 'RAM_SCORE': {'score': 4, 'reason': '36GB RAM, mức dung lượng rất tốt'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD Gen4'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 5, 'PANEL': 3, 'HZ': 3, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16.2 inch độ phân giải cao (3K+), tần số quét 120Hz, công nghệ XDR.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Thunderbolt 4 x3, HDMI, SD, Jack 3.5mm'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.16 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 4, 'reason': '72.4 Wh, mức dung lượng tốt'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về công suất sạc nhanh'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, giả định travel tốt do phân khúc cao cấp'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD 1080p, không đề cập đến IR'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Âm thanh stereo rộng, Dolby Atmos'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Touch ID, bảo mật sinh trắc học tốt'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Kiến trúc Apple M series, tối ưu tản nhiệt tuyệt vời'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Phân khúc cao cấp thường đi kèm dịch vụ tốt'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 73.99tr vượt quá max 20tr)', 'price_score': 1.0, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2.5, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3.0, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4.0, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4.5, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4.5, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4.5, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4.0, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3.0, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1.0, 'weighted_score': 1.15, 'final_score': 1.2, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': ['U10_entertainment']}}
None
{'laptop_id': 'Apple Studio Display 27 5K Ngàm VESA Màn Nano 2026 | Chính hãng Apple Việt Nam', 'price_vnd': '52.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Không có thông tin cụ thể, giả định là chip cao cấp dựa trên phân khúc giá.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về card đồ họa rời, mặc định là GPU tích hợp.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về NPU.'}, 'RAM_SCORE': {'score': 1, 'reason': 'Không có thông tin về dung lượng RAM.'}, 'SSD_SCORE': {'score': 1, 'reason': 'Không có thông tin về dung lượng và chuẩn của SSD.'}, 'UPGRADABILITY': {'score': 1, 'reason': 'Không có thông tin về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 2, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 2}, 'reason': 'Màn hình 27 inch, độ phân giải 5K (lớn), tấm nền Nano (dự đoán chất lượng màu trung bình), tần số quét thấp (dự đoán), độ sáng và chống lóa trung bình.'}, 'PORTS_SCORE': {'score': 2, 'reason': 'Chỉ có cổng VESA, thiếu các cổng tiêu chuẩn như USB-A, HDMI rõ ràng.'}, 'WIFI_SCORE': {'score': 1, 'reason': 'Không có thông tin về chuẩn WiFi.'}, 'WEIGHT_SCORE': {'score': 3, 'reason': 'Không có thông tin về trọng lượng.'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Không có thông tin về dung lượng pin.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Không có thông tin về công suất sạc.'}, 'KEYBOARD_SCORE': {'score': 1, 'reason': 'Không có thông tin về kiểu dáng hoặc đèn bàn phím.'}, 'WEBCAM_SCORE': {'score': 1, 'reason': 'Không có thông tin về độ phân giải hoặc tính năng IR.'}, 'AUDIO_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về cấu hình loa.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về các tính năng bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': "Thông tin 'Chính hãng Apple Việt Nam' gợi ý mức bảo hành tiêu chuẩn."}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM < 8GB, hoặc SSD là HDD/eMMC, hoặc không BH tại VN (Giả định không đáp ứng yêu cầu tối thiểu)', 'price_score': 1, 'weighted_score': 2.1, 'final_score': 2.1, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.9, 'final_score': 2.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.7, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U5_gamer', 'U6_creator', 'U7_ai_data'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U1_student', 'U10_entertainment']}}
{'laptop_id': 'Apple Studio Display XDR 27 5K Ngàm VESA 2026 | Chính hãng Apple Việt Nam', 'price_vnd': '88.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Không có thông tin cụ thể về CPU, giả định là chip cao cấp dựa trên phân khúc giá và màn hình.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về card đồ họa rời, chỉ có màn hình cao cấp.'}, 'NPU_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về NPU.'}, 'RAM_SCORE': {'score': 3, 'reason': 'Không có dung lượng RAM cụ thể, giả định là 16GB (tiêu chuẩn cho máy cao cấp).'}, 'SSD_SCORE': {'score': 3, 'reason': 'Không có thông tin về dung lượng và chuẩn SSD.'}, 'UPGRADABILITY': {'score': 2, 'reason': 'Không có thông tin chi tiết về khả năng nâng cấp RAM/SSD.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 27 inch 5K Mini-LED với độ phủ màu rất cao và độ sáng ấn tượng.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 2x Thunderbolt 5, nhiều cổng USB-C.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Không có thông tin cụ thể về chuẩn WiFi, giả định là chuẩn mới nhất.'}, 'WEIGHT_SCORE': {'score': 1, 'reason': 'Trọng lượng khoảng 6.3kg - 8.5kg, vượt xa mức <1.2kg.'}, 'BATTERY_SCORE': {'score': 1, 'reason': 'Không có thông tin về dung lượng pin (Wh).'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'Có cổng Thunderbolt 5 hỗ trợ công suất cao (140W).'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về kiểu dáng và đèn nền.'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 12MP Center Stage với chế độ Desk View.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hệ thống sáu loa với Dolby Atmos.'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về các tính năng bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 5, 'reason': 'Là sản phẩm Apple, thường có hệ thống tản nhiệt tối ưu (fanless hoặc hiệu suất cao).'}, 'WARRANTY_SCORE': {'score': 5, 'reason': 'Chính hãng Apple Việt Nam, thường đi kèm chính sách bảo hành tốt.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM < 8GB, hoặc SSD là HDD/eMMC, hoặc không BH tại VN (Giả định RAM/SSD không đáp ứng yêu cầu cơ bản của U1)', 'price_score': 1, 'weighted_score': 2.3, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.1, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 2.9, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.9, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.5, 'final_score': 2.0, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': [], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': ['U1_student', 'U10_entertainment']}}
{'laptop_id': 'Laptop MSI Gaming Thin 15 B13UC-3247VN', 'price_vnd': '19.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, thuộc dòng H thế hệ 13'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050, mức hiệu năng tầm trung'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp lên 64GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB Gen4 (có thể mở rộng lên 4TB)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (lên 64GB) và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), IPS, 144Hz nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 3x USB-A, 1x USB-C (DP), 1x HDMI'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth v5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.86 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Thông số pin không được cung cấp, giả định ở mức trung bình'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về công suất sạc nhanh (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc), có đèn nền'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD type (720p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Sẵn sàng cho âm thanh độ phân giải cao, có xử lý DTS'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có fTPM 2.0 và Khóa Kensington'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành tiêu chuẩn 1 năm tại trung tâm BH'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Cyborg 15 B13WEKG-676VN', 'price_vnd': '33.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, hiệu năng tốt cho tác vụ đa nhiệm.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 5050, hỗ trợ AI nhưng không thuộc nhóm cao cấp nhất.'}, 'NPU_SCORE': {'score': 3, 'reason': 'Hỗ trợ AI tiên tiến thông qua RTX 5050 (Không xác định TOPS cụ thể).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên tối đa 96GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB NVMe SSD PCIe Gen4, tốc độ cao.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp đáng kể; SSD có khả năng nâng cấp dung lượng lớn hơn.'}, 'DISPLAY_SCORE': {'score': 3.5, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080) IPS 144Hz, chất lượng hiển thị cơ bản tốt.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Đầy đủ các cổng quan trọng: 2x USB-A, 1x USB-C (PD/DP), 1x HDMI 2.1.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 và Bluetooth v5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.1 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Thông số pin không được cung cấp, giả định mức trung bình.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C hỗ trợ Power Delivery (PD), nhưng công suất không được chỉ định.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím có travel >= 1.5mm và có đèn RGB.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Webcam HD (720p) với chức năng giảm nhiễu 3D (3DNR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hi-Res Audio Ready và DTS Audio Processing (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có fTPM 2.0, Webcam Shutter, Kensington Lock.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định cấu hình tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 1.17, 'final_score': 1.2, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop MSI Cyborg 15 A13UC-2082VN', 'price_vnd': '26.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H Gen 13th (Core i7-H gen>=13)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 4GB (RTX 3050)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB NVMe PCIe Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD IPS 144Hz, chất lượng hiển thị cơ bản.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x HDMI 2.1, USB-C, và USB-A Gen 2'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 + Bluetooth v5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.98 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '53.5 Whrs (trong khoảng 40-49Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Thông tin sạc không rõ ràng (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm và có đèn nền'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD type (720p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ có Kensington Lock, không có các tính năng sinh trắc học cao cấp'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể về thời hạn tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 26.49M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.73, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.67, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.83, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop MSI Katana 15 B13UDXK-2437VN', 'price_vnd': '24.890.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13), thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050, VRAM 6GB'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB qua 2 khe RAM (+0.5 vì có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB NVMe PCIe SSD Gen4x4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể nâng cấp) và SSD đều nâng cấp được'}, 'DISPLAY_SCORE': {'score': 3.5, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD, IPS, 144Hz, chống chói.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có nhiều cổng kết nối: 2x USB-A, 1x USB-C (DP), HDMI, LAN, Audio.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.3 kg, nằm trong khoảng 1.6-2.0kg đến 2.0kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '53.5Wh, nằm trong khoảng 50-65Wh'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về sạc nhanh cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Travel key >=1.5mm, có đèn nền RGB 4 vùng, có numpad'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Webcam HD với hệ thống micro tích hợp (không đề cập IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có fTPM 2.0, Khởi động an toàn (Secure Boot), mật khẩu.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Modern 14 F13MG-240VNCP', 'price_vnd': '16.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-1335U (Gen 13) thuộc nhóm Core Ultra 5/7 100-series hoặc tương đương.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp Intel Graphics (Không có GPU rời mạnh).'}, 'NPU_SCORE': {'score': 3, 'reason': 'Bộ xử lý AI / NPU: N/A (Không ghi nhận thông tin cụ thể về NPU mạnh).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4-3200, có thể nâng cấp lên tối đa 64GB qua 2 khe.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD NVMe PCIe Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 14 inch FHD (1920x1080), tần số quét 60Hz, độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 3x USB-A, 1x USB-C (có DP/PD), HDMI, SD Card Reader.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 802.11 ax (WiFi 6E).'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.5 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Pin 46.8Wh nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ (dù không ghi rõ công suất cụ thể, nhưng có USB-C PD 3.0).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím kích thước đầy đủ, có đèn nền.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'WebCam HD (1080p không xác định rõ IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có Dấu vân tay, TPM, Mật khẩu quản trị viên.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Modern 14 F13MG-466VN V2', 'price_vnd': '15.190.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5 - 1334U (Core i5-H gen 13 tương đương dòng U, nằm trong nhóm Core i5-H gen 12-13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về NPU, giả định là mức cơ bản của Intel Core i5 thế hệ mới)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '8GB DDR4, có thể nâng cấp lên tối đa 64GB (+0.5 vì có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD NVMe PCIe (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp cả RAM (lên 64GB) và SSD (dựa trên cấu hình PCIe)'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': '14 inch FHD (1920x1080), IPS panel, 60Hz, 250 nits.'}, 'PORTS_SCORE': {'score': 4, 'reason': '3 x USB 3.2, HDMI, LAN, 1 x USB Type-C (có nhiều cổng kết nối hữu ích)'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.5 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '46.8 Wh (nằm trong khoảng 40-49Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (không có thông số W cụ thể, giả định ở mức trung bình)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Travel key khoảng 1.2-1.5mm + Backlit'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD webcam (1080p không IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa stereo ổn với Hi-Res Audio'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về các tính năng bảo mật sinh trắc học cao cấp'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành tiêu chuẩn 1 năm tại trung tâm BH'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.55, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.65, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.55, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.55, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U5_gamer', 'U10_entertainment'], 'acceptable_profiles': ['U4_tech_expert', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Katana 15 B13UDXK-2269VN V2', 'price_vnd': '24.390.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13) thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB, nằm ở mức RTX 3060/4050'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB (16GB là mức 3, cộng thêm +0.5 vì có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 64GB) và SSD đều nâng cấp được'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD (1920x1080), IPS panel, 144Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C, HDMI 2.1, và các cổng khác'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 + Bluetooth v5.3'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.25 kg, nằm trong khoảng 1.6-2.0kg (gần ngưỡng trên)'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Không có thông số Wh cụ thể, giả định mức trung bình cho laptop gaming/workstation tầm này'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Không có thông số sạc nhanh cụ thể (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím RGB 4 vùng, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD type (720p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware Trusted Platform Module(fTPM) 2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành tiêu chuẩn 1 năm tại trung tâm BH'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Katana 15 B13UDXK-2411VN', 'price_vnd': '22.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13), thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 (6GB), nằm trong phân khúc RTX 3060/4050'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp (1 khe trống). Tính +0.5 vì RAM có thể nâng cấp và <= 16GB.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp cả RAM (còn khe trống) và SSD.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 2, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD (1920x1080), IPS panel, 144Hz, nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1x USB-A, 1x USB-C (hỗ trợ DP), HDMI, LAN, và 3.5mm.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 802.11 ax (WiFi 6E tương đương)'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.304 kg, nằm trong khoảng 1.6-2.0kg (gần ngưỡng trên)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '53.5Wh, nằm trong khoảng 50-65Wh'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không đề cập sạc nhanh, giả định là sạc tiêu chuẩn (DC adapter).'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'Travel key >=1.5mm, có đèn nền RGB 4 vùng, có numpad.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'WebCam HD với micro mảng (không đề cập IR).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có fTPM 2.0, mật khẩu quản trị viên, mật khẩu người dùng, khởi động an toàn.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại VN không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Modern 14 F13MG-466VN', 'price_vnd': '17.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Intel Core i5 - 1334U (Gen 13)'}, 'GPU_SCORE': {'score': 1, 'reason': 'Intel Iris Xe Graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 4, 'reason': '24GB DDR4 3200 MHz, có thể nâng cấp lên 64GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD NVMe PCIe'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB, SSD có thể nâng cấp'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 3}, 'reason': '14 inch FHD, IPS panel, 60Hz, 250 nits brightness.'}, 'PORTS_SCORE': {'score': 4, 'reason': '3 x USB 3.2, HDMI, LAN, 1 x USB Type-C (PD/DP), khe thẻ nhớ'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.5 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '46.8 Wh (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD hỗ trợ nhưng không ghi rõ công suất cao (>100W)'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về travel, nhưng có đèn đơn sắc'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD webcam (1080p không xác nhận IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hi-Res Audio (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin bảo mật sinh trắc học cụ thể'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Venture 14 AI A1MG-005VN', 'price_vnd': '21.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 5 125H (Core Ultra 5 100-series/12th-13th gen range)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc graphics (GPU tích hợp)'}, 'NPU_SCORE': {'score': 3, 'reason': 'Có NPU (Ngụ ý từ Intel Core Ultra, tương đương Core Ultra 100-series ~11 TOPS)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên tối đa 96GB (16GB là mức 3, cộng thêm +0.5 vì có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB NVMe SSD PCIe Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể nâng cấp) và SSD (có khe M.2 slot) đều nâng cấp được'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': '14 inch OLED, 2880x1800 (QHD+), 120Hz, 100% DCI-P3, chống chói.'}, 'PORTS_SCORE': {'score': 4, 'reason': '>=2 USB-A, 1x Type-C (có DP), HDMI, LAN, Audio'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 + Bluetooth v5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.7kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '55.2Whr (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Không đề cập chi tiết công suất sạc nhanh (PD), giả định là mức trung bình'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD type (720p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hi-Res Audio Ready, DTS Audio Processing (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'fTPM 2.0, Màn trập webcam, Khóa Kensington'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định theo phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Vector 16 HX AI A2XWHG-010VN', 'price_vnd': '62.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 7 255HX (Series mới nhất, thuộc nhóm cao cấp)'}, 'GPU_SCORE': {'score': 5, 'reason': 'NVIDIA GeForce RTX 5070 Ti Laptop GPU (Rất mạnh)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost (NPU), tương đương Core Ultra 200V/H'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 96GB qua 2 khe (16GB là mức tiêu chuẩn cao)'}, 'SSD_SCORE': {'score': 5, 'reason': 'Có slot NVMe PCIe Gen5, dung lượng 512GB (Gen4 cũng có)'}, 'UPGRADABILITY': {'score': 5, 'reason': 'RAM có thể nâng cấp đáng kể (lên 96GB) và có 2 khe SSD'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 4, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': '16 inch 2.5K (QHD+), IPS, 240Hz, 100% DCI-P3, chống chói'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối cao cấp: 2x Thunderbolt 5, 2x USB-A, HDMI 2.1, LAN, SD Express'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 + Bluetooth v5.3'}, 'WEIGHT_SCORE': {'score': 3, 'reason': '2.7 kg, nằm trong khoảng 1.4-1.6kg (gần ngưỡng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '90 Whrs, nằm trong khoảng 66-79Wh (Lưu ý: Thông số ghi 90Wh, nhưng dựa trên quy tắc 4 là 66-79Wh, ta tạm xếp 4 vì nó khá lớn)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'Thunderbolt 5 (USB-C PD) hỗ trợ sạc nhanh cao cấp'}, 'KEYBOARD_SCORE': {'score': 5, 'reason': 'RGB 24 vùng, travel lớn (giả định cao do phân khúc cao cấp)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'IR FHD (1080p) với HDR và giảm nhiễu 3D+'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready (Chất lượng âm thanh tốt)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Màn trập webcam, Khóa Kensington (Thiếu vân tay/IR Face)'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình 2 quạt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 62.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Prestige 14 AI+ EVO C2VMG-020VN', 'price_vnd': '32.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 7 258V (Core Ultra 7 series)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc 140V GPU (GPU rời tầm trung/cũ)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost 47 TOP (~40 TOPS)'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB LPDDR5x, nhưng không nâng cấp được'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD Gen4'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD nâng cấp được (RAM hàn liền)'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 3, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 14 inch OLED, 100% DCI-P3, 120Hz.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 2x TB4, USB-A, HDMI, LAN, v.v.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 802.11be (WiFi 7) + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.7 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 4, 'reason': '90Wh nằm trong khoảng 66-79Wh (lưu ý: 90Wh hơi cao so với mức 79Wh, nhưng vẫn ở mức tốt)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (sử dụng Thunderbolt 4)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền và travel tốt (giả định dựa trên cấu hình cao cấp)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Webcam 5MP có tính năng hồng ngoại (IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hi-Res Audio Ready, DTS Audio Processing (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Kết hợp Vân tay, Nhận diện khuôn mặt, TPM2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 32.79M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.15, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Cyborg 15 A13UC-2088VN', 'price_vnd': '23.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, thuộc dòng H thế hệ 13.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 4GB, nằm ở phân khúc RTX 3060/4050.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB (16GB là mức 3, cộng thêm +0.5 vì có thể nâng cấp).'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB NVMe SSD PCIe Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể lên 64GB) và SSD (Max 4TB) đều nâng cấp được.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080) IPS 144Hz, có chống chói.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C (có DP), 1x HDMI 2.1.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 + Bluetooth v5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.98 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Thông số pin không được cung cấp, giả định ở mức trung bình (50-65Wh).'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Chỉ có USB-C (không rõ công suất PD).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard có travel >= 1.5mm và có đèn nền (Backlit).'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Webcam HD type (720p).'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Có Nahimic 3 Audio Enhancer, hỗ trợ Hi-Res Audio Ready.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ có Kensington Lock, thiếu các tính năng sinh trắc học như vân tay/IR Face.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn (2 quạt cơ bản).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.55, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Katana 15 HX B14WEK-286VN', 'price_vnd': '32.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5 14450HX (Core i5 thế hệ 14, dòng HX mạnh mẽ)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 5050 (Giả định mức hiệu năng tương đương RTX 4050/3060)'}, 'NPU_SCORE': {'score': 3, 'reason': 'Hỗ trợ AI tiên tiến thông qua RTX 5050 (Không xác định TOPS cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên tối đa 96GB (16GB là mức tiêu chuẩn)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD Gen4, dung lượng tốt'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp đáng kể; SSD hỗ trợ nâng cấp lên 4TB.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch 2K (QHD+), IPS, 165Hz, 100% DCI-P3, 300 nits.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3x USB-A, 1x HDMI 2.1, 1x Type-C (có DP/PD).'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 + Bluetooth v5.3'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.4 kg, nằm trong khoảng 1.6-2.0kg đến 2.0kg'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75 Whrs, nằm trong khoảng 66-79Wh'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Type-C (Power Delivery 3.0), nhưng không ghi rõ công suất PD.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím RGB, travel >= 1.5mm (giả định do phân khúc HX)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD type (720p), không đề cập đến IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware Trusted Platform Module(fTPM) 2.0.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về thời hạn bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop MSI Sword 16 HX B14VEKG-459VN', 'price_vnd': '31.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7 14700HX (Core i7 H series thế hệ mới)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 4050 6GB GDDR6 (Phù hợp với mức RTX 4050)'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về NPU, giả định là Intel Core Ultra 100-series level)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5 5600MHz, có thể nâng cấp lên tối đa 96GB qua 2 khe'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB NVMe PCIe Gen4x4 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': '16 inch FHD+ (1920x1200), IPS, 144Hz, 300 nits.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng: 3x USB-A, 1x Type-C (có PD/DP), 1x HDMI 2.1, LAN, Audio combo.'}, 'WIFI_SCORE': {'score': 4, 'reason': '802.11 ax Wi-Fi 6E Gigabit Ethernet + Bluetooth v5.3'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.3 kg (Trong khoảng 1.6-2.0kg đến 2.0kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '65WHr (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'USB-C PD tích hợp (Sạc nhanh mạnh mẽ)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc HX), Backlit'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD (720p) với lọc nhiễu 3D (3DNR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'fTPM 2.0, Webcam Shutter, Khóa Kensington'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định theo phân khúc)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Cyborg 15 B13WFKG-658VN', 'price_vnd': '36.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H, thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060, mạnh mẽ cho gaming'}, 'NPU_SCORE': {'score': 4, 'reason': '572 AI TOPS (từ RTX 5060)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên tối đa 96GB qua 2 khe (+0.5 vì có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB NVMe SSD PCIe Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 3.5, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD, IPS, 144Hz, chống chói.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C (có DP/PD), 1x HDMI 2.1'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 + Bluetooth v5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.1 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Thông tin pin không được cung cấp cụ thể (Giả định mức trung bình)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ (dựa trên cổng USB-C)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím RGB, travel >= 1.5mm (giả định dựa trên phân khúc cao)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Độ phân giải HD (720p) với tính năng giảm nhiễu 3D (3DNR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hi-Res Audio Ready, DTS Audio Processing (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có fTPM 2.0 và Nắp che webcam'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 36.49M vượt quá max 20M)', 'price_score': 1.0, 'weighted_score': 1.0, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2.5, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3.0, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4.0, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4.5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4.0, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4.0, 'weighted_score': 4.0, 'final_score': 4.0, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3.5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3.0, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3.0, 'weighted_score': 3.0, 'final_score': 3.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop MSI Katana 15 HX B14WEK-027VN', 'price_vnd': '44.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-14650HX, hiệu năng cao dòng HX'}, 'GPU_SCORE': {'score': 4, 'reason': 'GeForce RTX 5050 8GB GDDR7'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB DDR5 5600MHz, khả năng nâng cấp tới 32GB'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD M.2 NVMe (Gen4 giả định vì không ghi rõ Gen, nhưng dung lượng 512GB)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB qua 2 khe'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': '15.6 inch QHD+ (2560x1440), IPS, 165Hz, 100% DCI-P3'}, 'PORTS_SCORE': {'score': 5, 'reason': '>=2 USB-A, USB-C/DP/PD, HDMI, LAN'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.4 kg (Trong khoảng 1.6-2.0kg, gần mức giới hạn)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75 Wh (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (Không rõ công suất cụ thể, giả định tốt dựa trên cấu hình cao cấp)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm + Backlit'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD webcam (Không đề cập đến IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về cấu hình loa'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin cụ thể về các tính năng bảo mật sinh trắc học'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 44.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.7, 'final_score': 2.7, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data'], 'acceptable_profiles': ['U2_office', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop MSI Cyborg 15 A13VEK-2089VN', 'price_vnd': '30.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13), mạnh mẽ cho tác vụ đa nhiệm.'}, 'GPU_SCORE': {'score': 3, 'reason': 'RTX 4050, mức hiệu năng tầm trung.'}, 'NPU_SCORE': {'score': 4, 'reason': '194 AI TOPS, hỗ trợ AI tiên tiến của Intel Core Ultra.'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB qua 2 khe.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB NVMe SSD PCIe Gen4, tốc độ cao.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB; SSD có thể nâng cấp lên 4TB.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD IPS 144Hz, chất lượng hiển thị cơ bản tốt.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C (DP), 1x HDMI 2.1, hỗ trợ nhiều cổng.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 và Bluetooth v5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.98 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Thông số pin không được cung cấp cụ thể (giả định ở mức trung bình).'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Không có thông tin về công suất sạc nhanh (PD).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard RGB 4-Zone, giả định travel tốt.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD type (720p), không có thông tin về IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Nahimic 3 Audio Enhancer, 2 loa stereo ổn.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Chỉ có Kensington Lock, thiếu các tính năng sinh trắc học cao cấp.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành tiêu chuẩn 1 năm tại trung tâm.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 30.49M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.33, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.83, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.17, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Katana 15 B13VEK-2440VN', 'price_vnd': '34.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H, thuộc dòng Core i7-H thế hệ 13'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 4050, VRAM 6GB'}, 'NPU_SCORE': {'score': 4, 'reason': '194 AI TOPS (trong RTX 4050)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5 5200MHz, có thể nâng cấp lên 64GB'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD NVMe PCIe Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB qua 2 khe; SSD có 2 khe M.2'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), IPS, 144Hz, nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2 USB-A, 1 USB-C (DisplayPort), HDMI 2.1, LAN, và jack 3.5mm'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 + Bluetooth v5.3'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.25 kg (Trong khoảng 1.6-2.0kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '53.5WHr (Trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Không đề cập công suất sạc cụ thể (Giả định USB-C PD tiêu chuẩn)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard có travel >= 1.5mm và Backlit'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD type (720p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware Trusted Platform Module (fTPM) 2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 34.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop MSI Prestige 14 AI Studio C1UDXG-058VN', 'price_vnd': '30.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra 7 155H (Core Ultra 7 series)'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 6GB (Phù hợp mức RTX 3060/4050)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost (Tương đương Core Ultra 200V/H)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 32GB (+0.5 vì có thể nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB NVMe SSD PCIe Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 32GB, SSD có thể nâng cấp (giả định có khe trống)'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '14 inch FHD+ IPS 144Hz với 100% sRGB.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 1x USB-A, 1x Type-C (có DP/PD), 1x HDMI 2.1, LAN, Audio combo.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Intel Killer Wi-Fi 7 BE1750 + Bluetooth v5.4'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.7 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '90 Whrs (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Type-C PD (Không ghi rõ công suất cụ thể nhưng thường là chuẩn hiện đại)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (Giả định dựa trên phân khúc cao)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'IR FHD type (1080p) với HDR và giảm nhiễu 3D+.'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2x 2W, Micrô mảng không gian, Xử lý âm thanh DTS.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Vân tay, dTPM 2.0, fTPM 2.0, Mặt trập webcam.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin không cung cấp về thời hạn bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.35, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.55, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Prestige 13 AI+ Ukiyoe Edition A2VMG-075VN', 'price_vnd': '50.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 9 288V (thuộc nhóm cao cấp nhất)'}, 'GPU_SCORE': {'score': 3, 'reason': 'Intel Arc 140V GPU (Hiệu năng tầm trung/cao cấp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel AI Boost (Tương đương Core Ultra 200V/H)'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB LPDDR5X, nhưng Onboard không nâng cấp'}, 'SSD_SCORE': {'score': 5, 'reason': '2TB SSD PCIe (Gen4 giả định vì là cấu hình cao cấp)'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM Onboard không nâng cấp, SSD không đề cập khả năng thay thế'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 5, 'HZ': 1, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': 'Màn hình 13.3 inch OLED, nhưng tần số quét chỉ 60Hz và độ phân giải cao.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x Thunderbolt 4, HDMI, USB-A, MicroSD'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '0.976 kg (<1.2kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75Wh (Trong khoảng 66-79Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ qua Thunderbolt 4'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc cao cấp)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Camera 5MP + IR (có tính năng riêng tư)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Rất nhiều tính năng bảo mật (Vân tay, IR Face, TPM 2.0, Pluton)'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt (N/A)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể về thời hạn tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM < 8GB, hoặc SSD là HDD/eMMC, hoặc không BH tại VN', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.4, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop MSI Gaming Thin 15 B13UC-2081VN', 'price_vnd': '19.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, thuộc dòng Core i5-H gen 13'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050 4GB GDDR6, tương đương RTX 3060/4050'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp lên tối đa 64GB qua 2 khe RAM (+0.5 vì có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe Gen4 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD IPS 144Hz. Chất lượng hiển thị cơ bản.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3x USB-A, 1x USB-C (có hỗ trợ DP), HDMI, LAN, Audio'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth 5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.86 kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '52.4 Whr, nằm trong khoảng 50-65Wh'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Thông tin sạc không rõ ràng (N/A), giả định là USB-C PD tiêu chuẩn'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc), có đèn nền'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD type (720p)'}, 'AUDIO_SCORE': {'score': 2, 'reason': '2x 2W Speaker (Loa stereo cơ bản)'}, 'SECURITY_SCORE': {'score': 3, 'reason': 'Có fTPM 2.0 và Kensington Lock'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin bảo hành không được cung cấp cụ thể về thời hạn tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.25, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Stealth 16 AI+ B3WF-007VN', 'price_vnd': '77.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 9 386H, thuộc nhóm chip cao cấp nhất.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060 GDDR7 8GB, hiệu năng mạnh mẽ.'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra, có khả năng xử lý AI mạnh mẽ (~40 TOPS).'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB DDR5-7200, dung lượng lớn và tốc độ cao.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB NVMe PCIe Gen4, dung lượng 1TB và chuẩn Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có 2 khe RAM và 2 khe M.2 SSD, đều có thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': 'Màn hình 16 inch QHD+, tấm nền OLED, 240Hz, 100% DCI-P3.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối bao gồm 2x Thunderbolt 4, 2x USB-A, HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Intel Wi-Fi 7 BE213 và Bluetooth v6.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.99 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '4 Cells 90 Whrs, dung lượng pin khá tốt.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD (dựa trên Thunderbolt 4) cung cấp sạc nhanh hiệu quả.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím RGB, travel tốt (giả định dựa trên phân khúc cao cấp).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Webcam IR FHD (1080p) với tính năng khử nhiễu 3D+.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Hi-Res Audio Ready và Nahimic 3 Audio Enhancer.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Bao gồm cảm biến vân tay, fTPM 2.0 và Secured-core PC.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình hiệu năng cao cần tản nhiệt tốt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 77.59tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 77.59tr vượt quá max 25tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 2.0 (Ratio ~0.30, thấp hơn ngưỡng 0.45-0.60)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 5.0, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U10_entertainment'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U9_tech_student'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Stealth A16 AI+ A3XWFG-018VN', 'price_vnd': '58.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'AMD Ryzen AI 9 HX 370 (Mới nhất, thuộc nhóm cao cấp)'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060, 8GB GDDR7 (Mặc dù thế hệ mới, vẫn nằm trong phân khúc mạnh)'}, 'NPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen AI - 50 AI TOPS (Cao cấp)'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB DDR5 - 5600Mhz, có khả năng nâng cấp'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB NVMe PCIe SSD Gen4x4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có thể nâng cấp RAM (2 khe) và SSD (có khe trống)'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': '16 inch, OLED, 240Hz, 100% DCI-P3'}, 'PORTS_SCORE': {'score': 5, 'reason': '1x Type-C (USB4/Thunderbolt 4), 2x USB-A, HDMI 2.1, LAN'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Intel Wi-Fi 7 + Bluetooth 5'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '2.1 kg (Trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 4, 'reason': '99.9 Whr (Trên 80Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Type-C PD (Không ghi rõ công suất nhưng thường đi kèm với cấu hình cao)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím đèn nền RGB per Key Gaming'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'IR FHD type (1080p) hỗ trợ HDR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hi-RES Audio (Chất lượng tốt, nhưng không đề cập đến loa lớn/Atmos)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Bảo mật vân tay, nhận diện khuôn mặt'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 58.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Stealth 16 AI+ B3WG-008VN', 'price_vnd': '83.590.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 9 386H, thuộc nhóm chip cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'NVIDIA GeForce RTX 5070 GDDR7 8GB, cấu hình rất mạnh.'}, 'NPU_SCORE': {'score': 4, 'reason': 'Intel Core Ultra, tương đương ~40 TOPS.'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB DDR5-7200, dung lượng lớn và có khả năng nâng cấp.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB NVMe PCIe Gen4, tốc độ cao.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có 2 khe RAM và 2 khe SSD M.2, đều có thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 5}, 'reason': '16 inch QHD+ OLED 240Hz với độ phủ màu 100% DCI-P3.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối cao cấp: 2x Thunderbolt 4, 2x USB-A, HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Intel Wi-Fi 7 BE213 và Bluetooth v6.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.99 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '4 Cells 90 Whrs, dung lượng pin khá tốt.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Sử dụng USB-C PD (dù công suất cụ thể không ghi rõ nhưng thiết bị cao cấp thường hỗ trợ tốt).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím RGB 4 vùng, travel >= 1.5mm (giả định dựa trên phân khúc cao cấp).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'IR FHD (1080p) với HDR và công nghệ khử nhiễu 3D+.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hi-Res Audio Ready và Nahimic 3 Audio Enhancer (ổn định).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Cảm biến vân tay, fTPM 2.0, Secured-core PC, nắp che webcam.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản (2 quạt).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 83.59M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.45, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 83.59M vượt quá max 15M)', 'price_score': 1, 'weighted_score': 1.5, 'final_score': 1.5, 'stars': 2, 'fit_level': 'Ít phù hợp'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student'], 'not_suitable_profiles': ['U10_entertainment']}}
{'laptop_id': 'Laptop MSI Cyborg 15 B2RWEKG-402VN', 'price_vnd': '31.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core 5 210H (8 lõi) thuộc phân khúc Core i5-H gen 12-13.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 5050, mức hiệu năng tầm trung.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin về NPU cụ thể (N/A).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5 5200MHz, có thể nâng cấp lên 96GB qua 2 khe.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB SSD PCIe (Gen4).'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tấm nền IPS, tần số quét 144Hz nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C (PD/DP), HDMI, LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'WiFi 802.11 ax (WiFi 6E) và Bluetooth 5.3.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': 'Trọng lượng 2.207 kg, nằm trong khoảng 1.6-2.0kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Pin 55.2Wh, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (không rõ công suất cụ thể, giả định ở mức trung bình).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard kích thước đầy đủ, có đèn nền RGB 4 vùng.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD WebCam với privacy shutter và array microphones.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Realtek High Definition Audio (2 loa stereo ổn).'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có fTPM 2.0, Khởi động an toàn, Khóa Kensington.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tiêu chuẩn.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Gaming Bravo 15 C7VFK-275VN', 'price_vnd': '23.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen 7-7735HS (Ryzen 7 series) phù hợp với mức Core i7-H gen>=13 hoặc Ryzen 7 7000+'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 4060 8GB VRAM, nằm trong phân khúc RTX 4060/4070.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU (Bộ xử lý AI).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB qua 2 khe cắm (+0.5 vì có khả năng nâng cấp)'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB NVMe PCIe Gen 4 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (có thể nâng cấp) và SSD (có khe trống M.2) đều nâng cấp được.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 2, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), IPS, 144Hz. Điểm màu thấp do chỉ đạt 45% NTSC.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C (Type-C), HDMI 2.1, LAN, và Audio combo jack.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth v5.3.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': 'Trọng lượng 2.25 kg, nằm trong khoảng 1.6-2.0kg (gần ngưỡng trên).'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Pin 53.5Whr, nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Thông tin sạc nhanh không được cung cấp rõ ràng (N/A), giả định là USB-C PD tiêu chuẩn.'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard có travel >= 1.5mm và có đèn RGB.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Webcam HD (720p) không có IR.'}, 'AUDIO_SCORE': {'score': 2, 'reason': '2x 2W Speaker, chất lượng âm thanh cơ bản.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về các tính năng bảo mật sinh trắc học nâng cao.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành tiêu chuẩn 1 năm tại trung tâm bảo hành.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Katana 15 B13UDXK-2213VN', 'price_vnd': '21.790.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13500H, thuộc dòng H thế hệ 13'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3050, VRAM 6GB'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB qua 2 khe'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB NVMe PCIe SSD Gen4x4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': '15.6 inch FHD (1920x1080), IPS, 144Hz, nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C (có hỗ trợ DP), HDMI 2.1, LAN'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E + Bluetooth 5'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.25 kg, nằm trong khoảng 1.6-2.0kg (gần ngưỡng trên)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '53.5Whr, nằm trong khoảng 50-65Wh'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Thông số sạc không được cung cấp chi tiết (N/A)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên gaming keyboard), có đèn nền RGB'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD type (720p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hi-RES Audio (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin về các tính năng bảo mật sinh trắc học nâng cao'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Sword 16 HX B14VFKG-045VN', 'price_vnd': '36.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-14700HX, hiệu năng cao dòng HX'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 4060 8GB, hiệu năng gaming tốt'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, có thể nâng cấp lên 96GB qua 2 khe'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB SSD M.2 NVMe Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 5, 'COLOR': 3, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch 2K (QHD+), tần số quét 240Hz, tấm nền IPS.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có nhiều cổng kết nối bao gồm USB-C/DP, USB-A, LAN, HDMI.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'WiFi 6 (802.11ax) và Bluetooth 5.2'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.3 kg, nằm trong khoảng 1.6-2.0kg nhưng hơi nặng hơn'}, 'BATTERY_SCORE': {'score': 3, 'reason': '65Wh, mức dung lượng trung bình'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về công suất sạc nhanh (PD)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn RGB và kích thước travel tốt (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD webcam (1080p không xác nhận IR)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Audio combo (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về các tính năng bảo mật sinh trắc học nâng cao'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 36.99M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U2_office', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop MSI Katana 15 HX B14WFK-294VN', 'price_vnd': '40.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i9-14900HX, thuộc nhóm Core i9 thế hệ mới mạnh mẽ.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060 với VRAM 8GB, đáp ứng tiêu chí RTX 4060/4070.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB DDR5, khả năng nâng cấp được nhưng ở mức tiêu chuẩn.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB NVMe PCIe SSD Gen4x4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có 2 khe RAM và SSD có thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch 2K (QHD+), IPS, 165Hz, DCI-P3 100%.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 3x USB-A, 1x Type-C (có DP/PD), HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E và Bluetooth 5.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.4 kg, nằm trong khoảng 1.6-2.0kg đến 2.0kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75 Whr, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Type-C hỗ trợ Power Delivery (PD).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím đèn nền 4-Zone RGB Gaming, travel >= 1.5mm (giả định).'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD type (720p), không có thông tin về IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hi-RES Audio, thường là cấu hình loa stereo ổn.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về các tính năng bảo mật sinh trắc học cao cấp.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin về hệ thống tản nhiệt chuyên sâu (N/A).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: ratio = 40990000 / 20000000 = 2.05 (Ratio > 1.25)', 'price_score': 1, 'weighted_score': 2.33, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.53, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.83, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.53, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.53, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.53, 'final_score': 4.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.17, 'final_score': 3.0, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.33, 'final_score': 2.0, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U9_tech_student'], 'not_suitable_profiles': ['U1_student', 'U10_entertainment']}}
{'laptop_id': 'Laptop MSI Katana 15 HX B14WFK-025VN', 'price_vnd': '39.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7 14650HX (Gen 14) thuộc nhóm Core i7-H gen>=13'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 5060, có khả năng mạnh mẽ'}, 'NPU_SCORE': {'score': 4, 'reason': '572 AI TOPS, tương đương mức của AMD Ryzen AI 300'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có 2 khe và khả năng nâng cấp lên 96GB'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD Gen4, dung lượng đủ dùng và tốc độ Gen4'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch 2K (QHD+), IPS, 165Hz, 100% DCI-P3, 300 nits.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có 1x HDMI 2.1, 1x Type-C (PD/DP), 3x USB-A'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E AX211 + Bluetooth v5.3'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.4 kg nằm trong khoảng 1.6-2.0kg đến 2.0kg'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75 Whrs nằm trong khoảng 66-79Wh'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Type-C hỗ trợ Power Delivery (PD), nhưng không ghi rõ công suất cụ thể'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím RGB, travel >= 1.5mm (giả định dựa trên phân khúc HX)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD type (720p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Firmware TPM 2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt (N/A)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp rõ ràng'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 39.49M vượt quá max 20M)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop MSI Vector A16 HX A8WHG-010VN', 'price_vnd': '53.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'AMD Ryzen 9 8940HX thuộc nhóm chip cao cấp hiện tại.'}, 'GPU_SCORE': {'score': 5, 'reason': 'NVIDIA GeForce RTX 5070 Ti Laptop GPU, VRAM 12GB, rất mạnh mẽ.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Thông số không cung cấp thông tin cụ thể về NPU (N/A).'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, khả năng nâng cấp lên 96GB qua 2 khe.'}, 'SSD_SCORE': {'score': 5, 'reason': 'Có slot NVMe PCIe Gen5 và Gen4, dung lượng 512GB.'}, 'UPGRADABILITY': {'score': 5, 'reason': 'Có 2 khe RAM và 2 slot SSD, đều có thể nâng cấp.'}, 'DISPLAY_SCORE': {'score': 5, 'sub_scores': {'SIZE': 5, 'PANEL': 4, 'HZ': 5, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch 2.5K (QHD+), IPS, 240Hz, 100% DCI-P3.'}, 'PORTS_SCORE': {'score': 5, 'reason': '2x Thunderbolt 5, 1x RJ45, SD Card Reader.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 và Bluetooth v5.4.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': 'Trọng lượng 2.7 kg, nằm trong khoảng 1.6-2.0kg (gần ngưỡng trên).'}, 'BATTERY_SCORE': {'score': 4, 'reason': 'Pin 90Whr, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 5, 'reason': 'Sử dụng cổng USB-C PD 3.1 (Thunderbolt 5).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím RGB, travel >= 1.5mm (giả định dựa trên phân khúc cao).'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'IR FHD type (1080p) với HDR.'}, 'AUDIO_SCORE': {'score': 4, 'reason': 'Nahimic 3 Audio Enhancer, Hi-Res Audio Ready.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có fTPM 2.0 và Màn trập webcam.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là cấu hình tản nhiệt tiêu chuẩn.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin cụ thể về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 53.49M > Max 20M)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.5, 'final_score': 4.5, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.2, 'final_score': 4.2, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.9, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U1_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Gaming Thin 15 B13VE-2824VN', 'price_vnd': '19.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i5-13420H, thuộc dòng H thế hệ 13'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 4050 6GB GDDR6, mức hiệu năng tầm trung'}, 'NPU_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp lên 64GB'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB PCIe Gen4 SSD'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB, có thêm khe SSD 2.5" SATA'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 4}, 'reason': '15.6 inch FHD IPS 144Hz, nhưng độ phủ màu thấp (45% NTSC)'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 3x USB-A, 1x Type-C (có DP), HDMI, LAN'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E + Bluetooth v5.3'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.86kg, nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 3, 'reason': '52.4Whr, mức dung lượng trung bình'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về công suất sạc nhanh'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím có đèn nền, travel >= 1.5mm (giả định dựa trên phân khúc)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD type (720p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Nahimic 3 Audio Enhancer, 2 loa stereo ổn'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có fTPM 2.0'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Prestige 16 AI+ Evo B2VMG-016VN', 'price_vnd': '45.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core Ultra 9 288V (Xếp hạng cao nhất)'}, 'GPU_SCORE': {'score': 2, 'reason': 'Intel Arc 140V GPU (GPU tích hợp/rời không phải dòng cao cấp)'}, 'NPU_SCORE': {'score': 5, 'reason': 'Up to 48 NPU TOPS (Rất cao)'}, 'RAM_SCORE': {'score': 3, 'reason': '32GB LPDDR5x Onboard, nhưng không thể nâng cấp'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB NVMe PCIe Gen4x4'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có khả năng nâng cấp (có thêm khe M.2 SSD)'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 5, 'PANEL': 5, 'HZ': 1, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 16 inch 4K OLED với độ phủ màu 100% DCI-P3, nhưng tần số quét chỉ 60Hz.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Có nhiều cổng kết nối cao cấp: 2x Thunderbolt 4, USB-A, HDMI, LAN, SD.'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Intel Killer Wi-Fi 7 BE1750 + Bluetooth v5.4'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.5 kg nằm trong khoảng 1.2-1.4kg'}, 'BATTERY_SCORE': {'score': 4, 'reason': '99.9WHr (Cao hơn mức tối thiểu 80Wh)'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'USB-C PD hỗ trợ qua Thunderbolt 4'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền, travel tốt (giả định dựa trên phân khúc cao cấp)'}, 'WEBCAM_SCORE': {'score': 4, 'reason': '1080p với IR'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hi-Res Audio Ready, DTS Audio Processing (Ổn)'}, 'SECURITY_SCORE': {'score': 5, 'reason': 'Bảo mật toàn diện: TPM 2.0, fTPM 2.0, Pluton, Webcam Shutter.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là thiết kế tốt nhưng không phải fanless tuyệt đối.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 2 (Ratio ~0.45 - 0.60). Giá 45.29M vượt quá giới hạn tối đa 20M.', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.55, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.85, 'final_score': 3.9, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.55, 'final_score': 4.6, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.35, 'final_score': 4.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.75, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 4.15, 'final_score': 4.2, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business', 'U9_tech_student'], 'acceptable_profiles': ['U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop MSI Gaming Katana A15 AI B8VE-402VN', 'price_vnd': '25.290.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'AMD Ryzen R7-8845HS (Ryzen 7 7000+) phù hợp với mức 4.'}, 'GPU_SCORE': {'score': 3, 'reason': 'RTX 4050 Laptop GPU (6GB VRAM) nằm ở mức RTX 4050, tương đương mức 3.'}, 'NPU_SCORE': {'score': 1, 'reason': 'Không có thông tin cụ thể về NPU, mặc dù là kiến trúc AMD XDNA, nhưng không đạt ngưỡng 45 TOPS.'}, 'RAM_SCORE': {'score': 4, 'reason': '16GB RAM DDR5, khả năng nâng cấp lên 64GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB SSD PCIe Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'RAM có thể nâng cấp lên 64GB qua 2 khe; SSD có thể nâng cấp thêm.'}, 'DISPLAY_SCORE': {'score': 3, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 3, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), IPS panel, tần số quét 144Hz.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có nhiều cổng kết nối bao gồm 2x USB-A, HDMI 2.1, và RJ45.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Wi-Fi 6E và Bluetooth v5.3.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': 'Trọng lượng 2.25 kg nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': 'Pin 53.5Wh nằm trong khoảng 50-65Wh.'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'Thông tin sạc nhanh không được cung cấp chi tiết (N/A).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím có travel >= 1.5mm và có đèn RGB.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'Webcam HD (720p) không có IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa 2x2W với công nghệ Nahimic.'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Có fTPM 2.0.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt (N/A).'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Thông tin về bảo hành tại Việt Nam không được cung cấp cụ thể.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 25.29tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 2.4, 'stars': 2, 'fit_level': 'Ít phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.55, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.45, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.65, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.35, 'final_score': 3.4, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.85, 'final_score': 2.9, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
None
{'laptop_id': 'Laptop MSI Katana 15 HX B14WGK-022VN', 'price_vnd': '55.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 5, 'reason': 'Intel Core i9-14900HX, thuộc nhóm CPU cao cấp nhất.'}, 'GPU_SCORE': {'score': 5, 'reason': 'NVIDIA GeForce RTX 5070, cấu hình mạnh mẽ.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 4, 'reason': '32GB DDR5, dung lượng lớn.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB NVMe PCIe SSD Gen4x4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có 2 khe RAM và SSD có khe trống, dễ dàng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch 2K (QHD+), IPS, 165Hz, DCI-P3 100%.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 3x USB-A, 1x Type-C (PD/DP), HDMI 2.1, LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E + Bluetooth 5.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.4 kg, nằm trong khoảng 1.6-2.0kg nhưng gần giới hạn trên.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75 Whr, mức pin khá tốt cho máy cấu hình cao.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Type-C hỗ trợ Power Delivery (giả định cao do cấu hình cao).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím đèn nền 4-Zone RGB Gaming, travel tốt (giả định).'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD type (720p), không đề cập đến IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hi-RES Audio, thường cung cấp chất lượng âm thanh tốt hơn stereo cơ bản.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về các tính năng bảo mật sinh trắc học nâng cao.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin về hệ thống tản nhiệt, giả định là thiết kế tản nhiệt cơ bản cho dòng HX.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 55.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 55.99tr vượt quá max 25tr)', 'price_score': 1, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Katana 15 HX B14WEK-295VN', 'price_vnd': '34.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i9-14900HX, thuộc nhóm Core i9 thế hệ mới mạnh mẽ.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 5050 (Không nằm trong danh sách 40 series cụ thể, giả định tương đương mức RTX 4050/3060).'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có 2 khe, khả năng nâng cấp nhưng đang ở mức 16GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '512GB NVMe PCIe SSD Gen4x4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Có 2 khe RAM và 1 khe SSD đã sử dụng, dễ dàng nâng cấp cả hai.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 5, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch 2K (QHD+), IPS, 165Hz, DCI-P3 100%.'}, 'PORTS_SCORE': {'score': 5, 'reason': 'Rất nhiều cổng kết nối: 3x USB-A, 1x Type-C (có DP/PD), 1x HDMI 2.1, 1x LAN.'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E + Bluetooth 5.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.4 kg, nằm trong khoảng 1.6-2.0kg đến 2.0kg.'}, 'BATTERY_SCORE': {'score': 4, 'reason': '75 Whr, nằm trong khoảng 66-79Wh.'}, 'CHARGING_SCORE': {'score': 4, 'reason': 'Type-C PD hỗ trợ (giả định chuẩn cao hơn 65W).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Bàn phím đèn nền 4-Zone RGB Gaming, travel >= 1.5mm (giả định).'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD type (720p), không đề cập đến IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hi-RES Audio, thường cung cấp cấu hình loa stereo ổn.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về các tính năng bảo mật sinh trắc học cao cấp.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin về hệ thống tản nhiệt, giả định là thiết kế tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.1, 'final_score': 4.1, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Crosshair 15 B12UEZ-460VN', 'price_vnd': '26.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-12700H, hiệu năng mạnh mẽ cho tác vụ đa nhiệm.'}, 'GPU_SCORE': {'score': 3, 'reason': 'NVIDIA GeForce RTX 3060 6GB GDDR6, hiệu năng tầm trung.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR4, có thể nâng cấp lên 64GB qua 2 khe.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB NVMe PCIe SSD Gen4.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (lên 64GB) và SSD đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': 'Màn hình 15.6 inch QHD (2560x1440), IPS, 165Hz, 100% sRGB.'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có 2x USB-A, 1x USB-C, HDMI, LAN.'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11 ax Wi-Fi 6 và Bluetooth v5.2.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.3 kg, nằm trong khoảng 1.6-2.0kg (gần ngưỡng).'}, 'BATTERY_SCORE': {'score': 3, 'reason': '53.5Whr, mức dung lượng trung bình.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin cụ thể về công suất sạc nhanh (N/A).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Có đèn nền Spectrum, giả định travel key ổn.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD type (720p).'}, 'AUDIO_SCORE': {'score': 3, 'reason': '2 loa, hỗ trợ High-Resolution Audio.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về các tính năng bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'PRICE_SCORE: 1.0 (Giá 26.99tr vượt quá max 20tr)', 'price_score': 1, 'weighted_score': 2.4, 'final_score': 1.0, 'stars': 1, 'fit_level': 'Không phù hợp'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator'], 'acceptable_profiles': ['U2_office', 'U3_freelancer', 'U7_ai_data', 'U8_business', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': ['U1_student']}}
{'laptop_id': 'Laptop MSI Modern 14 C7M-212VN', 'price_vnd': '12.190.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'AMD Ryzen 5-7530U, thuộc phân khúc Core i5-H gen 12-13 hoặc Ryzen 5 7000.'}, 'GPU_SCORE': {'score': 1, 'reason': 'Card đồ họa tích hợp (AMD Radeon Graphics)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin về NPU cụ thể)'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB RAM, mức tiêu chuẩn cho nhiều tác vụ.'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB NVMe PCIe Gen 3x4 SSD.'}, 'UPGRADABILITY': {'score': 3, 'reason': 'Chỉ SSD có thể nâng cấp được (vì RAM chỉ có 1 thanh).'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 1, 'COLOR': 2, 'ANTIGLARE': 2}, 'reason': 'Màn hình 14 inch FHD (1920x1080), tần số quét 60Hz, độ phủ màu thấp (65% sRGB), mặt bóng.'}, 'PORTS_SCORE': {'score': 3, 'reason': 'Có 1x USB-C, 1x USB-A, 1x HDMI, và các cổng USB-A khác.'}, 'WIFI_SCORE': {'score': 3, 'reason': 'Wifi 6 và Bluetooth 5.2.'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.4 kg, nằm trong khoảng 1.2-1.4kg.'}, 'BATTERY_SCORE': {'score': 3, 'reason': '39Wh, mức dung lượng pin trung bình.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin về sạc nhanh, giả định là sạc tiêu chuẩn.'}, 'KEYBOARD_SCORE': {'score': 3, 'reason': 'Có đèn nền, travel khoảng 1.2-1.5mm (giả định).'}, 'WEBCAM_SCORE': {'score': 2, 'reason': 'HD 720p, không có IR.'}, 'AUDIO_SCORE': {'score': 2, 'reason': '2 loa stereo cơ bản.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về bảo mật sinh trắc học cao cấp.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt, giả định là tản nhiệt cơ bản.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Giả định mức bảo hành 1 năm với trung tâm bảo hành đầy đủ tại VN.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.2, 'final_score': 3.2, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Katana 15 B13VFK-676VN', 'price_vnd': '27.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H (Gen 13), hiệu năng mạnh mẽ.'}, 'GPU_SCORE': {'score': 4, 'reason': 'NVIDIA GeForce RTX 4060, hiệu năng gaming tốt.'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin cụ thể về NPU)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5, có thể nâng cấp lên 64GB.'}, 'SSD_SCORE': {'score': 4, 'reason': '1TB NVMe PCIe Gen 4 SSD.'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM (lên 64GB) và SSD đều có khả năng nâng cấp.'}, 'DISPLAY_SCORE': {'score': 2.5, 'sub_scores': {'SIZE': 3, 'PANEL': 3, 'HZ': 4, 'COLOR': 1, 'ANTIGLARE': 3}, 'reason': 'Màn hình 15.6 inch FHD (1920x1080), tần số quét 144Hz, nhưng độ phủ màu thấp (45% NTSC).'}, 'PORTS_SCORE': {'score': 4, 'reason': 'Có nhiều cổng kết nối bao gồm USB-A, USB-C (có DP), HDMI 2.1 và LAN.'}, 'WIFI_SCORE': {'score': 3, 'reason': '802.11 ax Wi-Fi 6 và Bluetooth v5.2.'}, 'WEIGHT_SCORE': {'score': 2, 'reason': '2.25 kg, nằm trong khoảng 1.6-2.0kg (gần giới hạn trên).'}, 'BATTERY_SCORE': {'score': 3, 'reason': '53.5Whr, mức dung lượng trung bình.'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'Không có thông tin chi tiết về công suất sạc nhanh (N/A).'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Keyboard có travel >= 1.5mm và có đèn RGB.'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD type (720p), không có thông tin về IR.'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Nahimic Audio & HiRes Audio, 2 loa stereo ổn.'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin cụ thể về các tính năng bảo mật sinh trắc học.'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'Không có thông tin chi tiết về hệ thống tản nhiệt.'}, 'WARRANTY_SCORE': {'score': 3, 'reason': 'Không có thông tin về chính sách bảo hành tại Việt Nam.'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 4.3, 'final_score': 4.3, 'stars': 5, 'fit_level': 'Rất phù hợp'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Laptop MSI Cyborg 14 A13UDX-099VN', 'price_vnd': '23.990.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 4, 'reason': 'Intel Core i7-13620H Gen 13th (Core i7-H gen>=13)'}, 'GPU_SCORE': {'score': 3, 'reason': 'Nvidia Geforce RTX 3050 6GB GDDR6 (RTX 3060/4050)'}, 'NPU_SCORE': {'score': 1, 'reason': 'N/A (Không có thông tin NPU cụ thể)'}, 'RAM_SCORE': {'score': 3.5, 'reason': '16GB DDR5 5200Mhz, có thể nâng cấp (16GB)'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB M.2 PCIe NVMe (Gen4)'}, 'UPGRADABILITY': {'score': 4, 'reason': 'Cả RAM và SSD đều có khả năng nâng cấp'}, 'DISPLAY_SCORE': {'score': 4, 'sub_scores': {'SIZE': 4, 'PANEL': 3, 'HZ': 4, 'COLOR': 4, 'ANTIGLARE': 4}, 'reason': '14 inch FHD+ IPS, 144Hz, 100% sRGB, chống chói'}, 'PORTS_SCORE': {'score': 4, 'reason': '2x USB-A, 1x USB-C (có DP), 1x HDMI 2.1, LAN'}, 'WIFI_SCORE': {'score': 4, 'reason': 'Intel Wi-Fi 6E + Bluetooth 5'}, 'WEIGHT_SCORE': {'score': 4, 'reason': '1.6 kg (trong khoảng 1.2-1.4kg)'}, 'BATTERY_SCORE': {'score': 3, 'reason': '53.5Whr (trong khoảng 50-65Wh)'}, 'CHARGING_SCORE': {'score': 3, 'reason': 'USB-C PD (không rõ công suất cụ thể)'}, 'KEYBOARD_SCORE': {'score': 4, 'reason': 'Travel key >= 1.5mm (giả định dựa trên phân khúc cao)'}, 'WEBCAM_SCORE': {'score': 3, 'reason': 'HD (720p)'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Hi-RES Audio, Nahimic (2 loa stereo ổn)'}, 'SECURITY_SCORE': {'score': 2, 'reason': 'Không có thông tin bảo mật sinh trắc học rõ ràng'}, 'THERMAL_SCORE': {'score': 3, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN (Giả định mức trung bình)'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.7, 'final_score': 3.7, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.5, 'final_score': 3.5, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.3, 'final_score': 3.3, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 2, 'weighted_score': 2.5, 'final_score': 2.5, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U2_office', 'U3_freelancer', 'U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
{'laptop_id': 'Surface Pro 12 inch', 'price_vnd': '34.490.000đ', 'criterion_scores': {'CPU_SCORE': {'score': 3, 'reason': 'Snapdragon Xplus (8 lõi) - Hiệu năng tầm trung'}, 'GPU_SCORE': {'score': 1, 'reason': 'Adreno GPU (Tích hợp)'}, 'NPU_SCORE': {'score': 4, 'reason': 'Qualcomm Hexagon 45 TOPS'}, 'RAM_SCORE': {'score': 3, 'reason': '16GB LPDDR5x, Onboard không nâng cấp'}, 'SSD_SCORE': {'score': 3, 'reason': '512GB Gen4'}, 'UPGRADABILITY': {'score': 1, 'reason': 'RAM và SSD đều không nâng cấp được (Onboard)'}, 'DISPLAY_SCORE': {'score': 2, 'sub_scores': {'SIZE': 2, 'PANEL': 3, 'HZ': 2, 'COLOR': 3, 'ANTIGLARE': 2}, 'reason': '12 inch FHD IPS, tần số quét 90Hz, chất lượng màu trung bình.'}, 'PORTS_SCORE': {'score': 3, 'reason': '2 x USB-C, 1 x Keyboard port'}, 'WIFI_SCORE': {'score': 5, 'reason': 'Wi-Fi 7 + Bluetooth 5.4'}, 'WEIGHT_SCORE': {'score': 5, 'reason': '<1.2kg (686 g)'}, 'BATTERY_SCORE': {'score': 2, 'reason': '38 Wh'}, 'CHARGING_SCORE': {'score': 2, 'reason': 'N/A (Không đề cập chi tiết về công suất sạc)'}, 'KEYBOARD_SCORE': {'score': 2, 'reason': 'Không có đèn nền'}, 'WEBCAM_SCORE': {'score': 4, 'reason': 'Full HD (1080p) với camera sau 10MP'}, 'AUDIO_SCORE': {'score': 3, 'reason': 'Loa stereo 2W, Dolby Atmos'}, 'SECURITY_SCORE': {'score': 4, 'reason': 'Microsoft Pluton TPM 2.0, Windows Hello nhận diện khuôn mặt'}, 'THERMAL_SCORE': {'score': 2, 'reason': 'N/A (Không có thông tin chi tiết về hệ thống tản nhiệt)'}, 'WARRANTY_SCORE': {'score': 3, 'reason': '1 năm bảo hành, trung tâm BH đầy đủ tại VN'}}, 'profile_scores': {'U1_student': {'profile_name': 'Học sinh / Sinh viên', 'price_range_vnd': [0, 20000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U1: RAM (16GB) >= 8GB, SSD (512GB Gen4) != HDD/eMMC, Warranty OK.', 'price_score': 1, 'weighted_score': 3.1, 'final_score': 3.1, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U2_office': {'profile_name': 'Nhân viên văn phòng', 'price_range_vnd': [12000000, 25000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U3_freelancer': {'profile_name': 'Freelancer / Làm việc di động', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 3, 'weighted_score': 3.4, 'final_score': 3.4, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U4_tech_expert': {'profile_name': 'Chuyên gia kỹ thuật', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U5_gamer': {'profile_name': 'Game thủ', 'price_range_vnd': [18000000, 60000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U6_creator': {'profile_name': 'Sáng tạo nội dung / Creator', 'price_range_vnd': [25000000, 70000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.6, 'final_score': 3.6, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U7_ai_data': {'profile_name': 'AI / Data Science', 'price_range_vnd': [30000000, 80000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U8_business': {'profile_name': 'Kinh doanh / Doanh nghiệp', 'price_range_vnd': [20000000, 50000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 4, 'weighted_score': 3.8, 'final_score': 3.8, 'stars': 4, 'fit_level': 'Phù hợp tốt'}, 'U9_tech_student': {'profile_name': 'Sinh viên chuyên ngành kỹ thuật', 'price_range_vnd': [15000000, 35000000], 'deal_breaker_triggered': True, 'deal_breaker_reason': 'U9: UPGRADABILITY (1/8), CPU (3 lõi < 4 lõi).', 'price_score': 3, 'weighted_score': 2.8, 'final_score': 2.8, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}, 'U10_entertainment': {'profile_name': 'Giải trí / Gia đình', 'price_range_vnd': [0, 15000000], 'deal_breaker_triggered': False, 'deal_breaker_reason': None, 'price_score': 5, 'weighted_score': 2.6, 'final_score': 2.6, 'stars': 3, 'fit_level': 'Phù hợp cơ bản'}}, 'summary': {'best_fit_profiles': ['U4_tech_expert', 'U5_gamer', 'U6_creator', 'U7_ai_data', 'U8_business'], 'acceptable_profiles': ['U1_student', 'U2_office', 'U3_freelancer', 'U9_tech_student', 'U10_entertainment'], 'not_suitable_profiles': []}}
]
